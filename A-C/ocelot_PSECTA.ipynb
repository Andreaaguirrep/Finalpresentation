# %%
from ocelot import *
from ocelot.cpbd.elements import *
from ocelot.gui.accelerator import *
from ocelot.cpbd.track import track_debug
import matplotlib.pyplot as plt


from PSECTA import *


lat = MagneticLattice(lattice_list)



##### PA1RFGUN #####
AX =-21.12   
BX =24.36 
AY =-21.16     
BY =24.42      
EMITX =1.2023504614117648e-06
EMITY =1.2023504614117648e-06 
DP =.01
##### PA1RFGUN #####

energy = 0.0091 # GeV  #why?
tw0 = Twiss()
tw0.alpha_x = AX
tw0.beta_x = BX

tw0.alpha_y = AY
tw0.beta_y = BY
tw0.E = energy
tw0.emit_xn = EMITX 
tw0.emit_yn = EMITY
tw0.emit_x = EMITX   / energy * 0.511e-3
tw0.emit_y = EMITY / energy * 0.511e-3

tws = twiss(lat,tw0)

plot_opt_func(lat, tws,legend=False, grid=False, top_plot=['Dx','Dy'])

# %%
start_index = next(i for i, el in enumerate(lattice_list) if el.id == "PA1RFGUN")
end_index = next(i for i, el in enumerate(lattice_list) if el.id == "L491")

sub_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

R = lattice_transfer_map(sub_lat, energy=1.5)
print("R56 = ", R[4,5]*1000, "mm")
# Out:
# R56 =  -23.38775880448409 mm

# %%
def gauss_from_twiss_vec(emit, beta, alpha, size=1):
    phi = 2 * np.pi * np.random.rand(size)
    u = np.random.rand(size)
    a = np.sqrt(-2 * np.log(1 - u) * emit)
    x = a * np.sqrt(beta) * np.cos(phi)
    xp = -a / np.sqrt(beta) * (np.sin(phi) + alpha * np.cos(phi))
    return x, xp

nparticles = 100000
p_array = ParticleArray(n=nparticles)

sigma_tau = 6.7e-3  # (bunch length in time)
sigma_p = 5.e-4     # relative momentum spread (Δp/p)  

p_array.E = energy  # GeV

# Longitudinal
p_array.rparticles[4] = np.random.randn(nparticles) * sigma_tau
p_array.rparticles[5] = np.random.randn(nparticles) * sigma_p

# Transverse: vectorized sampling from Twiss parameters
x, xp = gauss_from_twiss_vec(tw0.emit_x, tw0.beta_x, tw0.alpha_x, size=nparticles)
y, yp = gauss_from_twiss_vec(tw0.emit_y, tw0.beta_y, tw0.alpha_y, size=nparticles)

p_array.rparticles[0] = x
p_array.rparticles[1] = xp
p_array.rparticles[2] = y
p_array.rparticles[3] = yp

# Charge distribution
charge = 4.0e-9  # nC
p_array.q_array = np.ones(nparticles) * (charge / nparticles)

# %%
plt.hist(p_array.rparticles[0], bins=100, alpha=0.7, label='x')
plt.hist(p_array.rparticles[1], bins=100, alpha=0.7, label="x'")
plt.legend()
plt.show()

plt.hist(p_array.rparticles[2], bins=100, alpha=0.7, label='y')
plt.hist(p_array.rparticles[3], bins=100, alpha=0.7, label="y'")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
x = p_array.rparticles[0]
xp = p_array.rparticles[1]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_x, sigma_xp = twiss_sigmas(tw0.emit_x, tw0.beta_x, tw0.alpha_x)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='x (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='x (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="x′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_xp), 'r--', label="x′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of x and x′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
y = p_array.rparticles[2]
yp = p_array.rparticles[3]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_y, sigma_yp = twiss_sigmas(tw0.emit_y, tw0.beta_y, tw0.alpha_y)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='y (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='y (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="y′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_yp), 'r--', label="y′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of y and y′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def check_beam_stats(p_array, twiss, axis_label="x"):
    idx = 0 if axis_label == "x" else 2
    idxp = 1 if axis_label == "x" else 3

    sigma = np.std(p_array.rparticles[idx])
    sigmap = np.std(p_array.rparticles[idxp])

    beta = getattr(twiss, f"beta_{axis_label}")
    alpha = getattr(twiss, f"alpha_{axis_label}")
    emit = getattr(twiss, f"emit_{axis_label}")

    sigma_theo = np.sqrt(beta * emit)
    gamma = (1 + alpha**2) / beta
    sigmap_theo = np.sqrt(gamma * emit)

    print(f"σ_{axis_label} (simulated):     {sigma}")
    print(f"σ_{axis_label} (theoretical):   {sigma_theo}")
    print(f"σ_{axis_label}' (simulated):    {sigmap}")
    print(f"σ_{axis_label}' (theoretical):  {sigmap_theo}")

# %%
check_beam_stats(p_array, tw0, axis_label="x")
# Out:
# σ_x (simulated):     0.0012801290483762599
# σ_x (theoretical):   0.001282460309333141
# σ_x' (simulated):    0.0011111985768642758
# σ_x' (theoretical):  0.0011131324306998926

# %%
check_beam_stats(p_array, tw0, axis_label="y")
# Out:
# σ_y (simulated):     0.0012886113586607019
# σ_y (theoretical):   0.001284038722618926
# σ_y' (simulated):    0.0011179198783284135
# σ_y' (theoretical):  0.0011138650134345758

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- X plane ---
x = p_array.rparticles[0]
xp = p_array.rparticles[1]
emit_x = tw0.emit_x
beta_x = tw0.beta_x
alpha_x = tw0.alpha_x

theta = np.linspace(0, 2*np.pi, 400)
x_ellipse = np.sqrt(emit_x * beta_x) * np.cos(theta)
xp_ellipse = (-alpha_x * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_x / beta_x)

# --- Y plane ---
y = p_array.rparticles[2]
yp = p_array.rparticles[3]
emit_y = tw0.emit_y
beta_y = tw0.beta_y
alpha_y = tw0.alpha_y

y_ellipse = np.sqrt(emit_y * beta_y) * np.cos(theta)
yp_ellipse = (-alpha_y * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_y / beta_y)

# --- Plot ---
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# x-x'
axes[0].scatter(x, xp, s=1, alpha=0.3, label='Particles')
axes[0].plot(x_ellipse, xp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[0].set_xlabel('x [m]')
axes[0].set_ylabel("x′ [rad]")
axes[0].set_title('Phase space: x vs x′')
axes[0].grid(True)
axes[0].axis('equal')
axes[0].legend()

# y-y'
axes[1].scatter(y, yp, s=1, alpha=0.3, color='orange', label='Particles')
axes[1].plot(y_ellipse, yp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[1].set_xlabel('y [m]')
axes[1].set_ylabel("y′ [rad]")
axes[1].set_title('Phase space: y vs y′')
axes[1].grid(True)
axes[1].axis('equal')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy

def plot_emittances_vs_s(p_array, nparts_in_slice=5000, smooth_param=0.05,
                         tau_units="m", inverse_tau=False, grid=True,
                         title="Normalized Emittances vs s", figsize=(8, 4),
                         filename=None):
    """
    Plot normalized emittances vs longitudinal position s (head-tail slicing).

    :param p_array: ParticleArray object
    :param nparts_in_slice: number of particles per slice
    :param smooth_param: smoothing parameter used in slice analysis
    :param tau_units: 'm', 'mm', or 'um'
    :param inverse_tau: flip the tau axis
    :param grid: show grid
    :param title: plot title
    :param figsize: matplotlib figsize
    :param filename: optional path to save the plot
    """
    # Set scale for s-axis
    tau_factors = {"m": 1, "mm": 1e3, "um": 1e6}
    tau_factor = tau_factors.get(tau_units, 1e3)
    tau_label = f"$s\,[\\mathrm{{{tau_units}}}]$"

    # Deepcopy to preserve original
    p_array_copy = deepcopy(p_array)
    if inverse_tau:
        p_array_copy.tau()[:] *= -1

    # Perform slice analysis (assumes this function exists in your codebase)
    slice_params = global_slice_analysis(p_array_copy, nparts_in_slice, smooth_param)

    # Extract and convert to proper units
    s = slice_params.s * tau_factor
    emit_x = slice_params.exn * 1e6  # [mm·mrad]
    emit_y = slice_params.eyn * 1e6

    # Plot
    plt.figure(figsize=figsize)
    plt.plot(s, emit_x, label=r"$\varepsilon_x$", color='red')
    plt.plot(s, emit_y, label=r"$\varepsilon_y$", color='blue')
    plt.xlabel(tau_label)
    plt.ylabel(r"Normalized Emittance [$\mathrm{mm\cdot{}mrad}$]")
    plt.title(title)
    plt.legend()
    if grid:
        plt.grid(True)
    if filename:
        plt.savefig(filename)
    plt.tight_layout()
    plt.show()

# %%
show_e_beam(p_array)

# %%
plot_emittances_vs_s(p_array)

# %%
import time
from copy import deepcopy
import numpy as np
import matplotlib.pyplot as plt
from ocelot.cpbd.physics_proc import PhysProc

# Create the Navigator
navi = Navigator(lat)
navi.unit_step = 0.1  # high-resolution steps

# CSR example (optional)
# csr = CSR(n_bin=500, m_bin=5, sigma_min=.2e-6)
# navi.add_physics_proc(csr, csrm1_start, csrm1_end)

# Define the hook as a physics process
class HookProcess(PhysProc):
    def __init__(self, sigma_tau_list):
        super().__init__()
        self.sigma_tau_list = sigma_tau_list

    def apply(self, p_array, step_size):
        sigma_tau = np.std(p_array.rparticles[4])
        self.sigma_tau_list.append(sigma_tau)
        print(f"s = {self.z0:.3f} m, σ_τ = {sigma_tau:.3e} s")

# Attach the custom hook process
sigma_tau_list = []
hook_proc = HookProcess(sigma_tau_list)
navi.add_physics_proc(hook_proc, lat.sequence[0], lat.sequence[-1])

# Track
p_array_t = deepcopy(p_array)
start = time.time()
tws_track, p_array_t = track(lat, p_array_t, navi)
print("\n time exec:", time.time() - start, "sec")

# Plot
print("sigma_tau_list length:", len(sigma_tau_list))
print("lat.totalLen:", lat.totalLen)

s_axis = np.linspace(0, lat.totalLen, len(sigma_tau_list))
plt.plot(s_axis, sigma_tau_list)
plt.xlabel("s [m]")
plt.ylabel("σ_τ [s]")
plt.title("Evolution of Bunch Length σ_τ Along the Lattice")
plt.grid(True)
plt.show()
# Out:
# s = 0.100 m, σ_τ = 6.682e-03 s
# z = 0.1 / 239.41012539999994. Applied: HookProcesss = 0.200 m, σ_τ = 6.682e-03 s
# z = 0.2 / 239.41012539999994. Applied: HookProcesss = 0.300 m, σ_τ = 6.682e-03 s
# z = 0.30000000000000004 / 239.41012539999994. Applied: HookProcesss = 0.400 m, σ_τ = 6.682e-03 s
# z = 0.4 / 239.41012539999994. Applied: HookProcesss = 0.500 m, σ_τ = 6.682e-03 s
# z = 0.5 / 239.41012539999994. Applied: HookProcesss = 0.600 m, σ_τ = 6.682e-03 s
# z = 0.6 / 239.41012539999994. Applied: HookProcesss = 0.700 m, σ_τ = 6.682e-03 s
# z = 0.7 / 239.41012539999994. Applied: HookProcesss = 0.800 m, σ_τ = 6.682e-03 s
# z = 0.7999999999999999 / 239.41012539999994. Applied: HookProcesss = 0.900 m, σ_τ = 6.682e-03 s
# z = 0.8999999999999999 / 239.41012539999994. Applied: HookProcesss = 1.000 m, σ_τ = 6.682e-03 s
# z = 0.9999999999999999 / 239.41012539999994. Applied: HookProcesss = 1.100 m, σ_τ = 6.682e-03 s
# z = 1.0999999999999999 / 239.41012539999994. Applied: HookProcesss = 1.200 m, σ_τ = 6.682e-03 s
# z = 1.2 / 239.41012539999994. Applied: HookProcesss = 1.300 m, σ_τ = 6.682e-03 s
# z = 1.3 / 239.41012539999994. Applied: HookProcesss = 1.400 m, σ_τ = 6.682e-03 s
# z = 1.4000000000000001 / 239.41012539999994. Applied: HookProcesss = 1.500 m, σ_τ = 6.682e-03 s
# z = 1.5000000000000002 / 239.41012539999994. Applied: HookProcesss = 1.600 m, σ_τ = 6.682e-03 s
# z = 1.6000000000000003 / 239.41012539999994. Applied: HookProcesss = 1.700 m, σ_τ = 6.682e-03 s
# z = 1.7000000000000004 / 239.41012539999994. Applied: HookProcesss = 1.800 m, σ_τ = 6.682e-03 s
# z = 1.8000000000000005 / 239.41012539999994. Applied: HookProcesss = 1.900 m, σ_τ = 6.684e-03 s
# z = 1.9000000000000006 / 239.41012539999994. Applied: HookProcesss = 2.000 m, σ_τ = 6.692e-03 s
# z = 2.0000000000000004 / 239.41012539999994. Applied: HookProcesss = 2.100 m, σ_τ = 6.704e-03 s
# z = 2.1000000000000005 / 239.41012539999994. Applied: HookProcesss = 2.200 m, σ_τ = 6.719e-03 s
# z = 2.2000000000000006 / 239.41012539999994. Applied: HookProcesss = 2.300 m, σ_τ = 6.735e-03 s
# z = 2.3000000000000007 / 239.41012539999994. Applied: HookProcesss = 2.400 m, σ_τ = 6.753e-03 s
# z = 2.400000000000001 / 239.41012539999994. Applied: HookProcesss = 2.500 m, σ_τ = 6.770e-03 s
# z = 2.500000000000001 / 239.41012539999994. Applied: HookProcesss = 2.600 m, σ_τ = 6.788e-03 s
# z = 2.600000000000001 / 239.41012539999994. Applied: HookProcesss = 2.700 m, σ_τ = 6.806e-03 s
# z = 2.700000000000001 / 239.41012539999994. Applied: HookProcesss = 2.800 m, σ_τ = 6.823e-03 s
# z = 2.800000000000001 / 239.41012539999994. Applied: HookProcesss = 2.900 m, σ_τ = 6.840e-03 s
# z = 2.9000000000000012 / 239.41012539999994. Applied: HookProcesss = 3.000 m, σ_τ = 6.856e-03 s
# z = 3.0000000000000013 / 239.41012539999994. Applied: HookProcesss = 3.100 m, σ_τ = 6.872e-03 s
# z = 3.1000000000000014 / 239.41012539999994. Applied: HookProcesss = 3.200 m, σ_τ = 6.887e-03 s
# z = 3.2000000000000015 / 239.41012539999994. Applied: HookProcesss = 3.300 m, σ_τ = 6.902e-03 s
# z = 3.3000000000000016 / 239.41012539999994. Applied: HookProcesss = 3.400 m, σ_τ = 6.916e-03 s
# z = 3.4000000000000017 / 239.41012539999994. Applied: HookProcesss = 3.500 m, σ_τ = 6.930e-03 s
# z = 3.5000000000000018 / 239.41012539999994. Applied: HookProcesss = 3.600 m, σ_τ = 6.943e-03 s
# z = 3.600000000000002 / 239.41012539999994. Applied: HookProcesss = 3.700 m, σ_τ = 6.956e-03 s
# z = 3.700000000000002 / 239.41012539999994. Applied: HookProcesss = 3.800 m, σ_τ = 6.965e-03 s
# z = 3.800000000000002 / 239.41012539999994. Applied: HookProcesss = 3.900 m, σ_τ = 6.974e-03 s
# z = 3.900000000000002 / 239.41012539999994. Applied: HookProcesss = 4.000 m, σ_τ = 6.982e-03 s
# z = 4.000000000000002 / 239.41012539999994. Applied: HookProcesss = 4.100 m, σ_τ = 6.991e-03 s
# z = 4.100000000000001 / 239.41012539999994. Applied: HookProcesss = 4.200 m, σ_τ = 7.000e-03 s
# z = 4.200000000000001 / 239.41012539999994. Applied: HookProcesss = 4.300 m, σ_τ = 7.008e-03 s
# z = 4.300000000000001 / 239.41012539999994. Applied: HookProcesss = 4.400 m, σ_τ = 7.017e-03 s
# z = 4.4 / 239.41012539999994. Applied: HookProcesss = 4.500 m, σ_τ = 7.026e-03 s
# z = 4.5 / 239.41012539999994. Applied: HookProcesss = 4.600 m, σ_τ = 7.034e-03 s
# z = 4.6 / 239.41012539999994. Applied: HookProcesss = 4.700 m, σ_τ = 7.035e-03 s
# z = 4.699999999999999 / 239.41012539999994. Applied: HookProcesss = 4.800 m, σ_τ = 6.924e-03 s
# z = 4.799999999999999 / 239.41012539999994. Applied: HookProcesss = 4.900 m, σ_τ = 6.933e-03 s
# z = 4.899999999999999 / 239.41012539999994. Applied: HookProcesss = 5.000 m, σ_τ = 6.941e-03 s
# z = 4.999999999999998 / 239.41012539999994. Applied: HookProcesss = 5.100 m, σ_τ = 6.950e-03 s
# z = 5.099999999999998 / 239.41012539999994. Applied: HookProcesss = 5.200 m, σ_τ = 7.903e-03 s
# z = 5.1999999999999975 / 239.41012539999994. Applied: HookProcesss = 5.300 m, σ_τ = 9.512e-03 s
# z = 5.299999999999997 / 239.41012539999994. Applied: HookProcesss = 5.400 m, σ_τ = 9.521e-03 s
# z = 5.399999999999997 / 239.41012539999994. Applied: HookProcesss = 5.500 m, σ_τ = 9.530e-03 s
# z = 5.4999999999999964 / 239.41012539999994. Applied: HookProcesss = 5.600 m, σ_τ = 1.061e-02 s
# z = 5.599999999999996 / 239.41012539999994. Applied: HookProcesss = 5.700 m, σ_τ = 1.214e-02 s
# z = 5.699999999999996 / 239.41012539999994. Applied: HookProcesss = 5.800 m, σ_τ = 1.214e-02 s
# z = 5.799999999999995 / 239.41012539999994. Applied: HookProcesss = 5.900 m, σ_τ = 1.215e-02 s
# z = 5.899999999999995 / 239.41012539999994. Applied: HookProcesss = 6.000 m, σ_τ = 1.216e-02 s
# z = 5.999999999999995 / 239.41012539999994. Applied: HookProcesss = 6.100 m, σ_τ = 1.207e-02 s
# z = 6.099999999999994 / 239.41012539999994. Applied: HookProcesss = 6.200 m, σ_τ = 1.205e-02 s
# z = 6.199999999999994 / 239.41012539999994. Applied: HookProcesss = 6.300 m, σ_τ = 1.206e-02 s
# z = 6.299999999999994 / 239.41012539999994. Applied: HookProcesss = 6.400 m, σ_τ = 1.207e-02 s
# z = 6.399999999999993 / 239.41012539999994. Applied: HookProcesss = 6.500 m, σ_τ = 1.207e-02 s
# z = 6.499999999999993 / 239.41012539999994. Applied: HookProcesss = 6.600 m, σ_τ = 1.208e-02 s
# z = 6.5999999999999925 / 239.41012539999994. Applied: HookProcesss = 6.700 m, σ_τ = 1.209e-02 s
# z = 6.699999999999992 / 239.41012539999994. Applied: HookProcesss = 6.800 m, σ_τ = 1.210e-02 s
# z = 6.799999999999992 / 239.41012539999994. Applied: HookProcesss = 6.900 m, σ_τ = 1.211e-02 s
# z = 6.8999999999999915 / 239.41012539999994. Applied: HookProcesss = 7.000 m, σ_τ = 1.212e-02 s
# z = 6.999999999999991 / 239.41012539999994. Applied: HookProcesss = 7.100 m, σ_τ = 1.213e-02 s
# z = 7.099999999999991 / 239.41012539999994. Applied: HookProcesss = 7.200 m, σ_τ = 1.214e-02 s
# z = 7.19999999999999 / 239.41012539999994. Applied: HookProcesss = 7.300 m, σ_τ = 1.215e-02 s
# z = 7.29999999999999 / 239.41012539999994. Applied: HookProcesss = 7.400 m, σ_τ = 1.215e-02 s
# z = 7.39999999999999 / 239.41012539999994. Applied: HookProcesss = 7.500 m, σ_τ = 1.216e-02 s
# z = 7.499999999999989 / 239.41012539999994. Applied: HookProcesss = 7.600 m, σ_τ = 1.217e-02 s
# z = 7.599999999999989 / 239.41012539999994. Applied: HookProcesss = 7.700 m, σ_τ = 1.218e-02 s
# z = 7.699999999999989 / 239.41012539999994. Applied: HookProcesss = 7.800 m, σ_τ = 1.219e-02 s
# z = 7.799999999999988 / 239.41012539999994. Applied: HookProcesss = 7.900 m, σ_τ = 1.220e-02 s
# z = 7.899999999999988 / 239.41012539999994. Applied: HookProcesss = 8.000 m, σ_τ = 1.221e-02 s
# z = 7.999999999999988 / 239.41012539999994. Applied: HookProcesss = 8.100 m, σ_τ = 1.222e-02 s
# z = 8.099999999999987 / 239.41012539999994. Applied: HookProcesss = 8.200 m, σ_τ = 1.223e-02 s
# z = 8.199999999999987 / 239.41012539999994. Applied: HookProcesss = 8.300 m, σ_τ = 1.224e-02 s
# z = 8.299999999999986 / 239.41012539999994. Applied: HookProcesss = 8.400 m, σ_τ = 1.224e-02 s
# z = 8.399999999999986 / 239.41012539999994. Applied: HookProcesss = 8.500 m, σ_τ = 1.225e-02 s
# z = 8.499999999999986 / 239.41012539999994. Applied: HookProcesss = 8.600 m, σ_τ = 1.226e-02 s
# z = 8.599999999999985 / 239.41012539999994. Applied: HookProcesss = 8.700 m, σ_τ = 1.227e-02 s
# z = 8.699999999999985 / 239.41012539999994. Applied: HookProcesss = 8.800 m, σ_τ = 1.228e-02 s
# z = 8.799999999999985 / 239.41012539999994. Applied: HookProcesss = 8.900 m, σ_τ = 1.229e-02 s
# z = 8.899999999999984 / 239.41012539999994. Applied: HookProcesss = 9.000 m, σ_τ = 1.230e-02 s
# z = 8.999999999999984 / 239.41012539999994. Applied: HookProcesss = 9.100 m, σ_τ = 1.231e-02 s
# z = 9.099999999999984 / 239.41012539999994. Applied: HookProcesss = 9.200 m, σ_τ = 1.232e-02 s
# z = 9.199999999999983 / 239.41012539999994. Applied: HookProcesss = 9.300 m, σ_τ = 1.232e-02 s
# z = 9.299999999999983 / 239.41012539999994. Applied: HookProcesss = 9.400 m, σ_τ = 1.233e-02 s
# z = 9.399999999999983 / 239.41012539999994. Applied: HookProcesss = 9.500 m, σ_τ = 1.234e-02 s
# z = 9.499999999999982 / 239.41012539999994. Applied: HookProcesss = 9.600 m, σ_τ = 1.235e-02 s
# z = 9.599999999999982 / 239.41012539999994. Applied: HookProcesss = 9.700 m, σ_τ = 1.236e-02 s
# z = 9.699999999999982 / 239.41012539999994. Applied: HookProcesss = 9.800 m, σ_τ = 1.237e-02 s
# z = 9.799999999999981 / 239.41012539999994. Applied: HookProcesss = 9.900 m, σ_τ = 1.239e-02 s
# z = 9.89999999999998 / 239.41012539999994. Applied: HookProcesss = 10.000 m, σ_τ = 1.240e-02 s
# z = 9.99999999999998 / 239.41012539999994. Applied: HookProcesss = 10.100 m, σ_τ = 1.240e-02 s
# z = 10.09999999999998 / 239.41012539999994. Applied: HookProcesss = 10.200 m, σ_τ = 1.241e-02 s
# z = 10.19999999999998 / 239.41012539999994. Applied: HookProcesss = 10.300 m, σ_τ = 1.242e-02 s
# z = 10.29999999999998 / 239.41012539999994. Applied: HookProcesss = 10.400 m, σ_τ = 1.243e-02 s
# z = 10.399999999999979 / 239.41012539999994. Applied: HookProcesss = 10.500 m, σ_τ = 1.244e-02 s
# z = 10.499999999999979 / 239.41012539999994. Applied: HookProcesss = 10.600 m, σ_τ = 1.244e-02 s
# z = 10.599999999999978 / 239.41012539999994. Applied: HookProcesss = 10.700 m, σ_τ = 1.245e-02 s
# z = 10.699999999999978 / 239.41012539999994. Applied: HookProcesss = 10.800 m, σ_τ = 1.245e-02 s
# z = 10.799999999999978 / 239.41012539999994. Applied: HookProcesss = 10.900 m, σ_τ = 1.246e-02 s
# z = 10.899999999999977 / 239.41012539999994. Applied: HookProcesss = 11.000 m, σ_τ = 1.246e-02 s
# z = 10.999999999999977 / 239.41012539999994. Applied: HookProcesss = 11.100 m, σ_τ = 1.247e-02 s
# z = 11.099999999999977 / 239.41012539999994. Applied: HookProcesss = 11.200 m, σ_τ = 1.247e-02 s
# z = 11.199999999999976 / 239.41012539999994. Applied: HookProcesss = 11.300 m, σ_τ = 1.248e-02 s
# z = 11.299999999999976 / 239.41012539999994. Applied: HookProcesss = 11.400 m, σ_τ = 1.248e-02 s
# z = 11.399999999999975 / 239.41012539999994. Applied: HookProcesss = 11.500 m, σ_τ = 1.248e-02 s
# z = 11.499999999999975 / 239.41012539999994. Applied: HookProcesss = 11.600 m, σ_τ = 1.249e-02 s
# z = 11.599999999999975 / 239.41012539999994. Applied: HookProcesss = 11.700 m, σ_τ = 1.249e-02 s
# z = 11.699999999999974 / 239.41012539999994. Applied: HookProcesss = 11.800 m, σ_τ = 1.249e-02 s
# z = 11.799999999999974 / 239.41012539999994. Applied: HookProcesss = 11.900 m, σ_τ = 1.249e-02 s
# z = 11.899999999999974 / 239.41012539999994. Applied: HookProcesss = 12.000 m, σ_τ = 1.249e-02 s
# z = 11.999999999999973 / 239.41012539999994. Applied: HookProcesss = 12.100 m, σ_τ = 1.250e-02 s
# z = 12.099999999999973 / 239.41012539999994. Applied: HookProcesss = 12.200 m, σ_τ = 1.250e-02 s
# z = 12.199999999999973 / 239.41012539999994. Applied: HookProcesss = 12.300 m, σ_τ = 1.250e-02 s
# z = 12.299999999999972 / 239.41012539999994. Applied: HookProcesss = 12.400 m, σ_τ = 1.250e-02 s
# z = 12.399999999999972 / 239.41012539999994. Applied: HookProcesss = 12.500 m, σ_τ = 1.250e-02 s
# z = 12.499999999999972 / 239.41012539999994. Applied: HookProcesss = 12.600 m, σ_τ = 1.251e-02 s
# z = 12.599999999999971 / 239.41012539999994. Applied: HookProcesss = 12.700 m, σ_τ = 1.251e-02 s
# z = 12.69999999999997 / 239.41012539999994. Applied: HookProcesss = 12.800 m, σ_τ = 1.251e-02 s
# z = 12.79999999999997 / 239.41012539999994. Applied: HookProcesss = 12.900 m, σ_τ = 1.251e-02 s
# z = 12.89999999999997 / 239.41012539999994. Applied: HookProcesss = 13.000 m, σ_τ = 1.252e-02 s
# z = 12.99999999999997 / 239.41012539999994. Applied: HookProcesss = 13.100 m, σ_τ = 1.252e-02 s
# z = 13.09999999999997 / 239.41012539999994. Applied: HookProcesss = 13.200 m, σ_τ = 1.252e-02 s
# z = 13.199999999999969 / 239.41012539999994. Applied: HookProcesss = 13.300 m, σ_τ = 1.252e-02 s
# z = 13.299999999999969 / 239.41012539999994. Applied: HookProcesss = 13.400 m, σ_τ = 1.253e-02 s
# z = 13.399999999999968 / 239.41012539999994. Applied: HookProcesss = 13.500 m, σ_τ = 1.253e-02 s
# z = 13.499999999999968 / 239.41012539999994. Applied: HookProcesss = 13.600 m, σ_τ = 1.253e-02 s
# z = 13.599999999999968 / 239.41012539999994. Applied: HookProcesss = 13.700 m, σ_τ = 1.253e-02 s
# z = 13.699999999999967 / 239.41012539999994. Applied: HookProcesss = 13.800 m, σ_τ = 1.254e-02 s
# z = 13.799999999999967 / 239.41012539999994. Applied: HookProcesss = 13.900 m, σ_τ = 1.254e-02 s
# z = 13.899999999999967 / 239.41012539999994. Applied: HookProcesss = 14.000 m, σ_τ = 1.254e-02 s
# z = 13.999999999999966 / 239.41012539999994. Applied: HookProcesss = 14.100 m, σ_τ = 1.254e-02 s
# z = 14.099999999999966 / 239.41012539999994. Applied: HookProcesss = 14.200 m, σ_τ = 1.254e-02 s
# z = 14.199999999999966 / 239.41012539999994. Applied: HookProcesss = 14.300 m, σ_τ = 1.254e-02 s
# z = 14.299999999999965 / 239.41012539999994. Applied: HookProcesss = 14.400 m, σ_τ = 1.255e-02 s
# z = 14.399999999999965 / 239.41012539999994. Applied: HookProcesss = 14.500 m, σ_τ = 1.255e-02 s
# z = 14.499999999999964 / 239.41012539999994. Applied: HookProcesss = 14.600 m, σ_τ = 1.255e-02 s
# z = 14.599999999999964 / 239.41012539999994. Applied: HookProcesss = 14.700 m, σ_τ = 1.255e-02 s
# z = 14.699999999999964 / 239.41012539999994. Applied: HookProcesss = 14.800 m, σ_τ = 1.255e-02 s
# z = 14.799999999999963 / 239.41012539999994. Applied: HookProcesss = 14.900 m, σ_τ = 1.255e-02 s
# z = 14.899999999999963 / 239.41012539999994. Applied: HookProcesss = 15.000 m, σ_τ = 1.255e-02 s
# z = 14.999999999999963 / 239.41012539999994. Applied: HookProcesss = 15.100 m, σ_τ = 1.255e-02 s
# z = 15.099999999999962 / 239.41012539999994. Applied: HookProcesss = 15.200 m, σ_τ = 1.255e-02 s
# z = 15.199999999999962 / 239.41012539999994. Applied: HookProcesss = 15.300 m, σ_τ = 1.255e-02 s
# z = 15.299999999999962 / 239.41012539999994. Applied: HookProcesss = 15.400 m, σ_τ = 1.255e-02 s
# z = 15.399999999999961 / 239.41012539999994. Applied: HookProcesss = 15.500 m, σ_τ = 1.255e-02 s
# z = 15.499999999999961 / 239.41012539999994. Applied: HookProcesss = 15.600 m, σ_τ = 1.255e-02 s
# z = 15.59999999999996 / 239.41012539999994. Applied: HookProcesss = 15.700 m, σ_τ = 1.256e-02 s
# z = 15.69999999999996 / 239.41012539999994. Applied: HookProcesss = 15.800 m, σ_τ = 1.256e-02 s
# z = 15.79999999999996 / 239.41012539999994. Applied: HookProcesss = 15.900 m, σ_τ = 1.256e-02 s
# z = 15.89999999999996 / 239.41012539999994. Applied: HookProcesss = 16.000 m, σ_τ = 1.256e-02 s
# z = 15.99999999999996 / 239.41012539999994. Applied: HookProcesss = 16.100 m, σ_τ = 1.256e-02 s
# z = 16.09999999999996 / 239.41012539999994. Applied: HookProcesss = 16.200 m, σ_τ = 1.256e-02 s
# z = 16.19999999999996 / 239.41012539999994. Applied: HookProcesss = 16.300 m, σ_τ = 1.256e-02 s
# z = 16.29999999999996 / 239.41012539999994. Applied: HookProcesss = 16.400 m, σ_τ = 1.256e-02 s
# z = 16.399999999999963 / 239.41012539999994. Applied: HookProcesss = 16.500 m, σ_τ = 1.257e-02 s
# z = 16.499999999999964 / 239.41012539999994. Applied: HookProcesss = 16.600 m, σ_τ = 1.257e-02 s
# z = 16.599999999999966 / 239.41012539999994. Applied: HookProcesss = 16.700 m, σ_τ = 1.257e-02 s
# z = 16.699999999999967 / 239.41012539999994. Applied: HookProcesss = 16.800 m, σ_τ = 1.257e-02 s
# z = 16.79999999999997 / 239.41012539999994. Applied: HookProcesss = 16.900 m, σ_τ = 1.257e-02 s
# z = 16.89999999999997 / 239.41012539999994. Applied: HookProcesss = 17.000 m, σ_τ = 1.257e-02 s
# z = 16.99999999999997 / 239.41012539999994. Applied: HookProcesss = 17.100 m, σ_τ = 1.257e-02 s
# z = 17.099999999999973 / 239.41012539999994. Applied: HookProcesss = 17.200 m, σ_τ = 1.257e-02 s
# z = 17.199999999999974 / 239.41012539999994. Applied: HookProcesss = 17.300 m, σ_τ = 1.257e-02 s
# z = 17.299999999999976 / 239.41012539999994. Applied: HookProcesss = 17.400 m, σ_τ = 1.257e-02 s
# z = 17.399999999999977 / 239.41012539999994. Applied: HookProcesss = 17.500 m, σ_τ = 1.257e-02 s
# z = 17.49999999999998 / 239.41012539999994. Applied: HookProcesss = 17.600 m, σ_τ = 1.257e-02 s
# z = 17.59999999999998 / 239.41012539999994. Applied: HookProcesss = 17.700 m, σ_τ = 1.257e-02 s
# z = 17.69999999999998 / 239.41012539999994. Applied: HookProcesss = 17.800 m, σ_τ = 1.258e-02 s
# z = 17.799999999999983 / 239.41012539999994. Applied: HookProcesss = 17.900 m, σ_τ = 1.258e-02 s
# z = 17.899999999999984 / 239.41012539999994. Applied: HookProcesss = 18.000 m, σ_τ = 1.258e-02 s
# z = 17.999999999999986 / 239.41012539999994. Applied: HookProcesss = 18.100 m, σ_τ = 1.258e-02 s
# z = 18.099999999999987 / 239.41012539999994. Applied: HookProcesss = 18.200 m, σ_τ = 1.258e-02 s
# z = 18.19999999999999 / 239.41012539999994. Applied: HookProcesss = 18.300 m, σ_τ = 1.258e-02 s
# z = 18.29999999999999 / 239.41012539999994. Applied: HookProcesss = 18.400 m, σ_τ = 1.258e-02 s
# z = 18.39999999999999 / 239.41012539999994. Applied: HookProcesss = 18.500 m, σ_τ = 1.258e-02 s
# z = 18.499999999999993 / 239.41012539999994. Applied: HookProcesss = 18.600 m, σ_τ = 1.258e-02 s
# z = 18.599999999999994 / 239.41012539999994. Applied: HookProcesss = 18.700 m, σ_τ = 1.258e-02 s
# z = 18.699999999999996 / 239.41012539999994. Applied: HookProcesss = 18.800 m, σ_τ = 1.258e-02 s
# z = 18.799999999999997 / 239.41012539999994. Applied: HookProcesss = 18.900 m, σ_τ = 1.258e-02 s
# z = 18.9 / 239.41012539999994. Applied: HookProcesss = 19.000 m, σ_τ = 1.258e-02 s
# z = 19.0 / 239.41012539999994. Applied: HookProcesss = 19.100 m, σ_τ = 1.258e-02 s
# z = 19.1 / 239.41012539999994. Applied: HookProcesss = 19.200 m, σ_τ = 1.258e-02 s
# z = 19.200000000000003 / 239.41012539999994. Applied: HookProcesss = 19.300 m, σ_τ = 1.258e-02 s
# z = 19.300000000000004 / 239.41012539999994. Applied: HookProcesss = 19.400 m, σ_τ = 1.259e-02 s
# z = 19.400000000000006 / 239.41012539999994. Applied: HookProcesss = 19.500 m, σ_τ = 1.259e-02 s
# z = 19.500000000000007 / 239.41012539999994. Applied: HookProcesss = 19.600 m, σ_τ = 1.259e-02 s
# z = 19.60000000000001 / 239.41012539999994. Applied: HookProcesss = 19.700 m, σ_τ = 1.259e-02 s
# z = 19.70000000000001 / 239.41012539999994. Applied: HookProcesss = 19.800 m, σ_τ = 1.259e-02 s
# z = 19.80000000000001 / 239.41012539999994. Applied: HookProcesss = 19.900 m, σ_τ = 1.259e-02 s
# z = 19.900000000000013 / 239.41012539999994. Applied: HookProcesss = 20.000 m, σ_τ = 1.259e-02 s
# z = 20.000000000000014 / 239.41012539999994. Applied: HookProcesss = 20.100 m, σ_τ = 1.259e-02 s
# z = 20.100000000000016 / 239.41012539999994. Applied: HookProcesss = 20.200 m, σ_τ = 1.259e-02 s
# z = 20.200000000000017 / 239.41012539999994. Applied: HookProcesss = 20.300 m, σ_τ = 1.259e-02 s
# z = 20.30000000000002 / 239.41012539999994. Applied: HookProcesss = 20.400 m, σ_τ = 1.259e-02 s
# z = 20.40000000000002 / 239.41012539999994. Applied: HookProcesss = 20.500 m, σ_τ = 1.259e-02 s
# z = 20.50000000000002 / 239.41012539999994. Applied: HookProcesss = 20.600 m, σ_τ = 1.259e-02 s
# z = 20.600000000000023 / 239.41012539999994. Applied: HookProcesss = 20.700 m, σ_τ = 1.259e-02 s
# z = 20.700000000000024 / 239.41012539999994. Applied: HookProcesss = 20.800 m, σ_τ = 1.259e-02 s
# z = 20.800000000000026 / 239.41012539999994. Applied: HookProcesss = 20.900 m, σ_τ = 1.259e-02 s
# z = 20.900000000000027 / 239.41012539999994. Applied: HookProcesss = 21.000 m, σ_τ = 1.259e-02 s
# z = 21.00000000000003 / 239.41012539999994. Applied: HookProcesss = 21.100 m, σ_τ = 1.259e-02 s
# z = 21.10000000000003 / 239.41012539999994. Applied: HookProcesss = 21.200 m, σ_τ = 1.259e-02 s
# z = 21.20000000000003 / 239.41012539999994. Applied: HookProcesss = 21.300 m, σ_τ = 1.259e-02 s
# z = 21.300000000000033 / 239.41012539999994. Applied: HookProcesss = 21.400 m, σ_τ = 1.259e-02 s
# z = 21.400000000000034 / 239.41012539999994. Applied: HookProcesss = 21.500 m, σ_τ = 1.259e-02 s
# z = 21.500000000000036 / 239.41012539999994. Applied: HookProcesss = 21.600 m, σ_τ = 1.259e-02 s
# z = 21.600000000000037 / 239.41012539999994. Applied: HookProcesss = 21.700 m, σ_τ = 1.259e-02 s
# z = 21.70000000000004 / 239.41012539999994. Applied: HookProcesss = 21.800 m, σ_τ = 1.259e-02 s
# z = 21.80000000000004 / 239.41012539999994. Applied: HookProcesss = 21.900 m, σ_τ = 1.259e-02 s
# z = 21.90000000000004 / 239.41012539999994. Applied: HookProcesss = 22.000 m, σ_τ = 1.260e-02 s
# z = 22.000000000000043 / 239.41012539999994. Applied: HookProcesss = 22.100 m, σ_τ = 1.260e-02 s
# z = 22.100000000000044 / 239.41012539999994. Applied: HookProcesss = 22.200 m, σ_τ = 1.260e-02 s
# z = 22.200000000000045 / 239.41012539999994. Applied: HookProcesss = 22.300 m, σ_τ = 1.260e-02 s
# z = 22.300000000000047 / 239.41012539999994. Applied: HookProcesss = 22.400 m, σ_τ = 1.260e-02 s
# z = 22.40000000000005 / 239.41012539999994. Applied: HookProcesss = 22.500 m, σ_τ = 1.260e-02 s
# z = 22.50000000000005 / 239.41012539999994. Applied: HookProcesss = 22.600 m, σ_τ = 1.260e-02 s
# z = 22.60000000000005 / 239.41012539999994. Applied: HookProcesss = 22.700 m, σ_τ = 1.260e-02 s
# z = 22.700000000000053 / 239.41012539999994. Applied: HookProcesss = 22.800 m, σ_τ = 1.260e-02 s
# z = 22.800000000000054 / 239.41012539999994. Applied: HookProcesss = 22.900 m, σ_τ = 1.260e-02 s
# z = 22.900000000000055 / 239.41012539999994. Applied: HookProcesss = 23.000 m, σ_τ = 1.260e-02 s
# z = 23.000000000000057 / 239.41012539999994. Applied: HookProcesss = 23.100 m, σ_τ = 1.260e-02 s
# z = 23.10000000000006 / 239.41012539999994. Applied: HookProcesss = 23.200 m, σ_τ = 1.260e-02 s
# z = 23.20000000000006 / 239.41012539999994. Applied: HookProcesss = 23.300 m, σ_τ = 1.260e-02 s
# z = 23.30000000000006 / 239.41012539999994. Applied: HookProcesss = 23.400 m, σ_τ = 1.260e-02 s
# z = 23.400000000000063 / 239.41012539999994. Applied: HookProcesss = 23.500 m, σ_τ = 1.260e-02 s
# z = 23.500000000000064 / 239.41012539999994. Applied: HookProcesss = 23.600 m, σ_τ = 1.260e-02 s
# z = 23.600000000000065 / 239.41012539999994. Applied: HookProcesss = 23.700 m, σ_τ = 1.260e-02 s
# z = 23.700000000000067 / 239.41012539999994. Applied: HookProcesss = 23.800 m, σ_τ = 1.260e-02 s
# z = 23.800000000000068 / 239.41012539999994. Applied: HookProcesss = 23.900 m, σ_τ = 1.260e-02 s
# z = 23.90000000000007 / 239.41012539999994. Applied: HookProcesss = 24.000 m, σ_τ = 1.260e-02 s
# z = 24.00000000000007 / 239.41012539999994. Applied: HookProcesss = 24.100 m, σ_τ = 1.260e-02 s
# z = 24.100000000000072 / 239.41012539999994. Applied: HookProcesss = 24.200 m, σ_τ = 1.260e-02 s
# z = 24.200000000000074 / 239.41012539999994. Applied: HookProcesss = 24.300 m, σ_τ = 1.260e-02 s
# z = 24.300000000000075 / 239.41012539999994. Applied: HookProcesss = 24.400 m, σ_τ = 1.260e-02 s
# z = 24.400000000000077 / 239.41012539999994. Applied: HookProcesss = 24.500 m, σ_τ = 1.260e-02 s
# z = 24.500000000000078 / 239.41012539999994. Applied: HookProcesss = 24.600 m, σ_τ = 1.260e-02 s
# z = 24.60000000000008 / 239.41012539999994. Applied: HookProcesss = 24.700 m, σ_τ = 1.261e-02 s
# z = 24.70000000000008 / 239.41012539999994. Applied: HookProcesss = 24.800 m, σ_τ = 1.261e-02 s
# z = 24.800000000000082 / 239.41012539999994. Applied: HookProcesss = 24.900 m, σ_τ = 1.261e-02 s
# z = 24.900000000000084 / 239.41012539999994. Applied: HookProcesss = 25.000 m, σ_τ = 1.261e-02 s
# z = 25.000000000000085 / 239.41012539999994. Applied: HookProcesss = 25.100 m, σ_τ = 1.261e-02 s
# z = 25.100000000000087 / 239.41012539999994. Applied: HookProcesss = 25.200 m, σ_τ = 1.261e-02 s
# z = 25.200000000000088 / 239.41012539999994. Applied: HookProcesss = 25.300 m, σ_τ = 1.261e-02 s
# z = 25.30000000000009 / 239.41012539999994. Applied: HookProcesss = 25.400 m, σ_τ = 1.261e-02 s
# z = 25.40000000000009 / 239.41012539999994. Applied: HookProcesss = 25.500 m, σ_τ = 1.261e-02 s
# z = 25.500000000000092 / 239.41012539999994. Applied: HookProcesss = 25.600 m, σ_τ = 1.261e-02 s
# z = 25.600000000000094 / 239.41012539999994. Applied: HookProcesss = 25.700 m, σ_τ = 1.261e-02 s
# z = 25.700000000000095 / 239.41012539999994. Applied: HookProcesss = 25.800 m, σ_τ = 1.261e-02 s
# z = 25.800000000000097 / 239.41012539999994. Applied: HookProcesss = 25.900 m, σ_τ = 1.261e-02 s
# z = 25.900000000000098 / 239.41012539999994. Applied: HookProcesss = 26.000 m, σ_τ = 1.261e-02 s
# z = 26.0000000000001 / 239.41012539999994. Applied: HookProcesss = 26.100 m, σ_τ = 1.261e-02 s
# z = 26.1000000000001 / 239.41012539999994. Applied: HookProcesss = 26.200 m, σ_τ = 1.261e-02 s
# z = 26.200000000000102 / 239.41012539999994. Applied: HookProcesss = 26.300 m, σ_τ = 1.261e-02 s
# z = 26.300000000000104 / 239.41012539999994. Applied: HookProcesss = 26.400 m, σ_τ = 1.261e-02 s
# z = 26.400000000000105 / 239.41012539999994. Applied: HookProcesss = 26.500 m, σ_τ = 1.261e-02 s
# z = 26.500000000000107 / 239.41012539999994. Applied: HookProcesss = 26.600 m, σ_τ = 1.261e-02 s
# z = 26.600000000000108 / 239.41012539999994. Applied: HookProcesss = 26.700 m, σ_τ = 1.261e-02 s
# z = 26.70000000000011 / 239.41012539999994. Applied: HookProcesss = 26.800 m, σ_τ = 1.261e-02 s
# z = 26.80000000000011 / 239.41012539999994. Applied: HookProcesss = 26.900 m, σ_τ = 1.261e-02 s
# z = 26.900000000000112 / 239.41012539999994. Applied: HookProcesss = 27.000 m, σ_τ = 1.261e-02 s
# z = 27.000000000000114 / 239.41012539999994. Applied: HookProcesss = 27.100 m, σ_τ = 1.261e-02 s
# z = 27.100000000000115 / 239.41012539999994. Applied: HookProcesss = 27.200 m, σ_τ = 1.261e-02 s
# z = 27.200000000000117 / 239.41012539999994. Applied: HookProcesss = 27.300 m, σ_τ = 1.261e-02 s
# z = 27.300000000000118 / 239.41012539999994. Applied: HookProcesss = 27.400 m, σ_τ = 1.261e-02 s
# z = 27.40000000000012 / 239.41012539999994. Applied: HookProcesss = 27.500 m, σ_τ = 1.261e-02 s
# z = 27.50000000000012 / 239.41012539999994. Applied: HookProcesss = 27.600 m, σ_τ = 1.261e-02 s
# z = 27.600000000000122 / 239.41012539999994. Applied: HookProcesss = 27.700 m, σ_τ = 1.261e-02 s
# z = 27.700000000000124 / 239.41012539999994. Applied: HookProcesss = 27.800 m, σ_τ = 1.261e-02 s
# z = 27.800000000000125 / 239.41012539999994. Applied: HookProcesss = 27.900 m, σ_τ = 1.261e-02 s
# z = 27.900000000000126 / 239.41012539999994. Applied: HookProcesss = 28.000 m, σ_τ = 1.261e-02 s
# z = 28.000000000000128 / 239.41012539999994. Applied: HookProcesss = 28.100 m, σ_τ = 1.261e-02 s
# z = 28.10000000000013 / 239.41012539999994. Applied: HookProcesss = 28.200 m, σ_τ = 1.261e-02 s
# z = 28.20000000000013 / 239.41012539999994. Applied: HookProcesss = 28.300 m, σ_τ = 1.261e-02 s
# z = 28.300000000000132 / 239.41012539999994. Applied: HookProcesss = 28.400 m, σ_τ = 1.261e-02 s
# z = 28.400000000000134 / 239.41012539999994. Applied: HookProcesss = 28.500 m, σ_τ = 1.261e-02 s
# z = 28.500000000000135 / 239.41012539999994. Applied: HookProcesss = 28.600 m, σ_τ = 1.261e-02 s
# z = 28.600000000000136 / 239.41012539999994. Applied: HookProcesss = 28.700 m, σ_τ = 1.261e-02 s
# z = 28.700000000000138 / 239.41012539999994. Applied: HookProcesss = 28.800 m, σ_τ = 1.261e-02 s
# z = 28.80000000000014 / 239.41012539999994. Applied: HookProcesss = 28.900 m, σ_τ = 1.261e-02 s
# z = 28.90000000000014 / 239.41012539999994. Applied: HookProcesss = 29.000 m, σ_τ = 1.261e-02 s
# z = 29.000000000000142 / 239.41012539999994. Applied: HookProcesss = 29.100 m, σ_τ = 1.261e-02 s
# z = 29.100000000000144 / 239.41012539999994. Applied: HookProcesss = 29.200 m, σ_τ = 1.261e-02 s
# z = 29.200000000000145 / 239.41012539999994. Applied: HookProcesss = 29.300 m, σ_τ = 1.261e-02 s
# z = 29.300000000000146 / 239.41012539999994. Applied: HookProcesss = 29.400 m, σ_τ = 1.261e-02 s
# z = 29.400000000000148 / 239.41012539999994. Applied: HookProcesss = 29.500 m, σ_τ = 1.261e-02 s
# z = 29.50000000000015 / 239.41012539999994. Applied: HookProcesss = 29.600 m, σ_τ = 1.261e-02 s
# z = 29.60000000000015 / 239.41012539999994. Applied: HookProcesss = 29.700 m, σ_τ = 1.261e-02 s
# z = 29.700000000000152 / 239.41012539999994. Applied: HookProcesss = 29.800 m, σ_τ = 1.261e-02 s
# z = 29.800000000000153 / 239.41012539999994. Applied: HookProcesss = 29.900 m, σ_τ = 1.261e-02 s
# z = 29.900000000000155 / 239.41012539999994. Applied: HookProcesss = 30.000 m, σ_τ = 1.261e-02 s
# z = 30.000000000000156 / 239.41012539999994. Applied: HookProcesss = 30.100 m, σ_τ = 1.262e-02 s
# z = 30.100000000000158 / 239.41012539999994. Applied: HookProcesss = 30.200 m, σ_τ = 1.262e-02 s
# z = 30.20000000000016 / 239.41012539999994. Applied: HookProcesss = 30.300 m, σ_τ = 1.262e-02 s
# z = 30.30000000000016 / 239.41012539999994. Applied: HookProcesss = 30.400 m, σ_τ = 1.262e-02 s
# z = 30.400000000000162 / 239.41012539999994. Applied: HookProcesss = 30.500 m, σ_τ = 1.262e-02 s
# z = 30.500000000000163 / 239.41012539999994. Applied: HookProcesss = 30.600 m, σ_τ = 1.262e-02 s
# z = 30.600000000000165 / 239.41012539999994. Applied: HookProcesss = 30.700 m, σ_τ = 1.262e-02 s
# z = 30.700000000000166 / 239.41012539999994. Applied: HookProcesss = 30.800 m, σ_τ = 1.262e-02 s
# z = 30.800000000000168 / 239.41012539999994. Applied: HookProcesss = 30.900 m, σ_τ = 1.262e-02 s
# z = 30.90000000000017 / 239.41012539999994. Applied: HookProcesss = 31.000 m, σ_τ = 1.262e-02 s
# z = 31.00000000000017 / 239.41012539999994. Applied: HookProcesss = 31.100 m, σ_τ = 1.262e-02 s
# z = 31.100000000000172 / 239.41012539999994. Applied: HookProcesss = 31.200 m, σ_τ = 1.262e-02 s
# z = 31.200000000000173 / 239.41012539999994. Applied: HookProcesss = 31.300 m, σ_τ = 1.262e-02 s
# z = 31.300000000000175 / 239.41012539999994. Applied: HookProcesss = 31.400 m, σ_τ = 1.262e-02 s
# z = 31.400000000000176 / 239.41012539999994. Applied: HookProcesss = 31.500 m, σ_τ = 1.262e-02 s
# z = 31.500000000000178 / 239.41012539999994. Applied: HookProcesss = 31.600 m, σ_τ = 1.262e-02 s
# z = 31.60000000000018 / 239.41012539999994. Applied: HookProcesss = 31.700 m, σ_τ = 1.262e-02 s
# z = 31.70000000000018 / 239.41012539999994. Applied: HookProcesss = 31.800 m, σ_τ = 1.262e-02 s
# z = 31.800000000000182 / 239.41012539999994. Applied: HookProcesss = 31.900 m, σ_τ = 1.262e-02 s
# z = 31.900000000000183 / 239.41012539999994. Applied: HookProcesss = 32.000 m, σ_τ = 1.262e-02 s
# z = 32.000000000000185 / 239.41012539999994. Applied: HookProcesss = 32.100 m, σ_τ = 1.262e-02 s
# z = 32.100000000000186 / 239.41012539999994. Applied: HookProcesss = 32.200 m, σ_τ = 1.262e-02 s
# z = 32.20000000000019 / 239.41012539999994. Applied: HookProcesss = 32.300 m, σ_τ = 1.262e-02 s
# z = 32.30000000000019 / 239.41012539999994. Applied: HookProcesss = 32.400 m, σ_τ = 1.262e-02 s
# z = 32.40000000000019 / 239.41012539999994. Applied: HookProcesss = 32.500 m, σ_τ = 1.262e-02 s
# z = 32.50000000000019 / 239.41012539999994. Applied: HookProcesss = 32.600 m, σ_τ = 1.262e-02 s
# z = 32.60000000000019 / 239.41012539999994. Applied: HookProcesss = 32.700 m, σ_τ = 1.262e-02 s
# z = 32.700000000000195 / 239.41012539999994. Applied: HookProcesss = 32.800 m, σ_τ = 1.262e-02 s
# z = 32.800000000000196 / 239.41012539999994. Applied: HookProcesss = 32.900 m, σ_τ = 1.262e-02 s
# z = 32.9000000000002 / 239.41012539999994. Applied: HookProcesss = 33.000 m, σ_τ = 1.262e-02 s
# z = 33.0000000000002 / 239.41012539999994. Applied: HookProcesss = 33.100 m, σ_τ = 1.262e-02 s
# z = 33.1000000000002 / 239.41012539999994. Applied: HookProcesss = 33.200 m, σ_τ = 1.262e-02 s
# z = 33.2000000000002 / 239.41012539999994. Applied: HookProcesss = 33.300 m, σ_τ = 1.262e-02 s
# z = 33.3000000000002 / 239.41012539999994. Applied: HookProcesss = 33.400 m, σ_τ = 1.262e-02 s
# z = 33.400000000000205 / 239.41012539999994. Applied: HookProcesss = 33.500 m, σ_τ = 1.262e-02 s
# z = 33.500000000000206 / 239.41012539999994. Applied: HookProcesss = 33.600 m, σ_τ = 1.262e-02 s
# z = 33.60000000000021 / 239.41012539999994. Applied: HookProcesss = 33.700 m, σ_τ = 1.262e-02 s
# z = 33.70000000000021 / 239.41012539999994. Applied: HookProcesss = 33.800 m, σ_τ = 1.262e-02 s
# z = 33.80000000000021 / 239.41012539999994. Applied: HookProcesss = 33.900 m, σ_τ = 1.262e-02 s
# z = 33.90000000000021 / 239.41012539999994. Applied: HookProcesss = 34.000 m, σ_τ = 1.262e-02 s
# z = 34.00000000000021 / 239.41012539999994. Applied: HookProcesss = 34.100 m, σ_τ = 1.262e-02 s
# z = 34.100000000000215 / 239.41012539999994. Applied: HookProcesss = 34.200 m, σ_τ = 1.262e-02 s
# z = 34.200000000000216 / 239.41012539999994. Applied: HookProcesss = 34.300 m, σ_τ = 1.262e-02 s
# z = 34.30000000000022 / 239.41012539999994. Applied: HookProcesss = 34.400 m, σ_τ = 1.262e-02 s
# z = 34.40000000000022 / 239.41012539999994. Applied: HookProcesss = 34.500 m, σ_τ = 1.262e-02 s
# z = 34.50000000000022 / 239.41012539999994. Applied: HookProcesss = 34.600 m, σ_τ = 1.262e-02 s
# z = 34.60000000000022 / 239.41012539999994. Applied: HookProcesss = 34.700 m, σ_τ = 1.262e-02 s
# z = 34.70000000000022 / 239.41012539999994. Applied: HookProcesss = 34.800 m, σ_τ = 1.262e-02 s
# z = 34.800000000000225 / 239.41012539999994. Applied: HookProcesss = 34.900 m, σ_τ = 1.262e-02 s
# z = 34.900000000000226 / 239.41012539999994. Applied: HookProcesss = 35.000 m, σ_τ = 1.262e-02 s
# z = 35.00000000000023 / 239.41012539999994. Applied: HookProcesss = 35.100 m, σ_τ = 1.262e-02 s
# z = 35.10000000000023 / 239.41012539999994. Applied: HookProcesss = 35.200 m, σ_τ = 1.262e-02 s
# z = 35.20000000000023 / 239.41012539999994. Applied: HookProcesss = 35.300 m, σ_τ = 1.262e-02 s
# z = 35.30000000000023 / 239.41012539999994. Applied: HookProcesss = 35.400 m, σ_τ = 1.262e-02 s
# z = 35.40000000000023 / 239.41012539999994. Applied: HookProcesss = 35.500 m, σ_τ = 1.262e-02 s
# z = 35.500000000000234 / 239.41012539999994. Applied: HookProcesss = 35.600 m, σ_τ = 1.262e-02 s
# z = 35.600000000000236 / 239.41012539999994. Applied: HookProcesss = 35.700 m, σ_τ = 1.262e-02 s
# z = 35.70000000000024 / 239.41012539999994. Applied: HookProcesss = 35.800 m, σ_τ = 1.262e-02 s
# z = 35.80000000000024 / 239.41012539999994. Applied: HookProcesss = 35.900 m, σ_τ = 1.262e-02 s
# z = 35.90000000000024 / 239.41012539999994. Applied: HookProcesss = 36.000 m, σ_τ = 1.262e-02 s
# z = 36.00000000000024 / 239.41012539999994. Applied: HookProcesss = 36.100 m, σ_τ = 1.262e-02 s
# z = 36.10000000000024 / 239.41012539999994. Applied: HookProcesss = 36.200 m, σ_τ = 1.262e-02 s
# z = 36.200000000000244 / 239.41012539999994. Applied: HookProcesss = 36.300 m, σ_τ = 1.262e-02 s
# z = 36.300000000000246 / 239.41012539999994. Applied: HookProcesss = 36.400 m, σ_τ = 1.262e-02 s
# z = 36.40000000000025 / 239.41012539999994. Applied: HookProcesss = 36.500 m, σ_τ = 1.262e-02 s
# z = 36.50000000000025 / 239.41012539999994. Applied: HookProcesss = 36.600 m, σ_τ = 1.262e-02 s
# z = 36.60000000000025 / 239.41012539999994. Applied: HookProcesss = 36.700 m, σ_τ = 1.262e-02 s
# z = 36.70000000000025 / 239.41012539999994. Applied: HookProcesss = 36.800 m, σ_τ = 1.262e-02 s
# z = 36.80000000000025 / 239.41012539999994. Applied: HookProcesss = 36.900 m, σ_τ = 1.262e-02 s
# z = 36.900000000000254 / 239.41012539999994. Applied: HookProcesss = 37.000 m, σ_τ = 1.262e-02 s
# z = 37.000000000000256 / 239.41012539999994. Applied: HookProcesss = 37.100 m, σ_τ = 1.262e-02 s
# z = 37.10000000000026 / 239.41012539999994. Applied: HookProcesss = 37.200 m, σ_τ = 1.262e-02 s
# z = 37.20000000000026 / 239.41012539999994. Applied: HookProcesss = 37.300 m, σ_τ = 1.262e-02 s
# z = 37.30000000000026 / 239.41012539999994. Applied: HookProcesss = 37.400 m, σ_τ = 1.262e-02 s
# z = 37.40000000000026 / 239.41012539999994. Applied: HookProcesss = 37.500 m, σ_τ = 1.262e-02 s
# z = 37.50000000000026 / 239.41012539999994. Applied: HookProcesss = 37.600 m, σ_τ = 1.262e-02 s
# z = 37.600000000000264 / 239.41012539999994. Applied: HookProcesss = 37.700 m, σ_τ = 1.262e-02 s
# z = 37.700000000000266 / 239.41012539999994. Applied: HookProcesss = 37.800 m, σ_τ = 1.262e-02 s
# z = 37.80000000000027 / 239.41012539999994. Applied: HookProcesss = 37.900 m, σ_τ = 1.262e-02 s
# z = 37.90000000000027 / 239.41012539999994. Applied: HookProcesss = 38.000 m, σ_τ = 1.262e-02 s
# z = 38.00000000000027 / 239.41012539999994. Applied: HookProcesss = 38.100 m, σ_τ = 1.262e-02 s
# z = 38.10000000000027 / 239.41012539999994. Applied: HookProcesss = 38.200 m, σ_τ = 1.262e-02 s
# z = 38.20000000000027 / 239.41012539999994. Applied: HookProcesss = 38.300 m, σ_τ = 1.262e-02 s
# z = 38.300000000000274 / 239.41012539999994. Applied: HookProcesss = 38.400 m, σ_τ = 1.262e-02 s
# z = 38.400000000000276 / 239.41012539999994. Applied: HookProcesss = 38.500 m, σ_τ = 1.262e-02 s
# z = 38.50000000000028 / 239.41012539999994. Applied: HookProcesss = 38.600 m, σ_τ = 1.262e-02 s
# z = 38.60000000000028 / 239.41012539999994. Applied: HookProcesss = 38.700 m, σ_τ = 1.262e-02 s
# z = 38.70000000000028 / 239.41012539999994. Applied: HookProcesss = 38.800 m, σ_τ = 1.262e-02 s
# z = 38.80000000000028 / 239.41012539999994. Applied: HookProcesss = 38.900 m, σ_τ = 1.262e-02 s
# z = 38.90000000000028 / 239.41012539999994. Applied: HookProcesss = 39.000 m, σ_τ = 1.262e-02 s
# z = 39.000000000000284 / 239.41012539999994. Applied: HookProcesss = 39.100 m, σ_τ = 1.262e-02 s
# z = 39.100000000000286 / 239.41012539999994. Applied: HookProcesss = 39.200 m, σ_τ = 1.262e-02 s
# z = 39.20000000000029 / 239.41012539999994. Applied: HookProcesss = 39.300 m, σ_τ = 1.262e-02 s
# z = 39.30000000000029 / 239.41012539999994. Applied: HookProcesss = 39.400 m, σ_τ = 1.262e-02 s
# z = 39.40000000000029 / 239.41012539999994. Applied: HookProcesss = 39.500 m, σ_τ = 1.262e-02 s
# z = 39.50000000000029 / 239.41012539999994. Applied: HookProcesss = 39.600 m, σ_τ = 1.262e-02 s
# z = 39.60000000000029 / 239.41012539999994. Applied: HookProcesss = 39.700 m, σ_τ = 1.262e-02 s
# z = 39.700000000000294 / 239.41012539999994. Applied: HookProcesss = 39.800 m, σ_τ = 1.262e-02 s
# z = 39.800000000000296 / 239.41012539999994. Applied: HookProcesss = 39.900 m, σ_τ = 1.262e-02 s
# z = 39.9000000000003 / 239.41012539999994. Applied: HookProcesss = 40.000 m, σ_τ = 1.262e-02 s
# z = 40.0000000000003 / 239.41012539999994. Applied: HookProcesss = 40.100 m, σ_τ = 1.262e-02 s
# z = 40.1000000000003 / 239.41012539999994. Applied: HookProcesss = 40.200 m, σ_τ = 1.262e-02 s
# z = 40.2000000000003 / 239.41012539999994. Applied: HookProcesss = 40.300 m, σ_τ = 1.262e-02 s
# z = 40.3000000000003 / 239.41012539999994. Applied: HookProcesss = 40.400 m, σ_τ = 1.262e-02 s
# z = 40.400000000000304 / 239.41012539999994. Applied: HookProcesss = 40.500 m, σ_τ = 1.262e-02 s
# z = 40.500000000000306 / 239.41012539999994. Applied: HookProcesss = 40.600 m, σ_τ = 1.262e-02 s
# z = 40.60000000000031 / 239.41012539999994. Applied: HookProcesss = 40.700 m, σ_τ = 1.262e-02 s
# z = 40.70000000000031 / 239.41012539999994. Applied: HookProcesss = 40.800 m, σ_τ = 1.262e-02 s
# z = 40.80000000000031 / 239.41012539999994. Applied: HookProcesss = 40.900 m, σ_τ = 1.262e-02 s
# z = 40.90000000000031 / 239.41012539999994. Applied: HookProcesss = 41.000 m, σ_τ = 1.262e-02 s
# z = 41.00000000000031 / 239.41012539999994. Applied: HookProcesss = 41.100 m, σ_τ = 1.262e-02 s
# z = 41.100000000000314 / 239.41012539999994. Applied: HookProcesss = 41.200 m, σ_τ = 1.262e-02 s
# z = 41.200000000000315 / 239.41012539999994. Applied: HookProcesss = 41.300 m, σ_τ = 1.262e-02 s
# z = 41.30000000000032 / 239.41012539999994. Applied: HookProcesss = 41.400 m, σ_τ = 1.262e-02 s
# z = 41.40000000000032 / 239.41012539999994. Applied: HookProcesss = 41.500 m, σ_τ = 1.262e-02 s
# z = 41.50000000000032 / 239.41012539999994. Applied: HookProcesss = 41.600 m, σ_τ = 1.262e-02 s
# z = 41.60000000000032 / 239.41012539999994. Applied: HookProcesss = 41.700 m, σ_τ = 1.262e-02 s
# z = 41.70000000000032 / 239.41012539999994. Applied: HookProcesss = 41.800 m, σ_τ = 1.262e-02 s
# z = 41.800000000000324 / 239.41012539999994. Applied: HookProcesss = 41.900 m, σ_τ = 1.262e-02 s
# z = 41.900000000000325 / 239.41012539999994. Applied: HookProcesss = 42.000 m, σ_τ = 1.262e-02 s
# z = 42.00000000000033 / 239.41012539999994. Applied: HookProcesss = 42.100 m, σ_τ = 1.262e-02 s
# z = 42.10000000000033 / 239.41012539999994. Applied: HookProcesss = 42.200 m, σ_τ = 1.262e-02 s
# z = 42.20000000000033 / 239.41012539999994. Applied: HookProcesss = 42.300 m, σ_τ = 1.262e-02 s
# z = 42.30000000000033 / 239.41012539999994. Applied: HookProcesss = 42.400 m, σ_τ = 1.262e-02 s
# z = 42.40000000000033 / 239.41012539999994. Applied: HookProcesss = 42.500 m, σ_τ = 1.262e-02 s
# z = 42.500000000000334 / 239.41012539999994. Applied: HookProcesss = 42.600 m, σ_τ = 1.262e-02 s
# z = 42.600000000000335 / 239.41012539999994. Applied: HookProcesss = 42.700 m, σ_τ = 1.262e-02 s
# z = 42.70000000000034 / 239.41012539999994. Applied: HookProcesss = 42.800 m, σ_τ = 1.262e-02 s
# z = 42.80000000000034 / 239.41012539999994. Applied: HookProcesss = 42.900 m, σ_τ = 1.262e-02 s
# z = 42.90000000000034 / 239.41012539999994. Applied: HookProcesss = 43.000 m, σ_τ = 1.263e-02 s
# z = 43.00000000000034 / 239.41012539999994. Applied: HookProcesss = 43.100 m, σ_τ = 1.263e-02 s
# z = 43.10000000000034 / 239.41012539999994. Applied: HookProcesss = 43.200 m, σ_τ = 1.263e-02 s
# z = 43.200000000000344 / 239.41012539999994. Applied: HookProcesss = 43.300 m, σ_τ = 1.263e-02 s
# z = 43.300000000000345 / 239.41012539999994. Applied: HookProcesss = 43.400 m, σ_τ = 1.263e-02 s
# z = 43.40000000000035 / 239.41012539999994. Applied: HookProcesss = 43.500 m, σ_τ = 1.263e-02 s
# z = 43.50000000000035 / 239.41012539999994. Applied: HookProcesss = 43.600 m, σ_τ = 1.263e-02 s
# z = 43.60000000000035 / 239.41012539999994. Applied: HookProcesss = 43.700 m, σ_τ = 1.263e-02 s
# z = 43.70000000000035 / 239.41012539999994. Applied: HookProcesss = 43.800 m, σ_τ = 1.263e-02 s
# z = 43.80000000000035 / 239.41012539999994. Applied: HookProcesss = 43.900 m, σ_τ = 1.263e-02 s
# z = 43.900000000000354 / 239.41012539999994. Applied: HookProcesss = 44.000 m, σ_τ = 1.263e-02 s
# z = 44.000000000000355 / 239.41012539999994. Applied: HookProcesss = 44.100 m, σ_τ = 1.263e-02 s
# z = 44.10000000000036 / 239.41012539999994. Applied: HookProcesss = 44.200 m, σ_τ = 1.263e-02 s
# z = 44.20000000000036 / 239.41012539999994. Applied: HookProcesss = 44.300 m, σ_τ = 1.263e-02 s
# z = 44.30000000000036 / 239.41012539999994. Applied: HookProcesss = 44.400 m, σ_τ = 1.263e-02 s
# z = 44.40000000000036 / 239.41012539999994. Applied: HookProcesss = 44.500 m, σ_τ = 1.263e-02 s
# z = 44.50000000000036 / 239.41012539999994. Applied: HookProcesss = 44.600 m, σ_τ = 1.263e-02 s
# z = 44.600000000000364 / 239.41012539999994. Applied: HookProcesss = 44.700 m, σ_τ = 1.263e-02 s
# z = 44.700000000000365 / 239.41012539999994. Applied: HookProcesss = 44.800 m, σ_τ = 1.263e-02 s
# z = 44.80000000000037 / 239.41012539999994. Applied: HookProcesss = 44.900 m, σ_τ = 1.263e-02 s
# z = 44.90000000000037 / 239.41012539999994. Applied: HookProcesss = 45.000 m, σ_τ = 1.263e-02 s
# z = 45.00000000000037 / 239.41012539999994. Applied: HookProcesss = 45.100 m, σ_τ = 1.263e-02 s
# z = 45.10000000000037 / 239.41012539999994. Applied: HookProcesss = 45.200 m, σ_τ = 1.263e-02 s
# z = 45.20000000000037 / 239.41012539999994. Applied: HookProcesss = 45.300 m, σ_τ = 1.263e-02 s
# z = 45.300000000000374 / 239.41012539999994. Applied: HookProcesss = 45.400 m, σ_τ = 1.263e-02 s
# z = 45.400000000000375 / 239.41012539999994. Applied: HookProcesss = 45.500 m, σ_τ = 1.263e-02 s
# z = 45.50000000000038 / 239.41012539999994. Applied: HookProcesss = 45.600 m, σ_τ = 1.263e-02 s
# z = 45.60000000000038 / 239.41012539999994. Applied: HookProcesss = 45.700 m, σ_τ = 1.263e-02 s
# z = 45.70000000000038 / 239.41012539999994. Applied: HookProcesss = 45.800 m, σ_τ = 1.263e-02 s
# z = 45.80000000000038 / 239.41012539999994. Applied: HookProcesss = 45.900 m, σ_τ = 1.263e-02 s
# z = 45.90000000000038 / 239.41012539999994. Applied: HookProcesss = 46.000 m, σ_τ = 1.263e-02 s
# z = 46.000000000000384 / 239.41012539999994. Applied: HookProcesss = 46.100 m, σ_τ = 1.263e-02 s
# z = 46.100000000000385 / 239.41012539999994. Applied: HookProcesss = 46.200 m, σ_τ = 1.263e-02 s
# z = 46.20000000000039 / 239.41012539999994. Applied: HookProcesss = 46.300 m, σ_τ = 1.263e-02 s
# z = 46.30000000000039 / 239.41012539999994. Applied: HookProcesss = 46.400 m, σ_τ = 1.263e-02 s
# z = 46.40000000000039 / 239.41012539999994. Applied: HookProcesss = 46.500 m, σ_τ = 1.263e-02 s
# z = 46.50000000000039 / 239.41012539999994. Applied: HookProcesss = 46.600 m, σ_τ = 1.263e-02 s
# z = 46.60000000000039 / 239.41012539999994. Applied: HookProcesss = 46.700 m, σ_τ = 1.263e-02 s
# z = 46.700000000000394 / 239.41012539999994. Applied: HookProcesss = 46.800 m, σ_τ = 1.263e-02 s
# z = 46.800000000000395 / 239.41012539999994. Applied: HookProcesss = 46.900 m, σ_τ = 1.263e-02 s
# z = 46.9000000000004 / 239.41012539999994. Applied: HookProcesss = 47.000 m, σ_τ = 1.263e-02 s
# z = 47.0000000000004 / 239.41012539999994. Applied: HookProcesss = 47.100 m, σ_τ = 1.263e-02 s
# z = 47.1000000000004 / 239.41012539999994. Applied: HookProcesss = 47.200 m, σ_τ = 1.263e-02 s
# z = 47.2000000000004 / 239.41012539999994. Applied: HookProcesss = 47.300 m, σ_τ = 1.263e-02 s
# z = 47.3000000000004 / 239.41012539999994. Applied: HookProcesss = 47.400 m, σ_τ = 1.263e-02 s
# z = 47.400000000000404 / 239.41012539999994. Applied: HookProcesss = 47.500 m, σ_τ = 1.263e-02 s
# z = 47.500000000000405 / 239.41012539999994. Applied: HookProcesss = 47.600 m, σ_τ = 1.263e-02 s
# z = 47.600000000000406 / 239.41012539999994. Applied: HookProcesss = 47.700 m, σ_τ = 1.263e-02 s
# z = 47.70000000000041 / 239.41012539999994. Applied: HookProcesss = 47.800 m, σ_τ = 1.263e-02 s
# z = 47.80000000000041 / 239.41012539999994. Applied: HookProcesss = 47.900 m, σ_τ = 1.263e-02 s
# z = 47.90000000000041 / 239.41012539999994. Applied: HookProcesss = 48.000 m, σ_τ = 1.263e-02 s
# z = 48.00000000000041 / 239.41012539999994. Applied: HookProcesss = 48.100 m, σ_τ = 1.263e-02 s
# z = 48.10000000000041 / 239.41012539999994. Applied: HookProcesss = 48.200 m, σ_τ = 1.263e-02 s
# z = 48.200000000000415 / 239.41012539999994. Applied: HookProcesss = 48.300 m, σ_τ = 1.263e-02 s
# z = 48.300000000000416 / 239.41012539999994. Applied: HookProcesss = 48.400 m, σ_τ = 1.263e-02 s
# z = 48.40000000000042 / 239.41012539999994. Applied: HookProcesss = 48.500 m, σ_τ = 1.263e-02 s
# z = 48.50000000000042 / 239.41012539999994. Applied: HookProcesss = 48.600 m, σ_τ = 1.263e-02 s
# z = 48.60000000000042 / 239.41012539999994. Applied: HookProcesss = 48.700 m, σ_τ = 1.263e-02 s
# z = 48.70000000000042 / 239.41012539999994. Applied: HookProcesss = 48.800 m, σ_τ = 1.263e-02 s
# z = 48.80000000000042 / 239.41012539999994. Applied: HookProcesss = 48.900 m, σ_τ = 1.263e-02 s
# z = 48.900000000000425 / 239.41012539999994. Applied: HookProcesss = 49.000 m, σ_τ = 1.263e-02 s
# z = 49.000000000000426 / 239.41012539999994. Applied: HookProcesss = 49.100 m, σ_τ = 1.263e-02 s
# z = 49.10000000000043 / 239.41012539999994. Applied: HookProcesss = 49.200 m, σ_τ = 1.263e-02 s
# z = 49.20000000000043 / 239.41012539999994. Applied: HookProcesss = 49.300 m, σ_τ = 1.263e-02 s
# z = 49.30000000000043 / 239.41012539999994. Applied: HookProcesss = 49.400 m, σ_τ = 1.263e-02 s
# z = 49.40000000000043 / 239.41012539999994. Applied: HookProcesss = 49.500 m, σ_τ = 1.263e-02 s
# z = 49.50000000000043 / 239.41012539999994. Applied: HookProcesss = 49.600 m, σ_τ = 1.263e-02 s
# z = 49.600000000000435 / 239.41012539999994. Applied: HookProcesss = 49.700 m, σ_τ = 1.263e-02 s
# z = 49.700000000000436 / 239.41012539999994. Applied: HookProcesss = 49.800 m, σ_τ = 1.263e-02 s
# z = 49.80000000000044 / 239.41012539999994. Applied: HookProcesss = 49.900 m, σ_τ = 1.263e-02 s
# z = 49.90000000000044 / 239.41012539999994. Applied: HookProcesss = 50.000 m, σ_τ = 1.263e-02 s
# z = 50.00000000000044 / 239.41012539999994. Applied: HookProcesss = 50.100 m, σ_τ = 1.263e-02 s
# ...
# z = 223.2999999999916 / 239.41012539999994. Applied: HookProcesss = 223.400 m, σ_τ = 1.269e-02 s
# z = 223.3999999999916 / 239.41012539999994. Applied: HookProcesss = 223.500 m, σ_τ = 1.269e-02 s
# z = 223.4999999999916 / 239.41012539999994. Applied: HookProcesss = 223.600 m, σ_τ = 1.269e-02 s
# z = 223.59999999999158 / 239.41012539999994. Applied: HookProcesss = 223.700 m, σ_τ = 1.269e-02 s
# z = 223.69999999999158 / 239.41012539999994. Applied: HookProcesss = 223.800 m, σ_τ = 1.269e-02 s
# z = 223.79999999999157 / 239.41012539999994. Applied: HookProcesss = 223.900 m, σ_τ = 1.269e-02 s
# z = 223.89999999999156 / 239.41012539999994. Applied: HookProcesss = 224.000 m, σ_τ = 1.269e-02 s
# z = 223.99999999999156 / 239.41012539999994. Applied: HookProcesss = 224.100 m, σ_τ = 1.269e-02 s
# z = 224.09999999999155 / 239.41012539999994. Applied: HookProcesss = 224.200 m, σ_τ = 1.269e-02 s
# z = 224.19999999999155 / 239.41012539999994. Applied: HookProcesss = 224.300 m, σ_τ = 1.269e-02 s
# z = 224.29999999999154 / 239.41012539999994. Applied: HookProcesss = 224.400 m, σ_τ = 1.269e-02 s
# z = 224.39999999999154 / 239.41012539999994. Applied: HookProcesss = 224.500 m, σ_τ = 1.269e-02 s
# z = 224.49999999999153 / 239.41012539999994. Applied: HookProcesss = 224.600 m, σ_τ = 1.269e-02 s
# z = 224.59999999999152 / 239.41012539999994. Applied: HookProcesss = 224.700 m, σ_τ = 1.269e-02 s
# z = 224.69999999999152 / 239.41012539999994. Applied: HookProcesss = 224.800 m, σ_τ = 1.269e-02 s
# z = 224.7999999999915 / 239.41012539999994. Applied: HookProcesss = 224.900 m, σ_τ = 1.269e-02 s
# z = 224.8999999999915 / 239.41012539999994. Applied: HookProcesss = 225.000 m, σ_τ = 1.269e-02 s
# z = 224.9999999999915 / 239.41012539999994. Applied: HookProcesss = 225.100 m, σ_τ = 1.269e-02 s
# z = 225.0999999999915 / 239.41012539999994. Applied: HookProcesss = 225.200 m, σ_τ = 1.269e-02 s
# z = 225.1999999999915 / 239.41012539999994. Applied: HookProcesss = 225.300 m, σ_τ = 1.269e-02 s
# z = 225.29999999999148 / 239.41012539999994. Applied: HookProcesss = 225.400 m, σ_τ = 1.269e-02 s
# z = 225.39999999999148 / 239.41012539999994. Applied: HookProcesss = 225.500 m, σ_τ = 1.269e-02 s
# z = 225.49999999999147 / 239.41012539999994. Applied: HookProcesss = 225.600 m, σ_τ = 1.269e-02 s
# z = 225.59999999999147 / 239.41012539999994. Applied: HookProcesss = 225.700 m, σ_τ = 1.269e-02 s
# z = 225.69999999999146 / 239.41012539999994. Applied: HookProcesss = 225.800 m, σ_τ = 1.269e-02 s
# z = 225.79999999999146 / 239.41012539999994. Applied: HookProcesss = 225.900 m, σ_τ = 1.269e-02 s
# z = 225.89999999999145 / 239.41012539999994. Applied: HookProcesss = 226.000 m, σ_τ = 1.269e-02 s
# z = 225.99999999999145 / 239.41012539999994. Applied: HookProcesss = 226.100 m, σ_τ = 1.269e-02 s
# z = 226.09999999999144 / 239.41012539999994. Applied: HookProcesss = 226.200 m, σ_τ = 1.269e-02 s
# z = 226.19999999999143 / 239.41012539999994. Applied: HookProcesss = 226.300 m, σ_τ = 1.269e-02 s
# z = 226.29999999999143 / 239.41012539999994. Applied: HookProcesss = 226.400 m, σ_τ = 1.269e-02 s
# z = 226.39999999999142 / 239.41012539999994. Applied: HookProcesss = 226.500 m, σ_τ = 1.269e-02 s
# z = 226.49999999999142 / 239.41012539999994. Applied: HookProcesss = 226.600 m, σ_τ = 1.269e-02 s
# z = 226.5999999999914 / 239.41012539999994. Applied: HookProcesss = 226.700 m, σ_τ = 1.269e-02 s
# z = 226.6999999999914 / 239.41012539999994. Applied: HookProcesss = 226.800 m, σ_τ = 1.269e-02 s
# z = 226.7999999999914 / 239.41012539999994. Applied: HookProcesss = 226.900 m, σ_τ = 1.269e-02 s
# z = 226.8999999999914 / 239.41012539999994. Applied: HookProcesss = 227.000 m, σ_τ = 1.269e-02 s
# z = 226.9999999999914 / 239.41012539999994. Applied: HookProcesss = 227.100 m, σ_τ = 1.269e-02 s
# z = 227.09999999999138 / 239.41012539999994. Applied: HookProcesss = 227.200 m, σ_τ = 1.269e-02 s
# z = 227.19999999999138 / 239.41012539999994. Applied: HookProcesss = 227.300 m, σ_τ = 1.269e-02 s
# z = 227.29999999999137 / 239.41012539999994. Applied: HookProcesss = 227.400 m, σ_τ = 1.269e-02 s
# z = 227.39999999999137 / 239.41012539999994. Applied: HookProcesss = 227.500 m, σ_τ = 1.269e-02 s
# z = 227.49999999999136 / 239.41012539999994. Applied: HookProcesss = 227.600 m, σ_τ = 1.269e-02 s
# z = 227.59999999999135 / 239.41012539999994. Applied: HookProcesss = 227.700 m, σ_τ = 1.269e-02 s
# z = 227.69999999999135 / 239.41012539999994. Applied: HookProcesss = 227.800 m, σ_τ = 1.269e-02 s
# z = 227.79999999999134 / 239.41012539999994. Applied: HookProcesss = 227.900 m, σ_τ = 1.269e-02 s
# z = 227.89999999999134 / 239.41012539999994. Applied: HookProcesss = 228.000 m, σ_τ = 1.269e-02 s
# z = 227.99999999999133 / 239.41012539999994. Applied: HookProcesss = 228.100 m, σ_τ = 1.269e-02 s
# z = 228.09999999999133 / 239.41012539999994. Applied: HookProcesss = 228.200 m, σ_τ = 1.269e-02 s
# z = 228.19999999999132 / 239.41012539999994. Applied: HookProcesss = 228.300 m, σ_τ = 1.269e-02 s
# z = 228.29999999999131 / 239.41012539999994. Applied: HookProcesss = 228.400 m, σ_τ = 1.269e-02 s
# z = 228.3999999999913 / 239.41012539999994. Applied: HookProcesss = 228.500 m, σ_τ = 1.269e-02 s
# z = 228.4999999999913 / 239.41012539999994. Applied: HookProcesss = 228.600 m, σ_τ = 1.269e-02 s
# z = 228.5999999999913 / 239.41012539999994. Applied: HookProcesss = 228.700 m, σ_τ = 1.269e-02 s
# z = 228.6999999999913 / 239.41012539999994. Applied: HookProcesss = 228.800 m, σ_τ = 1.269e-02 s
# z = 228.7999999999913 / 239.41012539999994. Applied: HookProcesss = 228.900 m, σ_τ = 1.269e-02 s
# z = 228.89999999999128 / 239.41012539999994. Applied: HookProcesss = 229.000 m, σ_τ = 1.269e-02 s
# z = 228.99999999999127 / 239.41012539999994. Applied: HookProcesss = 229.100 m, σ_τ = 1.269e-02 s
# z = 229.09999999999127 / 239.41012539999994. Applied: HookProcesss = 229.200 m, σ_τ = 1.269e-02 s
# z = 229.19999999999126 / 239.41012539999994. Applied: HookProcesss = 229.300 m, σ_τ = 1.269e-02 s
# z = 229.29999999999126 / 239.41012539999994. Applied: HookProcesss = 229.400 m, σ_τ = 1.269e-02 s
# z = 229.39999999999125 / 239.41012539999994. Applied: HookProcesss = 229.500 m, σ_τ = 1.269e-02 s
# z = 229.49999999999125 / 239.41012539999994. Applied: HookProcesss = 229.600 m, σ_τ = 1.269e-02 s
# z = 229.59999999999124 / 239.41012539999994. Applied: HookProcesss = 229.700 m, σ_τ = 1.269e-02 s
# z = 229.69999999999123 / 239.41012539999994. Applied: HookProcesss = 229.800 m, σ_τ = 1.269e-02 s
# z = 229.79999999999123 / 239.41012539999994. Applied: HookProcesss = 229.900 m, σ_τ = 1.269e-02 s
# z = 229.89999999999122 / 239.41012539999994. Applied: HookProcesss = 230.000 m, σ_τ = 1.269e-02 s
# z = 229.99999999999122 / 239.41012539999994. Applied: HookProcesss = 230.100 m, σ_τ = 1.269e-02 s
# z = 230.0999999999912 / 239.41012539999994. Applied: HookProcesss = 230.200 m, σ_τ = 1.269e-02 s
# z = 230.1999999999912 / 239.41012539999994. Applied: HookProcesss = 230.300 m, σ_τ = 1.269e-02 s
# z = 230.2999999999912 / 239.41012539999994. Applied: HookProcesss = 230.400 m, σ_τ = 1.269e-02 s
# z = 230.3999999999912 / 239.41012539999994. Applied: HookProcesss = 230.500 m, σ_τ = 1.269e-02 s
# z = 230.4999999999912 / 239.41012539999994. Applied: HookProcesss = 230.600 m, σ_τ = 1.269e-02 s
# z = 230.59999999999118 / 239.41012539999994. Applied: HookProcesss = 230.700 m, σ_τ = 1.269e-02 s
# z = 230.69999999999118 / 239.41012539999994. Applied: HookProcesss = 230.800 m, σ_τ = 1.269e-02 s
# z = 230.79999999999117 / 239.41012539999994. Applied: HookProcesss = 230.900 m, σ_τ = 1.269e-02 s
# z = 230.89999999999117 / 239.41012539999994. Applied: HookProcesss = 231.000 m, σ_τ = 1.269e-02 s
# z = 230.99999999999116 / 239.41012539999994. Applied: HookProcesss = 231.100 m, σ_τ = 1.269e-02 s
# z = 231.09999999999116 / 239.41012539999994. Applied: HookProcesss = 231.200 m, σ_τ = 1.269e-02 s
# z = 231.19999999999115 / 239.41012539999994. Applied: HookProcesss = 231.300 m, σ_τ = 1.269e-02 s
# z = 231.29999999999114 / 239.41012539999994. Applied: HookProcesss = 231.400 m, σ_τ = 1.269e-02 s
# z = 231.39999999999114 / 239.41012539999994. Applied: HookProcesss = 231.500 m, σ_τ = 1.269e-02 s
# z = 231.49999999999113 / 239.41012539999994. Applied: HookProcesss = 231.600 m, σ_τ = 1.269e-02 s
# z = 231.59999999999113 / 239.41012539999994. Applied: HookProcesss = 231.700 m, σ_τ = 1.269e-02 s
# z = 231.69999999999112 / 239.41012539999994. Applied: HookProcesss = 231.800 m, σ_τ = 1.269e-02 s
# z = 231.79999999999112 / 239.41012539999994. Applied: HookProcesss = 231.900 m, σ_τ = 1.269e-02 s
# z = 231.8999999999911 / 239.41012539999994. Applied: HookProcesss = 232.000 m, σ_τ = 1.269e-02 s
# z = 231.9999999999911 / 239.41012539999994. Applied: HookProcesss = 232.100 m, σ_τ = 1.269e-02 s
# z = 232.0999999999911 / 239.41012539999994. Applied: HookProcesss = 232.200 m, σ_τ = 1.269e-02 s
# z = 232.1999999999911 / 239.41012539999994. Applied: HookProcesss = 232.300 m, σ_τ = 1.269e-02 s
# z = 232.2999999999911 / 239.41012539999994. Applied: HookProcesss = 232.400 m, σ_τ = 1.269e-02 s
# z = 232.39999999999108 / 239.41012539999994. Applied: HookProcesss = 232.500 m, σ_τ = 1.269e-02 s
# z = 232.49999999999108 / 239.41012539999994. Applied: HookProcesss = 232.600 m, σ_τ = 1.269e-02 s
# z = 232.59999999999107 / 239.41012539999994. Applied: HookProcesss = 232.700 m, σ_τ = 1.269e-02 s
# z = 232.69999999999106 / 239.41012539999994. Applied: HookProcesss = 232.800 m, σ_τ = 1.269e-02 s
# z = 232.79999999999106 / 239.41012539999994. Applied: HookProcesss = 232.900 m, σ_τ = 1.269e-02 s
# z = 232.89999999999105 / 239.41012539999994. Applied: HookProcesss = 233.000 m, σ_τ = 1.269e-02 s
# z = 232.99999999999105 / 239.41012539999994. Applied: HookProcesss = 233.100 m, σ_τ = 1.269e-02 s
# z = 233.09999999999104 / 239.41012539999994. Applied: HookProcesss = 233.200 m, σ_τ = 1.269e-02 s
# z = 233.19999999999104 / 239.41012539999994. Applied: HookProcesss = 233.300 m, σ_τ = 1.269e-02 s
# z = 233.29999999999103 / 239.41012539999994. Applied: HookProcesss = 233.400 m, σ_τ = 1.269e-02 s
# z = 233.39999999999102 / 239.41012539999994. Applied: HookProcesss = 233.500 m, σ_τ = 1.269e-02 s
# z = 233.49999999999102 / 239.41012539999994. Applied: HookProcesss = 233.600 m, σ_τ = 1.269e-02 s
# z = 233.599999999991 / 239.41012539999994. Applied: HookProcesss = 233.700 m, σ_τ = 1.269e-02 s
# z = 233.699999999991 / 239.41012539999994. Applied: HookProcesss = 233.800 m, σ_τ = 1.269e-02 s
# z = 233.799999999991 / 239.41012539999994. Applied: HookProcesss = 233.900 m, σ_τ = 1.269e-02 s
# z = 233.899999999991 / 239.41012539999994. Applied: HookProcesss = 234.000 m, σ_τ = 1.269e-02 s
# z = 233.999999999991 / 239.41012539999994. Applied: HookProcesss = 234.100 m, σ_τ = 1.269e-02 s
# z = 234.09999999999098 / 239.41012539999994. Applied: HookProcesss = 234.200 m, σ_τ = 1.269e-02 s
# z = 234.19999999999098 / 239.41012539999994. Applied: HookProcesss = 234.300 m, σ_τ = 1.269e-02 s
# z = 234.29999999999097 / 239.41012539999994. Applied: HookProcesss = 234.400 m, σ_τ = 1.269e-02 s
# z = 234.39999999999097 / 239.41012539999994. Applied: HookProcesss = 234.500 m, σ_τ = 1.269e-02 s
# z = 234.49999999999096 / 239.41012539999994. Applied: HookProcesss = 234.600 m, σ_τ = 1.269e-02 s
# z = 234.59999999999096 / 239.41012539999994. Applied: HookProcesss = 234.700 m, σ_τ = 1.269e-02 s
# z = 234.69999999999095 / 239.41012539999994. Applied: HookProcesss = 234.800 m, σ_τ = 1.269e-02 s
# z = 234.79999999999094 / 239.41012539999994. Applied: HookProcesss = 234.900 m, σ_τ = 1.269e-02 s
# z = 234.89999999999094 / 239.41012539999994. Applied: HookProcesss = 235.000 m, σ_τ = 1.269e-02 s
# z = 234.99999999999093 / 239.41012539999994. Applied: HookProcesss = 235.100 m, σ_τ = 1.269e-02 s
# z = 235.09999999999093 / 239.41012539999994. Applied: HookProcesss = 235.200 m, σ_τ = 1.269e-02 s
# z = 235.19999999999092 / 239.41012539999994. Applied: HookProcesss = 235.300 m, σ_τ = 1.269e-02 s
# z = 235.29999999999092 / 239.41012539999994. Applied: HookProcesss = 235.400 m, σ_τ = 1.269e-02 s
# z = 235.3999999999909 / 239.41012539999994. Applied: HookProcesss = 235.500 m, σ_τ = 1.269e-02 s
# z = 235.4999999999909 / 239.41012539999994. Applied: HookProcesss = 235.600 m, σ_τ = 1.269e-02 s
# z = 235.5999999999909 / 239.41012539999994. Applied: HookProcesss = 235.700 m, σ_τ = 1.269e-02 s
# z = 235.6999999999909 / 239.41012539999994. Applied: HookProcesss = 235.800 m, σ_τ = 1.269e-02 s
# z = 235.7999999999909 / 239.41012539999994. Applied: HookProcesss = 235.900 m, σ_τ = 1.269e-02 s
# z = 235.89999999999088 / 239.41012539999994. Applied: HookProcesss = 236.000 m, σ_τ = 1.269e-02 s
# z = 235.99999999999088 / 239.41012539999994. Applied: HookProcesss = 236.100 m, σ_τ = 1.269e-02 s
# z = 236.09999999999087 / 239.41012539999994. Applied: HookProcesss = 236.200 m, σ_τ = 1.269e-02 s
# z = 236.19999999999087 / 239.41012539999994. Applied: HookProcesss = 236.300 m, σ_τ = 1.269e-02 s
# z = 236.29999999999086 / 239.41012539999994. Applied: HookProcesss = 236.400 m, σ_τ = 1.269e-02 s
# z = 236.39999999999085 / 239.41012539999994. Applied: HookProcesss = 236.500 m, σ_τ = 1.269e-02 s
# z = 236.49999999999085 / 239.41012539999994. Applied: HookProcesss = 236.600 m, σ_τ = 1.269e-02 s
# z = 236.59999999999084 / 239.41012539999994. Applied: HookProcesss = 236.700 m, σ_τ = 1.269e-02 s
# z = 236.69999999999084 / 239.41012539999994. Applied: HookProcesss = 236.800 m, σ_τ = 1.269e-02 s
# z = 236.79999999999083 / 239.41012539999994. Applied: HookProcesss = 236.900 m, σ_τ = 1.269e-02 s
# z = 236.89999999999083 / 239.41012539999994. Applied: HookProcesss = 237.000 m, σ_τ = 1.269e-02 s
# z = 236.99999999999082 / 239.41012539999994. Applied: HookProcesss = 237.100 m, σ_τ = 1.269e-02 s
# z = 237.0999999999908 / 239.41012539999994. Applied: HookProcesss = 237.200 m, σ_τ = 1.269e-02 s
# z = 237.1999999999908 / 239.41012539999994. Applied: HookProcesss = 237.300 m, σ_τ = 1.269e-02 s
# z = 237.2999999999908 / 239.41012539999994. Applied: HookProcesss = 237.400 m, σ_τ = 1.269e-02 s
# z = 237.3999999999908 / 239.41012539999994. Applied: HookProcesss = 237.500 m, σ_τ = 1.269e-02 s
# z = 237.4999999999908 / 239.41012539999994. Applied: HookProcesss = 237.600 m, σ_τ = 1.269e-02 s
# z = 237.59999999999079 / 239.41012539999994. Applied: HookProcesss = 237.700 m, σ_τ = 1.269e-02 s
# z = 237.69999999999078 / 239.41012539999994. Applied: HookProcesss = 237.800 m, σ_τ = 1.269e-02 s
# z = 237.79999999999077 / 239.41012539999994. Applied: HookProcesss = 237.900 m, σ_τ = 1.269e-02 s
# z = 237.89999999999077 / 239.41012539999994. Applied: HookProcesss = 238.000 m, σ_τ = 1.269e-02 s
# z = 237.99999999999076 / 239.41012539999994. Applied: HookProcesss = 238.100 m, σ_τ = 1.269e-02 s
# z = 238.09999999999076 / 239.41012539999994. Applied: HookProcesss = 238.200 m, σ_τ = 1.269e-02 s
# z = 238.19999999999075 / 239.41012539999994. Applied: HookProcesss = 238.300 m, σ_τ = 1.269e-02 s
# z = 238.29999999999075 / 239.41012539999994. Applied: HookProcesss = 238.400 m, σ_τ = 1.269e-02 s
# z = 238.39999999999074 / 239.41012539999994. Applied: HookProcesss = 238.500 m, σ_τ = 1.269e-02 s
# z = 238.49999999999073 / 239.41012539999994. Applied: HookProcesss = 238.600 m, σ_τ = 1.269e-02 s
# z = 238.59999999999073 / 239.41012539999994. Applied: HookProcesss = 238.700 m, σ_τ = 1.269e-02 s
# z = 238.69999999999072 / 239.41012539999994. Applied: HookProcesss = 238.800 m, σ_τ = 1.269e-02 s
# z = 238.79999999999072 / 239.41012539999994. Applied: HookProcesss = 238.900 m, σ_τ = 1.269e-02 s
# z = 238.8999999999907 / 239.41012539999994. Applied: HookProcesss = 239.000 m, σ_τ = 1.269e-02 s
# z = 238.9999999999907 / 239.41012539999994. Applied: HookProcesss = 239.100 m, σ_τ = 1.269e-02 s
# z = 239.0999999999907 / 239.41012539999994. Applied: HookProcesss = 239.200 m, σ_τ = 1.269e-02 s
# z = 239.1999999999907 / 239.41012539999994. Applied: HookProcesss = 239.300 m, σ_τ = 1.269e-02 s
# z = 239.2999999999907 / 239.41012539999994. Applied: HookProcesss = 239.400 m, σ_τ = 1.269e-02 s
# z = 239.39999999999068 / 239.41012539999994. Applied: HookProcesss = 239.410 m, σ_τ = 1.269e-02 s
# z = 239.41012539999986 / 239.41012539999994. Applied: HookProcess
#  time exec: 47.97696495056152 sec
# sigma_tau_list length: 2395
# lat.totalLen: 239.41012539999994

# %%
sigma_tau = np.std(p_array.rparticles[4])
print("σ_τ before tracking:", sigma_tau, "s")

sigma_tau = np.std(p_array_t.rparticles[4])
print("σ_τ after tracking:", sigma_tau, "s")
# Out:
# σ_τ before tracking: 0.006681943745963765 s
# σ_τ after tracking: 0.012690073965571038 s

# %%
show_e_beam(p_array)

# %%
show_e_beam(p_array_t)

# %%
plot_emittances_vs_s(p_array_t)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_energy_vs_position(tws_track):
    """
    Plot energy E as a function of position s from a list of Twiss-like objects.

    Parameters:
    tws_track (list): List of objects with attributes 's' (position) and 'E' (energy).
    """
    s = np.array([tw.s for tw in tws_track])
    E = np.array([tw.E for tw in tws_track])

    plt.figure(figsize=(10, 6))
    plt.plot(s, E, linewidth=2, marker='o', markersize=4)

    plt.title("Energy vs Position", fontsize=16)
    plt.xlabel("s (m)", fontsize=14)
    plt.ylabel("E (GeV)", fontsize=14)
    plt.grid(True, which='both', linestyle='--', alpha=0.5)
    plt.tick_params(axis='both', labelsize=12)
    plt.tight_layout()
    plt.show()

# %%
plot_energy_vs_position(tws_track)

# %%
# --- After tracking: get final x, x', y, y' ---
x_t = p_array_t.rparticles[0]
xp_t = p_array_t.rparticles[1]
y_t = p_array_t.rparticles[2]
yp_t = p_array_t.rparticles[3]

# --- Plot initial vs final side-by-side ---
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# x-x′ before
axes[0][0].scatter(p_array.rparticles[0], p_array.rparticles[1], s=1, alpha=0.3)
axes[0][0].set_title("x vs x′ (before)")
axes[0][0].set_xlabel("x [m]")
axes[0][0].set_ylabel("x′ [rad]")
axes[0][0].grid(True)
axes[0][0].axis('equal')

# x-x′ after
axes[0][1].scatter(x_t, xp_t, s=1, alpha=0.3)
axes[0][1].set_title("x vs x′ (after)")
axes[0][1].set_xlabel("x [m]")
axes[0][1].set_ylabel("x′ [rad]")
axes[0][1].grid(True)
axes[0][1].axis('equal')

# y-y′ before
axes[1][0].scatter(p_array.rparticles[2], p_array.rparticles[3], s=1, alpha=0.3, color='orange')
axes[1][0].set_title("y vs y′ (before)")
axes[1][0].set_xlabel("y [m]")
axes[1][0].set_ylabel("y′ [rad]")
axes[1][0].grid(True)
axes[1][0].axis('equal')

# y-y′ after
axes[1][1].scatter(y_t, yp_t, s=1, alpha=0.3, color='orange')
axes[1][1].set_title("y vs y′ (after)")
axes[1][1].set_xlabel("y [m]")
axes[1][1].set_ylabel("y′ [rad]")
axes[1][1].grid(True)
axes[1][1].axis('equal')

plt.tight_layout()
plt.show()

# %%
import numpy as np

def compute_emittance(x, xp):
    x_mean = np.mean(x)
    xp_mean = np.mean(xp)

    x_cent = x - x_mean
    xp_cent = xp - xp_mean

    xx = np.mean(x_cent ** 2)
    xpxp = np.mean(xp_cent ** 2)
    xxp = np.mean(x_cent * xp_cent)

    emit = np.sqrt(xx * xpxp - xxp**2)
    return emit

# Final tracked coordinates
x, xp = p_array_t.rparticles[0], p_array_t.rparticles[1]
y, yp = p_array_t.rparticles[2], p_array_t.rparticles[3]

emit_x = compute_emittance(x, xp)
emit_y = compute_emittance(y, yp)

print(f"εₓ (RMS, final) = {emit_x:.5e} m·rad")
print(f"εᵧ (RMS, final) = {emit_y:.5e} m·rad")

emit_x0 = compute_emittance(p_array.rparticles[0], p_array.rparticles[1])
emit_y0 = compute_emittance(p_array.rparticles[2], p_array.rparticles[3])
print("Initial εₓ:", emit_x0)
print("Initial εᵧ:", emit_y0)
# Out:
# εₓ (RMS, final) = 2.28272e-10 m·rad
# εᵧ (RMS, final) = 2.27456e-10 m·rad
# Initial εₓ: 6.757033829017005e-08
# Initial εᵧ: 6.771805922181499e-08

# %%
for tw in tws_track:
    print(f"s = {tw.s:.3f} m  |  beta_x = {tw.beta_x:.3f}  | beta_y = {tw.beta_y:.3f}  |  alpha_x = {tw.alpha_x:.3f} |  alpha_y = {tw.alpha_y:.3f}" )
# Out:
# s = 0.000 m  |  beta_x = 24.252  | beta_y = 24.521  |  alpha_x = -21.028 |  alpha_y = -21.249
# s = 0.100 m  |  beta_x = 28.641  | beta_y = 28.956  |  alpha_x = -22.855 |  alpha_y = -23.095
# s = 0.200 m  |  beta_x = 36.405  | beta_y = 30.890  |  alpha_x = -96.867 |  alpha_y = 40.071
# s = 0.300 m  |  beta_x = 66.818  | beta_y = 18.647  |  alpha_x = -100.235 |  alpha_y = 32.769
# s = 0.400 m  |  beta_x = 66.471  | beta_y = 17.588  |  alpha_x = 27.104 |  alpha_y = -1.355
# s = 0.500 m  |  beta_x = 61.161  | beta_y = 17.861  |  alpha_x = 25.998 |  alpha_y = -1.371
# s = 0.600 m  |  beta_x = 56.072  | beta_y = 18.137  |  alpha_x = 24.891 |  alpha_y = -1.387
# s = 0.700 m  |  beta_x = 51.205  | beta_y = 18.416  |  alpha_x = 23.784 |  alpha_y = -1.403
# s = 0.800 m  |  beta_x = 46.558  | beta_y = 18.698  |  alpha_x = 22.677 |  alpha_y = -1.419
# s = 0.900 m  |  beta_x = 42.134  | beta_y = 18.983  |  alpha_x = 21.571 |  alpha_y = -1.435
# s = 1.000 m  |  beta_x = 37.930  | beta_y = 19.272  |  alpha_x = 20.464 |  alpha_y = -1.452
# s = 1.100 m  |  beta_x = 33.948  | beta_y = 19.564  |  alpha_x = 19.357 |  alpha_y = -1.468
# s = 1.200 m  |  beta_x = 30.187  | beta_y = 19.859  |  alpha_x = 18.251 |  alpha_y = -1.484
# s = 1.300 m  |  beta_x = 26.648  | beta_y = 20.158  |  alpha_x = 17.144 |  alpha_y = -1.500
# s = 1.400 m  |  beta_x = 23.330  | beta_y = 20.459  |  alpha_x = 16.037 |  alpha_y = -1.516
# s = 1.500 m  |  beta_x = 20.979  | beta_y = 20.042  |  alpha_x = 3.899 |  alpha_y = 9.265
# s = 1.600 m  |  beta_x = 20.248  | beta_y = 18.190  |  alpha_x = 6.013 |  alpha_y = 6.874
# s = 1.700 m  |  beta_x = 18.881  | beta_y = 17.006  |  alpha_x = 6.799 |  alpha_y = 5.743
# s = 1.800 m  |  beta_x = 17.547  | beta_y = 15.877  |  alpha_x = 6.549 |  alpha_y = 5.543
# s = 1.900 m  |  beta_x = 16.236  | beta_y = 14.765  |  alpha_x = 6.681 |  alpha_y = 5.691
# s = 2.000 m  |  beta_x = 14.879  | beta_y = 13.604  |  alpha_x = 6.865 |  alpha_y = 5.890
# s = 2.100 m  |  beta_x = 13.500  | beta_y = 12.417  |  alpha_x = 6.902 |  alpha_y = 5.959
# s = 2.200 m  |  beta_x = 12.126  | beta_y = 11.227  |  alpha_x = 6.821 |  alpha_y = 5.924
# s = 2.300 m  |  beta_x = 10.778  | beta_y = 10.053  |  alpha_x = 6.645 |  alpha_y = 5.805
# s = 2.400 m  |  beta_x = 9.473  | beta_y = 8.910  |  alpha_x = 6.394 |  alpha_y = 5.617
# s = 2.500 m  |  beta_x = 8.224  | beta_y = 7.810  |  alpha_x = 6.081 |  alpha_y = 5.374
# s = 2.600 m  |  beta_x = 7.044  | beta_y = 6.763  |  alpha_x = 5.718 |  alpha_y = 5.086
# s = 2.700 m  |  beta_x = 5.940  | beta_y = 5.778  |  alpha_x = 5.314 |  alpha_y = 4.762
# s = 2.800 m  |  beta_x = 4.920  | beta_y = 4.861  |  alpha_x = 4.878 |  alpha_y = 4.407
# s = 2.900 m  |  beta_x = 3.991  | beta_y = 4.017  |  alpha_x = 4.415 |  alpha_y = 4.028
# s = 3.000 m  |  beta_x = 3.156  | beta_y = 3.251  |  alpha_x = 3.931 |  alpha_y = 3.630
# s = 3.100 m  |  beta_x = 2.419  | beta_y = 2.566  |  alpha_x = 3.430 |  alpha_y = 3.216
# s = 3.200 m  |  beta_x = 1.785  | beta_y = 1.965  |  alpha_x = 2.917 |  alpha_y = 2.789
# s = 3.300 m  |  beta_x = 1.253  | beta_y = 1.451  |  alpha_x = 2.393 |  alpha_y = 2.353
# s = 3.400 m  |  beta_x = 0.828  | beta_y = 1.024  |  alpha_x = 1.862 |  alpha_y = 1.909
# s = 3.500 m  |  beta_x = 0.509  | beta_y = 0.687  |  alpha_x = 1.325 |  alpha_y = 1.460
# s = 3.600 m  |  beta_x = 0.298  | beta_y = 0.441  |  alpha_x = 0.785 |  alpha_y = 1.007
# s = 3.700 m  |  beta_x = 0.195  | beta_y = 0.285  |  alpha_x = 0.244 |  alpha_y = 0.551
# s = 3.800 m  |  beta_x = 0.201  | beta_y = 0.220  |  alpha_x = -0.299 |  alpha_y = 0.094
# s = 3.900 m  |  beta_x = 0.315  | beta_y = 0.247  |  alpha_x = -0.843 |  alpha_y = -0.364
# s = 4.000 m  |  beta_x = 0.538  | beta_y = 0.366  |  alpha_x = -1.390 |  alpha_y = -0.819
# s = 4.100 m  |  beta_x = 0.856  | beta_y = 0.585  |  alpha_x = -1.647 |  alpha_y = -1.471
# s = 4.200 m  |  beta_x = 1.177  | beta_y = 0.972  |  alpha_x = -1.678 |  alpha_y = -2.328
# s = 4.300 m  |  beta_x = 1.545  | beta_y = 1.504  |  alpha_x = -2.002 |  alpha_y = -2.987
# s = 4.400 m  |  beta_x = 1.978  | beta_y = 2.167  |  alpha_x = -2.327 |  alpha_y = -3.647
# s = 4.500 m  |  beta_x = 2.476  | beta_y = 2.963  |  alpha_x = -2.651 |  alpha_y = -4.307
# s = 4.600 m  |  beta_x = 3.038  | beta_y = 3.890  |  alpha_x = -2.976 |  alpha_y = -4.967
# s = 4.700 m  |  beta_x = 0.062  | beta_y = 4.950  |  alpha_x = -1.349 |  alpha_y = -5.627
# s = 4.800 m  |  beta_x = 0.810  | beta_y = 6.121  |  alpha_x = -9.524 |  alpha_y = -5.204
# s = 4.900 m  |  beta_x = 3.852  | beta_y = 7.208  |  alpha_x = -20.842 |  alpha_y = -5.663
# s = 5.000 m  |  beta_x = 9.139  | beta_y = 8.387  |  alpha_x = -32.070 |  alpha_y = -6.122
# s = 5.100 m  |  beta_x = 16.628  | beta_y = 9.658  |  alpha_x = -43.164 |  alpha_y = -6.581
# s = 5.200 m  |  beta_x = 57.449  | beta_y = 10.801  |  alpha_x = -78.606 |  alpha_y = -5.116
# s = 5.300 m  |  beta_x = 61.127  | beta_y = 11.846  |  alpha_x = -0.027 |  alpha_y = -5.367
# s = 5.400 m  |  beta_x = 61.133  | beta_y = 12.945  |  alpha_x = -0.029 |  alpha_y = -5.619
# s = 5.500 m  |  beta_x = 61.139  | beta_y = 14.094  |  alpha_x = -0.030 |  alpha_y = -5.870
# s = 5.600 m  |  beta_x = 23.424  | beta_y = 15.295  |  alpha_x = 20.233 |  alpha_y = -6.122
# s = 5.700 m  |  beta_x = 8.526  | beta_y = 16.489  |  alpha_x = 20.458 |  alpha_y = -3.457
# s = 5.800 m  |  beta_x = 4.923  | beta_y = 17.189  |  alpha_x = 15.540 |  alpha_y = -3.536
# s = 5.900 m  |  beta_x = 2.303  | beta_y = 17.904  |  alpha_x = 10.608 |  alpha_y = -3.614
# s = 6.000 m  |  beta_x = 0.671  | beta_y = 18.635  |  alpha_x = 5.666 |  alpha_y = -3.693
# s = 6.100 m  |  beta_x = 0.091  | beta_y = 18.983  |  alpha_x = 1.272 |  alpha_y = -0.384
# s = 6.200 m  |  beta_x = 21.251  | beta_y = 19.056  |  alpha_x = -8.242 |  alpha_y = -0.390
# s = 6.300 m  |  beta_x = 22.932  | beta_y = 19.135  |  alpha_x = -8.566 |  alpha_y = -0.396
# s = 6.400 m  |  beta_x = 24.678  | beta_y = 19.215  |  alpha_x = -8.890 |  alpha_y = -0.403
# s = 6.500 m  |  beta_x = 26.488  | beta_y = 19.296  |  alpha_x = -9.215 |  alpha_y = -0.409
# s = 6.600 m  |  beta_x = 28.363  | beta_y = 19.378  |  alpha_x = -9.539 |  alpha_y = -0.415
# s = 6.700 m  |  beta_x = 30.304  | beta_y = 19.462  |  alpha_x = -9.863 |  alpha_y = -0.421
# s = 6.800 m  |  beta_x = 32.309  | beta_y = 19.547  |  alpha_x = -10.188 |  alpha_y = -0.427
# s = 6.900 m  |  beta_x = 34.379  | beta_y = 19.632  |  alpha_x = -10.512 |  alpha_y = -0.433
# s = 7.000 m  |  beta_x = 36.514  | beta_y = 19.720  |  alpha_x = -10.836 |  alpha_y = -0.439
# s = 7.100 m  |  beta_x = 38.713  | beta_y = 19.808  |  alpha_x = -11.161 |  alpha_y = -0.445
# s = 7.200 m  |  beta_x = 40.978  | beta_y = 19.898  |  alpha_x = -11.485 |  alpha_y = -0.451
# s = 7.300 m  |  beta_x = 43.307  | beta_y = 19.988  |  alpha_x = -11.809 |  alpha_y = -0.457
# s = 7.400 m  |  beta_x = 45.702  | beta_y = 20.080  |  alpha_x = -12.134 |  alpha_y = -0.463
# s = 7.500 m  |  beta_x = 48.161  | beta_y = 20.174  |  alpha_x = -12.458 |  alpha_y = -0.469
# s = 7.600 m  |  beta_x = 50.685  | beta_y = 20.268  |  alpha_x = -12.782 |  alpha_y = -0.475
# s = 7.700 m  |  beta_x = 53.274  | beta_y = 20.364  |  alpha_x = -13.107 |  alpha_y = -0.481
# s = 7.800 m  |  beta_x = 55.928  | beta_y = 20.460  |  alpha_x = -13.431 |  alpha_y = -0.487
# s = 7.900 m  |  beta_x = 58.646  | beta_y = 20.559  |  alpha_x = -13.756 |  alpha_y = -0.493
# s = 8.000 m  |  beta_x = 62.356  | beta_y = 20.348  |  alpha_x = -37.076 |  alpha_y = 7.081
# s = 8.100 m  |  beta_x = 76.076  | beta_y = 17.298  |  alpha_x = -93.883 |  alpha_y = 20.123
# s = 8.200 m  |  beta_x = 96.011  | beta_y = 13.508  |  alpha_x = -104.677 |  alpha_y = 17.664
# s = 8.300 m  |  beta_x = 105.982  | beta_y = 11.537  |  alpha_x = 8.770 |  alpha_y = 2.786
# s = 8.400 m  |  beta_x = 99.683  | beta_y = 11.486  |  alpha_x = 33.735 |  alpha_y = -0.055
# s = 8.500 m  |  beta_x = 93.051  | beta_y = 11.498  |  alpha_x = 32.592 |  alpha_y = -0.063
# s = 8.600 m  |  beta_x = 86.647  | beta_y = 11.511  |  alpha_x = 31.450 |  alpha_y = -0.072
# s = 8.700 m  |  beta_x = 80.471  | beta_y = 11.527  |  alpha_x = 30.307 |  alpha_y = -0.081
# s = 8.800 m  |  beta_x = 74.524  | beta_y = 11.544  |  alpha_x = 29.164 |  alpha_y = -0.090
# s = 8.900 m  |  beta_x = 68.805  | beta_y = 11.563  |  alpha_x = 28.022 |  alpha_y = -0.098
# s = 9.000 m  |  beta_x = 63.315  | beta_y = 11.583  |  alpha_x = 26.879 |  alpha_y = -0.107
# s = 9.100 m  |  beta_x = 58.054  | beta_y = 11.605  |  alpha_x = 25.736 |  alpha_y = -0.116
# s = 9.200 m  |  beta_x = 53.021  | beta_y = 11.629  |  alpha_x = 24.594 |  alpha_y = -0.124
# s = 9.300 m  |  beta_x = 48.216  | beta_y = 11.655  |  alpha_x = 23.451 |  alpha_y = -0.133
# s = 9.400 m  |  beta_x = 43.640  | beta_y = 11.683  |  alpha_x = 22.308 |  alpha_y = -0.142
# s = 9.500 m  |  beta_x = 39.293  | beta_y = 11.712  |  alpha_x = 21.166 |  alpha_y = -0.151
# s = 9.600 m  |  beta_x = 35.174  | beta_y = 11.743  |  alpha_x = 20.023 |  alpha_y = -0.159
# s = 9.700 m  |  beta_x = 31.283  | beta_y = 11.775  |  alpha_x = 18.934 |  alpha_y = -0.148
# s = 9.800 m  |  beta_x = 27.562  | beta_y = 11.786  |  alpha_x = 18.246 |  alpha_y = 0.041
# s = 9.900 m  |  beta_x = 23.996  | beta_y = 11.761  |  alpha_x = 17.387 |  alpha_y = 0.206
# s = 10.000 m  |  beta_x = 20.616  | beta_y = 11.705  |  alpha_x = 16.392 |  alpha_y = 0.349
# s = 10.100 m  |  beta_x = 17.447  | beta_y = 11.622  |  alpha_x = 15.286 |  alpha_y = 0.475
# s = 10.200 m  |  beta_x = 14.508  | beta_y = 11.516  |  alpha_x = 14.092 |  alpha_y = 0.585
# s = 10.300 m  |  beta_x = 11.815  | beta_y = 11.389  |  alpha_x = 12.827 |  alpha_y = 0.680
# s = 10.400 m  |  beta_x = 9.381  | beta_y = 11.245  |  alpha_x = 11.505 |  alpha_y = 0.763
# s = 10.500 m  |  beta_x = 7.215  | beta_y = 11.085  |  alpha_x = 10.139 |  alpha_y = 0.835
# s = 10.600 m  |  beta_x = 5.327  | beta_y = 10.911  |  alpha_x = 8.738 |  alpha_y = 0.898
# s = 10.700 m  |  beta_x = 3.722  | beta_y = 10.726  |  alpha_x = 7.310 |  alpha_y = 0.951
# s = 10.800 m  |  beta_x = 2.405  | beta_y = 10.531  |  alpha_x = 5.862 |  alpha_y = 0.997
# s = 10.900 m  |  beta_x = 1.378  | beta_y = 10.328  |  alpha_x = 4.399 |  alpha_y = 1.035
# s = 11.000 m  |  beta_x = 0.646  | beta_y = 10.118  |  alpha_x = 2.925 |  alpha_y = 1.067
# s = 11.100 m  |  beta_x = 0.209  | beta_y = 9.901  |  alpha_x = 1.446 |  alpha_y = 1.094
# s = 11.200 m  |  beta_x = 0.068  | beta_y = 9.680  |  alpha_x = -0.036 |  alpha_y = 1.115
# s = 11.300 m  |  beta_x = 0.223  | beta_y = 9.456  |  alpha_x = -1.518 |  alpha_y = 1.131
# s = 11.400 m  |  beta_x = 0.675  | beta_y = 9.228  |  alpha_x = -2.998 |  alpha_y = 1.143
# s = 11.500 m  |  beta_x = 1.422  | beta_y = 8.999  |  alpha_x = -4.473 |  alpha_y = 1.151
# s = 11.600 m  |  beta_x = 2.463  | beta_y = 8.768  |  alpha_x = -5.944 |  alpha_y = 1.150
# s = 11.700 m  |  beta_x = 3.800  | beta_y = 8.541  |  alpha_x = -7.419 |  alpha_y = 1.123
# s = 11.800 m  |  beta_x = 5.431  | beta_y = 8.319  |  alpha_x = -8.894 |  alpha_y = 1.097
# s = 11.900 m  |  beta_x = 7.416  | beta_y = 8.036  |  alpha_x = -12.792 |  alpha_y = 3.712
# s = 12.000 m  |  beta_x = 11.462  | beta_y = 6.359  |  alpha_x = -29.082 |  alpha_y = 12.119
# s = 12.100 m  |  beta_x = 18.017  | beta_y = 4.167  |  alpha_x = -36.470 |  alpha_y = 9.794
# s = 12.200 m  |  beta_x = 23.293  | beta_y = 2.805  |  alpha_x = -9.339 |  alpha_y = 3.681
# s = 12.300 m  |  beta_x = 22.754  | beta_y = 2.375  |  alpha_x = 5.432 |  alpha_y = 1.745
# s = 12.400 m  |  beta_x = 21.681  | beta_y = 2.043  |  alpha_x = 5.298 |  alpha_y = 1.574
# s = 12.500 m  |  beta_x = 20.635  | beta_y = 1.745  |  alpha_x = 5.165 |  alpha_y = 1.404
# s = 12.600 m  |  beta_x = 19.609  | beta_y = 1.481  |  alpha_x = 5.096 |  alpha_y = 1.239
# s = 12.700 m  |  beta_x = 18.598  | beta_y = 1.250  |  alpha_x = 5.016 |  alpha_y = 1.071
# s = 12.800 m  |  beta_x = 17.603  | beta_y = 1.052  |  alpha_x = 4.927 |  alpha_y = 0.903
# s = 12.900 m  |  beta_x = 16.627  | beta_y = 0.889  |  alpha_x = 4.829 |  alpha_y = 0.732
# s = 13.000 m  |  beta_x = 15.672  | beta_y = 0.759  |  alpha_x = 4.724 |  alpha_y = 0.562
# s = 13.100 m  |  beta_x = 14.738  | beta_y = 0.664  |  alpha_x = 4.612 |  alpha_y = 0.390
# s = 13.200 m  |  beta_x = 13.828  | beta_y = 0.603  |  alpha_x = 4.494 |  alpha_y = 0.218
# s = 13.300 m  |  beta_x = 12.941  | beta_y = 0.577  |  alpha_x = 4.370 |  alpha_y = 0.045
# s = 13.400 m  |  beta_x = 12.080  | beta_y = 0.585  |  alpha_x = 4.240 |  alpha_y = -0.127
# s = 13.500 m  |  beta_x = 11.246  | beta_y = 0.628  |  alpha_x = 4.106 |  alpha_y = -0.299
# s = 13.600 m  |  beta_x = 10.438  | beta_y = 0.705  |  alpha_x = 3.968 |  alpha_y = -0.472
# s = 13.700 m  |  beta_x = 9.659  | beta_y = 0.816  |  alpha_x = 3.825 |  alpha_y = -0.644
# s = 13.800 m  |  beta_x = 8.908  | beta_y = 0.962  |  alpha_x = 3.679 |  alpha_y = -0.815
# s = 13.900 m  |  beta_x = 8.187  | beta_y = 1.142  |  alpha_x = 3.530 |  alpha_y = -0.986
# s = 14.000 m  |  beta_x = 7.496  | beta_y = 1.357  |  alpha_x = 3.378 |  alpha_y = -1.157
# s = 14.100 m  |  beta_x = 6.836  | beta_y = 1.605  |  alpha_x = 3.223 |  alpha_y = -1.326
# s = 14.200 m  |  beta_x = 6.207  | beta_y = 1.887  |  alpha_x = 3.066 |  alpha_y = -1.495
# s = 14.300 m  |  beta_x = 5.610  | beta_y = 2.203  |  alpha_x = 2.907 |  alpha_y = -1.664
# s = 14.400 m  |  beta_x = 5.045  | beta_y = 2.553  |  alpha_x = 2.744 |  alpha_y = -1.832
# s = 14.500 m  |  beta_x = 4.513  | beta_y = 2.936  |  alpha_x = 2.575 |  alpha_y = -2.002
# s = 14.600 m  |  beta_x = 4.014  | beta_y = 3.353  |  alpha_x = 2.406 |  alpha_y = -2.173
# s = 14.700 m  |  beta_x = 3.550  | beta_y = 3.805  |  alpha_x = 2.237 |  alpha_y = -2.343
# s = 14.800 m  |  beta_x = 3.120  | beta_y = 4.291  |  alpha_x = 2.068 |  alpha_y = -2.514
# s = 14.900 m  |  beta_x = 2.723  | beta_y = 4.811  |  alpha_x = 1.899 |  alpha_y = -2.685
# s = 15.000 m  |  beta_x = 2.360  | beta_y = 5.365  |  alpha_x = 1.730 |  alpha_y = -2.855
# s = 15.100 m  |  beta_x = 2.031  | beta_y = 5.953  |  alpha_x = 1.561 |  alpha_y = -3.026
# s = 15.200 m  |  beta_x = 1.736  | beta_y = 6.575  |  alpha_x = 1.391 |  alpha_y = -3.197
# s = 15.300 m  |  beta_x = 1.475  | beta_y = 7.231  |  alpha_x = 1.222 |  alpha_y = -3.367
# s = 15.400 m  |  beta_x = 1.247  | beta_y = 7.922  |  alpha_x = 1.053 |  alpha_y = -3.536
# s = 15.500 m  |  beta_x = 1.053  | beta_y = 8.645  |  alpha_x = 0.886 |  alpha_y = -3.695
# s = 15.600 m  |  beta_x = 0.893  | beta_y = 9.400  |  alpha_x = 0.717 |  alpha_y = -3.852
# s = 15.700 m  |  beta_x = 0.766  | beta_y = 10.186  |  alpha_x = 0.549 |  alpha_y = -4.008
# s = 15.800 m  |  beta_x = 0.673  | beta_y = 11.003  |  alpha_x = 0.380 |  alpha_y = -4.162
# s = 15.900 m  |  beta_x = 0.614  | beta_y = 11.851  |  alpha_x = 0.210 |  alpha_y = -4.315
# s = 16.000 m  |  beta_x = 0.589  | beta_y = 12.729  |  alpha_x = 0.041 |  alpha_y = -4.467
# s = 16.100 m  |  beta_x = 0.598  | beta_y = 13.637  |  alpha_x = -0.128 |  alpha_y = -4.616
# s = 16.200 m  |  beta_x = 0.640  | beta_y = 14.575  |  alpha_x = -0.298 |  alpha_y = -4.765
# s = 16.300 m  |  beta_x = 0.717  | beta_y = 15.543  |  alpha_x = -0.467 |  alpha_y = -4.912
# s = 16.400 m  |  beta_x = 0.827  | beta_y = 16.540  |  alpha_x = -0.636 |  alpha_y = -5.057
# s = 16.500 m  |  beta_x = 0.971  | beta_y = 17.566  |  alpha_x = -0.805 |  alpha_y = -5.201
# s = 16.600 m  |  beta_x = 1.149  | beta_y = 18.620  |  alpha_x = -0.973 |  alpha_y = -5.343
# s = 16.700 m  |  beta_x = 1.361  | beta_y = 19.703  |  alpha_x = -1.142 |  alpha_y = -5.485
# s = 16.800 m  |  beta_x = 1.606  | beta_y = 20.814  |  alpha_x = -1.310 |  alpha_y = -5.624
# s = 16.900 m  |  beta_x = 1.884  | beta_y = 21.953  |  alpha_x = -1.477 |  alpha_y = -5.763
# s = 17.000 m  |  beta_x = 2.196  | beta_y = 23.119  |  alpha_x = -1.644 |  alpha_y = -5.900
# s = 17.100 m  |  beta_x = 2.542  | beta_y = 24.312  |  alpha_x = -1.811 |  alpha_y = -6.035
# s = 17.200 m  |  beta_x = 2.921  | beta_y = 25.533  |  alpha_x = -1.977 |  alpha_y = -6.170
# s = 17.300 m  |  beta_x = 3.333  | beta_y = 26.780  |  alpha_x = -2.143 |  alpha_y = -6.308
# s = 17.400 m  |  beta_x = 3.778  | beta_y = 28.057  |  alpha_x = -2.311 |  alpha_y = -6.460
# s = 17.500 m  |  beta_x = 4.302  | beta_y = 29.054  |  alpha_x = -3.926 |  alpha_y = 3.236
# s = 17.600 m  |  beta_x = 5.481  | beta_y = 26.364  |  alpha_x = -6.770 |  alpha_y = 15.904
# s = 17.700 m  |  beta_x = 6.552  | beta_y = 24.676  |  alpha_x = -2.144 |  alpha_y = -4.958
# s = 17.800 m  |  beta_x = 6.388  | beta_y = 28.027  |  alpha_x = 1.821 |  alpha_y = -21.470
# s = 17.900 m  |  beta_x = 6.282  | beta_y = 31.223  |  alpha_x = -2.333 |  alpha_y = -2.264
# s = 18.000 m  |  beta_x = 6.936  | beta_y = 30.836  |  alpha_x = -3.424 |  alpha_y = 2.233
# s = 18.100 m  |  beta_x = 7.639  | beta_y = 30.391  |  alpha_x = -3.607 |  alpha_y = 2.213
# s = 18.200 m  |  beta_x = 8.379  | beta_y = 29.950  |  alpha_x = -3.790 |  alpha_y = 2.196
# s = 18.300 m  |  beta_x = 9.155  | beta_y = 29.511  |  alpha_x = -3.967 |  alpha_y = 2.198
# s = 18.400 m  |  beta_x = 9.966  | beta_y = 29.071  |  alpha_x = -4.143 |  alpha_y = 2.199
# s = 18.500 m  |  beta_x = 10.812  | beta_y = 28.632  |  alpha_x = -4.318 |  alpha_y = 2.198
# s = 18.600 m  |  beta_x = 11.693  | beta_y = 28.192  |  alpha_x = -4.491 |  alpha_y = 2.197
# s = 18.700 m  |  beta_x = 12.609  | beta_y = 27.753  |  alpha_x = -4.664 |  alpha_y = 2.195
# s = 18.800 m  |  beta_x = 13.559  | beta_y = 27.314  |  alpha_x = -4.836 |  alpha_y = 2.191
# s = 18.900 m  |  beta_x = 14.543  | beta_y = 26.877  |  alpha_x = -5.007 |  alpha_y = 2.187
# s = 19.000 m  |  beta_x = 15.561  | beta_y = 26.440  |  alpha_x = -5.177 |  alpha_y = 2.181
# s = 19.100 m  |  beta_x = 16.614  | beta_y = 26.004  |  alpha_x = -5.346 |  alpha_y = 2.175
# s = 19.200 m  |  beta_x = 17.699  | beta_y = 25.570  |  alpha_x = -5.513 |  alpha_y = 2.167
# s = 19.300 m  |  beta_x = 18.819  | beta_y = 25.137  |  alpha_x = -5.680 |  alpha_y = 2.159
# s = 19.400 m  |  beta_x = 19.971  | beta_y = 24.706  |  alpha_x = -5.846 |  alpha_y = 2.150
# s = 19.500 m  |  beta_x = 21.157  | beta_y = 24.277  |  alpha_x = -6.011 |  alpha_y = 2.141
# s = 19.600 m  |  beta_x = 22.376  | beta_y = 23.850  |  alpha_x = -6.175 |  alpha_y = 2.130
# s = 19.700 m  |  beta_x = 23.627  | beta_y = 23.425  |  alpha_x = -6.337 |  alpha_y = 2.119
# s = 19.800 m  |  beta_x = 24.911  | beta_y = 23.003  |  alpha_x = -6.499 |  alpha_y = 2.107
# s = 19.900 m  |  beta_x = 26.226  | beta_y = 22.583  |  alpha_x = -6.660 |  alpha_y = 2.094
# s = 20.000 m  |  beta_x = 27.574  | beta_y = 22.165  |  alpha_x = -6.820 |  alpha_y = 2.081
# s = 20.100 m  |  beta_x = 28.954  | beta_y = 21.750  |  alpha_x = -6.981 |  alpha_y = 2.065
# s = 20.200 m  |  beta_x = 30.368  | beta_y = 21.340  |  alpha_x = -7.152 |  alpha_y = 2.041
# s = 20.300 m  |  beta_x = 31.920  | beta_y = 20.865  |  alpha_x = -12.679 |  alpha_y = 5.525
# s = 20.400 m  |  beta_x = 37.472  | beta_y = 18.098  |  alpha_x = -44.418 |  alpha_y = 21.349
# s = 20.500 m  |  beta_x = 46.940  | beta_y = 14.055  |  alpha_x = -45.966 |  alpha_y = 17.711
# s = 20.600 m  |  beta_x = 51.904  | beta_y = 11.837  |  alpha_x = -2.168 |  alpha_y = 5.137
# s = 20.700 m  |  beta_x = 47.756  | beta_y = 11.874  |  alpha_x = 42.392 |  alpha_y = -5.521
# s = 20.800 m  |  beta_x = 38.781  | beta_y = 13.259  |  alpha_x = 42.815 |  alpha_y = -7.199
# s = 20.900 m  |  beta_x = 33.603  | beta_y = 13.561  |  alpha_x = 10.305 |  alpha_y = 4.312
# s = 21.000 m  |  beta_x = 32.648  | beta_y = 12.288  |  alpha_x = 4.087 |  alpha_y = 6.458
# s = 21.100 m  |  beta_x = 31.836  | beta_y = 11.031  |  alpha_x = 4.033 |  alpha_y = 6.111
# s = 21.200 m  |  beta_x = 31.035  | beta_y = 9.843  |  alpha_x = 3.978 |  alpha_y = 5.763
# s = 21.300 m  |  beta_x = 30.245  | beta_y = 8.726  |  alpha_x = 3.924 |  alpha_y = 5.415
# s = 21.400 m  |  beta_x = 29.465  | beta_y = 7.677  |  alpha_x = 3.870 |  alpha_y = 5.068
# s = 21.500 m  |  beta_x = 28.697  | beta_y = 6.699  |  alpha_x = 3.816 |  alpha_y = 4.720
# s = 21.600 m  |  beta_x = 27.939  | beta_y = 5.789  |  alpha_x = 3.771 |  alpha_y = 4.375
# s = 21.700 m  |  beta_x = 27.188  | beta_y = 4.949  |  alpha_x = 3.735 |  alpha_y = 4.030
# s = 21.800 m  |  beta_x = 26.445  | beta_y = 4.177  |  alpha_x = 3.697 |  alpha_y = 3.684
# s = 21.900 m  |  beta_x = 25.709  | beta_y = 3.475  |  alpha_x = 3.658 |  alpha_y = 3.338
# s = 22.000 m  |  beta_x = 24.981  | beta_y = 2.842  |  alpha_x = 3.618 |  alpha_y = 2.990
# s = 22.100 m  |  beta_x = 24.262  | beta_y = 2.279  |  alpha_x = 3.576 |  alpha_y = 2.642
# s = 22.200 m  |  beta_x = 23.551  | beta_y = 1.785  |  alpha_x = 3.533 |  alpha_y = 2.293
# s = 22.300 m  |  beta_x = 22.849  | beta_y = 1.362  |  alpha_x = 3.489 |  alpha_y = 1.943
# s = 22.400 m  |  beta_x = 22.155  | beta_y = 1.008  |  alpha_x = 3.444 |  alpha_y = 1.593
# s = 22.500 m  |  beta_x = 21.471  | beta_y = 0.725  |  alpha_x = 3.398 |  alpha_y = 1.242
# s = 22.600 m  |  beta_x = 20.796  | beta_y = 0.511  |  alpha_x = 3.351 |  alpha_y = 0.892
# s = 22.700 m  |  beta_x = 20.131  | beta_y = 0.368  |  alpha_x = 3.302 |  alpha_y = 0.541
# s = 22.800 m  |  beta_x = 19.475  | beta_y = 0.295  |  alpha_x = 3.253 |  alpha_y = 0.190
# s = 22.900 m  |  beta_x = 18.830  | beta_y = 0.292  |  alpha_x = 3.203 |  alpha_y = -0.161
# s = 23.000 m  |  beta_x = 18.194  | beta_y = 0.360  |  alpha_x = 3.152 |  alpha_y = -0.512
# s = 23.100 m  |  beta_x = 17.569  | beta_y = 0.497  |  alpha_x = 3.100 |  alpha_y = -0.863
# s = 23.200 m  |  beta_x = 16.954  | beta_y = 0.705  |  alpha_x = 3.048 |  alpha_y = -1.214
# s = 23.300 m  |  beta_x = 16.350  | beta_y = 0.983  |  alpha_x = 2.995 |  alpha_y = -1.565
# s = 23.400 m  |  beta_x = 15.756  | beta_y = 1.331  |  alpha_x = 2.941 |  alpha_y = -1.915
# s = 23.500 m  |  beta_x = 15.174  | beta_y = 1.749  |  alpha_x = 2.882 |  alpha_y = -2.266
# s = 23.600 m  |  beta_x = 14.603  | beta_y = 2.237  |  alpha_x = 2.821 |  alpha_y = -2.616
# s = 23.700 m  |  beta_x = 14.045  | beta_y = 2.795  |  alpha_x = 2.764 |  alpha_y = -2.966
# s = 23.800 m  |  beta_x = 13.498  | beta_y = 3.423  |  alpha_x = 2.709 |  alpha_y = -3.315
# s = 23.900 m  |  beta_x = 12.962  | beta_y = 4.121  |  alpha_x = 2.652 |  alpha_y = -3.664
# s = 24.000 m  |  beta_x = 12.437  | beta_y = 4.889  |  alpha_x = 2.595 |  alpha_y = -4.012
# s = 24.100 m  |  beta_x = 11.924  | beta_y = 5.726  |  alpha_x = 2.538 |  alpha_y = -4.359
# s = 24.200 m  |  beta_x = 11.422  | beta_y = 6.632  |  alpha_x = 2.480 |  alpha_y = -4.706
# s = 24.300 m  |  beta_x = 10.932  | beta_y = 7.608  |  alpha_x = 2.422 |  alpha_y = -5.052
# s = 24.400 m  |  beta_x = 10.453  | beta_y = 8.653  |  alpha_x = 2.363 |  alpha_y = -5.397
# s = 24.500 m  |  beta_x = 9.987  | beta_y = 9.767  |  alpha_x = 2.303 |  alpha_y = -5.742
# s = 24.600 m  |  beta_x = 9.532  | beta_y = 10.950  |  alpha_x = 2.244 |  alpha_y = -6.085
# s = 24.700 m  |  beta_x = 9.089  | beta_y = 12.201  |  alpha_x = 2.184 |  alpha_y = -6.428
# s = 24.800 m  |  beta_x = 8.658  | beta_y = 13.521  |  alpha_x = 2.123 |  alpha_y = -6.771
# s = 24.900 m  |  beta_x = 8.240  | beta_y = 14.909  |  alpha_x = 2.062 |  alpha_y = -7.112
# s = 25.000 m  |  beta_x = 7.834  | beta_y = 16.366  |  alpha_x = 2.001 |  alpha_y = -7.452
# s = 25.100 m  |  beta_x = 7.439  | beta_y = 17.890  |  alpha_x = 1.940 |  alpha_y = -7.792
# s = 25.200 m  |  beta_x = 7.058  | beta_y = 19.482  |  alpha_x = 1.878 |  alpha_y = -8.131
# s = 25.300 m  |  beta_x = 6.688  | beta_y = 21.142  |  alpha_x = 1.816 |  alpha_y = -8.468
# s = 25.400 m  |  beta_x = 6.331  | beta_y = 22.870  |  alpha_x = 1.754 |  alpha_y = -8.805
# s = 25.500 m  |  beta_x = 5.987  | beta_y = 24.664  |  alpha_x = 1.691 |  alpha_y = -9.141
# s = 25.600 m  |  beta_x = 5.655  | beta_y = 26.527  |  alpha_x = 1.627 |  alpha_y = -9.483
# s = 25.700 m  |  beta_x = 5.336  | beta_y = 28.457  |  alpha_x = 1.562 |  alpha_y = -9.826
# s = 25.800 m  |  beta_x = 5.396  | beta_y = 28.420  |  alpha_x = -2.640 |  alpha_y = 12.663
# s = 25.900 m  |  beta_x = 6.213  | beta_y = 24.681  |  alpha_x = -4.503 |  alpha_y = 19.220
# s = 26.000 m  |  beta_x = 6.751  | beta_y = 22.300  |  alpha_x = 0.235 |  alpha_y = 1.588
# s = 26.100 m  |  beta_x = 6.100  | beta_y = 24.102  |  alpha_x = 6.071 |  alpha_y = -20.159
# s = 26.200 m  |  beta_x = 4.619  | beta_y = 29.983  |  alpha_x = 7.314 |  alpha_y = -33.337
# s = 26.300 m  |  beta_x = 3.426  | beta_y = 35.560  |  alpha_x = 4.090 |  alpha_y = -15.142
# s = 26.400 m  |  beta_x = 2.863  | beta_y = 36.159  |  alpha_x = 2.309 |  alpha_y = 1.309
# s = 26.500 m  |  beta_x = 2.423  | beta_y = 35.898  |  alpha_x = 2.088 |  alpha_y = 1.301
# s = 26.600 m  |  beta_x = 2.028  | beta_y = 35.639  |  alpha_x = 1.867 |  alpha_y = 1.294
# s = 26.700 m  |  beta_x = 1.677  | beta_y = 35.381  |  alpha_x = 1.646 |  alpha_y = 1.286
# s = 26.800 m  |  beta_x = 1.370  | beta_y = 35.124  |  alpha_x = 1.425 |  alpha_y = 1.287
# s = 26.900 m  |  beta_x = 1.107  | beta_y = 34.866  |  alpha_x = 1.204 |  alpha_y = 1.290
# s = 27.000 m  |  beta_x = 0.888  | beta_y = 34.608  |  alpha_x = 0.983 |  alpha_y = 1.292
# s = 27.100 m  |  beta_x = 0.714  | beta_y = 34.349  |  alpha_x = 0.762 |  alpha_y = 1.294
# s = 27.200 m  |  beta_x = 0.583  | beta_y = 34.090  |  alpha_x = 0.540 |  alpha_y = 1.296
# s = 27.300 m  |  beta_x = 0.497  | beta_y = 33.831  |  alpha_x = 0.319 |  alpha_y = 1.298
# s = 27.400 m  |  beta_x = 0.456  | beta_y = 33.571  |  alpha_x = 0.098 |  alpha_y = 1.299
# s = 27.500 m  |  beta_x = 0.458  | beta_y = 33.311  |  alpha_x = -0.124 |  alpha_y = 1.300
# s = 27.600 m  |  beta_x = 0.505  | beta_y = 33.051  |  alpha_x = -0.345 |  alpha_y = 1.300
# s = 27.700 m  |  beta_x = 0.596  | beta_y = 32.791  |  alpha_x = -0.566 |  alpha_y = 1.300
# s = 27.800 m  |  beta_x = 0.732  | beta_y = 32.531  |  alpha_x = -0.788 |  alpha_y = 1.301
# s = 27.900 m  |  beta_x = 0.911  | beta_y = 32.271  |  alpha_x = -1.009 |  alpha_y = 1.300
# s = 28.000 m  |  beta_x = 1.135  | beta_y = 32.011  |  alpha_x = -1.230 |  alpha_y = 1.300
# s = 28.100 m  |  beta_x = 1.403  | beta_y = 31.751  |  alpha_x = -1.451 |  alpha_y = 1.299
# s = 28.200 m  |  beta_x = 1.716  | beta_y = 31.491  |  alpha_x = -1.672 |  alpha_y = 1.298
# s = 28.300 m  |  beta_x = 2.072  | beta_y = 31.232  |  alpha_x = -1.892 |  alpha_y = 1.297
# s = 28.400 m  |  beta_x = 2.473  | beta_y = 30.973  |  alpha_x = -2.113 |  alpha_y = 1.295
# s = 28.500 m  |  beta_x = 2.917  | beta_y = 30.714  |  alpha_x = -2.333 |  alpha_y = 1.294
# s = 28.600 m  |  beta_x = 3.406  | beta_y = 30.455  |  alpha_x = -2.553 |  alpha_y = 1.292
# s = 28.700 m  |  beta_x = 3.939  | beta_y = 30.198  |  alpha_x = -2.774 |  alpha_y = 1.284
# s = 28.800 m  |  beta_x = 4.515  | beta_y = 29.942  |  alpha_x = -2.995 |  alpha_y = 1.275
# s = 28.900 m  |  beta_x = 5.136  | beta_y = 29.687  |  alpha_x = -3.214 |  alpha_y = 1.273
# s = 29.000 m  |  beta_x = 5.801  | beta_y = 29.433  |  alpha_x = -3.434 |  alpha_y = 1.271
# s = 29.100 m  |  beta_x = 6.510  | beta_y = 29.179  |  alpha_x = -3.653 |  alpha_y = 1.268
# s = 29.200 m  |  beta_x = 7.262  | beta_y = 28.925  |  alpha_x = -3.872 |  alpha_y = 1.265
# s = 29.300 m  |  beta_x = 8.059  | beta_y = 28.673  |  alpha_x = -4.090 |  alpha_y = 1.262
# s = 29.400 m  |  beta_x = 8.898  | beta_y = 28.421  |  alpha_x = -4.309 |  alpha_y = 1.259
# s = 29.500 m  |  beta_x = 9.782  | beta_y = 28.169  |  alpha_x = -4.526 |  alpha_y = 1.255
# s = 29.600 m  |  beta_x = 10.709  | beta_y = 27.919  |  alpha_x = -4.744 |  alpha_y = 1.252
# s = 29.700 m  |  beta_x = 11.680  | beta_y = 27.669  |  alpha_x = -4.961 |  alpha_y = 1.248
# s = 29.800 m  |  beta_x = 12.693  | beta_y = 27.419  |  alpha_x = -5.178 |  alpha_y = 1.244
# s = 29.900 m  |  beta_x = 13.751  | beta_y = 27.171  |  alpha_x = -5.395 |  alpha_y = 1.240
# s = 30.000 m  |  beta_x = 14.851  | beta_y = 26.924  |  alpha_x = -5.611 |  alpha_y = 1.235
# s = 30.100 m  |  beta_x = 15.995  | beta_y = 26.677  |  alpha_x = -5.826 |  alpha_y = 1.231
# s = 30.200 m  |  beta_x = 17.182  | beta_y = 26.431  |  alpha_x = -6.042 |  alpha_y = 1.226
# s = 30.300 m  |  beta_x = 18.412  | beta_y = 26.187  |  alpha_x = -6.257 |  alpha_y = 1.221
# s = 30.400 m  |  beta_x = 19.685  | beta_y = 25.943  |  alpha_x = -6.471 |  alpha_y = 1.216
# s = 30.500 m  |  beta_x = 21.000  | beta_y = 25.700  |  alpha_x = -6.686 |  alpha_y = 1.211
# s = 30.600 m  |  beta_x = 22.359  | beta_y = 25.458  |  alpha_x = -6.899 |  alpha_y = 1.206
# s = 30.700 m  |  beta_x = 23.760  | beta_y = 25.217  |  alpha_x = -7.113 |  alpha_y = 1.200
# s = 30.800 m  |  beta_x = 25.204  | beta_y = 24.978  |  alpha_x = -7.331 |  alpha_y = 1.190
# s = 30.900 m  |  beta_x = 26.701  | beta_y = 24.733  |  alpha_x = -9.012 |  alpha_y = 2.537
# s = 31.000 m  |  beta_x = 31.069  | beta_y = 22.139  |  alpha_x = -35.943 |  alpha_y = 22.634
# s = 31.100 m  |  beta_x = 39.523  | beta_y = 17.371  |  alpha_x = -45.154 |  alpha_y = 22.582
# s = 31.200 m  |  beta_x = 45.194  | beta_y = 14.441  |  alpha_x = -8.620 |  alpha_y = 7.102
# s = 31.300 m  |  beta_x = 42.758  | beta_y = 14.352  |  alpha_x = 32.227 |  alpha_y = -6.184
# s = 31.400 m  |  beta_x = 34.966  | beta_y = 16.241  |  alpha_x = 38.132 |  alpha_y = -10.197
# s = 31.500 m  |  beta_x = 29.749  | beta_y = 17.207  |  alpha_x = 11.901 |  alpha_y = 2.527
# s = 31.600 m  |  beta_x = 28.877  | beta_y = 15.861  |  alpha_x = 2.773 |  alpha_y = 7.468
# s = 31.700 m  |  beta_x = 28.325  | beta_y = 14.403  |  alpha_x = 2.743 |  alpha_y = 7.110
# s = 31.800 m  |  beta_x = 27.780  | beta_y = 13.017  |  alpha_x = 2.713 |  alpha_y = 6.752
# s = 31.900 m  |  beta_x = 27.240  | beta_y = 11.702  |  alpha_x = 2.683 |  alpha_y = 6.394
# s = 32.000 m  |  beta_x = 26.706  | beta_y = 10.459  |  alpha_x = 2.653 |  alpha_y = 6.036
# s = 32.100 m  |  beta_x = 26.179  | beta_y = 9.288  |  alpha_x = 2.625 |  alpha_y = 5.679
# s = 32.200 m  |  beta_x = 25.656  | beta_y = 8.187  |  alpha_x = 2.599 |  alpha_y = 5.323
# s = 32.300 m  |  beta_x = 25.139  | beta_y = 7.159  |  alpha_x = 2.573 |  alpha_y = 4.966
# s = 32.400 m  |  beta_x = 24.627  | beta_y = 6.201  |  alpha_x = 2.547 |  alpha_y = 4.608
# s = 32.500 m  |  beta_x = 24.121  | beta_y = 5.315  |  alpha_x = 2.520 |  alpha_y = 4.250
# s = 32.600 m  |  beta_x = 23.619  | beta_y = 4.501  |  alpha_x = 2.493 |  alpha_y = 3.892
# s = 32.700 m  |  beta_x = 23.123  | beta_y = 3.758  |  alpha_x = 2.466 |  alpha_y = 3.534
# s = 32.800 m  |  beta_x = 22.633  | beta_y = 3.087  |  alpha_x = 2.439 |  alpha_y = 3.176
# s = 32.900 m  |  beta_x = 22.148  | beta_y = 2.488  |  alpha_x = 2.412 |  alpha_y = 2.817
# s = 33.000 m  |  beta_x = 21.668  | beta_y = 1.961  |  alpha_x = 2.384 |  alpha_y = 2.458
# s = 33.100 m  |  beta_x = 21.194  | beta_y = 1.505  |  alpha_x = 2.357 |  alpha_y = 2.099
# s = 33.200 m  |  beta_x = 20.725  | beta_y = 1.121  |  alpha_x = 2.329 |  alpha_y = 1.740
# s = 33.300 m  |  beta_x = 20.262  | beta_y = 0.809  |  alpha_x = 2.301 |  alpha_y = 1.381
# s = 33.400 m  |  beta_x = 19.805  | beta_y = 0.569  |  alpha_x = 2.272 |  alpha_y = 1.022
# s = 33.500 m  |  beta_x = 19.353  | beta_y = 0.400  |  alpha_x = 2.244 |  alpha_y = 0.662
# s = 33.600 m  |  beta_x = 18.907  | beta_y = 0.304  |  alpha_x = 2.215 |  alpha_y = 0.303
# s = 33.700 m  |  beta_x = 18.467  | beta_y = 0.279  |  alpha_x = 2.187 |  alpha_y = -0.057
# s = 33.800 m  |  beta_x = 18.033  | beta_y = 0.326  |  alpha_x = 2.158 |  alpha_y = -0.416
# s = 33.900 m  |  beta_x = 17.604  | beta_y = 0.445  |  alpha_x = 2.129 |  alpha_y = -0.775
# s = 34.000 m  |  beta_x = 17.181  | beta_y = 0.637  |  alpha_x = 2.098 |  alpha_y = -1.135
# s = 34.100 m  |  beta_x = 16.765  | beta_y = 0.899  |  alpha_x = 2.067 |  alpha_y = -1.494
# s = 34.200 m  |  beta_x = 16.354  | beta_y = 1.234  |  alpha_x = 2.037 |  alpha_y = -1.854
# s = 34.300 m  |  beta_x = 15.950  | beta_y = 1.641  |  alpha_x = 2.008 |  alpha_y = -2.213
# s = 34.400 m  |  beta_x = 15.551  | beta_y = 2.119  |  alpha_x = 1.978 |  alpha_y = -2.572
# s = 34.500 m  |  beta_x = 15.159  | beta_y = 2.670  |  alpha_x = 1.949 |  alpha_y = -2.931
# s = 34.600 m  |  beta_x = 14.772  | beta_y = 3.292  |  alpha_x = 1.919 |  alpha_y = -3.290
# s = 34.700 m  |  beta_x = 14.391  | beta_y = 3.985  |  alpha_x = 1.889 |  alpha_y = -3.648
# s = 34.800 m  |  beta_x = 14.016  | beta_y = 4.751  |  alpha_x = 1.859 |  alpha_y = -4.007
# s = 34.900 m  |  beta_x = 13.648  | beta_y = 5.588  |  alpha_x = 1.829 |  alpha_y = -4.365
# s = 35.000 m  |  beta_x = 13.285  | beta_y = 6.497  |  alpha_x = 1.799 |  alpha_y = -4.723
# s = 35.100 m  |  beta_x = 12.928  | beta_y = 7.477  |  alpha_x = 1.768 |  alpha_y = -5.081
# s = 35.200 m  |  beta_x = 12.578  | beta_y = 8.529  |  alpha_x = 1.738 |  alpha_y = -5.438
# s = 35.300 m  |  beta_x = 12.233  | beta_y = 9.652  |  alpha_x = 1.707 |  alpha_y = -5.796
# s = 35.400 m  |  beta_x = 11.895  | beta_y = 10.847  |  alpha_x = 1.677 |  alpha_y = -6.153
# s = 35.500 m  |  beta_x = 11.562  | beta_y = 12.114  |  alpha_x = 1.646 |  alpha_y = -6.510
# s = 35.600 m  |  beta_x = 11.236  | beta_y = 13.451  |  alpha_x = 1.615 |  alpha_y = -6.866
# s = 35.700 m  |  beta_x = 10.916  | beta_y = 14.860  |  alpha_x = 1.584 |  alpha_y = -7.223
# s = 35.800 m  |  beta_x = 10.603  | beta_y = 16.340  |  alpha_x = 1.553 |  alpha_y = -7.579
# s = 35.900 m  |  beta_x = 10.295  | beta_y = 17.892  |  alpha_x = 1.522 |  alpha_y = -7.934
# s = 36.000 m  |  beta_x = 9.994  | beta_y = 19.514  |  alpha_x = 1.491 |  alpha_y = -8.290
# s = 36.100 m  |  beta_x = 9.699  | beta_y = 21.207  |  alpha_x = 1.459 |  alpha_y = -8.646
# s = 36.200 m  |  beta_x = 9.410  | beta_y = 22.972  |  alpha_x = 1.427 |  alpha_y = -9.004
# s = 36.300 m  |  beta_x = 9.468  | beta_y = 23.936  |  alpha_x = -2.434 |  alpha_y = 0.553
# s = 36.400 m  |  beta_x = 10.205  | beta_y = 23.239  |  alpha_x = -3.994 |  alpha_y = 4.014
# s = 36.500 m  |  beta_x = 10.679  | beta_y = 23.174  |  alpha_x = 0.170 |  alpha_y = -5.261
# s = 36.600 m  |  beta_x = 10.117  | beta_y = 25.465  |  alpha_x = 5.358 |  alpha_y = -18.031
# s = 36.700 m  |  beta_x = 8.757  | beta_y = 30.143  |  alpha_x = 6.971 |  alpha_y = -25.673
# s = 36.800 m  |  beta_x = 7.590  | beta_y = 34.753  |  alpha_x = 4.017 |  alpha_y = -16.766
# s = 36.900 m  |  beta_x = 7.063  | beta_y = 36.896  |  alpha_x = 2.129 |  alpha_y = -8.614
# s = 37.000 m  |  beta_x = 6.645  | beta_y = 38.639  |  alpha_x = 2.051 |  alpha_y = -8.818
# s = 37.100 m  |  beta_x = 6.243  | beta_y = 40.423  |  alpha_x = 1.972 |  alpha_y = -9.022
# s = 37.200 m  |  beta_x = 5.856  | beta_y = 42.248  |  alpha_x = 1.894 |  alpha_y = -9.226
# s = 37.300 m  |  beta_x = 5.485  | beta_y = 44.113  |  alpha_x = 1.816 |  alpha_y = -9.426
# s = 37.400 m  |  beta_x = 5.130  | beta_y = 46.018  |  alpha_x = 1.738 |  alpha_y = -9.625
# s = 37.500 m  |  beta_x = 4.790  | beta_y = 47.963  |  alpha_x = 1.660 |  alpha_y = -9.823
# s = 37.600 m  |  beta_x = 4.466  | beta_y = 49.948  |  alpha_x = 1.582 |  alpha_y = -10.021
# s = 37.700 m  |  beta_x = 4.157  | beta_y = 51.972  |  alpha_x = 1.504 |  alpha_y = -10.219
# s = 37.800 m  |  beta_x = 3.864  | beta_y = 54.035  |  alpha_x = 1.426 |  alpha_y = -10.416
# s = 37.900 m  |  beta_x = 3.586  | beta_y = 56.138  |  alpha_x = 1.348 |  alpha_y = -10.613
# s = 38.000 m  |  beta_x = 3.325  | beta_y = 58.280  |  alpha_x = 1.270 |  alpha_y = -10.810
# s = 38.100 m  |  beta_x = 3.078  | beta_y = 60.462  |  alpha_x = 1.192 |  alpha_y = -11.006
# s = 38.200 m  |  beta_x = 2.848  | beta_y = 62.683  |  alpha_x = 1.113 |  alpha_y = -11.202
# s = 38.300 m  |  beta_x = 2.633  | beta_y = 64.943  |  alpha_x = 1.035 |  alpha_y = -11.398
# s = 38.400 m  |  beta_x = 2.434  | beta_y = 67.242  |  alpha_x = 0.956 |  alpha_y = -11.593
# s = 38.500 m  |  beta_x = 2.251  | beta_y = 69.580  |  alpha_x = 0.878 |  alpha_y = -11.788
# s = 38.600 m  |  beta_x = 2.083  | beta_y = 71.957  |  alpha_x = 0.800 |  alpha_y = -11.982
# s = 38.700 m  |  beta_x = 1.931  | beta_y = 74.373  |  alpha_x = 0.721 |  alpha_y = -12.176
# s = 38.800 m  |  beta_x = 1.794  | beta_y = 76.827  |  alpha_x = 0.642 |  alpha_y = -12.370
# s = 38.900 m  |  beta_x = 1.674  | beta_y = 79.321  |  alpha_x = 0.564 |  alpha_y = -12.563
# s = 39.000 m  |  beta_x = 1.569  | beta_y = 81.852  |  alpha_x = 0.485 |  alpha_y = -12.756
# s = 39.100 m  |  beta_x = 1.480  | beta_y = 84.423  |  alpha_x = 0.407 |  alpha_y = -12.948
# s = 39.200 m  |  beta_x = 1.406  | beta_y = 87.032  |  alpha_x = 0.328 |  alpha_y = -13.147
# s = 39.300 m  |  beta_x = 1.348  | beta_y = 89.682  |  alpha_x = 0.249 |  alpha_y = -13.347
# s = 39.400 m  |  beta_x = 1.307  | beta_y = 92.370  |  alpha_x = 0.171 |  alpha_y = -13.538
# s = 39.500 m  |  beta_x = 1.280  | beta_y = 95.097  |  alpha_x = 0.092 |  alpha_y = -13.729
# s = 39.600 m  |  beta_x = 1.270  | beta_y = 97.862  |  alpha_x = 0.013 |  alpha_y = -13.920
# s = 39.700 m  |  beta_x = 1.275  | beta_y = 100.665  |  alpha_x = -0.065 |  alpha_y = -14.111
# s = 39.800 m  |  beta_x = 1.296  | beta_y = 103.506  |  alpha_x = -0.144 |  alpha_y = -14.301
# s = 39.900 m  |  beta_x = 1.333  | beta_y = 106.385  |  alpha_x = -0.223 |  alpha_y = -14.490
# s = 40.000 m  |  beta_x = 1.385  | beta_y = 109.302  |  alpha_x = -0.301 |  alpha_y = -14.679
# s = 40.100 m  |  beta_x = 1.453  | beta_y = 112.257  |  alpha_x = -0.380 |  alpha_y = -14.868
# s = 40.200 m  |  beta_x = 1.537  | beta_y = 115.250  |  alpha_x = -0.459 |  alpha_y = -15.057
# s = 40.300 m  |  beta_x = 1.637  | beta_y = 118.280  |  alpha_x = -0.537 |  alpha_y = -15.245
# s = 40.400 m  |  beta_x = 1.752  | beta_y = 121.347  |  alpha_x = -0.616 |  alpha_y = -15.432
# s = 40.500 m  |  beta_x = 1.883  | beta_y = 124.453  |  alpha_x = -0.694 |  alpha_y = -15.620
# s = 40.600 m  |  beta_x = 2.030  | beta_y = 127.595  |  alpha_x = -0.773 |  alpha_y = -15.806
# s = 40.700 m  |  beta_x = 2.192  | beta_y = 130.775  |  alpha_x = -0.852 |  alpha_y = -15.993
# s = 40.800 m  |  beta_x = 2.370  | beta_y = 133.992  |  alpha_x = -0.930 |  alpha_y = -16.179
# s = 40.900 m  |  beta_x = 2.564  | beta_y = 137.247  |  alpha_x = -1.009 |  alpha_y = -16.364
# s = 41.000 m  |  beta_x = 2.774  | beta_y = 140.538  |  alpha_x = -1.087 |  alpha_y = -16.550
# s = 41.100 m  |  beta_x = 2.999  | beta_y = 143.867  |  alpha_x = -1.165 |  alpha_y = -16.734
# s = 41.200 m  |  beta_x = 3.240  | beta_y = 147.232  |  alpha_x = -1.244 |  alpha_y = -16.921
# s = 41.300 m  |  beta_x = 3.497  | beta_y = 150.636  |  alpha_x = -1.323 |  alpha_y = -17.116
# s = 41.400 m  |  beta_x = 3.769  | beta_y = 154.078  |  alpha_x = -1.401 |  alpha_y = -17.311
# s = 41.500 m  |  beta_x = 4.057  | beta_y = 157.560  |  alpha_x = -1.480 |  alpha_y = -17.506
# s = 41.600 m  |  beta_x = 4.361  | beta_y = 161.081  |  alpha_x = -1.558 |  alpha_y = -17.701
# s = 41.700 m  |  beta_x = 4.776  | beta_y = 161.310  |  alpha_x = -3.355 |  alpha_y = 40.956
# s = 41.800 m  |  beta_x = 5.770  | beta_y = 144.612  |  alpha_x = -5.943 |  alpha_y = 101.281
# s = 41.900 m  |  beta_x = 6.999  | beta_y = 125.476  |  alpha_x = -5.527 |  alpha_y = 75.482
# s = 42.000 m  |  beta_x = 7.629  | beta_y = 118.961  |  alpha_x = -0.626 |  alpha_y = -8.842
# s = 42.100 m  |  beta_x = 7.238  | beta_y = 129.177  |  alpha_x = 4.444 |  alpha_y = -95.652
# s = 42.200 m  |  beta_x = 6.463  | beta_y = 147.116  |  alpha_x = 2.280 |  alpha_y = -59.628
# s = 42.300 m  |  beta_x = 6.396  | beta_y = 150.120  |  alpha_x = -0.832 |  alpha_y = 12.224
# s = 42.400 m  |  beta_x = 6.565  | beta_y = 147.685  |  alpha_x = -0.858 |  alpha_y = 12.124
# s = 42.500 m  |  beta_x = 6.739  | beta_y = 145.270  |  alpha_x = -0.885 |  alpha_y = 12.023
# s = 42.600 m  |  beta_x = 6.919  | beta_y = 142.876  |  alpha_x = -0.911 |  alpha_y = 11.923
# s = 42.700 m  |  beta_x = 7.103  | beta_y = 140.501  |  alpha_x = -0.937 |  alpha_y = 11.823
# s = 42.800 m  |  beta_x = 7.294  | beta_y = 138.147  |  alpha_x = -0.964 |  alpha_y = 11.723
# s = 42.900 m  |  beta_x = 7.489  | beta_y = 135.812  |  alpha_x = -0.990 |  alpha_y = 11.623
# s = 43.000 m  |  beta_x = 7.690  | beta_y = 133.497  |  alpha_x = -1.017 |  alpha_y = 11.522
# s = 43.100 m  |  beta_x = 7.896  | beta_y = 131.203  |  alpha_x = -1.043 |  alpha_y = 11.422
# s = 43.200 m  |  beta_x = 8.107  | beta_y = 128.929  |  alpha_x = -1.070 |  alpha_y = 11.322
# s = 43.300 m  |  beta_x = 8.324  | beta_y = 126.674  |  alpha_x = -1.096 |  alpha_y = 11.222
# s = 43.400 m  |  beta_x = 8.545  | beta_y = 124.440  |  alpha_x = -1.123 |  alpha_y = 11.122
# s = 43.500 m  |  beta_x = 8.773  | beta_y = 122.226  |  alpha_x = -1.149 |  alpha_y = 11.021
# s = 43.600 m  |  beta_x = 9.005  | beta_y = 120.031  |  alpha_x = -1.175 |  alpha_y = 10.921
# s = 43.700 m  |  beta_x = 9.243  | beta_y = 117.857  |  alpha_x = -1.202 |  alpha_y = 10.821
# s = 43.800 m  |  beta_x = 9.486  | beta_y = 115.703  |  alpha_x = -1.228 |  alpha_y = 10.721
# s = 43.900 m  |  beta_x = 9.734  | beta_y = 113.569  |  alpha_x = -1.255 |  alpha_y = 10.621
# s = 44.000 m  |  beta_x = 9.988  | beta_y = 111.455  |  alpha_x = -1.281 |  alpha_y = 10.520
# s = 44.100 m  |  beta_x = 10.247  | beta_y = 109.361  |  alpha_x = -1.308 |  alpha_y = 10.420
# s = 44.200 m  |  beta_x = 10.511  | beta_y = 107.287  |  alpha_x = -1.334 |  alpha_y = 10.320
# s = 44.300 m  |  beta_x = 10.780  | beta_y = 105.233  |  alpha_x = -1.361 |  alpha_y = 10.220
# s = 44.400 m  |  beta_x = 11.055  | beta_y = 103.199  |  alpha_x = -1.387 |  alpha_y = 10.120
# s = 44.500 m  |  beta_x = 11.335  | beta_y = 101.185  |  alpha_x = -1.414 |  alpha_y = 10.019
# s = 44.600 m  |  beta_x = 11.620  | beta_y = 99.191  |  alpha_x = -1.440 |  alpha_y = 9.919
# s = 44.700 m  |  beta_x = 11.911  | beta_y = 97.217  |  alpha_x = -1.466 |  alpha_y = 9.819
# s = 44.800 m  |  beta_x = 12.207  | beta_y = 95.263  |  alpha_x = -1.493 |  alpha_y = 9.719
# s = 44.900 m  |  beta_x = 12.508  | beta_y = 93.330  |  alpha_x = -1.519 |  alpha_y = 9.619
# s = 45.000 m  |  beta_x = 12.815  | beta_y = 91.416  |  alpha_x = -1.546 |  alpha_y = 9.518
# s = 45.100 m  |  beta_x = 13.127  | beta_y = 89.522  |  alpha_x = -1.572 |  alpha_y = 9.418
# s = 45.200 m  |  beta_x = 13.444  | beta_y = 87.649  |  alpha_x = -1.599 |  alpha_y = 9.319
# s = 45.300 m  |  beta_x = 13.766  | beta_y = 85.794  |  alpha_x = -1.624 |  alpha_y = 9.225
# s = 45.400 m  |  beta_x = 14.093  | beta_y = 83.959  |  alpha_x = -1.649 |  alpha_y = 9.131
# s = 45.500 m  |  beta_x = 14.426  | beta_y = 82.142  |  alpha_x = -1.675 |  alpha_y = 9.036
# s = 45.600 m  |  beta_x = 14.763  | beta_y = 80.344  |  alpha_x = -1.700 |  alpha_y = 8.941
# s = 45.700 m  |  beta_x = 15.106  | beta_y = 78.566  |  alpha_x = -1.725 |  alpha_y = 8.846
# s = 45.800 m  |  beta_x = 15.453  | beta_y = 76.806  |  alpha_x = -1.751 |  alpha_y = 8.751
# s = 45.900 m  |  beta_x = 15.806  | beta_y = 75.065  |  alpha_x = -1.776 |  alpha_y = 8.655
# s = 46.000 m  |  beta_x = 16.163  | beta_y = 73.344  |  alpha_x = -1.801 |  alpha_y = 8.559
# s = 46.100 m  |  beta_x = 16.526  | beta_y = 71.642  |  alpha_x = -1.826 |  alpha_y = 8.462
# s = 46.200 m  |  beta_x = 16.894  | beta_y = 69.959  |  alpha_x = -1.851 |  alpha_y = 8.366
# s = 46.300 m  |  beta_x = 17.267  | beta_y = 68.296  |  alpha_x = -1.876 |  alpha_y = 8.269
# s = 46.400 m  |  beta_x = 17.644  | beta_y = 66.651  |  alpha_x = -1.901 |  alpha_y = 8.172
# s = 46.500 m  |  beta_x = 18.027  | beta_y = 65.027  |  alpha_x = -1.926 |  alpha_y = 8.075
# s = 46.600 m  |  beta_x = 18.415  | beta_y = 63.422  |  alpha_x = -1.951 |  alpha_y = 7.977
# s = 46.700 m  |  beta_x = 18.807  | beta_y = 61.836  |  alpha_x = -1.976 |  alpha_y = 7.879
# s = 46.800 m  |  beta_x = 19.205  | beta_y = 60.270  |  alpha_x = -2.001 |  alpha_y = 7.781
# s = 46.900 m  |  beta_x = 19.608  | beta_y = 58.724  |  alpha_x = -2.025 |  alpha_y = 7.683
# s = 47.000 m  |  beta_x = 20.015  | beta_y = 57.197  |  alpha_x = -2.050 |  alpha_y = 7.584
# s = 47.100 m  |  beta_x = 20.428  | beta_y = 55.690  |  alpha_x = -2.075 |  alpha_y = 7.485
# s = 47.200 m  |  beta_x = 20.845  | beta_y = 54.203  |  alpha_x = -2.101 |  alpha_y = 7.382
# s = 47.300 m  |  beta_x = 21.268  | beta_y = 52.737  |  alpha_x = -2.127 |  alpha_y = 7.281
# s = 47.400 m  |  beta_x = 21.696  | beta_y = 51.291  |  alpha_x = -2.151 |  alpha_y = 7.182
# s = 47.500 m  |  beta_x = 22.129  | beta_y = 49.864  |  alpha_x = -2.176 |  alpha_y = 7.082
# s = 47.600 m  |  beta_x = 22.566  | beta_y = 48.458  |  alpha_x = -2.200 |  alpha_y = 6.983
# s = 47.700 m  |  beta_x = 23.009  | beta_y = 47.071  |  alpha_x = -2.225 |  alpha_y = 6.883
# s = 47.800 m  |  beta_x = 23.456  | beta_y = 45.705  |  alpha_x = -2.249 |  alpha_y = 6.783
# s = 47.900 m  |  beta_x = 23.908  | beta_y = 44.358  |  alpha_x = -2.274 |  alpha_y = 6.683
# s = 48.000 m  |  beta_x = 24.366  | beta_y = 43.032  |  alpha_x = -2.298 |  alpha_y = 6.582
# s = 48.100 m  |  beta_x = 24.828  | beta_y = 41.725  |  alpha_x = -2.322 |  alpha_y = 6.482
# s = 48.200 m  |  beta_x = 25.295  | beta_y = 40.439  |  alpha_x = -2.347 |  alpha_y = 6.381
# s = 48.300 m  |  beta_x = 25.766  | beta_y = 39.173  |  alpha_x = -2.371 |  alpha_y = 6.280
# s = 48.400 m  |  beta_x = 26.243  | beta_y = 37.927  |  alpha_x = -2.395 |  alpha_y = 6.179
# s = 48.500 m  |  beta_x = 26.724  | beta_y = 36.701  |  alpha_x = -2.419 |  alpha_y = 6.078
# s = 48.600 m  |  beta_x = 27.210  | beta_y = 35.495  |  alpha_x = -2.443 |  alpha_y = 5.977
# s = 48.700 m  |  beta_x = 27.701  | beta_y = 34.310  |  alpha_x = -2.467 |  alpha_y = 5.875
# s = 48.800 m  |  beta_x = 28.197  | beta_y = 33.145  |  alpha_x = -2.491 |  alpha_y = 5.774
# s = 48.900 m  |  beta_x = 28.698  | beta_y = 32.001  |  alpha_x = -2.515 |  alpha_y = 5.672
# s = 49.000 m  |  beta_x = 29.203  | beta_y = 30.877  |  alpha_x = -2.539 |  alpha_y = 5.570
# s = 49.100 m  |  beta_x = 29.714  | beta_y = 29.773  |  alpha_x = -2.563 |  alpha_y = 5.468
# s = 49.200 m  |  beta_x = 30.229  | beta_y = 28.690  |  alpha_x = -2.588 |  alpha_y = 5.365
# s = 49.300 m  |  beta_x = 30.749  | beta_y = 27.627  |  alpha_x = -2.613 |  alpha_y = 5.261
# s = 49.400 m  |  beta_x = 31.274  | beta_y = 26.585  |  alpha_x = -2.638 |  alpha_y = 5.157
# s = 49.500 m  |  beta_x = 31.804  | beta_y = 25.564  |  alpha_x = -2.664 |  alpha_y = 5.053
# s = 49.600 m  |  beta_x = 32.339  | beta_y = 24.564  |  alpha_x = -2.688 |  alpha_y = 4.951
# s = 49.700 m  |  beta_x = 32.879  | beta_y = 23.584  |  alpha_x = -2.712 |  alpha_y = 4.848
# s = 49.800 m  |  beta_x = 33.424  | beta_y = 22.625  |  alpha_x = -2.735 |  alpha_y = 4.745
# s = 49.900 m  |  beta_x = 33.973  | beta_y = 21.686  |  alpha_x = -2.759 |  alpha_y = 4.643
# s = 50.000 m  |  beta_x = 34.527  | beta_y = 20.768  |  alpha_x = -2.782 |  alpha_y = 4.540
# s = 50.100 m  |  beta_x = 35.086  | beta_y = 19.870  |  alpha_x = -2.806 |  alpha_y = 4.437
# s = 50.200 m  |  beta_x = 35.650  | beta_y = 18.993  |  alpha_x = -2.829 |  alpha_y = 4.334
# s = 50.300 m  |  beta_x = 36.218  | beta_y = 18.136  |  alpha_x = -2.853 |  alpha_y = 4.230
# s = 50.400 m  |  beta_x = 36.791  | beta_y = 17.301  |  alpha_x = -2.876 |  alpha_y = 4.127
# s = 50.500 m  |  beta_x = 37.368  | beta_y = 16.486  |  alpha_x = -2.899 |  alpha_y = 4.024
# s = 50.600 m  |  beta_x = 37.950  | beta_y = 15.691  |  alpha_x = -2.923 |  alpha_y = 3.920
# s = 50.700 m  |  beta_x = 38.537  | beta_y = 14.918  |  alpha_x = -2.946 |  alpha_y = 3.817
# s = 50.800 m  |  beta_x = 39.129  | beta_y = 14.165  |  alpha_x = -2.969 |  alpha_y = 3.713
# s = 50.900 m  |  beta_x = 39.725  | beta_y = 13.432  |  alpha_x = -2.992 |  alpha_y = 3.609
# s = 51.000 m  |  beta_x = 40.326  | beta_y = 12.721  |  alpha_x = -3.015 |  alpha_y = 3.505
# s = 51.100 m  |  beta_x = 40.931  | beta_y = 12.030  |  alpha_x = -3.038 |  alpha_y = 3.402
# s = 51.200 m  |  beta_x = 41.541  | beta_y = 11.360  |  alpha_x = -3.061 |  alpha_y = 3.298
# s = 51.300 m  |  beta_x = 42.155  | beta_y = 10.711  |  alpha_x = -3.084 |  alpha_y = 3.194
# s = 51.400 m  |  beta_x = 42.774  | beta_y = 10.083  |  alpha_x = -3.107 |  alpha_y = 3.090
# s = 51.500 m  |  beta_x = 43.398  | beta_y = 9.475  |  alpha_x = -3.132 |  alpha_y = 2.985
# s = 51.600 m  |  beta_x = 44.027  | beta_y = 8.889  |  alpha_x = -3.156 |  alpha_y = 2.880
# s = 51.700 m  |  beta_x = 44.661  | beta_y = 8.323  |  alpha_x = -3.179 |  alpha_y = 2.776
# s = 51.800 m  |  beta_x = 45.299  | beta_y = 7.778  |  alpha_x = -3.202 |  alpha_y = 2.672
# s = 51.900 m  |  beta_x = 45.942  | beta_y = 7.254  |  alpha_x = -3.225 |  alpha_y = 2.568
# s = 52.000 m  |  beta_x = 46.589  | beta_y = 6.751  |  alpha_x = -3.247 |  alpha_y = 2.463
# s = 52.100 m  |  beta_x = 47.240  | beta_y = 6.269  |  alpha_x = -3.270 |  alpha_y = 2.359
# s = 52.200 m  |  beta_x = 47.897  | beta_y = 5.808  |  alpha_x = -3.293 |  alpha_y = 2.254
# s = 52.300 m  |  beta_x = 48.557  | beta_y = 5.367  |  alpha_x = -3.315 |  alpha_y = 2.150
# ...
# s = 222.700 m  |  beta_x = 24.819  | beta_y = 79.012  |  alpha_x = 2.985 |  alpha_y = -0.702
# s = 222.800 m  |  beta_x = 24.226  | beta_y = 79.152  |  alpha_x = 2.945 |  alpha_y = -0.704
# s = 222.900 m  |  beta_x = 23.641  | beta_y = 79.293  |  alpha_x = 2.905 |  alpha_y = -0.705
# s = 223.000 m  |  beta_x = 23.064  | beta_y = 79.435  |  alpha_x = 2.865 |  alpha_y = -0.707
# s = 223.100 m  |  beta_x = 22.495  | beta_y = 79.576  |  alpha_x = 2.826 |  alpha_y = -0.709
# s = 223.200 m  |  beta_x = 21.933  | beta_y = 79.718  |  alpha_x = 2.786 |  alpha_y = -0.710
# s = 223.300 m  |  beta_x = 21.380  | beta_y = 79.860  |  alpha_x = 2.746 |  alpha_y = -0.712
# s = 223.400 m  |  beta_x = 20.835  | beta_y = 80.003  |  alpha_x = 2.706 |  alpha_y = -0.714
# s = 223.500 m  |  beta_x = 20.298  | beta_y = 80.146  |  alpha_x = 2.666 |  alpha_y = -0.716
# s = 223.600 m  |  beta_x = 19.769  | beta_y = 80.289  |  alpha_x = 2.626 |  alpha_y = -0.717
# s = 223.700 m  |  beta_x = 19.248  | beta_y = 80.433  |  alpha_x = 2.586 |  alpha_y = -0.719
# s = 223.800 m  |  beta_x = 18.734  | beta_y = 80.577  |  alpha_x = 2.546 |  alpha_y = -0.721
# s = 223.900 m  |  beta_x = 18.229  | beta_y = 80.721  |  alpha_x = 2.506 |  alpha_y = -0.723
# s = 224.000 m  |  beta_x = 17.732  | beta_y = 80.866  |  alpha_x = 2.466 |  alpha_y = -0.724
# s = 224.100 m  |  beta_x = 17.243  | beta_y = 81.011  |  alpha_x = 2.426 |  alpha_y = -0.726
# s = 224.200 m  |  beta_x = 16.761  | beta_y = 81.156  |  alpha_x = 2.387 |  alpha_y = -0.728
# s = 224.300 m  |  beta_x = 16.288  | beta_y = 81.302  |  alpha_x = 2.347 |  alpha_y = -0.730
# s = 224.400 m  |  beta_x = 16.133  | beta_y = 79.884  |  alpha_x = -2.553 |  alpha_y = 23.645
# s = 224.500 m  |  beta_x = 17.443  | beta_y = 71.636  |  alpha_x = -10.759 |  alpha_y = 57.525
# s = 224.600 m  |  beta_x = 20.237  | beta_y = 58.633  |  alpha_x = -15.224 |  alpha_y = 64.177
# s = 224.700 m  |  beta_x = 22.904  | beta_y = 47.585  |  alpha_x = -9.028 |  alpha_y = 42.132
# s = 224.800 m  |  beta_x = 23.645  | beta_y = 41.514  |  alpha_x = 1.731 |  alpha_y = 19.520
# s = 224.900 m  |  beta_x = 22.677  | beta_y = 38.762  |  alpha_x = 5.447 |  alpha_y = 12.386
# s = 225.000 m  |  beta_x = 21.601  | beta_y = 36.325  |  alpha_x = 5.312 |  alpha_y = 11.988
# s = 225.100 m  |  beta_x = 20.553  | beta_y = 33.967  |  alpha_x = 5.176 |  alpha_y = 11.589
# s = 225.200 m  |  beta_x = 19.531  | beta_y = 31.689  |  alpha_x = 5.041 |  alpha_y = 11.191
# s = 225.300 m  |  beta_x = 18.536  | beta_y = 29.491  |  alpha_x = 4.906 |  alpha_y = 10.793
# s = 225.400 m  |  beta_x = 17.569  | beta_y = 27.372  |  alpha_x = 4.771 |  alpha_y = 10.394
# s = 225.500 m  |  beta_x = 16.628  | beta_y = 25.333  |  alpha_x = 4.635 |  alpha_y = 9.996
# s = 225.600 m  |  beta_x = 15.714  | beta_y = 23.374  |  alpha_x = 4.500 |  alpha_y = 9.597
# s = 225.700 m  |  beta_x = 14.828  | beta_y = 21.494  |  alpha_x = 4.365 |  alpha_y = 9.199
# s = 225.800 m  |  beta_x = 13.968  | beta_y = 19.694  |  alpha_x = 4.230 |  alpha_y = 8.801
# s = 225.900 m  |  beta_x = 13.136  | beta_y = 17.974  |  alpha_x = 4.094 |  alpha_y = 8.402
# s = 226.000 m  |  beta_x = 12.331  | beta_y = 16.333  |  alpha_x = 3.959 |  alpha_y = 8.004
# s = 226.100 m  |  beta_x = 11.552  | beta_y = 14.772  |  alpha_x = 3.824 |  alpha_y = 7.606
# s = 226.200 m  |  beta_x = 10.801  | beta_y = 13.291  |  alpha_x = 3.689 |  alpha_y = 7.207
# s = 226.300 m  |  beta_x = 10.077  | beta_y = 11.889  |  alpha_x = 3.553 |  alpha_y = 6.809
# s = 226.400 m  |  beta_x = 9.380  | beta_y = 10.567  |  alpha_x = 3.418 |  alpha_y = 6.411
# s = 226.500 m  |  beta_x = 8.710  | beta_y = 9.325  |  alpha_x = 3.283 |  alpha_y = 6.012
# s = 226.600 m  |  beta_x = 8.067  | beta_y = 8.163  |  alpha_x = 3.148 |  alpha_y = 5.614
# s = 226.700 m  |  beta_x = 7.450  | beta_y = 7.080  |  alpha_x = 3.013 |  alpha_y = 5.216
# s = 226.800 m  |  beta_x = 6.861  | beta_y = 6.076  |  alpha_x = 2.877 |  alpha_y = 4.817
# s = 226.900 m  |  beta_x = 6.300  | beta_y = 5.153  |  alpha_x = 2.742 |  alpha_y = 4.419
# s = 227.000 m  |  beta_x = 5.765  | beta_y = 4.309  |  alpha_x = 2.607 |  alpha_y = 4.020
# s = 227.100 m  |  beta_x = 5.257  | beta_y = 3.544  |  alpha_x = 2.472 |  alpha_y = 3.622
# s = 227.200 m  |  beta_x = 4.776  | beta_y = 2.860  |  alpha_x = 2.336 |  alpha_y = 3.224
# s = 227.300 m  |  beta_x = 4.322  | beta_y = 2.255  |  alpha_x = 2.201 |  alpha_y = 2.825
# s = 227.400 m  |  beta_x = 3.896  | beta_y = 1.730  |  alpha_x = 2.066 |  alpha_y = 2.427
# s = 227.500 m  |  beta_x = 3.496  | beta_y = 1.284  |  alpha_x = 1.931 |  alpha_y = 2.029
# s = 227.600 m  |  beta_x = 3.123  | beta_y = 0.918  |  alpha_x = 1.795 |  alpha_y = 1.630
# s = 227.700 m  |  beta_x = 2.778  | beta_y = 0.632  |  alpha_x = 1.660 |  alpha_y = 1.232
# s = 227.800 m  |  beta_x = 2.459  | beta_y = 0.425  |  alpha_x = 1.525 |  alpha_y = 0.834
# s = 227.900 m  |  beta_x = 2.168  | beta_y = 0.299  |  alpha_x = 1.390 |  alpha_y = 0.435
# s = 228.000 m  |  beta_x = 1.903  | beta_y = 0.251  |  alpha_x = 1.255 |  alpha_y = 0.037
# s = 228.100 m  |  beta_x = 1.666  | beta_y = 0.284  |  alpha_x = 1.119 |  alpha_y = -0.361
# s = 228.200 m  |  beta_x = 1.456  | beta_y = 0.396  |  alpha_x = 0.984 |  alpha_y = -0.760
# s = 228.300 m  |  beta_x = 1.272  | beta_y = 0.588  |  alpha_x = 0.849 |  alpha_y = -1.158
# s = 228.400 m  |  beta_x = 1.116  | beta_y = 0.859  |  alpha_x = 0.714 |  alpha_y = -1.557
# s = 228.500 m  |  beta_x = 0.987  | beta_y = 1.210  |  alpha_x = 0.578 |  alpha_y = -1.955
# s = 228.600 m  |  beta_x = 0.885  | beta_y = 1.641  |  alpha_x = 0.443 |  alpha_y = -2.353
# s = 228.700 m  |  beta_x = 0.810  | beta_y = 2.152  |  alpha_x = 0.308 |  alpha_y = -2.752
# s = 228.800 m  |  beta_x = 0.762  | beta_y = 2.742  |  alpha_x = 0.173 |  alpha_y = -3.150
# s = 228.900 m  |  beta_x = 0.741  | beta_y = 3.412  |  alpha_x = 0.037 |  alpha_y = -3.548
# s = 229.000 m  |  beta_x = 0.747  | beta_y = 4.161  |  alpha_x = -0.098 |  alpha_y = -3.947
# s = 229.100 m  |  beta_x = 0.780  | beta_y = 4.990  |  alpha_x = -0.233 |  alpha_y = -4.345
# s = 229.200 m  |  beta_x = 0.840  | beta_y = 5.899  |  alpha_x = -0.368 |  alpha_y = -4.743
# s = 229.300 m  |  beta_x = 0.927  | beta_y = 6.888  |  alpha_x = -0.504 |  alpha_y = -5.142
# s = 229.400 m  |  beta_x = 1.041  | beta_y = 7.956  |  alpha_x = -0.639 |  alpha_y = -5.540
# s = 229.500 m  |  beta_x = 1.182  | beta_y = 9.104  |  alpha_x = -0.774 |  alpha_y = -5.938
# s = 229.600 m  |  beta_x = 1.351  | beta_y = 10.331  |  alpha_x = -0.909 |  alpha_y = -6.337
# s = 229.700 m  |  beta_x = 1.546  | beta_y = 11.638  |  alpha_x = -1.044 |  alpha_y = -6.735
# s = 229.800 m  |  beta_x = 1.769  | beta_y = 13.025  |  alpha_x = -1.180 |  alpha_y = -7.133
# s = 229.900 m  |  beta_x = 2.018  | beta_y = 14.492  |  alpha_x = -1.315 |  alpha_y = -7.532
# s = 230.000 m  |  beta_x = 2.294  | beta_y = 16.038  |  alpha_x = -1.450 |  alpha_y = -7.930
# s = 230.100 m  |  beta_x = 2.598  | beta_y = 17.664  |  alpha_x = -1.585 |  alpha_y = -8.328
# s = 230.200 m  |  beta_x = 2.929  | beta_y = 19.369  |  alpha_x = -1.721 |  alpha_y = -8.727
# s = 230.300 m  |  beta_x = 3.286  | beta_y = 21.154  |  alpha_x = -1.856 |  alpha_y = -9.125
# s = 230.400 m  |  beta_x = 3.671  | beta_y = 23.019  |  alpha_x = -1.991 |  alpha_y = -9.523
# s = 230.500 m  |  beta_x = 4.083  | beta_y = 24.964  |  alpha_x = -2.126 |  alpha_y = -9.922
# s = 230.600 m  |  beta_x = 4.521  | beta_y = 26.988  |  alpha_x = -2.261 |  alpha_y = -10.320
# s = 230.700 m  |  beta_x = 4.987  | beta_y = 29.092  |  alpha_x = -2.397 |  alpha_y = -10.718
# s = 230.800 m  |  beta_x = 5.480  | beta_y = 31.275  |  alpha_x = -2.532 |  alpha_y = -11.116
# s = 230.900 m  |  beta_x = 6.000  | beta_y = 33.538  |  alpha_x = -2.667 |  alpha_y = -11.515
# s = 231.000 m  |  beta_x = 6.547  | beta_y = 35.881  |  alpha_x = -2.802 |  alpha_y = -11.913
# s = 231.100 m  |  beta_x = 7.121  | beta_y = 38.303  |  alpha_x = -2.938 |  alpha_y = -12.311
# s = 231.200 m  |  beta_x = 7.722  | beta_y = 40.806  |  alpha_x = -3.073 |  alpha_y = -12.709
# s = 231.300 m  |  beta_x = 8.350  | beta_y = 43.387  |  alpha_x = -3.208 |  alpha_y = -13.108
# s = 231.400 m  |  beta_x = 9.005  | beta_y = 46.049  |  alpha_x = -3.343 |  alpha_y = -13.506
# s = 231.500 m  |  beta_x = 9.687  | beta_y = 48.790  |  alpha_x = -3.478 |  alpha_y = -13.904
# s = 231.600 m  |  beta_x = 10.396  | beta_y = 51.610  |  alpha_x = -3.614 |  alpha_y = -14.302
# s = 231.700 m  |  beta_x = 11.133  | beta_y = 54.510  |  alpha_x = -3.749 |  alpha_y = -14.701
# s = 231.800 m  |  beta_x = 11.896  | beta_y = 57.490  |  alpha_x = -3.884 |  alpha_y = -15.099
# s = 231.900 m  |  beta_x = 12.686  | beta_y = 60.550  |  alpha_x = -4.019 |  alpha_y = -15.497
# s = 232.000 m  |  beta_x = 13.504  | beta_y = 63.689  |  alpha_x = -4.154 |  alpha_y = -15.895
# s = 232.100 m  |  beta_x = 14.348  | beta_y = 66.908  |  alpha_x = -4.290 |  alpha_y = -16.293
# s = 232.200 m  |  beta_x = 15.219  | beta_y = 70.207  |  alpha_x = -4.425 |  alpha_y = -16.691
# s = 232.300 m  |  beta_x = 16.118  | beta_y = 73.585  |  alpha_x = -4.560 |  alpha_y = -17.090
# s = 232.400 m  |  beta_x = 17.043  | beta_y = 77.042  |  alpha_x = -4.695 |  alpha_y = -17.488
# s = 232.500 m  |  beta_x = 17.996  | beta_y = 80.580  |  alpha_x = -4.830 |  alpha_y = -17.886
# s = 232.600 m  |  beta_x = 18.976  | beta_y = 84.197  |  alpha_x = -4.965 |  alpha_y = -18.284
# s = 232.700 m  |  beta_x = 19.982  | beta_y = 87.893  |  alpha_x = -5.101 |  alpha_y = -18.682
# s = 232.800 m  |  beta_x = 21.016  | beta_y = 91.669  |  alpha_x = -5.236 |  alpha_y = -19.080
# s = 232.900 m  |  beta_x = 22.076  | beta_y = 95.525  |  alpha_x = -5.371 |  alpha_y = -19.478
# s = 233.000 m  |  beta_x = 23.164  | beta_y = 99.461  |  alpha_x = -5.506 |  alpha_y = -19.876
# s = 233.100 m  |  beta_x = 24.279  | beta_y = 103.476  |  alpha_x = -5.641 |  alpha_y = -20.274
# s = 233.200 m  |  beta_x = 25.421  | beta_y = 107.570  |  alpha_x = -5.776 |  alpha_y = -20.672
# s = 233.300 m  |  beta_x = 26.589  | beta_y = 111.744  |  alpha_x = -5.912 |  alpha_y = -21.070
# s = 233.400 m  |  beta_x = 27.785  | beta_y = 115.998  |  alpha_x = -6.047 |  alpha_y = -21.468
# s = 233.500 m  |  beta_x = 29.008  | beta_y = 120.332  |  alpha_x = -6.182 |  alpha_y = -21.866
# s = 233.600 m  |  beta_x = 30.258  | beta_y = 124.745  |  alpha_x = -6.317 |  alpha_y = -22.264
# s = 233.700 m  |  beta_x = 31.535  | beta_y = 129.237  |  alpha_x = -6.452 |  alpha_y = -22.662
# s = 233.800 m  |  beta_x = 32.839  | beta_y = 133.810  |  alpha_x = -6.587 |  alpha_y = -23.060
# s = 233.900 m  |  beta_x = 34.170  | beta_y = 138.462  |  alpha_x = -6.723 |  alpha_y = -23.459
# s = 234.000 m  |  beta_x = 35.528  | beta_y = 143.193  |  alpha_x = -6.858 |  alpha_y = -23.857
# s = 234.100 m  |  beta_x = 36.913  | beta_y = 148.004  |  alpha_x = -6.993 |  alpha_y = -24.255
# s = 234.200 m  |  beta_x = 38.325  | beta_y = 152.895  |  alpha_x = -7.128 |  alpha_y = -24.653
# s = 234.300 m  |  beta_x = 39.764  | beta_y = 157.865  |  alpha_x = -7.263 |  alpha_y = -25.051
# s = 234.400 m  |  beta_x = 41.230  | beta_y = 162.915  |  alpha_x = -7.398 |  alpha_y = -25.449
# s = 234.500 m  |  beta_x = 42.723  | beta_y = 168.045  |  alpha_x = -7.533 |  alpha_y = -25.846
# s = 234.600 m  |  beta_x = 44.244  | beta_y = 173.254  |  alpha_x = -7.668 |  alpha_y = -26.244
# s = 234.700 m  |  beta_x = 45.791  | beta_y = 178.543  |  alpha_x = -7.804 |  alpha_y = -26.642
# s = 234.800 m  |  beta_x = 47.365  | beta_y = 183.911  |  alpha_x = -7.939 |  alpha_y = -27.040
# s = 234.900 m  |  beta_x = 48.966  | beta_y = 189.358  |  alpha_x = -8.074 |  alpha_y = -27.438
# s = 235.000 m  |  beta_x = 50.595  | beta_y = 194.886  |  alpha_x = -8.209 |  alpha_y = -27.835
# s = 235.100 m  |  beta_x = 52.250  | beta_y = 200.493  |  alpha_x = -8.344 |  alpha_y = -28.233
# s = 235.200 m  |  beta_x = 53.932  | beta_y = 206.179  |  alpha_x = -8.479 |  alpha_y = -28.631
# s = 235.300 m  |  beta_x = 55.641  | beta_y = 211.945  |  alpha_x = -8.614 |  alpha_y = -29.029
# s = 235.400 m  |  beta_x = 57.378  | beta_y = 217.790  |  alpha_x = -8.749 |  alpha_y = -29.426
# s = 235.500 m  |  beta_x = 59.141  | beta_y = 223.715  |  alpha_x = -8.884 |  alpha_y = -29.824
# s = 235.600 m  |  beta_x = 60.931  | beta_y = 229.720  |  alpha_x = -9.019 |  alpha_y = -30.221
# s = 235.700 m  |  beta_x = 62.749  | beta_y = 235.804  |  alpha_x = -9.154 |  alpha_y = -30.619
# s = 235.800 m  |  beta_x = 64.593  | beta_y = 241.968  |  alpha_x = -9.289 |  alpha_y = -31.017
# s = 235.900 m  |  beta_x = 66.464  | beta_y = 248.211  |  alpha_x = -9.424 |  alpha_y = -31.414
# s = 236.000 m  |  beta_x = 68.363  | beta_y = 254.533  |  alpha_x = -9.559 |  alpha_y = -31.812
# s = 236.100 m  |  beta_x = 70.288  | beta_y = 260.936  |  alpha_x = -9.694 |  alpha_y = -32.210
# s = 236.200 m  |  beta_x = 72.240  | beta_y = 267.417  |  alpha_x = -9.830 |  alpha_y = -32.608
# s = 236.300 m  |  beta_x = 74.220  | beta_y = 273.979  |  alpha_x = -9.965 |  alpha_y = -33.005
# s = 236.400 m  |  beta_x = 76.226  | beta_y = 280.619  |  alpha_x = -10.100 |  alpha_y = -33.403
# s = 236.500 m  |  beta_x = 78.260  | beta_y = 287.340  |  alpha_x = -10.235 |  alpha_y = -33.800
# s = 236.600 m  |  beta_x = 80.320  | beta_y = 294.140  |  alpha_x = -10.369 |  alpha_y = -34.198
# s = 236.700 m  |  beta_x = 82.407  | beta_y = 301.019  |  alpha_x = -10.504 |  alpha_y = -34.595
# s = 236.800 m  |  beta_x = 84.522  | beta_y = 307.978  |  alpha_x = -10.639 |  alpha_y = -34.993
# s = 236.900 m  |  beta_x = 86.663  | beta_y = 315.016  |  alpha_x = -10.774 |  alpha_y = -35.390
# s = 237.000 m  |  beta_x = 88.832  | beta_y = 322.134  |  alpha_x = -10.909 |  alpha_y = -35.787
# s = 237.100 m  |  beta_x = 91.027  | beta_y = 329.331  |  alpha_x = -11.044 |  alpha_y = -36.185
# s = 237.200 m  |  beta_x = 93.249  | beta_y = 336.608  |  alpha_x = -11.179 |  alpha_y = -36.582
# s = 237.300 m  |  beta_x = 95.499  | beta_y = 343.964  |  alpha_x = -11.314 |  alpha_y = -36.979
# s = 237.400 m  |  beta_x = 97.775  | beta_y = 351.399  |  alpha_x = -11.449 |  alpha_y = -37.377
# s = 237.500 m  |  beta_x = 100.078  | beta_y = 358.914  |  alpha_x = -11.584 |  alpha_y = -37.774
# s = 237.600 m  |  beta_x = 102.409  | beta_y = 366.509  |  alpha_x = -11.719 |  alpha_y = -38.171
# s = 237.700 m  |  beta_x = 104.766  | beta_y = 374.183  |  alpha_x = -11.854 |  alpha_y = -38.568
# s = 237.800 m  |  beta_x = 107.150  | beta_y = 381.936  |  alpha_x = -11.989 |  alpha_y = -38.965
# s = 237.900 m  |  beta_x = 109.561  | beta_y = 389.769  |  alpha_x = -12.124 |  alpha_y = -39.363
# s = 238.000 m  |  beta_x = 112.000  | beta_y = 397.681  |  alpha_x = -12.259 |  alpha_y = -39.760
# s = 238.100 m  |  beta_x = 114.465  | beta_y = 405.673  |  alpha_x = -12.393 |  alpha_y = -40.157
# s = 238.200 m  |  beta_x = 116.957  | beta_y = 413.744  |  alpha_x = -12.529 |  alpha_y = -40.555
# s = 238.300 m  |  beta_x = 119.476  | beta_y = 421.895  |  alpha_x = -12.664 |  alpha_y = -40.953
# s = 238.400 m  |  beta_x = 122.614  | beta_y = 428.047  |  alpha_x = -29.157 |  alpha_y = 15.941
# s = 238.500 m  |  beta_x = 133.229  | beta_y = 409.378  |  alpha_x = -78.289 |  alpha_y = 168.445
# s = 238.600 m  |  beta_x = 154.117  | beta_y = 363.735  |  alpha_x = -120.667 |  alpha_y = 253.188
# s = 238.700 m  |  beta_x = 178.072  | beta_y = 316.924  |  alpha_x = -102.428 |  alpha_y = 186.498
# s = 238.800 m  |  beta_x = 192.023  | beta_y = 291.853  |  alpha_x = -35.324 |  alpha_y = 67.346
# s = 238.900 m  |  beta_x = 192.864  | beta_y = 287.791  |  alpha_x = 10.013 |  alpha_y = -0.967
# s = 239.000 m  |  beta_x = 190.867  | beta_y = 287.984  |  alpha_x = 9.960 |  alpha_y = -0.968
# s = 239.100 m  |  beta_x = 188.880  | beta_y = 288.178  |  alpha_x = 9.908 |  alpha_y = -0.969
# s = 239.200 m  |  beta_x = 186.903  | beta_y = 288.372  |  alpha_x = 9.855 |  alpha_y = -0.969
# s = 239.300 m  |  beta_x = 184.938  | beta_y = 288.566  |  alpha_x = 9.803 |  alpha_y = -0.970
# s = 239.400 m  |  beta_x = 182.982  | beta_y = 288.760  |  alpha_x = 9.750 |  alpha_y = -0.971
# s = 239.410 m  |  beta_x = 182.785  | beta_y = 288.779  |  alpha_x = 9.745 |  alpha_y = -0.971

# %%
def get_energy_at_s(s_target, tws_list):
    s_array = np.array([tw.s for tw in tws_list])
    E_array = np.array([tw.E for tw in tws_list])
    return np.interp(s_target, s_array, E_array)

# %%
def plot_opt_func(lat, tws, top_plot=["Dx"], legend=True, fig_name=None, grid=True, font_size=12,
                  excld_legend=None, figsize=None, plt_figure=None):
    from ocelot.cpbd.optics import lattice_transfer_map

    if plt_figure is None:
        if fig_name is None:
            fig = plt.figure(figsize=figsize)
        else:
            fig = plt.figure(fig_name, figsize=figsize)
    else:
        fig = plt_figure

    plt.rc('axes', grid=grid)
    plt.rc('grid', color='0.75', linestyle='-', linewidth=0.5)
    left, width = 0.1, 0.85

    rect1 = [left, 0.65, width, 0.3]
    rect2 = [left, 0.19, width, 0.46]
    rect3 = [left, 0.07, width, 0.12]

    ax_top = fig.add_axes(rect1)
    ax_b = fig.add_axes(rect2, sharex=ax_top)
    ax_el = fig.add_axes(rect3, sharex=ax_top)

    for ax in ax_b, ax_el, ax_top:
        if ax != ax_el:
            for label in ax.get_xticklabels():
                label.set_visible(False)

    ax_b.grid(grid)
    ax_top.grid(grid)
    ax_el.set_yticks([])
    ax_el.grid(grid)

    fig.subplots_adjust(hspace=0)
    beta_x = [p.beta_x for p in tws]
    beta_y = [p.beta_y for p in tws]
    S = [p.s for p in tws]

    plt.xlim(S[0], S[-1])

    # Plot standard Twiss parameters
    plot_disp(ax_top, tws, [p for p in top_plot if p != "R56"], font_size)

    # ---- Add R56 Plotting ----
    if "R56" in top_plot:
        R56_vals = []
        s_vals = []

        for i in range(2, len(lat.sequence)):
            partial_lat = MagneticLattice(lat.sequence[:i])
            s_here = sum(e.l for e in partial_lat.sequence)

            try:
                E_here = get_energy_at_s(s_here, tws)
                R = lattice_transfer_map(partial_lat, energy=E_here)
                r56 = R[4, 5]
            except Exception as e:
                print(f"[WARN] Failed R56 at s = {s_here:.2f} m: {e}")
                r56 = 0

            # Debug print
            if i % 50 == 0 or s_here > 100:  # customize condition as you like
                print(f"s = {s_here:.2f} m, E = {E_here:.3f} GeV, R56 = {r56*1000:.3f} mm")

            R56_vals.append(r56)
            s_vals.append(s_here)

        
        ax_top.plot(s_vals, np.array(R56_vals), label="R56 [m]", color="red", linewidth=2)

    if "R56" in top_plot or legend:
        ax_top.legend(fontsize=font_size - 2)

    # Plot betas and elements
    plot_betas(ax_b, S, beta_x, beta_y, font_size)
    plot_elems(fig, ax_el, lat, s_point=S[0], legend=legend, y_scale=0.8, font_size=font_size,
               excld_legend=excld_legend)

# %%
plot_opt_func(lat, tws, top_plot=["Dx", "R56"], legend=True )
# Out:
# s = 5.14 m, E = 0.025 GeV, R56 = -0.935 mm
# s = 10.25 m, E = 0.034 GeV, R56 = -17.541 mm
# s = 17.31 m, E = 0.122 GeV, R56 = -21.131 mm
# s = 22.11 m, E = 0.166 GeV, R56 = -21.716 mm
# s = 30.72 m, E = 0.313 GeV, R56 = -22.551 mm
# s = 36.96 m, E = 0.393 GeV, R56 = -22.757 mm
# s = 45.19 m, E = 0.472 GeV, R56 = -22.897 mm
# s = 54.47 m, E = 0.631 GeV, R56 = -23.074 mm
# s = 63.76 m, E = 0.789 GeV, R56 = -23.182 mm
# s = 72.97 m, E = 0.948 GeV, R56 = -23.255 mm
# s = 82.32 m, E = 1.107 GeV, R56 = -23.307 mm
# s = 89.99 m, E = 1.194 GeV, R56 = -23.330 mm
# s = 99.44 m, E = 1.311 GeV, R56 = -23.356 mm
# s = 101.48 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 101.48 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 101.52 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 101.57 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 101.62 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 101.62 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 101.77 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 101.77 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 101.91 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 101.99 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 102.25 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 102.31 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 102.31 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 102.33 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 102.47 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 102.61 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 102.70 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 102.76 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 102.79 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 102.79 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 103.35 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 103.35 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 103.35 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 104.68 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 104.68 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 104.71 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 104.77 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 104.77 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 104.83 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 104.86 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 104.86 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 106.75 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 106.75 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 106.79 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 106.84 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 106.89 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 106.89 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 106.93 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 106.97 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 106.97 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 107.03 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 107.09 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 107.12 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 107.12 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 107.68 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 107.68 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 107.68 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 109.01 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 109.01 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 109.04 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 109.10 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 109.10 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 109.16 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 109.19 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 109.19 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.08 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.08 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.12 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.17 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.22 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.22 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.37 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.37 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.51 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.59 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.85 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.91 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.91 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 111.93 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 112.07 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 112.13 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 112.17 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 112.17 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 112.21 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 112.30 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 112.36 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 112.39 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 112.39 m, E = 1.341 GeV, R56 = -23.362 mm
# s = 112.95 m, E = 1.353 GeV, R56 = -23.364 mm
# s = 112.95 m, E = 1.353 GeV, R56 = -23.364 mm
# s = 112.95 m, E = 1.353 GeV, R56 = -23.364 mm
# s = 114.28 m, E = 1.381 GeV, R56 = -23.370 mm
# s = 114.28 m, E = 1.381 GeV, R56 = -23.370 mm
# s = 114.31 m, E = 1.381 GeV, R56 = -23.370 mm
# s = 114.37 m, E = 1.381 GeV, R56 = -23.370 mm
# s = 114.37 m, E = 1.381 GeV, R56 = -23.370 mm
# s = 114.43 m, E = 1.381 GeV, R56 = -23.370 mm
# s = 114.46 m, E = 1.381 GeV, R56 = -23.370 mm
# s = 114.46 m, E = 1.381 GeV, R56 = -23.370 mm
# s = 116.35 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.35 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.39 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.44 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.49 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.49 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.53 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.57 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.57 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.63 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.69 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.72 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 116.72 m, E = 1.421 GeV, R56 = -23.377 mm
# s = 117.28 m, E = 1.432 GeV, R56 = -23.379 mm
# s = 117.28 m, E = 1.432 GeV, R56 = -23.379 mm
# s = 117.28 m, E = 1.432 GeV, R56 = -23.379 mm
# s = 118.61 m, E = 1.460 GeV, R56 = -23.383 mm
# s = 118.61 m, E = 1.460 GeV, R56 = -23.383 mm
# s = 118.64 m, E = 1.460 GeV, R56 = -23.383 mm
# s = 118.70 m, E = 1.460 GeV, R56 = -23.383 mm
# s = 118.70 m, E = 1.460 GeV, R56 = -23.383 mm
# s = 118.76 m, E = 1.460 GeV, R56 = -23.383 mm
# s = 118.79 m, E = 1.460 GeV, R56 = -23.383 mm
# s = 118.79 m, E = 1.460 GeV, R56 = -23.383 mm
# s = 120.68 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 120.68 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 120.72 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 120.77 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 120.86 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 120.96 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.02 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.02 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.02 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.02 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.06 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.14 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.14 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.26 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.40 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.40 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.52 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.57 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.59 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.59 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.72 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.72 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.95 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 121.95 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 122.28 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 122.36 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 122.42 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 122.42 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 122.48 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 122.48 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 122.48 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 122.81 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 123.05 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 123.05 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 123.35 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 123.64 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 123.85 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 123.98 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.06 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.06 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.18 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.32 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.32 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.44 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.53 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.53 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.53 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.75 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.77 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.77 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 124.77 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 125.09 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 125.30 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 125.30 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 125.62 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 125.93 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 125.96 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 125.96 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 126.01 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 126.14 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 126.14 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 126.14 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 126.14 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 126.14 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 126.14 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 126.14 m, E = 1.500 GeV, R56 = -23.390 mm
# s = 128.05 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.05 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.05 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.05 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.05 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.05 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.05 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.20 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.44 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.44 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.56 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.72 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.76 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.76 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.80 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.84 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.84 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.92 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 128.92 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 129.25 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 129.33 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 129.47 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 129.47 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 129.61 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 129.97 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 130.12 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 130.12 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 130.12 m, E = 1.500 GeV, R56 = 19.728 mm
# s = 132.03 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.03 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.03 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.03 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.17 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.35 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.35 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.47 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.58 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.62 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.62 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.70 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 132.70 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.02 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.11 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.15 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.15 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.19 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.30 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.30 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.62 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.73 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.84 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.84 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 133.95 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 134.09 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 134.09 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 134.09 m, E = 1.500 GeV, R56 = 16.816 mm
# s = 136.00 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.00 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.00 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.00 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.16 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.24 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.24 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.33 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.37 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.37 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.43 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.43 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.54 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.61 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.68 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.68 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.74 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.78 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.78 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.87 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.88 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.88 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 136.88 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.20 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.20 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.21 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.29 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.33 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.37 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.37 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.41 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.45 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.54 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.54 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.66 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 137.93 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 138.08 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 138.08 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 138.08 m, E = 1.500 GeV, R56 = -23.461 mm
# s = 139.99 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 139.99 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 139.99 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 139.99 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.14 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.19 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.19 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.36 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.46 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.46 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.78 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.86 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.91 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.91 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.95 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.99 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 140.99 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 141.06 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 141.06 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 141.38 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 141.48 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 141.61 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 141.61 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 141.73 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 141.91 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 142.05 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 142.05 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 142.05 m, E = 1.500 GeV, R56 = -63.733 mm
# s = 143.96 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 143.96 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 143.96 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 143.96 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.11 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.25 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.25 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.44 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.63 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.67 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.67 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.71 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.76 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.76 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.83 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 144.83 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 145.16 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 145.25 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 145.30 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 145.30 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 145.34 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 145.52 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 145.52 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 145.64 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 145.89 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 146.03 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 146.03 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 146.03 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 146.03 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 146.03 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 146.03 m, E = 1.500 GeV, R56 = -66.642 mm
# s = 147.94 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 147.94 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 147.94 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 147.94 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 147.94 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.09 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.13 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.17 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.17 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.32 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.32 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.44 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.58 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.58 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.70 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.89 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 148.89 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 149.12 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 149.12 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 149.44 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 149.53 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 149.57 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 149.65 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 149.65 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 149.97 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 149.97 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 150.08 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 150.08 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 150.17 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 150.26 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 150.26 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 151.41 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 151.47 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 151.47 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 151.52 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 151.52 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 151.59 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 153.72 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 153.76 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 153.76 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 154.00 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 154.00 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 154.32 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 154.52 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 154.85 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 155.00 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 155.00 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 155.14 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 155.14 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 155.44 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 155.44 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 155.58 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 155.58 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 155.67 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 155.71 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 155.75 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 156.22 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 156.26 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 156.34 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 156.34 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 156.34 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.05 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.17 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.31 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.43 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.43 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.43 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.68 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.76 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.82 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.82 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.85 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 157.85 m, E = 1.500 GeV, R56 = -23.527 mm
# s = 158.41 m, E = 1.512 GeV, R56 = -23.529 mm
# s = 158.41 m, E = 1.512 GeV, R56 = -23.529 mm
# s = 158.41 m, E = 1.512 GeV, R56 = -23.529 mm
# s = 159.74 m, E = 1.540 GeV, R56 = -23.535 mm
# s = 159.74 m, E = 1.540 GeV, R56 = -23.535 mm
# s = 159.78 m, E = 1.540 GeV, R56 = -23.535 mm
# s = 159.83 m, E = 1.540 GeV, R56 = -23.535 mm
# s = 159.86 m, E = 1.540 GeV, R56 = -23.535 mm
# s = 159.92 m, E = 1.540 GeV, R56 = -23.535 mm
# s = 159.95 m, E = 1.540 GeV, R56 = -23.535 mm
# s = 159.95 m, E = 1.540 GeV, R56 = -23.535 mm
# s = 161.84 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 161.84 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 161.88 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 161.93 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 161.98 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 161.98 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.02 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.08 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.08 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.13 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.13 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.20 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.20 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.24 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.28 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.33 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.37 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.37 m, E = 1.579 GeV, R56 = -23.542 mm
# s = 162.93 m, E = 1.591 GeV, R56 = -23.545 mm
# s = 162.93 m, E = 1.591 GeV, R56 = -23.545 mm
# s = 162.93 m, E = 1.591 GeV, R56 = -23.545 mm
# s = 164.26 m, E = 1.619 GeV, R56 = -23.549 mm
# s = 164.26 m, E = 1.619 GeV, R56 = -23.549 mm
# s = 164.29 m, E = 1.619 GeV, R56 = -23.549 mm
# s = 164.35 m, E = 1.619 GeV, R56 = -23.549 mm
# s = 164.37 m, E = 1.619 GeV, R56 = -23.549 mm
# s = 164.43 m, E = 1.619 GeV, R56 = -23.549 mm
# s = 164.47 m, E = 1.619 GeV, R56 = -23.549 mm
# s = 164.47 m, E = 1.619 GeV, R56 = -23.549 mm
# s = 166.36 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.36 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.39 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.45 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.49 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.49 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.53 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.57 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.57 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.73 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.73 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.73 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.93 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.97 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 166.97 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 167.03 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 167.23 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 167.23 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 167.28 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 167.36 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 167.42 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 167.45 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 167.45 m, E = 1.659 GeV, R56 = -23.556 mm
# s = 168.01 m, E = 1.670 GeV, R56 = -23.558 mm
# s = 168.01 m, E = 1.670 GeV, R56 = -23.558 mm
# s = 168.01 m, E = 1.670 GeV, R56 = -23.558 mm
# s = 169.34 m, E = 1.698 GeV, R56 = -23.563 mm
# s = 169.34 m, E = 1.698 GeV, R56 = -23.563 mm
# s = 169.38 m, E = 1.698 GeV, R56 = -23.563 mm
# s = 169.43 m, E = 1.698 GeV, R56 = -23.563 mm
# s = 169.46 m, E = 1.698 GeV, R56 = -23.563 mm
# s = 169.52 m, E = 1.698 GeV, R56 = -23.563 mm
# s = 169.55 m, E = 1.698 GeV, R56 = -23.563 mm
# s = 169.55 m, E = 1.698 GeV, R56 = -23.563 mm
# s = 171.44 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.44 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.48 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.53 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.59 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.59 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.64 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.64 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.71 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.71 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.75 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.80 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.80 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.84 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.88 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.93 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.97 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 171.97 m, E = 1.738 GeV, R56 = -23.569 mm
# s = 172.53 m, E = 1.750 GeV, R56 = -23.571 mm
# s = 172.53 m, E = 1.750 GeV, R56 = -23.571 mm
# s = 172.53 m, E = 1.750 GeV, R56 = -23.571 mm
# s = 173.86 m, E = 1.778 GeV, R56 = -23.575 mm
# s = 173.86 m, E = 1.778 GeV, R56 = -23.575 mm
# s = 173.89 m, E = 1.778 GeV, R56 = -23.575 mm
# s = 173.95 m, E = 1.778 GeV, R56 = -23.575 mm
# s = 173.97 m, E = 1.778 GeV, R56 = -23.575 mm
# s = 174.03 m, E = 1.778 GeV, R56 = -23.575 mm
# s = 174.07 m, E = 1.778 GeV, R56 = -23.575 mm
# s = 174.07 m, E = 1.778 GeV, R56 = -23.575 mm
# s = 175.96 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 175.96 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 175.99 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.05 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.09 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.09 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.24 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.25 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.25 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.45 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.54 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.74 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.74 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.74 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.88 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 176.96 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 177.02 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 177.05 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 177.05 m, E = 1.817 GeV, R56 = -23.581 mm
# s = 177.61 m, E = 1.829 GeV, R56 = -23.583 mm
# s = 177.61 m, E = 1.829 GeV, R56 = -23.583 mm
# s = 177.61 m, E = 1.829 GeV, R56 = -23.583 mm
# s = 178.94 m, E = 1.857 GeV, R56 = -23.587 mm
# s = 178.94 m, E = 1.857 GeV, R56 = -23.587 mm
# s = 178.98 m, E = 1.857 GeV, R56 = -23.587 mm
# s = 179.03 m, E = 1.857 GeV, R56 = -23.587 mm
# s = 179.06 m, E = 1.857 GeV, R56 = -23.587 mm
# s = 179.12 m, E = 1.857 GeV, R56 = -23.587 mm
# s = 179.15 m, E = 1.857 GeV, R56 = -23.587 mm
# s = 179.15 m, E = 1.857 GeV, R56 = -23.587 mm
# s = 181.04 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.04 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.08 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.13 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.19 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.19 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.24 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.24 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.31 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.31 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.35 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.40 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.40 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.48 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.53 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.57 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 181.57 m, E = 1.897 GeV, R56 = -23.592 mm
# s = 182.13 m, E = 1.909 GeV, R56 = -23.594 mm
# s = 182.13 m, E = 1.909 GeV, R56 = -23.594 mm
# s = 182.13 m, E = 1.909 GeV, R56 = -23.594 mm
# s = 183.46 m, E = 1.936 GeV, R56 = -23.597 mm
# s = 183.46 m, E = 1.936 GeV, R56 = -23.597 mm
# s = 183.49 m, E = 1.936 GeV, R56 = -23.597 mm
# s = 183.55 m, E = 1.936 GeV, R56 = -23.597 mm
# s = 183.57 m, E = 1.936 GeV, R56 = -23.597 mm
# s = 183.63 m, E = 1.936 GeV, R56 = -23.597 mm
# s = 183.67 m, E = 1.936 GeV, R56 = -23.597 mm
# s = 183.67 m, E = 1.936 GeV, R56 = -23.597 mm
# s = 185.56 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 185.56 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 185.59 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 185.65 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 185.69 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 185.69 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 185.84 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 185.85 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 185.85 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 186.05 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 186.14 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 186.34 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 186.34 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 186.34 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 186.34 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 186.48 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 186.56 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 186.62 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 186.65 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 186.65 m, E = 1.976 GeV, R56 = -23.602 mm
# s = 187.21 m, E = 1.988 GeV, R56 = -23.604 mm
# s = 187.21 m, E = 1.988 GeV, R56 = -23.604 mm
# s = 187.21 m, E = 1.988 GeV, R56 = -23.604 mm
# s = 188.54 m, E = 2.016 GeV, R56 = -23.607 mm
# s = 188.54 m, E = 2.016 GeV, R56 = -23.607 mm
# s = 188.58 m, E = 2.016 GeV, R56 = -23.607 mm
# s = 188.63 m, E = 2.016 GeV, R56 = -23.607 mm
# s = 188.66 m, E = 2.016 GeV, R56 = -23.607 mm
# s = 188.72 m, E = 2.016 GeV, R56 = -23.607 mm
# s = 188.75 m, E = 2.016 GeV, R56 = -23.607 mm
# s = 188.75 m, E = 2.016 GeV, R56 = -23.607 mm
# s = 190.64 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 190.64 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 190.68 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 190.73 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 190.79 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 190.79 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 190.84 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 190.84 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 190.91 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 190.91 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 190.95 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 191.08 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 191.13 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 191.17 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 191.17 m, E = 2.055 GeV, R56 = -23.612 mm
# s = 191.73 m, E = 2.067 GeV, R56 = -23.613 mm
# s = 191.73 m, E = 2.067 GeV, R56 = -23.613 mm
# s = 191.73 m, E = 2.067 GeV, R56 = -23.613 mm
# s = 193.06 m, E = 2.095 GeV, R56 = -23.616 mm
# s = 193.06 m, E = 2.095 GeV, R56 = -23.616 mm
# s = 193.09 m, E = 2.095 GeV, R56 = -23.616 mm
# s = 193.15 m, E = 2.095 GeV, R56 = -23.616 mm
# s = 193.17 m, E = 2.095 GeV, R56 = -23.616 mm
# s = 193.23 m, E = 2.095 GeV, R56 = -23.616 mm
# s = 193.27 m, E = 2.095 GeV, R56 = -23.616 mm
# s = 193.27 m, E = 2.095 GeV, R56 = -23.616 mm
# s = 195.16 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.16 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.19 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.25 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.29 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.29 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.44 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.45 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.65 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.74 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.94 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.94 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 195.94 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 196.03 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 196.08 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 196.16 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 196.22 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 196.25 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 196.25 m, E = 2.135 GeV, R56 = -23.621 mm
# s = 196.49 m, E = 2.139 GeV, R56 = -23.621 mm
# s = 196.49 m, E = 2.139 GeV, R56 = -23.621 mm
# s = 196.49 m, E = 2.139 GeV, R56 = -23.621 mm
# s = 198.14 m, E = 2.169 GeV, R56 = -23.624 mm
# s = 198.14 m, E = 2.169 GeV, R56 = -23.624 mm
# s = 198.18 m, E = 2.169 GeV, R56 = -23.624 mm
# s = 198.23 m, E = 2.169 GeV, R56 = -23.624 mm
# s = 198.26 m, E = 2.169 GeV, R56 = -23.624 mm
# s = 198.32 m, E = 2.169 GeV, R56 = -23.624 mm
# s = 198.35 m, E = 2.169 GeV, R56 = -23.624 mm
# s = 198.35 m, E = 2.169 GeV, R56 = -23.624 mm
# s = 200.24 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.24 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.28 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.33 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.39 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.39 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.44 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.44 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.51 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.51 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.55 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.68 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.73 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.77 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 200.77 m, E = 2.203 GeV, R56 = -23.628 mm
# s = 201.33 m, E = 2.213 GeV, R56 = -23.629 mm
# s = 201.33 m, E = 2.213 GeV, R56 = -23.629 mm
# s = 201.33 m, E = 2.213 GeV, R56 = -23.629 mm
# s = 202.66 m, E = 2.237 GeV, R56 = -23.631 mm
# s = 202.66 m, E = 2.237 GeV, R56 = -23.631 mm
# s = 202.69 m, E = 2.237 GeV, R56 = -23.631 mm
# s = 202.75 m, E = 2.237 GeV, R56 = -23.631 mm
# s = 202.77 m, E = 2.237 GeV, R56 = -23.631 mm
# s = 202.83 m, E = 2.237 GeV, R56 = -23.631 mm
# s = 202.87 m, E = 2.237 GeV, R56 = -23.631 mm
# s = 202.87 m, E = 2.237 GeV, R56 = -23.631 mm
# s = 204.76 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 204.76 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 204.79 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 204.85 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 204.87 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 204.91 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 204.91 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.06 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.06 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.27 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.36 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.56 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.56 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.56 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.63 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.70 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.81 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.85 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 205.85 m, E = 2.271 GeV, R56 = -23.635 mm
# s = 206.41 m, E = 2.283 GeV, R56 = -23.636 mm
# s = 206.41 m, E = 2.283 GeV, R56 = -23.636 mm
# s = 206.41 m, E = 2.283 GeV, R56 = -23.636 mm
# s = 207.74 m, E = 2.311 GeV, R56 = -23.638 mm
# s = 207.74 m, E = 2.311 GeV, R56 = -23.638 mm
# s = 207.78 m, E = 2.311 GeV, R56 = -23.638 mm
# s = 207.91 m, E = 2.311 GeV, R56 = -23.638 mm
# s = 207.95 m, E = 2.311 GeV, R56 = -23.638 mm
# s = 207.95 m, E = 2.311 GeV, R56 = -23.638 mm
# s = 209.84 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 209.84 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 209.88 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 209.91 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 209.95 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.01 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.01 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.06 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.06 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.13 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.13 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.18 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.22 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.32 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.36 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.36 m, E = 2.350 GeV, R56 = -23.642 mm
# s = 210.92 m, E = 2.362 GeV, R56 = -23.643 mm
# s = 210.92 m, E = 2.362 GeV, R56 = -23.643 mm
# s = 210.92 m, E = 2.362 GeV, R56 = -23.643 mm
# s = 212.25 m, E = 2.390 GeV, R56 = -23.646 mm
# s = 212.25 m, E = 2.390 GeV, R56 = -23.646 mm
# s = 212.29 m, E = 2.390 GeV, R56 = -23.646 mm
# s = 212.42 m, E = 2.390 GeV, R56 = -23.646 mm
# s = 212.46 m, E = 2.390 GeV, R56 = -23.646 mm
# s = 212.46 m, E = 2.390 GeV, R56 = -23.646 mm
# s = 214.35 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 214.35 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 214.39 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 214.43 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 214.54 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 214.58 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 214.58 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 214.73 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 214.74 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 214.94 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 214.97 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 214.97 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 215.03 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 215.24 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 215.30 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 215.37 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 215.48 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 215.52 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 215.52 m, E = 2.430 GeV, R56 = -23.649 mm
# s = 216.08 m, E = 2.440 GeV, R56 = -23.650 mm
# s = 216.08 m, E = 2.440 GeV, R56 = -23.650 mm
# s = 216.08 m, E = 2.440 GeV, R56 = -23.650 mm
# s = 217.41 m, E = 2.466 GeV, R56 = -23.652 mm
# s = 217.41 m, E = 2.466 GeV, R56 = -23.652 mm
# s = 217.45 m, E = 2.466 GeV, R56 = -23.652 mm
# s = 217.58 m, E = 2.466 GeV, R56 = -23.652 mm
# s = 217.62 m, E = 2.466 GeV, R56 = -23.652 mm
# s = 217.62 m, E = 2.466 GeV, R56 = -23.652 mm
# s = 219.51 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.51 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.55 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.58 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.62 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.68 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.68 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.73 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.73 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.80 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.80 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.85 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.89 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 219.99 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 220.03 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 220.03 m, E = 2.501 GeV, R56 = -23.655 mm
# s = 221.92 m, E = 2.537 GeV, R56 = -23.658 mm
# s = 221.92 m, E = 2.537 GeV, R56 = -23.658 mm
# s = 221.96 m, E = 2.537 GeV, R56 = -23.658 mm
# s = 222.09 m, E = 2.537 GeV, R56 = -23.658 mm
# s = 222.13 m, E = 2.537 GeV, R56 = -23.658 mm
# s = 222.13 m, E = 2.537 GeV, R56 = -23.658 mm
# s = 223.79 m, E = 2.569 GeV, R56 = -23.661 mm
# s = 223.79 m, E = 2.569 GeV, R56 = -23.661 mm
# s = 223.79 m, E = 2.569 GeV, R56 = -23.661 mm
# s = 224.02 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.02 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.06 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.10 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.14 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.18 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.18 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.33 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.34 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.54 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.57 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.57 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.63 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 224.84 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 227.54 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 227.69 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 227.80 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 227.95 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 229.40 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 229.51 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 229.55 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 229.55 m, E = 2.573 GeV, R56 = -23.661 mm
# s = 230.11 m, E = 2.583 GeV, R56 = -23.662 mm
# s = 230.11 m, E = 2.583 GeV, R56 = -23.662 mm
# s = 230.11 m, E = 2.583 GeV, R56 = -23.662 mm
# s = 231.44 m, E = 2.607 GeV, R56 = -23.664 mm
# s = 231.44 m, E = 2.607 GeV, R56 = -23.664 mm
# s = 231.48 m, E = 2.607 GeV, R56 = -23.664 mm
# s = 231.61 m, E = 2.607 GeV, R56 = -23.664 mm
# s = 231.65 m, E = 2.607 GeV, R56 = -23.664 mm
# s = 231.65 m, E = 2.607 GeV, R56 = -23.664 mm
# s = 233.54 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 233.54 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 233.58 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 233.61 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 233.66 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 233.75 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 233.79 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 233.88 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 233.88 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 233.92 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 234.02 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 234.06 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 234.06 m, E = 2.641 GeV, R56 = -23.666 mm
# s = 234.62 m, E = 2.651 GeV, R56 = -23.667 mm
# s = 235.95 m, E = 2.675 GeV, R56 = -23.669 mm
# s = 235.95 m, E = 2.675 GeV, R56 = -23.669 mm
# s = 235.99 m, E = 2.675 GeV, R56 = -23.669 mm
# s = 236.12 m, E = 2.675 GeV, R56 = -23.669 mm
# s = 236.16 m, E = 2.675 GeV, R56 = -23.669 mm
# s = 236.16 m, E = 2.675 GeV, R56 = -23.669 mm
# s = 238.05 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.05 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.09 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.13 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.17 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.21 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.21 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.36 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.36 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.57 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.66 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.86 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.93 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.97 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 238.97 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 239.23 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 239.30 m, E = 2.709 GeV, R56 = -23.671 mm
# s = 239.41 m, E = 2.709 GeV, R56 = -23.671 mm

# %%
# Your element IDs
start_id = "PA1RFGUN"
end_id   = "L491"

# Find their indices in the lattice
start_index = next(i for i, el in enumerate(lattice_list) if el.id == start_id)
end_index   = next(i for i, el in enumerate(lattice_list) if el.id == end_id)

# Create the sub-lattice
partial_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

# Get s-positions of those indices
s_start = sum(el.l for el in lattice_list[:start_index])
s_end   = sum(el.l for el in lattice_list[:end_index + 1])
s_mid   = 0.5 * (s_start + s_end)

# Interpolate energy at midpoint
E_here = get_energy_at_s(s_mid, tws)

# Calculate R56
R = lattice_transfer_map(partial_lat, energy=E_here)
r56 = R[4, 5]

# Print result
print(f"R56 from '{start_id}' to '{end_id}' (s = {s_start:.2f} to {s_end:.2f} m, E ≈ {E_here:.3f} GeV): R56 = {r56*1000:.3f} mm")
# Out:
# R56 from 'PA1RFGUN' to 'L491' (s = 0.00 to 45.01 m, E ≈ 0.175 GeV): R56 = -21.806 mm

# %%
def compute_r56_with_energy_evolution(lat_list, tws, id_start, id_end):
    # Find element indices
    i_start = next(i for i, el in enumerate(lat_list) if el.id == id_start)
    i_end   = next(i for i, el in enumerate(lat_list) if el.id == id_end)

    # Build the sub-lattice
    partial_lat = MagneticLattice(lat_list[i_start:i_end + 1])

    # Use starting energy from Twiss at i_start
    s_start = sum(e.l for e in lat_list[:i_start])
    E_start = get_energy_at_s(s_start, tws)

    # Compute transfer maps at every step (tracks energy changes!)
    Bs, Rs, Ts, Ss = partial_lat.transfer_maps(energy=E_start, output_at_each_step=True)

    # Get the last transfer matrix — full map from PJARCM1 to PSECTC
    R_final = Rs[-1]
    r56 = R_final[4, 5]

    s_end = s_start + sum(e.l for e in lat_list[i_start:i_end + 1])
    print(f"R56 from '{id_start}' to '{id_end}' (s = {s_start:.2f} → {s_end:.2f} m): R56 = {r56*1000:.3f} mm")

# %%
compute_r56_with_energy_evolution(lattice_list, tws, "PA1RFGUN", "L491")
# Out:
# R56 from 'PA1RFGUN' to 'L491' (s = 0.00 → 45.01 m): R56 = -22.795 mm

# %%
final_twiss = tws_track[-1]

print("\n===== Final Beam Parameters =====")
print(f"Position s (m):       {final_twiss.s:.4f}")
print(f"Energy E (GeV):       {final_twiss.E:.6f}")
print(f"Beta X (βx) (m):      {final_twiss.beta_x:.6f}")
print(f"Beta Y (βy) (m):      {final_twiss.beta_y:.6f}")
print(f"Alpha X (αx):         {final_twiss.alpha_x:.6f}")
print(f"Alpha Y (αy):         {final_twiss.alpha_y:.6f}")
print(f"Norm. Emit X (m.rad): {final_twiss.emit_xn:.6e}")
print(f"Norm. Emit Y (m.rad): {final_twiss.emit_yn:.6e}")
print(f"Geom. Emit X (m.rad): {final_twiss.emit_x:.6e}")
print(f"Geom. Emit Y (m.rad): {final_twiss.emit_y:.6e}")
# Out:
# ===== Final Beam Parameters =====
# Position s (m):       239.4101
# Energy E (GeV):       2.709241
# Beta X (βx) (m):      182.784982
# Beta Y (βy) (m):      288.779269
# Alpha X (αx):         9.744906
# Alpha Y (αy):         -0.970697
# Norm. Emit X (m.rad): 1.210266e-06
# Norm. Emit Y (m.rad): 1.205941e-06
# Geom. Emit X (m.rad): 2.282723e-10
# Geom. Emit Y (m.rad): 2.274564e-10

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract position and beta functions
s = np.array([tw.s for tw in tws_track])
beta_x = np.array([tw.beta_x for tw in tws_track])
beta_y = np.array([tw.beta_y for tw in tws_track])

# Use initial geometric emittances
emit_x = tw0.emit_x
emit_y = tw0.emit_y

# Compute beam sizes σx and σy in meters
sigma_x = np.sqrt(beta_x * emit_x)
sigma_y = np.sqrt(beta_y * emit_y)

# Plot beam sizes in millimeters
plt.figure(figsize=(10, 6))
plt.plot(s, sigma_x * 1e3, label=r'$\sigma_x$ [mm]', linewidth=2)
plt.plot(s, sigma_y * 1e3, label=r'$\sigma_y$ [mm]', linewidth=2)

plt.xlabel('s [m]', fontsize=14)
plt.ylabel('Beam Size σ [mm]', fontsize=14)
plt.title('Transverse Beam Sizes Along the Lattice', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()
