# %%
from ocelot import *
from ocelot.cpbd.elements import *
from ocelot.gui.accelerator import *
from ocelot.cpbd.track import track_debug
from utils import trunc_s, show_parameter_evolution
import matplotlib.pyplot as plt


#from rfglinacbte import *
#from Jarc import *
from JarcCSR import *

#lat = MagneticLattice(lattice_list)
lat = MagneticLattice(lattice_list)   



##### PA1RFGUN #####
# AX =-21.12   
# BX =24.36 
# AY =-21.16     
# BY =24.42      
# EMITX =1.2023504614117648e-06
# EMITY =1.2023504614117648e-06 
##### PA1RFGUN #####


##### PSECTB #####
AX =.8330530584703799  
BX =8.804855185360497    
AY =.8104567519439174
BY =8.82335409438248       
EMITX =1.2023504614117648e-06 
EMITY =1.2023504614117648e-06 
##### PSECTB #####

energy = 0.5 # GeV  #why?
tw0 = Twiss()
tw0.alpha_x = AX
tw0.beta_x = BX

tw0.alpha_y = AY
tw0.beta_y = BY
tw0.E = energy
tw0.emit_xn = EMITX 
tw0.emit_yn = EMITY
tw0.emit_x = EMITX   / energy * 0.511e-3
tw0.emit_y = EMITY / energy * 0.511e-3

tws = twiss(lat,tw0)

plot_opt_func(lat, tws,legend=False, grid=False, top_plot=['Dx','Dy'])
# Out:
# initializing ocelot...

# %%
def gauss_from_twiss_vec(emit, beta, alpha, size=1):
    phi = 2 * np.pi * np.random.rand(size)
    u = np.random.rand(size)
    a = np.sqrt(-2 * np.log(1 - u) * emit)
    x = a * np.sqrt(beta) * np.cos(phi)
    xp = -a / np.sqrt(beta) * (np.sin(phi) + alpha * np.cos(phi))
    return x, xp

# %%
start_index = next(i for i, el in enumerate(lattice_list) if el.id == "PJARCM1")
end_index = next(i for i, el in enumerate(lattice_list) if el.id == "PSECTC")

sub_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

R = lattice_transfer_map(sub_lat, energy=1.5)
print("R56 = ", R[4,5]*1000, "mm")
# Out:
# R56 =  -0.27711775672648775 mm

# %%
nparticles = 1000000
p_array = ParticleArray(n=nparticles)

sigma_tau = 4.5e-3  # seconds
sigma_p = 5.e-4     # relative momentum spread (Δp/p)

p_array.E = energy  # GeV

# Longitudinal
p_array.rparticles[4] = np.random.randn(nparticles) * sigma_tau
p_array.rparticles[5] = np.random.randn(nparticles) * sigma_p

# Transverse: vectorized sampling from Twiss parameters
x, xp = gauss_from_twiss_vec(tw0.emit_x, tw0.beta_x, tw0.alpha_x, size=nparticles)
y, yp = gauss_from_twiss_vec(tw0.emit_y, tw0.beta_y, tw0.alpha_y, size=nparticles)

p_array.rparticles[0] = x
p_array.rparticles[1] = xp
p_array.rparticles[2] = y
p_array.rparticles[3] = yp

# Charge distribution
charge = 4.0e-9  # nC
p_array.q_array = np.ones(nparticles) * (charge / nparticles)

# %%
plt.hist(p_array.rparticles[0], bins=100, alpha=0.7, label='x')
plt.hist(p_array.rparticles[1], bins=100, alpha=0.7, label="x'")
plt.legend()
plt.show()

plt.hist(p_array.rparticles[2], bins=100, alpha=0.7, label='y')
plt.hist(p_array.rparticles[3], bins=100, alpha=0.7, label="y'")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
x = p_array.rparticles[0]
xp = p_array.rparticles[1]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_x, sigma_xp = twiss_sigmas(tw0.emit_x, tw0.beta_x, tw0.alpha_x)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='x (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='x (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="x′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_xp), 'r--', label="x′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of x and x′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
y = p_array.rparticles[2]
yp = p_array.rparticles[3]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_y, sigma_yp = twiss_sigmas(tw0.emit_y, tw0.beta_y, tw0.alpha_y)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='y (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='y (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="y′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_yp), 'r--', label="y′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of y and y′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def check_beam_stats(p_array, twiss, axis_label="x"):
    idx = 0 if axis_label == "x" else 2
    idxp = 1 if axis_label == "x" else 3

    sigma = np.std(p_array.rparticles[idx])
    sigmap = np.std(p_array.rparticles[idxp])

    beta = getattr(twiss, f"beta_{axis_label}")
    alpha = getattr(twiss, f"alpha_{axis_label}")
    emit = getattr(twiss, f"emit_{axis_label}")

    sigma_theo = np.sqrt(beta * emit)
    gamma = (1 + alpha**2) / beta
    sigmap_theo = np.sqrt(gamma * emit)

    print(f"σ_{axis_label} (simulated):     {sigma}")
    print(f"σ_{axis_label} (theoretical):   {sigma_theo}")
    print(f"σ_{axis_label}' (simulated):    {sigmap}")
    print(f"σ_{axis_label}' (theoretical):  {sigmap_theo}")

# %%
check_beam_stats(p_array, tw0, axis_label="x")
# Out:
# σ_x (simulated):     0.0001040222314942401
# σ_x (theoretical):   0.00010401646586991489
# σ_x' (simulated):    1.5383669012783392e-05
# σ_x' (theoretical):  1.5375656996782916e-05

# %%
check_beam_stats(p_array, tw0, axis_label="y")
# Out:
# σ_y (simulated):     0.0001041596717810972
# σ_y (theoretical):   0.00010412567729261079
# σ_y' (simulated):    1.51928601176261e-05
# σ_y' (theoretical):  1.5190233002553629e-05

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- X plane ---
x = p_array.rparticles[0]
xp = p_array.rparticles[1]
emit_x = tw0.emit_x
beta_x = tw0.beta_x
alpha_x = tw0.alpha_x

theta = np.linspace(0, 2*np.pi, 400)
x_ellipse = np.sqrt(emit_x * beta_x) * np.cos(theta)
xp_ellipse = (-alpha_x * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_x / beta_x)

# --- Y plane ---
y = p_array.rparticles[2]
yp = p_array.rparticles[3]
emit_y = tw0.emit_y
beta_y = tw0.beta_y
alpha_y = tw0.alpha_y

y_ellipse = np.sqrt(emit_y * beta_y) * np.cos(theta)
yp_ellipse = (-alpha_y * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_y / beta_y)

# --- Plot ---
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# x-x'
axes[0].scatter(x, xp, s=1, alpha=0.3, label='Particles')
axes[0].plot(x_ellipse, xp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[0].set_xlabel('x [m]')
axes[0].set_ylabel("x′ [rad]")
axes[0].set_title('Phase space: x vs x′')
axes[0].grid(True)
axes[0].axis('equal')
axes[0].legend()

# y-y'
axes[1].scatter(y, yp, s=1, alpha=0.3, color='orange', label='Particles')
axes[1].plot(y_ellipse, yp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[1].set_xlabel('y [m]')
axes[1].set_ylabel("y′ [rad]")
axes[1].set_title('Phase space: y vs y′')
axes[1].grid(True)
axes[1].axis('equal')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy

def plot_emittances_vs_s(p_array, nparts_in_slice=5000, smooth_param=0.05,
                         tau_units="m", inverse_tau=False, grid=True,
                         title="Normalized Emittances vs s", figsize=(8, 4),
                         filename=None):
    """
    Plot normalized emittances vs longitudinal position s (head-tail slicing).

    :param p_array: ParticleArray object
    :param nparts_in_slice: number of particles per slice
    :param smooth_param: smoothing parameter used in slice analysis
    :param tau_units: 'm', 'mm', or 'um'
    :param inverse_tau: flip the tau axis
    :param grid: show grid
    :param title: plot title
    :param figsize: matplotlib figsize
    :param filename: optional path to save the plot
    """
    # Set scale for s-axis
    tau_factors = {"m": 1, "mm": 1e3, "um": 1e6}
    tau_factor = tau_factors.get(tau_units, 1e3)
    tau_label = f"$s\,[\\mathrm{{{tau_units}}}]$"

    # Deepcopy to preserve original
    p_array_copy = deepcopy(p_array)
    if inverse_tau:
        p_array_copy.tau()[:] *= -1

    # Perform slice analysis (assumes this function exists in your codebase)
    slice_params = global_slice_analysis(p_array_copy, nparts_in_slice, smooth_param)

    # Extract and convert to proper units
    s = slice_params.s * tau_factor
    emit_x = slice_params.exn * 1e6  # [mm·mrad]
    emit_y = slice_params.eyn * 1e6

    # Plot
    plt.figure(figsize=figsize)
    plt.plot(s, emit_x, label=r"$\varepsilon_x$", color='red')
    plt.plot(s, emit_y, label=r"$\varepsilon_y$", color='blue')
    plt.xlabel(tau_label)
    plt.ylabel(r"Normalized Emittance [$\mathrm{mm\cdot{}mrad}$]")
    plt.title(title)
    plt.legend()
    if grid:
        plt.grid(True)
    if filename:
        plt.savefig(filename)
    plt.tight_layout()
    plt.show()

# %%
plot_emittances_vs_s(p_array)

# %%
import time
navi = Navigator(lat)
navi.unit_step = 0.1 # m, only with CSR

csr = CSR(n_bin=500, m_bin=5, sigma_min=.2e-6)

#navi.add_physics_proc(csr, csrm1_start, csrm1_end)

p_array_t = deepcopy(p_array)

start = time.time()
tws_track, p_array_t = track(lat, p_array_t, navi)
print("\n time exec:", time.time() - start, "sec")
# Out:
# z = 194.39617779999986 / 194.39617779999992. Applied:
#  time exec: 129.51211714744568 sec

# %%
plot_emittances_vs_s(p_array_t)

# %%
show_e_beam(p_array)

# %%
show_e_beam(p_array_t)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_energy_vs_position(tws_track):
    """
    Plot energy E as a function of position s from a list of Twiss-like objects.

    Parameters:
    tws_track (list): List of objects with attributes 's' (position) and 'E' (energy).
    """
    s = np.array([tw.s for tw in tws_track])
    E = np.array([tw.E for tw in tws_track])

    plt.figure(figsize=(10, 6))
    plt.plot(s, E, linewidth=2, marker='o', markersize=4)

    plt.title("Energy vs Position", fontsize=16)
    plt.xlabel("s (m)", fontsize=14)
    plt.ylabel("E (GeV)", fontsize=14)
    plt.grid(True, which='both', linestyle='--', alpha=0.5)
    plt.tick_params(axis='both', labelsize=12)
    plt.tight_layout()
    plt.show()

# %%
plot_energy_vs_position(tws_track)

# %%
# --- After tracking: get final x, x', y, y' ---
x_t = p_array_t.rparticles[0]
xp_t = p_array_t.rparticles[1]
y_t = p_array_t.rparticles[2]
yp_t = p_array_t.rparticles[3]

# --- Plot initial vs final side-by-side ---
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# x-x′ before
axes[0][0].scatter(p_array.rparticles[0], p_array.rparticles[1], s=1, alpha=0.3)
axes[0][0].set_title("x vs x′ (before)")
axes[0][0].set_xlabel("x [m]")
axes[0][0].set_ylabel("x′ [rad]")
axes[0][0].grid(True)
axes[0][0].axis('equal')

# x-x′ after
axes[0][1].scatter(x_t, xp_t, s=1, alpha=0.3)
axes[0][1].set_title("x vs x′ (after)")
axes[0][1].set_xlabel("x [m]")
axes[0][1].set_ylabel("x′ [rad]")
axes[0][1].grid(True)
axes[0][1].axis('equal')

# y-y′ before
axes[1][0].scatter(p_array.rparticles[2], p_array.rparticles[3], s=1, alpha=0.3, color='orange')
axes[1][0].set_title("y vs y′ (before)")
axes[1][0].set_xlabel("y [m]")
axes[1][0].set_ylabel("y′ [rad]")
axes[1][0].grid(True)
axes[1][0].axis('equal')

# y-y′ after
axes[1][1].scatter(y_t, yp_t, s=1, alpha=0.3, color='orange')
axes[1][1].set_title("y vs y′ (after)")
axes[1][1].set_xlabel("y [m]")
axes[1][1].set_ylabel("y′ [rad]")
axes[1][1].grid(True)
axes[1][1].axis('equal')

plt.tight_layout()
plt.show()

# %%
import numpy as np

def compute_emittance(x, xp):
    x_mean = np.mean(x)
    xp_mean = np.mean(xp)

    x_cent = x - x_mean
    xp_cent = xp - xp_mean

    xx = np.mean(x_cent ** 2)
    xpxp = np.mean(xp_cent ** 2)
    xxp = np.mean(x_cent * xp_cent)

    emit = np.sqrt(xx * xpxp - xxp**2)
    return emit

# Final tracked coordinates
x, xp = p_array_t.rparticles[0], p_array_t.rparticles[1]
y, yp = p_array_t.rparticles[2], p_array_t.rparticles[3]

emit_x = compute_emittance(x, xp)
emit_y = compute_emittance(y, yp)

print(f"εₓ (RMS, final) = {emit_x:.5e} m·rad")
print(f"εᵧ (RMS, final) = {emit_y:.5e} m·rad")

emit_x0 = compute_emittance(p_array.rparticles[0], p_array.rparticles[1])
emit_y0 = compute_emittance(p_array.rparticles[2], p_array.rparticles[3])
print("Initial εₓ:", emit_x0)
print("Initial εᵧ:", emit_y0)
# Out:
# εₓ (RMS, final) = 2.24453e-10 m·rad
# εᵧ (RMS, final) = 2.24868e-10 m·rad
# Initial εₓ: 1.2286961569742876e-09
# Initial εᵧ: 1.2310499461011824e-09

# %%
for tw in tws_track:
    print(f"s = {tw.s:.3f} m  |  beta_x = {tw.beta_x:.3f}  |  alpha_x = {tw.alpha_x:.3f}" )
# Out:
# s = 0.000 m  |  beta_x = 8.807  |  alpha_x = 0.834
# s = 0.000 m  |  beta_x = 8.807  |  alpha_x = 0.834
# s = 0.085 m  |  beta_x = 8.666  |  alpha_x = 0.818
# s = 0.142 m  |  beta_x = 8.574  |  alpha_x = 0.807
# s = 0.176 m  |  beta_x = 8.518  |  alpha_x = 0.800
# s = 0.736 m  |  beta_x = 7.681  |  alpha_x = 0.695
# s = 2.066 m  |  beta_x = 6.166  |  alpha_x = 0.443
# s = 2.101 m  |  beta_x = 6.135  |  alpha_x = 0.437
# s = 2.157 m  |  beta_x = 6.086  |  alpha_x = 0.426
# s = 2.158 m  |  beta_x = 6.086  |  alpha_x = 0.425
# s = 2.215 m  |  beta_x = 6.038  |  alpha_x = 0.414
# s = 2.250 m  |  beta_x = 6.010  |  alpha_x = 0.408
# s = 4.139 m  |  beta_x = 5.152  |  alpha_x = 0.046
# s = 4.174 m  |  beta_x = 5.149  |  alpha_x = 0.039
# s = 4.231 m  |  beta_x = 5.145  |  alpha_x = 0.028
# s = 4.302 m  |  beta_x = 5.142  |  alpha_x = 0.014
# s = 4.372 m  |  beta_x = 5.141  |  alpha_x = 0.001
# s = 4.415 m  |  beta_x = 5.141  |  alpha_x = -0.008
# s = 4.471 m  |  beta_x = 5.143  |  alpha_x = -0.019
# s = 4.506 m  |  beta_x = 5.144  |  alpha_x = -0.026
# s = 5.066 m  |  beta_x = 5.233  |  alpha_x = -0.133
# s = 6.396 m  |  beta_x = 5.926  |  alpha_x = -0.388
# s = 6.431 m  |  beta_x = 5.953  |  alpha_x = -0.395
# s = 6.487 m  |  beta_x = 5.999  |  alpha_x = -0.406
# s = 6.488 m  |  beta_x = 5.999  |  alpha_x = -0.406
# s = 6.545 m  |  beta_x = 6.046  |  alpha_x = -0.417
# s = 6.580 m  |  beta_x = 6.075  |  alpha_x = -0.424
# s = 8.469 m  |  beta_x = 8.359  |  alpha_x = -0.784
# s = 8.504 m  |  beta_x = 8.414  |  alpha_x = -0.791
# s = 8.561 m  |  beta_x = 8.504  |  alpha_x = -0.802
# s = 8.603 m  |  beta_x = 8.572  |  alpha_x = -0.810
# s = 8.756 m  |  beta_x = 8.824  |  alpha_x = -0.840
# s = 8.759 m  |  beta_x = 8.830  |  alpha_x = -0.840
# s = 8.892 m  |  beta_x = 9.997  |  alpha_x = -8.210
# s = 8.979 m  |  beta_x = 11.482  |  alpha_x = -8.807
# s = 9.232 m  |  beta_x = 11.480  |  alpha_x = 8.813
# s = 9.298 m  |  beta_x = 10.333  |  alpha_x = 8.355
# s = 9.319 m  |  beta_x = 9.994  |  alpha_x = 8.215
# s = 9.452 m  |  beta_x = 8.826  |  alpha_x = 0.847
# s = 9.510 m  |  beta_x = 8.728  |  alpha_x = 0.836
# s = 9.595 m  |  beta_x = 8.588  |  alpha_x = 0.819
# s = 9.652 m  |  beta_x = 8.496  |  alpha_x = 0.808
# s = 9.687 m  |  beta_x = 8.439  |  alpha_x = 0.802
# s = 10.246 m  |  beta_x = 7.602  |  alpha_x = 0.694
# s = 11.576 m  |  beta_x = 6.096  |  alpha_x = 0.438
# s = 11.611 m  |  beta_x = 6.066  |  alpha_x = 0.431
# s = 11.667 m  |  beta_x = 6.018  |  alpha_x = 0.420
# s = 11.668 m  |  beta_x = 6.017  |  alpha_x = 0.420
# s = 11.725 m  |  beta_x = 5.971  |  alpha_x = 0.409
# s = 11.760 m  |  beta_x = 5.942  |  alpha_x = 0.402
# s = 13.649 m  |  beta_x = 5.115  |  alpha_x = 0.036
# s = 13.684 m  |  beta_x = 5.113  |  alpha_x = 0.029
# s = 13.741 m  |  beta_x = 5.110  |  alpha_x = 0.018
# s = 13.812 m  |  beta_x = 5.109  |  alpha_x = 0.004
# s = 13.882 m  |  beta_x = 5.109  |  alpha_x = -0.010
# s = 13.925 m  |  beta_x = 5.111  |  alpha_x = -0.018
# s = 13.981 m  |  beta_x = 5.113  |  alpha_x = -0.030
# s = 14.016 m  |  beta_x = 5.116  |  alpha_x = -0.036
# s = 14.576 m  |  beta_x = 5.217  |  alpha_x = -0.145
# s = 15.906 m  |  beta_x = 5.946  |  alpha_x = -0.403
# s = 15.941 m  |  beta_x = 5.975  |  alpha_x = -0.410
# s = 15.997 m  |  beta_x = 6.022  |  alpha_x = -0.421
# s = 15.998 m  |  beta_x = 6.022  |  alpha_x = -0.421
# s = 16.055 m  |  beta_x = 6.070  |  alpha_x = -0.432
# s = 16.090 m  |  beta_x = 6.101  |  alpha_x = -0.439
# s = 17.979 m  |  beta_x = 8.451  |  alpha_x = -0.804
# s = 18.014 m  |  beta_x = 8.507  |  alpha_x = -0.811
# s = 18.071 m  |  beta_x = 8.600  |  alpha_x = -0.822
# s = 18.113 m  |  beta_x = 8.670  |  alpha_x = -0.831
# s = 18.266 m  |  beta_x = 8.928  |  alpha_x = -0.860
# s = 18.269 m  |  beta_x = 8.934  |  alpha_x = -0.861
# s = 18.402 m  |  beta_x = 10.118  |  alpha_x = -8.319
# s = 18.489 m  |  beta_x = 11.622  |  alpha_x = -8.925
# s = 18.742 m  |  beta_x = 11.625  |  alpha_x = 8.915
# s = 18.829 m  |  beta_x = 10.122  |  alpha_x = 8.311
# s = 18.962 m  |  beta_x = 8.941  |  alpha_x = 0.849
# s = 19.200 m  |  beta_x = 8.548  |  alpha_x = 0.803
# s = 19.285 m  |  beta_x = 8.413  |  alpha_x = 0.787
# s = 19.342 m  |  beta_x = 8.324  |  alpha_x = 0.776
# s = 19.377 m  |  beta_x = 8.270  |  alpha_x = 0.770
# s = 19.936 m  |  beta_x = 7.468  |  alpha_x = 0.663
# s = 21.266 m  |  beta_x = 6.044  |  alpha_x = 0.408
# s = 21.301 m  |  beta_x = 6.016  |  alpha_x = 0.402
# s = 21.357 m  |  beta_x = 5.971  |  alpha_x = 0.391
# s = 21.358 m  |  beta_x = 5.970  |  alpha_x = 0.391
# s = 21.415 m  |  beta_x = 5.927  |  alpha_x = 0.380
# s = 21.450 m  |  beta_x = 5.900  |  alpha_x = 0.373
# s = 23.339 m  |  beta_x = 5.176  |  alpha_x = 0.010
# s = 23.374 m  |  beta_x = 5.176  |  alpha_x = 0.003
# s = 23.431 m  |  beta_x = 5.176  |  alpha_x = -0.008
# s = 23.502 m  |  beta_x = 5.178  |  alpha_x = -0.021
# s = 23.572 m  |  beta_x = 5.182  |  alpha_x = -0.035
# s = 23.615 m  |  beta_x = 5.186  |  alpha_x = -0.043
# s = 23.671 m  |  beta_x = 5.191  |  alpha_x = -0.054
# s = 23.706 m  |  beta_x = 5.195  |  alpha_x = -0.061
# s = 24.266 m  |  beta_x = 5.323  |  alpha_x = -0.168
# s = 25.596 m  |  beta_x = 6.111  |  alpha_x = -0.424
# s = 25.631 m  |  beta_x = 6.141  |  alpha_x = -0.430
# s = 25.687 m  |  beta_x = 6.190  |  alpha_x = -0.441
# s = 25.688 m  |  beta_x = 6.190  |  alpha_x = -0.441
# s = 25.745 m  |  beta_x = 6.241  |  alpha_x = -0.452
# s = 25.780 m  |  beta_x = 6.273  |  alpha_x = -0.459
# s = 27.669 m  |  beta_x = 8.692  |  alpha_x = -0.821
# s = 27.704 m  |  beta_x = 8.750  |  alpha_x = -0.828
# s = 27.761 m  |  beta_x = 8.844  |  alpha_x = -0.839
# s = 27.803 m  |  beta_x = 8.915  |  alpha_x = -0.847
# s = 27.956 m  |  beta_x = 9.178  |  alpha_x = -0.876
# s = 27.959 m  |  beta_x = 9.184  |  alpha_x = -0.877
# s = 28.092 m  |  beta_x = 10.399  |  alpha_x = -8.541
# s = 28.179 m  |  beta_x = 11.943  |  alpha_x = -9.162
# s = 28.432 m  |  beta_x = 11.942  |  alpha_x = 9.168
# s = 28.499 m  |  beta_x = 10.748  |  alpha_x = 8.692
# s = 28.519 m  |  beta_x = 10.396  |  alpha_x = 8.547
# s = 28.652 m  |  beta_x = 9.180  |  alpha_x = 0.884
# s = 28.800 m  |  beta_x = 8.923  |  alpha_x = 0.855
# s = 28.885 m  |  beta_x = 8.779  |  alpha_x = 0.839
# s = 28.942 m  |  beta_x = 8.685  |  alpha_x = 0.828
# s = 28.977 m  |  beta_x = 8.627  |  alpha_x = 0.821
# s = 29.536 m  |  beta_x = 7.768  |  alpha_x = 0.713
# s = 30.866 m  |  beta_x = 6.214  |  alpha_x = 0.456
# s = 30.901 m  |  beta_x = 6.182  |  alpha_x = 0.449
# s = 30.957 m  |  beta_x = 6.132  |  alpha_x = 0.438
# s = 30.958 m  |  beta_x = 6.131  |  alpha_x = 0.438
# s = 31.015 m  |  beta_x = 6.083  |  alpha_x = 0.427
# s = 31.050 m  |  beta_x = 6.053  |  alpha_x = 0.420
# s = 32.939 m  |  beta_x = 5.155  |  alpha_x = 0.055
# s = 32.974 m  |  beta_x = 5.152  |  alpha_x = 0.048
# s = 33.031 m  |  beta_x = 5.147  |  alpha_x = 0.037
# s = 33.102 m  |  beta_x = 5.143  |  alpha_x = 0.023
# s = 33.172 m  |  beta_x = 5.140  |  alpha_x = 0.009
# s = 33.215 m  |  beta_x = 5.140  |  alpha_x = 0.001
# s = 33.271 m  |  beta_x = 5.141  |  alpha_x = -0.010
# s = 33.306 m  |  beta_x = 5.142  |  alpha_x = -0.017
# s = 33.866 m  |  beta_x = 5.221  |  alpha_x = -0.125
# s = 35.196 m  |  beta_x = 5.897  |  alpha_x = -0.383
# s = 35.231 m  |  beta_x = 5.924  |  alpha_x = -0.390
# s = 35.287 m  |  beta_x = 5.969  |  alpha_x = -0.401
# s = 35.288 m  |  beta_x = 5.970  |  alpha_x = -0.401
# s = 35.345 m  |  beta_x = 6.016  |  alpha_x = -0.412
# s = 35.380 m  |  beta_x = 6.045  |  alpha_x = -0.419
# s = 37.269 m  |  beta_x = 8.318  |  alpha_x = -0.784
# s = 37.304 m  |  beta_x = 8.373  |  alpha_x = -0.791
# s = 37.361 m  |  beta_x = 8.463  |  alpha_x = -0.802
# s = 37.403 m  |  beta_x = 8.531  |  alpha_x = -0.810
# s = 37.556 m  |  beta_x = 8.783  |  alpha_x = -0.840
# s = 37.559 m  |  beta_x = 8.789  |  alpha_x = -0.840
# s = 37.692 m  |  beta_x = 9.952  |  alpha_x = -8.177
# s = 37.779 m  |  beta_x = 11.430  |  alpha_x = -8.772
# s = 38.032 m  |  beta_x = 11.431  |  alpha_x = 8.771
# s = 38.099 m  |  beta_x = 10.289  |  alpha_x = 8.315
# s = 38.119 m  |  beta_x = 9.952  |  alpha_x = 8.176
# s = 38.252 m  |  beta_x = 8.789  |  alpha_x = 0.839
# s = 38.400 m  |  beta_x = 8.545  |  alpha_x = 0.811
# s = 38.485 m  |  beta_x = 8.409  |  alpha_x = 0.794
# s = 38.542 m  |  beta_x = 8.320  |  alpha_x = 0.783
# s = 38.577 m  |  beta_x = 8.265  |  alpha_x = 0.776
# s = 39.136 m  |  beta_x = 7.457  |  alpha_x = 0.668
# s = 40.466 m  |  beta_x = 6.022  |  alpha_x = 0.411
# s = 40.501 m  |  beta_x = 5.994  |  alpha_x = 0.404
# s = 40.557 m  |  beta_x = 5.949  |  alpha_x = 0.393
# s = 40.558 m  |  beta_x = 5.948  |  alpha_x = 0.393
# s = 40.615 m  |  beta_x = 5.905  |  alpha_x = 0.382
# s = 40.650 m  |  beta_x = 5.878  |  alpha_x = 0.375
# s = 42.539 m  |  beta_x = 5.152  |  alpha_x = 0.009
# s = 42.574 m  |  beta_x = 5.152  |  alpha_x = 0.002
# s = 42.631 m  |  beta_x = 5.152  |  alpha_x = -0.009
# s = 42.702 m  |  beta_x = 5.155  |  alpha_x = -0.023
# s = 42.772 m  |  beta_x = 5.159  |  alpha_x = -0.036
# s = 42.815 m  |  beta_x = 5.162  |  alpha_x = -0.045
# s = 42.871 m  |  beta_x = 5.168  |  alpha_x = -0.055
# s = 42.906 m  |  beta_x = 5.172  |  alpha_x = -0.062
# s = 43.466 m  |  beta_x = 5.302  |  alpha_x = -0.171
# s = 44.796 m  |  beta_x = 6.099  |  alpha_x = -0.428
# s = 44.831 m  |  beta_x = 6.129  |  alpha_x = -0.435
# s = 44.887 m  |  beta_x = 6.179  |  alpha_x = -0.446
# s = 44.888 m  |  beta_x = 6.180  |  alpha_x = -0.446
# s = 44.945 m  |  beta_x = 6.231  |  alpha_x = -0.457
# s = 44.980 m  |  beta_x = 6.263  |  alpha_x = -0.464
# s = 46.869 m  |  beta_x = 8.708  |  alpha_x = -0.830
# s = 46.904 m  |  beta_x = 8.766  |  alpha_x = -0.836
# s = 46.961 m  |  beta_x = 8.861  |  alpha_x = -0.847
# s = 47.003 m  |  beta_x = 8.933  |  alpha_x = -0.856
# s = 47.156 m  |  beta_x = 9.199  |  alpha_x = -0.885
# s = 47.159 m  |  beta_x = 9.205  |  alpha_x = -0.886
# s = 47.292 m  |  beta_x = 10.470  |  alpha_x = -8.938
# s = 47.379 m  |  beta_x = 12.089  |  alpha_x = -9.612
# s = 47.632 m  |  beta_x = 12.046  |  alpha_x = 9.757
# s = 47.699 m  |  beta_x = 10.778  |  alpha_x = 9.224
# s = 47.719 m  |  beta_x = 10.405  |  alpha_x = 9.060
# s = 47.852 m  |  beta_x = 9.102  |  alpha_x = 1.053
# s = 48.000 m  |  beta_x = 8.796  |  alpha_x = 1.019
# s = 48.085 m  |  beta_x = 8.624  |  alpha_x = 0.999
# s = 48.142 m  |  beta_x = 8.512  |  alpha_x = 0.986
# s = 48.177 m  |  beta_x = 8.443  |  alpha_x = 0.978
# s = 48.736 m  |  beta_x = 7.421  |  alpha_x = 0.849
# s = 50.066 m  |  beta_x = 5.573  |  alpha_x = 0.541
# s = 50.101 m  |  beta_x = 5.535  |  alpha_x = 0.533
# s = 50.157 m  |  beta_x = 5.476  |  alpha_x = 0.520
# s = 50.158 m  |  beta_x = 5.475  |  alpha_x = 0.519
# s = 50.215 m  |  beta_x = 5.417  |  alpha_x = 0.506
# s = 50.250 m  |  beta_x = 5.382  |  alpha_x = 0.498
# s = 52.139 m  |  beta_x = 4.326  |  alpha_x = 0.060
# s = 52.174 m  |  beta_x = 4.322  |  alpha_x = 0.052
# s = 52.231 m  |  beta_x = 4.317  |  alpha_x = 0.039
# s = 52.302 m  |  beta_x = 4.313  |  alpha_x = 0.023
# s = 52.372 m  |  beta_x = 4.311  |  alpha_x = 0.006
# s = 52.415 m  |  beta_x = 4.311  |  alpha_x = -0.004
# s = 52.471 m  |  beta_x = 4.312  |  alpha_x = -0.017
# s = 52.506 m  |  beta_x = 4.313  |  alpha_x = -0.025
# s = 53.066 m  |  beta_x = 4.414  |  alpha_x = -0.155
# s = 54.396 m  |  beta_x = 5.234  |  alpha_x = -0.463
# s = 54.431 m  |  beta_x = 5.267  |  alpha_x = -0.471
# s = 54.487 m  |  beta_x = 5.321  |  alpha_x = -0.484
# s = 54.488 m  |  beta_x = 5.322  |  alpha_x = -0.484
# s = 54.545 m  |  beta_x = 5.377  |  alpha_x = -0.497
# s = 54.580 m  |  beta_x = 5.412  |  alpha_x = -0.505
# s = 56.469 m  |  beta_x = 8.148  |  alpha_x = -0.943
# s = 56.504 m  |  beta_x = 8.214  |  alpha_x = -0.951
# s = 56.561 m  |  beta_x = 8.323  |  alpha_x = -0.964
# s = 56.603 m  |  beta_x = 8.405  |  alpha_x = -0.974
# s = 56.756 m  |  beta_x = 8.707  |  alpha_x = -1.009
# s = 56.759 m  |  beta_x = 8.714  |  alpha_x = -1.010
# s = 56.892 m  |  beta_x = 9.977  |  alpha_x = -8.803
# s = 56.979 m  |  beta_x = 11.573  |  alpha_x = -9.489
# s = 57.232 m  |  beta_x = 11.582  |  alpha_x = 9.460
# s = 57.299 m  |  beta_x = 10.352  |  alpha_x = 8.938
# s = 57.319 m  |  beta_x = 9.990  |  alpha_x = 8.779
# s = 57.452 m  |  beta_x = 8.734  |  alpha_x = 0.977
# s = 57.600 m  |  beta_x = 8.451  |  alpha_x = 0.944
# s = 57.685 m  |  beta_x = 8.292  |  alpha_x = 0.925
# s = 57.742 m  |  beta_x = 8.188  |  alpha_x = 0.912
# s = 57.777 m  |  beta_x = 8.125  |  alpha_x = 0.904
# s = 58.336 m  |  beta_x = 7.182  |  alpha_x = 0.779
# s = 59.666 m  |  beta_x = 5.507  |  alpha_x = 0.481
# s = 59.701 m  |  beta_x = 5.473  |  alpha_x = 0.474
# s = 59.757 m  |  beta_x = 5.421  |  alpha_x = 0.461
# s = 59.758 m  |  beta_x = 5.420  |  alpha_x = 0.461
# s = 59.815 m  |  beta_x = 5.369  |  alpha_x = 0.448
# s = 59.850 m  |  beta_x = 5.337  |  alpha_x = 0.440
# s = 61.739 m  |  beta_x = 4.472  |  alpha_x = 0.018
# s = 61.774 m  |  beta_x = 4.471  |  alpha_x = 0.010
# s = 61.831 m  |  beta_x = 4.471  |  alpha_x = -0.003
# s = 61.873 m  |  beta_x = 4.471  |  alpha_x = -0.012
# s = 61.916 m  |  beta_x = 4.473  |  alpha_x = -0.022
# s = 61.958 m  |  beta_x = 4.475  |  alpha_x = -0.031
# s = 62.015 m  |  beta_x = 4.479  |  alpha_x = -0.044
# s = 62.071 m  |  beta_x = 4.485  |  alpha_x = -0.057
# s = 62.106 m  |  beta_x = 4.489  |  alpha_x = -0.064
# s = 62.666 m  |  beta_x = 4.632  |  alpha_x = -0.190
# s = 63.996 m  |  beta_x = 5.531  |  alpha_x = -0.487
# s = 64.031 m  |  beta_x = 5.566  |  alpha_x = -0.495
# s = 64.087 m  |  beta_x = 5.622  |  alpha_x = -0.508
# s = 64.088 m  |  beta_x = 5.623  |  alpha_x = -0.508
# s = 64.145 m  |  beta_x = 5.681  |  alpha_x = -0.520
# s = 64.180 m  |  beta_x = 5.718  |  alpha_x = -0.528
# s = 66.069 m  |  beta_x = 8.512  |  alpha_x = -0.951
# s = 66.104 m  |  beta_x = 8.579  |  alpha_x = -0.959
# s = 66.161 m  |  beta_x = 8.688  |  alpha_x = -0.971
# s = 66.203 m  |  beta_x = 8.771  |  alpha_x = -0.981
# s = 66.356 m  |  beta_x = 9.076  |  alpha_x = -1.015
# s = 66.359 m  |  beta_x = 9.082  |  alpha_x = -1.016
# s = 66.492 m  |  beta_x = 10.369  |  alpha_x = -8.974
# s = 66.579 m  |  beta_x = 11.995  |  alpha_x = -9.660
# s = 66.832 m  |  beta_x = 11.891  |  alpha_x = 10.015
# s = 66.899 m  |  beta_x = 10.591  |  alpha_x = 9.446
# s = 66.919 m  |  beta_x = 10.208  |  alpha_x = 9.272
# s = 67.052 m  |  beta_x = 8.831  |  alpha_x = 1.421
# s = 67.115 m  |  beta_x = 8.654  |  alpha_x = 1.400
# s = 67.158 m  |  beta_x = 8.536  |  alpha_x = 1.385
# s = 67.200 m  |  beta_x = 8.419  |  alpha_x = 1.371
# s = 67.285 m  |  beta_x = 8.188  |  alpha_x = 1.341
# s = 67.342 m  |  beta_x = 8.038  |  alpha_x = 1.322
# s = 67.377 m  |  beta_x = 7.946  |  alpha_x = 1.310
# s = 67.936 m  |  beta_x = 6.586  |  alpha_x = 1.119
# s = 69.266 m  |  beta_x = 4.214  |  alpha_x = 0.665
# s = 69.301 m  |  beta_x = 4.167  |  alpha_x = 0.653
# s = 69.357 m  |  beta_x = 4.095  |  alpha_x = 0.633
# s = 69.358 m  |  beta_x = 4.094  |  alpha_x = 0.633
# s = 69.415 m  |  beta_x = 4.023  |  alpha_x = 0.614
# s = 69.450 m  |  beta_x = 3.981  |  alpha_x = 0.602
# s = 71.339 m  |  beta_x = 2.927  |  alpha_x = -0.044
# s = 71.374 m  |  beta_x = 2.931  |  alpha_x = -0.056
# s = 71.431 m  |  beta_x = 2.938  |  alpha_x = -0.076
# s = 71.473 m  |  beta_x = 2.945  |  alpha_x = -0.090
# s = 71.516 m  |  beta_x = 2.953  |  alpha_x = -0.105
# s = 71.558 m  |  beta_x = 2.963  |  alpha_x = -0.119
# s = 71.615 m  |  beta_x = 2.978  |  alpha_x = -0.139
# s = 71.671 m  |  beta_x = 2.994  |  alpha_x = -0.158
# s = 71.706 m  |  beta_x = 3.006  |  alpha_x = -0.170
# s = 72.266 m  |  beta_x = 3.303  |  alpha_x = -0.362
# s = 73.596 m  |  beta_x = 4.869  |  alpha_x = -0.816
# s = 73.631 m  |  beta_x = 4.927  |  alpha_x = -0.828
# s = 73.687 m  |  beta_x = 5.022  |  alpha_x = -0.847
# s = 73.688 m  |  beta_x = 5.023  |  alpha_x = -0.848
# s = 73.745 m  |  beta_x = 5.120  |  alpha_x = -0.867
# s = 73.780 m  |  beta_x = 5.181  |  alpha_x = -0.879
# s = 75.669 m  |  beta_x = 9.722  |  alpha_x = -1.524
# s = 75.704 m  |  beta_x = 9.829  |  alpha_x = -1.536
# s = 75.761 m  |  beta_x = 10.004  |  alpha_x = -1.556
# s = 75.846 m  |  beta_x = 10.271  |  alpha_x = -1.585
# s = 75.948 m  |  beta_x = 10.598  |  alpha_x = -1.619
# s = 76.001 m  |  beta_x = 10.772  |  alpha_x = -1.638
# s = 76.044 m  |  beta_x = 10.912  |  alpha_x = -1.652
# s = 76.126 m  |  beta_x = 11.185  |  alpha_x = -1.680
# s = 76.246 m  |  beta_x = 11.593  |  alpha_x = -1.721
# s = 76.385 m  |  beta_x = 12.081  |  alpha_x = -1.769
# s = 76.505 m  |  beta_x = 12.511  |  alpha_x = -1.810
# s = 76.551 m  |  beta_x = 12.677  |  alpha_x = -1.826
# s = 76.577 m  |  beta_x = 12.772  |  alpha_x = -1.835
# s = 76.707 m  |  beta_x = 13.254  |  alpha_x = -1.879
# s = 76.940 m  |  beta_x = 14.147  |  alpha_x = -1.959
# s = 77.262 m  |  beta_x = 17.486  |  alpha_x = -8.854
# s = 77.345 m  |  beta_x = 18.989  |  alpha_x = -9.231
# s = 77.402 m  |  beta_x = 20.066  |  alpha_x = -9.492
# s = 77.470 m  |  beta_x = 21.362  |  alpha_x = -9.797
# s = 77.792 m  |  beta_x = 23.462  |  alpha_x = 3.703
# s = 78.034 m  |  beta_x = 21.707  |  alpha_x = 3.551
# s = 78.336 m  |  beta_x = 19.617  |  alpha_x = 3.361
# s = 78.624 m  |  beta_x = 17.733  |  alpha_x = 3.181
# s = 78.833 m  |  beta_x = 16.428  |  alpha_x = 3.049
# s = 78.969 m  |  beta_x = 15.612  |  alpha_x = 2.964
# s = 79.050 m  |  beta_x = 15.138  |  alpha_x = 2.914
# s = 79.170 m  |  beta_x = 14.448  |  alpha_x = 2.839
# s = 79.309 m  |  beta_x = 13.666  |  alpha_x = 2.751
# s = 79.429 m  |  beta_x = 13.015  |  alpha_x = 2.676
# s = 79.519 m  |  beta_x = 12.541  |  alpha_x = 2.620
# s = 79.735 m  |  beta_x = 11.437  |  alpha_x = 2.484
# s = 79.752 m  |  beta_x = 11.356  |  alpha_x = 2.474
# s = 80.074 m  |  beta_x = 12.992  |  alpha_x = -8.015
# s = 80.282 m  |  beta_x = 16.539  |  alpha_x = -9.058
# s = 80.604 m  |  beta_x = 17.949  |  alpha_x = 5.068
# s = 80.921 m  |  beta_x = 14.885  |  alpha_x = 4.597
# s = 80.949 m  |  beta_x = 14.628  |  alpha_x = 4.555
# s = 80.991 m  |  beta_x = 14.243  |  alpha_x = 4.492
# s = 81.131 m  |  beta_x = 10.463  |  alpha_x = 3.443
# s = 83.038 m  |  beta_x = 218.648  |  alpha_x = -223.337
# s = 83.184 m  |  beta_x = 266.667  |  alpha_x = -236.986
# s = 83.427 m  |  beta_x = 347.536  |  alpha_x = -253.719
# s = 83.544 m  |  beta_x = 386.225  |  alpha_x = -259.753
# s = 83.701 m  |  beta_x = 438.052  |  alpha_x = -266.392
# s = 83.744 m  |  beta_x = 452.031  |  alpha_x = -267.948
# s = 83.786 m  |  beta_x = 465.989  |  alpha_x = -269.415
# s = 83.829 m  |  beta_x = 479.925  |  alpha_x = -270.799
# s = 83.909 m  |  beta_x = 506.260  |  alpha_x = -273.214
# s = 84.232 m  |  beta_x = 321.342  |  alpha_x = 208.123
# s = 84.316 m  |  beta_x = 302.330  |  alpha_x = 207.104
# s = 84.454 m  |  beta_x = 271.011  |  alpha_x = 205.041
# s = 84.591 m  |  beta_x = 239.476  |  alpha_x = 202.314
# s = 84.960 m  |  beta_x = 153.545  |  alpha_x = 188.745
# s = 85.105 m  |  beta_x = 119.344  |  alpha_x = 178.535
# s = 87.013 m  |  beta_x = 1152.409  |  alpha_x = -305.390
# s = 87.159 m  |  beta_x = 1243.135  |  alpha_x = -317.182
# s = 87.338 m  |  beta_x = 1359.343  |  alpha_x = -331.674
# s = 87.455 m  |  beta_x = 1437.909  |  alpha_x = -341.123
# s = 87.563 m  |  beta_x = 1512.380  |  alpha_x = -349.843
# s = 87.605 m  |  beta_x = 1542.259  |  alpha_x = -353.281
# s = 87.685 m  |  beta_x = 1599.108  |  alpha_x = -359.732
# s = 88.008 m  |  beta_x = 462.242  |  alpha_x = -493.879
# s = 88.093 m  |  beta_x = 505.486  |  alpha_x = -495.231
# s = 88.135 m  |  beta_x = 527.168  |  alpha_x = -495.794
# s = 88.178 m  |  beta_x = 548.829  |  alpha_x = -496.294
# s = 88.285 m  |  beta_x = 603.409  |  alpha_x = -497.335
# s = 88.608 m  |  beta_x = 4820.108  |  alpha_x = 1178.419
# s = 88.715 m  |  beta_x = 4577.759  |  alpha_x = 1149.318
# s = 88.827 m  |  beta_x = 4332.342  |  alpha_x = 1118.980
# s = 88.935 m  |  beta_x = 4098.708  |  alpha_x = 1089.218
# s = 89.079 m  |  beta_x = 3804.854  |  alpha_x = 1052.528
# s = 90.988 m  |  beta_x = 60.894  |  alpha_x = -125.787
# s = 91.144 m  |  beta_x = 89.592  |  alpha_x = -139.680
# s = 91.229 m  |  beta_x = 105.183  |  alpha_x = -144.711
# s = 91.314 m  |  beta_x = 120.694  |  alpha_x = -148.584
# s = 91.356 m  |  beta_x = 128.231  |  alpha_x = -150.152
# s = 91.412 m  |  beta_x = 138.333  |  alpha_x = -151.993
# s = 91.529 m  |  beta_x = 159.329  |  alpha_x = -155.061
# s = 91.597 m  |  beta_x = 171.569  |  alpha_x = -156.483
# s = 91.662 m  |  beta_x = 183.129  |  alpha_x = -157.632
# s = 91.727 m  |  beta_x = 194.645  |  alpha_x = -158.623
# s = 91.770 m  |  beta_x = 202.152  |  alpha_x = -159.199
# s = 91.861 m  |  beta_x = 218.222  |  alpha_x = -160.274
# s = 91.863 m  |  beta_x = 218.661  |  alpha_x = -160.301
# s = 91.863 m  |  beta_x = 218.662  |  alpha_x = -160.301
# s = 92.190 m  |  beta_x = 218.815  |  alpha_x = 160.410
# s = 92.192 m  |  beta_x = 218.376  |  alpha_x = 160.383
# s = 92.280 m  |  beta_x = 202.944  |  alpha_x = 159.360
# s = 92.315 m  |  beta_x = 196.762  |  alpha_x = 158.895
# s = 92.358 m  |  beta_x = 189.240  |  alpha_x = 158.282
# s = 92.400 m  |  beta_x = 181.700  |  alpha_x = 157.607
# s = 92.435 m  |  beta_x = 175.476  |  alpha_x = 156.999
# s = 92.525 m  |  beta_x = 159.466  |  alpha_x = 155.191
# s = 92.642 m  |  beta_x = 138.461  |  alpha_x = 152.130
# s = 92.913 m  |  beta_x = 88.980  |  alpha_x = 139.567
# s = 93.066 m  |  beta_x = 60.903  |  alpha_x = 125.900
# s = 94.975 m  |  beta_x = 3092.917  |  alpha_x = -854.492
# s = 95.122 m  |  beta_x = 3345.325  |  alpha_x = -888.093
# s = 95.177 m  |  beta_x = 3441.694  |  alpha_x = -900.569
# s = 95.342 m  |  beta_x = 3739.906  |  alpha_x = -938.048
# s = 95.445 m  |  beta_x = 3932.525  |  alpha_x = -961.421
# s = 95.768 m  |  beta_x = 599.852  |  alpha_x = 494.404
# s = 95.850 m  |  beta_x = 558.355  |  alpha_x = 493.234
# s = 95.892 m  |  beta_x = 536.577  |  alpha_x = 492.519
# s = 95.935 m  |  beta_x = 514.770  |  alpha_x = 491.718
# s = 95.977 m  |  beta_x = 492.932  |  alpha_x = 490.818
# s = 96.045 m  |  beta_x = 457.789  |  alpha_x = 489.122
# s = 96.368 m  |  beta_x = 1289.937  |  alpha_x = 290.184
# s = 96.465 m  |  beta_x = 1234.764  |  alpha_x = 283.911
# s = 96.598 m  |  beta_x = 1159.898  |  alpha_x = 275.171
# s = 96.715 m  |  beta_x = 1096.520  |  alpha_x = 267.548
# s = 96.898 m  |  beta_x = 1000.797  |  alpha_x = 255.605
# s = 97.041 m  |  beta_x = 930.330  |  alpha_x = 247.087
# s = 98.949 m  |  beta_x = 131.578  |  alpha_x = -196.733
# s = 99.097 m  |  beta_x = 165.852  |  alpha_x = -202.901
# s = 99.235 m  |  beta_x = 197.305  |  alpha_x = -206.504
# s = 99.426 m  |  beta_x = 240.584  |  alpha_x = -209.673
# s = 99.616 m  |  beta_x = 283.217  |  alpha_x = -211.642
# s = 99.658 m  |  beta_x = 292.715  |  alpha_x = -211.980
# s = 99.701 m  |  beta_x = 302.201  |  alpha_x = -212.289
# s = 99.743 m  |  beta_x = 311.676  |  alpha_x = -212.574
# s = 99.821 m  |  beta_x = 328.928  |  alpha_x = -213.035
# s = 100.144 m  |  beta_x = 534.580  |  alpha_x = 288.501
# s = 100.241 m  |  beta_x = 503.727  |  alpha_x = 286.891
# s = 100.283 m  |  beta_x = 490.156  |  alpha_x = 286.107
# s = 100.326 m  |  beta_x = 476.561  |  alpha_x = 285.269
# s = 100.509 m  |  beta_x = 417.688  |  alpha_x = 280.917
# s = 100.626 m  |  beta_x = 379.884  |  alpha_x = 277.339
# s = 100.874 m  |  beta_x = 298.935  |  alpha_x = 266.587
# s = 101.016 m  |  beta_x = 252.054  |  alpha_x = 257.529
# s = 102.923 m  |  beta_x = 5.434  |  alpha_x = -1.701
# s = 103.073 m  |  beta_x = 5.958  |  alpha_x = -1.808
# s = 103.115 m  |  beta_x = 6.113  |  alpha_x = -1.838
# s = 103.158 m  |  beta_x = 6.271  |  alpha_x = -1.869
# s = 103.303 m  |  beta_x = 6.830  |  alpha_x = -1.973
# s = 103.423 m  |  beta_x = 7.313  |  alpha_x = -2.059
# s = 103.563 m  |  beta_x = 7.904  |  alpha_x = -2.159
# s = 103.683 m  |  beta_x = 8.432  |  alpha_x = -2.245
# s = 103.873 m  |  beta_x = 9.309  |  alpha_x = -2.381
# s = 104.105 m  |  beta_x = 10.454  |  alpha_x = -2.547
# s = 104.427 m  |  beta_x = 14.683  |  alpha_x = -11.459
# s = 104.515 m  |  beta_x = 16.760  |  alpha_x = -12.249
# s = 104.558 m  |  beta_x = 17.844  |  alpha_x = -12.641
# s = 104.635 m  |  beta_x = 19.837  |  alpha_x = -13.333
# s = 104.957 m  |  beta_x = 23.885  |  alpha_x = 1.730
# s = 105.064 m  |  beta_x = 23.517  |  alpha_x = 1.712
# s = 105.157 m  |  beta_x = 23.201  |  alpha_x = 1.697
# s = 105.242 m  |  beta_x = 22.914  |  alpha_x = 1.683
# s = 106.394 m  |  beta_x = 19.257  |  alpha_x = 1.490
# s = 106.452 m  |  beta_x = 19.086  |  alpha_x = 1.480
# s = 106.502 m  |  beta_x = 18.939  |  alpha_x = 1.472
# s = 106.572 m  |  beta_x = 18.733  |  alpha_x = 1.460
# s = 108.707 m  |  beta_x = 13.259  |  alpha_x = 1.103
# s = 108.749 m  |  beta_x = 13.167  |  alpha_x = 1.096
# s = 108.981 m  |  beta_x = 12.667  |  alpha_x = 1.057
# s = 109.303 m  |  beta_x = 14.334  |  alpha_x = -6.538
# s = 109.510 m  |  beta_x = 17.174  |  alpha_x = -7.170
# s = 109.834 m  |  beta_x = 19.205  |  alpha_x = 1.203
# s = 109.990 m  |  beta_x = 18.832  |  alpha_x = 1.183
# s = 110.125 m  |  beta_x = 18.515  |  alpha_x = 1.166
# s = 110.430 m  |  beta_x = 17.816  |  alpha_x = 1.127
# s = 110.570 m  |  beta_x = 17.503  |  alpha_x = 1.109
# s = 110.654 m  |  beta_x = 17.317  |  alpha_x = 1.099
# s = 110.696 m  |  beta_x = 17.224  |  alpha_x = 1.093
# s = 110.739 m  |  beta_x = 17.131  |  alpha_x = 1.088
# s = 111.206 m  |  beta_x = 16.143  |  alpha_x = 1.028
# s = 111.246 m  |  beta_x = 16.061  |  alpha_x = 1.023
# s = 111.326 m  |  beta_x = 15.898  |  alpha_x = 1.013
# s = 112.032 m  |  beta_x = 14.530  |  alpha_x = 0.923
# s = 112.152 m  |  beta_x = 14.311  |  alpha_x = 0.908
# s = 112.292 m  |  beta_x = 14.059  |  alpha_x = 0.890
# s = 112.412 m  |  beta_x = 13.847  |  alpha_x = 0.875
# s = 112.663 m  |  beta_x = 13.417  |  alpha_x = 0.843
# s = 112.748 m  |  beta_x = 13.275  |  alpha_x = 0.832
# s = 112.804 m  |  beta_x = 13.181  |  alpha_x = 0.825
# s = 112.839 m  |  beta_x = 13.123  |  alpha_x = 0.820
# s = 113.399 m  |  beta_x = 12.245  |  alpha_x = 0.749
# s = 114.729 m  |  beta_x = 10.476  |  alpha_x = 0.581
# s = 114.764 m  |  beta_x = 10.436  |  alpha_x = 0.576
# s = 114.820 m  |  beta_x = 10.371  |  alpha_x = 0.569
# s = 114.847 m  |  beta_x = 10.341  |  alpha_x = 0.566
# s = 114.904 m  |  beta_x = 10.277  |  alpha_x = 0.558
# s = 114.939 m  |  beta_x = 10.238  |  alpha_x = 0.554
# s = 116.828 m  |  beta_x = 8.598  |  alpha_x = 0.314
# s = 116.863 m  |  beta_x = 8.577  |  alpha_x = 0.309
# s = 116.920 m  |  beta_x = 8.542  |  alpha_x = 0.302
# s = 116.962 m  |  beta_x = 8.517  |  alpha_x = 0.297
# s = 117.005 m  |  beta_x = 8.492  |  alpha_x = 0.291
# s = 117.062 m  |  beta_x = 8.459  |  alpha_x = 0.284
# s = 117.112 m  |  beta_x = 8.431  |  alpha_x = 0.277
# s = 117.182 m  |  beta_x = 8.392  |  alpha_x = 0.269
# s = 117.225 m  |  beta_x = 8.370  |  alpha_x = 0.263
# s = 117.261 m  |  beta_x = 8.351  |  alpha_x = 0.258
# s = 117.318 m  |  beta_x = 8.322  |  alpha_x = 0.251
# s = 117.353 m  |  beta_x = 8.304  |  alpha_x = 0.247
# s = 117.913 m  |  beta_x = 8.068  |  alpha_x = 0.175
# s = 119.242 m  |  beta_x = 7.826  |  alpha_x = 0.006
# s = 119.277 m  |  beta_x = 7.826  |  alpha_x = 0.002
# s = 119.334 m  |  beta_x = 7.826  |  alpha_x = -0.005
# s = 119.361 m  |  beta_x = 7.827  |  alpha_x = -0.009
# s = 119.417 m  |  beta_x = 7.828  |  alpha_x = -0.016
# s = 119.452 m  |  beta_x = 7.829  |  alpha_x = -0.021
# s = 121.342 m  |  beta_x = 8.361  |  alpha_x = -0.261
# s = 121.377 m  |  beta_x = 8.380  |  alpha_x = -0.266
# s = 121.433 m  |  beta_x = 8.410  |  alpha_x = -0.273
# s = 121.476 m  |  beta_x = 8.434  |  alpha_x = -0.278
# s = 121.518 m  |  beta_x = 8.458  |  alpha_x = -0.284
# s = 121.561 m  |  beta_x = 8.482  |  alpha_x = -0.289
# s = 121.713 m  |  beta_x = 8.573  |  alpha_x = -0.309
# s = 121.716 m  |  beta_x = 8.575  |  alpha_x = -0.309
# s = 121.920 m  |  beta_x = 10.329  |  alpha_x = -8.794
# s = 121.955 m  |  beta_x = 10.954  |  alpha_x = -9.059
# s = 122.011 m  |  beta_x = 11.994  |  alpha_x = -9.485
# s = 122.215 m  |  beta_x = 13.614  |  alpha_x = 2.034
# s = 122.263 m  |  beta_x = 13.422  |  alpha_x = 2.016
# s = 122.348 m  |  beta_x = 13.082  |  alpha_x = 1.984
# s = 122.404 m  |  beta_x = 12.859  |  alpha_x = 1.962
# s = 122.439 m  |  beta_x = 12.722  |  alpha_x = 1.949
# s = 122.999 m  |  beta_x = 10.658  |  alpha_x = 1.738
# s = 124.329 m  |  beta_x = 6.701  |  alpha_x = 1.237
# s = 124.364 m  |  beta_x = 6.615  |  alpha_x = 1.224
# s = 124.420 m  |  beta_x = 6.478  |  alpha_x = 1.203
# s = 124.447 m  |  beta_x = 6.414  |  alpha_x = 1.192
# s = 124.504 m  |  beta_x = 6.280  |  alpha_x = 1.171
# s = 124.539 m  |  beta_x = 6.198  |  alpha_x = 1.158
# s = 126.428 m  |  beta_x = 3.171  |  alpha_x = 0.445
# s = 126.463 m  |  beta_x = 3.140  |  alpha_x = 0.431
# s = 126.520 m  |  beta_x = 3.092  |  alpha_x = 0.410
# s = 126.577 m  |  beta_x = 3.046  |  alpha_x = 0.388
# s = 126.627 m  |  beta_x = 3.009  |  alpha_x = 0.369
# s = 126.697 m  |  beta_x = 2.959  |  alpha_x = 0.343
# s = 126.740 m  |  beta_x = 2.930  |  alpha_x = 0.327
# s = 126.782 m  |  beta_x = 2.903  |  alpha_x = 0.311
# s = 126.825 m  |  beta_x = 2.877  |  alpha_x = 0.295
# s = 126.861 m  |  beta_x = 2.856  |  alpha_x = 0.281
# s = 126.918 m  |  beta_x = 2.826  |  alpha_x = 0.260
# s = 126.953 m  |  beta_x = 2.808  |  alpha_x = 0.246
# s = 127.513 m  |  beta_x = 2.650  |  alpha_x = 0.035
# s = 128.842 m  |  beta_x = 3.225  |  alpha_x = -0.467
# s = 128.877 m  |  beta_x = 3.258  |  alpha_x = -0.480
# s = 128.934 m  |  beta_x = 3.314  |  alpha_x = -0.502
# s = 128.961 m  |  beta_x = 3.341  |  alpha_x = -0.512
# s = 129.017 m  |  beta_x = 3.400  |  alpha_x = -0.533
# s = 129.052 m  |  beta_x = 3.438  |  alpha_x = -0.546
# s = 130.942 m  |  beta_x = 6.850  |  alpha_x = -1.260
# s = 130.977 m  |  beta_x = 6.939  |  alpha_x = -1.273
# s = 131.033 m  |  beta_x = 7.084  |  alpha_x = -1.294
# s = 131.076 m  |  beta_x = 7.195  |  alpha_x = -1.310
# s = 131.228 m  |  beta_x = 7.603  |  alpha_x = -1.368
# s = 131.231 m  |  beta_x = 7.611  |  alpha_x = -1.369
# s = 131.435 m  |  beta_x = 9.685  |  alpha_x = -9.395
# s = 131.526 m  |  beta_x = 11.473  |  alpha_x = -10.235
# s = 131.730 m  |  beta_x = 13.514  |  alpha_x = 0.850
# s = 131.863 m  |  beta_x = 13.291  |  alpha_x = 0.833
# s = 131.948 m  |  beta_x = 13.150  |  alpha_x = 0.822
# s = 132.004 m  |  beta_x = 13.058  |  alpha_x = 0.815
# s = 132.039 m  |  beta_x = 13.001  |  alpha_x = 0.811
# s = 132.599 m  |  beta_x = 12.133  |  alpha_x = 0.740
# s = 133.929 m  |  beta_x = 10.391  |  alpha_x = 0.571
# s = 133.964 m  |  beta_x = 10.351  |  alpha_x = 0.566
# s = 134.020 m  |  beta_x = 10.287  |  alpha_x = 0.559
# s = 134.047 m  |  beta_x = 10.257  |  alpha_x = 0.556
# s = 134.104 m  |  beta_x = 10.195  |  alpha_x = 0.548
# s = 134.139 m  |  beta_x = 10.156  |  alpha_x = 0.544
# s = 136.028 m  |  beta_x = 8.555  |  alpha_x = 0.304
# s = 136.063 m  |  beta_x = 8.534  |  alpha_x = 0.299
# s = 136.120 m  |  beta_x = 8.500  |  alpha_x = 0.292
# s = 136.177 m  |  beta_x = 8.467  |  alpha_x = 0.285
# s = 136.227 m  |  beta_x = 8.439  |  alpha_x = 0.278
# s = 136.297 m  |  beta_x = 8.401  |  alpha_x = 0.269
# s = 136.340 m  |  beta_x = 8.378  |  alpha_x = 0.264
# s = 136.381 m  |  beta_x = 8.356  |  alpha_x = 0.259
# s = 136.461 m  |  beta_x = 8.316  |  alpha_x = 0.248
# s = 136.518 m  |  beta_x = 8.288  |  alpha_x = 0.241
# s = 136.553 m  |  beta_x = 8.271  |  alpha_x = 0.237
# s = 137.113 m  |  beta_x = 8.046  |  alpha_x = 0.165
# s = 138.442 m  |  beta_x = 7.832  |  alpha_x = -0.004
# s = 138.477 m  |  beta_x = 7.832  |  alpha_x = -0.008
# s = 138.534 m  |  beta_x = 7.833  |  alpha_x = -0.016
# s = 138.561 m  |  beta_x = 7.834  |  alpha_x = -0.019
# s = 138.617 m  |  beta_x = 7.837  |  alpha_x = -0.026
# s = 138.652 m  |  beta_x = 7.839  |  alpha_x = -0.031
# s = 140.542 m  |  beta_x = 8.410  |  alpha_x = -0.271
# s = 140.577 m  |  beta_x = 8.429  |  alpha_x = -0.276
# s = 140.633 m  |  beta_x = 8.460  |  alpha_x = -0.283
# s = 140.676 m  |  beta_x = 8.485  |  alpha_x = -0.288
# s = 140.828 m  |  beta_x = 8.576  |  alpha_x = -0.308
# s = 140.831 m  |  beta_x = 8.578  |  alpha_x = -0.308
# s = 141.035 m  |  beta_x = 10.113  |  alpha_x = -7.605
# s = 141.126 m  |  beta_x = 11.547  |  alpha_x = -8.135
# s = 141.330 m  |  beta_x = 13.099  |  alpha_x = 0.914
# s = 141.463 m  |  beta_x = 12.859  |  alpha_x = 0.895
# s = 141.548 m  |  beta_x = 12.708  |  alpha_x = 0.883
# s = 141.604 m  |  beta_x = 12.608  |  alpha_x = 0.875
# s = 141.639 m  |  beta_x = 12.547  |  alpha_x = 0.870
# s = 142.199 m  |  beta_x = 11.617  |  alpha_x = 0.792
# s = 143.529 m  |  beta_x = 9.757  |  alpha_x = 0.606
# s = 143.564 m  |  beta_x = 9.715  |  alpha_x = 0.601
# s = 143.620 m  |  beta_x = 9.647  |  alpha_x = 0.594
# s = 143.647 m  |  beta_x = 9.616  |  alpha_x = 0.590
# s = 143.704 m  |  beta_x = 9.549  |  alpha_x = 0.582
# s = 143.739 m  |  beta_x = 9.509  |  alpha_x = 0.577
# s = 145.628 m  |  beta_x = 7.828  |  alpha_x = 0.313
# s = 145.663 m  |  beta_x = 7.806  |  alpha_x = 0.308
# s = 145.720 m  |  beta_x = 7.772  |  alpha_x = 0.300
# s = 145.777 m  |  beta_x = 7.738  |  alpha_x = 0.292
# s = 145.827 m  |  beta_x = 7.709  |  alpha_x = 0.285
# s = 145.897 m  |  beta_x = 7.670  |  alpha_x = 0.275
# s = 145.940 m  |  beta_x = 7.647  |  alpha_x = 0.269
# s = 146.061 m  |  beta_x = 7.583  |  alpha_x = 0.252
# s = 146.118 m  |  beta_x = 7.555  |  alpha_x = 0.244
# s = 146.153 m  |  beta_x = 7.538  |  alpha_x = 0.239
# s = 146.713 m  |  beta_x = 7.314  |  alpha_x = 0.161
# s = 148.042 m  |  beta_x = 7.135  |  alpha_x = -0.025
# s = 148.077 m  |  beta_x = 7.137  |  alpha_x = -0.030
# s = 148.134 m  |  beta_x = 7.140  |  alpha_x = -0.038
# s = 148.161 m  |  beta_x = 7.143  |  alpha_x = -0.042
# s = 148.217 m  |  beta_x = 7.148  |  alpha_x = -0.050
# s = 148.252 m  |  beta_x = 7.151  |  alpha_x = -0.055
# s = 150.142 m  |  beta_x = 7.859  |  alpha_x = -0.319
# s = 150.177 m  |  beta_x = 7.881  |  alpha_x = -0.324
# s = 150.233 m  |  beta_x = 7.918  |  alpha_x = -0.332
# s = 150.276 m  |  beta_x = 7.947  |  alpha_x = -0.338
# s = 150.428 m  |  beta_x = 8.053  |  alpha_x = -0.360
# s = 150.431 m  |  beta_x = 8.055  |  alpha_x = -0.360
# s = 150.635 m  |  beta_x = 9.570  |  alpha_x = -7.457
# s = 150.726 m  |  beta_x = 10.978  |  alpha_x = -7.996
# s = 150.930 m  |  beta_x = 12.489  |  alpha_x = 0.978
# s = 151.012 m  |  beta_x = 12.330  |  alpha_x = 0.966
# s = 151.063 m  |  beta_x = 12.233  |  alpha_x = 0.958
# s = 151.148 m  |  beta_x = 12.071  |  alpha_x = 0.944
# s = 151.204 m  |  beta_x = 11.965  |  alpha_x = 0.936
# s = 151.239 m  |  beta_x = 11.900  |  alpha_x = 0.930
# s = 151.478 m  |  beta_x = 11.465  |  alpha_x = 0.893
# s = 153.129 m  |  beta_x = 8.944  |  alpha_x = 0.634
# s = 153.164 m  |  beta_x = 8.899  |  alpha_x = 0.629
# s = 153.220 m  |  beta_x = 8.829  |  alpha_x = 0.620
# s = 153.247 m  |  beta_x = 8.795  |  alpha_x = 0.616
# s = 153.304 m  |  beta_x = 8.726  |  alpha_x = 0.607
# s = 153.339 m  |  beta_x = 8.684  |  alpha_x = 0.601
# s = 155.228 m  |  beta_x = 6.970  |  alpha_x = 0.305
# s = 155.263 m  |  beta_x = 6.949  |  alpha_x = 0.300
# s = 155.320 m  |  beta_x = 6.916  |  alpha_x = 0.291
# s = 155.377 m  |  beta_x = 6.883  |  alpha_x = 0.282
# s = 155.427 m  |  beta_x = 6.855  |  alpha_x = 0.274
# s = 155.497 m  |  beta_x = 6.817  |  alpha_x = 0.263
# s = 155.540 m  |  beta_x = 6.795  |  alpha_x = 0.257
# s = 155.661 m  |  beta_x = 6.735  |  alpha_x = 0.238
# s = 155.718 m  |  beta_x = 6.709  |  alpha_x = 0.229
# s = 155.753 m  |  beta_x = 6.693  |  alpha_x = 0.223
# s = 156.313 m  |  beta_x = 6.492  |  alpha_x = 0.135
# s = 157.642 m  |  beta_x = 6.409  |  alpha_x = -0.073
# s = 157.677 m  |  beta_x = 6.414  |  alpha_x = -0.078
# s = 157.734 m  |  beta_x = 6.424  |  alpha_x = -0.087
# s = 157.761 m  |  beta_x = 6.429  |  alpha_x = -0.092
# s = 157.817 m  |  beta_x = 6.440  |  alpha_x = -0.100
# s = 157.852 m  |  beta_x = 6.447  |  alpha_x = -0.106
# s = 159.742 m  |  beta_x = 7.406  |  alpha_x = -0.402
# s = 159.777 m  |  beta_x = 7.434  |  alpha_x = -0.407
# s = 159.833 m  |  beta_x = 7.481  |  alpha_x = -0.416
# s = 159.852 m  |  beta_x = 7.496  |  alpha_x = -0.419
# s = 159.894 m  |  beta_x = 7.532  |  alpha_x = -0.426
# s = 160.047 m  |  beta_x = 7.666  |  alpha_x = -0.450
# s = 160.050 m  |  beta_x = 7.669  |  alpha_x = -0.450
# s = 160.254 m  |  beta_x = 9.187  |  alpha_x = -7.394
# s = 160.345 m  |  beta_x = 10.585  |  alpha_x = -7.946
# s = 160.549 m  |  beta_x = 12.105  |  alpha_x = 0.895
# s = 160.612 m  |  beta_x = 11.992  |  alpha_x = 0.885
# s = 160.690 m  |  beta_x = 11.855  |  alpha_x = 0.874
# s = 160.796 m  |  beta_x = 11.671  |  alpha_x = 0.858
# s = 160.835 m  |  beta_x = 11.605  |  alpha_x = 0.852
# s = 161.395 m  |  beta_x = 10.697  |  alpha_x = 0.769
# s = 162.725 m  |  beta_x = 8.915  |  alpha_x = 0.572
# s = 162.764 m  |  beta_x = 8.870  |  alpha_x = 0.566
# s = 162.896 m  |  beta_x = 8.723  |  alpha_x = 0.546
# s = 162.935 m  |  beta_x = 8.681  |  alpha_x = 0.540
# s = 164.824 m  |  beta_x = 7.170  |  alpha_x = 0.260
# s = 164.863 m  |  beta_x = 7.150  |  alpha_x = 0.254
# s = 164.898 m  |  beta_x = 7.132  |  alpha_x = 0.249
# s = 164.941 m  |  beta_x = 7.111  |  alpha_x = 0.242
# s = 164.999 m  |  beta_x = 7.083  |  alpha_x = 0.234
# s = 165.049 m  |  beta_x = 7.060  |  alpha_x = 0.226
# s = 165.119 m  |  beta_x = 7.030  |  alpha_x = 0.216
# s = 165.161 m  |  beta_x = 7.011  |  alpha_x = 0.209
# s = 165.204 m  |  beta_x = 6.994  |  alpha_x = 0.203
# s = 165.310 m  |  beta_x = 6.953  |  alpha_x = 0.187
# s = 165.349 m  |  beta_x = 6.938  |  alpha_x = 0.181
# s = 165.909 m  |  beta_x = 6.782  |  alpha_x = 0.098
# s = 167.238 m  |  beta_x = 6.783  |  alpha_x = -0.100
# s = 167.277 m  |  beta_x = 6.791  |  alpha_x = -0.105
# s = 167.409 m  |  beta_x = 6.822  |  alpha_x = -0.125
# s = 167.448 m  |  beta_x = 6.832  |  alpha_x = -0.131
# s = 169.338 m  |  beta_x = 7.857  |  alpha_x = -0.412
# s = 169.377 m  |  beta_x = 7.889  |  alpha_x = -0.417
# s = 169.412 m  |  beta_x = 7.918  |  alpha_x = -0.423
# s = 169.526 m  |  beta_x = 8.017  |  alpha_x = -0.440
# s = 169.568 m  |  beta_x = 8.054  |  alpha_x = -0.446
# s = 169.721 m  |  beta_x = 8.194  |  alpha_x = -0.469
# s = 169.724 m  |  beta_x = 8.197  |  alpha_x = -0.469
# s = 169.928 m  |  beta_x = 9.814  |  alpha_x = -7.883
# s = 169.955 m  |  beta_x = 10.252  |  alpha_x = -8.060
# s = 170.019 m  |  beta_x = 11.303  |  alpha_x = -8.469
# s = 170.223 m  |  beta_x = 12.919  |  alpha_x = 0.974
# s = 170.282 m  |  beta_x = 12.804  |  alpha_x = 0.965
# s = 170.360 m  |  beta_x = 12.654  |  alpha_x = 0.953
# s = 170.466 m  |  beta_x = 12.454  |  alpha_x = 0.937
# s = 170.505 m  |  beta_x = 12.381  |  alpha_x = 0.931
# s = 171.065 m  |  beta_x = 11.386  |  alpha_x = 0.847
# s = 172.395 m  |  beta_x = 9.400  |  alpha_x = 0.647
# s = 172.434 m  |  beta_x = 9.350  |  alpha_x = 0.641
# s = 172.566 m  |  beta_x = 9.183  |  alpha_x = 0.621
# s = 172.605 m  |  beta_x = 9.135  |  alpha_x = 0.615
# s = 174.494 m  |  beta_x = 7.349  |  alpha_x = 0.330
# s = 174.533 m  |  beta_x = 7.323  |  alpha_x = 0.324
# s = 174.568 m  |  beta_x = 7.301  |  alpha_x = 0.319
# s = 174.611 m  |  beta_x = 7.274  |  alpha_x = 0.313
# s = 174.669 m  |  beta_x = 7.238  |  alpha_x = 0.304
# s = 174.719 m  |  beta_x = 7.208  |  alpha_x = 0.296
# s = 174.789 m  |  beta_x = 7.167  |  alpha_x = 0.286
# s = 174.831 m  |  beta_x = 7.143  |  alpha_x = 0.279
# s = 174.874 m  |  beta_x = 7.120  |  alpha_x = 0.273
# s = 174.980 m  |  beta_x = 7.064  |  alpha_x = 0.257
# s = 175.019 m  |  beta_x = 7.044  |  alpha_x = 0.251
# s = 176.908 m  |  beta_x = 6.633  |  alpha_x = -0.034
# s = 176.947 m  |  beta_x = 6.636  |  alpha_x = -0.040
# s = 177.079 m  |  beta_x = 6.649  |  alpha_x = -0.060
# s = 177.118 m  |  beta_x = 6.654  |  alpha_x = -0.066
# s = 178.772 m  |  beta_x = 7.283  |  alpha_x = -0.315
# s = 179.008 m  |  beta_x = 7.440  |  alpha_x = -0.350
# s = 179.047 m  |  beta_x = 7.468  |  alpha_x = -0.356
# s = 179.082 m  |  beta_x = 7.493  |  alpha_x = -0.362
# s = 179.124 m  |  beta_x = 7.524  |  alpha_x = -0.368
# s = 179.167 m  |  beta_x = 7.556  |  alpha_x = -0.374
# s = 179.319 m  |  beta_x = 7.673  |  alpha_x = -0.397
# s = 179.322 m  |  beta_x = 7.676  |  alpha_x = -0.398
# s = 179.526 m  |  beta_x = 9.486  |  alpha_x = -9.057
# s = 179.555 m  |  beta_x = 10.019  |  alpha_x = -9.311
# s = 179.617 m  |  beta_x = 11.209  |  alpha_x = -9.855
# s = 179.821 m  |  beta_x = 13.049  |  alpha_x = 1.417
# s = 182.531 m  |  beta_x = 7.063  |  alpha_x = 0.792
# s = 182.672 m  |  beta_x = 6.843  |  alpha_x = 0.760
# s = 182.790 m  |  beta_x = 6.668  |  alpha_x = 0.733
# s = 182.931 m  |  beta_x = 6.465  |  alpha_x = 0.700
# s = 184.390 m  |  beta_x = 4.913  |  alpha_x = 0.364
# s = 184.496 m  |  beta_x = 4.839  |  alpha_x = 0.339
# s = 184.535 m  |  beta_x = 4.813  |  alpha_x = 0.330
# s = 185.095 m  |  beta_x = 4.515  |  alpha_x = 0.201
# s = 186.425 m  |  beta_x = 4.387  |  alpha_x = -0.105
# s = 186.464 m  |  beta_x = 4.395  |  alpha_x = -0.114
# s = 186.596 m  |  beta_x = 4.429  |  alpha_x = -0.144
# s = 186.635 m  |  beta_x = 4.441  |  alpha_x = -0.153
# s = 188.524 m  |  beta_x = 5.843  |  alpha_x = -0.589
# s = 188.563 m  |  beta_x = 5.889  |  alpha_x = -0.598
# s = 188.598 m  |  beta_x = 5.931  |  alpha_x = -0.606
# s = 188.650 m  |  beta_x = 5.995  |  alpha_x = -0.618
# s = 188.732 m  |  beta_x = 6.098  |  alpha_x = -0.637
# s = 188.780 m  |  beta_x = 6.159  |  alpha_x = -0.648
# s = 188.862 m  |  beta_x = 6.267  |  alpha_x = -0.666
# s = 188.904 m  |  beta_x = 6.323  |  alpha_x = -0.676
# s = 189.010 m  |  beta_x = 6.469  |  alpha_x = -0.701
# s = 189.049 m  |  beta_x = 6.524  |  alpha_x = -0.710
# s = 189.609 m  |  beta_x = 7.391  |  alpha_x = -0.838
# s = 190.938 m  |  beta_x = 10.027  |  alpha_x = -1.145
# s = 190.977 m  |  beta_x = 10.117  |  alpha_x = -1.154
# s = 191.109 m  |  beta_x = 10.425  |  alpha_x = -1.184
# s = 191.148 m  |  beta_x = 10.518  |  alpha_x = -1.193
# s = 193.038 m  |  beta_x = 15.848  |  alpha_x = -1.628
# s = 193.077 m  |  beta_x = 15.975  |  alpha_x = -1.637
# s = 193.112 m  |  beta_x = 16.090  |  alpha_x = -1.645
# s = 193.152 m  |  beta_x = 16.222  |  alpha_x = -1.654
# s = 193.194 m  |  beta_x = 16.363  |  alpha_x = -1.664
# s = 193.347 m  |  beta_x = 16.876  |  alpha_x = -1.699
# s = 193.350 m  |  beta_x = 16.886  |  alpha_x = -1.700
# s = 193.554 m  |  beta_x = 20.381  |  alpha_x = -16.306
# s = 193.645 m  |  beta_x = 23.461  |  alpha_x = -17.499
# s = 193.849 m  |  beta_x = 26.915  |  alpha_x = 1.450
# s = 193.912 m  |  beta_x = 26.733  |  alpha_x = 1.443
# s = 193.955 m  |  beta_x = 26.607  |  alpha_x = 1.438
# s = 194.212 m  |  beta_x = 25.876  |  alpha_x = 1.408
# s = 194.290 m  |  beta_x = 25.657  |  alpha_x = 1.399
# s = 194.396 m  |  beta_x = 25.362  |  alpha_x = 1.387

# %%
def get_energy_at_s(s_target, tws_list):
    s_array = np.array([tw.s for tw in tws_list])
    E_array = np.array([tw.E for tw in tws_list])
    return np.interp(s_target, s_array, E_array)

# %%
def plot_opt_func(lat, tws, top_plot=["Dx"], legend=True, fig_name=None, grid=True, font_size=12,
                  excld_legend=None, figsize=None, plt_figure=None):
    from ocelot.cpbd.optics import lattice_transfer_map

    if plt_figure is None:
        if fig_name is None:
            fig = plt.figure(figsize=figsize)
        else:
            fig = plt.figure(fig_name, figsize=figsize)
    else:
        fig = plt_figure

    plt.rc('axes', grid=grid)
    plt.rc('grid', color='0.75', linestyle='-', linewidth=0.5)
    left, width = 0.1, 0.85

    rect1 = [left, 0.65, width, 0.3]
    rect2 = [left, 0.19, width, 0.46]
    rect3 = [left, 0.07, width, 0.12]

    ax_top = fig.add_axes(rect1)
    ax_b = fig.add_axes(rect2, sharex=ax_top)
    ax_el = fig.add_axes(rect3, sharex=ax_top)

    for ax in ax_b, ax_el, ax_top:
        if ax != ax_el:
            for label in ax.get_xticklabels():
                label.set_visible(False)

    ax_b.grid(grid)
    ax_top.grid(grid)
    ax_el.set_yticks([])
    ax_el.grid(grid)

    fig.subplots_adjust(hspace=0)
    beta_x = [p.beta_x for p in tws]
    beta_y = [p.beta_y for p in tws]
    S = [p.s for p in tws]

    plt.xlim(S[0], S[-1])

    # Plot standard Twiss parameters
    plot_disp(ax_top, tws, [p for p in top_plot if p != "R56"], font_size)

    # ---- Add R56 Plotting ----
    if "R56" in top_plot:
        R56_vals = []
        s_vals = []

        for i in range(2, len(lat.sequence)):
            partial_lat = MagneticLattice(lat.sequence[:i])
            s_here = sum(e.l for e in partial_lat.sequence)

            try:
                E_here = get_energy_at_s(s_here, tws)
                R = lattice_transfer_map(partial_lat, energy=E_here)
                r56 = R[4, 5]
            except Exception as e:
                print(f"[WARN] Failed R56 at s = {s_here:.2f} m: {e}")
                r56 = 0

            # Debug print
            if i % 50 == 0 or s_here > 100:  # customize condition as you like
                print(f"s = {s_here:.2f} m, E = {E_here:.3f} GeV, R56 = {r56*1000:.3f} mm")

            R56_vals.append(r56)
            s_vals.append(s_here)

        
        ax_top.plot(s_vals, np.array(R56_vals), label="R56 [m]", color="red", linewidth=2)

    if "R56" in top_plot or legend:
        ax_top.legend(fontsize=font_size - 2)

    # Plot betas and elements
    plot_betas(ax_b, S, beta_x, beta_y, font_size)
    plot_elems(fig, ax_el, lat, s_point=S[0], legend=legend, y_scale=0.8, font_size=font_size,
               excld_legend=excld_legend)

# %%
plot_opt_func(lat, tws, top_plot=["Dx", "R56"], legend=True )
# Out:
# s = 8.98 m, E = 0.659 GeV, R56 = -0.004 mm
# s = 18.11 m, E = 0.817 GeV, R56 = -0.004 mm
# s = 27.67 m, E = 0.976 GeV, R56 = -0.004 mm
# s = 35.34 m, E = 1.095 GeV, R56 = -0.004 mm
# s = 44.80 m, E = 1.222 GeV, R56 = -0.004 mm
# s = 53.07 m, E = 1.318 GeV, R56 = -0.004 mm
# s = 61.96 m, E = 1.369 GeV, R56 = -0.004 mm
# s = 71.34 m, E = 1.449 GeV, R56 = -0.004 mm
# s = 77.40 m, E = 1.528 GeV, R56 = -0.004 mm
# s = 83.54 m, E = 1.528 GeV, R56 = 51.392 mm
# s = 91.14 m, E = 1.528 GeV, R56 = -0.089 mm
# s = 95.98 m, E = 1.528 GeV, R56 = -48.092 mm
# s = 100.14 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.24 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.28 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.28 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.33 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.51 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.51 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.63 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.87 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 102.92 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 102.92 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 102.92 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 102.92 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 102.92 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.07 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.12 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.16 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.16 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.30 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.30 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.42 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.56 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.56 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.68 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.87 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.87 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 104.11 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 104.11 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 104.43 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 104.51 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 104.56 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 104.64 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 104.64 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 104.96 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 104.96 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 105.06 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 105.06 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 105.16 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 105.24 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 105.24 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.39 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.45 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.45 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.50 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.50 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.57 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 108.71 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 108.75 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 108.75 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 108.98 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 108.98 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 109.30 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 109.51 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 109.83 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 109.99 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 109.99 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.13 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.13 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.43 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.43 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.57 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.57 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.65 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.70 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.74 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 111.21 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 111.25 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 111.33 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 111.33 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 111.33 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.03 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.15 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.29 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.41 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.41 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.41 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.66 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.75 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.80 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.80 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.84 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.84 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 113.40 m, E = 1.540 GeV, R56 = -0.168 mm
# s = 113.40 m, E = 1.540 GeV, R56 = -0.168 mm
# s = 113.40 m, E = 1.540 GeV, R56 = -0.168 mm
# s = 114.73 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.73 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.76 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.82 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.85 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.90 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.94 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.94 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 116.83 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 116.83 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 116.86 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 116.92 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 116.96 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 116.96 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.00 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.06 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.06 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.11 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.11 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.18 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.18 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.22 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.26 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.32 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.35 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.35 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.91 m, E = 1.619 GeV, R56 = -0.171 mm
# s = 117.91 m, E = 1.619 GeV, R56 = -0.171 mm
# s = 117.91 m, E = 1.619 GeV, R56 = -0.171 mm
# s = 119.24 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.24 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.28 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.33 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.36 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.42 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.45 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.45 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 121.34 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.34 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.38 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.43 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.48 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.48 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.52 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.56 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.56 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.71 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.72 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.72 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.92 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.96 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.96 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.01 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.22 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.22 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.26 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.35 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.40 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.44 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.44 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 123.00 m, E = 1.698 GeV, R56 = -0.174 mm
# s = 123.00 m, E = 1.698 GeV, R56 = -0.174 mm
# s = 123.00 m, E = 1.698 GeV, R56 = -0.174 mm
# s = 124.33 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.33 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.36 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.42 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.45 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.50 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.54 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.54 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 126.43 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.43 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.46 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.52 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.58 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.58 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.63 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.63 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.70 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.70 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.74 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.78 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.78 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.82 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.86 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.92 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.95 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.95 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 127.51 m, E = 1.778 GeV, R56 = -0.177 mm
# s = 127.51 m, E = 1.778 GeV, R56 = -0.177 mm
# s = 127.51 m, E = 1.778 GeV, R56 = -0.177 mm
# s = 128.84 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 128.84 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 128.88 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 128.93 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 128.96 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 129.02 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 129.05 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 129.05 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 130.94 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 130.94 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 130.98 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.03 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.08 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.08 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.23 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.23 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.23 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.44 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.53 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.73 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.73 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.73 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.86 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.95 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 132.00 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 132.04 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 132.04 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 132.60 m, E = 1.857 GeV, R56 = -0.180 mm
# s = 132.60 m, E = 1.857 GeV, R56 = -0.180 mm
# s = 132.60 m, E = 1.857 GeV, R56 = -0.180 mm
# s = 133.93 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 133.93 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 133.96 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 134.02 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 134.05 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 134.10 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 134.14 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 134.14 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 136.03 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.03 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.06 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.12 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.18 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.18 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.23 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.23 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.30 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.30 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.34 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.38 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.38 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.46 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.52 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.55 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.55 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 137.11 m, E = 1.937 GeV, R56 = -0.182 mm
# s = 137.11 m, E = 1.937 GeV, R56 = -0.182 mm
# s = 137.11 m, E = 1.937 GeV, R56 = -0.182 mm
# s = 138.44 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.44 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.48 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.53 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.56 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.62 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.65 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.65 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 140.54 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.54 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.58 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.63 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.68 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.68 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.83 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.83 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.83 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.04 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.13 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.33 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.33 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.33 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.33 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.46 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.55 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.60 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.64 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.64 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 142.20 m, E = 2.016 GeV, R56 = -0.184 mm
# s = 142.20 m, E = 2.016 GeV, R56 = -0.184 mm
# s = 142.20 m, E = 2.016 GeV, R56 = -0.184 mm
# s = 143.53 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.53 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.56 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.62 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.65 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.70 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.74 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.74 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 145.63 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.63 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.66 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.72 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.78 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.78 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.83 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.83 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.90 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.90 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.94 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 146.06 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 146.12 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 146.15 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 146.15 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 146.71 m, E = 2.095 GeV, R56 = -0.187 mm
# s = 146.71 m, E = 2.095 GeV, R56 = -0.187 mm
# s = 146.71 m, E = 2.095 GeV, R56 = -0.187 mm
# s = 148.04 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.04 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.08 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.13 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.16 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.22 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.25 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.25 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 150.14 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.14 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.18 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.23 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.28 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.28 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.43 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.43 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.64 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.73 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.93 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.93 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.93 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.01 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.06 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.15 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.20 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.24 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.24 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.48 m, E = 2.167 GeV, R56 = -0.188 mm
# s = 151.48 m, E = 2.167 GeV, R56 = -0.188 mm
# s = 151.48 m, E = 2.167 GeV, R56 = -0.188 mm
# s = 153.13 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.13 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.16 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.22 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.25 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.30 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.34 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.34 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 155.23 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.23 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.26 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.32 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.38 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.38 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.43 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.43 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.50 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.50 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.54 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.66 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.72 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.75 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.75 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 156.31 m, E = 2.241 GeV, R56 = -0.190 mm
# s = 156.31 m, E = 2.241 GeV, R56 = -0.190 mm
# s = 156.31 m, E = 2.241 GeV, R56 = -0.190 mm
# s = 157.64 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.64 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.68 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.73 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.76 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.82 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.85 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.85 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 159.74 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.74 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.78 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.83 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.85 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.89 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.89 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.05 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.05 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.25 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.34 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.55 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.55 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.55 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.61 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.69 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.80 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.84 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.84 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 161.40 m, E = 2.311 GeV, R56 = -0.192 mm
# s = 161.40 m, E = 2.311 GeV, R56 = -0.192 mm
# s = 161.40 m, E = 2.311 GeV, R56 = -0.192 mm
# s = 162.72 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 162.72 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 162.76 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 162.90 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 162.93 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 162.93 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 164.82 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 164.82 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 164.86 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 164.90 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 164.94 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.00 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.00 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.05 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.05 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.12 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.12 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.16 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.20 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.31 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.35 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.35 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.91 m, E = 2.390 GeV, R56 = -0.194 mm
# s = 165.91 m, E = 2.390 GeV, R56 = -0.194 mm
# s = 165.91 m, E = 2.390 GeV, R56 = -0.194 mm
# s = 167.24 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 167.24 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 167.28 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 167.41 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 167.45 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 167.45 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 169.34 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.34 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.38 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.41 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.53 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.57 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.57 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.72 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.72 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.93 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.96 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.96 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.02 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.22 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.28 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.36 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.47 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.51 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.51 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 171.07 m, E = 2.468 GeV, R56 = -0.196 mm
# s = 171.07 m, E = 2.468 GeV, R56 = -0.196 mm
# s = 171.07 m, E = 2.468 GeV, R56 = -0.196 mm
# s = 172.39 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 172.39 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 172.43 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 172.57 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 172.60 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 172.60 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 174.49 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.49 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.53 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.57 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.61 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.67 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.67 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.72 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.72 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.79 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.79 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.83 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.87 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.98 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 175.02 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 175.02 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 176.91 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 176.91 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 176.95 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 177.08 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 177.12 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 177.12 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 178.77 m, E = 2.597 GeV, R56 = -0.198 mm
# s = 178.77 m, E = 2.597 GeV, R56 = -0.198 mm
# s = 178.77 m, E = 2.597 GeV, R56 = -0.198 mm
# s = 179.01 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.01 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.05 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.08 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.12 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.17 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.17 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.32 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.32 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.53 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.56 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.56 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.62 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.82 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 182.53 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 182.67 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 182.79 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 182.93 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 184.39 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 184.50 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 184.54 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 184.54 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 185.10 m, E = 2.611 GeV, R56 = -0.199 mm
# s = 185.10 m, E = 2.611 GeV, R56 = -0.199 mm
# s = 185.10 m, E = 2.611 GeV, R56 = -0.199 mm
# s = 186.42 m, E = 2.635 GeV, R56 = -0.199 mm
# s = 186.42 m, E = 2.635 GeV, R56 = -0.199 mm
# s = 186.46 m, E = 2.635 GeV, R56 = -0.199 mm
# s = 186.60 m, E = 2.635 GeV, R56 = -0.199 mm
# s = 186.63 m, E = 2.635 GeV, R56 = -0.199 mm
# s = 186.63 m, E = 2.635 GeV, R56 = -0.199 mm
# s = 188.52 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 188.52 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 188.56 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 188.60 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 188.65 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 188.73 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 188.78 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 188.86 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 188.86 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 188.90 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 189.01 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 189.05 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 189.05 m, E = 2.669 GeV, R56 = -0.200 mm
# s = 189.61 m, E = 2.679 GeV, R56 = -0.200 mm
# s = 190.94 m, E = 2.703 GeV, R56 = -0.200 mm
# s = 190.94 m, E = 2.703 GeV, R56 = -0.200 mm
# s = 190.98 m, E = 2.703 GeV, R56 = -0.200 mm
# s = 191.11 m, E = 2.703 GeV, R56 = -0.200 mm
# s = 191.15 m, E = 2.703 GeV, R56 = -0.200 mm
# s = 191.15 m, E = 2.703 GeV, R56 = -0.200 mm
# s = 193.04 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.04 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.08 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.11 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.15 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.19 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.19 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.35 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.35 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.55 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.64 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.85 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.91 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.96 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 193.96 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 194.21 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 194.29 m, E = 2.737 GeV, R56 = -0.201 mm
# s = 194.40 m, E = 2.737 GeV, R56 = -0.201 mm

# %%
# Your element IDs
start_id = "PJARCM1"
end_id   = "PSECTC"

# Find their indices in the lattice
start_index = next(i for i, el in enumerate(lattice_list) if el.id == start_id)
end_index   = next(i for i, el in enumerate(lattice_list) if el.id == end_id)

# Create the sub-lattice
partial_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

# Get s-positions of those indices
s_start = sum(el.l for el in lattice_list[:start_index])
s_end   = sum(el.l for el in lattice_list[:end_index + 1])
s_mid   = 0.5 * (s_start + s_end)

# Interpolate energy at midpoint
E_here = get_energy_at_s(s_mid, tws)

# Calculate R56
R = lattice_transfer_map(partial_lat, energy=E_here)
r56 = R[4, 5]

# Print result
print(f"R56 from '{start_id}' to '{end_id}' (s = {s_start:.2f} to {s_end:.2f} m, E ≈ {E_here:.3f} GeV): R56 = {r56*1000:.3f} mm")
# Out:
# R56 from 'PJARCM1' to 'PSECTC' (s = 76.00 to 112.80 m, E ≈ 1.528 GeV): R56 = -0.277 mm

# %%
def compute_r56_with_energy_evolution(lat_list, tws, id_start, id_end):
    # Find element indices
    i_start = next(i for i, el in enumerate(lat_list) if el.id == id_start)
    i_end   = next(i for i, el in enumerate(lat_list) if el.id == id_end)

    # Build the sub-lattice
    partial_lat = MagneticLattice(lat_list[i_start:i_end + 1])

    # Use starting energy from Twiss at i_start
    s_start = sum(e.l for e in lat_list[:i_start])
    E_start = get_energy_at_s(s_start, tws)

    # Compute transfer maps at every step (tracks energy changes!)
    Bs, Rs, Ts, Ss = partial_lat.transfer_maps(energy=E_start, output_at_each_step=True)

    # Get the last transfer matrix — full map from PJARCM1 to PSECTC
    R_final = Rs[-1]
    r56 = R_final[4, 5]

    s_end = s_start + sum(e.l for e in lat_list[i_start:i_end + 1])
    print(f"R56 from '{id_start}' to '{id_end}' (s = {s_start:.2f} → {s_end:.2f} m): R56 = {r56*1000:.3f} mm")

# %%
compute_r56_with_energy_evolution(lattice_list, tws, "PJARCM1", "PSECTC")
# Out:
# R56 from 'PJARCM1' to 'PSECTC' (s = 76.00 → 112.80 m): R56 = -0.277 mm
