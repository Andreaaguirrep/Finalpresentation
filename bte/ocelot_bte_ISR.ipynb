# %%
from ocelot import *
from ocelot.cpbd.elements import *
from ocelot.gui.accelerator import *
from ocelot.cpbd.track import track_debug
import matplotlib.pyplot as plt


from bte import *
# Out:
# initializing ocelot...

# %%
_logger = logging.getLogger(__name__)

class ISRBend(PhysProc):
    """
    Incoherent Synchrotron Radiation (ISR) effects in dipoles:
    - Classical energy loss
    - Quantum energy diffusion (causes emittance growth)
    """

    def __init__(self, radius, step=1):
        super().__init__(step=step)
        self.radius = radius  # bending radius [m]
        self.type = "dipole"
        self.energy_loss = True
        self.quant_diff = True
        self.filling_coeff = 1.0

    def apply(self, p_array, dz):
        if self.type != "dipole":
            raise ValueError("ISRBend only supports type='dipole'")

        _logger.debug("ISRBend (dipole ISR) applied")

        mean_p = np.mean(p_array.p())             # relative momentum
        energy = p_array.E * (1 + mean_p)         # total energy [GeV]
        gamma = energy / m_e_GeV

        rho = self.radius

        # --- Apply Quantum Diffusion (energy spread) ---
        if self.quant_diff:
            sigma_E = self.quantum_diffusion(gamma, dz, rho)  # [GeV]
            dE = sigma_E * np.random.randn(p_array.n)         # [GeV]
            p_array.p()[:] += dE / energy * self.filling_coeff  # relative momentum change

        # --- Apply Energy Loss (classical) ---
        if self.energy_loss:
            dE_loss = self.classical_energy_loss(energy, dz, rho)  # [GeV]
            p_array.p()[:] -= dE_loss / energy * self.filling_coeff

    def classical_energy_loss(self, E, ds, rho):
        """From PDG: dE/ds = Cγ/(2π) * E⁴ / ρ²"""
        C_gamma = 8.846e-5  # m/GeV³
        return (C_gamma / (2 * np.pi)) * (E ** 4) / (rho ** 2) * ds

    def quantum_diffusion(self, gamma, ds, rho):
        """σ_E² = (55 / 24√3) * λ_c * r_e * γ⁷ * ds / ρ³"""
        lambda_c = h_eV_s / (m_e_eV * speed_of_light)  # [m] ≈ 3.86e-13
        r_e = ro_e                                    # classical electron radius ≈ 2.82e-15 m

        const = 55 / (24 * np.sqrt(3))
        sigma_E2 = const * lambda_c * r_e * gamma ** 7 * ds / rho ** 3
        return np.sqrt(sigma_E2)  # [GeV]

# %%
#lat = MagneticLattice(lattice_list[0:380])
#lat = MagneticLattice(lattice_list[320:540])
lat = MagneticLattice(lattice_list)


energy = 7 # GeV  #why?
tw0 = Twiss()
tw0.alpha_x = AX
tw0.beta_x = BX

tw0.alpha_y = AY
tw0.beta_y = BY
tw0.E = energy
tw0.emit_xn = EMITX 
tw0.emit_yn = EMITY
tw0.emit_x = EMITX   / energy * 0.511e-3
tw0.emit_y = EMITY / energy * 0.511e-3

tws = twiss(lat,tw0)

plot_opt_func(lat, tws,legend=False, grid=False, top_plot=['Dx','Dy'])

# %%
# start_index = next(i for i, el in enumerate(lattice_list) if el.id == "PA1RFGUN")
# end_index = next(i for i, el in enumerate(lattice_list) if el.id == "L491")

# sub_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

# R = lattice_transfer_map(sub_lat, energy=1.5)
# print("R56 = ", R[4,5]*1000, "mm")

# %%
    def gauss_from_twiss_vec(emit, beta, alpha, size=1):
        phi = 2 * np.pi * np.random.rand(size)
        u = np.random.rand(size)
        a = np.sqrt(-2 * np.log(1 - u) * emit)
        x = a * np.sqrt(beta) * np.cos(phi)
        xp = -a / np.sqrt(beta) * (np.sin(phi) + alpha * np.cos(phi))
        return x, xp

    nparticles = 100000
    p_array = ParticleArray(n=nparticles)

    sigma_tau = 6.7e-3  # m
    sigma_p = 5.e-4     # relative momentum spread

    p_array.E = energy  # GeV

    # Longitudinal
    p_array.rparticles[4] = np.random.randn(nparticles) * sigma_tau
    p_array.rparticles[5] = np.random.randn(nparticles) * sigma_p

    # Transverse: vectorized sampling from Twiss parameters
    x, xp = gauss_from_twiss_vec(tw0.emit_x, tw0.beta_x, tw0.alpha_x, size=nparticles)
    y, yp = gauss_from_twiss_vec(tw0.emit_y, tw0.beta_y, tw0.alpha_y, size=nparticles)

    p_array.rparticles[0] = x
    p_array.rparticles[1] = xp
    p_array.rparticles[2] = y
    p_array.rparticles[3] = yp

    # Charge distribution
    charge = 4.0e-9  # nC
    p_array.q_array = np.ones(nparticles) * (charge / nparticles)

# %%
plt.hist(p_array.rparticles[0], bins=100, alpha=0.7, label='x')
plt.hist(p_array.rparticles[1], bins=100, alpha=0.7, label="x'")
plt.legend()
plt.show()

plt.hist(p_array.rparticles[2], bins=100, alpha=0.7, label='y')
plt.hist(p_array.rparticles[3], bins=100, alpha=0.7, label="y'")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
x = p_array.rparticles[0]
xp = p_array.rparticles[1]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_x, sigma_xp = twiss_sigmas(tw0.emit_x, tw0.beta_x, tw0.alpha_x)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='x (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='x (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="x′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_xp), 'r--', label="x′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of x and x′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
y = p_array.rparticles[2]
yp = p_array.rparticles[3]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_y, sigma_yp = twiss_sigmas(tw0.emit_y, tw0.beta_y, tw0.alpha_y)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='y (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='y (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="y′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_yp), 'r--', label="y′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of y and y′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def check_beam_stats(p_array, twiss, axis_label="x"):
    idx = 0 if axis_label == "x" else 2
    idxp = 1 if axis_label == "x" else 3

    sigma = np.std(p_array.rparticles[idx])
    sigmap = np.std(p_array.rparticles[idxp])

    beta = getattr(twiss, f"beta_{axis_label}")
    alpha = getattr(twiss, f"alpha_{axis_label}")
    emit = getattr(twiss, f"emit_{axis_label}")

    sigma_theo = np.sqrt(beta * emit)
    gamma = (1 + alpha**2) / beta
    sigmap_theo = np.sqrt(gamma * emit)

    print(f"σ_{axis_label} (simulated):     {sigma}")
    print(f"σ_{axis_label} (theoretical):   {sigma_theo}")
    print(f"σ_{axis_label}' (simulated):    {sigmap}")
    print(f"σ_{axis_label}' (theoretical):  {sigmap_theo}")

# %%
check_beam_stats(p_array, tw0, axis_label="x")
# Out:
# σ_x (simulated):     4.298738999599284e-05
# σ_x (theoretical):   4.291163367644033e-05
# σ_x' (simulated):    2.9347490820502235e-06
# σ_x' (theoretical):  2.92787645355913e-06

# %%
check_beam_stats(p_array, tw0, axis_label="y")
# Out:
# σ_y (simulated):     3.986413600517955e-05
# σ_y (theoretical):   3.99447953007678e-05
# σ_y' (simulated):    2.3527519663839962e-06
# σ_y' (theoretical):  2.3535278848054194e-06

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- X plane ---
x = p_array.rparticles[0]
xp = p_array.rparticles[1]
emit_x = tw0.emit_x
beta_x = tw0.beta_x
alpha_x = tw0.alpha_x

theta = np.linspace(0, 2*np.pi, 400)
x_ellipse = np.sqrt(emit_x * beta_x) * np.cos(theta)
xp_ellipse = (-alpha_x * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_x / beta_x)

# --- Y plane ---
y = p_array.rparticles[2]
yp = p_array.rparticles[3]
emit_y = tw0.emit_y
beta_y = tw0.beta_y
alpha_y = tw0.alpha_y

y_ellipse = np.sqrt(emit_y * beta_y) * np.cos(theta)
yp_ellipse = (-alpha_y * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_y / beta_y)

# --- Plot ---
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# x-x'
axes[0].scatter(x, xp, s=1, alpha=0.3, label='Particles')
axes[0].plot(x_ellipse, xp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[0].set_xlabel('x [m]')
axes[0].set_ylabel("x′ [rad]")
axes[0].set_title('Phase space: x vs x′')
axes[0].grid(True)
axes[0].axis('equal')
axes[0].legend()

# y-y'
axes[1].scatter(y, yp, s=1, alpha=0.3, color='orange', label='Particles')
axes[1].plot(y_ellipse, yp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[1].set_xlabel('y [m]')
axes[1].set_ylabel("y′ [rad]")
axes[1].set_title('Phase space: y vs y′')
axes[1].grid(True)
axes[1].axis('equal')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy

def plot_emittances_vs_s(p_array, nparts_in_slice=5000, smooth_param=0.05,
                         tau_units="m", inverse_tau=False, grid=True,
                         title="Normalized Emittances vs s", figsize=(8, 4),
                         filename=None):
    """
    Plot normalized emittances vs longitudinal position s (head-tail slicing).

    :param p_array: ParticleArray object
    :param nparts_in_slice: number of particles per slice
    :param smooth_param: smoothing parameter used in slice analysis
    :param tau_units: 'm', 'mm', or 'um'
    :param inverse_tau: flip the tau axis
    :param grid: show grid
    :param title: plot title
    :param figsize: matplotlib figsize
    :param filename: optional path to save the plot
    """
    # Set scale for s-axis
    tau_factors = {"m": 1, "mm": 1e3, "um": 1e6}
    tau_factor = tau_factors.get(tau_units, 1e3)
    tau_label = f"$s\,[\\mathrm{{{tau_units}}}]$"

    # Deepcopy to preserve original
    p_array_copy = deepcopy(p_array)
    if inverse_tau:
        p_array_copy.tau()[:] *= -1

    # Perform slice analysis (assumes this function exists in your codebase)
    slice_params = global_slice_analysis(p_array_copy, nparts_in_slice, smooth_param)

    # Extract and convert to proper units
    s = slice_params.s * tau_factor
    emit_x = slice_params.exn * 1e6  # [mm·mrad]
    emit_y = slice_params.eyn * 1e6

    # Plot
    plt.figure(figsize=figsize)
    plt.plot(s, emit_x, label=r"$\varepsilon_x$", color='red')
    plt.plot(s, emit_y, label=r"$\varepsilon_y$", color='blue')
    plt.xlabel(tau_label)
    plt.ylabel(r"Normalized Emittance [$\mathrm{mm\cdot{}mrad}$]")
    plt.title(title)
    plt.legend()
    if grid:
        plt.grid(True)
    if filename:
        plt.savefig(filename)
    plt.tight_layout()
    plt.show()

# %%
show_e_beam(p_array)

# %%
plot_emittances_vs_s(p_array)

# %%
import time
navi = Navigator(lat)
navi.unit_step = 0.1 # m, only with CSR

for i in range(len(lat.sequence)-1):
    elem = lat.sequence[i]
    if isinstance(elem, SBend):
        # Estimate local bending radius
        if abs(elem.angle) > 0:
            rho = elem.l / abs(elem.angle)
            isr_proc = ISRBend(radius=rho)
            navi.add_physics_proc(isr_proc, elem, lat.sequence[i+1])


            print(elem.l,"rho=" ,rho)


p_array_t = deepcopy(p_array)
start = time.time()
tws_track, p_array_t = track_debug(lat, p_array_t, navi)
print("\n time exec:", time.time() - start, "sec")

show_e_beam(p_array_t)
# Out:
# 1.5361042457936593 rho= 16.361050285083245
# 1.81222 rho= 94.05668599377697
# 1.5491873961201 rho= 20.76086588894663
# 1.9060111581781 rho= 25.74722529536083
# 1.9060111581781 rho= 25.74722529536083
# 2.0340137 rho= 19.98198551849364
# 1.9060111581781 rho= 25.74722529536083
# 1.9060111581781 rho= 25.74722529536083
# 2.0340137 rho= 19.98198551849364
# 2.0340137 rho= 19.98198551849364
# 2.0340137 rho= 19.98198551849364
# 2.0340137 rho= 19.98198551849364
# 2.0340137 rho= 19.98198551849364
# 2.0856319020778 rho= 28.972582626548327
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.078583912105 rho= 21.571978536556724
# 2.0834231922962 rho= 22.84561956369299
# 2.0834231922962 rho= 22.84561956369299
# 2.0834231922962 rho= 22.84561956369299
# 2.0834231922962 rho= 22.84561956369299
# 2.0834231922962 rho= 22.84561956369299
# 2.0834231922962 rho= 22.84561956369299
# 2.0834231922962 rho= 22.84561956369299
# 2.0834231922962 rho= 22.84561956369299
# 2.0834231922962 rho= 22.84561956369299
# 2.2921703908216 rho= 22.522435641602605
# 2.2921703908216 rho= 22.522435641602605
# 2.2921703908216 rho= 22.522435641602605
# 2.2921703908216 rho= 22.522435641602605
# 2.2921703908216 rho= 22.522435641602605
# 2.2921703908216 rho= 22.522435641602605
# 2.2921703908216 rho= 22.522435641602605
# 2.2921703908216 rho= 22.522435641602605
# 2.2921703908216 rho= 22.522435641602605
# 2.2921703908216 rho= 22.522435641602605
# 1.9060190663188 rho= 25.500686914134153
# 1.9060190663188 rho= 25.500686914134153
# 1.9060190663188 rho= 25.500686914134153
# 1.9060190663188 rho= 25.500686914134153
# 1.8126044257406 rho= 25.229504469344747
# 1.8126044257406 rho= 25.229504469344747
# 1.8126044257406 rho= 25.229504469344747
# 1.8126044257406 rho= 25.229504469344747
# 1.8126044257406 rho= 25.229504469344747
# 1.8126044257406 rho= 25.229504469344747
# 1.8126044257406 rho= 25.229504469344747
# 1.8126044257406 rho= 25.229504469344747
# 1.8126044257406 rho= 25.229504469344747
# 1.813369682202 rho= 25.316164676186254
# 1.813369682202 rho= 25.316164676186254
# 1.0000585961533 rho= 26.668229230754665
# 1.0000585961533 rho= 26.668229230754665
# 1.0000585961533 rho= 28.290200739838756
# 1.0002344134579 rho= 25.328802569204864
# ⚠️ Skipping zero-step at z = 0.000000, element = LL3478E
#
# [Step 2/4666] z = 0.217, Element: BC1P, dz = 0.217
#   ✔ Applied TM: TransferMap, len = 0.217, time = 0.0014s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0011s
# z = 0.217 / 466.604 m → PhysProcs: None
# [Step 3/4666] z = 0.317, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0050s
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0015s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0021s
# z = 0.317 / 466.604 m → PhysProcs: ISRBend
# [Step 4/4666] z = 0.417, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0013s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 0.417 / 466.604 m → PhysProcs: ISRBend
# [Step 5/4666] z = 0.517, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0051s
# z = 0.517 / 466.604 m → PhysProcs: ISRBend
# [Step 6/4666] z = 0.617, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0022s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
# z = 0.617 / 466.604 m → PhysProcs: ISRBend
# [Step 7/4666] z = 0.717, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0024s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0058s
# z = 0.717 / 466.604 m → PhysProcs: ISRBend
# [Step 8/4666] z = 0.817, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0057s
# z = 0.817 / 466.604 m → PhysProcs: ISRBend
# [Step 9/4666] z = 0.917, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0012s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 0.917 / 466.604 m → PhysProcs: ISRBend
# [Step 10/4666] z = 1.017, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0010s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 1.017 / 466.604 m → PhysProcs: ISRBend
# [Step 11/4666] z = 1.117, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0022s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0056s
# z = 1.117 / 466.604 m → PhysProcs: ISRBend
# [Step 12/4666] z = 1.217, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0023s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0053s
# z = 1.217 / 466.604 m → PhysProcs: ISRBend
# [Step 13/4666] z = 1.317, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
# z = 1.317 / 466.604 m → PhysProcs: ISRBend
# [Step 14/4666] z = 1.417, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0023s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
# z = 1.417 / 466.604 m → PhysProcs: ISRBend
# [Step 15/4666] z = 1.517, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0030s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 1.517 / 466.604 m → PhysProcs: ISRBend
# [Step 16/4666] z = 1.617, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 1.617 / 466.604 m → PhysProcs: ISRBend
# [Step 17/4666] z = 1.717, Element: BC1P, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0057s
# z = 1.717 / 466.604 m → PhysProcs: ISRBend
# [Step 18/4666] z = 1.753, Element: LDMP1A, dz = 0.036
#   ✔ Applied TM: TransferMap, len = 1.536, time = 0.0012s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0010s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.036104245793658674
#     ✔ Done in 0.0019s
# z = 1.753 / 466.604 m → PhysProcs: ISRBend
# [Step 19/4666] z = 3.536, Element: BH0E, dz = 1.783
#   ✔ Applied TM: TransferMap, len = 1.783, time = 0.0012s
# z = 3.536 / 466.604 m → PhysProcs: None
# [Step 20/4666] z = 4.116, Element: LMBLH, dz = 0.580
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0020s
#   ✔ Applied TM: TransferMap, len = 0.580, time = 0.0020s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0012s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0012s
# z = 4.116 / 466.604 m → PhysProcs: None
# [Step 21/4666] z = 4.241, Element: LMBLH, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0019s
# z = 4.241 / 466.604 m → PhysProcs: None
# [Step 22/4666] z = 4.366, Element: LDMP1B, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0020s
# z = 4.366 / 466.604 m → PhysProcs: None
# [Step 23/4666] z = 4.996, Element: LPMH, dz = 0.630
#   ✔ Applied TM: TransferMap, len = 0.630, time = 0.0039s
# z = 4.996 / 466.604 m → PhysProcs: None
# [Step 24/4666] z = 5.096, Element: LPMH, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.100, time = 0.0020s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0028s
# z = 5.096 / 466.604 m → PhysProcs: None
# [Step 25/4666] z = 5.196, Element: LBLCC, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.100, time = 0.0025s
# z = 5.196 / 466.604 m → PhysProcs: None
# [Step 26/4666] z = 5.420, Element: BHD0, dz = 0.224
#   ✔ Applied TM: TransferMap, len = 0.224, time = 0.0026s
# z = 5.420 / 466.604 m → PhysProcs: None
# [Step 27/4666] z = 5.520, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0018s
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0060s
# z = 5.520 / 466.604 m → PhysProcs: ISRBend
# [Step 28/4666] z = 5.620, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0014s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
# z = 5.620 / 466.604 m → PhysProcs: ISRBend
# [Step 29/4666] z = 5.720, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 5.720 / 466.604 m → PhysProcs: ISRBend
# [Step 30/4666] z = 5.820, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 5.820 / 466.604 m → PhysProcs: ISRBend
# [Step 31/4666] z = 5.920, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0014s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
# z = 5.920 / 466.604 m → PhysProcs: ISRBend
# [Step 32/4666] z = 6.020, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0056s
# z = 6.020 / 466.604 m → PhysProcs: ISRBend
# [Step 33/4666] z = 6.120, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
# z = 6.120 / 466.604 m → PhysProcs: ISRBend
# [Step 34/4666] z = 6.220, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0022s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0059s
# z = 6.220 / 466.604 m → PhysProcs: ISRBend
# [Step 35/4666] z = 6.320, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0016s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 6.320 / 466.604 m → PhysProcs: ISRBend
# [Step 36/4666] z = 6.420, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0023s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0060s
# z = 6.420 / 466.604 m → PhysProcs: ISRBend
# [Step 37/4666] z = 6.520, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 6.520 / 466.604 m → PhysProcs: ISRBend
# [Step 38/4666] z = 6.620, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0023s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 6.620 / 466.604 m → PhysProcs: ISRBend
# [Step 39/4666] z = 6.720, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0046s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 6.720 / 466.604 m → PhysProcs: ISRBend
# [Step 40/4666] z = 6.820, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0056s
# z = 6.820 / 466.604 m → PhysProcs: ISRBend
# [Step 41/4666] z = 6.920, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 6.920 / 466.604 m → PhysProcs: ISRBend
# [Step 42/4666] z = 7.020, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 7.020 / 466.604 m → PhysProcs: ISRBend
# [Step 43/4666] z = 7.120, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 7.120 / 466.604 m → PhysProcs: ISRBend
# [Step 44/4666] z = 7.220, Element: BHD0, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 7.220 / 466.604 m → PhysProcs: ISRBend
# [Step 45/4666] z = 7.232, Element: LCE0A, dz = 0.012
#   ✔ Applied TM: TransferMap, len = 1.812, time = 0.0023s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0027s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.012220000000007225
#     ✔ Done in 0.0047s
# z = 7.232 / 466.604 m → PhysProcs: ISRBend
# [Step 46/4666] z = 9.366, Element: LMBLH, dz = 2.134
#   ✔ Applied TM: TransferMap, len = 2.134, time = 0.0018s
# z = 9.366 / 466.604 m → PhysProcs: None
# [Step 47/4666] z = 9.491, Element: LMBLH, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0018s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0021s
# z = 9.491 / 466.604 m → PhysProcs: None
# [Step 48/4666] z = 9.616, Element: LQMD, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0020s
# z = 9.616 / 466.604 m → PhysProcs: None
# [Step 49/4666] z = 9.723, Element: QX1E, dz = 0.107
#   ✔ Applied TM: TransferMap, len = 0.107, time = 0.0018s
# z = 9.723 / 466.604 m → PhysProcs: None
# [Step 50/4666] z = 10.248, Element: LQZ, dz = 0.525
#   ✔ Applied TM: TransferMap, len = 0.525, time = 0.0020s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0018s
# z = 10.248 / 466.604 m → PhysProcs: None
# [Step 51/4666] z = 10.436, Element: HX01E, dz = 0.187
#   ✔ Applied TM: TransferMap, len = 0.187, time = 0.0047s
# z = 10.436 / 466.604 m → PhysProcs: None
# [Step 52/4666] z = 10.636, Element: LCE01A, dz = 0.200
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0020s
#   ✔ Applied TM: TransferMap, len = 0.200, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
# z = 10.636 / 466.604 m → PhysProcs: None
# [Step 53/4666] z = 10.710, Element: LD300, dz = 0.074
#   ✔ Applied TM: TransferMap, len = 0.074, time = 0.0022s
# z = 10.710 / 466.604 m → PhysProcs: None
# [Step 54/4666] z = 11.010, Element: LCE01A, dz = 0.300
#   ✔ Applied TM: TransferMap, len = 0.300, time = 0.0026s
# z = 11.010 / 466.604 m → PhysProcs: None
# [Step 55/4666] z = 11.084, Element: VX01E, dz = 0.074
#   ✔ Applied TM: TransferMap, len = 0.074, time = 0.0013s
# z = 11.084 / 466.604 m → PhysProcs: None
# [Step 56/4666] z = 11.284, Element: LQZ, dz = 0.200
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0035s
#   ✔ Applied TM: TransferMap, len = 0.200, time = 0.0020s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
# z = 11.284 / 466.604 m → PhysProcs: None
# [Step 57/4666] z = 11.472, Element: QX2E, dz = 0.187
#   ✔ Applied TM: TransferMap, len = 0.187, time = 0.0017s
# z = 11.472 / 466.604 m → PhysProcs: None
# [Step 58/4666] z = 11.997, Element: LQMD, dz = 0.525
#   ✔ Applied TM: TransferMap, len = 0.525, time = 0.0035s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
# z = 11.997 / 466.604 m → PhysProcs: None
# [Step 59/4666] z = 12.104, Element: LMBLH, dz = 0.107
#   ✔ Applied TM: TransferMap, len = 0.107, time = 0.0019s
# z = 12.104 / 466.604 m → PhysProcs: None
# [Step 60/4666] z = 12.229, Element: LMBLH, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0018s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0020s
# z = 12.229 / 466.604 m → PhysProcs: None
# [Step 61/4666] z = 12.354, Element: LCE1A, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0021s
# z = 12.354 / 466.604 m → PhysProcs: None
# [Step 62/4666] z = 13.417, Element: LPMH, dz = 1.063
#   ✔ Applied TM: TransferMap, len = 1.063, time = 0.0011s
# z = 13.417 / 466.604 m → PhysProcs: None
# [Step 63/4666] z = 13.517, Element: LPMH, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.100, time = 0.0023s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0021s
# z = 13.517 / 466.604 m → PhysProcs: None
# [Step 64/4666] z = 13.617, Element: LBELL, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.100, time = 0.0029s
# z = 13.617 / 466.604 m → PhysProcs: None
# [Step 65/4666] z = 13.707, Element: LBLCD, dz = 0.090
#   ✔ Applied TM: TransferMap, len = 0.090, time = 0.0023s
# z = 13.707 / 466.604 m → PhysProcs: None
# [Step 66/4666] z = 13.924, Element: B0E, dz = 0.216
#   ✔ Applied TM: TransferMap, len = 0.216, time = 0.0018s
# z = 13.924 / 466.604 m → PhysProcs: None
# [Step 67/4666] z = 14.024, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0024s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0053s
# z = 14.024 / 466.604 m → PhysProcs: ISRBend
# [Step 68/4666] z = 14.124, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0070s
# z = 14.124 / 466.604 m → PhysProcs: ISRBend
# [Step 69/4666] z = 14.224, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0035s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0022s
# z = 14.224 / 466.604 m → PhysProcs: ISRBend
# [Step 70/4666] z = 14.324, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0026s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0056s
# z = 14.324 / 466.604 m → PhysProcs: ISRBend
# [Step 71/4666] z = 14.424, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0027s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0058s
# z = 14.424 / 466.604 m → PhysProcs: ISRBend
# [Step 72/4666] z = 14.524, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0025s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 14.524 / 466.604 m → PhysProcs: ISRBend
# [Step 73/4666] z = 14.624, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0025s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 14.624 / 466.604 m → PhysProcs: ISRBend
# [Step 74/4666] z = 14.724, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0039s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0026s
# z = 14.724 / 466.604 m → PhysProcs: ISRBend
# [Step 75/4666] z = 14.824, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0012s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
# z = 14.824 / 466.604 m → PhysProcs: ISRBend
# [Step 76/4666] z = 14.924, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0012s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 14.924 / 466.604 m → PhysProcs: ISRBend
# [Step 77/4666] z = 15.024, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0025s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0019s
# z = 15.024 / 466.604 m → PhysProcs: ISRBend
# [Step 78/4666] z = 15.124, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0024s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0057s
# z = 15.124 / 466.604 m → PhysProcs: ISRBend
# [Step 79/4666] z = 15.224, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0027s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0021s
# z = 15.224 / 466.604 m → PhysProcs: ISRBend
# [Step 80/4666] z = 15.324, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 15.324 / 466.604 m → PhysProcs: ISRBend
# [Step 81/4666] z = 15.424, Element: B0E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0035s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0069s
# z = 15.424 / 466.604 m → PhysProcs: ISRBend
# [Step 82/4666] z = 15.473, Element: LCE2A1, dz = 0.049
#   ✔ Applied TM: TransferMap, len = 1.549, time = 0.0022s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0018s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0027s
#   → Applying PhysProc: ISRBend, z_step = 0.049187396120105475
#     ✔ Done in 0.0018s
# z = 15.473 / 466.604 m → PhysProcs: ISRBend
# [Step 83/4666] z = 15.839, Element: HX02E, dz = 0.366
#   ✔ Applied TM: TransferMap, len = 0.366, time = 0.0023s
# z = 15.839 / 466.604 m → PhysProcs: None
# [Step 84/4666] z = 16.039, Element: LD260, dz = 0.200
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0022s
#   ✔ Applied TM: TransferMap, len = 0.200, time = 0.0035s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
# z = 16.039 / 466.604 m → PhysProcs: None
# [Step 85/4666] z = 16.299, Element: LQMC, dz = 0.260
#   ✔ Applied TM: TransferMap, len = 0.260, time = 0.0018s
# z = 16.299 / 466.604 m → PhysProcs: None
# [Step 86/4666] z = 16.406, Element: QX3E, dz = 0.107
#   ✔ Applied TM: TransferMap, len = 0.107, time = 0.0021s
# z = 16.406 / 466.604 m → PhysProcs: None
# [Step 87/4666] z = 16.782, Element: LQMC, dz = 0.376
#   ✔ Applied TM: TransferMap, len = 0.376, time = 0.0018s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0023s
# z = 16.782 / 466.604 m → PhysProcs: None
# [Step 88/4666] z = 16.889, Element: LMBLH, dz = 0.107
#   ✔ Applied TM: TransferMap, len = 0.107, time = 0.0038s
# z = 16.889 / 466.604 m → PhysProcs: None
# [Step 89/4666] z = 17.014, Element: LMBLH, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0112s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0013s
# z = 17.014 / 466.604 m → PhysProcs: None
# [Step 90/4666] z = 17.139, Element: LBVQXA, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0019s
# z = 17.139 / 466.604 m → PhysProcs: None
# [Step 91/4666] z = 17.416, Element: BV1UE, dz = 0.277
#   ✔ Applied TM: TransferMap, len = 0.277, time = 0.0019s
# z = 17.416 / 466.604 m → PhysProcs: None
# [Step 92/4666] z = 17.516, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0031s
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0060s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0043s
# z = 17.516 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 93/4666] z = 17.616, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0036s
# z = 17.616 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 94/4666] z = 17.716, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 17.716 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 95/4666] z = 17.816, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0031s
# z = 17.816 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 96/4666] z = 17.916, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0029s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0022s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 17.916 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 97/4666] z = 18.016, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0048s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0043s
# z = 18.016 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 98/4666] z = 18.116, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0026s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0051s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 18.116 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 99/4666] z = 18.216, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0028s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0043s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0047s
# z = 18.216 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 100/4666] z = 18.316, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 18.316 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 101/4666] z = 18.416, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0011s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 18.416 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 102/4666] z = 18.516, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0011s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 18.516 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 103/4666] z = 18.616, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0023s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0028s
# z = 18.616 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 104/4666] z = 18.716, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0048s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 18.716 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 105/4666] z = 18.816, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0060s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0025s
# z = 18.816 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 106/4666] z = 18.916, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0025s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0061s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0039s
# z = 18.916 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 107/4666] z = 19.016, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0028s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0019s
# z = 19.016 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 108/4666] z = 19.116, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0012s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0041s
# z = 19.116 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 109/4666] z = 19.216, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0045s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0019s
# z = 19.216 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 110/4666] z = 19.316, Element: BV1UE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0011s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 19.316 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 111/4666] z = 19.322, Element: LBLC, dz = 0.006
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0021s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.006011158178072407
#     ✔ Done in 0.0038s
#   → Applying PhysProc: ISRBend, z_step = 0.006011158178072407
#     ✔ Done in 0.0017s
# z = 19.322 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 112/4666] z = 19.509, Element: LBELL, dz = 0.187
#   ✔ Applied TM: TransferMap, len = 0.187, time = 0.0034s
# z = 19.509 / 466.604 m → PhysProcs: None
# [Step 113/4666] z = 19.599, Element: LD500, dz = 0.090
#   ✔ Applied TM: TransferMap, len = 0.090, time = 0.0018s
# z = 19.599 / 466.604 m → PhysProcs: None
# [Step 114/4666] z = 20.099, Element: LBVA, dz = 0.500
#   ✔ Applied TM: TransferMap, len = 0.500, time = 0.0020s
# z = 20.099 / 466.604 m → PhysProcs: None
# [Step 115/4666] z = 21.472, Element: BV1DE, dz = 1.372
#   ✔ Applied TM: TransferMap, len = 1.372, time = 0.0017s
# z = 21.472 / 466.604 m → PhysProcs: None
# [Step 116/4666] z = 21.572, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0020s
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0052s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 21.572 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 117/4666] z = 21.672, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0033s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 21.672 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 118/4666] z = 21.772, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0057s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
# z = 21.772 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 119/4666] z = 21.872, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0030s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 21.872 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 120/4666] z = 21.972, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0035s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 21.972 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 121/4666] z = 22.072, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0043s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0071s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
# z = 22.072 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 122/4666] z = 22.172, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0015s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 22.172 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 123/4666] z = 22.272, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0035s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 22.272 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 124/4666] z = 22.372, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 22.372 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 125/4666] z = 22.472, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0034s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0022s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 22.472 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 126/4666] z = 22.572, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0029s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0101s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0024s
# z = 22.572 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 127/4666] z = 22.672, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0040s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 22.672 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 128/4666] z = 22.772, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0088s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0027s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 22.772 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 129/4666] z = 22.872, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0053s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 22.872 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 130/4666] z = 22.972, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0028s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0062s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0052s
# z = 22.972 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 131/4666] z = 23.072, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0056s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0026s
# z = 23.072 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 132/4666] z = 23.172, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0057s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0038s
# z = 23.172 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 133/4666] z = 23.272, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0026s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 23.272 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 134/4666] z = 23.372, Element: BV1DE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0026s
# z = 23.372 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 135/4666] z = 23.378, Element: LBQX2, dz = 0.006
#   ✔ Applied TM: TransferMap, len = 1.906, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0022s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.006011158178072407
#     ✔ Done in 0.0034s
#   → Applying PhysProc: ISRBend, z_step = 0.006011158178072407
#     ✔ Done in 0.0018s
# z = 23.378 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 136/4666] z = 23.812, Element: QX4E, dz = 0.434
#   ✔ Applied TM: TransferMap, len = 0.434, time = 0.0018s
# z = 23.812 / 466.604 m → PhysProcs: None
# [Step 137/4666] z = 24.188, Element: LQMC, dz = 0.376
#   ✔ Applied TM: TransferMap, len = 0.376, time = 0.0018s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
# z = 24.188 / 466.604 m → PhysProcs: None
# [Step 138/4666] z = 24.295, Element: LMBLH, dz = 0.107
#   ✔ Applied TM: TransferMap, len = 0.107, time = 0.0019s
# z = 24.295 / 466.604 m → PhysProcs: None
# [Step 139/4666] z = 24.420, Element: LMBLH, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0021s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0018s
# z = 24.420 / 466.604 m → PhysProcs: None
# [Step 140/4666] z = 24.545, Element: LCE21, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0029s
# z = 24.545 / 466.604 m → PhysProcs: None
# [Step 141/4666] z = 26.037, Element: LPMLH, dz = 1.492
#   ✔ Applied TM: TransferMap, len = 1.492, time = 0.0020s
# z = 26.037 / 466.604 m → PhysProcs: None
# [Step 142/4666] z = 26.162, Element: LPMLH, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0026s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0028s
# z = 26.162 / 466.604 m → PhysProcs: None
# [Step 143/4666] z = 26.287, Element: LD350, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0025s
# z = 26.287 / 466.604 m → PhysProcs: None
# [Step 144/4666] z = 26.637, Element: HX03E, dz = 0.350
#   ✔ Applied TM: TransferMap, len = 0.350, time = 0.0020s
# z = 26.637 / 466.604 m → PhysProcs: None
# [Step 145/4666] z = 26.837, Element: LMZ, dz = 0.200
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0026s
#   ✔ Applied TM: TransferMap, len = 0.200, time = 0.0027s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
# z = 26.837 / 466.604 m → PhysProcs: None
# [Step 146/4666] z = 26.937, Element: LMBLH, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.100, time = 0.0026s
# z = 26.937 / 466.604 m → PhysProcs: None
# [Step 147/4666] z = 27.062, Element: LMBLH, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0052s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0018s
# z = 27.062 / 466.604 m → PhysProcs: None
# [Step 148/4666] z = 27.187, Element: LQMC, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0049s
# z = 27.187 / 466.604 m → PhysProcs: None
# [Step 149/4666] z = 27.294, Element: QX5E, dz = 0.107
#   ✔ Applied TM: TransferMap, len = 0.107, time = 0.0025s
# z = 27.294 / 466.604 m → PhysProcs: None
# [Step 150/4666] z = 27.670, Element: LBQX0, dz = 0.376
#   ✔ Applied TM: TransferMap, len = 0.376, time = 0.0011s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0010s
# z = 27.670 / 466.604 m → PhysProcs: None
# [Step 151/4666] z = 28.216, Element: B1E, dz = 0.545
#   ✔ Applied TM: TransferMap, len = 0.545, time = 0.0029s
# z = 28.216 / 466.604 m → PhysProcs: None
# [Step 152/4666] z = 28.316, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0033s
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0037s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0026s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0028s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 28.316 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 153/4666] z = 28.416, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0028s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0066s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0034s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0029s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 28.416 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 154/4666] z = 28.516, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0022s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0059s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0056s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0033s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0057s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0052s
# z = 28.516 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 155/4666] z = 28.616, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0024s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 28.616 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 156/4666] z = 28.716, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0023s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0029s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0022s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 28.716 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 157/4666] z = 28.816, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0025s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0060s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0026s
# z = 28.816 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 158/4666] z = 28.916, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0013s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0051s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0041s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0052s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0053s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 28.916 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 159/4666] z = 29.016, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0075s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0059s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0053s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0048s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 29.016 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 160/4666] z = 29.116, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0021s
# z = 29.116 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 161/4666] z = 29.216, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0062s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0039s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 29.216 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 162/4666] z = 29.316, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0056s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0037s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0088s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 29.316 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 163/4666] z = 29.416, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0023s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0048s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0034s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0046s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0051s
# z = 29.416 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 164/4666] z = 29.516, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0045s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0056s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0023s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0023s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0075s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0060s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0065s
# z = 29.516 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 165/4666] z = 29.616, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0032s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0029s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0052s
# z = 29.616 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 166/4666] z = 29.716, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0011s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0053s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0026s
# z = 29.716 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 167/4666] z = 29.816, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0032s
# z = 29.816 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 168/4666] z = 29.916, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0042s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0046s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0038s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 29.916 / 466.604 m → PhysProcs: ISRBend, ISRBend, ISRBend, ISRBend, ISRBend, ISRBend
# [Step 169/4666] z = 30.016, Element: B1E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 2.034, time = 0.0016s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0022s
#   → Applying PhysProc: ISRBend, z_step = 0.1
# ...
#     ✔ Done in 0.0059s
# z = 455.674 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 920/4666] z = 455.774, Element: BH4AE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.813, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0056s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0052s
# z = 455.774 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 921/4666] z = 455.874, Element: BH4AE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.813, time = 0.0033s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 455.874 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 922/4666] z = 455.974, Element: BH4AE, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.813, time = 0.0012s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0025s
# z = 455.974 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 923/4666] z = 455.987, Element: LMBBHC, dz = 0.013
#   ✔ Applied TM: TransferMap, len = 1.813, time = 0.0032s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0020s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.013369682201528121
#     ✔ Done in 0.0073s
#   → Applying PhysProc: ISRBend, z_step = 0.013369682201528121
#     ✔ Done in 0.0019s
# z = 455.987 / 466.604 m → PhysProcs: ISRBend, ISRBend
# [Step 924/4666] z = 456.373, Element: BH4AE, dz = 0.386
#   ✔ Applied TM: TransferMap, len = 0.386, time = 0.0043s
# z = 456.373 / 466.604 m → PhysProcs: None
# [Step 925/4666] z = 458.186, Element: LM4F1, dz = 1.813
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0028s
#   ✔ Applied TM: TransferMap, len = 1.813, time = 0.0020s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0018s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0017s
# z = 458.186 / 466.604 m → PhysProcs: None
# [Step 926/4666] z = 458.489, Element: LD100, dz = 0.303
#   ✔ Applied TM: TransferMap, len = 0.303, time = 0.0020s
# z = 458.489 / 466.604 m → PhysProcs: None
# [Step 927/4666] z = 458.589, Element: VM28E, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.100, time = 0.0015s
# z = 458.589 / 466.604 m → PhysProcs: None
# [Step 928/4666] z = 458.789, Element: LQZ, dz = 0.200
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0023s
#   ✔ Applied TM: TransferMap, len = 0.200, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0027s
# z = 458.789 / 466.604 m → PhysProcs: None
# [Step 929/4666] z = 458.977, Element: QMD10E, dz = 0.187
#   ✔ Applied TM: TransferMap, len = 0.187, time = 0.0082s
# z = 458.977 / 466.604 m → PhysProcs: None
# [Step 930/4666] z = 459.502, Element: LQMD, dz = 0.525
#   ✔ Applied TM: TransferMap, len = 0.525, time = 0.0021s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0052s
# z = 459.502 / 466.604 m → PhysProcs: None
# [Step 931/4666] z = 459.609, Element: LMBLH, dz = 0.107
#   ✔ Applied TM: TransferMap, len = 0.107, time = 0.0048s
# z = 459.609 / 466.604 m → PhysProcs: None
# [Step 932/4666] z = 459.734, Element: LMBLH, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0067s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0272s
# z = 459.734 / 466.604 m → PhysProcs: None
# [Step 933/4666] z = 459.859, Element: LMI2, dz = 0.125
#   ✔ Applied TM: TransferMap, len = 0.125, time = 0.0011s
#   ✔ Applied TM: TransferMap, len = -0.118, time = 0.0010s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0009s
#   ✔ Applied TM: TransferMap, len = 0.220, time = 0.0011s
# z = 459.859 / 466.604 m → PhysProcs: None
# [Step 934/4666] z = 459.962, Element: LMI3, dz = 0.102
#   ✔ Applied TM: TransferMap, len = 0.220, time = 0.0022s
# z = 459.962 / 466.604 m → PhysProcs: None
# [Step 935/4666] z = 460.211, Element: SE4, dz = 0.249
#   ✔ Applied TM: TransferMap, len = 0.249, time = 0.0017s
# z = 460.211 / 466.604 m → PhysProcs: None
# [Step 936/4666] z = 460.311, Element: SE4, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0026s
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0024s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0061s
# z = 460.311 / 466.604 m → PhysProcs: ISRBend
# [Step 937/4666] z = 460.411, Element: SE4, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
# z = 460.411 / 466.604 m → PhysProcs: ISRBend
# [Step 938/4666] z = 460.511, Element: SE4, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0035s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0046s
# z = 460.511 / 466.604 m → PhysProcs: ISRBend
# [Step 939/4666] z = 460.611, Element: SE4, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0041s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0019s
# z = 460.611 / 466.604 m → PhysProcs: ISRBend
# [Step 940/4666] z = 460.711, Element: SE4, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0076s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0047s
# z = 460.711 / 466.604 m → PhysProcs: ISRBend
# [Step 941/4666] z = 460.811, Element: SE4, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0032s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
# z = 460.811 / 466.604 m → PhysProcs: ISRBend
# [Step 942/4666] z = 460.911, Element: SE4, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0024s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0066s
# z = 460.911 / 466.604 m → PhysProcs: ISRBend
# [Step 943/4666] z = 461.011, Element: SE4, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0059s
# z = 461.011 / 466.604 m → PhysProcs: ISRBend
# [Step 944/4666] z = 461.111, Element: SE4, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0012s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
# z = 461.111 / 466.604 m → PhysProcs: ISRBend
# [Step 945/4666] z = 461.211, Element: SE4, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0060s
# z = 461.211 / 466.604 m → PhysProcs: ISRBend
# [Step 946/4666] z = 461.211, Element: LSE3, dz = 0.000
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0039s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0020s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 5.859615311010202e-05
#     ✔ Done in 0.0025s
# z = 461.211 / 466.604 m → PhysProcs: ISRBend
# [Step 947/4666] z = 461.631, Element: SE3, dz = 0.420
#   ✔ Applied TM: TransferMap, len = 0.420, time = 0.0019s
# z = 461.631 / 466.604 m → PhysProcs: None
# [Step 948/4666] z = 461.731, Element: SE3, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0025s
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0032s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0062s
# z = 461.731 / 466.604 m → PhysProcs: ISRBend
# [Step 949/4666] z = 461.831, Element: SE3, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0050s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0045s
# z = 461.831 / 466.604 m → PhysProcs: ISRBend
# [Step 950/4666] z = 461.931, Element: SE3, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 461.931 / 466.604 m → PhysProcs: ISRBend
# [Step 951/4666] z = 462.031, Element: SE3, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0058s
# z = 462.031 / 466.604 m → PhysProcs: ISRBend
# [Step 952/4666] z = 462.131, Element: SE3, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0050s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0041s
# z = 462.131 / 466.604 m → PhysProcs: ISRBend
# [Step 953/4666] z = 462.231, Element: SE3, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0025s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0057s
# z = 462.231 / 466.604 m → PhysProcs: ISRBend
# [Step 954/4666] z = 462.331, Element: SE3, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0036s
# z = 462.331 / 466.604 m → PhysProcs: ISRBend
# [Step 955/4666] z = 462.431, Element: SE3, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0055s
# z = 462.431 / 466.604 m → PhysProcs: ISRBend
# [Step 956/4666] z = 462.531, Element: SE3, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0015s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 462.531 / 466.604 m → PhysProcs: ISRBend
# [Step 957/4666] z = 462.631, Element: SE3, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0028s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0056s
# z = 462.631 / 466.604 m → PhysProcs: ISRBend
# [Step 958/4666] z = 462.631, Element: LSE2, dz = 0.000
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0025s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0066s
#   → Applying PhysProc: ISRBend, z_step = 5.8596153053258604e-05
#     ✔ Done in 0.0034s
# z = 462.631 / 466.604 m → PhysProcs: ISRBend
# [Step 959/4666] z = 463.051, Element: SE2, dz = 0.420
#   ✔ Applied TM: TransferMap, len = 0.420, time = 0.0031s
# z = 463.051 / 466.604 m → PhysProcs: None
# [Step 960/4666] z = 463.151, Element: SE2, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0214s
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0039s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0072s
# z = 463.151 / 466.604 m → PhysProcs: ISRBend
# [Step 961/4666] z = 463.251, Element: SE2, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0014s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 463.251 / 466.604 m → PhysProcs: ISRBend
# [Step 962/4666] z = 463.351, Element: SE2, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0022s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0056s
# z = 463.351 / 466.604 m → PhysProcs: ISRBend
# [Step 963/4666] z = 463.451, Element: SE2, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0013s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0020s
# z = 463.451 / 466.604 m → PhysProcs: ISRBend
# [Step 964/4666] z = 463.551, Element: SE2, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0024s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0024s
# z = 463.551 / 466.604 m → PhysProcs: ISRBend
# [Step 965/4666] z = 463.651, Element: SE2, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0010s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0019s
# z = 463.651 / 466.604 m → PhysProcs: ISRBend
# [Step 966/4666] z = 463.751, Element: SE2, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0012s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 463.751 / 466.604 m → PhysProcs: ISRBend
# [Step 967/4666] z = 463.851, Element: SE2, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0060s
# z = 463.851 / 466.604 m → PhysProcs: ISRBend
# [Step 968/4666] z = 463.951, Element: SE2, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0021s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0058s
# z = 463.951 / 466.604 m → PhysProcs: ISRBend
# [Step 969/4666] z = 464.051, Element: SE2, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0079s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0017s
# z = 464.051 / 466.604 m → PhysProcs: ISRBend
# [Step 970/4666] z = 464.051, Element: LSE1, dz = 0.000
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0055s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0051s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0055s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0032s
#   → Applying PhysProc: ISRBend, z_step = 5.859615311010202e-05
#     ✔ Done in 0.0056s
# z = 464.051 / 466.604 m → PhysProcs: ISRBend
# [Step 971/4666] z = 464.471, Element: SE1, dz = 0.420
#   ✔ Applied TM: TransferMap, len = 0.420, time = 0.0018s
# z = 464.471 / 466.604 m → PhysProcs: None
# [Step 972/4666] z = 464.571, Element: SE1, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0018s
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0064s
# z = 464.571 / 466.604 m → PhysProcs: ISRBend
# [Step 973/4666] z = 464.671, Element: SE1, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0066s
# z = 464.671 / 466.604 m → PhysProcs: ISRBend
# [Step 974/4666] z = 464.771, Element: SE1, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0037s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 464.771 / 466.604 m → PhysProcs: ISRBend
# [Step 975/4666] z = 464.871, Element: SE1, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0050s
# z = 464.871 / 466.604 m → PhysProcs: ISRBend
# [Step 976/4666] z = 464.971, Element: SE1, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0027s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0075s
# z = 464.971 / 466.604 m → PhysProcs: ISRBend
# [Step 977/4666] z = 465.071, Element: SE1, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0043s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 465.071 / 466.604 m → PhysProcs: ISRBend
# [Step 978/4666] z = 465.171, Element: SE1, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0020s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0058s
# z = 465.171 / 466.604 m → PhysProcs: ISRBend
# [Step 979/4666] z = 465.271, Element: SE1, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0018s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0060s
# z = 465.271 / 466.604 m → PhysProcs: ISRBend
# [Step 980/4666] z = 465.371, Element: SE1, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0019s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0054s
# z = 465.371 / 466.604 m → PhysProcs: ISRBend
# [Step 981/4666] z = 465.471, Element: SE1, dz = 0.100
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0038s
#   → Applying PhysProc: ISRBend, z_step = 0.1
#     ✔ Done in 0.0018s
# z = 465.471 / 466.604 m → PhysProcs: ISRBend
# [Step 982/4666] z = 465.471, Element: LFR049, dz = 0.000
#   ✔ Applied TM: TransferMap, len = 1.000, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0033s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0023s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0018s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0031s
#   → Applying PhysProc: ISRBend, z_step = 0.00023441345769015243
#     ✔ Done in 0.0069s
# z = 465.471 / 466.604 m → PhysProcs: ISRBend
# [Step 983/4666] z = 465.778, Element: QI4E, dz = 0.307
#   ✔ Applied TM: TransferMap, len = 0.307, time = 0.0011s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0011s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0009s
# z = 465.778 / 466.604 m → PhysProcs: None
# [Step 984/4666] z = 466.604, Element: ID_60020663_, dz = 0.826
#   ✔ Applied TM: TransferMap, len = 0.826, time = 0.0018s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0020s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0019s
#   ✔ Applied TM: TransferMap, len = 0.000, time = 0.0022s
# z = 466.604 / 466.604 m → PhysProcs: None
# ✅ Tracking finished. Skipped 1 dz=0 steps.
#
#  time exec: 20.227948904037476 sec

# %%
plot_emittances_vs_s(p_array_t)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_energy_vs_position(tws_track):
    """
    Plot energy E as a function of position s from a list of Twiss-like objects.

    Parameters:
    tws_track (list): List of objects with attributes 's' (position) and 'E' (energy).
    """
    s = np.array([tw.s for tw in tws_track])
    E = np.array([tw.E for tw in tws_track])

    plt.figure(figsize=(10, 6))
    plt.plot(s, E, linewidth=2, marker='o', markersize=4)

    plt.title("Energy vs Position", fontsize=16)
    plt.xlabel("s (m)", fontsize=14)
    plt.ylabel("E (GeV)", fontsize=14)
    plt.grid(True, which='both', linestyle='--', alpha=0.5)
    plt.tick_params(axis='both', labelsize=12)
    plt.tight_layout()
    plt.show()

# %%
plot_energy_vs_position(tws_track)

# %%
# --- After tracking: get final x, x', y, y' ---
x_t = p_array_t.rparticles[0]
xp_t = p_array_t.rparticles[1]
y_t = p_array_t.rparticles[2]
yp_t = p_array_t.rparticles[3]

# --- Plot initial vs final side-by-side ---
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# x-x′ before
axes[0][0].scatter(p_array.rparticles[0], p_array.rparticles[1], s=1, alpha=0.3)
axes[0][0].set_title("x vs x′ (before)")
axes[0][0].set_xlabel("x [m]")
axes[0][0].set_ylabel("x′ [rad]")
axes[0][0].grid(True)
axes[0][0].axis('equal')

# x-x′ after
axes[0][1].scatter(x_t, xp_t, s=1, alpha=0.3)
axes[0][1].set_title("x vs x′ (after)")
axes[0][1].set_xlabel("x [m]")
axes[0][1].set_ylabel("x′ [rad]")
axes[0][1].grid(True)
axes[0][1].axis('equal')

# y-y′ before
axes[1][0].scatter(p_array.rparticles[2], p_array.rparticles[3], s=1, alpha=0.3, color='orange')
axes[1][0].set_title("y vs y′ (before)")
axes[1][0].set_xlabel("y [m]")
axes[1][0].set_ylabel("y′ [rad]")
axes[1][0].grid(True)
axes[1][0].axis('equal')

# y-y′ after
axes[1][1].scatter(y_t, yp_t, s=1, alpha=0.3, color='orange')
axes[1][1].set_title("y vs y′ (after)")
axes[1][1].set_xlabel("y [m]")
axes[1][1].set_ylabel("y′ [rad]")
axes[1][1].grid(True)
axes[1][1].axis('equal')

plt.tight_layout()
plt.show()

# %%
import numpy as np

def compute_emittance(x, xp):
    x_mean = np.mean(x)
    xp_mean = np.mean(xp)

    x_cent = x - x_mean
    xp_cent = xp - xp_mean

    xx = np.mean(x_cent ** 2)
    xpxp = np.mean(xp_cent ** 2)
    xxp = np.mean(x_cent * xp_cent)

    emit = np.sqrt(xx * xpxp - xxp**2)
    return emit

# Final tracked coordinates
x, xp = p_array_t.rparticles[0], p_array_t.rparticles[1]
y, yp = p_array_t.rparticles[2], p_array_t.rparticles[3]

emit_x = compute_emittance(x, xp)
emit_y = compute_emittance(y, yp)

print(f"εₓ (RMS, final) = {emit_x:.5e} m·rad")
print(f"εᵧ (RMS, final) = {emit_y:.5e} m·rad")

emit_x0 = compute_emittance(p_array.rparticles[0], p_array.rparticles[1])
emit_y0 = compute_emittance(p_array.rparticles[2], p_array.rparticles[3])
print("Initial εₓ:", emit_x0)
print("Initial εᵧ:", emit_y0)
# Out:
# εₓ (RMS, final) = 8.81703e-11 m·rad
# εᵧ (RMS, final) = 8.78941e-11 m·rad
# Initial εₓ: 8.808212049781106e-11
# Initial εᵧ: 8.765187845113946e-11

# %%
for tw in tws_track:
    print(f"s = {tw.s:.3f} m  |  beta_x = {tw.beta_x:.3f}  | beta_y = {tw.beta_y:.3f}  |  alpha_x = {tw.alpha_x:.3f} |  alpha_y = {tw.alpha_y:.3f}" )
# Out:
# s = 0.000 m  |  beta_x = 20.979  | beta_y = 18.130  |  alpha_x = 1.025 |  alpha_y = 0.381
# s = 0.217 m  |  beta_x = 20.540  | beta_y = 17.968  |  alpha_x = 1.004 |  alpha_y = 0.367
# s = 0.317 m  |  beta_x = 11.399  | beta_y = 17.895  |  alpha_x = 0.564 |  alpha_y = 0.361
# s = 0.417 m  |  beta_x = 6.467  | beta_y = 17.824  |  alpha_x = 0.313 |  alpha_y = 0.354
# s = 0.517 m  |  beta_x = 4.409  | beta_y = 17.754  |  alpha_x = 0.194 |  alpha_y = 0.348
# s = 0.617 m  |  beta_x = 3.324  | beta_y = 17.685  |  alpha_x = 0.116 |  alpha_y = 0.342
# s = 0.717 m  |  beta_x = 2.664  | beta_y = 17.617  |  alpha_x = 0.050 |  alpha_y = 0.335
# s = 0.817 m  |  beta_x = 2.229  | beta_y = 17.551  |  alpha_x = -0.013 |  alpha_y = 0.329
# s = 0.917 m  |  beta_x = 1.927  | beta_y = 17.485  |  alpha_x = -0.077 |  alpha_y = 0.323
# s = 1.017 m  |  beta_x = 1.713  | beta_y = 17.421  |  alpha_x = -0.144 |  alpha_y = 0.317
# s = 1.117 m  |  beta_x = 1.562  | beta_y = 17.359  |  alpha_x = -0.217 |  alpha_y = 0.310
# s = 1.217 m  |  beta_x = 1.459  | beta_y = 17.297  |  alpha_x = -0.296 |  alpha_y = 0.304
# s = 1.317 m  |  beta_x = 1.395  | beta_y = 17.237  |  alpha_x = -0.380 |  alpha_y = 0.298
# s = 1.417 m  |  beta_x = 1.364  | beta_y = 17.178  |  alpha_x = -0.472 |  alpha_y = 0.291
# s = 1.517 m  |  beta_x = 1.363  | beta_y = 17.121  |  alpha_x = -0.571 |  alpha_y = 0.285
# s = 1.617 m  |  beta_x = 1.390  | beta_y = 17.064  |  alpha_x = -0.677 |  alpha_y = 0.279
# s = 1.717 m  |  beta_x = 1.443  | beta_y = 17.009  |  alpha_x = -0.790 |  alpha_y = 0.272
# s = 1.753 m  |  beta_x = 1.468  | beta_y = 16.990  |  alpha_x = -0.842 |  alpha_y = 0.368
# s = 3.536 m  |  beta_x = 8.169  | beta_y = 15.890  |  alpha_x = -2.916 |  alpha_y = 0.249
# s = 4.116 m  |  beta_x = 11.943  | beta_y = 15.624  |  alpha_x = -3.591 |  alpha_y = 0.210
# s = 4.241 m  |  beta_x = 12.859  | beta_y = 15.573  |  alpha_x = -3.737 |  alpha_y = 0.202
# s = 4.366 m  |  beta_x = 13.811  | beta_y = 15.523  |  alpha_x = -3.882 |  alpha_y = 0.193
# s = 4.996 m  |  beta_x = 19.165  | beta_y = 15.306  |  alpha_x = -4.615 |  alpha_y = 0.151
# s = 5.096 m  |  beta_x = 20.100  | beta_y = 15.277  |  alpha_x = -4.732 |  alpha_y = 0.144
# s = 5.196 m  |  beta_x = 21.058  | beta_y = 15.249  |  alpha_x = -4.848 |  alpha_y = 0.138
# s = 5.420 m  |  beta_x = 23.287  | beta_y = 15.190  |  alpha_x = -5.108 |  alpha_y = 0.123
# s = 5.520 m  |  beta_x = 24.530  | beta_y = 15.166  |  alpha_x = -5.210 |  alpha_y = 0.116
# s = 5.620 m  |  beta_x = 25.804  | beta_y = 15.144  |  alpha_x = -5.310 |  alpha_y = 0.109
# s = 5.720 m  |  beta_x = 27.110  | beta_y = 15.123  |  alpha_x = -5.407 |  alpha_y = 0.103
# s = 5.820 m  |  beta_x = 28.446  | beta_y = 15.103  |  alpha_x = -5.501 |  alpha_y = 0.096
# s = 5.920 m  |  beta_x = 29.814  | beta_y = 15.084  |  alpha_x = -5.593 |  alpha_y = 0.089
# s = 6.020 m  |  beta_x = 31.213  | beta_y = 15.067  |  alpha_x = -5.682 |  alpha_y = 0.083
# s = 6.120 m  |  beta_x = 32.641  | beta_y = 15.051  |  alpha_x = -5.768 |  alpha_y = 0.076
# s = 6.220 m  |  beta_x = 34.100  | beta_y = 15.037  |  alpha_x = -5.852 |  alpha_y = 0.069
# s = 6.320 m  |  beta_x = 35.589  | beta_y = 15.023  |  alpha_x = -5.932 |  alpha_y = 0.063
# s = 6.420 m  |  beta_x = 37.106  | beta_y = 15.012  |  alpha_x = -6.010 |  alpha_y = 0.056
# s = 6.520 m  |  beta_x = 38.653  | beta_y = 15.001  |  alpha_x = -6.085 |  alpha_y = 0.049
# s = 6.620 m  |  beta_x = 40.229  | beta_y = 14.992  |  alpha_x = -6.157 |  alpha_y = 0.043
# s = 6.720 m  |  beta_x = 41.832  | beta_y = 14.984  |  alpha_x = -6.226 |  alpha_y = 0.036
# s = 6.820 m  |  beta_x = 43.463  | beta_y = 14.977  |  alpha_x = -6.291 |  alpha_y = 0.029
# s = 6.920 m  |  beta_x = 45.122  | beta_y = 14.972  |  alpha_x = -6.354 |  alpha_y = 0.023
# s = 7.020 m  |  beta_x = 46.807  | beta_y = 14.968  |  alpha_x = -6.413 |  alpha_y = 0.016
# s = 7.120 m  |  beta_x = 48.518  | beta_y = 14.966  |  alpha_x = -6.469 |  alpha_y = 0.009
# s = 7.220 m  |  beta_x = 50.254  | beta_y = 14.965  |  alpha_x = -6.522 |  alpha_y = 0.003
# s = 7.232 m  |  beta_x = 50.468  | beta_y = 14.965  |  alpha_x = -6.539 |  alpha_y = 0.005
# s = 9.366 m  |  beta_x = 82.322  | beta_y = 15.249  |  alpha_x = -8.389 |  alpha_y = -0.138
# s = 9.491 m  |  beta_x = 84.432  | beta_y = 15.284  |  alpha_x = -8.497 |  alpha_y = -0.146
# s = 9.616 m  |  beta_x = 86.570  | beta_y = 15.322  |  alpha_x = -8.605 |  alpha_y = -0.155
# s = 9.723 m  |  beta_x = 88.428  | beta_y = 15.356  |  alpha_x = -8.699 |  alpha_y = -0.162
# s = 10.248 m  |  beta_x = 96.464  | beta_y = 15.766  |  alpha_x = -6.526 |  alpha_y = -0.622
# s = 10.436 m  |  beta_x = 98.925  | beta_y = 16.002  |  alpha_x = -6.611 |  alpha_y = -0.639
# s = 10.636 m  |  beta_x = 101.587  | beta_y = 16.261  |  alpha_x = -6.702 |  alpha_y = -0.656
# s = 10.710 m  |  beta_x = 102.586  | beta_y = 16.359  |  alpha_x = -6.735 |  alpha_y = -0.663
# s = 11.010 m  |  beta_x = 106.668  | beta_y = 16.765  |  alpha_x = -6.871 |  alpha_y = -0.689
# s = 11.084 m  |  beta_x = 107.692  | beta_y = 16.868  |  alpha_x = -6.904 |  alpha_y = -0.696
# s = 11.284 m  |  beta_x = 110.472  | beta_y = 17.150  |  alpha_x = -6.995 |  alpha_y = -0.714
# s = 11.472 m  |  beta_x = 113.109  | beta_y = 17.420  |  alpha_x = -7.079 |  alpha_y = -0.730
# s = 11.997 m  |  beta_x = 131.190  | beta_y = 16.702  |  alpha_x = -28.328 |  alpha_y = 2.057
# s = 12.104 m  |  beta_x = 137.342  | beta_y = 16.264  |  alpha_x = -28.986 |  alpha_y = 2.024
# s = 12.229 m  |  beta_x = 144.684  | beta_y = 15.763  |  alpha_x = -29.751 |  alpha_y = 1.984
# s = 12.354 m  |  beta_x = 152.218  | beta_y = 15.272  |  alpha_x = -30.517 |  alpha_y = 1.945
# s = 13.417 m  |  beta_x = 224.008  | beta_y = 11.490  |  alpha_x = -37.026 |  alpha_y = 1.612
# s = 13.517 m  |  beta_x = 231.475  | beta_y = 11.171  |  alpha_x = -37.639 |  alpha_y = 1.581
# s = 13.617 m  |  beta_x = 239.064  | beta_y = 10.858  |  alpha_x = -38.251 |  alpha_y = 1.550
# s = 13.707 m  |  beta_x = 245.998  | beta_y = 10.582  |  alpha_x = -38.803 |  alpha_y = 1.522
# s = 13.924 m  |  beta_x = 263.067  | beta_y = 9.938  |  alpha_x = -40.127 |  alpha_y = 1.454
# s = 14.024 m  |  beta_x = 277.571  | beta_y = 9.647  |  alpha_x = -41.128 |  alpha_y = 1.440
# s = 14.124 m  |  beta_x = 291.767  | beta_y = 9.362  |  alpha_x = -41.501 |  alpha_y = 1.408
# s = 14.224 m  |  beta_x = 305.380  | beta_y = 9.084  |  alpha_x = -41.693 |  alpha_y = 1.376
# s = 14.324 m  |  beta_x = 318.113  | beta_y = 8.812  |  alpha_x = -41.677 |  alpha_y = 1.344
# s = 14.424 m  |  beta_x = 329.656  | beta_y = 8.546  |  alpha_x = -41.434 |  alpha_y = 1.312
# s = 14.524 m  |  beta_x = 339.716  | beta_y = 8.287  |  alpha_x = -40.949 |  alpha_y = 1.281
# s = 14.624 m  |  beta_x = 348.037  | beta_y = 8.034  |  alpha_x = -40.216 |  alpha_y = 1.249
# s = 14.724 m  |  beta_x = 354.425  | beta_y = 7.787  |  alpha_x = -39.240 |  alpha_y = 1.217
# s = 14.824 m  |  beta_x = 358.767  | beta_y = 7.547  |  alpha_x = -38.037 |  alpha_y = 1.185
# s = 14.924 m  |  beta_x = 361.041  | beta_y = 7.313  |  alpha_x = -36.632 |  alpha_y = 1.153
# s = 15.024 m  |  beta_x = 361.312  | beta_y = 7.086  |  alpha_x = -35.056 |  alpha_y = 1.121
# s = 15.124 m  |  beta_x = 359.721  | beta_y = 6.865  |  alpha_x = -33.348 |  alpha_y = 1.089
# s = 15.224 m  |  beta_x = 356.466  | beta_y = 6.650  |  alpha_x = -31.545 |  alpha_y = 1.058
# s = 15.324 m  |  beta_x = 351.781  | beta_y = 6.442  |  alpha_x = -29.684 |  alpha_y = 1.026
# s = 15.424 m  |  beta_x = 345.912  | beta_y = 6.240  |  alpha_x = -27.800 |  alpha_y = 0.994
# s = 15.473 m  |  beta_x = 342.666  | beta_y = 6.143  |  alpha_x = -27.490 |  alpha_y = 0.989
# s = 15.839 m  |  beta_x = 363.098  | beta_y = 5.462  |  alpha_x = -28.299 |  alpha_y = 0.871
# s = 16.039 m  |  beta_x = 374.506  | beta_y = 5.126  |  alpha_x = -28.740 |  alpha_y = 0.807
# s = 16.299 m  |  beta_x = 389.600  | beta_y = 4.728  |  alpha_x = -29.314 |  alpha_y = 0.723
# s = 16.406 m  |  beta_x = 395.893  | beta_y = 4.577  |  alpha_x = -29.550 |  alpha_y = 0.689
# s = 16.782 m  |  beta_x = 400.750  | beta_y = 4.293  |  alpha_x = 16.827 |  alpha_y = 0.078
# s = 16.889 m  |  beta_x = 397.161  | beta_y = 4.279  |  alpha_x = 16.751 |  alpha_y = 0.053
# s = 17.014 m  |  beta_x = 392.984  | beta_y = 4.270  |  alpha_x = 16.663 |  alpha_y = 0.024
# s = 17.139 m  |  beta_x = 388.830  | beta_y = 4.267  |  alpha_x = 16.574 |  alpha_y = -0.006
# s = 17.416 m  |  beta_x = 379.695  | beta_y = 4.288  |  alpha_x = 16.377 |  alpha_y = -0.071
# s = 17.516 m  |  beta_x = 376.318  | beta_y = 3.957  |  alpha_x = 16.848 |  alpha_y = -0.093
# s = 17.616 m  |  beta_x = 372.956  | beta_y = 3.279  |  alpha_x = 16.772 |  alpha_y = -0.105
# s = 17.716 m  |  beta_x = 369.609  | beta_y = 2.665  |  alpha_x = 16.696 |  alpha_y = -0.123
# s = 17.816 m  |  beta_x = 366.278  | beta_y = 2.207  |  alpha_x = 16.621 |  alpha_y = -0.152
# s = 17.916 m  |  beta_x = 362.961  | beta_y = 1.880  |  alpha_x = 16.545 |  alpha_y = -0.192
# s = 18.016 m  |  beta_x = 359.660  | beta_y = 1.648  |  alpha_x = 16.469 |  alpha_y = -0.242
# s = 18.116 m  |  beta_x = 356.373  | beta_y = 1.486  |  alpha_x = 16.394 |  alpha_y = -0.304
# s = 18.216 m  |  beta_x = 353.102  | beta_y = 1.377  |  alpha_x = 16.318 |  alpha_y = -0.375
# s = 18.316 m  |  beta_x = 349.846  | beta_y = 1.310  |  alpha_x = 16.242 |  alpha_y = -0.457
# s = 18.416 m  |  beta_x = 346.605  | beta_y = 1.279  |  alpha_x = 16.167 |  alpha_y = -0.548
# s = 18.516 m  |  beta_x = 343.380  | beta_y = 1.280  |  alpha_x = 16.091 |  alpha_y = -0.650
# s = 18.616 m  |  beta_x = 340.169  | beta_y = 1.309  |  alpha_x = 16.015 |  alpha_y = -0.760
# s = 18.716 m  |  beta_x = 336.973  | beta_y = 1.367  |  alpha_x = 15.940 |  alpha_y = -0.880
# s = 18.816 m  |  beta_x = 333.793  | beta_y = 1.451  |  alpha_x = 15.864 |  alpha_y = -1.009
# s = 18.916 m  |  beta_x = 330.628  | beta_y = 1.561  |  alpha_x = 15.788 |  alpha_y = -1.148
# s = 19.016 m  |  beta_x = 327.478  | beta_y = 1.698  |  alpha_x = 15.712 |  alpha_y = -1.295
# s = 19.116 m  |  beta_x = 324.343  | beta_y = 1.862  |  alpha_x = 15.637 |  alpha_y = -1.451
# s = 19.216 m  |  beta_x = 321.223  | beta_y = 2.052  |  alpha_x = 15.561 |  alpha_y = -1.616
# s = 19.316 m  |  beta_x = 318.119  | beta_y = 2.271  |  alpha_x = 15.485 |  alpha_y = -1.789
# s = 19.322 m  |  beta_x = 317.932  | beta_y = 2.285  |  alpha_x = 15.938 |  alpha_y = -1.803
# s = 19.509 m  |  beta_x = 311.993  | beta_y = 3.025  |  alpha_x = 15.788 |  alpha_y = -2.151
# s = 19.599 m  |  beta_x = 309.158  | beta_y = 3.427  |  alpha_x = 15.716 |  alpha_y = -2.318
# s = 20.099 m  |  beta_x = 293.643  | beta_y = 6.210  |  alpha_x = 15.315 |  alpha_y = -3.248
# s = 21.472 m  |  beta_x = 253.124  | beta_y = 18.625  |  alpha_x = 14.214 |  alpha_y = -5.799
# s = 21.572 m  |  beta_x = 250.216  | beta_y = 21.072  |  alpha_x = 14.494 |  alpha_y = -6.071
# s = 21.672 m  |  beta_x = 247.326  | beta_y = 23.792  |  alpha_x = 14.409 |  alpha_y = -6.310
# s = 21.772 m  |  beta_x = 244.453  | beta_y = 26.810  |  alpha_x = 14.325 |  alpha_y = -6.536
# s = 21.872 m  |  beta_x = 241.596  | beta_y = 30.136  |  alpha_x = 14.241 |  alpha_y = -6.742
# s = 21.972 m  |  beta_x = 238.756  | beta_y = 33.761  |  alpha_x = 14.156 |  alpha_y = -6.914
# s = 22.072 m  |  beta_x = 235.934  | beta_y = 37.628  |  alpha_x = 14.072 |  alpha_y = -7.032
# s = 22.172 m  |  beta_x = 233.128  | beta_y = 41.612  |  alpha_x = 13.988 |  alpha_y = -7.069
# s = 22.272 m  |  beta_x = 230.339  | beta_y = 45.485  |  alpha_x = 13.903 |  alpha_y = -6.988
# s = 22.372 m  |  beta_x = 227.566  | beta_y = 48.913  |  alpha_x = 13.819 |  alpha_y = -6.755
# s = 22.472 m  |  beta_x = 224.811  | beta_y = 51.501  |  alpha_x = 13.735 |  alpha_y = -6.342
# s = 22.572 m  |  beta_x = 222.073  | beta_y = 52.901  |  alpha_x = 13.650 |  alpha_y = -5.752
# s = 22.672 m  |  beta_x = 219.351  | beta_y = 52.955  |  alpha_x = 13.566 |  alpha_y = -5.017
# s = 22.772 m  |  beta_x = 216.646  | beta_y = 51.756  |  alpha_x = 13.481 |  alpha_y = -4.200
# s = 22.872 m  |  beta_x = 213.958  | beta_y = 49.596  |  alpha_x = 13.397 |  alpha_y = -3.367
# s = 22.972 m  |  beta_x = 211.287  | beta_y = 46.834  |  alpha_x = 13.313 |  alpha_y = -2.571
# s = 23.072 m  |  beta_x = 208.633  | beta_y = 43.790  |  alpha_x = 13.228 |  alpha_y = -1.844
# s = 23.172 m  |  beta_x = 205.996  | beta_y = 40.692  |  alpha_x = 13.144 |  alpha_y = -1.200
# s = 23.272 m  |  beta_x = 203.376  | beta_y = 37.683  |  alpha_x = 13.060 |  alpha_y = -0.641
# s = 23.372 m  |  beta_x = 200.772  | beta_y = 34.839  |  alpha_x = 12.975 |  alpha_y = -0.161
# s = 23.378 m  |  beta_x = 200.616  | beta_y = 34.674  |  alpha_x = 13.259 |  alpha_y = -0.184
# s = 23.812 m  |  beta_x = 189.271  | beta_y = 34.839  |  alpha_x = 12.876 |  alpha_y = -0.197
# s = 24.188 m  |  beta_x = 199.722  | beta_y = 31.429  |  alpha_x = -41.628 |  alpha_y = 8.941
# s = 24.295 m  |  beta_x = 208.721  | beta_y = 29.547  |  alpha_x = -42.556 |  alpha_y = 8.665
# s = 24.420 m  |  beta_x = 219.496  | beta_y = 27.421  |  alpha_x = -43.641 |  alpha_y = 8.344
# s = 24.545 m  |  beta_x = 230.542  | beta_y = 25.375  |  alpha_x = -44.727 |  alpha_y = 8.022
# s = 26.037 m  |  beta_x = 383.365  | beta_y = 7.169  |  alpha_x = -57.682 |  alpha_y = 4.179
# s = 26.162 m  |  beta_x = 397.922  | beta_y = 6.164  |  alpha_x = -58.767 |  alpha_y = 3.857
# s = 26.287 m  |  beta_x = 412.749  | beta_y = 5.241  |  alpha_x = -59.852 |  alpha_y = 3.535
# s = 26.637 m  |  beta_x = 455.709  | beta_y = 3.082  |  alpha_x = -62.891 |  alpha_y = 2.634
# s = 26.837 m  |  beta_x = 481.213  | beta_y = 2.131  |  alpha_x = -64.627 |  alpha_y = 2.119
# s = 26.937 m  |  beta_x = 494.225  | beta_y = 1.733  |  alpha_x = -65.496 |  alpha_y = 1.861
# s = 27.062 m  |  beta_x = 510.735  | beta_y = 1.308  |  alpha_x = -66.581 |  alpha_y = 1.539
# s = 27.187 m  |  beta_x = 527.516  | beta_y = 0.964  |  alpha_x = -67.666 |  alpha_y = 1.217
# s = 27.294 m  |  beta_x = 542.082  | beta_y = 0.733  |  alpha_x = -68.594 |  alpha_y = 0.942
# s = 27.670 m  |  beta_x = 540.079  | beta_y = 0.428  |  alpha_x = 73.741 |  alpha_y = -0.104
# s = 28.216 m  |  beta_x = 462.648  | beta_y = 1.245  |  alpha_x = 68.250 |  alpha_y = -1.393
# s = 28.316 m  |  beta_x = 495.938  | beta_y = 1.546  |  alpha_x = 71.687 |  alpha_y = -1.626
# s = 28.416 m  |  beta_x = 533.335  | beta_y = 1.895  |  alpha_x = 76.839 |  alpha_y = -1.862
# s = 28.516 m  |  beta_x = 574.130  | beta_y = 2.291  |  alpha_x = 82.411 |  alpha_y = -2.097
# s = 28.616 m  |  beta_x = 616.193  | beta_y = 2.734  |  alpha_x = 88.087 |  alpha_y = -2.333
# s = 28.716 m  |  beta_x = 655.104  | beta_y = 3.224  |  alpha_x = 93.225 |  alpha_y = -2.568
# s = 28.816 m  |  beta_x = 683.767  | beta_y = 3.761  |  alpha_x = 96.819 |  alpha_y = -2.804
# s = 28.916 m  |  beta_x = 693.881  | beta_y = 4.345  |  alpha_x = 97.716 |  alpha_y = -3.040
# s = 29.016 m  |  beta_x = 679.987  | beta_y = 4.977  |  alpha_x = 95.190 |  alpha_y = -3.275
# s = 29.116 m  |  beta_x = 643.411  | beta_y = 5.656  |  alpha_x = 89.487 |  alpha_y = -3.511
# s = 29.216 m  |  beta_x = 591.697  | beta_y = 6.381  |  alpha_x = 81.718 |  alpha_y = -3.747
# s = 29.316 m  |  beta_x = 534.015  | beta_y = 7.154  |  alpha_x = 73.193 |  alpha_y = -3.982
# s = 29.416 m  |  beta_x = 477.292  | beta_y = 7.974  |  alpha_x = 64.884 |  alpha_y = -4.218
# s = 29.516 m  |  beta_x = 425.269  | beta_y = 8.842  |  alpha_x = 57.303 |  alpha_y = -4.454
# s = 29.616 m  |  beta_x = 379.306  | beta_y = 9.756  |  alpha_x = 50.627 |  alpha_y = -4.689
# s = 29.716 m  |  beta_x = 339.438  | beta_y = 10.717  |  alpha_x = 44.846 |  alpha_y = -4.925
# s = 29.816 m  |  beta_x = 305.116  | beta_y = 11.726  |  alpha_x = 39.873 |  alpha_y = -5.161
# s = 29.916 m  |  beta_x = 275.609  | beta_y = 12.781  |  alpha_x = 35.598 |  alpha_y = -5.396
# s = 30.016 m  |  beta_x = 250.189  | beta_y = 13.884  |  alpha_x = 31.913 |  alpha_y = -5.632
# s = 30.116 m  |  beta_x = 228.205  | beta_y = 15.034  |  alpha_x = 28.723 |  alpha_y = -5.868
# s = 30.216 m  |  beta_x = 209.103  | beta_y = 16.231  |  alpha_x = 25.946 |  alpha_y = -6.103
# s = 30.250 m  |  beta_x = 203.177  | beta_y = 16.649  |  alpha_x = 24.566 |  alpha_y = -6.141
# s = 30.788 m  |  beta_x = 177.566  | beta_y = 23.943  |  alpha_x = 22.962 |  alpha_y = -7.394
# s = 30.913 m  |  beta_x = 171.871  | beta_y = 25.828  |  alpha_x = 22.591 |  alpha_y = -7.684
# s = 31.038 m  |  beta_x = 166.270  | beta_y = 27.785  |  alpha_x = 22.219 |  alpha_y = -7.975
# s = 31.146 m  |  beta_x = 161.534  | beta_y = 29.524  |  alpha_x = 21.899 |  alpha_y = -8.225
# s = 31.671 m  |  beta_x = 161.129  | beta_y = 33.996  |  alpha_x = -21.092 |  alpha_y = 0.117
# s = 32.106 m  |  beta_x = 179.983  | beta_y = 33.900  |  alpha_x = -22.295 |  alpha_y = 0.104
# s = 34.012 m  |  beta_x = 273.807  | beta_y = 17.726  |  alpha_x = -26.795 |  alpha_y = 5.582
# s = 34.199 m  |  beta_x = 283.931  | beta_y = 15.700  |  alpha_x = -27.287 |  alpha_y = 5.243
# s = 34.289 m  |  beta_x = 288.864  | beta_y = 14.771  |  alpha_x = -27.523 |  alpha_y = 5.079
# s = 34.789 m  |  beta_x = 317.044  | beta_y = 10.145  |  alpha_x = -28.836 |  alpha_y = 4.172
# s = 36.161 m  |  beta_x = 401.126  | beta_y = 2.111  |  alpha_x = -32.439 |  alpha_y = 1.682
# s = 38.067 m  |  beta_x = 531.791  | beta_y = 5.815  |  alpha_x = -35.926 |  alpha_y = -0.602
# s = 38.344 m  |  beta_x = 551.895  | beta_y = 6.166  |  alpha_x = -36.600 |  alpha_y = -0.667
# s = 38.554 m  |  beta_x = 567.374  | beta_y = 6.457  |  alpha_x = -37.110 |  alpha_y = -0.716
# s = 38.634 m  |  beta_x = 573.327  | beta_y = 6.573  |  alpha_x = -37.304 |  alpha_y = -0.735
# s = 38.834 m  |  beta_x = 588.346  | beta_y = 6.877  |  alpha_x = -37.790 |  alpha_y = -0.782
# s = 39.022 m  |  beta_x = 602.591  | beta_y = 7.178  |  alpha_x = -38.245 |  alpha_y = -0.826
# s = 39.547 m  |  beta_x = 590.407  | beta_y = 8.803  |  alpha_x = 60.765 |  alpha_y = -2.357
# s = 39.654 m  |  beta_x = 577.433  | beta_y = 9.318  |  alpha_x = 60.094 |  alpha_y = -2.437
# s = 39.779 m  |  beta_x = 562.507  | beta_y = 9.939  |  alpha_x = 59.312 |  alpha_y = -2.531
# s = 39.904 m  |  beta_x = 547.777  | beta_y = 10.583  |  alpha_x = 58.530 |  alpha_y = -2.624
# s = 40.029 m  |  beta_x = 533.242  | beta_y = 11.251  |  alpha_x = 57.748 |  alpha_y = -2.717
# s = 40.154 m  |  beta_x = 518.903  | beta_y = 11.942  |  alpha_x = 56.966 |  alpha_y = -2.810
# s = 43.154 m  |  beta_x = 233.433  | beta_y = 35.502  |  alpha_x = 38.201 |  alpha_y = -5.044
# s = 43.279 m  |  beta_x = 223.980  | beta_y = 36.774  |  alpha_x = 37.419 |  alpha_y = -5.137
# s = 43.404 m  |  beta_x = 214.723  | beta_y = 38.070  |  alpha_x = 36.637 |  alpha_y = -5.231
# s = 43.529 m  |  beta_x = 205.662  | beta_y = 39.390  |  alpha_x = 35.855 |  alpha_y = -5.324
# s = 43.654 m  |  beta_x = 196.796  | beta_y = 40.732  |  alpha_x = 35.073 |  alpha_y = -5.417
# s = 43.744 m  |  beta_x = 190.533  | beta_y = 41.713  |  alpha_x = 34.510 |  alpha_y = -5.484
# s = 43.824 m  |  beta_x = 185.052  | beta_y = 42.595  |  alpha_x = 34.009 |  alpha_y = -5.543
# s = 44.024 m  |  beta_x = 171.698  | beta_y = 44.843  |  alpha_x = 32.758 |  alpha_y = -5.692
# s = 44.211 m  |  beta_x = 159.644  | beta_y = 47.002  |  alpha_x = 31.586 |  alpha_y = -5.832
# s = 44.737 m  |  beta_x = 141.077  | beta_y = 48.842  |  alpha_x = 4.818 |  alpha_y = 2.435
# s = 44.844 m  |  beta_x = 140.044  | beta_y = 48.321  |  alpha_x = 4.800 |  alpha_y = 2.420
# s = 44.969 m  |  beta_x = 138.847  | beta_y = 47.718  |  alpha_x = 4.778 |  alpha_y = 2.402
# s = 45.635 m  |  beta_x = 132.559  | beta_y = 44.582  |  alpha_x = 4.664 |  alpha_y = 2.307
# s = 45.923 m  |  beta_x = 129.887  | beta_y = 43.265  |  alpha_x = 4.614 |  alpha_y = 2.267
# s = 48.744 m  |  beta_x = 105.221  | beta_y = 31.607  |  alpha_x = 4.130 |  alpha_y = 1.866
# s = 48.944 m  |  beta_x = 103.575  | beta_y = 30.866  |  alpha_x = 4.096 |  alpha_y = 1.838
# s = 49.044 m  |  beta_x = 102.758  | beta_y = 30.500  |  alpha_x = 4.079 |  alpha_y = 1.824
# s = 49.169 m  |  beta_x = 101.741  | beta_y = 30.046  |  alpha_x = 4.057 |  alpha_y = 1.806
# s = 49.294 m  |  beta_x = 100.729  | beta_y = 29.597  |  alpha_x = 4.036 |  alpha_y = 1.788
# s = 49.401 m  |  beta_x = 99.865  | beta_y = 29.214  |  alpha_x = 4.017 |  alpha_y = 1.773
# s = 49.926 m  |  beta_x = 90.455  | beta_y = 28.957  |  alpha_x = 13.566 |  alpha_y = -1.275
# s = 50.034 m  |  beta_x = 87.566  | beta_y = 29.232  |  alpha_x = 13.346 |  alpha_y = -1.285
# s = 50.184 m  |  beta_x = 83.609  | beta_y = 29.620  |  alpha_x = 13.039 |  alpha_y = -1.298
# s = 50.309 m  |  beta_x = 80.381  | beta_y = 29.946  |  alpha_x = 12.784 |  alpha_y = -1.310
# s = 50.434 m  |  beta_x = 77.217  | beta_y = 30.275  |  alpha_x = 12.528 |  alpha_y = -1.321
# s = 50.559 m  |  beta_x = 74.117  | beta_y = 30.606  |  alpha_x = 12.272 |  alpha_y = -1.332
# s = 50.684 m  |  beta_x = 71.081  | beta_y = 30.941  |  alpha_x = 12.017 |  alpha_y = -1.344
# s = 54.388 m  |  beta_x = 10.125  | beta_y = 42.140  |  alpha_x = 4.440 |  alpha_y = -1.680
# s = 54.513 m  |  beta_x = 9.047  | beta_y = 42.561  |  alpha_x = 4.184 |  alpha_y = -1.691
# s = 54.638 m  |  beta_x = 8.033  | beta_y = 42.985  |  alpha_x = 3.928 |  alpha_y = -1.702
# s = 54.861 m  |  beta_x = 6.379  | beta_y = 43.751  |  alpha_x = 3.471 |  alpha_y = -1.723
# s = 56.895 m  |  beta_x = 2.871  | beta_y = 50.644  |  alpha_x = 0.539 |  alpha_y = -1.649
# s = 57.279 m  |  beta_x = 2.524  | beta_y = 51.920  |  alpha_x = 0.367 |  alpha_y = -1.677
# s = 57.479 m  |  beta_x = 2.395  | beta_y = 52.593  |  alpha_x = 0.277 |  alpha_y = -1.692
# s = 57.666 m  |  beta_x = 2.307  | beta_y = 53.230  |  alpha_x = 0.192 |  alpha_y = -1.706
# s = 58.191 m  |  beta_x = 2.307  | beta_y = 53.178  |  alpha_x = -0.191 |  alpha_y = 1.804
# s = 58.299 m  |  beta_x = 2.353  | beta_y = 52.791  |  alpha_x = -0.240 |  alpha_y = 1.795
# s = 58.399 m  |  beta_x = 2.406  | beta_y = 52.433  |  alpha_x = -0.285 |  alpha_y = 1.787
# s = 58.499 m  |  beta_x = 2.467  | beta_y = 52.076  |  alpha_x = -0.329 |  alpha_y = 1.779
# s = 58.792 m  |  beta_x = 2.699  | beta_y = 51.039  |  alpha_x = -0.461 |  alpha_y = 1.756
# s = 60.826 m  |  beta_x = 1.951  | beta_y = 43.736  |  alpha_x = -0.483 |  alpha_y = 1.816
# s = 62.093 m  |  beta_x = 4.189  | beta_y = 39.291  |  alpha_x = -1.283 |  alpha_y = 1.691
# s = 62.495 m  |  beta_x = 5.322  | beta_y = 37.948  |  alpha_x = -1.537 |  alpha_y = 1.652
# s = 62.995 m  |  beta_x = 7.017  | beta_y = 36.320  |  alpha_x = -1.853 |  alpha_y = 1.603
# s = 63.085 m  |  beta_x = 7.356  | beta_y = 36.033  |  alpha_x = -1.910 |  alpha_y = 1.594
# s = 63.160 m  |  beta_x = 7.646  | beta_y = 35.794  |  alpha_x = -1.958 |  alpha_y = 1.587
# s = 63.260 m  |  beta_x = 8.044  | beta_y = 35.478  |  alpha_x = -2.021 |  alpha_y = 1.577
# s = 63.460 m  |  beta_x = 8.878  | beta_y = 34.851  |  alpha_x = -2.147 |  alpha_y = 1.557
# s = 63.647 m  |  beta_x = 9.704  | beta_y = 34.271  |  alpha_x = -2.266 |  alpha_y = 1.539
# s = 64.173 m  |  beta_x = 11.445  | beta_y = 35.178  |  alpha_x = -0.967 |  alpha_y = -3.307
# s = 64.280 m  |  beta_x = 11.655  | beta_y = 35.892  |  alpha_x = -0.985 |  alpha_y = -3.344
# s = 64.405 m  |  beta_x = 11.904  | beta_y = 36.733  |  alpha_x = -1.007 |  alpha_y = -3.386
# s = 64.530 m  |  beta_x = 12.158  | beta_y = 37.585  |  alpha_x = -1.028 |  alpha_y = -3.429
# s = 69.241 m  |  beta_x = 25.597  | beta_y = 77.426  |  alpha_x = -1.825 |  alpha_y = -5.028
# s = 69.441 m  |  beta_x = 26.333  | beta_y = 79.451  |  alpha_x = -1.858 |  alpha_y = -5.096
# s = 69.629 m  |  beta_x = 27.035  | beta_y = 81.372  |  alpha_x = -1.890 |  alpha_y = -5.159
# s = 70.154 m  |  beta_x = 31.350  | beta_y = 80.389  |  alpha_x = -6.538 |  alpha_y = 6.981
# s = 70.261 m  |  beta_x = 32.770  | beta_y = 78.898  |  alpha_x = -6.687 |  alpha_y = 6.915
# s = 70.386 m  |  beta_x = 34.464  | beta_y = 77.179  |  alpha_x = -6.862 |  alpha_y = 6.837
# s = 70.511 m  |  beta_x = 36.201  | beta_y = 75.479  |  alpha_x = -7.036 |  alpha_y = 6.760
# s = 74.533 m  |  beta_x = 115.355  | beta_y = 31.115  |  alpha_x = -12.647 |  alpha_y = 4.272
# s = 74.783 m  |  beta_x = 121.766  | beta_y = 29.017  |  alpha_x = -12.996 |  alpha_y = 4.117
# s = 74.908 m  |  beta_x = 125.037  | beta_y = 27.998  |  alpha_x = -13.170 |  alpha_y = 4.040
# s = 75.033 m  |  beta_x = 128.351  | beta_y = 26.997  |  alpha_x = -13.345 |  alpha_y = 3.963
# s = 75.123 m  |  beta_x = 130.764  | beta_y = 26.289  |  alpha_x = -13.470 |  alpha_y = 3.907
# s = 75.223 m  |  beta_x = 133.472  | beta_y = 25.514  |  alpha_x = -13.610 |  alpha_y = 3.845
# s = 75.423 m  |  beta_x = 138.972  | beta_y = 24.001  |  alpha_x = -13.889 |  alpha_y = 3.721
# s = 75.610 m  |  beta_x = 144.225  | beta_y = 22.628  |  alpha_x = -14.150 |  alpha_y = 3.605
# s = 76.136 m  |  beta_x = 145.409  | beta_y = 20.969  |  alpha_x = 11.968 |  alpha_y = -0.350
# s = 76.243 m  |  beta_x = 142.851  | beta_y = 21.045  |  alpha_x = 11.861 |  alpha_y = -0.355
# s = 76.368 m  |  beta_x = 139.901  | beta_y = 21.135  |  alpha_x = 11.737 |  alpha_y = -0.362
# s = 76.493 m  |  beta_x = 136.982  | beta_y = 21.226  |  alpha_x = 11.613 |  alpha_y = -0.369
# s = 81.204 m  |  beta_x = 49.569  | beta_y = 25.889  |  alpha_x = 6.940 |  alpha_y = -0.621
# s = 81.404 m  |  beta_x = 46.832  | beta_y = 26.140  |  alpha_x = 6.742 |  alpha_y = -0.632
# s = 81.592 m  |  beta_x = 44.341  | beta_y = 26.378  |  alpha_x = 6.556 |  alpha_y = -0.642
# s = 82.117 m  |  beta_x = 40.499  | beta_y = 25.285  |  alpha_x = 0.923 |  alpha_y = 2.676
# s = 82.224 m  |  beta_x = 40.301  | beta_y = 24.714  |  alpha_x = 0.918 |  alpha_y = 2.642
# s = 82.349 m  |  beta_x = 40.072  | beta_y = 24.058  |  alpha_x = 0.913 |  alpha_y = 2.601
# s = 82.474 m  |  beta_x = 39.845  | beta_y = 23.413  |  alpha_x = 0.907 |  alpha_y = 2.561
# s = 84.648 m  |  beta_x = 36.118  | beta_y = 13.804  |  alpha_x = 0.807 |  alpha_y = 1.859
# s = 86.682 m  |  beta_x = 54.511  | beta_y = 7.473  |  alpha_x = -8.172 |  alpha_y = 1.237
# s = 87.261 m  |  beta_x = 64.381  | beta_y = 6.155  |  alpha_x = -8.892 |  alpha_y = 1.041
# s = 87.461 m  |  beta_x = 67.987  | beta_y = 5.752  |  alpha_x = -9.140 |  alpha_y = 0.974
# s = 87.648 m  |  beta_x = 71.447  | beta_y = 5.400  |  alpha_x = -9.373 |  alpha_y = 0.910
# s = 88.024 m  |  beta_x = 67.068  | beta_y = 5.604  |  alpha_x = 20.383 |  alpha_y = -1.481
# s = 88.131 m  |  beta_x = 62.782  | beta_y = 5.927  |  alpha_x = 19.719 |  alpha_y = -1.542
# s = 88.256 m  |  beta_x = 57.949  | beta_y = 6.321  |  alpha_x = 18.943 |  alpha_y = -1.613
# s = 88.381 m  |  beta_x = 53.310  | beta_y = 6.734  |  alpha_x = 18.166 |  alpha_y = -1.685
# s = 88.899 m  |  beta_x = 36.143  | beta_y = 8.633  |  alpha_x = 14.947 |  alpha_y = -1.980
# s = 90.933 m  |  beta_x = 9.190  | beta_y = 18.915  |  alpha_x = 5.046 |  alpha_y = -3.049
# s = 91.700 m  |  beta_x = 3.144  | beta_y = 23.911  |  alpha_x = 2.838 |  alpha_y = -3.466
# s = 93.734 m  |  beta_x = 4.854  | beta_y = 39.943  |  alpha_x = -0.753 |  alpha_y = -4.375
# s = 94.205 m  |  beta_x = 5.634  | beta_y = 44.174  |  alpha_x = -0.905 |  alpha_y = -4.612
# s = 94.730 m  |  beta_x = 7.434  | beta_y = 43.846  |  alpha_x = -2.653 |  alpha_y = 5.211
# s = 94.837 m  |  beta_x = 8.016  | beta_y = 42.735  |  alpha_x = -2.769 |  alpha_y = 5.142
# s = 94.962 m  |  beta_x = 8.725  | beta_y = 41.459  |  alpha_x = -2.904 |  alpha_y = 5.062
# s = 95.087 m  |  beta_x = 9.468  | beta_y = 40.204  |  alpha_x = -3.039 |  alpha_y = 4.982
# s = 95.187 m  |  beta_x = 10.086  | beta_y = 39.214  |  alpha_x = -3.147 |  alpha_y = 4.917
# s = 95.387 m  |  beta_x = 11.388  | beta_y = 37.273  |  alpha_x = -3.363 |  alpha_y = 4.789
# s = 101.014 m  |  beta_x = 83.464  | beta_y = 3.710  |  alpha_x = -9.446 |  alpha_y = 1.176
# s = 101.214 m  |  beta_x = 87.286  | beta_y = 3.266  |  alpha_x = -9.663 |  alpha_y = 1.047
# s = 101.401 m  |  beta_x = 90.944  | beta_y = 2.896  |  alpha_x = -9.865 |  alpha_y = 0.927
# s = 101.927 m  |  beta_x = 92.570  | beta_y = 2.326  |  alpha_x = 6.869 |  alpha_y = 0.192
# s = 102.034 m  |  beta_x = 91.102  | beta_y = 2.290  |  alpha_x = 6.813 |  alpha_y = 0.144
# s = 102.159 m  |  beta_x = 89.407  | beta_y = 2.261  |  alpha_x = 6.748 |  alpha_y = 0.088
# s = 102.284 m  |  beta_x = 87.728  | beta_y = 2.246  |  alpha_x = 6.683 |  alpha_y = 0.032
# s = 108.211 m  |  beta_x = 26.798  | beta_y = 17.517  |  alpha_x = 3.598 |  alpha_y = -2.609
# s = 108.411 m  |  beta_x = 25.379  | beta_y = 18.578  |  alpha_x = 3.494 |  alpha_y = -2.698
# s = 108.598 m  |  beta_x = 24.088  | beta_y = 19.605  |  alpha_x = 3.397 |  alpha_y = -2.782
# s = 109.123 m  |  beta_x = 23.125  | beta_y = 20.379  |  alpha_x = -1.496 |  alpha_y = 1.362
# s = 109.231 m  |  beta_x = 23.448  | beta_y = 20.088  |  alpha_x = -1.511 |  alpha_y = 1.347
# s = 109.356 m  |  beta_x = 23.828  | beta_y = 19.754  |  alpha_x = -1.529 |  alpha_y = 1.329
# s = 109.481 m  |  beta_x = 24.212  | beta_y = 19.424  |  alpha_x = -1.546 |  alpha_y = 1.312
# s = 115.215 m  |  beta_x = 46.549  | beta_y = 8.984  |  alpha_x = -2.349 |  alpha_y = 0.509
# s = 115.415 m  |  beta_x = 47.494  | beta_y = 8.787  |  alpha_x = -2.377 |  alpha_y = 0.480
# s = 115.603 m  |  beta_x = 48.390  | beta_y = 8.612  |  alpha_x = -2.403 |  alpha_y = 0.454
# s = 116.128 m  |  beta_x = 48.388  | beta_y = 8.613  |  alpha_x = 2.407 |  alpha_y = -0.458
# s = 116.235 m  |  beta_x = 47.873  | beta_y = 8.713  |  alpha_x = 2.392 |  alpha_y = -0.473
# s = 116.360 m  |  beta_x = 47.277  | beta_y = 8.834  |  alpha_x = 2.374 |  alpha_y = -0.491
# s = 116.485 m  |  beta_x = 46.686  | beta_y = 8.959  |  alpha_x = 2.357 |  alpha_y = -0.508
# s = 116.575 m  |  beta_x = 46.262  | beta_y = 9.051  |  alpha_x = 2.344 |  alpha_y = -0.521
# s = 116.700 m  |  beta_x = 45.679  | beta_y = 9.184  |  alpha_x = 2.327 |  alpha_y = -0.538
# s = 116.825 m  |  beta_x = 45.099  | beta_y = 9.321  |  alpha_x = 2.309 |  alpha_y = -0.556
# s = 117.075 m  |  beta_x = 43.953  | beta_y = 9.607  |  alpha_x = 2.274 |  alpha_y = -0.591
# s = 129.648 m  |  beta_x = 8.966  | beta_y = 46.672  |  alpha_x = 0.509 |  alpha_y = -2.357
# s = 129.848 m  |  beta_x = 8.768  | beta_y = 47.620  |  alpha_x = 0.481 |  alpha_y = -2.385
# s = 130.036 m  |  beta_x = 8.593  | beta_y = 48.519  |  alpha_x = 0.454 |  alpha_y = -2.411
# s = 130.561 m  |  beta_x = 8.594  | beta_y = 48.518  |  alpha_x = -0.456 |  alpha_y = 2.412
# s = 130.668 m  |  beta_x = 8.694  | beta_y = 48.002  |  alpha_x = -0.471 |  alpha_y = 2.397
# s = 130.793 m  |  beta_x = 8.814  | beta_y = 47.405  |  alpha_x = -0.489 |  alpha_y = 2.379
# s = 130.918 m  |  beta_x = 8.938  | beta_y = 46.813  |  alpha_x = -0.506 |  alpha_y = 2.362
# s = 131.008 m  |  beta_x = 9.030  | beta_y = 46.389  |  alpha_x = -0.519 |  alpha_y = 2.349
# s = 131.258 m  |  beta_x = 9.299  | beta_y = 45.223  |  alpha_x = -0.554 |  alpha_y = 2.314
# s = 131.383 m  |  beta_x = 9.439  | beta_y = 44.647  |  alpha_x = -0.572 |  alpha_y = 2.296
# s = 131.508 m  |  beta_x = 9.584  | beta_y = 44.075  |  alpha_x = -0.589 |  alpha_y = 2.279
# s = 144.081 m  |  beta_x = 46.623  | beta_y = 8.984  |  alpha_x = -2.357 |  alpha_y = 0.512
# s = 144.281 m  |  beta_x = 47.572  | beta_y = 8.785  |  alpha_x = -2.385 |  alpha_y = 0.484
# s = 144.469 m  |  beta_x = 48.470  | beta_y = 8.608  |  alpha_x = -2.411 |  alpha_y = 0.458
# s = 144.994 m  |  beta_x = 48.472  | beta_y = 8.607  |  alpha_x = 2.407 |  alpha_y = -0.454
# s = 145.101 m  |  beta_x = 47.957  | beta_y = 8.706  |  alpha_x = 2.392 |  alpha_y = -0.469
# s = 145.226 m  |  beta_x = 47.361  | beta_y = 8.825  |  alpha_x = 2.375 |  alpha_y = -0.487
# s = 145.351 m  |  beta_x = 46.770  | beta_y = 8.949  |  alpha_x = 2.357 |  alpha_y = -0.504
# s = 145.441 m  |  beta_x = 46.346  | beta_y = 9.041  |  alpha_x = 2.345 |  alpha_y = -0.517
# s = 145.691 m  |  beta_x = 45.183  | beta_y = 9.308  |  alpha_x = 2.310 |  alpha_y = -0.552
# s = 145.816 m  |  beta_x = 44.608  | beta_y = 9.448  |  alpha_x = 2.292 |  alpha_y = -0.569
# s = 145.941 m  |  beta_x = 44.037  | beta_y = 9.593  |  alpha_x = 2.275 |  alpha_y = -0.587
# s = 158.514 m  |  beta_x = 9.002  | beta_y = 46.501  |  alpha_x = 0.512 |  alpha_y = -2.349
# s = 158.714 m  |  beta_x = 8.803  | beta_y = 47.446  |  alpha_x = 0.484 |  alpha_y = -2.377
# s = 158.902 m  |  beta_x = 8.627  | beta_y = 48.341  |  alpha_x = 0.458 |  alpha_y = -2.403
# s = 159.427 m  |  beta_x = 8.626  | beta_y = 48.342  |  alpha_x = -0.456 |  alpha_y = 2.402
# s = 159.534 m  |  beta_x = 8.726  | beta_y = 47.827  |  alpha_x = -0.471 |  alpha_y = 2.387
# s = 159.659 m  |  beta_x = 8.845  | beta_y = 47.233  |  alpha_x = -0.488 |  alpha_y = 2.370
# s = 159.784 m  |  beta_x = 8.970  | beta_y = 46.643  |  alpha_x = -0.506 |  alpha_y = 2.352
# s = 159.874 m  |  beta_x = 9.062  | beta_y = 46.220  |  alpha_x = -0.519 |  alpha_y = 2.340
# s = 160.124 m  |  beta_x = 9.330  | beta_y = 45.059  |  alpha_x = -0.554 |  alpha_y = 2.305
# s = 160.249 m  |  beta_x = 9.470  | beta_y = 44.485  |  alpha_x = -0.571 |  alpha_y = 2.287
# s = 160.374 m  |  beta_x = 9.615  | beta_y = 43.915  |  alpha_x = -0.589 |  alpha_y = 2.270
# s = 172.947 m  |  beta_x = 46.549  | beta_y = 8.984  |  alpha_x = -2.349 |  alpha_y = 0.509
# s = 173.147 m  |  beta_x = 47.494  | beta_y = 8.787  |  alpha_x = -2.377 |  alpha_y = 0.480
# s = 173.335 m  |  beta_x = 48.390  | beta_y = 8.612  |  alpha_x = -2.403 |  alpha_y = 0.454
# s = 173.860 m  |  beta_x = 48.388  | beta_y = 8.613  |  alpha_x = 2.407 |  alpha_y = -0.458
# s = 173.967 m  |  beta_x = 47.873  | beta_y = 8.713  |  alpha_x = 2.392 |  alpha_y = -0.473
# s = 174.092 m  |  beta_x = 47.277  | beta_y = 8.834  |  alpha_x = 2.374 |  alpha_y = -0.491
# s = 174.217 m  |  beta_x = 46.686  | beta_y = 8.959  |  alpha_x = 2.357 |  alpha_y = -0.508
# s = 174.307 m  |  beta_x = 46.262  | beta_y = 9.051  |  alpha_x = 2.344 |  alpha_y = -0.521
# s = 174.557 m  |  beta_x = 45.099  | beta_y = 9.321  |  alpha_x = 2.309 |  alpha_y = -0.556
# s = 174.682 m  |  beta_x = 44.524  | beta_y = 9.462  |  alpha_x = 2.292 |  alpha_y = -0.573
# s = 174.807 m  |  beta_x = 43.953  | beta_y = 9.607  |  alpha_x = 2.274 |  alpha_y = -0.591
# s = 187.380 m  |  beta_x = 8.966  | beta_y = 46.672  |  alpha_x = 0.509 |  alpha_y = -2.357
# s = 187.580 m  |  beta_x = 8.768  | beta_y = 47.620  |  alpha_x = 0.481 |  alpha_y = -2.385
# s = 187.767 m  |  beta_x = 8.593  | beta_y = 48.519  |  alpha_x = 0.454 |  alpha_y = -2.411
# s = 188.293 m  |  beta_x = 8.594  | beta_y = 48.518  |  alpha_x = -0.456 |  alpha_y = 2.412
# s = 188.400 m  |  beta_x = 8.694  | beta_y = 48.002  |  alpha_x = -0.471 |  alpha_y = 2.397
# s = 188.525 m  |  beta_x = 8.814  | beta_y = 47.405  |  alpha_x = -0.489 |  alpha_y = 2.379
# s = 188.650 m  |  beta_x = 8.938  | beta_y = 46.813  |  alpha_x = -0.506 |  alpha_y = 2.362
# s = 188.900 m  |  beta_x = 9.200  | beta_y = 45.640  |  alpha_x = -0.541 |  alpha_y = 2.327
# s = 188.990 m  |  beta_x = 9.299  | beta_y = 45.223  |  alpha_x = -0.554 |  alpha_y = 2.314
# s = 189.115 m  |  beta_x = 9.439  | beta_y = 44.647  |  alpha_x = -0.572 |  alpha_y = 2.296
# s = 189.240 m  |  beta_x = 9.584  | beta_y = 44.075  |  alpha_x = -0.589 |  alpha_y = 2.279
# s = 201.813 m  |  beta_x = 46.623  | beta_y = 8.984  |  alpha_x = -2.357 |  alpha_y = 0.512
# s = 202.013 m  |  beta_x = 47.572  | beta_y = 8.785  |  alpha_x = -2.385 |  alpha_y = 0.484
# s = 202.200 m  |  beta_x = 48.470  | beta_y = 8.608  |  alpha_x = -2.411 |  alpha_y = 0.458
# s = 202.726 m  |  beta_x = 48.014  | beta_y = 8.688  |  alpha_x = 3.262 |  alpha_y = -0.613
# s = 202.833 m  |  beta_x = 47.317  | beta_y = 8.822  |  alpha_x = 3.236 |  alpha_y = -0.630
# s = 202.958 m  |  beta_x = 46.511  | beta_y = 8.982  |  alpha_x = 3.205 |  alpha_y = -0.650
# s = 203.083 m  |  beta_x = 45.714  | beta_y = 9.147  |  alpha_x = 3.175 |  alpha_y = -0.669
# s = 203.183 m  |  beta_x = 45.081  | beta_y = 9.282  |  alpha_x = 3.151 |  alpha_y = -0.685
# s = 203.283 m  |  beta_x = 44.454  | beta_y = 9.421  |  alpha_x = 3.127 |  alpha_y = -0.701
# s = 203.383 m  |  beta_x = 43.831  | beta_y = 9.562  |  alpha_x = 3.102 |  alpha_y = -0.717
# s = 203.670 m  |  beta_x = 42.069  | beta_y = 9.987  |  alpha_x = 3.033 |  alpha_y = -0.762
# s = 203.770 m  |  beta_x = 26.432  | beta_y = 10.139  |  alpha_x = 1.855 |  alpha_y = -0.766
# s = 203.870 m  |  beta_x = 15.771  | beta_y = 10.294  |  alpha_x = 1.092 |  alpha_y = -0.781
# s = 203.970 m  |  beta_x = 10.887  | beta_y = 10.451  |  alpha_x = 0.737 |  alpha_y = -0.797
# s = 204.070 m  |  beta_x = 8.227  | beta_y = 10.612  |  alpha_x = 0.538 |  alpha_y = -0.813
# s = 204.170 m  |  beta_x = 6.576  | beta_y = 10.776  |  alpha_x = 0.407 |  alpha_y = -0.828
# s = 204.270 m  |  beta_x = 5.460  | beta_y = 10.944  |  alpha_x = 0.311 |  alpha_y = -0.844
# s = 204.370 m  |  beta_x = 4.661  | beta_y = 11.114  |  alpha_x = 0.235 |  alpha_y = -0.860
# s = 204.470 m  |  beta_x = 4.063  | beta_y = 11.287  |  alpha_x = 0.169 |  alpha_y = -0.875
# s = 204.570 m  |  beta_x = 3.604  | beta_y = 11.464  |  alpha_x = 0.110 |  alpha_y = -0.891
# s = 204.670 m  |  beta_x = 3.243  | beta_y = 11.644  |  alpha_x = 0.054 |  alpha_y = -0.906
# s = 204.770 m  |  beta_x = 2.956  | beta_y = 11.827  |  alpha_x = 0.001 |  alpha_y = -0.922
# s = 204.870 m  |  beta_x = 2.727  | beta_y = 12.013  |  alpha_x = -0.053 |  alpha_y = -0.938
# s = 204.970 m  |  beta_x = 2.543  | beta_y = 12.202  |  alpha_x = -0.107 |  alpha_y = -0.953
# s = 205.070 m  |  beta_x = 2.397  | beta_y = 12.394  |  alpha_x = -0.161 |  alpha_y = -0.969
# s = 205.170 m  |  beta_x = 2.283  | beta_y = 12.589  |  alpha_x = -0.218 |  alpha_y = -0.985
# s = 205.270 m  |  beta_x = 2.197  | beta_y = 12.788  |  alpha_x = -0.276 |  alpha_y = -1.000
# s = 205.370 m  |  beta_x = 2.136  | beta_y = 12.989  |  alpha_x = -0.336 |  alpha_y = -1.016
# s = 205.470 m  |  beta_x = 2.097  | beta_y = 13.194  |  alpha_x = -0.399 |  alpha_y = -1.032
# s = 205.570 m  |  beta_x = 2.078  | beta_y = 13.402  |  alpha_x = -0.464 |  alpha_y = -1.047
# s = 205.670 m  |  beta_x = 2.080  | beta_y = 13.613  |  alpha_x = -0.532 |  alpha_y = -1.063
# s = 205.756 m  |  beta_x = 2.096  | beta_y = 13.796  |  alpha_x = -0.595 |  alpha_y = -1.059
# s = 211.425 m  |  beta_x = 29.623  | beta_y = 30.749  |  alpha_x = -4.260 |  alpha_y = -1.931
# s = 211.625 m  |  beta_x = 31.352  | beta_y = 31.527  |  alpha_x = -4.389 |  alpha_y = -1.962
# s = 211.896 m  |  beta_x = 33.780  | beta_y = 32.602  |  alpha_x = -4.564 |  alpha_y = -2.004
# s = 211.996 m  |  beta_x = 33.784  | beta_y = 32.990  |  alpha_x = -4.865 |  alpha_y = -1.945
# s = 212.096 m  |  beta_x = 33.869  | beta_y = 33.381  |  alpha_x = -5.092 |  alpha_y = -1.960
# s = 212.196 m  |  beta_x = 34.030  | beta_y = 33.774  |  alpha_x = -5.322 |  alpha_y = -1.974
# s = 212.296 m  |  beta_x = 34.266  | beta_y = 34.170  |  alpha_x = -5.555 |  alpha_y = -1.989
# s = 212.396 m  |  beta_x = 34.573  | beta_y = 34.569  |  alpha_x = -5.791 |  alpha_y = -2.003
# s = 212.496 m  |  beta_x = 34.949  | beta_y = 34.971  |  alpha_x = -6.032 |  alpha_y = -2.018
# s = 212.596 m  |  beta_x = 35.394  | beta_y = 35.376  |  alpha_x = -6.278 |  alpha_y = -2.032
# s = 212.696 m  |  beta_x = 35.905  | beta_y = 35.784  |  alpha_x = -6.529 |  alpha_y = -2.047
# s = 212.796 m  |  beta_x = 36.482  | beta_y = 36.195  |  alpha_x = -6.787 |  alpha_y = -2.061
# s = 212.896 m  |  beta_x = 37.125  | beta_y = 36.609  |  alpha_x = -7.050 |  alpha_y = -2.076
# s = 212.996 m  |  beta_x = 37.833  | beta_y = 37.025  |  alpha_x = -7.321 |  alpha_y = -2.090
# s = 213.096 m  |  beta_x = 38.606  | beta_y = 37.445  |  alpha_x = -7.599 |  alpha_y = -2.105
# s = 213.196 m  |  beta_x = 39.444  | beta_y = 37.867  |  alpha_x = -7.884 |  alpha_y = -2.119
# s = 213.296 m  |  beta_x = 40.348  | beta_y = 38.292  |  alpha_x = -8.177 |  alpha_y = -2.134
# s = 213.396 m  |  beta_x = 41.317  | beta_y = 38.721  |  alpha_x = -8.479 |  alpha_y = -2.148
# s = 213.496 m  |  beta_x = 42.354  | beta_y = 39.152  |  alpha_x = -8.789 |  alpha_y = -2.163
# s = 213.596 m  |  beta_x = 43.457  | beta_y = 39.586  |  alpha_x = -9.108 |  alpha_y = -2.177
# s = 213.696 m  |  beta_x = 44.630  | beta_y = 40.023  |  alpha_x = -9.437 |  alpha_y = -2.192
# s = 213.796 m  |  beta_x = 45.871  | beta_y = 40.462  |  alpha_x = -9.774 |  alpha_y = -2.206
# s = 213.896 m  |  beta_x = 47.183  | beta_y = 40.905  |  alpha_x = -10.122 |  alpha_y = -2.221
# s = 213.975 m  |  beta_x = 48.265  | beta_y = 41.255  |  alpha_x = -10.510 |  alpha_y = -2.140
# s = 214.303 m  |  beta_x = 55.418  | beta_y = 42.675  |  alpha_x = -11.268 |  alpha_y = -2.184
# s = 214.829 m  |  beta_x = 73.346  | beta_y = 41.411  |  alpha_x = -23.807 |  alpha_y = 4.523
# s = 214.936 m  |  beta_x = 78.547  | beta_y = 40.446  |  alpha_x = -24.638 |  alpha_y = 4.468
# s = 215.036 m  |  beta_x = 83.552  | beta_y = 39.558  |  alpha_x = -25.412 |  alpha_y = 4.416
# s = 215.136 m  |  beta_x = 88.712  | beta_y = 38.680  |  alpha_x = -26.186 |  alpha_y = 4.364
# s = 215.374 m  |  beta_x = 101.607  | beta_y = 36.633  |  alpha_x = -28.027 |  alpha_y = 4.241
# s = 217.453 m  |  beta_x = 223.074  | beta_y = 20.985  |  alpha_x = -48.616 |  alpha_y = 3.253
# s = 217.725 m  |  beta_x = 250.325  | beta_y = 19.255  |  alpha_x = -51.501 |  alpha_y = 3.102
# s = 219.803 m  |  beta_x = 429.650  | beta_y = 8.623  |  alpha_x = -74.069 |  alpha_y = 1.989
# s = 220.029 m  |  beta_x = 463.773  | beta_y = 7.754  |  alpha_x = -76.955 |  alpha_y = 1.859
# s = 220.054 m  |  beta_x = 467.629  | beta_y = 7.662  |  alpha_x = -77.274 |  alpha_y = 1.845
# s = 220.079 m  |  beta_x = 471.501  | beta_y = 7.570  |  alpha_x = -77.593 |  alpha_y = 1.830
# s = 220.166 m  |  beta_x = 485.083  | beta_y = 7.256  |  alpha_x = -78.703 |  alpha_y = 1.780
# s = 220.542 m  |  beta_x = 500.603  | beta_y = 6.586  |  alpha_x = 38.683 |  alpha_y = 0.054
# s = 220.679 m  |  beta_x = 490.067  | beta_y = 6.574  |  alpha_x = 38.274 |  alpha_y = 0.033
# s = 220.804 m  |  beta_x = 480.545  | beta_y = 6.568  |  alpha_x = 37.900 |  alpha_y = 0.014
# s = 220.929 m  |  beta_x = 471.117  | beta_y = 6.567  |  alpha_x = 37.526 |  alpha_y = -0.005
# s = 221.156 m  |  beta_x = 454.289  | beta_y = 6.577  |  alpha_x = 36.849 |  alpha_y = -0.040
# s = 223.234 m  |  beta_x = 285.533  | beta_y = 7.338  |  alpha_x = 16.119 |  alpha_y = -0.325
# s = 223.506 m  |  beta_x = 276.826  | beta_y = 7.526  |  alpha_x = 15.871 |  alpha_y = -0.366
# s = 225.585 m  |  beta_x = 216.633  | beta_y = 9.620  |  alpha_x = 4.572 |  alpha_y = -0.637
# s = 225.831 m  |  beta_x = 214.389  | beta_y = 9.943  |  alpha_x = 4.547 |  alpha_y = -0.673
# s = 226.031 m  |  beta_x = 212.574  | beta_y = 10.218  |  alpha_x = 4.527 |  alpha_y = -0.702
# s = 226.218 m  |  beta_x = 210.881  | beta_y = 10.486  |  alpha_x = 4.508 |  alpha_y = -0.730
# s = 226.744 m  |  beta_x = 206.174  | beta_y = 11.293  |  alpha_x = 4.452 |  alpha_y = -0.806
# s = 226.881 m  |  beta_x = 204.953  | beta_y = 11.518  |  alpha_x = 4.439 |  alpha_y = -0.827
# s = 227.006 m  |  beta_x = 203.845  | beta_y = 11.727  |  alpha_x = 4.426 |  alpha_y = -0.845
# s = 227.131 m  |  beta_x = 202.740  | beta_y = 11.940  |  alpha_x = 4.413 |  alpha_y = -0.863
# s = 227.357 m  |  beta_x = 200.748  | beta_y = 12.338  |  alpha_x = 4.390 |  alpha_y = -0.896
# s = 229.436 m  |  beta_x = 215.385  | beta_y = 16.563  |  alpha_x = -4.512 |  alpha_y = -1.127
# s = 229.708 m  |  beta_x = 217.848  | beta_y = 17.187  |  alpha_x = -4.539 |  alpha_y = -1.164
# s = 231.787 m  |  beta_x = 307.001  | beta_y = 22.438  |  alpha_x = -17.901 |  alpha_y = -1.350
# s = 232.150 m  |  beta_x = 320.130  | beta_y = 23.434  |  alpha_x = -18.281 |  alpha_y = -1.396
# s = 232.526 m  |  beta_x = 302.290  | beta_y = 26.987  |  alpha_x = 64.119 |  alpha_y = -8.359
# s = 232.663 m  |  beta_x = 284.989  | beta_y = 29.325  |  alpha_x = 62.257 |  alpha_y = -8.719
# s = 232.788 m  |  beta_x = 269.637  | beta_y = 31.546  |  alpha_x = 60.557 |  alpha_y = -9.047
# s = 232.913 m  |  beta_x = 254.710  | beta_y = 33.848  |  alpha_x = 58.856 |  alpha_y = -9.375
# s = 233.139 m  |  beta_x = 228.773  | beta_y = 38.225  |  alpha_x = 55.778 |  alpha_y = -9.969
# s = 235.217 m  |  beta_x = 85.774  | beta_y = 90.469  |  alpha_x = 31.457 |  alpha_y = -15.048
# s = 235.490 m  |  beta_x = 69.505  | beta_y = 98.847  |  alpha_x = 28.313 |  alpha_y = -15.733
# s = 237.568 m  |  beta_x = 5.796  | beta_y = 173.892  |  alpha_x = 7.153 |  alpha_y = -20.204
# s = 237.814 m  |  beta_x = 2.820  | beta_y = 183.979  |  alpha_x = 4.938 |  alpha_y = -20.783
# s = 238.014 m  |  beta_x = 1.205  | beta_y = 192.387  |  alpha_x = 3.138 |  alpha_y = -21.253
# s = 238.202 m  |  beta_x = 0.345  | beta_y = 200.433  |  alpha_x = 1.451 |  alpha_y = -21.694
# s = 238.727 m  |  beta_x = 1.321  | beta_y = 202.064  |  alpha_x = -3.373 |  alpha_y = 18.699
# s = 238.864 m  |  beta_x = 2.424  | beta_y = 196.960  |  alpha_x = -4.660 |  alpha_y = 18.460
# s = 238.989 m  |  beta_x = 3.735  | beta_y = 192.372  |  alpha_x = -5.831 |  alpha_y = 18.243
# s = 239.114 m  |  beta_x = 5.339  | beta_y = 187.838  |  alpha_x = -7.002 |  alpha_y = 18.027
# s = 239.341 m  |  beta_x = 8.988  | beta_y = 179.769  |  alpha_x = -9.122 |  alpha_y = 17.634
# s = 241.419 m  |  beta_x = 114.916  | beta_y = 112.634  |  alpha_x = -29.659 |  alpha_y = 14.515
# s = 241.691 m  |  beta_x = 131.630  | beta_y = 104.871  |  alpha_x = -31.745 |  alpha_y = 14.003
# s = 243.770 m  |  beta_x = 308.238  | beta_y = 54.076  |  alpha_x = -31.502 |  alpha_y = 10.321
# s = 244.133 m  |  beta_x = 331.523  | beta_y = 46.847  |  alpha_x = -32.671 |  alpha_y = 9.599
# s = 244.509 m  |  beta_x = 327.394  | beta_y = 43.648  |  alpha_x = 43.330 |  alpha_y = -0.851
# s = 244.646 m  |  beta_x = 315.637  | beta_y = 43.882  |  alpha_x = 42.544 |  alpha_y = -0.857
# s = 244.771 m  |  beta_x = 305.091  | beta_y = 44.096  |  alpha_x = 41.827 |  alpha_y = -0.862
# s = 244.896 m  |  beta_x = 294.724  | beta_y = 44.312  |  alpha_x = 41.110 |  alpha_y = -0.866
# s = 245.122 m  |  beta_x = 276.414  | beta_y = 44.706  |  alpha_x = 39.811 |  alpha_y = -0.875
# s = 247.201 m  |  beta_x = 54.000  | beta_y = 48.085  |  alpha_x = 18.864 |  alpha_y = -0.742
# s = 247.473 m  |  beta_x = 44.220  | beta_y = 48.491  |  alpha_x = 17.065 |  alpha_y = -0.751
# s = 249.552 m  |  beta_x = 0.228  | beta_y = 51.290  |  alpha_x = 0.943 |  alpha_y = -0.589
# s = 249.798 m  |  beta_x = 0.265  | beta_y = 51.581  |  alpha_x = -1.095 |  alpha_y = -0.595
# s = 249.998 m  |  beta_x = 1.035  | beta_y = 51.820  |  alpha_x = -2.751 |  alpha_y = -0.600
# s = 250.185 m  |  beta_x = 2.356  | beta_y = 52.046  |  alpha_x = -4.303 |  alpha_y = -0.605
# s = 250.710 m  |  beta_x = 9.552  | beta_y = 49.470  |  alpha_x = -9.680 |  alpha_y = 5.407
# s = 250.848 m  |  beta_x = 12.398  | beta_y = 47.996  |  alpha_x = -11.042 |  alpha_y = 5.323
# s = 250.973 m  |  beta_x = 15.313  | beta_y = 46.675  |  alpha_x = -12.282 |  alpha_y = 5.247
# s = 251.098 m  |  beta_x = 18.539  | beta_y = 45.373  |  alpha_x = -13.521 |  alpha_y = 5.170
# s = 251.324 m  |  beta_x = 25.165  | beta_y = 43.064  |  alpha_x = -15.764 |  alpha_y = 5.032
# s = 253.403 m  |  beta_x = 126.860  | beta_y = 24.484  |  alpha_x = -39.991 |  alpha_y = 3.865
# s = 253.675 m  |  beta_x = 149.565  | beta_y = 22.428  |  alpha_x = -43.424 |  alpha_y = 3.688
# s = 255.753 m  |  beta_x = 356.219  | beta_y = 9.772  |  alpha_x = -74.083 |  alpha_y = 2.372
# s = 256.116 m  |  beta_x = 412.010  | beta_y = 8.140  |  alpha_x = -79.675 |  alpha_y = 2.126
# s = 256.492 m  |  beta_x = 419.088  | beta_y = 7.577  |  alpha_x = 61.663 |  alpha_y = -0.567
# s = 256.629 m  |  beta_x = 402.375  | beta_y = 7.736  |  alpha_x = 60.420 |  alpha_y = -0.591
# s = 256.754 m  |  beta_x = 387.411  | beta_y = 7.886  |  alpha_x = 59.286 |  alpha_y = -0.613
# s = 256.879 m  |  beta_x = 372.732  | beta_y = 8.042  |  alpha_x = 58.151 |  alpha_y = -0.635
# s = 257.105 m  |  beta_x = 346.881  | beta_y = 8.338  |  alpha_x = 56.098 |  alpha_y = -0.674
# s = 259.184 m  |  beta_x = 160.227  | beta_y = 11.806  |  alpha_x = 29.399 |  alpha_y = -0.986
# s = 259.456 m  |  beta_x = 144.623  | beta_y = 12.355  |  alpha_x = 27.929 |  alpha_y = -1.031
# s = 261.535 m  |  beta_x = 64.674  | beta_y = 17.230  |  alpha_x = 14.154 |  alpha_y = -1.303
# s = 261.781 m  |  beta_x = 57.895  | beta_y = 17.881  |  alpha_x = 13.388 |  alpha_y = -1.342
# s = 261.981 m  |  beta_x = 52.664  | beta_y = 18.424  |  alpha_x = 12.766 |  alpha_y = -1.373
# s = 262.168 m  |  beta_x = 47.990  | beta_y = 18.944  |  alpha_x = 12.182 |  alpha_y = -1.402
# s = 262.694 m  |  beta_x = 37.728  | beta_y = 19.642  |  alpha_x = 7.624 |  alpha_y = 0.091
# s = 262.831 m  |  beta_x = 35.663  | beta_y = 19.618  |  alpha_x = 7.408 |  alpha_y = 0.084
# s = 262.956 m  |  beta_x = 33.836  | beta_y = 19.598  |  alpha_x = 7.212 |  alpha_y = 0.078
# ...
# s = 424.390 m  |  beta_x = 14.824  | beta_y = 13.789  |  alpha_x = -1.058 |  alpha_y = 1.554
# s = 424.515 m  |  beta_x = 15.090  | beta_y = 13.405  |  alpha_x = -1.076 |  alpha_y = 1.523
# s = 424.640 m  |  beta_x = 15.362  | beta_y = 13.028  |  alpha_x = -1.094 |  alpha_y = 1.492
# s = 424.765 m  |  beta_x = 15.638  | beta_y = 12.659  |  alpha_x = -1.112 |  alpha_y = 1.461
# s = 424.890 m  |  beta_x = 15.918  | beta_y = 12.298  |  alpha_x = -1.130 |  alpha_y = 1.430
# s = 424.976 m  |  beta_x = 16.115  | beta_y = 12.051  |  alpha_x = -1.142 |  alpha_y = 1.408
# s = 425.353 m  |  beta_x = 15.790  | beta_y = 11.888  |  alpha_x = 1.986 |  alpha_y = -0.964
# s = 425.460 m  |  beta_x = 15.369  | beta_y = 12.096  |  alpha_x = 1.952 |  alpha_y = -0.981
# s = 425.585 m  |  beta_x = 14.886  | beta_y = 12.344  |  alpha_x = 1.913 |  alpha_y = -1.002
# s = 425.710 m  |  beta_x = 14.412  | beta_y = 12.597  |  alpha_x = 1.874 |  alpha_y = -1.022
# s = 426.058 m  |  beta_x = 13.143  | beta_y = 13.329  |  alpha_x = 1.765 |  alpha_y = -1.078
# s = 426.158 m  |  beta_x = 10.392  | beta_y = 13.543  |  alpha_x = 1.385 |  alpha_y = -1.075
# s = 426.258 m  |  beta_x = 7.000  | beta_y = 13.759  |  alpha_x = 0.929 |  alpha_y = -1.091
# s = 426.358 m  |  beta_x = 4.993  | beta_y = 13.979  |  alpha_x = 0.648 |  alpha_y = -1.107
# s = 426.458 m  |  beta_x = 3.800  | beta_y = 14.202  |  alpha_x = 0.468 |  alpha_y = -1.123
# s = 426.558 m  |  beta_x = 3.037  | beta_y = 14.429  |  alpha_x = 0.338 |  alpha_y = -1.139
# s = 426.658 m  |  beta_x = 2.518  | beta_y = 14.658  |  alpha_x = 0.233 |  alpha_y = -1.155
# s = 426.758 m  |  beta_x = 2.149  | beta_y = 14.891  |  alpha_x = 0.141 |  alpha_y = -1.171
# s = 426.858 m  |  beta_x = 1.882  | beta_y = 15.126  |  alpha_x = 0.055 |  alpha_y = -1.187
# s = 426.958 m  |  beta_x = 1.686  | beta_y = 15.365  |  alpha_x = -0.030 |  alpha_y = -1.203
# s = 427.058 m  |  beta_x = 1.544  | beta_y = 15.608  |  alpha_x = -0.116 |  alpha_y = -1.219
# s = 427.158 m  |  beta_x = 1.446  | beta_y = 15.853  |  alpha_x = -0.204 |  alpha_y = -1.235
# s = 427.258 m  |  beta_x = 1.384  | beta_y = 16.101  |  alpha_x = -0.296 |  alpha_y = -1.251
# s = 427.358 m  |  beta_x = 1.354  | beta_y = 16.353  |  alpha_x = -0.394 |  alpha_y = -1.266
# s = 427.458 m  |  beta_x = 1.353  | beta_y = 16.608  |  alpha_x = -0.496 |  alpha_y = -1.282
# s = 427.558 m  |  beta_x = 1.379  | beta_y = 16.866  |  alpha_x = -0.605 |  alpha_y = -1.298
# s = 427.658 m  |  beta_x = 1.431  | beta_y = 17.127  |  alpha_x = -0.721 |  alpha_y = -1.314
# s = 427.758 m  |  beta_x = 1.509  | beta_y = 17.392  |  alpha_x = -0.843 |  alpha_y = -1.330
# s = 427.858 m  |  beta_x = 1.613  | beta_y = 17.659  |  alpha_x = -0.973 |  alpha_y = -1.346
# s = 427.871 m  |  beta_x = 1.628  | beta_y = 17.693  |  alpha_x = -0.992 |  alpha_y = -1.323
# s = 428.258 m  |  beta_x = 2.577  | beta_y = 18.739  |  alpha_x = -1.463 |  alpha_y = -1.383
# s = 430.070 m  |  beta_x = 11.579  | beta_y = 24.154  |  alpha_x = -5.652 |  alpha_y = -1.597
# s = 430.738 m  |  beta_x = 20.397  | beta_y = 26.352  |  alpha_x = -7.553 |  alpha_y = -1.695
# s = 432.551 m  |  beta_x = 55.509  | beta_y = 32.826  |  alpha_x = -16.845 |  alpha_y = -1.868
# s = 432.934 m  |  beta_x = 69.198  | beta_y = 34.281  |  alpha_x = -18.814 |  alpha_y = -1.921
# s = 433.134 m  |  beta_x = 76.929  | beta_y = 35.054  |  alpha_x = -19.840 |  alpha_y = -1.948
# s = 433.322 m  |  beta_x = 84.543  | beta_y = 35.789  |  alpha_x = -20.801 |  alpha_y = -1.974
# s = 433.847 m  |  beta_x = 115.972  | beta_y = 35.005  |  alpha_x = -40.616 |  alpha_y = 3.425
# s = 433.954 m  |  beta_x = 124.856  | beta_y = 34.274  |  alpha_x = -42.144 |  alpha_y = 3.386
# s = 434.079 m  |  beta_x = 135.615  | beta_y = 33.433  |  alpha_x = -43.923 |  alpha_y = 3.341
# s = 434.204 m  |  beta_x = 146.818  | beta_y = 32.603  |  alpha_x = -45.702 |  alpha_y = 3.295
# s = 434.537 m  |  beta_x = 178.793  | beta_y = 30.452  |  alpha_x = -50.436 |  alpha_y = 3.174
# s = 436.350 m  |  beta_x = 375.090  | beta_y = 20.011  |  alpha_x = -81.300 |  alpha_y = 2.570
# s = 436.736 m  |  beta_x = 440.566  | beta_y = 18.081  |  alpha_x = -88.112 |  alpha_y = 2.424
# s = 438.549 m  |  beta_x = 620.229  | beta_y = 10.474  |  alpha_x = -103.942 |  alpha_y = 1.763
# s = 438.869 m  |  beta_x = 688.589  | beta_y = 9.385  |  alpha_x = -109.521 |  alpha_y = 1.637
# s = 438.969 m  |  beta_x = 710.668  | beta_y = 9.061  |  alpha_x = -111.263 |  alpha_y = 1.598
# s = 439.017 m  |  beta_x = 721.389  | beta_y = 8.909  |  alpha_x = -112.099 |  alpha_y = 1.579
# s = 439.142 m  |  beta_x = 749.686  | beta_y = 8.520  |  alpha_x = -114.277 |  alpha_y = 1.530
# s = 439.267 m  |  beta_x = 778.527  | beta_y = 8.144  |  alpha_x = -116.454 |  alpha_y = 1.481
# s = 439.354 m  |  beta_x = 798.899  | beta_y = 7.890  |  alpha_x = -117.968 |  alpha_y = 1.447
# s = 439.730 m  |  beta_x = 813.887  | beta_y = 7.534  |  alpha_x = 79.348 |  alpha_y = -0.474
# s = 439.837 m  |  beta_x = 797.011  | beta_y = 7.637  |  alpha_x = 78.521 |  alpha_y = -0.491
# s = 439.962 m  |  beta_x = 777.501  | beta_y = 7.763  |  alpha_x = 77.554 |  alpha_y = -0.511
# s = 440.087 m  |  beta_x = 758.234  | beta_y = 7.893  |  alpha_x = 76.587 |  alpha_y = -0.532
# s = 440.436 m  |  beta_x = 705.735  | beta_y = 8.284  |  alpha_x = 73.887 |  alpha_y = -0.588
# s = 442.248 m  |  beta_x = 360.528  | beta_y = 10.902  |  alpha_x = 35.690 |  alpha_y = -0.853
# s = 442.635 m  |  beta_x = 333.470  | beta_y = 11.585  |  alpha_x = 34.323 |  alpha_y = -0.914
# s = 444.448 m  |  beta_x = 198.488  | beta_y = 15.350  |  alpha_x = 17.693 |  alpha_y = -1.158
# s = 445.097 m  |  beta_x = 176.182  | beta_y = 16.917  |  alpha_x = 16.666 |  alpha_y = -1.257
# s = 445.222 m  |  beta_x = 172.040  | beta_y = 17.234  |  alpha_x = 16.468 |  alpha_y = -1.276
# s = 445.347 m  |  beta_x = 167.948  | beta_y = 17.555  |  alpha_x = 16.271 |  alpha_y = -1.295
# s = 445.472 m  |  beta_x = 163.905  | beta_y = 17.881  |  alpha_x = 16.073 |  alpha_y = -1.314
# s = 445.597 m  |  beta_x = 159.912  | beta_y = 18.212  |  alpha_x = 15.875 |  alpha_y = -1.333
# s = 445.847 m  |  beta_x = 152.073  | beta_y = 18.888  |  alpha_x = 15.479 |  alpha_y = -1.371
# s = 445.937 m  |  beta_x = 149.299  | beta_y = 19.136  |  alpha_x = 15.337 |  alpha_y = -1.385
# s = 446.037 m  |  beta_x = 146.248  | beta_y = 19.415  |  alpha_x = 15.179 |  alpha_y = -1.400
# s = 446.237 m  |  beta_x = 140.240  | beta_y = 19.981  |  alpha_x = 14.862 |  alpha_y = -1.431
# s = 446.424 m  |  beta_x = 134.726  | beta_y = 20.523  |  alpha_x = 14.566 |  alpha_y = -1.459
# s = 446.949 m  |  beta_x = 128.368  | beta_y = 20.691  |  alpha_x = -2.194 |  alpha_y = 1.146
# s = 447.057 m  |  beta_x = 128.839  | beta_y = 20.446  |  alpha_x = -2.199 |  alpha_y = 1.134
# s = 447.182 m  |  beta_x = 129.390  | beta_y = 20.164  |  alpha_x = -2.204 |  alpha_y = 1.120
# s = 447.307 m  |  beta_x = 129.942  | beta_y = 19.886  |  alpha_x = -2.210 |  alpha_y = 1.106
# s = 447.407 m  |  beta_x = 130.384  | beta_y = 19.666  |  alpha_x = -2.215 |  alpha_y = 1.095
# s = 447.557 m  |  beta_x = 131.049  | beta_y = 19.340  |  alpha_x = -2.221 |  alpha_y = 1.078
# s = 447.707 m  |  beta_x = 131.717  | beta_y = 19.019  |  alpha_x = -2.228 |  alpha_y = 1.061
# s = 447.807 m  |  beta_x = 132.163  | beta_y = 18.808  |  alpha_x = -2.233 |  alpha_y = 1.050
# s = 448.336 m  |  beta_x = 134.537  | beta_y = 17.728  |  alpha_x = -2.257 |  alpha_y = 0.991
# s = 450.148 m  |  beta_x = 166.557  | beta_y = 14.421  |  alpha_x = -8.981 |  alpha_y = 0.829
# s = 450.535 m  |  beta_x = 173.572  | beta_y = 13.797  |  alpha_x = -9.171 |  alpha_y = 0.784
# s = 452.347 m  |  beta_x = 267.807  | beta_y = 11.277  |  alpha_x = -21.390 |  alpha_y = 0.603
# s = 452.668 m  |  beta_x = 281.711  | beta_y = 10.902  |  alpha_x = -21.939 |  alpha_y = 0.565
# s = 452.768 m  |  beta_x = 286.116  | beta_y = 10.790  |  alpha_x = -22.111 |  alpha_y = 0.552
# s = 452.816 m  |  beta_x = 288.242  | beta_y = 10.737  |  alpha_x = -22.193 |  alpha_y = 0.547
# s = 452.906 m  |  beta_x = 292.251  | beta_y = 10.640  |  alpha_x = -22.347 |  alpha_y = 0.536
# s = 452.993 m  |  beta_x = 296.148  | beta_y = 10.548  |  alpha_x = -22.496 |  alpha_y = 0.525
# s = 453.369 m  |  beta_x = 286.820  | beta_y = 11.110  |  alpha_x = 46.552 |  alpha_y = -2.064
# s = 453.476 m  |  beta_x = 276.954  | beta_y = 11.557  |  alpha_x = 45.744 |  alpha_y = -2.115
# s = 453.601 m  |  beta_x = 265.636  | beta_y = 12.093  |  alpha_x = 44.799 |  alpha_y = -2.174
# s = 453.726 m  |  beta_x = 254.554  | beta_y = 12.644  |  alpha_x = 43.854 |  alpha_y = -2.233
# s = 454.174 m  |  beta_x = 216.790  | beta_y = 14.739  |  alpha_x = 40.469 |  alpha_y = -2.445
# s = 454.274 m  |  beta_x = 212.066  | beta_y = 15.229  |  alpha_x = 39.621 |  alpha_y = -2.471
# s = 454.374 m  |  beta_x = 207.395  | beta_y = 15.727  |  alpha_x = 39.080 |  alpha_y = -2.518
# s = 454.474 m  |  beta_x = 202.777  | beta_y = 16.236  |  alpha_x = 38.538 |  alpha_y = -2.564
# s = 454.574 m  |  beta_x = 198.212  | beta_y = 16.753  |  alpha_x = 37.996 |  alpha_y = -2.611
# s = 454.674 m  |  beta_x = 193.701  | beta_y = 17.280  |  alpha_x = 37.453 |  alpha_y = -2.658
# s = 454.774 m  |  beta_x = 189.244  | beta_y = 17.816  |  alpha_x = 36.910 |  alpha_y = -2.704
# s = 454.874 m  |  beta_x = 184.841  | beta_y = 18.362  |  alpha_x = 36.367 |  alpha_y = -2.751
# s = 454.974 m  |  beta_x = 180.494  | beta_y = 18.917  |  alpha_x = 35.823 |  alpha_y = -2.798
# s = 455.074 m  |  beta_x = 176.201  | beta_y = 19.481  |  alpha_x = 35.280 |  alpha_y = -2.844
# s = 455.174 m  |  beta_x = 171.964  | beta_y = 20.054  |  alpha_x = 34.736 |  alpha_y = -2.891
# s = 455.274 m  |  beta_x = 167.783  | beta_y = 20.637  |  alpha_x = 34.193 |  alpha_y = -2.938
# s = 455.374 m  |  beta_x = 163.657  | beta_y = 21.229  |  alpha_x = 33.650 |  alpha_y = -2.984
# s = 455.474 m  |  beta_x = 159.588  | beta_y = 21.831  |  alpha_x = 33.107 |  alpha_y = -3.031
# s = 455.574 m  |  beta_x = 155.576  | beta_y = 22.442  |  alpha_x = 32.564 |  alpha_y = -3.078
# s = 455.674 m  |  beta_x = 151.621  | beta_y = 23.062  |  alpha_x = 32.023 |  alpha_y = -3.124
# s = 455.774 m  |  beta_x = 147.723  | beta_y = 23.691  |  alpha_x = 31.481 |  alpha_y = -3.171
# s = 455.874 m  |  beta_x = 143.882  | beta_y = 24.330  |  alpha_x = 30.941 |  alpha_y = -3.218
# s = 455.974 m  |  beta_x = 140.100  | beta_y = 24.978  |  alpha_x = 30.401 |  alpha_y = -3.264
# s = 455.987 m  |  beta_x = 139.599  | beta_y = 25.066  |  alpha_x = 30.131 |  alpha_y = -3.235
# s = 456.373 m  |  beta_x = 117.324  | beta_y = 27.629  |  alpha_x = 27.620 |  alpha_y = -3.411
# s = 458.186 m  |  beta_x = 63.072  | beta_y = 41.332  |  alpha_x = 17.925 |  alpha_y = -4.126
# s = 458.489 m  |  beta_x = 52.683  | beta_y = 43.871  |  alpha_x = 16.377 |  alpha_y = -4.258
# s = 458.589 m  |  beta_x = 49.459  | beta_y = 44.727  |  alpha_x = 15.866 |  alpha_y = -4.301
# s = 458.789 m  |  beta_x = 43.317  | beta_y = 46.465  |  alpha_x = 14.844 |  alpha_y = -4.389
# s = 458.977 m  |  beta_x = 37.934  | beta_y = 48.125  |  alpha_x = 13.887 |  alpha_y = -4.470
# s = 459.502 m  |  beta_x = 26.775  | beta_y = 49.499  |  alpha_x = 7.842 |  alpha_y = 1.916
# s = 459.609 m  |  beta_x = 25.118  | beta_y = 49.088  |  alpha_x = 7.591 |  alpha_y = 1.905
# s = 459.734 m  |  beta_x = 23.257  | beta_y = 48.614  |  alpha_x = 7.299 |  alpha_y = 1.894
# s = 459.859 m  |  beta_x = 21.468  | beta_y = 48.142  |  alpha_x = 7.008 |  alpha_y = 1.882
# s = 459.962 m  |  beta_x = 20.058  | beta_y = 47.757  |  alpha_x = 6.769 |  alpha_y = 1.872
# s = 460.211 m  |  beta_x = 16.830  | beta_y = 46.830  |  alpha_x = 6.187 |  alpha_y = 1.849
# s = 460.311 m  |  beta_x = 15.946  | beta_y = 46.455  |  alpha_x = 5.914 |  alpha_y = 1.872
# s = 460.411 m  |  beta_x = 15.106  | beta_y = 46.082  |  alpha_x = 5.662 |  alpha_y = 1.862
# s = 460.511 m  |  beta_x = 14.309  | beta_y = 45.710  |  alpha_x = 5.416 |  alpha_y = 1.852
# s = 460.611 m  |  beta_x = 13.552  | beta_y = 45.341  |  alpha_x = 5.178 |  alpha_y = 1.843
# s = 460.711 m  |  beta_x = 12.834  | beta_y = 44.973  |  alpha_x = 4.948 |  alpha_y = 1.833
# s = 460.811 m  |  beta_x = 12.156  | beta_y = 44.607  |  alpha_x = 4.725 |  alpha_y = 1.823
# s = 460.911 m  |  beta_x = 11.515  | beta_y = 44.244  |  alpha_x = 4.510 |  alpha_y = 1.814
# s = 461.011 m  |  beta_x = 10.910  | beta_y = 43.882  |  alpha_x = 4.301 |  alpha_y = 1.804
# s = 461.111 m  |  beta_x = 10.341  | beta_y = 43.522  |  alpha_x = 4.100 |  alpha_y = 1.794
# s = 461.211 m  |  beta_x = 9.807  | beta_y = 43.164  |  alpha_x = 3.906 |  alpha_y = 1.785
# s = 461.211 m  |  beta_x = 9.806  | beta_y = 43.164  |  alpha_x = 3.899 |  alpha_y = 1.815
# s = 461.631 m  |  beta_x = 6.823  | beta_y = 41.657  |  alpha_x = 3.205 |  alpha_y = 1.773
# s = 461.731 m  |  beta_x = 6.389  | beta_y = 41.297  |  alpha_x = 3.021 |  alpha_y = 1.792
# s = 461.831 m  |  beta_x = 5.986  | beta_y = 40.940  |  alpha_x = 2.849 |  alpha_y = 1.782
# s = 461.931 m  |  beta_x = 5.611  | beta_y = 40.585  |  alpha_x = 2.683 |  alpha_y = 1.772
# s = 462.031 m  |  beta_x = 5.265  | beta_y = 40.231  |  alpha_x = 2.525 |  alpha_y = 1.762
# s = 462.131 m  |  beta_x = 4.946  | beta_y = 39.880  |  alpha_x = 2.372 |  alpha_y = 1.751
# s = 462.231 m  |  beta_x = 4.653  | beta_y = 39.531  |  alpha_x = 2.226 |  alpha_y = 1.741
# s = 462.331 m  |  beta_x = 4.387  | beta_y = 39.183  |  alpha_x = 2.086 |  alpha_y = 1.731
# s = 462.431 m  |  beta_x = 4.146  | beta_y = 38.838  |  alpha_x = 1.953 |  alpha_y = 1.721
# s = 462.531 m  |  beta_x = 3.930  | beta_y = 38.495  |  alpha_x = 1.825 |  alpha_y = 1.711
# s = 462.631 m  |  beta_x = 3.738  | beta_y = 38.154  |  alpha_x = 1.703 |  alpha_y = 1.700
# s = 462.631 m  |  beta_x = 3.738  | beta_y = 38.154  |  alpha_x = 1.701 |  alpha_y = 1.727
# s = 463.051 m  |  beta_x = 2.493  | beta_y = 36.721  |  alpha_x = 1.263 |  alpha_y = 1.683
# s = 463.151 m  |  beta_x = 2.357  | beta_y = 36.381  |  alpha_x = 1.151 |  alpha_y = 1.696
# s = 463.251 m  |  beta_x = 2.242  | beta_y = 36.043  |  alpha_x = 1.046 |  alpha_y = 1.685
# s = 463.351 m  |  beta_x = 2.149  | beta_y = 35.707  |  alpha_x = 0.946 |  alpha_y = 1.674
# s = 463.451 m  |  beta_x = 2.077  | beta_y = 35.373  |  alpha_x = 0.852 |  alpha_y = 1.664
# s = 463.551 m  |  beta_x = 2.028  | beta_y = 35.042  |  alpha_x = 0.762 |  alpha_y = 1.653
# s = 463.651 m  |  beta_x = 2.001  | beta_y = 34.712  |  alpha_x = 0.676 |  alpha_y = 1.642
# s = 463.751 m  |  beta_x = 1.997  | beta_y = 34.385  |  alpha_x = 0.596 |  alpha_y = 1.632
# s = 463.851 m  |  beta_x = 2.020  | beta_y = 34.059  |  alpha_x = 0.519 |  alpha_y = 1.621
# s = 463.951 m  |  beta_x = 2.071  | beta_y = 33.736  |  alpha_x = 0.446 |  alpha_y = 1.611
# s = 464.051 m  |  beta_x = 2.153  | beta_y = 33.415  |  alpha_x = 0.377 |  alpha_y = 1.600
# s = 464.051 m  |  beta_x = 2.153  | beta_y = 33.415  |  alpha_x = 0.376 |  alpha_y = 1.621
# s = 464.471 m  |  beta_x = 1.931  | beta_y = 32.073  |  alpha_x = 0.153 |  alpha_y = 1.575
# s = 464.571 m  |  beta_x = 2.109  | beta_y = 31.749  |  alpha_x = 0.083 |  alpha_y = 1.614
# s = 464.671 m  |  beta_x = 2.346  | beta_y = 31.427  |  alpha_x = 0.018 |  alpha_y = 1.602
# s = 464.771 m  |  beta_x = 2.664  | beta_y = 31.108  |  alpha_x = -0.047 |  alpha_y = 1.591
# s = 464.871 m  |  beta_x = 3.097  | beta_y = 30.791  |  alpha_x = -0.116 |  alpha_y = 1.580
# s = 464.971 m  |  beta_x = 3.705  | beta_y = 30.476  |  alpha_x = -0.193 |  alpha_y = 1.568
# s = 465.071 m  |  beta_x = 4.599  | beta_y = 30.163  |  alpha_x = -0.286 |  alpha_y = 1.557
# s = 465.171 m  |  beta_x = 6.009  | beta_y = 29.853  |  alpha_x = -0.414 |  alpha_y = 1.546
# s = 465.271 m  |  beta_x = 8.457  | beta_y = 29.545  |  alpha_x = -0.617 |  alpha_y = 1.534
# s = 465.371 m  |  beta_x = 13.033  | beta_y = 29.239  |  alpha_x = -0.983 |  alpha_y = 1.523
# s = 465.471 m  |  beta_x = 17.954  | beta_y = 28.936  |  alpha_x = -1.383 |  alpha_y = 1.512
# s = 465.471 m  |  beta_x = 17.955  | beta_y = 28.935  |  alpha_x = -1.384 |  alpha_y = 1.512
# s = 465.778 m  |  beta_x = 18.820  | beta_y = 28.018  |  alpha_x = -1.433 |  alpha_y = 1.477
# s = 466.604 m  |  beta_x = 18.869  | beta_y = 29.065  |  alpha_x = 1.376 |  alpha_y = -2.797

# %%
def get_energy_at_s(s_target, tws_list):
    s_array = np.array([tw.s for tw in tws_list])
    E_array = np.array([tw.E for tw in tws_list])
    return np.interp(s_target, s_array, E_array)

# %%
def plot_opt_func(lat, tws, top_plot=["Dx"], legend=True, fig_name=None, grid=True, font_size=12,
                  excld_legend=None, figsize=None, plt_figure=None):
    from ocelot.cpbd.optics import lattice_transfer_map

    if plt_figure is None:
        if fig_name is None:
            fig = plt.figure(figsize=figsize)
        else:
            fig = plt.figure(fig_name, figsize=figsize)
    else:
        fig = plt_figure

    plt.rc('axes', grid=grid)
    plt.rc('grid', color='0.75', linestyle='-', linewidth=0.5)
    left, width = 0.1, 0.85

    rect1 = [left, 0.65, width, 0.3]
    rect2 = [left, 0.19, width, 0.46]
    rect3 = [left, 0.07, width, 0.12]

    ax_top = fig.add_axes(rect1)
    ax_b = fig.add_axes(rect2, sharex=ax_top)
    ax_el = fig.add_axes(rect3, sharex=ax_top)

    for ax in ax_b, ax_el, ax_top:
        if ax != ax_el:
            for label in ax.get_xticklabels():
                label.set_visible(False)

    ax_b.grid(grid)
    ax_top.grid(grid)
    ax_el.set_yticks([])
    ax_el.grid(grid)

    fig.subplots_adjust(hspace=0)
    beta_x = [p.beta_x for p in tws]
    beta_y = [p.beta_y for p in tws]
    S = [p.s for p in tws]

    plt.xlim(S[0], S[-1])

    # Plot standard Twiss parameters
    plot_disp(ax_top, tws, [p for p in top_plot if p != "R56"], font_size)

    # ---- Add R56 Plotting ----
    if "R56" in top_plot:
        R56_vals = []
        s_vals = []

        for i in range(2, len(lat.sequence)):
            partial_lat = MagneticLattice(lat.sequence[:i])
            s_here = sum(e.l for e in partial_lat.sequence)

            try:
                E_here = get_energy_at_s(s_here, tws)
                R = lattice_transfer_map(partial_lat, energy=E_here)
                r56 = R[4, 5]
            except Exception as e:
                print(f"[WARN] Failed R56 at s = {s_here:.2f} m: {e}")
                r56 = 0

            # Debug print
            if i % 50 == 0 or s_here > 100:  # customize condition as you like
                print(f"s = {s_here:.2f} m, E = {E_here:.3f} GeV, R56 = {r56*1000:.3f} mm")

            R56_vals.append(r56)
            s_vals.append(s_here)

        
        ax_top.plot(s_vals, np.array(R56_vals), label="R56 [m]", color="red", linewidth=2)

    if "R56" in top_plot or legend:
        ax_top.legend(fontsize=font_size - 2)

    # Plot betas and elements
    plot_betas(ax_b, S, beta_x, beta_y, font_size)
    plot_elems(fig, ax_el, lat, s_point=S[0], legend=legend, y_scale=0.8, font_size=font_size,
               excld_legend=excld_legend)

# %%
plot_opt_func(lat, tws, top_plot=["Dx", "R56"], legend=True )
# Out:
# s = 16.78 m, E = 7.000 GeV, R56 = -115.002 mm
# s = 34.79 m, E = 7.000 GeV, R56 = 5.696 mm
# s = 50.56 m, E = 7.000 GeV, R56 = 7.436 mm
# s = 74.91 m, E = 7.000 GeV, R56 = 20.367 mm
# s = 101.01 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 101.21 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 101.40 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 101.93 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 101.93 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 102.03 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 102.16 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 102.16 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 102.28 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 108.21 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 108.41 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 108.60 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.12 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.12 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.23 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.36 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.36 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.48 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 115.22 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 115.42 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 115.60 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 115.60 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.13 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.13 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.24 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.36 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.36 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.49 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.58 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.70 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.70 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.83 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 117.08 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 129.65 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 129.85 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.04 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.56 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.56 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.67 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.79 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.79 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.92 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 131.01 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 131.26 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 131.38 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 131.38 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 131.51 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 144.08 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 144.28 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 144.47 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 144.99 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 144.99 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.10 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.23 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.23 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.35 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.44 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.69 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.82 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.82 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.94 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 158.51 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 158.71 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 158.90 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.43 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.43 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.53 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.66 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.66 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.78 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.87 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 160.12 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 160.25 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 160.25 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 160.37 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 172.95 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 173.15 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 173.33 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 173.86 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 173.86 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 173.97 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.09 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.09 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.22 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.31 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.56 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.68 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.68 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.81 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 187.38 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 187.58 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 187.77 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.29 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.29 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.40 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.53 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.53 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.65 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.90 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.99 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 189.12 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 189.12 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 189.24 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 201.81 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.01 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.20 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.73 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.73 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.83 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.96 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.96 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.08 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.18 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.18 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.28 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.38 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.67 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.67 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 205.76 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 205.76 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 211.43 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 211.63 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 211.63 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 211.90 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 213.98 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 213.98 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 214.30 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 214.83 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 214.83 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 214.94 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 215.04 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 215.04 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 215.14 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 215.37 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 217.45 m, E = 7.000 GeV, R56 = 316.219 mm
# s = 217.45 m, E = 7.000 GeV, R56 = 316.219 mm
# s = 217.72 m, E = 7.000 GeV, R56 = 316.219 mm
# s = 219.80 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 219.80 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.03 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.05 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.05 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.08 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.17 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.54 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.54 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.68 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.80 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.80 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.93 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 221.16 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 223.23 m, E = 7.000 GeV, R56 = 816.646 mm
# s = 223.23 m, E = 7.000 GeV, R56 = 816.646 mm
# s = 223.51 m, E = 7.000 GeV, R56 = 816.646 mm
# s = 225.58 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 225.58 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 225.83 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 226.03 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 226.22 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 226.74 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 226.74 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 226.88 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 227.01 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 227.01 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 227.13 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 227.36 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 229.44 m, E = 7.000 GeV, R56 = 1266.503 mm
# s = 229.44 m, E = 7.000 GeV, R56 = 1266.503 mm
# s = 229.71 m, E = 7.000 GeV, R56 = 1266.503 mm
# s = 231.79 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 231.79 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.15 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.53 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.53 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.66 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.79 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.79 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.91 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 233.14 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 235.22 m, E = 7.000 GeV, R56 = 1649.237 mm
# s = 235.22 m, E = 7.000 GeV, R56 = 1649.237 mm
# s = 235.49 m, E = 7.000 GeV, R56 = 1649.237 mm
# s = 237.57 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 237.57 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 237.81 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.01 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.20 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.73 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.73 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.86 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.99 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.99 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 239.11 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 239.34 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 241.42 m, E = 7.000 GeV, R56 = 1648.794 mm
# s = 241.42 m, E = 7.000 GeV, R56 = 1648.794 mm
# s = 241.69 m, E = 7.000 GeV, R56 = 1648.794 mm
# s = 243.77 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 243.77 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.13 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.51 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.51 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.65 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.77 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.77 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.90 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 245.12 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 247.20 m, E = 7.000 GeV, R56 = 1431.279 mm
# s = 247.20 m, E = 7.000 GeV, R56 = 1431.279 mm
# s = 247.47 m, E = 7.000 GeV, R56 = 1431.279 mm
# s = 249.55 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 249.55 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 249.80 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.00 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.19 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.71 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.71 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.85 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.97 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.97 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 251.10 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 251.32 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 253.40 m, E = 7.000 GeV, R56 = 1500.878 mm
# s = 253.40 m, E = 7.000 GeV, R56 = 1500.878 mm
# s = 253.67 m, E = 7.000 GeV, R56 = 1500.878 mm
# s = 255.75 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 255.75 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.12 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.49 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.49 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.63 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.75 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.75 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.88 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 257.11 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 259.18 m, E = 7.000 GeV, R56 = 1959.870 mm
# s = 259.18 m, E = 7.000 GeV, R56 = 1959.870 mm
# s = 259.46 m, E = 7.000 GeV, R56 = 1959.870 mm
# s = 261.53 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 261.53 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 261.78 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 261.98 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.17 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.69 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.69 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.83 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.96 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.96 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 263.08 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 263.31 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 265.39 m, E = 7.000 GeV, R56 = 2175.077 mm
# s = 265.39 m, E = 7.000 GeV, R56 = 2175.077 mm
# s = 265.39 m, E = 7.000 GeV, R56 = 2175.077 mm
# s = 269.90 m, E = 7.000 GeV, R56 = 2175.077 mm
# s = 269.90 m, E = 7.000 GeV, R56 = 2175.077 mm
# s = 271.98 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 271.98 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 271.98 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 272.43 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 272.96 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 272.96 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 273.06 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 273.19 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 273.19 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 273.31 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 274.70 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 274.83 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 274.83 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 274.95 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 278.67 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 278.87 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 278.97 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.10 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.10 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.22 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.33 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.86 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.86 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 286.93 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.45 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.45 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.56 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.68 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.68 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.81 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.91 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 288.11 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 294.13 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 294.33 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 294.52 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.05 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.05 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.15 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.28 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.28 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.40 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.36 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.48 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.48 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.61 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.73 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.73 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.86 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 297.13 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 297.13 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 299.22 m, E = 7.000 GeV, R56 = 2179.890 mm
# s = 299.22 m, E = 7.000 GeV, R56 = 2179.890 mm
# s = 299.22 m, E = 7.000 GeV, R56 = 2179.890 mm
# s = 299.49 m, E = 7.000 GeV, R56 = 2179.890 mm
# s = 301.57 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 301.57 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 301.95 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.33 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.33 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.44 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.56 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.56 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.69 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.92 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 305.00 m, E = 7.000 GeV, R56 = 2259.374 mm
# s = 305.00 m, E = 7.000 GeV, R56 = 2259.374 mm
# s = 305.32 m, E = 7.000 GeV, R56 = 2259.374 mm
# s = 307.40 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 307.40 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 307.97 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 308.17 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 308.36 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 308.88 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 308.88 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 308.99 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 309.11 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 309.11 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 309.24 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 309.47 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 311.55 m, E = 7.000 GeV, R56 = 2520.196 mm
# s = 311.55 m, E = 7.000 GeV, R56 = 2520.196 mm
# s = 311.87 m, E = 7.000 GeV, R56 = 2520.196 mm
# s = 313.95 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 313.95 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.34 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.71 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.71 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.82 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.94 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.94 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 315.07 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 315.30 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 317.38 m, E = 7.000 GeV, R56 = 2951.643 mm
# s = 317.38 m, E = 7.000 GeV, R56 = 2951.643 mm
# s = 317.70 m, E = 7.000 GeV, R56 = 2951.643 mm
# s = 319.78 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 319.78 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 320.35 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 320.55 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 320.74 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.26 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.26 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.37 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.50 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.50 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.62 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.85 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 323.93 m, E = 7.000 GeV, R56 = 3050.050 mm
# s = 323.93 m, E = 7.000 GeV, R56 = 3050.050 mm
# s = 324.25 m, E = 7.000 GeV, R56 = 3050.050 mm
# s = 326.54 m, E = 7.000 GeV, R56 = 3112.713 mm
# s = 326.54 m, E = 7.000 GeV, R56 = 3112.713 mm
# s = 330.21 m, E = 7.000 GeV, R56 = 3112.713 mm
# s = 330.21 m, E = 7.000 GeV, R56 = 3112.713 mm
# s = 332.50 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 332.50 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.31 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.68 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.68 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.79 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.92 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.92 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 334.04 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 334.49 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 336.78 m, E = 7.000 GeV, R56 = 3607.760 mm
# s = 336.78 m, E = 7.000 GeV, R56 = 3607.760 mm
# s = 337.09 m, E = 7.000 GeV, R56 = 3607.760 mm
# s = 339.38 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 339.38 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 339.78 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 339.98 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.16 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.69 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.69 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.80 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.92 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.92 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 341.05 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 341.47 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 343.77 m, E = 7.000 GeV, R56 = 4071.474 mm
# s = 343.77 m, E = 7.000 GeV, R56 = 4071.474 mm
# s = 344.07 m, E = 7.000 GeV, R56 = 4071.474 mm
# s = 346.36 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 346.36 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.17 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.55 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.55 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.65 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.78 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.78 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.90 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.99 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 348.12 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 348.12 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 348.24 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 348.35 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 350.65 m, E = 7.000 GeV, R56 = 4663.495 mm
# s = 350.65 m, E = 7.000 GeV, R56 = 4663.495 mm
# s = 350.95 m, E = 7.000 GeV, R56 = 4663.495 mm
# s = 353.25 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 353.25 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 353.64 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 353.84 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.03 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.55 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.55 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.66 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.79 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.79 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.91 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 355.29 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 357.58 m, E = 7.000 GeV, R56 = 4848.384 mm
# s = 357.58 m, E = 7.000 GeV, R56 = 4848.384 mm
# s = 357.89 m, E = 7.000 GeV, R56 = 4848.384 mm
# s = 360.18 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 360.18 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 360.18 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 360.96 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.49 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.49 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.49 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.60 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.70 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.70 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.80 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 362.05 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 363.96 m, E = 7.000 GeV, R56 = 4853.532 mm
# s = 363.96 m, E = 7.000 GeV, R56 = 4853.532 mm
# s = 364.14 m, E = 7.000 GeV, R56 = 4853.532 mm
# s = 364.14 m, E = 7.000 GeV, R56 = 4853.532 mm
# s = 364.31 m, E = 7.000 GeV, R56 = 4853.532 mm
# s = 366.22 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 366.22 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 367.80 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 368.30 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 368.40 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 368.60 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 368.79 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.31 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.31 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.42 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.55 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.55 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.67 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.37 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.50 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.50 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.62 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.75 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.75 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.87 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.97 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 376.17 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 376.36 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 376.89 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 376.89 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 376.99 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 377.12 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 377.12 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 377.24 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 382.95 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 383.45 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 383.55 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 383.75 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 383.94 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 383.94 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.46 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.46 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.57 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.69 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.69 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.82 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.52 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.65 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.65 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.77 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.90 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.90 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 391.02 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 391.12 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 391.32 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 391.51 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.04 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.04 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.14 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.27 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.27 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.39 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 398.10 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 398.60 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 398.70 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 398.90 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.08 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.61 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.61 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.72 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.84 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.84 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.97 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 405.67 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 406.17 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 406.27 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 406.47 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 406.66 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.18 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.18 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.29 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.39 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.39 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.49 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.77 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 409.67 m, E = 7.000 GeV, R56 = 4882.511 mm
# s = 409.67 m, E = 7.000 GeV, R56 = 4882.511 mm
# s = 409.85 m, E = 7.000 GeV, R56 = 4882.511 mm
# s = 409.85 m, E = 7.000 GeV, R56 = 4882.511 mm
# s = 410.02 m, E = 7.000 GeV, R56 = 4882.511 mm
# s = 411.93 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 411.93 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 412.78 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 415.66 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 415.78 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 415.78 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 415.91 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.03 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.03 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.16 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.26 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.46 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.64 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.17 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.17 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.28 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.40 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.40 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.53 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.39 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.51 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.51 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.64 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.76 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.76 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.89 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.98 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.35 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.35 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.46 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.58 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.58 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.71 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 426.06 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 426.06 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 427.87 m, E = 7.000 GeV, R56 = 4886.259 mm
# s = 427.87 m, E = 7.000 GeV, R56 = 4886.259 mm
# s = 428.26 m, E = 7.000 GeV, R56 = 4886.259 mm
# s = 430.07 m, E = 7.000 GeV, R56 = 4899.175 mm
# s = 430.07 m, E = 7.000 GeV, R56 = 4899.175 mm
# s = 430.74 m, E = 7.000 GeV, R56 = 4899.175 mm
# s = 432.55 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 432.55 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 432.93 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 433.13 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 433.32 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 433.85 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 433.85 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 433.95 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 434.08 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 434.08 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 434.20 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 434.54 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 436.35 m, E = 7.000 GeV, R56 = 5053.923 mm
# s = 436.35 m, E = 7.000 GeV, R56 = 5053.923 mm
# s = 436.74 m, E = 7.000 GeV, R56 = 5053.923 mm
# s = 438.55 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 438.55 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 438.87 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 438.97 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.02 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.14 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.27 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.35 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.73 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.73 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.84 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.96 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.96 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 440.09 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 440.44 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 442.25 m, E = 7.000 GeV, R56 = 5447.823 mm
# s = 442.25 m, E = 7.000 GeV, R56 = 5447.823 mm
# s = 442.63 m, E = 7.000 GeV, R56 = 5447.823 mm
# s = 444.45 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 444.45 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.10 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.22 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.22 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.35 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.47 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.47 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.60 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.85 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.94 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 446.04 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 446.24 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 446.42 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 446.95 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 446.95 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.06 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.18 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.18 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.31 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.41 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.56 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.56 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.71 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.81 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 448.34 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 450.15 m, E = 7.000 GeV, R56 = 5746.290 mm
# s = 450.15 m, E = 7.000 GeV, R56 = 5746.290 mm
# s = 450.53 m, E = 7.000 GeV, R56 = 5746.290 mm
# s = 452.35 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.35 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.67 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.77 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.82 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.91 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.99 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.37 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.37 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.48 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.60 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.60 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.73 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 454.17 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 455.99 m, E = 7.000 GeV, R56 = 6010.536 mm
# s = 455.99 m, E = 7.000 GeV, R56 = 6010.536 mm
# s = 456.37 m, E = 7.000 GeV, R56 = 6010.536 mm
# s = 458.19 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 458.19 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 458.49 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 458.59 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 458.79 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 458.98 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.50 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.50 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.61 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.73 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.73 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.86 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.74 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.74 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.96 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 460.21 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 461.21 m, E = 7.000 GeV, R56 = 6094.605 mm
# s = 461.21 m, E = 7.000 GeV, R56 = 6094.605 mm
# s = 461.63 m, E = 7.000 GeV, R56 = 6094.605 mm
# s = 462.63 m, E = 7.000 GeV, R56 = 6101.035 mm
# s = 462.63 m, E = 7.000 GeV, R56 = 6101.035 mm
# s = 463.05 m, E = 7.000 GeV, R56 = 6101.035 mm
# s = 464.05 m, E = 7.000 GeV, R56 = 6103.335 mm
# s = 464.05 m, E = 7.000 GeV, R56 = 6103.335 mm
# s = 464.05 m, E = 7.000 GeV, R56 = 6103.335 mm
# s = 464.47 m, E = 7.000 GeV, R56 = 6103.335 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.78 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.78 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.78 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 466.60 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 466.60 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 466.60 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 466.60 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 466.60 m, E = 7.000 GeV, R56 = 6103.725 mm

# %%
# # Your element IDs
# start_id = "PA1RFGUN"
# end_id   = "L491"

# # Find their indices in the lattice
# start_index = next(i for i, el in enumerate(lattice_list) if el.id == start_id)
# end_index   = next(i for i, el in enumerate(lattice_list) if el.id == end_id)

# # Create the sub-lattice
# partial_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

# # Get s-positions of those indices
# s_start = sum(el.l for el in lattice_list[:start_index])
# s_end   = sum(el.l for el in lattice_list[:end_index + 1])
# s_mid   = 0.5 * (s_start + s_end)

# # Interpolate energy at midpoint
# E_here = get_energy_at_s(s_mid, tws)

# # Calculate R56
# R = lattice_transfer_map(partial_lat, energy=E_here)
# r56 = R[4, 5]

# # Print result
# print(f"R56 from '{start_id}' to '{end_id}' (s = {s_start:.2f} to {s_end:.2f} m, E ≈ {E_here:.3f} GeV): R56 = {r56*1000:.3f} mm")

# %%
# def compute_r56_with_energy_evolution(lat_list, tws, id_start, id_end):
#     # Find element indices
#     i_start = next(i for i, el in enumerate(lat_list) if el.id == id_start)
#     i_end   = next(i for i, el in enumerate(lat_list) if el.id == id_end)

#     # Build the sub-lattice
#     partial_lat = MagneticLattice(lat_list[i_start:i_end + 1])

#     # Use starting energy from Twiss at i_start
#     s_start = sum(e.l for e in lat_list[:i_start])
#     E_start = get_energy_at_s(s_start, tws)

#     # Compute transfer maps at every step (tracks energy changes!)
#     Bs, Rs, Ts, Ss = partial_lat.transfer_maps(energy=E_start, output_at_each_step=True)

#     # Get the last transfer matrix — full map from PJARCM1 to PSECTC
#     R_final = Rs[-1]
#     r56 = R_final[4, 5]

#     s_end = s_start + sum(e.l for e in lat_list[i_start:i_end + 1])
#     print(f"R56 from '{id_start}' to '{id_end}' (s = {s_start:.2f} → {s_end:.2f} m): R56 = {r56*1000:.3f} mm")

# %%
# compute_r56_with_energy_evolution(lattice_list, tws, "PA1RFGUN", "L491")

# %%
final_twiss = tws_track[-1]

print("\n===== Final Beam Parameters =====")
print(f"Position s (m):       {final_twiss.s:.4f}")
print(f"Energy E (GeV):       {final_twiss.E:.6f}")
print(f"Beta X (βx) (m):      {final_twiss.beta_x:.6f}")
print(f"Beta Y (βy) (m):      {final_twiss.beta_y:.6f}")
print(f"Alpha X (αx):         {final_twiss.alpha_x:.6f}")
print(f"Alpha Y (αy):         {final_twiss.alpha_y:.6f}")
print(f"Norm. Emit X (m.rad): {final_twiss.emit_xn:.6e}")
print(f"Norm. Emit Y (m.rad): {final_twiss.emit_yn:.6e}")
print(f"Geom. Emit X (m.rad): {final_twiss.emit_x:.6e}")
print(f"Geom. Emit Y (m.rad): {final_twiss.emit_y:.6e}")
# Out:
# ===== Final Beam Parameters =====
# Position s (m):       466.6043
# Energy E (GeV):       7.000000
# Beta X (βx) (m):      18.868923
# Beta Y (βy) (m):      29.065398
# Alpha X (αx):         1.376327
# Alpha Y (αy):         -2.796694
# Norm. Emit X (m.rad): 1.207816e-06
# Norm. Emit Y (m.rad): 1.204031e-06
# Geom. Emit X (m.rad): 8.817034e-11
# Geom. Emit Y (m.rad): 8.789405e-11

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract position and beta functions
s = np.array([tw.s for tw in tws_track])
beta_x = np.array([tw.beta_x for tw in tws_track])
beta_y = np.array([tw.beta_y for tw in tws_track])

# Use initial geometric emittances
emit_x = tw0.emit_x
emit_y = tw0.emit_y

# Compute beam sizes σx and σy in meters
sigma_x = np.sqrt(beta_x * emit_x)
sigma_y = np.sqrt(beta_y * emit_y)

# Plot beam sizes in millimeters
plt.figure(figsize=(10, 6))
plt.plot(s, sigma_x * 1e3, label=r'$\sigma_x$ [mm]', linewidth=2)
plt.plot(s, sigma_y * 1e3, label=r'$\sigma_y$ [mm]', linewidth=2)

plt.xlabel('s [m]', fontsize=14)
plt.ylabel('Beam Size σ [mm]', fontsize=14)
plt.title('Transverse Beam Sizes Along the Lattice', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
show_e_beam(p_array)

# %%
show_e_beam(p_array_t)

# %%
print(np.std(p_array.rparticles[5]))
print("mean:")
print(np.mean(p_array.rparticles[5]))
# Out:
# 0.0005023000839903633
# mean:
# 1.6757896668317998e-06

# %%
print(np.std(p_array_t.rparticles[5]))
print("mean:")
print(np.mean(p_array_t.rparticles[5]))
# Out:
# 0.0005023000844099754
# mean:
# -0.0012933869429611936

# %%
plt.hist(p_array.rparticles[5], bins=100, alpha=0.5, label="Initial", density=True)
plt.hist(p_array_t.rparticles[5], bins=100, alpha=0.5, label="Final", density=True)
plt.axvline(np.mean(p_array.rparticles[5]), color='blue', linestyle='--')
plt.axvline(np.mean(p_array_t.rparticles[5]), color='orange', linestyle='--')
plt.title("Initial vs Final Relative Momentum Spread")
plt.xlabel("dp/p")
plt.ylabel("Normalized Counts")
plt.legend()
plt.grid(True)
plt.show()
