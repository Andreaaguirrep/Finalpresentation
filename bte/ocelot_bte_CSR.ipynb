# %%
from ocelot import *
from ocelot.cpbd.elements import *
from ocelot.gui.accelerator import *
from ocelot.cpbd.track import track_debug
import matplotlib.pyplot as plt


from bte import *

#lat = MagneticLattice(lattice_list[0:380])
#lat = MagneticLattice(lattice_list[320:540])
lat = MagneticLattice(lattice_list)


energy = 7 # GeV  #why?
tw0 = Twiss()
tw0.alpha_x = AX
tw0.beta_x = BX

tw0.alpha_y = AY
tw0.beta_y = BY
tw0.E = energy
tw0.emit_xn = EMITX 
tw0.emit_yn = EMITY
tw0.emit_x = EMITX   / energy * 0.511e-3
tw0.emit_y = EMITY / energy * 0.511e-3

tws = twiss(lat,tw0)

plot_opt_func(lat, tws,legend=False, grid=False, top_plot=['Dx','Dy'])
# Out:
# initializing ocelot...

# %%
# start_index = next(i for i, el in enumerate(lattice_list) if el.id == "PA1RFGUN")
# end_index = next(i for i, el in enumerate(lattice_list) if el.id == "L491")

# sub_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

# R = lattice_transfer_map(sub_lat, energy=1.5)
# print("R56 = ", R[4,5]*1000, "mm")

# %%
def gauss_from_twiss_vec(emit, beta, alpha, size=1):
    phi = 2 * np.pi * np.random.rand(size)
    u = np.random.rand(size)
    a = np.sqrt(-2 * np.log(1 - u) * emit)
    x = a * np.sqrt(beta) * np.cos(phi)
    xp = -a / np.sqrt(beta) * (np.sin(phi) + alpha * np.cos(phi))
    return x, xp

nparticles = 100000
p_array = ParticleArray(n=nparticles)

sigma_tau = 6.7e-3  # m
sigma_p = 5.e-4

p_array.E = energy  # GeV

# Longitudinal
p_array.rparticles[4] = np.random.randn(nparticles) * sigma_tau
p_array.rparticles[5] = np.random.randn(nparticles) * sigma_p

# Transverse: vectorized sampling from Twiss parameters
x, xp = gauss_from_twiss_vec(tw0.emit_x, tw0.beta_x, tw0.alpha_x, size=nparticles)
y, yp = gauss_from_twiss_vec(tw0.emit_y, tw0.beta_y, tw0.alpha_y, size=nparticles)

p_array.rparticles[0] = x
p_array.rparticles[1] = xp
p_array.rparticles[2] = y
p_array.rparticles[3] = yp

# Charge distribution
charge = 4.0e-9  # nC
p_array.q_array = np.ones(nparticles) * (charge / nparticles)

# %%
plt.hist(p_array.rparticles[0], bins=100, alpha=0.7, label='x')
plt.hist(p_array.rparticles[1], bins=100, alpha=0.7, label="x'")
plt.legend()
plt.show()

plt.hist(p_array.rparticles[2], bins=100, alpha=0.7, label='y')
plt.hist(p_array.rparticles[3], bins=100, alpha=0.7, label="y'")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
x = p_array.rparticles[0]
xp = p_array.rparticles[1]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_x, sigma_xp = twiss_sigmas(tw0.emit_x, tw0.beta_x, tw0.alpha_x)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='x (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='x (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="x′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_xp), 'r--', label="x′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of x and x′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
y = p_array.rparticles[2]
yp = p_array.rparticles[3]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_y, sigma_yp = twiss_sigmas(tw0.emit_y, tw0.beta_y, tw0.alpha_y)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='y (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='y (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="y′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_yp), 'r--', label="y′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of y and y′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def check_beam_stats(p_array, twiss, axis_label="x"):
    idx = 0 if axis_label == "x" else 2
    idxp = 1 if axis_label == "x" else 3

    sigma = np.std(p_array.rparticles[idx])
    sigmap = np.std(p_array.rparticles[idxp])

    beta = getattr(twiss, f"beta_{axis_label}")
    alpha = getattr(twiss, f"alpha_{axis_label}")
    emit = getattr(twiss, f"emit_{axis_label}")

    sigma_theo = np.sqrt(beta * emit)
    gamma = (1 + alpha**2) / beta
    sigmap_theo = np.sqrt(gamma * emit)

    print(f"σ_{axis_label} (simulated):     {sigma}")
    print(f"σ_{axis_label} (theoretical):   {sigma_theo}")
    print(f"σ_{axis_label}' (simulated):    {sigmap}")
    print(f"σ_{axis_label}' (theoretical):  {sigmap_theo}")

# %%
check_beam_stats(p_array, tw0, axis_label="x")
# Out:
# σ_x (simulated):     4.288976792555718e-05
# σ_x (theoretical):   4.291163367644033e-05
# σ_x' (simulated):    2.9204802047006856e-06
# σ_x' (theoretical):  2.92787645355913e-06

# %%
check_beam_stats(p_array, tw0, axis_label="y")
# Out:
# σ_y (simulated):     3.9961867551714515e-05
# σ_y (theoretical):   3.99447953007678e-05
# σ_y' (simulated):    2.347900886785083e-06
# σ_y' (theoretical):  2.3535278848054194e-06

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- X plane ---
x = p_array.rparticles[0]
xp = p_array.rparticles[1]
emit_x = tw0.emit_x
beta_x = tw0.beta_x
alpha_x = tw0.alpha_x

theta = np.linspace(0, 2*np.pi, 400)
x_ellipse = np.sqrt(emit_x * beta_x) * np.cos(theta)
xp_ellipse = (-alpha_x * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_x / beta_x)

# --- Y plane ---
y = p_array.rparticles[2]
yp = p_array.rparticles[3]
emit_y = tw0.emit_y
beta_y = tw0.beta_y
alpha_y = tw0.alpha_y

y_ellipse = np.sqrt(emit_y * beta_y) * np.cos(theta)
yp_ellipse = (-alpha_y * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_y / beta_y)

# --- Plot ---
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# x-x'
axes[0].scatter(x, xp, s=1, alpha=0.3, label='Particles')
axes[0].plot(x_ellipse, xp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[0].set_xlabel('x [m]')
axes[0].set_ylabel("x′ [rad]")
axes[0].set_title('Phase space: x vs x′')
axes[0].grid(True)
axes[0].axis('equal')
axes[0].legend()

# y-y'
axes[1].scatter(y, yp, s=1, alpha=0.3, color='orange', label='Particles')
axes[1].plot(y_ellipse, yp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[1].set_xlabel('y [m]')
axes[1].set_ylabel("y′ [rad]")
axes[1].set_title('Phase space: y vs y′')
axes[1].grid(True)
axes[1].axis('equal')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy

def plot_emittances_vs_s(p_array, nparts_in_slice=5000, smooth_param=0.05,
                         tau_units="m", inverse_tau=False, grid=True,
                         title="Normalized Emittances vs s", figsize=(8, 4),
                         filename=None):
    """
    Plot normalized emittances vs longitudinal position s (head-tail slicing).

    :param p_array: ParticleArray object
    :param nparts_in_slice: number of particles per slice
    :param smooth_param: smoothing parameter used in slice analysis
    :param tau_units: 'm', 'mm', or 'um'
    :param inverse_tau: flip the tau axis
    :param grid: show grid
    :param title: plot title
    :param figsize: matplotlib figsize
    :param filename: optional path to save the plot
    """
    # Set scale for s-axis
    tau_factors = {"m": 1, "mm": 1e3, "um": 1e6}
    tau_factor = tau_factors.get(tau_units, 1e3)
    tau_label = f"$s\,[\\mathrm{{{tau_units}}}]$"

    # Deepcopy to preserve original
    p_array_copy = deepcopy(p_array)
    if inverse_tau:
        p_array_copy.tau()[:] *= -1

    # Perform slice analysis (assumes this function exists in your codebase)
    slice_params = global_slice_analysis(p_array_copy, nparts_in_slice, smooth_param)

    # Extract and convert to proper units
    s = slice_params.s * tau_factor
    emit_x = slice_params.exn * 1e6  # [mm·mrad]
    emit_y = slice_params.eyn * 1e6

    # Plot
    plt.figure(figsize=figsize)
    plt.plot(s, emit_x, label=r"$\varepsilon_x$", color='red')
    plt.plot(s, emit_y, label=r"$\varepsilon_y$", color='blue')
    plt.xlabel(tau_label)
    plt.ylabel(r"Normalized Emittance [$\mathrm{mm\cdot{}mrad}$]")
    plt.title(title)
    plt.legend()
    if grid:
        plt.grid(True)
    if filename:
        plt.savefig(filename)
    plt.tight_layout()
    plt.show()

# %%
show_e_beam(p_array)

# %%
plot_emittances_vs_s(p_array)

# %%
import time
navi = Navigator(lat)
navi.unit_step = 0.1 # m, only with CSR

csr = CSR(n_bin=500, m_bin=5, sigma_min=.2e-6)

navi.add_physics_proc(csr, CSR_START, CSR_END)

p_array_t = deepcopy(p_array)

start = time.time()
tws_track, p_array_t = track(lat, p_array_t, navi)
print("\n time exec:", time.time() - start, "sec")
# Out:
# z = 197.4349506814455 / 466.60429345389946. Applied: CSRR

# %%
plot_emittances_vs_s(p_array_t)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_energy_vs_position(tws_track):
    """
    Plot energy E as a function of position s from a list of Twiss-like objects.

    Parameters:
    tws_track (list): List of objects with attributes 's' (position) and 'E' (energy).
    """
    s = np.array([tw.s for tw in tws_track])
    E = np.array([tw.E for tw in tws_track])

    plt.figure(figsize=(10, 6))
    plt.plot(s, E, linewidth=2, marker='o', markersize=4)

    plt.title("Energy vs Position", fontsize=16)
    plt.xlabel("s (m)", fontsize=14)
    plt.ylabel("E (GeV)", fontsize=14)
    plt.grid(True, which='both', linestyle='--', alpha=0.5)
    plt.tick_params(axis='both', labelsize=12)
    plt.tight_layout()
    plt.show()

# %%
plot_energy_vs_position(tws_track)

# %%
# --- After tracking: get final x, x', y, y' ---
x_t = p_array_t.rparticles[0]
xp_t = p_array_t.rparticles[1]
y_t = p_array_t.rparticles[2]
yp_t = p_array_t.rparticles[3]

# --- Plot initial vs final side-by-side ---
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# x-x′ before
axes[0][0].scatter(p_array.rparticles[0], p_array.rparticles[1], s=1, alpha=0.3)
axes[0][0].set_title("x vs x′ (before)")
axes[0][0].set_xlabel("x [m]")
axes[0][0].set_ylabel("x′ [rad]")
axes[0][0].grid(True)
axes[0][0].axis('equal')

# x-x′ after
axes[0][1].scatter(x_t, xp_t, s=1, alpha=0.3)
axes[0][1].set_title("x vs x′ (after)")
axes[0][1].set_xlabel("x [m]")
axes[0][1].set_ylabel("x′ [rad]")
axes[0][1].grid(True)
axes[0][1].axis('equal')

# y-y′ before
axes[1][0].scatter(p_array.rparticles[2], p_array.rparticles[3], s=1, alpha=0.3, color='orange')
axes[1][0].set_title("y vs y′ (before)")
axes[1][0].set_xlabel("y [m]")
axes[1][0].set_ylabel("y′ [rad]")
axes[1][0].grid(True)
axes[1][0].axis('equal')

# y-y′ after
axes[1][1].scatter(y_t, yp_t, s=1, alpha=0.3, color='orange')
axes[1][1].set_title("y vs y′ (after)")
axes[1][1].set_xlabel("y [m]")
axes[1][1].set_ylabel("y′ [rad]")
axes[1][1].grid(True)
axes[1][1].axis('equal')

plt.tight_layout()
plt.show()

# %%
import numpy as np

def compute_emittance(x, xp):
    x_mean = np.mean(x)
    xp_mean = np.mean(xp)

    x_cent = x - x_mean
    xp_cent = xp - xp_mean

    xx = np.mean(x_cent ** 2)
    xpxp = np.mean(xp_cent ** 2)
    xxp = np.mean(x_cent * xp_cent)

    emit = np.sqrt(xx * xpxp - xxp**2)
    return emit

# Final tracked coordinates
x, xp = p_array_t.rparticles[0], p_array_t.rparticles[1]
y, yp = p_array_t.rparticles[2], p_array_t.rparticles[3]

emit_x = compute_emittance(x, xp)
emit_y = compute_emittance(y, yp)

print(f"εₓ (RMS, final) = {emit_x:.5e} m·rad")
print(f"εᵧ (RMS, final) = {emit_y:.5e} m·rad")

emit_x0 = compute_emittance(p_array.rparticles[0], p_array.rparticles[1])
emit_y0 = compute_emittance(p_array.rparticles[2], p_array.rparticles[3])
print("Initial εₓ:", emit_x0)
print("Initial εᵧ:", emit_y0)
# Out:
# εₓ (RMS, final) = 9.74677e-11 m·rad
# εᵧ (RMS, final) = 1.10837e-10 m·rad
# Initial εₓ: 8.770824425575315e-11
# Initial εᵧ: 8.758463556904042e-11

# %%
for tw in tws_track:
    print(f"s = {tw.s:.3f} m  |  beta_x = {tw.beta_x:.3f}  | beta_y = {tw.beta_y:.3f}  |  alpha_x = {tw.alpha_x:.3f} |  alpha_y = {tw.alpha_y:.3f}" )
# Out:
# s = 0.000 m  |  beta_x = 21.016  | beta_y = 18.141  |  alpha_x = 1.024 |  alpha_y = 0.383
# s = 0.000 m  |  beta_x = 21.016  | beta_y = 18.141  |  alpha_x = 1.024 |  alpha_y = 0.383
# s = 0.217 m  |  beta_x = 20.577  | beta_y = 17.978  |  alpha_x = 1.003 |  alpha_y = 0.369
# s = 1.753 m  |  beta_x = 6.880  | beta_y = 16.994  |  alpha_x = -8.882 |  alpha_y = 0.370
# s = 3.536 m  |  beta_x = 75.461  | beta_y = 15.889  |  alpha_x = -29.582 |  alpha_y = 0.250
# s = 4.116 m  |  beta_x = 113.682  | beta_y = 15.621  |  alpha_x = -36.316 |  alpha_y = 0.212
# s = 4.241 m  |  beta_x = 122.942  | beta_y = 15.569  |  alpha_x = -37.768 |  alpha_y = 0.203
# s = 4.366 m  |  beta_x = 132.566  | beta_y = 15.519  |  alpha_x = -39.219 |  alpha_y = 0.195
# s = 4.996 m  |  beta_x = 186.596  | beta_y = 15.300  |  alpha_x = -46.534 |  alpha_y = 0.153
# s = 5.096 m  |  beta_x = 196.019  | beta_y = 15.270  |  alpha_x = -47.695 |  alpha_y = 0.146
# s = 5.196 m  |  beta_x = 205.674  | beta_y = 15.242  |  alpha_x = -48.856 |  alpha_y = 0.139
# s = 5.420 m  |  beta_x = 228.133  | beta_y = 15.183  |  alpha_x = -51.456 |  alpha_y = 0.124
# s = 7.232 m  |  beta_x = 500.798  | beta_y = 14.952  |  alpha_x = -65.754 |  alpha_y = 0.006
# s = 9.366 m  |  beta_x = 820.743  | beta_y = 15.230  |  alpha_x = -84.181 |  alpha_y = -0.137
# s = 9.491 m  |  beta_x = 841.923  | beta_y = 15.265  |  alpha_x = -85.261 |  alpha_y = -0.145
# s = 9.616 m  |  beta_x = 863.373  | beta_y = 15.302  |  alpha_x = -86.340 |  alpha_y = -0.153
# s = 9.723 m  |  beta_x = 882.010  | beta_y = 15.336  |  alpha_x = -87.267 |  alpha_y = -0.160
# s = 10.248 m  |  beta_x = 962.685  | beta_y = 15.744  |  alpha_x = -65.581 |  alpha_y = -0.621
# s = 10.436 m  |  beta_x = 987.415  | beta_y = 15.980  |  alpha_x = -66.419 |  alpha_y = -0.637
# s = 10.636 m  |  beta_x = 1014.161  | beta_y = 16.238  |  alpha_x = -67.312 |  alpha_y = -0.655
# s = 10.710 m  |  beta_x = 1024.194  | beta_y = 16.336  |  alpha_x = -67.644 |  alpha_y = -0.661
# s = 11.010 m  |  beta_x = 1065.183  | beta_y = 16.741  |  alpha_x = -68.985 |  alpha_y = -0.688
# s = 11.084 m  |  beta_x = 1075.466  | beta_y = 16.843  |  alpha_x = -69.317 |  alpha_y = -0.694
# s = 11.284 m  |  beta_x = 1103.371  | beta_y = 17.124  |  alpha_x = -70.211 |  alpha_y = -0.712
# s = 11.472 m  |  beta_x = 1129.836  | beta_y = 17.394  |  alpha_x = -71.048 |  alpha_y = -0.728
# s = 11.997 m  |  beta_x = 1310.806  | beta_y = 16.676  |  alpha_x = -283.335 |  alpha_y = 2.055
# s = 12.104 m  |  beta_x = 1372.344  | beta_y = 16.239  |  alpha_x = -289.910 |  alpha_y = 2.021
# s = 12.229 m  |  beta_x = 1445.778  | beta_y = 15.739  |  alpha_x = -297.565 |  alpha_y = 1.982
# s = 12.354 m  |  beta_x = 1521.127  | beta_y = 15.248  |  alpha_x = -305.221 |  alpha_y = 1.943
# s = 13.417 m  |  beta_x = 2239.144  | beta_y = 11.472  |  alpha_x = -370.317 |  alpha_y = 1.610
# s = 13.517 m  |  beta_x = 2313.820  | beta_y = 11.153  |  alpha_x = -376.441 |  alpha_y = 1.579
# s = 13.617 m  |  beta_x = 2389.720  | beta_y = 10.840  |  alpha_x = -382.566 |  alpha_y = 1.547
# s = 13.707 m  |  beta_x = 2459.079  | beta_y = 10.564  |  alpha_x = -388.078 |  alpha_y = 1.519
# s = 13.924 m  |  beta_x = 2629.787  | beta_y = 9.922  |  alpha_x = -401.322 |  alpha_y = 1.452
# s = 15.473 m  |  beta_x = 3432.117  | beta_y = 6.133  |  alpha_x = -274.975 |  alpha_y = 0.987
# s = 15.839 m  |  beta_x = 3636.491  | beta_y = 5.453  |  alpha_x = -283.044 |  alpha_y = 0.869
# s = 16.039 m  |  beta_x = 3750.590  | beta_y = 5.118  |  alpha_x = -287.450 |  alpha_y = 0.805
# s = 16.299 m  |  beta_x = 3901.553  | beta_y = 4.722  |  alpha_x = -293.178 |  alpha_y = 0.721
# s = 16.406 m  |  beta_x = 3964.486  | beta_y = 4.571  |  alpha_x = -295.533 |  alpha_y = 0.687
# s = 16.782 m  |  beta_x = 4012.834  | beta_y = 4.288  |  alpha_x = 168.890 |  alpha_y = 0.077
# s = 16.889 m  |  beta_x = 3976.807  | beta_y = 4.274  |  alpha_x = 168.130 |  alpha_y = 0.052
# s = 17.014 m  |  beta_x = 3934.885  | beta_y = 4.265  |  alpha_x = 167.242 |  alpha_y = 0.022
# s = 17.139 m  |  beta_x = 3893.186  | beta_y = 4.263  |  alpha_x = 166.353 |  alpha_y = -0.007
# s = 17.416 m  |  beta_x = 3801.506  | beta_y = 4.285  |  alpha_x = 164.383 |  alpha_y = -0.072
# s = 19.322 m  |  beta_x = 3181.604  | beta_y = 16.806  |  alpha_x = 159.961 |  alpha_y = -17.588
# s = 19.509 m  |  beta_x = 3121.997  | beta_y = 24.038  |  alpha_x = 158.456 |  alpha_y = -21.045
# s = 19.599 m  |  beta_x = 3093.540  | beta_y = 27.976  |  alpha_x = 157.732 |  alpha_y = -22.706
# s = 20.099 m  |  beta_x = 2937.819  | beta_y = 55.299  |  alpha_x = 153.710 |  alpha_y = -31.939
# s = 21.472 m  |  beta_x = 2531.120  | beta_y = 177.721  |  alpha_x = 142.674 |  alpha_y = -57.277
# s = 23.378 m  |  beta_x = 2004.093  | beta_y = 332.857  |  alpha_x = 133.075 |  alpha_y = -0.018
# s = 23.812 m  |  beta_x = 1890.222  | beta_y = 332.873  |  alpha_x = 129.239 |  alpha_y = -0.019
# s = 24.188 m  |  beta_x = 1994.080  | beta_y = 298.947  |  alpha_x = -414.961 |  alpha_y = 87.005
# s = 24.295 m  |  beta_x = 2083.786  | beta_y = 280.634  |  alpha_x = -424.192 |  alpha_y = 84.298
# s = 24.420 m  |  beta_x = 2191.183  | beta_y = 259.956  |  alpha_x = -434.986 |  alpha_y = 81.132
# s = 24.545 m  |  beta_x = 2301.279  | beta_y = 240.068  |  alpha_x = -445.780 |  alpha_y = 77.966
# s = 26.037 m  |  beta_x = 3824.044  | beta_y = 63.768  |  alpha_x = -574.642 |  alpha_y = 40.174
# s = 26.162 m  |  beta_x = 3969.054  | beta_y = 54.121  |  alpha_x = -585.436 |  alpha_y = 37.008
# s = 26.287 m  |  beta_x = 4116.762  | beta_y = 45.264  |  alpha_x = -596.230 |  alpha_y = 33.843
# s = 26.637 m  |  beta_x = 4544.702  | beta_y = 24.677  |  alpha_x = -626.453 |  alpha_y = 24.979
# s = 26.837 m  |  beta_x = 4798.737  | beta_y = 15.698  |  alpha_x = -643.724 |  alpha_y = 19.914
# s = 26.937 m  |  beta_x = 4928.346  | beta_y = 11.969  |  alpha_x = -652.359 |  alpha_y = 17.381
# s = 27.062 m  |  beta_x = 5092.785  | beta_y = 8.019  |  alpha_x = -663.153 |  alpha_y = 14.216
# s = 27.187 m  |  beta_x = 5259.922  | beta_y = 4.861  |  alpha_x = -673.947 |  alpha_y = 11.050
# s = 27.294 m  |  beta_x = 5404.999  | beta_y = 2.788  |  alpha_x = -683.178 |  alpha_y = 8.343
# s = 27.670 m  |  beta_x = 5384.494  | beta_y = 0.078  |  alpha_x = 735.952 |  alpha_y = -0.904
# s = 28.216 m  |  beta_x = 4611.739  | beta_y = 8.036  |  alpha_x = 681.098 |  alpha_y = -13.690
# s = 30.250 m  |  beta_x = 2021.752  | beta_y = 160.353  |  alpha_x = 243.689 |  alpha_y = -60.807
# s = 30.788 m  |  beta_x = 1767.645  | beta_y = 232.585  |  alpha_x = 227.860 |  alpha_y = -73.236
# s = 30.913 m  |  beta_x = 1711.139  | beta_y = 251.255  |  alpha_x = 224.189 |  alpha_y = -76.119
# s = 31.038 m  |  beta_x = 1655.551  | beta_y = 270.645  |  alpha_x = 220.517 |  alpha_y = -79.002
# s = 31.146 m  |  beta_x = 1608.544  | beta_y = 287.872  |  alpha_x = 217.364 |  alpha_y = -81.478
# s = 31.671 m  |  beta_x = 1605.259  | beta_y = 332.807  |  alpha_x = -210.809 |  alpha_y = 0.013
# s = 32.106 m  |  beta_x = 1793.702  | beta_y = 332.797  |  alpha_x = -222.840 |  alpha_y = 0.011
# s = 34.012 m  |  beta_x = 2731.602  | beta_y = 173.142  |  alpha_x = -267.885 |  alpha_y = 55.808
# s = 34.199 m  |  beta_x = 2832.819  | beta_y = 152.878  |  alpha_x = -272.803 |  alpha_y = 52.440
# s = 34.289 m  |  beta_x = 2882.136  | beta_y = 143.585  |  alpha_x = -275.167 |  alpha_y = 50.820
# s = 34.789 m  |  beta_x = 3163.872  | beta_y = 97.263  |  alpha_x = -288.303 |  alpha_y = 41.823
# s = 36.161 m  |  beta_x = 4004.559  | beta_y = 16.366  |  alpha_x = -324.353 |  alpha_y = 17.131
# s = 38.067 m  |  beta_x = 5311.123  | beta_y = 5.819  |  alpha_x = -359.266 |  alpha_y = -0.604
# s = 38.344 m  |  beta_x = 5512.168  | beta_y = 6.172  |  alpha_x = -366.002 |  alpha_y = -0.669
# s = 38.554 m  |  beta_x = 5666.961  | beta_y = 6.463  |  alpha_x = -371.106 |  alpha_y = -0.718
# s = 38.634 m  |  beta_x = 5726.493  | beta_y = 6.580  |  alpha_x = -373.050 |  alpha_y = -0.737
# s = 38.834 m  |  beta_x = 5876.685  | beta_y = 6.884  |  alpha_x = -377.910 |  alpha_y = -0.784
# s = 39.022 m  |  beta_x = 6019.142  | beta_y = 7.186  |  alpha_x = -382.463 |  alpha_y = -0.828
# s = 39.547 m  |  beta_x = 5897.838  | beta_y = 8.815  |  alpha_x = 606.575 |  alpha_y = -2.362
# s = 39.654 m  |  beta_x = 5768.325  | beta_y = 9.331  |  alpha_x = 599.878 |  alpha_y = -2.442
# s = 39.779 m  |  beta_x = 5619.331  | beta_y = 9.953  |  alpha_x = 592.080 |  alpha_y = -2.535
# s = 39.904 m  |  beta_x = 5472.286  | beta_y = 10.598  |  alpha_x = 584.282 |  alpha_y = -2.628
# s = 40.029 m  |  beta_x = 5327.191  | beta_y = 11.267  |  alpha_x = 576.484 |  alpha_y = -2.721
# s = 40.154 m  |  beta_x = 5184.045  | beta_y = 11.959  |  alpha_x = 568.686 |  alpha_y = -2.815
# s = 43.154 m  |  beta_x = 2333.627  | beta_y = 35.559  |  alpha_x = 381.552 |  alpha_y = -5.053
# s = 43.279 m  |  beta_x = 2239.214  | beta_y = 36.834  |  alpha_x = 373.754 |  alpha_y = -5.146
# s = 43.404 m  |  beta_x = 2146.750  | beta_y = 38.132  |  alpha_x = 365.956 |  alpha_y = -5.239
# s = 43.529 m  |  beta_x = 2056.236  | beta_y = 39.454  |  alpha_x = 358.157 |  alpha_y = -5.333
# s = 43.654 m  |  beta_x = 1967.671  | beta_y = 40.799  |  alpha_x = 350.359 |  alpha_y = -5.426
# s = 43.744 m  |  beta_x = 1905.112  | beta_y = 41.782  |  alpha_x = 344.745 |  alpha_y = -5.493
# s = 43.824 m  |  beta_x = 1850.352  | beta_y = 42.665  |  alpha_x = 339.754 |  alpha_y = -5.553
# s = 44.024 m  |  beta_x = 1716.946  | beta_y = 44.916  |  alpha_x = 327.277 |  alpha_y = -5.702
# s = 44.211 m  |  beta_x = 1596.505  | beta_y = 47.079  |  alpha_x = 315.589 |  alpha_y = -5.842
# s = 44.737 m  |  beta_x = 1411.100  | beta_y = 48.923  |  alpha_x = 47.941 |  alpha_y = 2.439
# s = 44.844 m  |  beta_x = 1400.826  | beta_y = 48.401  |  alpha_x = 47.766 |  alpha_y = 2.423
# s = 44.969 m  |  beta_x = 1388.909  | beta_y = 47.797  |  alpha_x = 47.563 |  alpha_y = 2.406
# s = 45.635 m  |  beta_x = 1326.279  | beta_y = 44.656  |  alpha_x = 46.477 |  alpha_y = 2.311
# s = 45.735 m  |  beta_x = 1317.000  | beta_y = 44.195  |  alpha_x = 46.314 |  alpha_y = 2.297
# s = 45.835 m  |  beta_x = 1307.753  | beta_y = 43.737  |  alpha_x = 46.151 |  alpha_y = 2.283
# s = 45.935 m  |  beta_x = 1298.539  | beta_y = 43.282  |  alpha_x = 45.989 |  alpha_y = 2.268
# s = 46.035 m  |  beta_x = 1289.358  | beta_y = 42.830  |  alpha_x = 45.826 |  alpha_y = 2.254
# s = 46.135 m  |  beta_x = 1280.209  | beta_y = 42.380  |  alpha_x = 45.663 |  alpha_y = 2.240
# s = 46.235 m  |  beta_x = 1271.093  | beta_y = 41.934  |  alpha_x = 45.500 |  alpha_y = 2.226
# s = 46.335 m  |  beta_x = 1262.009  | beta_y = 41.490  |  alpha_x = 45.337 |  alpha_y = 2.212
# s = 46.435 m  |  beta_x = 1252.958  | beta_y = 41.049  |  alpha_x = 45.174 |  alpha_y = 2.197
# s = 46.535 m  |  beta_x = 1243.940  | beta_y = 40.611  |  alpha_x = 45.011 |  alpha_y = 2.183
# s = 46.635 m  |  beta_x = 1234.954  | beta_y = 40.176  |  alpha_x = 44.848 |  alpha_y = 2.169
# s = 46.735 m  |  beta_x = 1226.001  | beta_y = 39.744  |  alpha_x = 44.685 |  alpha_y = 2.155
# s = 46.835 m  |  beta_x = 1217.080  | beta_y = 39.314  |  alpha_x = 44.522 |  alpha_y = 2.141
# s = 46.935 m  |  beta_x = 1208.192  | beta_y = 38.887  |  alpha_x = 44.359 |  alpha_y = 2.126
# s = 47.035 m  |  beta_x = 1199.336  | beta_y = 38.463  |  alpha_x = 44.196 |  alpha_y = 2.112
# s = 47.135 m  |  beta_x = 1190.513  | beta_y = 38.042  |  alpha_x = 44.033 |  alpha_y = 2.098
# s = 47.235 m  |  beta_x = 1181.723  | beta_y = 37.624  |  alpha_x = 43.870 |  alpha_y = 2.084
# s = 47.335 m  |  beta_x = 1172.965  | beta_y = 37.209  |  alpha_x = 43.707 |  alpha_y = 2.070
# s = 47.435 m  |  beta_x = 1164.240  | beta_y = 36.796  |  alpha_x = 43.544 |  alpha_y = 2.055
# s = 47.535 m  |  beta_x = 1155.548  | beta_y = 36.387  |  alpha_x = 43.381 |  alpha_y = 2.041
# s = 47.635 m  |  beta_x = 1146.888  | beta_y = 35.980  |  alpha_x = 43.218 |  alpha_y = 2.027
# s = 47.735 m  |  beta_x = 1138.260  | beta_y = 35.576  |  alpha_x = 43.055 |  alpha_y = 2.013
# s = 47.835 m  |  beta_x = 1129.665  | beta_y = 35.175  |  alpha_x = 42.892 |  alpha_y = 1.999
# s = 47.935 m  |  beta_x = 1121.103  | beta_y = 34.777  |  alpha_x = 42.730 |  alpha_y = 1.984
# s = 48.035 m  |  beta_x = 1112.574  | beta_y = 34.381  |  alpha_x = 42.567 |  alpha_y = 1.970
# s = 48.135 m  |  beta_x = 1104.077  | beta_y = 33.988  |  alpha_x = 42.404 |  alpha_y = 1.956
# s = 48.235 m  |  beta_x = 1095.612  | beta_y = 33.599  |  alpha_x = 42.241 |  alpha_y = 1.942
# s = 48.335 m  |  beta_x = 1087.180  | beta_y = 33.212  |  alpha_x = 42.078 |  alpha_y = 1.928
# s = 48.435 m  |  beta_x = 1078.781  | beta_y = 32.828  |  alpha_x = 41.915 |  alpha_y = 1.913
# s = 48.535 m  |  beta_x = 1070.414  | beta_y = 32.446  |  alpha_x = 41.752 |  alpha_y = 1.899
# s = 48.635 m  |  beta_x = 1062.080  | beta_y = 32.068  |  alpha_x = 41.589 |  alpha_y = 1.885
# s = 48.735 m  |  beta_x = 1053.779  | beta_y = 31.692  |  alpha_x = 41.426 |  alpha_y = 1.871
# s = 48.835 m  |  beta_x = 1045.510  | beta_y = 31.320  |  alpha_x = 41.263 |  alpha_y = 1.857
# s = 48.935 m  |  beta_x = 1037.274  | beta_y = 30.950  |  alpha_x = 41.100 |  alpha_y = 1.842
# s = 49.035 m  |  beta_x = 1029.070  | beta_y = 30.583  |  alpha_x = 40.937 |  alpha_y = 1.828
# s = 49.135 m  |  beta_x = 1020.899  | beta_y = 30.218  |  alpha_x = 40.774 |  alpha_y = 1.814
# s = 49.235 m  |  beta_x = 1012.760  | beta_y = 29.857  |  alpha_x = 40.611 |  alpha_y = 1.800
# s = 49.335 m  |  beta_x = 1004.654  | beta_y = 29.498  |  alpha_x = 40.448 |  alpha_y = 1.786
# s = 49.435 m  |  beta_x = 996.352  | beta_y = 29.149  |  alpha_x = 47.023 |  alpha_y = 1.574
# s = 49.535 m  |  beta_x = 984.999  | beta_y = 28.893  |  alpha_x = 66.430 |  alpha_y = 0.987
# s = 49.635 m  |  beta_x = 969.815  | beta_y = 28.754  |  alpha_x = 85.309 |  alpha_y = 0.408
# s = 49.735 m  |  beta_x = 950.921  | beta_y = 28.730  |  alpha_x = 103.508 |  alpha_y = -0.168
# s = 49.835 m  |  beta_x = 928.467  | beta_y = 28.821  |  alpha_x = 120.883 |  alpha_y = -0.745
# s = 49.935 m  |  beta_x = 902.645  | beta_y = 29.028  |  alpha_x = 135.741 |  alpha_y = -1.278
# s = 50.035 m  |  beta_x = 875.701  | beta_y = 29.284  |  alpha_x = 133.699 |  alpha_y = -1.287
# s = 50.135 m  |  beta_x = 849.165  | beta_y = 29.543  |  alpha_x = 131.658 |  alpha_y = -1.296
# s = 50.235 m  |  beta_x = 823.038  | beta_y = 29.803  |  alpha_x = 129.616 |  alpha_y = -1.305
# s = 50.335 m  |  beta_x = 797.319  | beta_y = 30.065  |  alpha_x = 127.575 |  alpha_y = -1.314
# s = 50.435 m  |  beta_x = 772.008  | beta_y = 30.328  |  alpha_x = 125.534 |  alpha_y = -1.323
# s = 50.535 m  |  beta_x = 747.105  | beta_y = 30.594  |  alpha_x = 123.492 |  alpha_y = -1.332
# s = 50.635 m  |  beta_x = 722.611  | beta_y = 30.861  |  alpha_x = 121.451 |  alpha_y = -1.341
# s = 50.735 m  |  beta_x = 698.525  | beta_y = 31.130  |  alpha_x = 119.410 |  alpha_y = -1.350
# s = 50.835 m  |  beta_x = 674.847  | beta_y = 31.401  |  alpha_x = 117.368 |  alpha_y = -1.359
# s = 50.935 m  |  beta_x = 651.578  | beta_y = 31.674  |  alpha_x = 115.327 |  alpha_y = -1.369
# s = 51.035 m  |  beta_x = 628.716  | beta_y = 31.949  |  alpha_x = 113.285 |  alpha_y = -1.378
# s = 51.135 m  |  beta_x = 606.263  | beta_y = 32.225  |  alpha_x = 111.244 |  alpha_y = -1.387
# s = 51.235 m  |  beta_x = 584.219  | beta_y = 32.503  |  alpha_x = 109.203 |  alpha_y = -1.396
# s = 51.335 m  |  beta_x = 562.582  | beta_y = 32.783  |  alpha_x = 107.161 |  alpha_y = -1.405
# s = 51.435 m  |  beta_x = 541.354  | beta_y = 33.065  |  alpha_x = 105.120 |  alpha_y = -1.414
# s = 51.535 m  |  beta_x = 520.534  | beta_y = 33.349  |  alpha_x = 103.078 |  alpha_y = -1.423
# s = 51.635 m  |  beta_x = 500.123  | beta_y = 33.635  |  alpha_x = 101.037 |  alpha_y = -1.432
# s = 51.735 m  |  beta_x = 480.120  | beta_y = 33.922  |  alpha_x = 98.996 |  alpha_y = -1.441
# s = 51.835 m  |  beta_x = 460.525  | beta_y = 34.211  |  alpha_x = 96.954 |  alpha_y = -1.450
# s = 51.935 m  |  beta_x = 441.338  | beta_y = 34.502  |  alpha_x = 94.913 |  alpha_y = -1.459
# s = 52.035 m  |  beta_x = 422.559  | beta_y = 34.795  |  alpha_x = 92.871 |  alpha_y = -1.468
# s = 52.135 m  |  beta_x = 404.189  | beta_y = 35.089  |  alpha_x = 90.830 |  alpha_y = -1.477
# s = 52.235 m  |  beta_x = 386.227  | beta_y = 35.386  |  alpha_x = 88.789 |  alpha_y = -1.486
# s = 52.335 m  |  beta_x = 368.674  | beta_y = 35.684  |  alpha_x = 86.747 |  alpha_y = -1.495
# s = 52.435 m  |  beta_x = 351.529  | beta_y = 35.984  |  alpha_x = 84.706 |  alpha_y = -1.505
# s = 52.535 m  |  beta_x = 334.792  | beta_y = 36.286  |  alpha_x = 82.664 |  alpha_y = -1.514
# s = 52.635 m  |  beta_x = 318.463  | beta_y = 36.589  |  alpha_x = 80.623 |  alpha_y = -1.523
# s = 52.735 m  |  beta_x = 302.542  | beta_y = 36.895  |  alpha_x = 78.582 |  alpha_y = -1.532
# s = 52.835 m  |  beta_x = 287.030  | beta_y = 37.202  |  alpha_x = 76.540 |  alpha_y = -1.541
# s = 52.935 m  |  beta_x = 271.926  | beta_y = 37.511  |  alpha_x = 74.499 |  alpha_y = -1.550
# s = 53.035 m  |  beta_x = 257.231  | beta_y = 37.822  |  alpha_x = 72.457 |  alpha_y = -1.559
# s = 53.135 m  |  beta_x = 242.943  | beta_y = 38.135  |  alpha_x = 70.416 |  alpha_y = -1.568
# s = 53.235 m  |  beta_x = 229.064  | beta_y = 38.449  |  alpha_x = 68.375 |  alpha_y = -1.577
# s = 53.335 m  |  beta_x = 215.593  | beta_y = 38.765  |  alpha_x = 66.333 |  alpha_y = -1.586
# s = 53.435 m  |  beta_x = 202.531  | beta_y = 39.084  |  alpha_x = 64.292 |  alpha_y = -1.595
# s = 53.535 m  |  beta_x = 189.876  | beta_y = 39.404  |  alpha_x = 62.251 |  alpha_y = -1.604
# s = 53.635 m  |  beta_x = 177.631  | beta_y = 39.725  |  alpha_x = 60.209 |  alpha_y = -1.613
# s = 53.735 m  |  beta_x = 165.793  | beta_y = 40.049  |  alpha_x = 58.168 |  alpha_y = -1.622
# s = 53.835 m  |  beta_x = 154.363  | beta_y = 40.374  |  alpha_x = 56.126 |  alpha_y = -1.632
# s = 53.935 m  |  beta_x = 143.342  | beta_y = 40.702  |  alpha_x = 54.085 |  alpha_y = -1.641
# s = 54.035 m  |  beta_x = 132.729  | beta_y = 41.031  |  alpha_x = 52.044 |  alpha_y = -1.650
# s = 54.135 m  |  beta_x = 122.525  | beta_y = 41.361  |  alpha_x = 50.002 |  alpha_y = -1.659
# s = 54.235 m  |  beta_x = 112.729  | beta_y = 41.694  |  alpha_x = 47.961 |  alpha_y = -1.668
# s = 54.335 m  |  beta_x = 103.341  | beta_y = 42.029  |  alpha_x = 45.919 |  alpha_y = -1.677
# s = 54.435 m  |  beta_x = 94.361  | beta_y = 42.365  |  alpha_x = 43.878 |  alpha_y = -1.686
# s = 54.535 m  |  beta_x = 85.789  | beta_y = 42.703  |  alpha_x = 41.837 |  alpha_y = -1.695
# s = 54.635 m  |  beta_x = 77.626  | beta_y = 43.043  |  alpha_x = 39.795 |  alpha_y = -1.704
# s = 54.735 m  |  beta_x = 69.871  | beta_y = 43.385  |  alpha_x = 37.754 |  alpha_y = -1.713
# s = 54.835 m  |  beta_x = 62.525  | beta_y = 43.728  |  alpha_x = 35.712 |  alpha_y = -1.722
# s = 54.935 m  |  beta_x = 56.900  | beta_y = 44.057  |  alpha_x = 33.374 |  alpha_y = -1.619
# s = 55.035 m  |  beta_x = 52.113  | beta_y = 44.382  |  alpha_x = 31.226 |  alpha_y = -1.627
# s = 55.135 m  |  beta_x = 47.675  | beta_y = 44.708  |  alpha_x = 29.177 |  alpha_y = -1.635
# s = 55.235 m  |  beta_x = 43.569  | beta_y = 45.036  |  alpha_x = 27.223 |  alpha_y = -1.644
# s = 55.335 m  |  beta_x = 39.782  | beta_y = 45.365  |  alpha_x = 25.364 |  alpha_y = -1.652
# s = 55.435 m  |  beta_x = 36.296  | beta_y = 45.696  |  alpha_x = 23.599 |  alpha_y = -1.660
# s = 55.535 m  |  beta_x = 33.099  | beta_y = 46.029  |  alpha_x = 21.924 |  alpha_y = -1.668
# s = 55.635 m  |  beta_x = 30.175  | beta_y = 46.364  |  alpha_x = 20.340 |  alpha_y = -1.677
# s = 55.735 m  |  beta_x = 27.512  | beta_y = 46.700  |  alpha_x = 18.844 |  alpha_y = -1.685
# s = 55.835 m  |  beta_x = 25.096  | beta_y = 47.038  |  alpha_x = 17.435 |  alpha_y = -1.693
# s = 55.935 m  |  beta_x = 22.917  | beta_y = 47.377  |  alpha_x = 16.110 |  alpha_y = -1.701
# s = 56.035 m  |  beta_x = 20.963  | beta_y = 47.718  |  alpha_x = 14.869 |  alpha_y = -1.709
# s = 56.135 m  |  beta_x = 19.224  | beta_y = 48.061  |  alpha_x = 13.709 |  alpha_y = -1.718
# s = 56.235 m  |  beta_x = 17.693  | beta_y = 48.405  |  alpha_x = 12.628 |  alpha_y = -1.726
# s = 56.335 m  |  beta_x = 16.363  | beta_y = 48.751  |  alpha_x = 11.625 |  alpha_y = -1.734
# s = 56.435 m  |  beta_x = 15.230  | beta_y = 49.099  |  alpha_x = 10.697 |  alpha_y = -1.742
# s = 56.535 m  |  beta_x = 14.294  | beta_y = 49.448  |  alpha_x = 9.842 |  alpha_y = -1.750
# s = 56.635 m  |  beta_x = 13.559  | beta_y = 49.799  |  alpha_x = 9.056 |  alpha_y = -1.759
# s = 56.735 m  |  beta_x = 13.036  | beta_y = 50.152  |  alpha_x = 8.335 |  alpha_y = -1.767
# s = 56.835 m  |  beta_x = 12.748  | beta_y = 50.506  |  alpha_x = 7.675 |  alpha_y = -1.775
# s = 56.935 m  |  beta_x = 12.133  | beta_y = 50.851  |  alpha_x = 7.103 |  alpha_y = -1.654
# s = 57.035 m  |  beta_x = 10.754  | beta_y = 51.183  |  alpha_x = 6.679 |  alpha_y = -1.661
# s = 57.135 m  |  beta_x = 9.461  | beta_y = 51.516  |  alpha_x = 6.255 |  alpha_y = -1.668
# s = 57.235 m  |  beta_x = 8.252  | beta_y = 51.850  |  alpha_x = 5.831 |  alpha_y = -1.676
# s = 57.335 m  |  beta_x = 7.129  | beta_y = 52.186  |  alpha_x = 5.407 |  alpha_y = -1.683
# s = 57.435 m  |  beta_x = 6.090  | beta_y = 52.523  |  alpha_x = 4.983 |  alpha_y = -1.690
# s = 57.535 m  |  beta_x = 5.136  | beta_y = 52.862  |  alpha_x = 4.559 |  alpha_y = -1.698
# s = 57.635 m  |  beta_x = 4.266  | beta_y = 53.203  |  alpha_x = 4.134 |  alpha_y = -1.705
# s = 57.735 m  |  beta_x = 3.484  | beta_y = 53.512  |  alpha_x = 3.680 |  alpha_y = -1.249
# s = 57.835 m  |  beta_x = 2.794  | beta_y = 53.695  |  alpha_x = 3.228 |  alpha_y = -0.579
# s = 57.935 m  |  beta_x = 2.192  | beta_y = 53.744  |  alpha_x = 2.792 |  alpha_y = 0.093
# s = 58.035 m  |  beta_x = 1.676  | beta_y = 53.658  |  alpha_x = 2.370 |  alpha_y = 0.765
# s = 58.135 m  |  beta_x = 1.243  | beta_y = 53.438  |  alpha_x = 1.960 |  alpha_y = 1.434
# s = 58.235 m  |  beta_x = 0.891  | beta_y = 53.098  |  alpha_x = 1.564 |  alpha_y = 1.804
# s = 58.335 m  |  beta_x = 0.617  | beta_y = 52.738  |  alpha_x = 1.177 |  alpha_y = 1.796
# s = 58.435 m  |  beta_x = 0.420  | beta_y = 52.379  |  alpha_x = 0.791 |  alpha_y = 1.788
# s = 58.535 m  |  beta_x = 0.301  | beta_y = 52.023  |  alpha_x = 0.404 |  alpha_y = 1.780
# s = 58.635 m  |  beta_x = 0.259  | beta_y = 51.667  |  alpha_x = 0.017 |  alpha_y = 1.772
# s = 58.735 m  |  beta_x = 0.294  | beta_y = 51.314  |  alpha_x = -0.369 |  alpha_y = 1.764
# s = 58.835 m  |  beta_x = 0.433  | beta_y = 50.951  |  alpha_x = -0.756 |  alpha_y = 1.886
# s = 58.935 m  |  beta_x = 0.721  | beta_y = 50.574  |  alpha_x = -1.107 |  alpha_y = 1.877
# s = 59.035 m  |  beta_x = 1.183  | beta_y = 50.200  |  alpha_x = -1.420 |  alpha_y = 1.868
# s = 59.135 m  |  beta_x = 1.943  | beta_y = 49.827  |  alpha_x = -1.713 |  alpha_y = 1.859
# s = 59.235 m  |  beta_x = 3.407  | beta_y = 49.456  |  alpha_x = -2.046 |  alpha_y = 1.850
# s = 59.335 m  |  beta_x = 7.782  | beta_y = 49.087  |  alpha_x = -2.719 |  alpha_y = 1.841
# s = 59.435 m  |  beta_x = 43.693  | beta_y = 48.720  |  alpha_x = -5.137 |  alpha_y = 1.832
# s = 59.535 m  |  beta_x = 6.610  | beta_y = 48.354  |  alpha_x = 0.698 |  alpha_y = 1.823
# s = 59.635 m  |  beta_x = 3.311  | beta_y = 47.990  |  alpha_x = 1.091 |  alpha_y = 1.814
# s = 59.735 m  |  beta_x = 2.040  | beta_y = 47.629  |  alpha_x = 1.144 |  alpha_y = 1.805
# s = 59.835 m  |  beta_x = 1.338  | beta_y = 47.268  |  alpha_x = 1.072 |  alpha_y = 1.796
# s = 59.935 m  |  beta_x = 0.889  | beta_y = 46.910  |  alpha_x = 0.921 |  alpha_y = 1.787
# s = 60.035 m  |  beta_x = 0.589  | beta_y = 46.553  |  alpha_x = 0.707 |  alpha_y = 1.779
# s = 60.135 m  |  beta_x = 0.396  | beta_y = 46.199  |  alpha_x = 0.439 |  alpha_y = 1.770
# s = 60.235 m  |  beta_x = 0.293  | beta_y = 45.846  |  alpha_x = 0.121 |  alpha_y = 1.761
# s = 60.335 m  |  beta_x = 0.270  | beta_y = 45.494  |  alpha_x = -0.244 |  alpha_y = 1.752
# s = 60.435 m  |  beta_x = 0.327  | beta_y = 45.145  |  alpha_x = -0.655 |  alpha_y = 1.743
# s = 60.535 m  |  beta_x = 0.464  | beta_y = 44.797  |  alpha_x = -1.109 |  alpha_y = 1.734
# s = 60.635 m  |  beta_x = 0.682  | beta_y = 44.451  |  alpha_x = -1.605 |  alpha_y = 1.725
# s = 60.735 m  |  beta_x = 0.985  | beta_y = 44.107  |  alpha_x = -2.142 |  alpha_y = 1.716
# s = 60.835 m  |  beta_x = 1.387  | beta_y = 43.763  |  alpha_x = -2.724 |  alpha_y = 1.819
# s = 60.935 m  |  beta_x = 1.992  | beta_y = 43.400  |  alpha_x = -3.331 |  alpha_y = 1.809
# s = 61.035 m  |  beta_x = 2.719  | beta_y = 43.039  |  alpha_x = -3.938 |  alpha_y = 1.799
# s = 61.135 m  |  beta_x = 3.567  | beta_y = 42.681  |  alpha_x = -4.546 |  alpha_y = 1.789
# s = 61.235 m  |  beta_x = 4.537  | beta_y = 42.324  |  alpha_x = -5.153 |  alpha_y = 1.779
# s = 61.335 m  |  beta_x = 5.629  | beta_y = 41.969  |  alpha_x = -5.760 |  alpha_y = 1.769
# s = 61.435 m  |  beta_x = 6.841  | beta_y = 41.616  |  alpha_x = -6.367 |  alpha_y = 1.760
# s = 61.535 m  |  beta_x = 8.176  | beta_y = 41.265  |  alpha_x = -6.975 |  alpha_y = 1.750
# s = 61.635 m  |  beta_x = 9.631  | beta_y = 40.916  |  alpha_x = -7.582 |  alpha_y = 1.740
# s = 61.735 m  |  beta_x = 11.208  | beta_y = 40.569  |  alpha_x = -8.189 |  alpha_y = 1.730
# s = 61.835 m  |  beta_x = 12.907  | beta_y = 40.224  |  alpha_x = -8.796 |  alpha_y = 1.720
# s = 61.935 m  |  beta_x = 14.727  | beta_y = 39.881  |  alpha_x = -9.404 |  alpha_y = 1.710
# s = 62.035 m  |  beta_x = 16.668  | beta_y = 39.540  |  alpha_x = -10.011 |  alpha_y = 1.700
# s = 62.135 m  |  beta_x = 18.731  | beta_y = 39.201  |  alpha_x = -10.618 |  alpha_y = 1.691
# s = 62.235 m  |  beta_x = 20.916  | beta_y = 38.864  |  alpha_x = -11.225 |  alpha_y = 1.681
# s = 62.335 m  |  beta_x = 23.221  | beta_y = 38.529  |  alpha_x = -11.833 |  alpha_y = 1.671
# s = 62.435 m  |  beta_x = 25.649  | beta_y = 38.196  |  alpha_x = -12.440 |  alpha_y = 1.661
# s = 62.535 m  |  beta_x = 28.197  | beta_y = 37.864  |  alpha_x = -13.047 |  alpha_y = 1.651
# s = 62.635 m  |  beta_x = 30.868  | beta_y = 37.535  |  alpha_x = -13.654 |  alpha_y = 1.641
# s = 62.735 m  |  beta_x = 33.659  | beta_y = 37.208  |  alpha_x = -14.262 |  alpha_y = 1.632
# s = 62.835 m  |  beta_x = 36.572  | beta_y = 36.882  |  alpha_x = -14.869 |  alpha_y = 1.622
# s = 62.935 m  |  beta_x = 39.607  | beta_y = 36.559  |  alpha_x = -15.476 |  alpha_y = 1.612
# s = 63.035 m  |  beta_x = 42.763  | beta_y = 36.238  |  alpha_x = -16.083 |  alpha_y = 1.602
# s = 63.135 m  |  beta_x = 46.040  | beta_y = 35.918  |  alpha_x = -16.691 |  alpha_y = 1.592
# s = 63.235 m  |  beta_x = 49.439  | beta_y = 35.601  |  alpha_x = -17.298 |  alpha_y = 1.582
# s = 63.335 m  |  beta_x = 52.959  | beta_y = 35.285  |  alpha_x = -17.905 |  alpha_y = 1.573
# s = 63.435 m  |  beta_x = 56.601  | beta_y = 34.972  |  alpha_x = -18.512 |  alpha_y = 1.563
# s = 63.535 m  |  beta_x = 60.364  | beta_y = 34.660  |  alpha_x = -19.120 |  alpha_y = 1.553
# s = 63.635 m  |  beta_x = 64.249  | beta_y = 34.351  |  alpha_x = -19.727 |  alpha_y = 1.543
# s = 63.735 m  |  beta_x = 68.119  | beta_y = 34.113  |  alpha_x = -18.748 |  alpha_y = 0.740
# s = 63.835 m  |  beta_x = 71.732  | beta_y = 34.056  |  alpha_x = -17.358 |  alpha_y = -0.169
# s = 63.935 m  |  beta_x = 75.049  | beta_y = 34.180  |  alpha_x = -15.783 |  alpha_y = -1.080
# s = 64.035 m  |  beta_x = 78.034  | beta_y = 34.488  |  alpha_x = -14.040 |  alpha_y = -2.002
# s = 64.135 m  |  beta_x = 80.655  | beta_y = 34.983  |  alpha_x = -12.148 |  alpha_y = -2.946
# s = 64.235 m  |  beta_x = 82.970  | beta_y = 35.632  |  alpha_x = -11.499 |  alpha_y = -3.331
# s = 64.335 m  |  beta_x = 85.285  | beta_y = 36.302  |  alpha_x = -11.659 |  alpha_y = -3.365
# s = 64.435 m  |  beta_x = 87.633  | beta_y = 36.978  |  alpha_x = -11.820 |  alpha_y = -3.399
# s = 64.535 m  |  beta_x = 90.013  | beta_y = 37.662  |  alpha_x = -11.980 |  alpha_y = -3.433
# s = 64.635 m  |  beta_x = 92.425  | beta_y = 38.352  |  alpha_x = -12.141 |  alpha_y = -3.467
# s = 64.735 m  |  beta_x = 94.870  | beta_y = 39.048  |  alpha_x = -12.302 |  alpha_y = -3.501
# s = 64.835 m  |  beta_x = 97.346  | beta_y = 39.752  |  alpha_x = -12.462 |  alpha_y = -3.535
# s = 64.935 m  |  beta_x = 99.855  | beta_y = 40.462  |  alpha_x = -12.623 |  alpha_y = -3.569
# s = 65.035 m  |  beta_x = 102.395  | beta_y = 41.180  |  alpha_x = -12.783 |  alpha_y = -3.603
# s = 65.135 m  |  beta_x = 104.968  | beta_y = 41.904  |  alpha_x = -12.944 |  alpha_y = -3.637
# s = 65.235 m  |  beta_x = 107.573  | beta_y = 42.634  |  alpha_x = -13.104 |  alpha_y = -3.671
# s = 65.335 m  |  beta_x = 110.210  | beta_y = 43.372  |  alpha_x = -13.265 |  alpha_y = -3.705
# s = 65.435 m  |  beta_x = 112.879  | beta_y = 44.116  |  alpha_x = -13.425 |  alpha_y = -3.739
# s = 65.535 m  |  beta_x = 115.580  | beta_y = 44.867  |  alpha_x = -13.586 |  alpha_y = -3.773
# s = 65.635 m  |  beta_x = 118.313  | beta_y = 45.625  |  alpha_x = -13.747 |  alpha_y = -3.806
# s = 65.735 m  |  beta_x = 121.078  | beta_y = 46.390  |  alpha_x = -13.907 |  alpha_y = -3.840
# s = 65.835 m  |  beta_x = 123.876  | beta_y = 47.161  |  alpha_x = -14.068 |  alpha_y = -3.874
# s = 65.935 m  |  beta_x = 126.705  | beta_y = 47.940  |  alpha_x = -14.228 |  alpha_y = -3.908
# s = 66.035 m  |  beta_x = 129.567  | beta_y = 48.725  |  alpha_x = -14.389 |  alpha_y = -3.942
# s = 66.135 m  |  beta_x = 132.461  | beta_y = 49.516  |  alpha_x = -14.549 |  alpha_y = -3.976
# s = 66.235 m  |  beta_x = 135.387  | beta_y = 50.315  |  alpha_x = -14.710 |  alpha_y = -4.010
# s = 66.335 m  |  beta_x = 138.345  | beta_y = 51.121  |  alpha_x = -14.871 |  alpha_y = -4.044
# s = 66.435 m  |  beta_x = 141.335  | beta_y = 51.933  |  alpha_x = -15.031 |  alpha_y = -4.078
# s = 66.535 m  |  beta_x = 144.357  | beta_y = 52.752  |  alpha_x = -15.192 |  alpha_y = -4.112
# s = 66.635 m  |  beta_x = 147.412  | beta_y = 53.578  |  alpha_x = -15.352 |  alpha_y = -4.146
# s = 66.735 m  |  beta_x = 150.498  | beta_y = 54.410  |  alpha_x = -15.513 |  alpha_y = -4.180
# s = 66.835 m  |  beta_x = 153.617  | beta_y = 55.250  |  alpha_x = -15.673 |  alpha_y = -4.214
# s = 66.935 m  |  beta_x = 156.768  | beta_y = 56.096  |  alpha_x = -15.834 |  alpha_y = -4.248
# s = 67.035 m  |  beta_x = 159.951  | beta_y = 56.949  |  alpha_x = -15.995 |  alpha_y = -4.282
# s = 67.135 m  |  beta_x = 163.166  | beta_y = 57.808  |  alpha_x = -16.155 |  alpha_y = -4.316
# s = 67.235 m  |  beta_x = 166.413  | beta_y = 58.675  |  alpha_x = -16.316 |  alpha_y = -4.350
# s = 67.335 m  |  beta_x = 169.692  | beta_y = 59.548  |  alpha_x = -16.476 |  alpha_y = -4.384
# s = 67.435 m  |  beta_x = 173.003  | beta_y = 60.428  |  alpha_x = -16.637 |  alpha_y = -4.418
# s = 67.535 m  |  beta_x = 176.347  | beta_y = 61.315  |  alpha_x = -16.797 |  alpha_y = -4.451
# s = 67.635 m  |  beta_x = 179.722  | beta_y = 62.209  |  alpha_x = -16.958 |  alpha_y = -4.485
# s = 67.735 m  |  beta_x = 183.130  | beta_y = 63.109  |  alpha_x = -17.118 |  alpha_y = -4.519
# s = 67.835 m  |  beta_x = 186.569  | beta_y = 64.017  |  alpha_x = -17.279 |  alpha_y = -4.553
# s = 67.935 m  |  beta_x = 190.041  | beta_y = 64.931  |  alpha_x = -17.440 |  alpha_y = -4.587
# s = 68.035 m  |  beta_x = 193.545  | beta_y = 65.852  |  alpha_x = -17.600 |  alpha_y = -4.621
# s = 68.135 m  |  beta_x = 197.081  | beta_y = 66.779  |  alpha_x = -17.761 |  alpha_y = -4.655
# s = 68.235 m  |  beta_x = 200.650  | beta_y = 67.714  |  alpha_x = -17.921 |  alpha_y = -4.689
# s = 68.335 m  |  beta_x = 204.250  | beta_y = 68.655  |  alpha_x = -18.082 |  alpha_y = -4.723
# s = 68.435 m  |  beta_x = 207.882  | beta_y = 69.603  |  alpha_x = -18.242 |  alpha_y = -4.757
# s = 68.535 m  |  beta_x = 211.547  | beta_y = 70.558  |  alpha_x = -18.403 |  alpha_y = -4.791
# s = 68.635 m  |  beta_x = 215.243  | beta_y = 71.519  |  alpha_x = -18.564 |  alpha_y = -4.825
# s = 68.735 m  |  beta_x = 218.972  | beta_y = 72.488  |  alpha_x = -18.724 |  alpha_y = -4.859
# s = 68.835 m  |  beta_x = 222.733  | beta_y = 73.463  |  alpha_x = -18.885 |  alpha_y = -4.893
# s = 68.935 m  |  beta_x = 226.526  | beta_y = 74.445  |  alpha_x = -19.045 |  alpha_y = -4.927
# s = 69.035 m  |  beta_x = 230.351  | beta_y = 75.434  |  alpha_x = -19.206 |  alpha_y = -4.961
# s = 69.135 m  |  beta_x = 234.208  | beta_y = 76.429  |  alpha_x = -19.366 |  alpha_y = -4.995
# s = 69.235 m  |  beta_x = 238.098  | beta_y = 77.431  |  alpha_x = -19.527 |  alpha_y = -5.029
# s = 69.335 m  |  beta_x = 242.019  | beta_y = 78.441  |  alpha_x = -19.688 |  alpha_y = -5.063
# s = 69.435 m  |  beta_x = 245.973  | beta_y = 79.457  |  alpha_x = -19.848 |  alpha_y = -5.097
# s = 69.535 m  |  beta_x = 249.958  | beta_y = 80.479  |  alpha_x = -20.009 |  alpha_y = -5.130
# s = 69.635 m  |  beta_x = 253.979  | beta_y = 81.508  |  alpha_x = -20.612 |  alpha_y = -5.022
# s = 69.735 m  |  beta_x = 258.848  | beta_y = 82.282  |  alpha_x = -28.128 |  alpha_y = -2.714
# s = 69.835 m  |  beta_x = 265.252  | beta_y = 82.591  |  alpha_x = -35.964 |  alpha_y = -0.375
# s = 69.935 m  |  beta_x = 273.261  | beta_y = 82.432  |  alpha_x = -44.209 |  alpha_y = 1.968
# s = 70.035 m  |  beta_x = 282.969  | beta_y = 81.806  |  alpha_x = -52.957 |  alpha_y = 4.289
# s = 70.135 m  |  beta_x = 294.485  | beta_y = 80.720  |  alpha_x = -62.308 |  alpha_y = 6.561
# s = 70.235 m  |  beta_x = 307.375  | beta_y = 79.334  |  alpha_x = -65.299 |  alpha_y = 6.939
# s = 70.335 m  |  beta_x = 320.573  | beta_y = 77.953  |  alpha_x = -66.686 |  alpha_y = 6.877
# s = 70.435 m  |  beta_x = 334.049  | beta_y = 76.584  |  alpha_x = -68.074 |  alpha_y = 6.815
# s = 70.535 m  |  beta_x = 347.803  | beta_y = 75.227  |  alpha_x = -69.461 |  alpha_y = 6.753
# s = 70.635 m  |  beta_x = 361.834  | beta_y = 73.882  |  alpha_x = -70.849 |  alpha_y = 6.691
# s = 70.735 m  |  beta_x = 376.142  | beta_y = 72.550  |  alpha_x = -72.236 |  alpha_y = 6.629
# s = 70.835 m  |  beta_x = 390.728  | beta_y = 71.231  |  alpha_x = -73.624 |  alpha_y = 6.567
# s = 70.935 m  |  beta_x = 405.592  | beta_y = 69.924  |  alpha_x = -75.011 |  alpha_y = 6.505
# s = 71.035 m  |  beta_x = 420.733  | beta_y = 68.629  |  alpha_x = -76.399 |  alpha_y = 6.443
# s = 71.135 m  |  beta_x = 436.151  | beta_y = 67.346  |  alpha_x = -77.786 |  alpha_y = 6.381
# s = 71.235 m  |  beta_x = 451.847  | beta_y = 66.076  |  alpha_x = -79.174 |  alpha_y = 6.319
# s = 71.335 m  |  beta_x = 467.821  | beta_y = 64.819  |  alpha_x = -80.561 |  alpha_y = 6.257
# s = 71.435 m  |  beta_x = 484.072  | beta_y = 63.574  |  alpha_x = -81.949 |  alpha_y = 6.195
# s = 71.535 m  |  beta_x = 500.600  | beta_y = 62.341  |  alpha_x = -83.336 |  alpha_y = 6.133
# s = 71.635 m  |  beta_x = 517.406  | beta_y = 61.120  |  alpha_x = -84.724 |  alpha_y = 6.071
# s = 71.735 m  |  beta_x = 534.490  | beta_y = 59.912  |  alpha_x = -86.112 |  alpha_y = 6.009
# s = 71.835 m  |  beta_x = 551.851  | beta_y = 58.717  |  alpha_x = -87.499 |  alpha_y = 5.947
# s = 71.935 m  |  beta_x = 569.490  | beta_y = 57.533  |  alpha_x = -88.887 |  alpha_y = 5.886
# s = 72.035 m  |  beta_x = 587.406  | beta_y = 56.362  |  alpha_x = -90.274 |  alpha_y = 5.824
# s = 72.135 m  |  beta_x = 605.599  | beta_y = 55.204  |  alpha_x = -91.662 |  alpha_y = 5.762
# s = 72.235 m  |  beta_x = 624.070  | beta_y = 54.058  |  alpha_x = -93.049 |  alpha_y = 5.700
# s = 72.335 m  |  beta_x = 642.819  | beta_y = 52.924  |  alpha_x = -94.437 |  alpha_y = 5.638
# s = 72.435 m  |  beta_x = 661.845  | beta_y = 51.803  |  alpha_x = -95.824 |  alpha_y = 5.576
# s = 72.535 m  |  beta_x = 681.149  | beta_y = 50.694  |  alpha_x = -97.212 |  alpha_y = 5.514
# s = 72.635 m  |  beta_x = 700.730  | beta_y = 49.597  |  alpha_x = -98.599 |  alpha_y = 5.452
# s = 72.735 m  |  beta_x = 720.588  | beta_y = 48.513  |  alpha_x = -99.987 |  alpha_y = 5.390
# s = 72.835 m  |  beta_x = 740.725  | beta_y = 47.441  |  alpha_x = -101.374 |  alpha_y = 5.328
# s = 72.935 m  |  beta_x = 761.138  | beta_y = 46.382  |  alpha_x = -102.762 |  alpha_y = 5.266
# s = 73.035 m  |  beta_x = 781.829  | beta_y = 45.335  |  alpha_x = -104.149 |  alpha_y = 5.204
# s = 73.135 m  |  beta_x = 802.798  | beta_y = 44.300  |  alpha_x = -105.537 |  alpha_y = 5.142
# s = 73.235 m  |  beta_x = 824.044  | beta_y = 43.278  |  alpha_x = -106.924 |  alpha_y = 5.080
# s = 73.335 m  |  beta_x = 845.568  | beta_y = 42.268  |  alpha_x = -108.312 |  alpha_y = 5.018
# s = 73.435 m  |  beta_x = 867.369  | beta_y = 41.270  |  alpha_x = -109.699 |  alpha_y = 4.956
# s = 73.535 m  |  beta_x = 889.447  | beta_y = 40.285  |  alpha_x = -111.087 |  alpha_y = 4.894
# s = 73.635 m  |  beta_x = 911.804  | beta_y = 39.313  |  alpha_x = -112.475 |  alpha_y = 4.832
# s = 73.735 m  |  beta_x = 934.437  | beta_y = 38.352  |  alpha_x = -113.862 |  alpha_y = 4.770
# s = 73.835 m  |  beta_x = 957.349  | beta_y = 37.405  |  alpha_x = -115.250 |  alpha_y = 4.709
# s = 73.935 m  |  beta_x = 980.537  | beta_y = 36.469  |  alpha_x = -116.637 |  alpha_y = 4.647
# s = 74.035 m  |  beta_x = 1004.003  | beta_y = 35.546  |  alpha_x = -118.025 |  alpha_y = 4.585
# s = 74.135 m  |  beta_x = 1027.747  | beta_y = 34.635  |  alpha_x = -119.412 |  alpha_y = 4.523
# s = 74.235 m  |  beta_x = 1051.768  | beta_y = 33.737  |  alpha_x = -120.800 |  alpha_y = 4.461
# s = 74.335 m  |  beta_x = 1076.067  | beta_y = 32.851  |  alpha_x = -122.187 |  alpha_y = 4.399
# s = 74.435 m  |  beta_x = 1100.643  | beta_y = 31.977  |  alpha_x = -123.575 |  alpha_y = 4.337
# s = 74.535 m  |  beta_x = 1125.497  | beta_y = 31.116  |  alpha_x = -124.962 |  alpha_y = 4.275
# s = 74.635 m  |  beta_x = 1150.628  | beta_y = 30.267  |  alpha_x = -126.350 |  alpha_y = 4.213
# s = 74.735 m  |  beta_x = 1176.037  | beta_y = 29.431  |  alpha_x = -127.737 |  alpha_y = 4.151
# s = 74.835 m  |  beta_x = 1201.723  | beta_y = 28.607  |  alpha_x = -129.125 |  alpha_y = 4.089
# s = 74.935 m  |  beta_x = 1227.687  | beta_y = 27.795  |  alpha_x = -130.512 |  alpha_y = 4.027
# s = 75.035 m  |  beta_x = 1253.928  | beta_y = 26.996  |  alpha_x = -131.900 |  alpha_y = 3.965
# s = 75.135 m  |  beta_x = 1280.447  | beta_y = 26.209  |  alpha_x = -133.287 |  alpha_y = 3.903
# s = 75.235 m  |  beta_x = 1307.243  | beta_y = 25.435  |  alpha_x = -134.675 |  alpha_y = 3.841
# s = 75.335 m  |  beta_x = 1334.317  | beta_y = 24.673  |  alpha_x = -136.063 |  alpha_y = 3.779
# s = 75.435 m  |  beta_x = 1361.668  | beta_y = 23.923  |  alpha_x = -137.450 |  alpha_y = 3.717
# s = 75.535 m  |  beta_x = 1389.297  | beta_y = 23.186  |  alpha_x = -138.838 |  alpha_y = 3.655
# s = 75.635 m  |  beta_x = 1416.908  | beta_y = 22.466  |  alpha_x = -128.279 |  alpha_y = 3.404
# s = 75.735 m  |  beta_x = 1437.799  | beta_y = 21.865  |  alpha_x = -80.394 |  alpha_y = 2.604
# s = 75.835 m  |  beta_x = 1448.992  | beta_y = 21.422  |  alpha_x = -31.414 |  alpha_y = 1.839
# s = 75.935 m  |  beta_x = 1450.336  | beta_y = 21.128  |  alpha_x = 17.993 |  alpha_y = 1.100
# s = 76.035 m  |  beta_x = 1441.812  | beta_y = 20.981  |  alpha_x = 67.155 |  alpha_y = 0.375
# s = 76.135 m  |  beta_x = 1423.535  | beta_y = 20.978  |  alpha_x = 115.403 |  alpha_y = -0.344
# s = 76.235 m  |  beta_x = 1400.495  | beta_y = 21.048  |  alpha_x = 114.734 |  alpha_y = -0.354
# s = 76.335 m  |  beta_x = 1377.642  | beta_y = 21.119  |  alpha_x = 113.794 |  alpha_y = -0.359
# s = 76.435 m  |  beta_x = 1354.977  | beta_y = 21.191  |  alpha_x = 112.854 |  alpha_y = -0.364
# s = 76.535 m  |  beta_x = 1332.500  | beta_y = 21.265  |  alpha_x = 111.914 |  alpha_y = -0.370
# s = 76.635 m  |  beta_x = 1310.211  | beta_y = 21.339  |  alpha_x = 110.974 |  alpha_y = -0.375
# s = 76.735 m  |  beta_x = 1288.111  | beta_y = 21.415  |  alpha_x = 110.034 |  alpha_y = -0.380
# s = 76.835 m  |  beta_x = 1266.198  | beta_y = 21.491  |  alpha_x = 109.094 |  alpha_y = -0.386
# s = 76.935 m  |  beta_x = 1244.473  | beta_y = 21.569  |  alpha_x = 108.154 |  alpha_y = -0.391
# s = 77.035 m  |  beta_x = 1222.936  | beta_y = 21.648  |  alpha_x = 107.214 |  alpha_y = -0.396
# s = 77.135 m  |  beta_x = 1201.587  | beta_y = 21.727  |  alpha_x = 106.274 |  alpha_y = -0.402
# s = 77.235 m  |  beta_x = 1180.427  | beta_y = 21.808  |  alpha_x = 105.334 |  alpha_y = -0.407
# s = 77.335 m  |  beta_x = 1159.454  | beta_y = 21.890  |  alpha_x = 104.394 |  alpha_y = -0.412
# s = 77.435 m  |  beta_x = 1138.669  | beta_y = 21.973  |  alpha_x = 103.454 |  alpha_y = -0.418
# s = 77.535 m  |  beta_x = 1118.072  | beta_y = 22.057  |  alpha_x = 102.514 |  alpha_y = -0.423
# s = 77.635 m  |  beta_x = 1097.663  | beta_y = 22.142  |  alpha_x = 101.574 |  alpha_y = -0.428
# s = 77.735 m  |  beta_x = 1077.443  | beta_y = 22.228  |  alpha_x = 100.634 |  alpha_y = -0.434
# s = 77.835 m  |  beta_x = 1057.410  | beta_y = 22.316  |  alpha_x = 99.694 |  alpha_y = -0.439
# s = 77.935 m  |  beta_x = 1037.565  | beta_y = 22.404  |  alpha_x = 98.754 |  alpha_y = -0.444
# s = 78.035 m  |  beta_x = 1017.908  | beta_y = 22.494  |  alpha_x = 97.814 |  alpha_y = -0.450
# s = 78.135 m  |  beta_x = 998.440  | beta_y = 22.584  |  alpha_x = 96.874 |  alpha_y = -0.455
# s = 78.235 m  |  beta_x = 979.159  | beta_y = 22.676  |  alpha_x = 95.934 |  alpha_y = -0.460
# s = 78.335 m  |  beta_x = 960.066  | beta_y = 22.768  |  alpha_x = 94.994 |  alpha_y = -0.466
# s = 78.435 m  |  beta_x = 941.161  | beta_y = 22.862  |  alpha_x = 94.054 |  alpha_y = -0.471
# s = 78.535 m  |  beta_x = 922.444  | beta_y = 22.957  |  alpha_x = 93.114 |  alpha_y = -0.476
# s = 78.635 m  |  beta_x = 903.916  | beta_y = 23.052  |  alpha_x = 92.174 |  alpha_y = -0.482
# s = 78.735 m  |  beta_x = 885.575  | beta_y = 23.149  |  alpha_x = 91.234 |  alpha_y = -0.487
# s = 78.835 m  |  beta_x = 867.422  | beta_y = 23.247  |  alpha_x = 90.294 |  alpha_y = -0.492
# s = 78.935 m  |  beta_x = 849.458  | beta_y = 23.346  |  alpha_x = 89.354 |  alpha_y = -0.498
# s = 79.035 m  |  beta_x = 831.681  | beta_y = 23.446  |  alpha_x = 88.414 |  alpha_y = -0.503
# s = 79.135 m  |  beta_x = 814.092  | beta_y = 23.548  |  alpha_x = 87.474 |  alpha_y = -0.509
# s = 79.235 m  |  beta_x = 796.691  | beta_y = 23.650  |  alpha_x = 86.534 |  alpha_y = -0.514
# s = 79.335 m  |  beta_x = 779.479  | beta_y = 23.753  |  alpha_x = 85.594 |  alpha_y = -0.519
# s = 79.435 m  |  beta_x = 762.454  | beta_y = 23.857  |  alpha_x = 84.654 |  alpha_y = -0.525
# s = 79.535 m  |  beta_x = 745.617  | beta_y = 23.963  |  alpha_x = 83.714 |  alpha_y = -0.530
# s = 79.635 m  |  beta_x = 728.969  | beta_y = 24.069  |  alpha_x = 82.773 |  alpha_y = -0.535
# s = 79.735 m  |  beta_x = 712.508  | beta_y = 24.177  |  alpha_x = 81.833 |  alpha_y = -0.541
# s = 79.835 m  |  beta_x = 696.235  | beta_y = 24.286  |  alpha_x = 80.893 |  alpha_y = -0.546
# s = 79.935 m  |  beta_x = 680.150  | beta_y = 24.395  |  alpha_x = 79.953 |  alpha_y = -0.551
# s = 80.035 m  |  beta_x = 664.254  | beta_y = 24.506  |  alpha_x = 79.013 |  alpha_y = -0.557
# s = 80.135 m  |  beta_x = 648.545  | beta_y = 24.618  |  alpha_x = 78.073 |  alpha_y = -0.562
# s = 80.235 m  |  beta_x = 633.024  | beta_y = 24.731  |  alpha_x = 77.133 |  alpha_y = -0.567
# s = 80.335 m  |  beta_x = 617.692  | beta_y = 24.845  |  alpha_x = 76.193 |  alpha_y = -0.573
# s = 80.435 m  |  beta_x = 602.547  | beta_y = 24.960  |  alpha_x = 75.253 |  alpha_y = -0.578
# s = 80.535 m  |  beta_x = 587.590  | beta_y = 25.076  |  alpha_x = 74.313 |  alpha_y = -0.583
# s = 80.635 m  |  beta_x = 572.822  | beta_y = 25.193  |  alpha_x = 73.373 |  alpha_y = -0.589
# s = 80.735 m  |  beta_x = 558.241  | beta_y = 25.312  |  alpha_x = 72.433 |  alpha_y = -0.594
# s = 80.835 m  |  beta_x = 543.848  | beta_y = 25.431  |  alpha_x = 71.493 |  alpha_y = -0.599
# s = 80.935 m  |  beta_x = 529.644  | beta_y = 25.551  |  alpha_x = 70.553 |  alpha_y = -0.605
# s = 81.035 m  |  beta_x = 515.627  | beta_y = 25.673  |  alpha_x = 69.613 |  alpha_y = -0.610
# s = 81.135 m  |  beta_x = 501.798  | beta_y = 25.795  |  alpha_x = 68.673 |  alpha_y = -0.615
# s = 81.235 m  |  beta_x = 488.158  | beta_y = 25.919  |  alpha_x = 67.733 |  alpha_y = -0.621
# s = 81.335 m  |  beta_x = 474.705  | beta_y = 26.044  |  alpha_x = 66.793 |  alpha_y = -0.626
# s = 81.435 m  |  beta_x = 461.441  | beta_y = 26.169  |  alpha_x = 65.853 |  alpha_y = -0.631
# s = 81.535 m  |  beta_x = 448.364  | beta_y = 26.296  |  alpha_x = 64.913 |  alpha_y = -0.637
# s = 81.635 m  |  beta_x = 435.678  | beta_y = 26.412  |  alpha_x = 59.324 |  alpha_y = -0.360
# s = 81.735 m  |  beta_x = 424.948  | beta_y = 26.419  |  alpha_x = 48.061 |  alpha_y = 0.287
# s = 81.835 m  |  beta_x = 416.422  | beta_y = 26.297  |  alpha_x = 37.272 |  alpha_y = 0.931
# s = 81.935 m  |  beta_x = 410.015  | beta_y = 26.048  |  alpha_x = 26.850 |  alpha_y = 1.565
# s = 82.035 m  |  beta_x = 405.664  | beta_y = 25.672  |  alpha_x = 16.693 |  alpha_y = 2.185
# s = 82.135 m  |  beta_x = 403.294  | beta_y = 25.177  |  alpha_x = 8.492 |  alpha_y = 2.671
# s = 82.235 m  |  beta_x = 401.598  | beta_y = 24.646  |  alpha_x = 8.474 |  alpha_y = 2.639
# s = 82.335 m  |  beta_x = 399.905  | beta_y = 24.122  |  alpha_x = 8.456 |  alpha_y = 2.606
# s = 82.435 m  |  beta_x = 398.215  | beta_y = 23.604  |  alpha_x = 8.438 |  alpha_y = 2.574
# s = 82.535 m  |  beta_x = 396.530  | beta_y = 23.092  |  alpha_x = 8.419 |  alpha_y = 2.542
# s = 82.635 m  |  beta_x = 394.848  | beta_y = 22.587  |  alpha_x = 8.401 |  alpha_y = 2.509
# s = 82.735 m  |  beta_x = 393.169  | beta_y = 22.088  |  alpha_x = 8.383 |  alpha_y = 2.477
# s = 82.835 m  |  beta_x = 391.494  | beta_y = 21.596  |  alpha_x = 8.365 |  alpha_y = 2.445
# s = 82.935 m  |  beta_x = 389.823  | beta_y = 21.110  |  alpha_x = 8.347 |  alpha_y = 2.413
# s = 83.035 m  |  beta_x = 388.156  | beta_y = 20.631  |  alpha_x = 8.329 |  alpha_y = 2.380
# s = 83.135 m  |  beta_x = 386.492  | beta_y = 20.158  |  alpha_x = 8.311 |  alpha_y = 2.348
# s = 83.235 m  |  beta_x = 384.831  | beta_y = 19.692  |  alpha_x = 8.293 |  alpha_y = 2.316
# s = 83.335 m  |  beta_x = 383.175  | beta_y = 19.232  |  alpha_x = 8.274 |  alpha_y = 2.283
# s = 83.435 m  |  beta_x = 381.522  | beta_y = 18.779  |  alpha_x = 8.256 |  alpha_y = 2.251
# s = 83.535 m  |  beta_x = 379.872  | beta_y = 18.332  |  alpha_x = 8.238 |  alpha_y = 2.219
# s = 83.635 m  |  beta_x = 378.226  | beta_y = 17.891  |  alpha_x = 8.220 |  alpha_y = 2.186
# s = 83.735 m  |  beta_x = 376.584  | beta_y = 17.457  |  alpha_x = 8.202 |  alpha_y = 2.154
# s = 83.835 m  |  beta_x = 374.946  | beta_y = 17.029  |  alpha_x = 8.184 |  alpha_y = 2.122
# s = 83.935 m  |  beta_x = 373.311  | beta_y = 16.608  |  alpha_x = 8.166 |  alpha_y = 2.089
# s = 84.035 m  |  beta_x = 371.679  | beta_y = 16.194  |  alpha_x = 8.147 |  alpha_y = 2.057
# s = 84.135 m  |  beta_x = 370.052  | beta_y = 15.786  |  alpha_x = 8.129 |  alpha_y = 2.025
# s = 84.235 m  |  beta_x = 368.428  | beta_y = 15.384  |  alpha_x = 8.111 |  alpha_y = 1.993
# s = 84.335 m  |  beta_x = 366.807  | beta_y = 14.988  |  alpha_x = 8.093 |  alpha_y = 1.960
# s = 84.435 m  |  beta_x = 365.190  | beta_y = 14.600  |  alpha_x = 8.075 |  alpha_y = 1.928
# s = 84.535 m  |  beta_x = 363.577  | beta_y = 14.217  |  alpha_x = 8.057 |  alpha_y = 1.896
# s = 84.635 m  |  beta_x = 361.968  | beta_y = 13.841  |  alpha_x = 8.039 |  alpha_y = 1.863
# s = 84.735 m  |  beta_x = 360.574  | beta_y = 13.466  |  alpha_x = 4.190 |  alpha_y = 1.865
# s = 84.835 m  |  beta_x = 360.079  | beta_y = 13.096  |  alpha_x = 0.833 |  alpha_y = 1.832
# s = 84.935 m  |  beta_x = 360.510  | beta_y = 12.733  |  alpha_x = -2.524 |  alpha_y = 1.799
# s = 85.035 m  |  beta_x = 361.871  | beta_y = 12.377  |  alpha_x = -5.896 |  alpha_y = 1.766
# s = 85.135 m  |  beta_x = 364.170  | beta_y = 12.027  |  alpha_x = -9.302 |  alpha_y = 1.732
# s = 85.235 m  |  beta_x = 367.421  | beta_y = 11.684  |  alpha_x = -12.756 |  alpha_y = 1.699
# s = 85.335 m  |  beta_x = 371.644  | beta_y = 11.347  |  alpha_x = -16.277 |  alpha_y = 1.666
# s = 85.435 m  |  beta_x = 376.863  | beta_y = 11.018  |  alpha_x = -19.883 |  alpha_y = 1.632
# s = 85.535 m  |  beta_x = 383.109  | beta_y = 10.694  |  alpha_x = -23.590 |  alpha_y = 1.599
# s = 85.635 m  |  beta_x = 390.421  | beta_y = 10.378  |  alpha_x = -27.417 |  alpha_y = 1.566
# s = 85.735 m  |  beta_x = 398.841  | beta_y = 10.068  |  alpha_x = -31.385 |  alpha_y = 1.533
# s = 85.835 m  |  beta_x = 408.418  | beta_y = 9.765  |  alpha_x = -35.513 |  alpha_y = 1.499
# s = 85.935 m  |  beta_x = 419.211  | beta_y = 9.468  |  alpha_x = -39.822 |  alpha_y = 1.466
# s = 86.035 m  |  beta_x = 431.281  | beta_y = 9.178  |  alpha_x = -44.334 |  alpha_y = 1.433
# s = 86.135 m  |  beta_x = 444.702  | beta_y = 8.895  |  alpha_x = -49.072 |  alpha_y = 1.400
# s = 86.235 m  |  beta_x = 459.550  | beta_y = 8.618  |  alpha_x = -54.061 |  alpha_y = 1.366
# s = 86.335 m  |  beta_x = 475.913  | beta_y = 8.349  |  alpha_x = -59.327 |  alpha_y = 1.333
# ...
# s = 369.313 m  |  beta_x = 1.913  | beta_y = 726.199  |  alpha_x = 0.307 |  alpha_y = 17.392
# s = 369.420 m  |  beta_x = 1.854  | beta_y = 722.470  |  alpha_x = 0.245 |  alpha_y = 17.347
# s = 369.545 m  |  beta_x = 1.801  | beta_y = 718.140  |  alpha_x = 0.174 |  alpha_y = 17.295
# s = 369.670 m  |  beta_x = 1.767  | beta_y = 713.823  |  alpha_x = 0.102 |  alpha_y = 17.242
# s = 375.374 m  |  beta_x = 19.210  | beta_y = 530.712  |  alpha_x = -3.160 |  alpha_y = 14.859
# s = 375.499 m  |  beta_x = 20.009  | beta_y = 527.004  |  alpha_x = -3.232 |  alpha_y = 14.806
# s = 375.624 m  |  beta_x = 20.826  | beta_y = 523.309  |  alpha_x = -3.303 |  alpha_y = 14.754
# s = 375.749 m  |  beta_x = 21.660  | beta_y = 519.627  |  alpha_x = -3.375 |  alpha_y = 14.702
# s = 375.874 m  |  beta_x = 22.513  | beta_y = 515.958  |  alpha_x = -3.446 |  alpha_y = 14.650
# s = 375.974 m  |  beta_x = 23.208  | beta_y = 513.032  |  alpha_x = -3.503 |  alpha_y = 14.608
# s = 376.174 m  |  beta_x = 24.632  | beta_y = 507.205  |  alpha_x = -3.618 |  alpha_y = 14.524
# s = 376.362 m  |  beta_x = 26.008  | beta_y = 501.778  |  alpha_x = -3.725 |  alpha_y = 14.446
# s = 376.887 m  |  beta_x = 26.754  | beta_y = 548.436  |  alpha_x = 2.361 |  alpha_y = -106.808
# s = 376.994 m  |  beta_x = 26.250  | beta_y = 571.607  |  alpha_x = 2.335 |  alpha_y = -109.041
# s = 377.119 m  |  beta_x = 25.670  | beta_y = 599.192  |  alpha_x = 2.304 |  alpha_y = -111.641
# s = 377.244 m  |  beta_x = 25.098  | beta_y = 627.428  |  alpha_x = 2.274 |  alpha_y = -114.241
# s = 382.949 m  |  beta_x = 7.158  | beta_y = 2607.624  |  alpha_x = 0.871 |  alpha_y = -232.904
# s = 383.449 m  |  beta_x = 6.348  | beta_y = 2845.728  |  alpha_x = 0.749 |  alpha_y = -243.305
# s = 383.549 m  |  beta_x = 6.201  | beta_y = 2894.598  |  alpha_x = 0.724 |  alpha_y = -245.386
# s = 383.749 m  |  beta_x = 5.921  | beta_y = 2993.584  |  alpha_x = 0.675 |  alpha_y = -249.546
# s = 383.936 m  |  beta_x = 5.677  | beta_y = 3087.819  |  alpha_x = 0.629 |  alpha_y = -253.444
# s = 384.461 m  |  beta_x = 5.752  | beta_y = 2977.414  |  alpha_x = -0.777 |  alpha_y = 455.011
# s = 384.569 m  |  beta_x = 5.922  | beta_y = 2880.525  |  alpha_x = -0.807 |  alpha_y = 447.546
# s = 384.694 m  |  beta_x = 6.129  | beta_y = 2769.724  |  alpha_x = -0.842 |  alpha_y = 438.854
# s = 384.819 m  |  beta_x = 6.344  | beta_y = 2661.097  |  alpha_x = -0.877 |  alpha_y = 430.162
# s = 390.523 m  |  beta_x = 25.426  | beta_y = 16.169  |  alpha_x = -2.468 |  alpha_y = 33.516
# s = 390.648 m  |  beta_x = 26.048  | beta_y = 8.877  |  alpha_x = -2.503 |  alpha_y = 24.824
# s = 390.773 m  |  beta_x = 26.678  | beta_y = 3.757  |  alpha_x = -2.538 |  alpha_y = 16.132
# s = 390.898 m  |  beta_x = 27.317  | beta_y = 0.810  |  alpha_x = -2.573 |  alpha_y = 7.440
# s = 391.023 m  |  beta_x = 27.964  | beta_y = 0.037  |  alpha_x = -2.608 |  alpha_y = -1.252
# s = 391.123 m  |  beta_x = 28.488  | beta_y = 0.983  |  alpha_x = -2.636 |  alpha_y = -8.205
# s = 391.323 m  |  beta_x = 29.554  | beta_y = 7.046  |  alpha_x = -2.691 |  alpha_y = -22.112
# s = 391.510 m  |  beta_x = 30.572  | beta_y = 17.772  |  alpha_x = -2.744 |  alpha_y = -35.140
# s = 392.036 m  |  beta_x = 29.762  | beta_y = 79.931  |  alpha_x = 4.223 |  alpha_y = -87.908
# s = 392.143 m  |  beta_x = 28.863  | beta_y = 99.920  |  alpha_x = 4.155 |  alpha_y = -98.288
# s = 392.268 m  |  beta_x = 27.834  | beta_y = 126.002  |  alpha_x = 4.076 |  alpha_y = -110.374
# s = 392.393 m  |  beta_x = 26.825  | beta_y = 155.107  |  alpha_x = 3.997 |  alpha_y = -122.461
# s = 398.097 m  |  beta_x = 1.818  | beta_y = 4698.424  |  alpha_x = 0.387 |  alpha_y = -674.020
# s = 398.597 m  |  beta_x = 1.588  | beta_y = 5396.620  |  alpha_x = 0.071 |  alpha_y = -722.367
# s = 398.697 m  |  beta_x = 1.581  | beta_y = 5542.060  |  alpha_x = 0.008 |  alpha_y = -732.036
# s = 398.897 m  |  beta_x = 1.603  | beta_y = 5838.743  |  alpha_x = -0.119 |  alpha_y = -751.375
# s = 399.084 m  |  beta_x = 1.669  | beta_y = 6123.678  |  alpha_x = -0.237 |  alpha_y = -769.490
# s = 399.610 m  |  beta_x = 2.333  | beta_y = 6177.535  |  alpha_x = -1.077 |  alpha_y = 671.092
# s = 399.717 m  |  beta_x = 2.575  | beta_y = 6034.292  |  alpha_x = -1.176 |  alpha_y = 663.266
# s = 399.842 m  |  beta_x = 2.883  | beta_y = 5869.614  |  alpha_x = -1.292 |  alpha_y = 654.153
# s = 399.967 m  |  beta_x = 3.221  | beta_y = 5707.215  |  alpha_x = -1.408 |  alpha_y = 645.040
# s = 405.671 m  |  beta_x = 49.396  | beta_y = 720.464  |  alpha_x = -6.687 |  alpha_y = 229.180
# s = 406.171 m  |  beta_x = 56.315  | beta_y = 509.509  |  alpha_x = -7.150 |  alpha_y = 192.728
# s = 406.271 m  |  beta_x = 57.754  | beta_y = 471.692  |  alpha_x = -7.243 |  alpha_y = 185.438
# s = 406.471 m  |  beta_x = 60.688  | beta_y = 400.433  |  alpha_x = -7.428 |  alpha_y = 170.857
# s = 406.659 m  |  beta_x = 63.504  | beta_y = 338.972  |  alpha_x = -7.601 |  alpha_y = 157.199
# s = 407.184 m  |  beta_x = 65.241  | beta_y = 217.767  |  alpha_x = 4.403 |  alpha_y = 80.979
# s = 407.291 m  |  beta_x = 64.299  | beta_y = 200.728  |  alpha_x = 4.369 |  alpha_y = 77.746
# s = 407.391 m  |  beta_x = 63.428  | beta_y = 185.480  |  alpha_x = 4.338 |  alpha_y = 74.734
# s = 407.491 m  |  beta_x = 62.564  | beta_y = 170.834  |  alpha_x = 4.307 |  alpha_y = 71.722
# s = 407.768 m  |  beta_x = 60.203  | beta_y = 133.424  |  alpha_x = 4.220 |  alpha_y = 63.383
# s = 409.674 m  |  beta_x = 44.958  | beta_y = 22.221  |  alpha_x = 3.755 |  alpha_y = 16.233
# s = 409.849 m  |  beta_x = 43.654  | beta_y = 16.904  |  alpha_x = 3.696 |  alpha_y = 14.150
# s = 410.024 m  |  beta_x = 42.371  | beta_y = 12.316  |  alpha_x = 3.638 |  alpha_y = 12.067
# s = 411.930 m  |  beta_x = 29.527  | beta_y = 18.541  |  alpha_x = 3.082 |  alpha_y = -2.864
# s = 412.779 m  |  beta_x = 24.552  | beta_y = 23.758  |  alpha_x = 2.781 |  alpha_y = -3.285
# s = 415.657 m  |  beta_x = 11.491  | beta_y = 46.783  |  alpha_x = 1.757 |  alpha_y = -4.714
# s = 415.782 m  |  beta_x = 11.058  | beta_y = 47.969  |  alpha_x = 1.712 |  alpha_y = -4.776
# s = 415.907 m  |  beta_x = 10.635  | beta_y = 49.170  |  alpha_x = 1.668 |  alpha_y = -4.838
# s = 416.032 m  |  beta_x = 10.224  | beta_y = 50.388  |  alpha_x = 1.624 |  alpha_y = -4.900
# s = 416.157 m  |  beta_x = 9.823  | beta_y = 51.620  |  alpha_x = 1.579 |  alpha_y = -4.962
# s = 416.257 m  |  beta_x = 9.511  | beta_y = 52.618  |  alpha_x = 1.544 |  alpha_y = -5.011
# s = 416.457 m  |  beta_x = 8.908  | beta_y = 54.642  |  alpha_x = 1.472 |  alpha_y = -5.111
# s = 416.645 m  |  beta_x = 8.369  | beta_y = 56.574  |  alpha_x = 1.406 |  alpha_y = -5.204
# s = 417.170 m  |  beta_x = 7.641  | beta_y = 57.181  |  alpha_x = 0.018 |  alpha_y = 4.082
# s = 417.277 m  |  beta_x = 7.639  | beta_y = 56.308  |  alpha_x = 0.004 |  alpha_y = 4.049
# s = 417.402 m  |  beta_x = 7.640  | beta_y = 55.301  |  alpha_x = -0.013 |  alpha_y = 4.010
# s = 417.527 m  |  beta_x = 7.645  | beta_y = 54.303  |  alpha_x = -0.029 |  alpha_y = 3.971
# s = 424.390 m  |  beta_x = 14.206  | beta_y = 14.341  |  alpha_x = -0.927 |  alpha_y = 1.852
# s = 424.515 m  |  beta_x = 14.440  | beta_y = 13.883  |  alpha_x = -0.944 |  alpha_y = 1.813
# s = 424.640 m  |  beta_x = 14.678  | beta_y = 13.435  |  alpha_x = -0.960 |  alpha_y = 1.775
# s = 424.765 m  |  beta_x = 14.920  | beta_y = 12.996  |  alpha_x = -0.976 |  alpha_y = 1.736
# s = 424.890 m  |  beta_x = 15.166  | beta_y = 12.567  |  alpha_x = -0.993 |  alpha_y = 1.697
# s = 424.976 m  |  beta_x = 15.340  | beta_y = 12.274  |  alpha_x = -1.004 |  alpha_y = 1.671
# s = 425.353 m  |  beta_x = 14.969  | beta_y = 11.929  |  alpha_x = 1.963 |  alpha_y = -0.732
# s = 425.460 m  |  beta_x = 14.553  | beta_y = 12.087  |  alpha_x = 1.929 |  alpha_y = -0.746
# s = 425.585 m  |  beta_x = 14.076  | beta_y = 12.276  |  alpha_x = 1.888 |  alpha_y = -0.762
# s = 425.710 m  |  beta_x = 13.609  | beta_y = 12.468  |  alpha_x = 1.848 |  alpha_y = -0.778
# s = 426.058 m  |  beta_x = 12.360  | beta_y = 13.027  |  alpha_x = 1.734 |  alpha_y = -0.823
# s = 427.871 m  |  beta_x = 10.138  | beta_y = 16.358  |  alpha_x = -10.954 |  alpha_y = -1.010
# s = 428.258 m  |  beta_x = 20.388  | beta_y = 17.157  |  alpha_x = -15.567 |  alpha_y = -1.058
# s = 430.070 m  |  beta_x = 114.039  | beta_y = 21.300  |  alpha_x = -56.785 |  alpha_y = -1.222
# s = 430.738 m  |  beta_x = 202.491  | beta_y = 22.984  |  alpha_x = -75.672 |  alpha_y = -1.300
# s = 432.551 m  |  beta_x = 553.848  | beta_y = 27.949  |  alpha_x = -168.303 |  alpha_y = -1.433
# s = 432.934 m  |  beta_x = 690.605  | beta_y = 29.066  |  alpha_x = -187.937 |  alpha_y = -1.475
# s = 433.134 m  |  beta_x = 767.826  | beta_y = 29.660  |  alpha_x = -198.166 |  alpha_y = -1.496
# s = 433.322 m  |  beta_x = 843.874  | beta_y = 30.224  |  alpha_x = -207.748 |  alpha_y = -1.517
# s = 433.847 m  |  beta_x = 1157.724  | beta_y = 29.412  |  alpha_x = -405.529 |  alpha_y = 3.022
# s = 433.954 m  |  beta_x = 1246.429  | beta_y = 28.767  |  alpha_x = -420.778 |  alpha_y = 2.985
# s = 434.079 m  |  beta_x = 1353.844  | beta_y = 28.026  |  alpha_x = -438.535 |  alpha_y = 2.942
# s = 434.204 m  |  beta_x = 1465.698  | beta_y = 27.296  |  alpha_x = -456.291 |  alpha_y = 2.899
# s = 434.537 m  |  beta_x = 1784.936  | beta_y = 25.405  |  alpha_x = -503.537 |  alpha_y = 2.785
# s = 436.350 m  |  beta_x = 3750.510  | beta_y = 16.337  |  alpha_x = -813.040 |  alpha_y = 2.205
# s = 436.736 m  |  beta_x = 4405.302  | beta_y = 14.687  |  alpha_x = -881.160 |  alpha_y = 2.066
# s = 438.549 m  |  beta_x = 6212.705  | beta_y = 8.318  |  alpha_x = -1041.390 |  alpha_y = 1.438
# s = 438.869 m  |  beta_x = 6897.600  | beta_y = 7.435  |  alpha_x = -1097.291 |  alpha_y = 1.320
# s = 438.969 m  |  beta_x = 7118.803  | beta_y = 7.175  |  alpha_x = -1114.747 |  alpha_y = 1.283
# s = 439.017 m  |  beta_x = 7226.221  | beta_y = 7.052  |  alpha_x = -1123.126 |  alpha_y = 1.265
# s = 439.142 m  |  beta_x = 7509.729  | beta_y = 6.742  |  alpha_x = -1144.945 |  alpha_y = 1.219
# s = 439.267 m  |  beta_x = 7798.691  | beta_y = 6.443  |  alpha_x = -1166.765 |  alpha_y = 1.173
# s = 439.354 m  |  beta_x = 8002.791  | beta_y = 6.241  |  alpha_x = -1181.934 |  alpha_y = 1.141
# s = 439.730 m  |  beta_x = 8152.820  | beta_y = 5.972  |  alpha_x = 794.618 |  alpha_y = -0.402
# s = 439.837 m  |  beta_x = 7983.817  | beta_y = 6.060  |  alpha_x = 786.339 |  alpha_y = -0.423
# s = 439.962 m  |  beta_x = 7788.444  | beta_y = 6.169  |  alpha_x = 776.659 |  alpha_y = -0.448
# s = 440.087 m  |  beta_x = 7595.491  | beta_y = 6.284  |  alpha_x = 766.978 |  alpha_y = -0.472
# s = 440.436 m  |  beta_x = 7069.739  | beta_y = 6.637  |  alpha_x = 739.957 |  alpha_y = -0.540
# s = 442.248 m  |  beta_x = 3614.313  | beta_y = 9.193  |  alpha_x = 357.547 |  alpha_y = -0.867
# s = 442.635 m  |  beta_x = 3343.223  | beta_y = 9.892  |  alpha_x = 343.877 |  alpha_y = -0.941
# s = 444.448 m  |  beta_x = 1990.747  | beta_y = 13.869  |  alpha_x = 177.265 |  alpha_y = -1.247
# s = 445.097 m  |  beta_x = 1767.243  | beta_y = 15.566  |  alpha_x = 167.018 |  alpha_y = -1.367
# s = 445.222 m  |  beta_x = 1725.735  | beta_y = 15.911  |  alpha_x = 165.045 |  alpha_y = -1.390
# s = 445.347 m  |  beta_x = 1684.720  | beta_y = 16.261  |  alpha_x = 163.072 |  alpha_y = -1.413
# s = 445.472 m  |  beta_x = 1644.199  | beta_y = 16.617  |  alpha_x = 161.099 |  alpha_y = -1.436
# s = 445.597 m  |  beta_x = 1604.171  | beta_y = 16.979  |  alpha_x = 159.125 |  alpha_y = -1.459
# s = 445.847 m  |  beta_x = 1525.595  | beta_y = 17.720  |  alpha_x = 155.179 |  alpha_y = -1.505
# s = 445.937 m  |  beta_x = 1497.790  | beta_y = 17.993  |  alpha_x = 153.759 |  alpha_y = -1.522
# s = 446.037 m  |  beta_x = 1467.196  | beta_y = 18.299  |  alpha_x = 152.180 |  alpha_y = -1.540
# s = 446.237 m  |  beta_x = 1406.956  | beta_y = 18.923  |  alpha_x = 149.023 |  alpha_y = -1.577
# s = 446.424 m  |  beta_x = 1351.671  | beta_y = 19.520  |  alpha_x = 146.066 |  alpha_y = -1.612
# s = 446.949 m  |  beta_x = 1287.930  | beta_y = 19.916  |  alpha_x = -22.041 |  alpha_y = 0.876
# s = 447.057 m  |  beta_x = 1292.667  | beta_y = 19.729  |  alpha_x = -22.082 |  alpha_y = 0.866
# s = 447.182 m  |  beta_x = 1298.193  | beta_y = 19.513  |  alpha_x = -22.129 |  alpha_y = 0.855
# s = 447.307 m  |  beta_x = 1303.731  | beta_y = 19.301  |  alpha_x = -22.176 |  alpha_y = 0.844
# s = 447.407 m  |  beta_x = 1308.170  | beta_y = 19.133  |  alpha_x = -22.214 |  alpha_y = 0.835
# s = 447.557 m  |  beta_x = 1314.843  | beta_y = 18.885  |  alpha_x = -22.271 |  alpha_y = 0.822
# s = 447.707 m  |  beta_x = 1321.533  | beta_y = 18.640  |  alpha_x = -22.327 |  alpha_y = 0.809
# s = 447.807 m  |  beta_x = 1326.002  | beta_y = 18.479  |  alpha_x = -22.365 |  alpha_y = 0.800
# s = 448.336 m  |  beta_x = 1349.762  | beta_y = 17.658  |  alpha_x = -22.565 |  alpha_y = 0.753
# s = 450.148 m  |  beta_x = 1670.554  | beta_y = 15.137  |  alpha_x = -89.904 |  alpha_y = 0.635
# s = 450.535 m  |  beta_x = 1740.770  | beta_y = 14.660  |  alpha_x = -91.774 |  alpha_y = 0.599
# s = 452.347 m  |  beta_x = 2684.694  | beta_y = 12.723  |  alpha_x = -214.176 |  alpha_y = 0.467
# s = 452.668 m  |  beta_x = 2823.907  | beta_y = 12.434  |  alpha_x = -219.659 |  alpha_y = 0.436
# s = 452.768 m  |  beta_x = 2868.010  | beta_y = 12.347  |  alpha_x = -221.367 |  alpha_y = 0.426
# s = 452.816 m  |  beta_x = 2889.301  | beta_y = 12.307  |  alpha_x = -222.188 |  alpha_y = 0.422
# s = 452.906 m  |  beta_x = 2929.433  | beta_y = 12.232  |  alpha_x = -223.725 |  alpha_y = 0.413
# s = 452.993 m  |  beta_x = 2968.446  | beta_y = 12.160  |  alpha_x = -225.210 |  alpha_y = 0.405
# s = 453.369 m  |  beta_x = 2874.743  | beta_y = 12.963  |  alpha_x = 466.864 |  alpha_y = -2.600
# s = 453.476 m  |  beta_x = 2775.794  | beta_y = 13.525  |  alpha_x = 458.759 |  alpha_y = -2.664
# s = 453.601 m  |  beta_x = 2662.289  | beta_y = 14.200  |  alpha_x = 449.282 |  alpha_y = -2.738
# s = 453.726 m  |  beta_x = 2551.153  | beta_y = 14.894  |  alpha_x = 439.804 |  alpha_y = -2.813
# s = 454.174 m  |  beta_x = 2172.424  | beta_y = 17.534  |  alpha_x = 405.848 |  alpha_y = -3.081
# s = 455.987 m  |  beta_x = 1397.590  | beta_y = 30.558  |  alpha_x = 302.031 |  alpha_y = -4.083
# s = 456.373 m  |  beta_x = 1174.310  | beta_y = 33.793  |  alpha_x = 276.855 |  alpha_y = -4.306
# s = 458.186 m  |  beta_x = 629.813  | beta_y = 51.096  |  alpha_x = 179.531 |  alpha_y = -5.212
# s = 458.489 m  |  beta_x = 525.764  | beta_y = 54.304  |  alpha_x = 164.032 |  alpha_y = -5.379
# s = 458.589 m  |  beta_x = 493.469  | beta_y = 55.385  |  alpha_x = 158.914 |  alpha_y = -5.434
# s = 458.789 m  |  beta_x = 431.950  | beta_y = 57.581  |  alpha_x = 148.678 |  alpha_y = -5.544
# s = 458.977 m  |  beta_x = 378.037  | beta_y = 59.677  |  alpha_x = 139.090 |  alpha_y = -5.647
# s = 459.502 m  |  beta_x = 266.126  | beta_y = 61.488  |  alpha_x = 78.804 |  alpha_y = 2.280
# s = 459.609 m  |  beta_x = 249.475  | beta_y = 60.999  |  alpha_x = 76.299 |  alpha_y = 2.269
# s = 459.734 m  |  beta_x = 230.765  | beta_y = 60.434  |  alpha_x = 73.381 |  alpha_y = 2.257
# s = 459.859 m  |  beta_x = 212.785  | beta_y = 59.871  |  alpha_x = 70.464 |  alpha_y = 2.244
# s = 459.962 m  |  beta_x = 198.599  | beta_y = 59.413  |  alpha_x = 68.074 |  alpha_y = 2.234
# s = 460.211 m  |  beta_x = 166.127  | beta_y = 58.306  |  alpha_x = 62.259 |  alpha_y = 2.209
# s = 461.211 m  |  beta_x = 94.421  | beta_y = 53.910  |  alpha_x = 39.443 |  alpha_y = 2.184
# s = 461.631 m  |  beta_x = 64.197  | beta_y = 52.095  |  alpha_x = 32.518 |  alpha_y = 2.139
# s = 462.631 m  |  beta_x = 30.383  | beta_y = 47.854  |  alpha_x = 17.695 |  alpha_y = 2.099
# s = 463.051 m  |  beta_x = 17.343  | beta_y = 46.111  |  alpha_x = 13.353 |  alpha_y = 2.051
# s = 464.051 m  |  beta_x = 5.357  | beta_y = 42.066  |  alpha_x = 5.155 |  alpha_y = 1.991
# s = 464.471 m  |  beta_x = 1.935  | beta_y = 40.414  |  alpha_x = 2.993 |  alpha_y = 1.941
# s = 465.471 m  |  beta_x = 19.207  | beta_y = 36.528  |  alpha_x = -1.406 |  alpha_y = 1.880
# s = 465.778 m  |  beta_x = 20.084  | beta_y = 35.386  |  alpha_x = -1.453 |  alpha_y = 1.842
# s = 466.604 m  |  beta_x = 20.008  | beta_y = 36.736  |  alpha_x = 1.541 |  alpha_y = -3.544

# %%
def get_energy_at_s(s_target, tws_list):
    s_array = np.array([tw.s for tw in tws_list])
    E_array = np.array([tw.E for tw in tws_list])
    return np.interp(s_target, s_array, E_array)

# %%
def plot_opt_func(lat, tws, top_plot=["Dx"], legend=True, fig_name=None, grid=True, font_size=12,
                  excld_legend=None, figsize=None, plt_figure=None):
    from ocelot.cpbd.optics import lattice_transfer_map

    if plt_figure is None:
        if fig_name is None:
            fig = plt.figure(figsize=figsize)
        else:
            fig = plt.figure(fig_name, figsize=figsize)
    else:
        fig = plt_figure

    plt.rc('axes', grid=grid)
    plt.rc('grid', color='0.75', linestyle='-', linewidth=0.5)
    left, width = 0.1, 0.85

    rect1 = [left, 0.65, width, 0.3]
    rect2 = [left, 0.19, width, 0.46]
    rect3 = [left, 0.07, width, 0.12]

    ax_top = fig.add_axes(rect1)
    ax_b = fig.add_axes(rect2, sharex=ax_top)
    ax_el = fig.add_axes(rect3, sharex=ax_top)

    for ax in ax_b, ax_el, ax_top:
        if ax != ax_el:
            for label in ax.get_xticklabels():
                label.set_visible(False)

    ax_b.grid(grid)
    ax_top.grid(grid)
    ax_el.set_yticks([])
    ax_el.grid(grid)

    fig.subplots_adjust(hspace=0)
    beta_x = [p.beta_x for p in tws]
    beta_y = [p.beta_y for p in tws]
    S = [p.s for p in tws]

    plt.xlim(S[0], S[-1])

    # Plot standard Twiss parameters
    plot_disp(ax_top, tws, [p for p in top_plot if p != "R56"], font_size)

    # ---- Add R56 Plotting ----
    if "R56" in top_plot:
        R56_vals = []
        s_vals = []

        for i in range(2, len(lat.sequence)):
            partial_lat = MagneticLattice(lat.sequence[:i])
            s_here = sum(e.l for e in partial_lat.sequence)

            try:
                E_here = get_energy_at_s(s_here, tws)
                R = lattice_transfer_map(partial_lat, energy=E_here)
                r56 = R[4, 5]
            except Exception as e:
                print(f"[WARN] Failed R56 at s = {s_here:.2f} m: {e}")
                r56 = 0

            # Debug print
            if i % 50 == 0 or s_here > 100:  # customize condition as you like
                print(f"s = {s_here:.2f} m, E = {E_here:.3f} GeV, R56 = {r56*1000:.3f} mm")

            R56_vals.append(r56)
            s_vals.append(s_here)

        
        ax_top.plot(s_vals, np.array(R56_vals), label="R56 [m]", color="red", linewidth=2)

    if "R56" in top_plot or legend:
        ax_top.legend(fontsize=font_size - 2)

    # Plot betas and elements
    plot_betas(ax_b, S, beta_x, beta_y, font_size)
    plot_elems(fig, ax_el, lat, s_point=S[0], legend=legend, y_scale=0.8, font_size=font_size,
               excld_legend=excld_legend)

# %%
plot_opt_func(lat, tws, top_plot=["Dx", "R56"], legend=True )
# Out:
# s = 16.78 m, E = 7.000 GeV, R56 = -115.002 mm
# s = 34.79 m, E = 7.000 GeV, R56 = 5.696 mm
# s = 50.56 m, E = 7.000 GeV, R56 = 7.436 mm
# s = 74.91 m, E = 7.000 GeV, R56 = 20.367 mm
# s = 101.01 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 101.21 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 101.40 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 101.93 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 101.93 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 102.03 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 102.16 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 102.16 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 102.28 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 108.21 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 108.41 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 108.60 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.12 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.12 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.23 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.36 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.36 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 109.48 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 115.22 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 115.42 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 115.60 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 115.60 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.13 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.13 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.24 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.36 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.36 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.49 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.58 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.70 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.70 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 116.83 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 117.08 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 129.65 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 129.85 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.04 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.56 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.56 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.67 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.79 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.79 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 130.92 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 131.01 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 131.26 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 131.38 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 131.38 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 131.51 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 144.08 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 144.28 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 144.47 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 144.99 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 144.99 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.10 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.23 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.23 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.35 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.44 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.69 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.82 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.82 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 145.94 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 158.51 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 158.71 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 158.90 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.43 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.43 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.53 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.66 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.66 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.78 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 159.87 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 160.12 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 160.25 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 160.25 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 160.37 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 172.95 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 173.15 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 173.33 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 173.86 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 173.86 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 173.97 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.09 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.09 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.22 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.31 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.56 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.68 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.68 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 174.81 m, E = 7.000 GeV, R56 = 111.860 mm
# s = 187.38 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 187.58 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 187.77 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.29 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.29 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.40 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.53 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.53 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.65 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.90 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 188.99 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 189.12 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 189.12 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 189.24 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 201.81 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.01 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.20 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.73 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.73 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.83 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.96 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 202.96 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.08 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.18 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.18 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.28 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.38 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.67 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 203.67 m, E = 7.000 GeV, R56 = 111.859 mm
# s = 205.76 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 205.76 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 211.43 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 211.63 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 211.63 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 211.90 m, E = 7.000 GeV, R56 = 113.997 mm
# s = 213.98 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 213.98 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 214.30 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 214.83 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 214.83 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 214.94 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 215.04 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 215.04 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 215.14 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 215.37 m, E = 7.000 GeV, R56 = 174.518 mm
# s = 217.45 m, E = 7.000 GeV, R56 = 316.219 mm
# s = 217.45 m, E = 7.000 GeV, R56 = 316.219 mm
# s = 217.72 m, E = 7.000 GeV, R56 = 316.219 mm
# s = 219.80 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 219.80 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.03 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.05 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.05 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.08 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.17 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.54 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.54 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.68 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.80 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.80 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 220.93 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 221.16 m, E = 7.000 GeV, R56 = 549.520 mm
# s = 223.23 m, E = 7.000 GeV, R56 = 816.646 mm
# s = 223.23 m, E = 7.000 GeV, R56 = 816.646 mm
# s = 223.51 m, E = 7.000 GeV, R56 = 816.646 mm
# s = 225.58 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 225.58 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 225.83 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 226.03 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 226.22 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 226.74 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 226.74 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 226.88 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 227.01 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 227.01 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 227.13 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 227.36 m, E = 7.000 GeV, R56 = 1050.748 mm
# s = 229.44 m, E = 7.000 GeV, R56 = 1266.503 mm
# s = 229.44 m, E = 7.000 GeV, R56 = 1266.503 mm
# s = 229.71 m, E = 7.000 GeV, R56 = 1266.503 mm
# s = 231.79 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 231.79 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.15 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.53 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.53 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.66 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.79 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.79 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 232.91 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 233.14 m, E = 7.000 GeV, R56 = 1492.899 mm
# s = 235.22 m, E = 7.000 GeV, R56 = 1649.237 mm
# s = 235.22 m, E = 7.000 GeV, R56 = 1649.237 mm
# s = 235.49 m, E = 7.000 GeV, R56 = 1649.237 mm
# s = 237.57 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 237.57 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 237.81 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.01 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.20 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.73 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.73 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.86 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.99 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 238.99 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 239.11 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 239.34 m, E = 7.000 GeV, R56 = 1709.993 mm
# s = 241.42 m, E = 7.000 GeV, R56 = 1648.794 mm
# s = 241.42 m, E = 7.000 GeV, R56 = 1648.794 mm
# s = 241.69 m, E = 7.000 GeV, R56 = 1648.794 mm
# s = 243.77 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 243.77 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.13 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.51 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.51 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.65 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.77 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.77 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 244.90 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 245.12 m, E = 7.000 GeV, R56 = 1534.180 mm
# s = 247.20 m, E = 7.000 GeV, R56 = 1431.279 mm
# s = 247.20 m, E = 7.000 GeV, R56 = 1431.279 mm
# s = 247.47 m, E = 7.000 GeV, R56 = 1431.279 mm
# s = 249.55 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 249.55 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 249.80 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.00 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.19 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.71 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.71 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.85 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.97 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 250.97 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 251.10 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 251.32 m, E = 7.000 GeV, R56 = 1392.438 mm
# s = 253.40 m, E = 7.000 GeV, R56 = 1500.878 mm
# s = 253.40 m, E = 7.000 GeV, R56 = 1500.878 mm
# s = 253.67 m, E = 7.000 GeV, R56 = 1500.878 mm
# s = 255.75 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 255.75 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.12 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.49 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.49 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.63 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.75 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.75 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 256.88 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 257.11 m, E = 7.000 GeV, R56 = 1725.143 mm
# s = 259.18 m, E = 7.000 GeV, R56 = 1959.870 mm
# s = 259.18 m, E = 7.000 GeV, R56 = 1959.870 mm
# s = 259.46 m, E = 7.000 GeV, R56 = 1959.870 mm
# s = 261.53 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 261.53 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 261.78 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 261.98 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.17 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.69 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.69 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.83 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.96 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 262.96 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 263.08 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 263.31 m, E = 7.000 GeV, R56 = 2110.831 mm
# s = 265.39 m, E = 7.000 GeV, R56 = 2175.077 mm
# s = 265.39 m, E = 7.000 GeV, R56 = 2175.077 mm
# s = 265.39 m, E = 7.000 GeV, R56 = 2175.077 mm
# s = 269.90 m, E = 7.000 GeV, R56 = 2175.077 mm
# s = 269.90 m, E = 7.000 GeV, R56 = 2175.077 mm
# s = 271.98 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 271.98 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 271.98 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 272.43 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 272.96 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 272.96 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 273.06 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 273.19 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 273.19 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 273.31 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 274.70 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 274.83 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 274.83 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 274.95 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 278.67 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 278.87 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 278.97 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.10 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.10 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.22 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.33 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.86 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 279.86 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 286.93 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.45 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.45 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.56 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.68 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.68 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.81 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 287.91 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 288.11 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 294.13 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 294.33 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 294.52 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.05 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.05 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.15 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.28 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.28 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 295.40 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.36 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.48 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.48 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.61 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.73 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.73 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 296.86 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 297.13 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 297.13 m, E = 7.000 GeV, R56 = 2177.529 mm
# s = 299.22 m, E = 7.000 GeV, R56 = 2179.890 mm
# s = 299.22 m, E = 7.000 GeV, R56 = 2179.890 mm
# s = 299.22 m, E = 7.000 GeV, R56 = 2179.890 mm
# s = 299.49 m, E = 7.000 GeV, R56 = 2179.890 mm
# s = 301.57 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 301.57 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 301.95 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.33 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.33 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.44 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.56 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.56 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.69 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 302.92 m, E = 7.000 GeV, R56 = 2201.627 mm
# s = 305.00 m, E = 7.000 GeV, R56 = 2259.374 mm
# s = 305.00 m, E = 7.000 GeV, R56 = 2259.374 mm
# s = 305.32 m, E = 7.000 GeV, R56 = 2259.374 mm
# s = 307.40 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 307.40 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 307.97 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 308.17 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 308.36 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 308.88 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 308.88 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 308.99 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 309.11 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 309.11 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 309.24 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 309.47 m, E = 7.000 GeV, R56 = 2349.273 mm
# s = 311.55 m, E = 7.000 GeV, R56 = 2520.196 mm
# s = 311.55 m, E = 7.000 GeV, R56 = 2520.196 mm
# s = 311.87 m, E = 7.000 GeV, R56 = 2520.196 mm
# s = 313.95 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 313.95 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.34 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.71 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.71 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.82 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.94 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 314.94 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 315.07 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 315.30 m, E = 7.000 GeV, R56 = 2751.604 mm
# s = 317.38 m, E = 7.000 GeV, R56 = 2951.643 mm
# s = 317.38 m, E = 7.000 GeV, R56 = 2951.643 mm
# s = 317.70 m, E = 7.000 GeV, R56 = 2951.643 mm
# s = 319.78 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 319.78 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 320.35 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 320.55 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 320.74 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.26 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.26 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.37 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.50 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.50 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.62 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 321.85 m, E = 7.000 GeV, R56 = 3058.632 mm
# s = 323.93 m, E = 7.000 GeV, R56 = 3050.050 mm
# s = 323.93 m, E = 7.000 GeV, R56 = 3050.050 mm
# s = 324.25 m, E = 7.000 GeV, R56 = 3050.050 mm
# s = 326.54 m, E = 7.000 GeV, R56 = 3112.713 mm
# s = 326.54 m, E = 7.000 GeV, R56 = 3112.713 mm
# s = 330.21 m, E = 7.000 GeV, R56 = 3112.713 mm
# s = 330.21 m, E = 7.000 GeV, R56 = 3112.713 mm
# s = 332.50 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 332.50 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.31 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.68 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.68 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.79 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.92 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 333.92 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 334.04 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 334.49 m, E = 7.000 GeV, R56 = 3346.714 mm
# s = 336.78 m, E = 7.000 GeV, R56 = 3607.760 mm
# s = 336.78 m, E = 7.000 GeV, R56 = 3607.760 mm
# s = 337.09 m, E = 7.000 GeV, R56 = 3607.760 mm
# s = 339.38 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 339.38 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 339.78 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 339.98 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.16 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.69 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.69 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.80 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.92 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 340.92 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 341.05 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 341.47 m, E = 7.000 GeV, R56 = 3826.961 mm
# s = 343.77 m, E = 7.000 GeV, R56 = 4071.474 mm
# s = 343.77 m, E = 7.000 GeV, R56 = 4071.474 mm
# s = 344.07 m, E = 7.000 GeV, R56 = 4071.474 mm
# s = 346.36 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 346.36 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.17 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.55 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.55 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.65 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.78 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.78 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.90 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 347.99 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 348.12 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 348.12 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 348.24 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 348.35 m, E = 7.000 GeV, R56 = 4387.844 mm
# s = 350.65 m, E = 7.000 GeV, R56 = 4663.495 mm
# s = 350.65 m, E = 7.000 GeV, R56 = 4663.495 mm
# s = 350.95 m, E = 7.000 GeV, R56 = 4663.495 mm
# s = 353.25 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 353.25 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 353.64 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 353.84 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.03 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.55 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.55 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.66 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.79 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.79 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 354.91 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 355.29 m, E = 7.000 GeV, R56 = 4817.923 mm
# s = 357.58 m, E = 7.000 GeV, R56 = 4848.384 mm
# s = 357.58 m, E = 7.000 GeV, R56 = 4848.384 mm
# s = 357.89 m, E = 7.000 GeV, R56 = 4848.384 mm
# s = 360.18 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 360.18 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 360.18 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 360.96 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.49 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.49 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.49 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.60 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.70 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.70 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 361.80 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 362.05 m, E = 7.000 GeV, R56 = 4851.758 mm
# s = 363.96 m, E = 7.000 GeV, R56 = 4853.532 mm
# s = 363.96 m, E = 7.000 GeV, R56 = 4853.532 mm
# s = 364.14 m, E = 7.000 GeV, R56 = 4853.532 mm
# s = 364.14 m, E = 7.000 GeV, R56 = 4853.532 mm
# s = 364.31 m, E = 7.000 GeV, R56 = 4853.532 mm
# s = 366.22 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 366.22 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 367.80 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 368.30 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 368.40 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 368.60 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 368.79 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.31 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.31 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.42 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.55 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.55 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 369.67 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.37 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.50 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.50 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.62 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.75 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.75 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.87 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 375.97 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 376.17 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 376.36 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 376.89 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 376.89 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 376.99 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 377.12 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 377.12 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 377.24 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 382.95 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 383.45 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 383.55 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 383.75 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 383.94 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 383.94 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.46 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.46 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.57 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.69 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.69 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 384.82 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.52 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.65 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.65 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.77 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.90 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 390.90 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 391.02 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 391.12 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 391.32 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 391.51 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.04 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.04 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.14 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.27 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.27 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 392.39 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 398.10 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 398.60 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 398.70 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 398.90 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.08 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.61 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.61 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.72 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.84 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.84 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 399.97 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 405.67 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 406.17 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 406.27 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 406.47 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 406.66 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.18 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.18 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.29 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.39 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.39 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.49 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 407.77 m, E = 7.000 GeV, R56 = 4867.912 mm
# s = 409.67 m, E = 7.000 GeV, R56 = 4882.511 mm
# s = 409.67 m, E = 7.000 GeV, R56 = 4882.511 mm
# s = 409.85 m, E = 7.000 GeV, R56 = 4882.511 mm
# s = 409.85 m, E = 7.000 GeV, R56 = 4882.511 mm
# s = 410.02 m, E = 7.000 GeV, R56 = 4882.511 mm
# s = 411.93 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 411.93 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 412.78 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 415.66 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 415.78 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 415.78 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 415.91 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.03 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.03 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.16 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.26 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.46 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 416.64 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.17 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.17 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.28 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.40 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.40 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 417.53 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.39 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.51 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.51 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.64 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.76 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.76 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.89 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 424.98 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.35 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.35 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.46 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.58 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.58 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 425.71 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 426.06 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 426.06 m, E = 7.000 GeV, R56 = 4884.633 mm
# s = 427.87 m, E = 7.000 GeV, R56 = 4886.259 mm
# s = 427.87 m, E = 7.000 GeV, R56 = 4886.259 mm
# s = 428.26 m, E = 7.000 GeV, R56 = 4886.259 mm
# s = 430.07 m, E = 7.000 GeV, R56 = 4899.175 mm
# s = 430.07 m, E = 7.000 GeV, R56 = 4899.175 mm
# s = 430.74 m, E = 7.000 GeV, R56 = 4899.175 mm
# s = 432.55 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 432.55 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 432.93 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 433.13 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 433.32 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 433.85 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 433.85 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 433.95 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 434.08 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 434.08 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 434.20 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 434.54 m, E = 7.000 GeV, R56 = 4937.632 mm
# s = 436.35 m, E = 7.000 GeV, R56 = 5053.923 mm
# s = 436.35 m, E = 7.000 GeV, R56 = 5053.923 mm
# s = 436.74 m, E = 7.000 GeV, R56 = 5053.923 mm
# s = 438.55 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 438.55 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 438.87 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 438.97 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.02 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.14 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.27 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.35 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.73 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.73 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.84 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.96 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 439.96 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 440.09 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 440.44 m, E = 7.000 GeV, R56 = 5238.221 mm
# s = 442.25 m, E = 7.000 GeV, R56 = 5447.823 mm
# s = 442.25 m, E = 7.000 GeV, R56 = 5447.823 mm
# s = 442.63 m, E = 7.000 GeV, R56 = 5447.823 mm
# s = 444.45 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 444.45 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.10 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.22 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.22 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.35 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.47 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.47 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.60 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.85 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 445.94 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 446.04 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 446.24 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 446.42 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 446.95 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 446.95 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.06 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.18 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.18 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.31 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.41 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.56 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.56 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.71 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 447.81 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 448.34 m, E = 7.000 GeV, R56 = 5615.916 mm
# s = 450.15 m, E = 7.000 GeV, R56 = 5746.290 mm
# s = 450.15 m, E = 7.000 GeV, R56 = 5746.290 mm
# s = 450.53 m, E = 7.000 GeV, R56 = 5746.290 mm
# s = 452.35 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.35 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.67 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.77 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.82 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.91 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 452.99 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.37 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.37 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.48 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.60 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.60 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 453.73 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 454.17 m, E = 7.000 GeV, R56 = 5892.678 mm
# s = 455.99 m, E = 7.000 GeV, R56 = 6010.536 mm
# s = 455.99 m, E = 7.000 GeV, R56 = 6010.536 mm
# s = 456.37 m, E = 7.000 GeV, R56 = 6010.536 mm
# s = 458.19 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 458.19 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 458.49 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 458.59 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 458.79 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 458.98 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.50 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.50 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.61 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.73 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.73 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.86 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.74 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.74 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 459.96 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 460.21 m, E = 7.000 GeV, R56 = 6082.200 mm
# s = 461.21 m, E = 7.000 GeV, R56 = 6094.605 mm
# s = 461.21 m, E = 7.000 GeV, R56 = 6094.605 mm
# s = 461.63 m, E = 7.000 GeV, R56 = 6094.605 mm
# s = 462.63 m, E = 7.000 GeV, R56 = 6101.035 mm
# s = 462.63 m, E = 7.000 GeV, R56 = 6101.035 mm
# s = 463.05 m, E = 7.000 GeV, R56 = 6101.035 mm
# s = 464.05 m, E = 7.000 GeV, R56 = 6103.335 mm
# s = 464.05 m, E = 7.000 GeV, R56 = 6103.335 mm
# s = 464.05 m, E = 7.000 GeV, R56 = 6103.335 mm
# s = 464.47 m, E = 7.000 GeV, R56 = 6103.335 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.47 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.78 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.78 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 465.78 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 466.60 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 466.60 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 466.60 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 466.60 m, E = 7.000 GeV, R56 = 6103.725 mm
# s = 466.60 m, E = 7.000 GeV, R56 = 6103.725 mm

# %%
# # Your element IDs
# start_id = "PA1RFGUN"
# end_id   = "L491"

# # Find their indices in the lattice
# start_index = next(i for i, el in enumerate(lattice_list) if el.id == start_id)
# end_index   = next(i for i, el in enumerate(lattice_list) if el.id == end_id)

# # Create the sub-lattice
# partial_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

# # Get s-positions of those indices
# s_start = sum(el.l for el in lattice_list[:start_index])
# s_end   = sum(el.l for el in lattice_list[:end_index + 1])
# s_mid   = 0.5 * (s_start + s_end)

# # Interpolate energy at midpoint
# E_here = get_energy_at_s(s_mid, tws)

# # Calculate R56
# R = lattice_transfer_map(partial_lat, energy=E_here)
# r56 = R[4, 5]

# # Print result
# print(f"R56 from '{start_id}' to '{end_id}' (s = {s_start:.2f} to {s_end:.2f} m, E ≈ {E_here:.3f} GeV): R56 = {r56*1000:.3f} mm")

# %%
# def compute_r56_with_energy_evolution(lat_list, tws, id_start, id_end):
#     # Find element indices
#     i_start = next(i for i, el in enumerate(lat_list) if el.id == id_start)
#     i_end   = next(i for i, el in enumerate(lat_list) if el.id == id_end)

#     # Build the sub-lattice
#     partial_lat = MagneticLattice(lat_list[i_start:i_end + 1])

#     # Use starting energy from Twiss at i_start
#     s_start = sum(e.l for e in lat_list[:i_start])
#     E_start = get_energy_at_s(s_start, tws)

#     # Compute transfer maps at every step (tracks energy changes!)
#     Bs, Rs, Ts, Ss = partial_lat.transfer_maps(energy=E_start, output_at_each_step=True)

#     # Get the last transfer matrix — full map from PJARCM1 to PSECTC
#     R_final = Rs[-1]
#     r56 = R_final[4, 5]

#     s_end = s_start + sum(e.l for e in lat_list[i_start:i_end + 1])
#     print(f"R56 from '{id_start}' to '{id_end}' (s = {s_start:.2f} → {s_end:.2f} m): R56 = {r56*1000:.3f} mm")

# %%
# compute_r56_with_energy_evolution(lattice_list, tws, "PA1RFGUN", "L491")

# %%
final_twiss = tws_track[-1]

print("\n===== Final Beam Parameters =====")
print(f"Position s (m):       {final_twiss.s:.4f}")
print(f"Energy E (GeV):       {final_twiss.E:.6f}")
print(f"Beta X (βx) (m):      {final_twiss.beta_x:.6f}")
print(f"Beta Y (βy) (m):      {final_twiss.beta_y:.6f}")
print(f"Alpha X (αx):         {final_twiss.alpha_x:.6f}")
print(f"Alpha Y (αy):         {final_twiss.alpha_y:.6f}")
print(f"Norm. Emit X (m.rad): {final_twiss.emit_xn:.6e}")
print(f"Norm. Emit Y (m.rad): {final_twiss.emit_yn:.6e}")
print(f"Geom. Emit X (m.rad): {final_twiss.emit_x:.6e}")
print(f"Geom. Emit Y (m.rad): {final_twiss.emit_y:.6e}")
# Out:
# ===== Final Beam Parameters =====
# Position s (m):       466.6043
# Energy E (GeV):       7.000000
# Beta X (βx) (m):      20.008056
# Beta Y (βy) (m):      36.736492
# Alpha X (αx):         1.541092
# Alpha Y (αy):         -3.543821
# Norm. Emit X (m.rad): 1.335177e-06
# Norm. Emit Y (m.rad): 1.518324e-06
# Geom. Emit X (m.rad): 9.746772e-11
# Geom. Emit Y (m.rad): 1.108374e-10

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract position and beta functions
s = np.array([tw.s for tw in tws_track])
beta_x = np.array([tw.beta_x for tw in tws_track])
beta_y = np.array([tw.beta_y for tw in tws_track])

# Use initial geometric emittances
emit_x = tw0.emit_x
emit_y = tw0.emit_y

# Compute beam sizes σx and σy in meters
sigma_x = np.sqrt(beta_x * emit_x)
sigma_y = np.sqrt(beta_y * emit_y)

# Plot beam sizes in millimeters
plt.figure(figsize=(10, 6))
plt.plot(s, sigma_x * 1e3, label=r'$\sigma_x$ [mm]', linewidth=2)
plt.plot(s, sigma_y * 1e3, label=r'$\sigma_y$ [mm]', linewidth=2)

plt.xlabel('s [m]', fontsize=14)
plt.ylabel('Beam Size σ [mm]', fontsize=14)
plt.title('Transverse Beam Sizes Along the Lattice', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
show_e_beam(p_array)

# %%
show_e_beam(p_array_t)
