# %%
from ocelot import *
from ocelot.cpbd.elements import *
from ocelot.gui.accelerator import *
from ocelot.cpbd.track import track_debug
import matplotlib.pyplot as plt


from PSECTA import *


lat = MagneticLattice(lattice_list)



##### PA1RFGUN #####
AX =-21.12   
BX =24.36 
AY =-21.16     
BY =24.42      
EMITX =1.2023504614117648e-06
EMITY =1.2023504614117648e-06 
##### PA1RFGUN #####

energy = 0.0091 # GeV  #why?
tw0 = Twiss()
tw0.alpha_x = AX
tw0.beta_x = BX

tw0.alpha_y = AY
tw0.beta_y = BY
tw0.E = energy
tw0.emit_xn = EMITX 
tw0.emit_yn = EMITY
tw0.emit_x = EMITX   / energy * 0.511e-3
tw0.emit_y = EMITY / energy * 0.511e-3

tws = twiss(lat,tw0)

plot_opt_func(lat, tws,legend=False, grid=False, top_plot=['Dx','Dy'])

# %%
start_index = next(i for i, el in enumerate(lattice_list) if el.id == "PA1RFGUN")
end_index = next(i for i, el in enumerate(lattice_list) if el.id == "L491")

sub_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

R = lattice_transfer_map(sub_lat, energy=1.5)
print("R56 = ", R[4,5]*1000, "mm")
# Out:
# R56 =  -23.38775880448409 mm

# %%
def gauss_from_twiss_vec(emit, beta, alpha, size=1):
    phi = 2 * np.pi * np.random.rand(size)
    u = np.random.rand(size)
    a = np.sqrt(-2 * np.log(1 - u) * emit)
    x = a * np.sqrt(beta) * np.cos(phi)
    xp = -a / np.sqrt(beta) * (np.sin(phi) + alpha * np.cos(phi))
    return x, xp

nparticles = 100000
p_array = ParticleArray(n=nparticles)

sigma_tau = 6.7e-3  # m
sigma_p = 5.e-4     # relative momentum spread

p_array.E = energy  # GeV

# Longitudinal
p_array.rparticles[4] = np.random.randn(nparticles) * sigma_tau
p_array.rparticles[5] = np.random.randn(nparticles) * sigma_p

# Transverse: vectorized sampling from Twiss parameters
x, xp = gauss_from_twiss_vec(tw0.emit_x, tw0.beta_x, tw0.alpha_x, size=nparticles)
y, yp = gauss_from_twiss_vec(tw0.emit_y, tw0.beta_y, tw0.alpha_y, size=nparticles)

p_array.rparticles[0] = x
p_array.rparticles[1] = xp
p_array.rparticles[2] = y
p_array.rparticles[3] = yp

# Charge distribution
charge = 4.0e-9  # nC
p_array.q_array = np.ones(nparticles) * (charge / nparticles)

# %%
plt.hist(p_array.rparticles[0], bins=100, alpha=0.7, label='x')
plt.hist(p_array.rparticles[1], bins=100, alpha=0.7, label="x'")
plt.legend()
plt.show()

plt.hist(p_array.rparticles[2], bins=100, alpha=0.7, label='y')
plt.hist(p_array.rparticles[3], bins=100, alpha=0.7, label="y'")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
x = p_array.rparticles[0]
xp = p_array.rparticles[1]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_x, sigma_xp = twiss_sigmas(tw0.emit_x, tw0.beta_x, tw0.alpha_x)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='x (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='x (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="x′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_xp), 'r--', label="x′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of x and x′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
y = p_array.rparticles[2]
yp = p_array.rparticles[3]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_y, sigma_yp = twiss_sigmas(tw0.emit_y, tw0.beta_y, tw0.alpha_y)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='y (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='y (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="y′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_yp), 'r--', label="y′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of y and y′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def check_beam_stats(p_array, twiss, axis_label="x"):
    idx = 0 if axis_label == "x" else 2
    idxp = 1 if axis_label == "x" else 3

    sigma = np.std(p_array.rparticles[idx])
    sigmap = np.std(p_array.rparticles[idxp])

    beta = getattr(twiss, f"beta_{axis_label}")
    alpha = getattr(twiss, f"alpha_{axis_label}")
    emit = getattr(twiss, f"emit_{axis_label}")

    sigma_theo = np.sqrt(beta * emit)
    gamma = (1 + alpha**2) / beta
    sigmap_theo = np.sqrt(gamma * emit)

    print(f"σ_{axis_label} (simulated):     {sigma}")
    print(f"σ_{axis_label} (theoretical):   {sigma_theo}")
    print(f"σ_{axis_label}' (simulated):    {sigmap}")
    print(f"σ_{axis_label}' (theoretical):  {sigmap_theo}")

# %%
check_beam_stats(p_array, tw0, axis_label="x")
# Out:
# σ_x (simulated):     0.0012792814217100997
# σ_x (theoretical):   0.001282460309333141
# σ_x' (simulated):    0.0011102318625416975
# σ_x' (theoretical):  0.0011131324306998926

# %%
check_beam_stats(p_array, tw0, axis_label="y")
# Out:
# σ_y (simulated):     0.0012812941313414244
# σ_y (theoretical):   0.001284038722618926
# σ_y' (simulated):    0.0011116810140078832
# σ_y' (theoretical):  0.0011138650134345758

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- X plane ---
x = p_array.rparticles[0]
xp = p_array.rparticles[1]
emit_x = tw0.emit_x
beta_x = tw0.beta_x
alpha_x = tw0.alpha_x

theta = np.linspace(0, 2*np.pi, 400)
x_ellipse = np.sqrt(emit_x * beta_x) * np.cos(theta)
xp_ellipse = (-alpha_x * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_x / beta_x)

# --- Y plane ---
y = p_array.rparticles[2]
yp = p_array.rparticles[3]
emit_y = tw0.emit_y
beta_y = tw0.beta_y
alpha_y = tw0.alpha_y

y_ellipse = np.sqrt(emit_y * beta_y) * np.cos(theta)
yp_ellipse = (-alpha_y * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_y / beta_y)

# --- Plot ---
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# x-x'
axes[0].scatter(x, xp, s=1, alpha=0.3, label='Particles')
axes[0].plot(x_ellipse, xp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[0].set_xlabel('x [m]')
axes[0].set_ylabel("x′ [rad]")
axes[0].set_title('Phase space: x vs x′')
axes[0].grid(True)
axes[0].axis('equal')
axes[0].legend()

# y-y'
axes[1].scatter(y, yp, s=1, alpha=0.3, color='orange', label='Particles')
axes[1].plot(y_ellipse, yp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[1].set_xlabel('y [m]')
axes[1].set_ylabel("y′ [rad]")
axes[1].set_title('Phase space: y vs y′')
axes[1].grid(True)
axes[1].axis('equal')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy

def plot_emittances_vs_s(p_array, nparts_in_slice=5000, smooth_param=0.05,
                         tau_units="m", inverse_tau=False, grid=True,
                         title="Normalized Emittances vs s", figsize=(8, 4),
                         filename=None):
    """
    Plot normalized emittances vs longitudinal position s (head-tail slicing).

    :param p_array: ParticleArray object
    :param nparts_in_slice: number of particles per slice
    :param smooth_param: smoothing parameter used in slice analysis
    :param tau_units: 'm', 'mm', or 'um'
    :param inverse_tau: flip the tau axis
    :param grid: show grid
    :param title: plot title
    :param figsize: matplotlib figsize
    :param filename: optional path to save the plot
    """
    # Set scale for s-axis
    tau_factors = {"m": 1, "mm": 1e3, "um": 1e6}
    tau_factor = tau_factors.get(tau_units, 1e3)
    tau_label = f"$s\,[\\mathrm{{{tau_units}}}]$"

    # Deepcopy to preserve original
    p_array_copy = deepcopy(p_array)
    if inverse_tau:
        p_array_copy.tau()[:] *= -1

    # Perform slice analysis (assumes this function exists in your codebase)
    slice_params = global_slice_analysis(p_array_copy, nparts_in_slice, smooth_param)

    # Extract and convert to proper units
    s = slice_params.s * tau_factor
    emit_x = slice_params.exn * 1e6  # [mm·mrad]
    emit_y = slice_params.eyn * 1e6

    # Plot
    plt.figure(figsize=figsize)
    plt.plot(s, emit_x, label=r"$\varepsilon_x$", color='red')
    plt.plot(s, emit_y, label=r"$\varepsilon_y$", color='blue')
    plt.xlabel(tau_label)
    plt.ylabel(r"Normalized Emittance [$\mathrm{mm\cdot{}mrad}$]")
    plt.title(title)
    plt.legend()
    if grid:
        plt.grid(True)
    if filename:
        plt.savefig(filename)
    plt.tight_layout()
    plt.show()

# %%
show_e_beam(p_array)

# %%
plot_emittances_vs_s(p_array)

# %%
import time
navi = Navigator(lat)
#navi.unit_step = 0.1 # m, only with CSR

#csr = CSR(n_bin=500, m_bin=5, sigma_min=.2e-6)

#navi.add_physics_proc(csr, csrm1_start, csrm1_end)

p_array_t = deepcopy(p_array)

start = time.time()
tws_track, p_array_t = track(lat, p_array_t, navi)
print("\n time exec:", time.time() - start, "sec")
# Out:
# z = 45.013947599999995 / 45.013947600000016. Applied:
#  time exec: 4.728853940963745 sec

# %%
show_e_beam(p_array)

# %%
show_e_beam(p_array_t)

# %%
plot_emittances_vs_s(p_array_t)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_energy_vs_position(tws_track):
    """
    Plot energy E as a function of position s from a list of Twiss-like objects.

    Parameters:
    tws_track (list): List of objects with attributes 's' (position) and 'E' (energy).
    """
    s = np.array([tw.s for tw in tws_track])
    E = np.array([tw.E for tw in tws_track])

    plt.figure(figsize=(10, 6))
    plt.plot(s, E, linewidth=2, marker='o', markersize=4)

    plt.title("Energy vs Position", fontsize=16)
    plt.xlabel("s (m)", fontsize=14)
    plt.ylabel("E (GeV)", fontsize=14)
    plt.grid(True, which='both', linestyle='--', alpha=0.5)
    plt.tick_params(axis='both', labelsize=12)
    plt.tight_layout()
    plt.show()

# %%
plot_energy_vs_position(tws_track)

# %%
# --- After tracking: get final x, x', y, y' ---
x_t = p_array_t.rparticles[0]
xp_t = p_array_t.rparticles[1]
y_t = p_array_t.rparticles[2]
yp_t = p_array_t.rparticles[3]

# --- Plot initial vs final side-by-side ---
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# x-x′ before
axes[0][0].scatter(p_array.rparticles[0], p_array.rparticles[1], s=1, alpha=0.3)
axes[0][0].set_title("x vs x′ (before)")
axes[0][0].set_xlabel("x [m]")
axes[0][0].set_ylabel("x′ [rad]")
axes[0][0].grid(True)
axes[0][0].axis('equal')

# x-x′ after
axes[0][1].scatter(x_t, xp_t, s=1, alpha=0.3)
axes[0][1].set_title("x vs x′ (after)")
axes[0][1].set_xlabel("x [m]")
axes[0][1].set_ylabel("x′ [rad]")
axes[0][1].grid(True)
axes[0][1].axis('equal')

# y-y′ before
axes[1][0].scatter(p_array.rparticles[2], p_array.rparticles[3], s=1, alpha=0.3, color='orange')
axes[1][0].set_title("y vs y′ (before)")
axes[1][0].set_xlabel("y [m]")
axes[1][0].set_ylabel("y′ [rad]")
axes[1][0].grid(True)
axes[1][0].axis('equal')

# y-y′ after
axes[1][1].scatter(y_t, yp_t, s=1, alpha=0.3, color='orange')
axes[1][1].set_title("y vs y′ (after)")
axes[1][1].set_xlabel("y [m]")
axes[1][1].set_ylabel("y′ [rad]")
axes[1][1].grid(True)
axes[1][1].axis('equal')

plt.tight_layout()
plt.show()

# %%
import numpy as np

def compute_emittance(x, xp):
    x_mean = np.mean(x)
    xp_mean = np.mean(xp)

    x_cent = x - x_mean
    xp_cent = xp - xp_mean

    xx = np.mean(x_cent ** 2)
    xpxp = np.mean(xp_cent ** 2)
    xxp = np.mean(x_cent * xp_cent)

    emit = np.sqrt(xx * xpxp - xxp**2)
    return emit

# Final tracked coordinates
x, xp = p_array_t.rparticles[0], p_array_t.rparticles[1]
y, yp = p_array_t.rparticles[2], p_array_t.rparticles[3]

emit_x = compute_emittance(x, xp)
emit_y = compute_emittance(y, yp)

print(f"εₓ (RMS, final) = {emit_x:.5e} m·rad")
print(f"εᵧ (RMS, final) = {emit_y:.5e} m·rad")

emit_x0 = compute_emittance(p_array.rparticles[0], p_array.rparticles[1])
emit_y0 = compute_emittance(p_array.rparticles[2], p_array.rparticles[3])
print("Initial εₓ:", emit_x0)
print("Initial εᵧ:", emit_y0)
# Out:
# εₓ (RMS, final) = 1.29675e-09 m·rad
# εᵧ (RMS, final) = 1.30505e-09 m·rad
# Initial εₓ: 6.725571826282203e-08
# Initial εᵧ: 6.768607316727123e-08

# %%
for tw in tws_track:
    print(f"s = {tw.s:.3f} m  |  beta_x = {tw.beta_x:.3f}  | beta_y = {tw.beta_y:.3f}  |  alpha_x = {tw.alpha_x:.3f} |  alpha_y = {tw.alpha_y:.3f}" )
# Out:
# s = 0.000 m  |  beta_x = 24.333  | beta_y = 24.255  |  alpha_x = -21.094 |  alpha_y = -21.020
# s = 0.000 m  |  beta_x = 24.333  | beta_y = 24.255  |  alpha_x = -21.094 |  alpha_y = -21.020
# s = 0.085 m  |  beta_x = 28.052  | beta_y = 27.960  |  alpha_x = -22.652 |  alpha_y = -22.572
# s = 0.130 m  |  beta_x = 30.128  | beta_y = 30.029  |  alpha_x = -23.477 |  alpha_y = -23.394
# s = 0.156 m  |  beta_x = 31.370  | beta_y = 31.267  |  alpha_x = -23.957 |  alpha_y = -23.872
# s = 0.230 m  |  beta_x = 44.243  | beta_y = 27.056  |  alpha_x = -165.412 |  alpha_y = 76.201
# s = 0.266 m  |  beta_x = 57.105  | beta_y = 21.793  |  alpha_x = -187.923 |  alpha_y = 68.388
# s = 0.340 m  |  beta_x = 70.002  | beta_y = 17.237  |  alpha_x = 27.865 |  alpha_y = -1.332
# s = 0.466 m  |  beta_x = 63.146  | beta_y = 17.576  |  alpha_x = 26.464 |  alpha_y = -1.353
# s = 0.593 m  |  beta_x = 56.578  | beta_y = 17.924  |  alpha_x = 25.048 |  alpha_y = -1.373
# s = 0.636 m  |  beta_x = 54.469  | beta_y = 18.041  |  alpha_x = 24.576 |  alpha_y = -1.380
# s = 0.693 m  |  beta_x = 51.680  | beta_y = 18.200  |  alpha_x = 23.937 |  alpha_y = -1.389
# s = 0.751 m  |  beta_x = 48.964  | beta_y = 18.360  |  alpha_x = 23.298 |  alpha_y = -1.399
# s = 1.393 m  |  beta_x = 23.626  | beta_y = 20.223  |  alpha_x = 16.168 |  alpha_y = -1.502
# s = 1.434 m  |  beta_x = 22.329  | beta_y = 20.345  |  alpha_x = 15.716 |  alpha_y = -1.509
# s = 1.507 m  |  beta_x = 20.994  | beta_y = 19.689  |  alpha_x = 2.679 |  alpha_y = 10.288
# s = 1.544 m  |  beta_x = 20.799  | beta_y = 18.948  |  alpha_x = 2.665 |  alpha_y = 10.090
# s = 1.617 m  |  beta_x = 20.082  | beta_y = 17.781  |  alpha_x = 7.031 |  alpha_y = 5.843
# s = 1.658 m  |  beta_x = 19.514  | beta_y = 17.309  |  alpha_x = 6.929 |  alpha_y = 5.763
# s = 1.700 m  |  beta_x = 18.929  | beta_y = 16.822  |  alpha_x = 6.822 |  alpha_y = 5.679
# s = 1.743 m  |  beta_x = 18.354  | beta_y = 16.343  |  alpha_x = 6.715 |  alpha_y = 5.595
# s = 1.834 m  |  beta_x = 17.146  | beta_y = 15.336  |  alpha_x = 6.485 |  alpha_y = 5.414
# s = 2.453 m  |  beta_x = 8.824  | beta_y = 8.238  |  alpha_x = 6.254 |  alpha_y = 5.435
# s = 3.724 m  |  beta_x = 0.186  | beta_y = 0.263  |  alpha_x = 0.110 |  alpha_y = 0.439
# s = 3.815 m  |  beta_x = 0.211  | beta_y = 0.221  |  alpha_x = -0.389 |  alpha_y = 0.024
# s = 3.860 m  |  beta_x = 0.257  | beta_y = 0.228  |  alpha_x = -0.634 |  alpha_y = -0.180
# s = 3.889 m  |  beta_x = 0.297  | beta_y = 0.242  |  alpha_x = -0.788 |  alpha_y = -0.307
# s = 3.962 m  |  beta_x = 0.443  | beta_y = 0.311  |  alpha_x = -1.193 |  alpha_y = -0.638
# s = 4.043 m  |  beta_x = 0.672  | beta_y = 0.444  |  alpha_x = -1.635 |  alpha_y = -1.004
# s = 4.158 m  |  beta_x = 1.046  | beta_y = 0.783  |  alpha_x = -1.549 |  alpha_y = -2.028
# s = 4.239 m  |  beta_x = 1.318  | beta_y = 1.154  |  alpha_x = -1.812 |  alpha_y = -2.556
# s = 4.312 m  |  beta_x = 1.603  | beta_y = 1.565  |  alpha_x = -2.052 |  alpha_y = -3.036
# s = 4.400 m  |  beta_x = 1.990  | beta_y = 2.152  |  alpha_x = -2.338 |  alpha_y = -3.611
# s = 4.450 m  |  beta_x = 2.232  | beta_y = 2.529  |  alpha_x = -2.501 |  alpha_y = -3.938
# s = 4.500 m  |  beta_x = 2.490  | beta_y = 2.939  |  alpha_x = -2.663 |  alpha_y = -4.264
# s = 4.642 m  |  beta_x = 3.308  | beta_y = 4.275  |  alpha_x = -3.123 |  alpha_y = -5.187
# s = 4.789 m  |  beta_x = 0.607  | beta_y = 5.948  |  alpha_x = -8.181 |  alpha_y = -5.098
# s = 5.142 m  |  beta_x = 20.193  | beta_y = 10.112  |  alpha_x = -47.282 |  alpha_y = -6.699
# s = 5.289 m  |  beta_x = 60.423  | beta_y = 11.607  |  alpha_x = -0.025 |  alpha_y = -5.281
# s = 5.415 m  |  beta_x = 60.430  | beta_y = 12.981  |  alpha_x = -0.027 |  alpha_y = -5.595
# s = 5.542 m  |  beta_x = 60.437  | beta_y = 14.435  |  alpha_x = -0.029 |  alpha_y = -5.910
# s = 5.689 m  |  beta_x = 8.877  | beta_y = 16.240  |  alpha_x = 20.760 |  alpha_y = -3.409
# s = 6.042 m  |  beta_x = 0.279  | beta_y = 18.743  |  alpha_x = 3.552 |  alpha_y = -3.683
# s = 6.189 m  |  beta_x = 21.140  | beta_y = 18.843  |  alpha_x = -8.229 |  alpha_y = -0.383
# s = 6.330 m  |  beta_x = 23.532  | beta_y = 18.953  |  alpha_x = -8.688 |  alpha_y = -0.392
# s = 6.415 m  |  beta_x = 25.033  | beta_y = 19.020  |  alpha_x = -8.965 |  alpha_y = -0.397
# s = 7.315 m  |  beta_x = 43.802  | beta_y = 19.784  |  alpha_x = -11.890 |  alpha_y = -0.452
# s = 7.470 m  |  beta_x = 47.562  | beta_y = 19.925  |  alpha_x = -12.393 |  alpha_y = -0.461
# s = 7.643 m  |  beta_x = 51.948  | beta_y = 20.087  |  alpha_x = -12.956 |  alpha_y = -0.472
# s = 7.755 m  |  beta_x = 54.894  | beta_y = 20.193  |  alpha_x = -13.320 |  alpha_y = -0.479
# s = 7.798 m  |  beta_x = 56.046  | beta_y = 20.235  |  alpha_x = -13.460 |  alpha_y = -0.481
# s = 7.875 m  |  beta_x = 58.138  | beta_y = 20.309  |  alpha_x = -13.710 |  alpha_y = -0.486
# s = 7.959 m  |  beta_x = 60.459  | beta_y = 20.391  |  alpha_x = -13.983 |  alpha_y = -0.491
# s = 8.082 m  |  beta_x = 72.869  | beta_y = 17.848  |  alpha_x = -92.007 |  alpha_y = 20.329
# s = 8.125 m  |  beta_x = 81.157  | beta_y = 16.110  |  alpha_x = -97.099 |  alpha_y = 19.311
# s = 8.199 m  |  beta_x = 96.127  | beta_y = 13.385  |  alpha_x = -105.677 |  alpha_y = 17.598
# s = 8.322 m  |  beta_x = 105.335  | beta_y = 11.352  |  alpha_x = 34.732 |  alpha_y = -0.047
# s = 8.400 m  |  beta_x = 99.931  | beta_y = 11.360  |  alpha_x = 33.828 |  alpha_y = -0.054
# s = 8.500 m  |  beta_x = 93.280  | beta_y = 11.372  |  alpha_x = 32.682 |  alpha_y = -0.063
# s = 8.570 m  |  beta_x = 88.761  | beta_y = 11.381  |  alpha_x = 31.880 |  alpha_y = -0.069
# s = 8.640 m  |  beta_x = 84.353  | beta_y = 11.391  |  alpha_x = 31.078 |  alpha_y = -0.076
# s = 8.765 m  |  beta_x = 76.763  | beta_y = 11.412  |  alpha_x = 29.645 |  alpha_y = -0.087
# s = 8.805 m  |  beta_x = 74.410  | beta_y = 11.419  |  alpha_x = 29.186 |  alpha_y = -0.090
# s = 8.885 m  |  beta_x = 69.813  | beta_y = 11.434  |  alpha_x = 28.270 |  alpha_y = -0.097
# s = 8.965 m  |  beta_x = 65.364  | beta_y = 11.450  |  alpha_x = 27.353 |  alpha_y = -0.104
# s = 9.005 m  |  beta_x = 63.194  | beta_y = 11.458  |  alpha_x = 26.894 |  alpha_y = -0.108
# s = 9.072 m  |  beta_x = 59.668  | beta_y = 11.473  |  alpha_x = 26.132 |  alpha_y = -0.114
# s = 9.114 m  |  beta_x = 57.467  | beta_y = 11.483  |  alpha_x = 25.645 |  alpha_y = -0.117
# s = 9.157 m  |  beta_x = 55.308  | beta_y = 11.493  |  alpha_x = 25.158 |  alpha_y = -0.121
# s = 9.199 m  |  beta_x = 53.190  | beta_y = 11.504  |  alpha_x = 24.671 |  alpha_y = -0.125
# s = 9.242 m  |  beta_x = 51.114  | beta_y = 11.514  |  alpha_x = 24.184 |  alpha_y = -0.129
# s = 9.362 m  |  beta_x = 45.475  | beta_y = 11.547  |  alpha_x = 22.808 |  alpha_y = -0.139
# s = 9.514 m  |  beta_x = 38.806  | beta_y = 11.591  |  alpha_x = 21.066 |  alpha_y = -0.153
# s = 9.599 m  |  beta_x = 35.308  | beta_y = 11.618  |  alpha_x = 20.092 |  alpha_y = -0.160
# s = 9.655 m  |  beta_x = 33.073  | beta_y = 11.636  |  alpha_x = 19.444 |  alpha_y = -0.165
# s = 9.690 m  |  beta_x = 31.727  | beta_y = 11.648  |  alpha_x = 19.043 |  alpha_y = -0.168
# s = 10.250 m  |  beta_x = 13.152  | beta_y = 11.337  |  alpha_x = 13.499 |  alpha_y = 0.624
# s = 11.580 m  |  beta_x = 2.240  | beta_y = 8.736  |  alpha_x = -5.669 |  alpha_y = 1.138
# s = 11.615 m  |  beta_x = 2.655  | beta_y = 8.656  |  alpha_x = -6.186 |  alpha_y = 1.129
# s = 11.671 m  |  beta_x = 3.401  | beta_y = 8.529  |  alpha_x = -7.022 |  alpha_y = 1.114
# s = 11.714 m  |  beta_x = 4.033  | beta_y = 8.434  |  alpha_x = -7.658 |  alpha_y = 1.103
# s = 11.791 m  |  beta_x = 5.300  | beta_y = 8.266  |  alpha_x = -8.797 |  alpha_y = 1.083
# s = 11.875 m  |  beta_x = 6.878  | beta_y = 8.086  |  alpha_x = -10.037 |  alpha_y = 1.061
# s = 11.998 m  |  beta_x = 11.363  | beta_y = 6.365  |  alpha_x = -29.005 |  alpha_y = 12.068
# s = 12.044 m  |  beta_x = 14.210  | beta_y = 5.296  |  alpha_x = -32.439 |  alpha_y = 11.001
# s = 12.115 m  |  beta_x = 19.214  | beta_y = 3.844  |  alpha_x = -37.727 |  alpha_y = 9.358
# s = 12.238 m  |  beta_x = 23.522  | beta_y = 2.580  |  alpha_x = 5.540 |  alpha_y = 1.829
# s = 12.322 m  |  beta_x = 22.597  | beta_y = 2.284  |  alpha_x = 5.426 |  alpha_y = 1.687
# s = 12.364 m  |  beta_x = 22.138  | beta_y = 2.143  |  alpha_x = 5.369 |  alpha_y = 1.616
# s = 12.407 m  |  beta_x = 21.684  | beta_y = 2.009  |  alpha_x = 5.312 |  alpha_y = 1.544
# s = 12.463 m  |  beta_x = 21.088  | beta_y = 1.840  |  alpha_x = 5.236 |  alpha_y = 1.449
# s = 12.498 m  |  beta_x = 20.724  | beta_y = 1.741  |  alpha_x = 5.188 |  alpha_y = 1.390
# s = 13.058 m  |  beta_x = 15.174  | beta_y = 0.704  |  alpha_x = 4.679 |  alpha_y = 0.455
# s = 14.388 m  |  beta_x = 5.121  | beta_y = 2.496  |  alpha_x = 2.775 |  alpha_y = -1.792
# s = 14.423 m  |  beta_x = 4.929  | beta_y = 2.623  |  alpha_x = 2.716 |  alpha_y = -1.851
# s = 14.479 m  |  beta_x = 4.627  | beta_y = 2.838  |  alpha_x = 2.620 |  alpha_y = -1.947
# s = 14.522 m  |  beta_x = 4.407  | beta_y = 3.007  |  alpha_x = 2.547 |  alpha_y = -2.018
# s = 14.579 m  |  beta_x = 4.123  | beta_y = 3.242  |  alpha_x = 2.450 |  alpha_y = -2.115
# s = 14.654 m  |  beta_x = 3.765  | beta_y = 3.569  |  alpha_x = 2.323 |  alpha_y = -2.241
# s = 14.741 m  |  beta_x = 3.373  | beta_y = 3.972  |  alpha_x = 2.175 |  alpha_y = -2.388
# s = 14.862 m  |  beta_x = 2.872  | beta_y = 4.574  |  alpha_x = 1.970 |  alpha_y = -2.592
# s = 14.949 m  |  beta_x = 2.542  | beta_y = 5.038  |  alpha_x = 1.822 |  alpha_y = -2.739
# s = 15.024 m  |  beta_x = 2.278  | beta_y = 5.458  |  alpha_x = 1.694 |  alpha_y = -2.865
# s = 15.124 m  |  beta_x = 1.957  | beta_y = 6.047  |  alpha_x = 1.525 |  alpha_y = -3.034
# s = 15.181 m  |  beta_x = 1.787  | beta_y = 6.401  |  alpha_x = 1.427 |  alpha_y = -3.131
# s = 15.251 m  |  beta_x = 1.596  | beta_y = 6.848  |  alpha_x = 1.308 |  alpha_y = -3.249
# s = 15.294 m  |  beta_x = 1.488  | beta_y = 7.127  |  alpha_x = 1.236 |  alpha_y = -3.321
# s = 15.350 m  |  beta_x = 1.354  | beta_y = 7.507  |  alpha_x = 1.140 |  alpha_y = -3.416
# s = 15.385 m  |  beta_x = 1.276  | beta_y = 7.749  |  alpha_x = 1.081 |  alpha_y = -3.475
# s = 15.945 m  |  beta_x = 0.596  | beta_y = 12.126  |  alpha_x = 0.132 |  alpha_y = -4.336
# s = 17.274 m  |  beta_x = 3.241  | beta_y = 26.191  |  alpha_x = -2.113 |  alpha_y = -6.201
# s = 17.309 m  |  beta_x = 3.391  | beta_y = 26.627  |  alpha_x = -2.171 |  alpha_y = -6.254
# s = 17.366 m  |  beta_x = 3.642  | beta_y = 27.339  |  alpha_x = -2.267 |  alpha_y = -6.339
# s = 17.408 m  |  beta_x = 3.837  | beta_y = 27.880  |  alpha_x = -2.338 |  alpha_y = -6.403
# s = 17.468 m  |  beta_x = 4.124  | beta_y = 28.654  |  alpha_x = -2.440 |  alpha_y = -6.493
# s = 17.543 m  |  beta_x = 4.768  | beta_y = 27.905  |  alpha_x = -6.321 |  alpha_y = 16.285
# s = 17.630 m  |  beta_x = 5.933  | beta_y = 25.143  |  alpha_x = -7.068 |  alpha_y = 15.455
# s = 17.751 m  |  beta_x = 6.602  | beta_y = 25.716  |  alpha_x = 1.863 |  alpha_y = -20.455
# s = 17.838 m  |  beta_x = 6.283  | beta_y = 29.398  |  alpha_x = 1.804 |  alpha_y = -21.873
# s = 17.913 m  |  beta_x = 6.392  | beta_y = 30.902  |  alpha_x = -3.283 |  alpha_y = 2.230
# s = 18.016 m  |  beta_x = 7.088  | beta_y = 30.444  |  alpha_x = -3.473 |  alpha_y = 2.210
# s = 18.059 m  |  beta_x = 7.386  | beta_y = 30.257  |  alpha_x = -3.551 |  alpha_y = 2.202
# s = 18.101 m  |  beta_x = 7.691  | beta_y = 30.070  |  alpha_x = -3.630 |  alpha_y = 2.194
# s = 18.158 m  |  beta_x = 8.107  | beta_y = 29.823  |  alpha_x = -3.734 |  alpha_y = 2.183
# s = 18.193 m  |  beta_x = 8.371  | beta_y = 29.670  |  alpha_x = -3.798 |  alpha_y = 2.176
# s = 18.753 m  |  beta_x = 13.176  | beta_y = 27.232  |  alpha_x = -4.780 |  alpha_y = 2.173
# s = 20.082 m  |  beta_x = 28.859  | beta_y = 21.588  |  alpha_x = -6.985 |  alpha_y = 2.049
# s = 20.117 m  |  beta_x = 29.350  | beta_y = 21.444  |  alpha_x = -7.046 |  alpha_y = 2.041
# s = 20.174 m  |  beta_x = 30.152  | beta_y = 21.215  |  alpha_x = -7.143 |  alpha_y = 2.027
# s = 20.216 m  |  beta_x = 30.762  | beta_y = 21.043  |  alpha_x = -7.217 |  alpha_y = 2.017
# s = 20.280 m  |  beta_x = 31.693  | beta_y = 20.786  |  alpha_x = -7.327 |  alpha_y = 2.002
# s = 20.401 m  |  beta_x = 37.793  | beta_y = 17.842  |  alpha_x = -45.182 |  alpha_y = 21.301
# s = 20.490 m  |  beta_x = 46.214  | beta_y = 14.271  |  alpha_x = -49.964 |  alpha_y = 19.045
# s = 20.712 m  |  beta_x = 46.932  | beta_y = 11.890  |  alpha_x = 47.225 |  alpha_y = -6.772
# s = 20.800 m  |  beta_x = 38.946  | beta_y = 13.120  |  alpha_x = 43.018 |  alpha_y = -7.121
# s = 20.921 m  |  beta_x = 33.465  | beta_y = 13.178  |  alpha_x = 4.152 |  alpha_y = 6.658
# s = 21.028 m  |  beta_x = 32.586  | beta_y = 11.797  |  alpha_x = 4.094 |  alpha_y = 6.291
# s = 21.072 m  |  beta_x = 32.224  | beta_y = 11.246  |  alpha_x = 4.070 |  alpha_y = 6.139
# s = 21.154 m  |  beta_x = 31.564  | beta_y = 10.268  |  alpha_x = 4.026 |  alpha_y = 5.858
# s = 21.211 m  |  beta_x = 31.103  | beta_y = 9.606  |  alpha_x = 3.994 |  alpha_y = 5.661
# s = 21.261 m  |  beta_x = 30.705  | beta_y = 9.048  |  alpha_x = 3.967 |  alpha_y = 5.489
# s = 21.331 m  |  beta_x = 30.152  | beta_y = 8.296  |  alpha_x = 3.929 |  alpha_y = 5.248
# s = 21.374 m  |  beta_x = 29.819  | beta_y = 7.857  |  alpha_x = 3.906 |  alpha_y = 5.102
# s = 21.459 m  |  beta_x = 29.159  | beta_y = 7.014  |  alpha_x = 3.859 |  alpha_y = 4.809
# s = 21.515 m  |  beta_x = 28.724  | beta_y = 6.482  |  alpha_x = 3.829 |  alpha_y = 4.615
# s = 21.550 m  |  beta_x = 28.457  | beta_y = 6.163  |  alpha_x = 3.810 |  alpha_y = 4.494
# s = 22.110 m  |  beta_x = 24.309  | beta_y = 2.202  |  alpha_x = 3.592 |  alpha_y = 2.575
# s = 23.440 m  |  beta_x = 15.595  | beta_y = 1.484  |  alpha_x = 2.936 |  alpha_y = -2.038
# s = 23.475 m  |  beta_x = 15.390  | beta_y = 1.631  |  alpha_x = 2.914 |  alpha_y = -2.159
# s = 23.531 m  |  beta_x = 15.063  | beta_y = 1.886  |  alpha_x = 2.879 |  alpha_y = -2.355
# s = 23.532 m  |  beta_x = 15.059  | beta_y = 1.890  |  alpha_x = 2.879 |  alpha_y = -2.358
# s = 23.589 m  |  beta_x = 14.736  | beta_y = 2.167  |  alpha_x = 2.844 |  alpha_y = -2.554
# s = 23.624 m  |  beta_x = 14.537  | beta_y = 2.350  |  alpha_x = 2.822 |  alpha_y = -2.675
# s = 24.183 m  |  beta_x = 11.554  | beta_y = 6.427  |  alpha_x = 2.504 |  alpha_y = -4.604
# s = 25.513 m  |  beta_x = 5.961  | beta_y = 24.674  |  alpha_x = 1.693 |  alpha_y = -9.094
# s = 25.548 m  |  beta_x = 5.843  | beta_y = 25.315  |  alpha_x = 1.670 |  alpha_y = -9.213
# s = 25.605 m  |  beta_x = 5.657  | beta_y = 26.367  |  alpha_x = 1.633 |  alpha_y = -9.405
# s = 25.647 m  |  beta_x = 5.519  | beta_y = 27.172  |  alpha_x = 1.606 |  alpha_y = -9.549
# s = 25.711 m  |  beta_x = 5.316  | beta_y = 28.408  |  alpha_x = 1.564 |  alpha_y = -9.766
# s = 25.832 m  |  beta_x = 5.631  | beta_y = 27.107  |  alpha_x = -4.276 |  alpha_y = 20.056
# s = 25.921 m  |  beta_x = 6.415  | beta_y = 23.673  |  alpha_x = -4.579 |  alpha_y = 18.739
# s = 26.143 m  |  beta_x = 5.510  | beta_y = 26.025  |  alpha_x = 8.013 |  alpha_y = -30.904
# s = 26.231 m  |  beta_x = 4.184  | beta_y = 31.783  |  alpha_x = 6.966 |  alpha_y = -34.155
# s = 26.352 m  |  beta_x = 3.094  | beta_y = 35.938  |  alpha_x = 2.424 |  alpha_y = 1.305
# s = 26.459 m  |  beta_x = 2.603  | beta_y = 35.661  |  alpha_x = 2.187 |  alpha_y = 1.297
# s = 26.516 m  |  beta_x = 2.359  | beta_y = 35.512  |  alpha_x = 2.059 |  alpha_y = 1.293
# s = 26.586 m  |  beta_x = 2.081  | beta_y = 35.331  |  alpha_x = 1.904 |  alpha_y = 1.288
# s = 26.629 m  |  beta_x = 1.923  | beta_y = 35.222  |  alpha_x = 1.809 |  alpha_y = 1.284
# s = 26.685 m  |  beta_x = 1.726  | beta_y = 35.077  |  alpha_x = 1.684 |  alpha_y = 1.280
# s = 26.720 m  |  beta_x = 1.611  | beta_y = 34.987  |  alpha_x = 1.606 |  alpha_y = 1.277
# s = 27.280 m  |  beta_x = 0.508  | beta_y = 33.549  |  alpha_x = 0.362 |  alpha_y = 1.289
# s = 28.610 m  |  beta_x = 3.473  | beta_y = 30.120  |  alpha_x = -2.589 |  alpha_y = 1.282
# s = 28.645 m  |  beta_x = 3.657  | beta_y = 30.030  |  alpha_x = -2.667 |  alpha_y = 1.279
# s = 28.701 m  |  beta_x = 3.966  | beta_y = 29.886  |  alpha_x = -2.792 |  alpha_y = 1.274
# s = 28.702 m  |  beta_x = 3.970  | beta_y = 29.884  |  alpha_x = -2.794 |  alpha_y = 1.274
# s = 28.758 m  |  beta_x = 4.293  | beta_y = 29.740  |  alpha_x = -2.919 |  alpha_y = 1.269
# s = 28.793 m  |  beta_x = 4.500  | beta_y = 29.652  |  alpha_x = -2.997 |  alpha_y = 1.266
# s = 29.353 m  |  beta_x = 8.546  | beta_y = 28.242  |  alpha_x = -4.229 |  alpha_y = 1.251
# s = 30.683 m  |  beta_x = 23.640  | beta_y = 24.989  |  alpha_x = -7.112 |  alpha_y = 1.191
# s = 30.718 m  |  beta_x = 24.140  | beta_y = 24.906  |  alpha_x = -7.188 |  alpha_y = 1.188
# s = 30.774 m  |  beta_x = 24.959  | beta_y = 24.772  |  alpha_x = -7.312 |  alpha_y = 1.182
# s = 30.817 m  |  beta_x = 25.585  | beta_y = 24.671  |  alpha_x = -7.405 |  alpha_y = 1.178
# s = 30.894 m  |  beta_x = 26.738  | beta_y = 24.490  |  alpha_x = -7.573 |  alpha_y = 1.171
# s = 31.015 m  |  beta_x = 32.371  | beta_y = 21.203  |  alpha_x = -40.968 |  alpha_y = 24.821
# s = 31.103 m  |  beta_x = 40.029  | beta_y = 17.037  |  alpha_x = -45.559 |  alpha_y = 22.245
# s = 31.325 m  |  beta_x = 41.110  | beta_y = 14.594  |  alpha_x = 41.458 |  alpha_y = -9.607
# s = 31.414 m  |  beta_x = 34.099  | beta_y = 16.344  |  alpha_x = 37.755 |  alpha_y = -10.172
# s = 31.535 m  |  beta_x = 29.392  | beta_y = 16.667  |  alpha_x = 2.809 |  alpha_y = 7.619
# s = 31.572 m  |  beta_x = 29.181  | beta_y = 16.098  |  alpha_x = 2.797 |  alpha_y = 7.486
# s = 31.654 m  |  beta_x = 28.727  | beta_y = 14.902  |  alpha_x = 2.773 |  alpha_y = 7.197
# s = 31.711 m  |  beta_x = 28.409  | beta_y = 14.086  |  alpha_x = 2.755 |  alpha_y = 6.993
# s = 31.761 m  |  beta_x = 28.134  | beta_y = 13.395  |  alpha_x = 2.740 |  alpha_y = 6.816
# s = 31.831 m  |  beta_x = 27.752  | beta_y = 12.458  |  alpha_x = 2.719 |  alpha_y = 6.568
# s = 31.874 m  |  beta_x = 27.521  | beta_y = 11.906  |  alpha_x = 2.706 |  alpha_y = 6.418
# s = 31.959 m  |  beta_x = 27.064  | beta_y = 10.841  |  alpha_x = 2.681 |  alpha_y = 6.117
# s = 32.015 m  |  beta_x = 26.762  | beta_y = 10.161  |  alpha_x = 2.663 |  alpha_y = 5.916
# s = 32.050 m  |  beta_x = 26.576  | beta_y = 9.751  |  alpha_x = 2.653 |  alpha_y = 5.792
# s = 32.610 m  |  beta_x = 23.687  | beta_y = 4.373  |  alpha_x = 2.505 |  alpha_y = 3.812
# s = 33.940 m  |  beta_x = 17.518  | beta_y = 0.516  |  alpha_x = 2.130 |  alpha_y = -0.914
# s = 33.975 m  |  beta_x = 17.369  | beta_y = 0.584  |  alpha_x = 2.119 |  alpha_y = -1.038
# s = 34.031 m  |  beta_x = 17.131  | beta_y = 0.713  |  alpha_x = 2.101 |  alpha_y = -1.239
# s = 34.032 m  |  beta_x = 17.128  | beta_y = 0.714  |  alpha_x = 2.101 |  alpha_y = -1.242
# s = 34.089 m  |  beta_x = 16.891  | beta_y = 0.866  |  alpha_x = 2.083 |  alpha_y = -1.443
# s = 34.124 m  |  beta_x = 16.746  | beta_y = 0.971  |  alpha_x = 2.072 |  alpha_y = -1.567
# s = 34.683 m  |  beta_x = 14.519  | beta_y = 3.840  |  alpha_x = 1.905 |  alpha_y = -3.557
# s = 36.013 m  |  beta_x = 9.992  | beta_y = 19.556  |  alpha_x = 1.496 |  alpha_y = -8.255
# s = 36.048 m  |  beta_x = 9.888  | beta_y = 20.138  |  alpha_x = 1.485 |  alpha_y = -8.379
# s = 36.105 m  |  beta_x = 9.721  | beta_y = 21.096  |  alpha_x = 1.467 |  alpha_y = -8.579
# s = 36.147 m  |  beta_x = 9.597  | beta_y = 21.832  |  alpha_x = 1.453 |  alpha_y = -8.729
# s = 36.211 m  |  beta_x = 9.412  | beta_y = 22.964  |  alpha_x = 1.432 |  alpha_y = -8.956
# s = 36.332 m  |  beta_x = 9.703  | beta_y = 23.573  |  alpha_x = -3.890 |  alpha_y = 4.033
# s = 36.421 m  |  beta_x = 10.405  | beta_y = 22.865  |  alpha_x = -4.037 |  alpha_y = 3.968
# s = 36.643 m  |  beta_x = 9.608  | beta_y = 27.014  |  alpha_x = 7.325 |  alpha_y = -24.184
# s = 36.731 m  |  beta_x = 8.356  | beta_y = 31.464  |  alpha_x = 6.821 |  alpha_y = -26.103
# s = 36.852 m  |  beta_x = 7.291  | beta_y = 35.740  |  alpha_x = 2.178 |  alpha_y = -8.432
# s = 36.959 m  |  beta_x = 6.835  | beta_y = 37.561  |  alpha_x = 2.094 |  alpha_y = -8.647
# s = 37.016 m  |  beta_x = 6.597  | beta_y = 38.562  |  alpha_x = 2.048 |  alpha_y = -8.763
# s = 37.086 m  |  beta_x = 6.314  | beta_y = 39.799  |  alpha_x = 1.993 |  alpha_y = -8.904
# s = 37.129 m  |  beta_x = 6.146  | beta_y = 40.559  |  alpha_x = 1.960 |  alpha_y = -8.990
# s = 37.185 m  |  beta_x = 5.927  | beta_y = 41.582  |  alpha_x = 1.915 |  alpha_y = -9.104
# s = 37.220 m  |  beta_x = 5.794  | beta_y = 42.221  |  alpha_x = 1.888 |  alpha_y = -9.174
# s = 37.780 m  |  beta_x = 3.926  | beta_y = 53.109  |  alpha_x = 1.449 |  alpha_y = -10.273
# s = 39.110 m  |  beta_x = 1.466  | beta_y = 83.849  |  alpha_x = 0.401 |  alpha_y = -12.836
# s = 39.145 m  |  beta_x = 1.438  | beta_y = 84.749  |  alpha_x = 0.373 |  alpha_y = -12.905
# s = 39.201 m  |  beta_x = 1.399  | beta_y = 86.214  |  alpha_x = 0.328 |  alpha_y = -13.016
# s = 39.202 m  |  beta_x = 1.398  | beta_y = 86.232  |  alpha_x = 0.328 |  alpha_y = -13.018
# s = 39.258 m  |  beta_x = 1.364  | beta_y = 87.710  |  alpha_x = 0.283 |  alpha_y = -13.130
# s = 39.293 m  |  beta_x = 1.345  | beta_y = 88.631  |  alpha_x = 0.255 |  alpha_y = -13.199
# s = 39.853 m  |  beta_x = 1.307  | beta_y = 104.002  |  alpha_x = -0.188 |  alpha_y = -14.255
# s = 41.183 m  |  beta_x = 3.203  | beta_y = 145.196  |  alpha_x = -1.238 |  alpha_y = -16.715
# s = 41.218 m  |  beta_x = 3.291  | beta_y = 146.368  |  alpha_x = -1.265 |  alpha_y = -16.783
# s = 41.274 m  |  beta_x = 3.436  | beta_y = 148.271  |  alpha_x = -1.310 |  alpha_y = -16.892
# s = 41.359 m  |  beta_x = 3.665  | beta_y = 151.157  |  alpha_x = -1.377 |  alpha_y = -17.056
# s = 41.512 m  |  beta_x = 4.102  | beta_y = 156.396  |  alpha_x = -1.498 |  alpha_y = -17.350
# s = 41.554 m  |  beta_x = 4.231  | beta_y = 157.874  |  alpha_x = -1.531 |  alpha_y = -17.432
# s = 41.644 m  |  beta_x = 4.511  | beta_y = 161.010  |  alpha_x = -1.602 |  alpha_y = -17.605
# s = 41.765 m  |  beta_x = 5.373  | beta_y = 150.370  |  alpha_x = -5.743 |  alpha_y = 102.767
# s = 41.878 m  |  beta_x = 6.761  | beta_y = 127.906  |  alpha_x = -6.462 |  alpha_y = 94.780
# s = 42.100 m  |  beta_x = 7.261  | beta_y = 127.941  |  alpha_x = 4.468 |  alpha_y = -94.951
# s = 42.154 m  |  beta_x = 6.787  | beta_y = 138.398  |  alpha_x = 4.312 |  alpha_y = -98.755
# s = 42.275 m  |  beta_x = 6.379  | beta_y = 149.221  |  alpha_x = -0.832 |  alpha_y = 12.131
# s = 42.399 m  |  beta_x = 6.589  | beta_y = 146.240  |  alpha_x = -0.865 |  alpha_y = 12.008
# s = 42.524 m  |  beta_x = 6.809  | beta_y = 143.249  |  alpha_x = -0.898 |  alpha_y = 11.884
# s = 42.665 m  |  beta_x = 7.069  | beta_y = 139.904  |  alpha_x = -0.936 |  alpha_y = 11.743
# s = 42.789 m  |  beta_x = 7.304  | beta_y = 137.018  |  alpha_x = -0.968 |  alpha_y = 11.621
# s = 42.931 m  |  beta_x = 7.583  | beta_y = 133.748  |  alpha_x = -1.006 |  alpha_y = 11.480
# s = 44.971 m  |  beta_x = 12.794  | beta_y = 91.024  |  alpha_x = -1.547 |  alpha_y = 9.454
# s = 45.014 m  |  beta_x = 12.926  | beta_y = 90.222  |  alpha_x = -1.559 |  alpha_y = 9.412

# %%
def get_energy_at_s(s_target, tws_list):
    s_array = np.array([tw.s for tw in tws_list])
    E_array = np.array([tw.E for tw in tws_list])
    return np.interp(s_target, s_array, E_array)

# %%
def plot_opt_func(lat, tws, top_plot=["Dx"], legend=True, fig_name=None, grid=True, font_size=12,
                  excld_legend=None, figsize=None, plt_figure=None):
    from ocelot.cpbd.optics import lattice_transfer_map

    if plt_figure is None:
        if fig_name is None:
            fig = plt.figure(figsize=figsize)
        else:
            fig = plt.figure(fig_name, figsize=figsize)
    else:
        fig = plt_figure

    plt.rc('axes', grid=grid)
    plt.rc('grid', color='0.75', linestyle='-', linewidth=0.5)
    left, width = 0.1, 0.85

    rect1 = [left, 0.65, width, 0.3]
    rect2 = [left, 0.19, width, 0.46]
    rect3 = [left, 0.07, width, 0.12]

    ax_top = fig.add_axes(rect1)
    ax_b = fig.add_axes(rect2, sharex=ax_top)
    ax_el = fig.add_axes(rect3, sharex=ax_top)

    for ax in ax_b, ax_el, ax_top:
        if ax != ax_el:
            for label in ax.get_xticklabels():
                label.set_visible(False)

    ax_b.grid(grid)
    ax_top.grid(grid)
    ax_el.set_yticks([])
    ax_el.grid(grid)

    fig.subplots_adjust(hspace=0)
    beta_x = [p.beta_x for p in tws]
    beta_y = [p.beta_y for p in tws]
    S = [p.s for p in tws]

    plt.xlim(S[0], S[-1])

    # Plot standard Twiss parameters
    plot_disp(ax_top, tws, [p for p in top_plot if p != "R56"], font_size)

    # ---- Add R56 Plotting ----
    if "R56" in top_plot:
        R56_vals = []
        s_vals = []

        for i in range(2, len(lat.sequence)):
            partial_lat = MagneticLattice(lat.sequence[:i])
            s_here = sum(e.l for e in partial_lat.sequence)

            try:
                E_here = get_energy_at_s(s_here, tws)
                R = lattice_transfer_map(partial_lat, energy=E_here)
                r56 = R[4, 5]
            except Exception as e:
                print(f"[WARN] Failed R56 at s = {s_here:.2f} m: {e}")
                r56 = 0

            # Debug print
            if i % 50 == 0 or s_here > 100:  # customize condition as you like
                print(f"s = {s_here:.2f} m, E = {E_here:.3f} GeV, R56 = {r56*1000:.3f} mm")

            R56_vals.append(r56)
            s_vals.append(s_here)

        
        ax_top.plot(s_vals, np.array(R56_vals), label="R56 [m]", color="red", linewidth=2)

    if "R56" in top_plot or legend:
        ax_top.legend(fontsize=font_size - 2)

    # Plot betas and elements
    plot_betas(ax_b, S, beta_x, beta_y, font_size)
    plot_elems(fig, ax_el, lat, s_point=S[0], legend=legend, y_scale=0.8, font_size=font_size,
               excld_legend=excld_legend)

# %%
plot_opt_func(lat, tws, top_plot=["Dx", "R56"], legend=True )
# Out:
# s = 5.14 m, E = 0.025 GeV, R56 = -0.935 mm
# s = 10.25 m, E = 0.034 GeV, R56 = -17.541 mm
# s = 17.31 m, E = 0.122 GeV, R56 = -21.131 mm
# s = 22.11 m, E = 0.166 GeV, R56 = -21.716 mm
# s = 30.72 m, E = 0.313 GeV, R56 = -22.551 mm
# s = 36.96 m, E = 0.393 GeV, R56 = -22.757 mm

# %%
# Your element IDs
start_id = "PA1RFGUN"
end_id   = "L491"

# Find their indices in the lattice
start_index = next(i for i, el in enumerate(lattice_list) if el.id == start_id)
end_index   = next(i for i, el in enumerate(lattice_list) if el.id == end_id)

# Create the sub-lattice
partial_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

# Get s-positions of those indices
s_start = sum(el.l for el in lattice_list[:start_index])
s_end   = sum(el.l for el in lattice_list[:end_index + 1])
s_mid   = 0.5 * (s_start + s_end)

# Interpolate energy at midpoint
E_here = get_energy_at_s(s_mid, tws)

# Calculate R56
R = lattice_transfer_map(partial_lat, energy=E_here)
r56 = R[4, 5]

# Print result
print(f"R56 from '{start_id}' to '{end_id}' (s = {s_start:.2f} to {s_end:.2f} m, E ≈ {E_here:.3f} GeV): R56 = {r56*1000:.3f} mm")
# Out:
# R56 from 'PA1RFGUN' to 'L491' (s = 0.00 to 45.01 m, E ≈ 0.175 GeV): R56 = -21.806 mm

# %%
def compute_r56_with_energy_evolution(lat_list, tws, id_start, id_end):
    # Find element indices
    i_start = next(i for i, el in enumerate(lat_list) if el.id == id_start)
    i_end   = next(i for i, el in enumerate(lat_list) if el.id == id_end)

    # Build the sub-lattice
    partial_lat = MagneticLattice(lat_list[i_start:i_end + 1])

    # Use starting energy from Twiss at i_start
    s_start = sum(e.l for e in lat_list[:i_start])
    E_start = get_energy_at_s(s_start, tws)

    # Compute transfer maps at every step (tracks energy changes!)
    Bs, Rs, Ts, Ss = partial_lat.transfer_maps(energy=E_start, output_at_each_step=True)

    # Get the last transfer matrix — full map from PJARCM1 to PSECTC
    R_final = Rs[-1]
    r56 = R_final[4, 5]

    s_end = s_start + sum(e.l for e in lat_list[i_start:i_end + 1])
    print(f"R56 from '{id_start}' to '{id_end}' (s = {s_start:.2f} → {s_end:.2f} m): R56 = {r56*1000:.3f} mm")

# %%
compute_r56_with_energy_evolution(lattice_list, tws, "PA1RFGUN", "L491")
# Out:
# R56 from 'PA1RFGUN' to 'L491' (s = 0.00 → 45.01 m): R56 = -22.795 mm

# %%
final_twiss = tws_track[-1]

print("\n===== Final Beam Parameters =====")
print(f"Position s (m):       {final_twiss.s:.4f}")
print(f"Energy E (GeV):       {final_twiss.E:.6f}")
print(f"Beta X (βx) (m):      {final_twiss.beta_x:.6f}")
print(f"Beta Y (βy) (m):      {final_twiss.beta_y:.6f}")
print(f"Alpha X (αx):         {final_twiss.alpha_x:.6f}")
print(f"Alpha Y (αy):         {final_twiss.alpha_y:.6f}")
print(f"Norm. Emit X (m.rad): {final_twiss.emit_xn:.6e}")
print(f"Norm. Emit Y (m.rad): {final_twiss.emit_yn:.6e}")
print(f"Geom. Emit X (m.rad): {final_twiss.emit_x:.6e}")
print(f"Geom. Emit Y (m.rad): {final_twiss.emit_y:.6e}")
# Out:
# ===== Final Beam Parameters =====
# Position s (m):       45.0139
# Energy E (GeV):       0.471969
# Beta X (βx) (m):      12.926344
# Beta Y (βy) (m):      90.222254
# Alpha X (αx):         -1.558629
# Alpha Y (αy):         9.411691
# Norm. Emit X (m.rad): 1.197707e-06
# Norm. Emit Y (m.rad): 1.205370e-06
# Geom. Emit X (m.rad): 1.296752e-09
# Geom. Emit Y (m.rad): 1.305049e-09

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract position and beta functions
s = np.array([tw.s for tw in tws_track])
beta_x = np.array([tw.beta_x for tw in tws_track])
beta_y = np.array([tw.beta_y for tw in tws_track])

# Use initial geometric emittances
emit_x = tw0.emit_x
emit_y = tw0.emit_y

# Compute beam sizes σx and σy in meters
sigma_x = np.sqrt(beta_x * emit_x)
sigma_y = np.sqrt(beta_y * emit_y)

# Plot beam sizes in millimeters
plt.figure(figsize=(10, 6))
plt.plot(s, sigma_x * 1e3, label=r'$\sigma_x$ [mm]', linewidth=2)
plt.plot(s, sigma_y * 1e3, label=r'$\sigma_y$ [mm]', linewidth=2)

plt.xlabel('s [m]', fontsize=14)
plt.ylabel('Beam Size σ [mm]', fontsize=14)
plt.title('Transverse Beam Sizes Along the Lattice', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()
