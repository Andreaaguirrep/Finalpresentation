# %%
from ocelot import *
from ocelot.cpbd.elements import *
from ocelot.gui.accelerator import *
from ocelot.cpbd.track import track_debug
from utils import trunc_s, show_parameter_evolution
import matplotlib.pyplot as plt


#from rfglinacbte import *
#from Jarc import *
from JarcCSR import *

#lat = MagneticLattice(lattice_list)
lat = MagneticLattice(lattice_list[0:1100])   



##### PA1RFGUN #####
# AX =-21.12   
# BX =24.36 
# AY =-21.16     
# BY =24.42      
# EMITX =1.2023504614117648e-06
# EMITY =1.2023504614117648e-06 
##### PA1RFGUN #####


##### PSECTB #####
AX =.8330530584703799  
BX =8.804855185360497    
AY =.8104567519439174
BY =8.82335409438248       
EMITX =1.2023504614117648e-06 
EMITY =1.2023504614117648e-06 
##### PSECTB #####

energy = 0.5 # GeV  #why?
tw0 = Twiss()
tw0.alpha_x = AX
tw0.beta_x = BX

tw0.alpha_y = AY
tw0.beta_y = BY
tw0.E = energy
tw0.emit_xn = EMITX 
tw0.emit_yn = EMITY
tw0.emit_x = EMITX   / energy * 0.511e-3
tw0.emit_y = EMITY / energy * 0.511e-3

tws = twiss(lat,tw0)

plot_opt_func(lat, tws,legend=False, grid=False, top_plot=['Dx','Dy'])

# %%
def gauss_from_twiss_vec(emit, beta, alpha, size=1):
    phi = 2 * np.pi * np.random.rand(size)
    u = np.random.rand(size)
    a = np.sqrt(-2 * np.log(1 - u) * emit)
    x = a * np.sqrt(beta) * np.cos(phi)
    xp = -a / np.sqrt(beta) * (np.sin(phi) + alpha * np.cos(phi))
    return x, xp

# %%
start_index = next(i for i, el in enumerate(lattice_list) if el.id == "PJARCM1")
end_index = next(i for i, el in enumerate(lattice_list) if el.id == "PSECTC")

sub_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

R = lattice_transfer_map(sub_lat, energy=1.5)
print("R56 = ", R[4,5]*1000, "mm")
# Out:
# R56 =  -0.27711775672648775 mm

# %%
nparticles = 1000000
p_array = ParticleArray(n=nparticles)

sigma_tau = 6.7e-3  # m
sigma_p = 5.e-3     # relative momentum spread

p_array.E = energy  # GeV

# Longitudinal
p_array.rparticles[4] = np.random.randn(nparticles) * sigma_tau
p_array.rparticles[5] = np.random.randn(nparticles) * sigma_p

# Transverse: vectorized sampling from Twiss parameters
x, xp = gauss_from_twiss_vec(tw0.emit_x, tw0.beta_x, tw0.alpha_x, size=nparticles)
y, yp = gauss_from_twiss_vec(tw0.emit_y, tw0.beta_y, tw0.alpha_y, size=nparticles)

p_array.rparticles[0] = x
p_array.rparticles[1] = xp
p_array.rparticles[2] = y
p_array.rparticles[3] = yp

# Charge distribution
charge = 4.0e-9  # nC
p_array.q_array = np.ones(nparticles) * (charge / nparticles)

# %%
plt.hist(p_array.rparticles[0], bins=100, alpha=0.7, label='x')
plt.hist(p_array.rparticles[1], bins=100, alpha=0.7, label="x'")
plt.legend()
plt.show()

plt.hist(p_array.rparticles[2], bins=100, alpha=0.7, label='y')
plt.hist(p_array.rparticles[3], bins=100, alpha=0.7, label="y'")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
x = p_array.rparticles[0]
xp = p_array.rparticles[1]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_x, sigma_xp = twiss_sigmas(tw0.emit_x, tw0.beta_x, tw0.alpha_x)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='x (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='x (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="x′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_xp), 'r--', label="x′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of x and x′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Get simulated data
y = p_array.rparticles[2]
yp = p_array.rparticles[3]

# Get theoretical σ values
def twiss_sigmas(emit, beta, alpha):
    gamma = (1 + alpha**2) / beta
    return np.sqrt(beta * emit), np.sqrt(gamma * emit)

sigma_y, sigma_yp = twiss_sigmas(tw0.emit_y, tw0.beta_y, tw0.alpha_y)

# Define histogram range
bins = 100
x_range = np.linspace(min(x.min(), xp.min()), max(x.max(), xp.max()), 1000)

# Plot x
plt.figure(figsize=(10, 4))
plt.hist(x, bins=bins, density=True, alpha=0.6, label='y (simulated)')
plt.plot(x_range, norm.pdf(x_range, 0, sigma_x), 'b--', label='y (theoretical Gaussian)')

# Plot x'
plt.hist(xp, bins=bins, density=True, alpha=0.6, label="y′ (simulated)")
plt.plot(x_range, norm.pdf(x_range, 0, sigma_yp), 'r--', label="y′ (theoretical Gaussian)")

plt.xlabel('[m or rad]')
plt.ylabel('Probability density')
plt.title("Distributions of y and y′ with Theoretical Gaussians")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def check_beam_stats(p_array, twiss, axis_label="x"):
    idx = 0 if axis_label == "x" else 2
    idxp = 1 if axis_label == "x" else 3

    sigma = np.std(p_array.rparticles[idx])
    sigmap = np.std(p_array.rparticles[idxp])

    beta = getattr(twiss, f"beta_{axis_label}")
    alpha = getattr(twiss, f"alpha_{axis_label}")
    emit = getattr(twiss, f"emit_{axis_label}")

    sigma_theo = np.sqrt(beta * emit)
    gamma = (1 + alpha**2) / beta
    sigmap_theo = np.sqrt(gamma * emit)

    print(f"σ_{axis_label} (simulated):     {sigma}")
    print(f"σ_{axis_label} (theoretical):   {sigma_theo}")
    print(f"σ_{axis_label}' (simulated):    {sigmap}")
    print(f"σ_{axis_label}' (theoretical):  {sigmap_theo}")

# %%
check_beam_stats(p_array, tw0, axis_label="x")
# Out:
# σ_x (simulated):     0.00010410315402864383
# σ_x (theoretical):   0.00010401646586991489
# σ_x' (simulated):    1.5386552843324483e-05
# σ_x' (theoretical):  1.5375656996782916e-05

# %%
check_beam_stats(p_array, tw0, axis_label="y")
# Out:
# σ_y (simulated):     0.00010395490326834361
# σ_y (theoretical):   0.00010412567729261079
# σ_y' (simulated):    1.5195114467265688e-05
# σ_y' (theoretical):  1.5190233002553629e-05

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- X plane ---
x = p_array.rparticles[0]
xp = p_array.rparticles[1]
emit_x = tw0.emit_x
beta_x = tw0.beta_x
alpha_x = tw0.alpha_x

theta = np.linspace(0, 2*np.pi, 400)
x_ellipse = np.sqrt(emit_x * beta_x) * np.cos(theta)
xp_ellipse = (-alpha_x * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_x / beta_x)

# --- Y plane ---
y = p_array.rparticles[2]
yp = p_array.rparticles[3]
emit_y = tw0.emit_y
beta_y = tw0.beta_y
alpha_y = tw0.alpha_y

y_ellipse = np.sqrt(emit_y * beta_y) * np.cos(theta)
yp_ellipse = (-alpha_y * np.cos(theta) + np.sin(theta)) * np.sqrt(emit_y / beta_y)

# --- Plot ---
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# x-x'
axes[0].scatter(x, xp, s=1, alpha=0.3, label='Particles')
axes[0].plot(x_ellipse, xp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[0].set_xlabel('x [m]')
axes[0].set_ylabel("x′ [rad]")
axes[0].set_title('Phase space: x vs x′')
axes[0].grid(True)
axes[0].axis('equal')
axes[0].legend()

# y-y'
axes[1].scatter(y, yp, s=1, alpha=0.3, color='orange', label='Particles')
axes[1].plot(y_ellipse, yp_ellipse, 'r', linewidth=2, label='Twiss ellipse')
axes[1].set_xlabel('y [m]')
axes[1].set_ylabel("y′ [rad]")
axes[1].set_title('Phase space: y vs y′')
axes[1].grid(True)
axes[1].axis('equal')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy

def plot_emittances_vs_s(p_array, nparts_in_slice=5000, smooth_param=0.05,
                         tau_units="m", inverse_tau=False, grid=True,
                         title="Normalized Emittances vs s", figsize=(8, 4),
                         filename=None):
    """
    Plot normalized emittances vs longitudinal position s (head-tail slicing).

    :param p_array: ParticleArray object
    :param nparts_in_slice: number of particles per slice
    :param smooth_param: smoothing parameter used in slice analysis
    :param tau_units: 'm', 'mm', or 'um'
    :param inverse_tau: flip the tau axis
    :param grid: show grid
    :param title: plot title
    :param figsize: matplotlib figsize
    :param filename: optional path to save the plot
    """
    # Set scale for s-axis
    tau_factors = {"m": 1, "mm": 1e3, "um": 1e6}
    tau_factor = tau_factors.get(tau_units, 1e3)
    tau_label = f"$s\,[\\mathrm{{{tau_units}}}]$"

    # Deepcopy to preserve original
    p_array_copy = deepcopy(p_array)
    if inverse_tau:
        p_array_copy.tau()[:] *= -1

    # Perform slice analysis (assumes this function exists in your codebase)
    slice_params = global_slice_analysis(p_array_copy, nparts_in_slice, smooth_param)

    # Extract and convert to proper units
    s = slice_params.s * tau_factor
    emit_x = slice_params.exn * 1e6  # [mm·mrad]
    emit_y = slice_params.eyn * 1e6

    # Plot
    plt.figure(figsize=figsize)
    plt.plot(s, emit_x, label=r"$\varepsilon_x$", color='red')
    plt.plot(s, emit_y, label=r"$\varepsilon_y$", color='blue')
    plt.xlabel(tau_label)
    plt.ylabel(r"Normalized Emittance [$\mathrm{mm\cdot{}mrad}$]")
    plt.title(title)
    plt.legend()
    if grid:
        plt.grid(True)
    if filename:
        plt.savefig(filename)
    plt.tight_layout()
    plt.show()

# %%
plot_emittances_vs_s(p_array)

# %%
import time
navi = Navigator(lat)
navi.unit_step = 0.1 # m, only with CSR

csr = CSR(n_bin=500, m_bin=5, sigma_min=.2e-6)

navi.add_physics_proc(csr, csrm1_start, csrm1_end)

p_array_t = deepcopy(p_array)

start = time.time()
tws_track, p_array_t = track(lat, p_array_t, navi)
print("\n time exec:", time.time() - start, "sec")
# Out:
# z = 179.0817027999999 / 179.08170280000002. Applied:  CSR
#  time exec: 164.25705289840698 sec

# %%
plot_emittances_vs_s(p_array_t)

# %%
show_e_beam(p_array)

# %%
show_e_beam(p_array_t)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_energy_vs_position(tws_track):
    """
    Plot energy E as a function of position s from a list of Twiss-like objects.

    Parameters:
    tws_track (list): List of objects with attributes 's' (position) and 'E' (energy).
    """
    s = np.array([tw.s for tw in tws_track])
    E = np.array([tw.E for tw in tws_track])

    plt.figure(figsize=(10, 6))
    plt.plot(s, E, linewidth=2, marker='o', markersize=4)

    plt.title("Energy vs Position", fontsize=16)
    plt.xlabel("s (m)", fontsize=14)
    plt.ylabel("E (GeV)", fontsize=14)
    plt.grid(True, which='both', linestyle='--', alpha=0.5)
    plt.tick_params(axis='both', labelsize=12)
    plt.tight_layout()
    plt.show()

# %%
plot_energy_vs_position(tws_track)

# %%
# --- After tracking: get final x, x', y, y' ---
x_t = p_array_t.rparticles[0]
xp_t = p_array_t.rparticles[1]
y_t = p_array_t.rparticles[2]
yp_t = p_array_t.rparticles[3]

# --- Plot initial vs final side-by-side ---
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# x-x′ before
axes[0][0].scatter(p_array.rparticles[0], p_array.rparticles[1], s=1, alpha=0.3)
axes[0][0].set_title("x vs x′ (before)")
axes[0][0].set_xlabel("x [m]")
axes[0][0].set_ylabel("x′ [rad]")
axes[0][0].grid(True)
axes[0][0].axis('equal')

# x-x′ after
axes[0][1].scatter(x_t, xp_t, s=1, alpha=0.3)
axes[0][1].set_title("x vs x′ (after)")
axes[0][1].set_xlabel("x [m]")
axes[0][1].set_ylabel("x′ [rad]")
axes[0][1].grid(True)
axes[0][1].axis('equal')

# y-y′ before
axes[1][0].scatter(p_array.rparticles[2], p_array.rparticles[3], s=1, alpha=0.3, color='orange')
axes[1][0].set_title("y vs y′ (before)")
axes[1][0].set_xlabel("y [m]")
axes[1][0].set_ylabel("y′ [rad]")
axes[1][0].grid(True)
axes[1][0].axis('equal')

# y-y′ after
axes[1][1].scatter(y_t, yp_t, s=1, alpha=0.3, color='orange')
axes[1][1].set_title("y vs y′ (after)")
axes[1][1].set_xlabel("y [m]")
axes[1][1].set_ylabel("y′ [rad]")
axes[1][1].grid(True)
axes[1][1].axis('equal')

plt.tight_layout()
plt.show()

# %%
import numpy as np

def compute_emittance(x, xp):
    x_mean = np.mean(x)
    xp_mean = np.mean(xp)

    x_cent = x - x_mean
    xp_cent = xp - xp_mean

    xx = np.mean(x_cent ** 2)
    xpxp = np.mean(xp_cent ** 2)
    xxp = np.mean(x_cent * xp_cent)

    emit = np.sqrt(xx * xpxp - xxp**2)
    return emit

# Final tracked coordinates
x, xp = p_array_t.rparticles[0], p_array_t.rparticles[1]
y, yp = p_array_t.rparticles[2], p_array_t.rparticles[3]

emit_x = compute_emittance(x, xp)
emit_y = compute_emittance(y, yp)

print(f"εₓ (RMS, final) = {emit_x:.5e} m·rad")
print(f"εᵧ (RMS, final) = {emit_y:.5e} m·rad")

emit_x0 = compute_emittance(p_array.rparticles[0], p_array.rparticles[1])
emit_y0 = compute_emittance(p_array.rparticles[2], p_array.rparticles[3])
print("Initial εₓ:", emit_x0)
print("Initial εᵧ:", emit_y0)
# Out:
# εₓ (RMS, final) = 6.42920e-10 m·rad
# εᵧ (RMS, final) = 2.35904e-10 m·rad
# Initial εₓ: 1.2308674731133695e-09
# Initial εᵧ: 1.227279463251414e-09

# %%
for tw in tws_track:
    print(f"s = {tw.s:.3f} m  |  beta_x = {tw.beta_x:.3f}  |  alpha_x = {tw.alpha_x:.3f}" )
# Out:
# s = 0.000 m  |  beta_x = 8.805  |  alpha_x = 0.833
# s = 0.000 m  |  beta_x = 8.805  |  alpha_x = 0.833
# s = 0.085 m  |  beta_x = 8.665  |  alpha_x = 0.816
# s = 0.142 m  |  beta_x = 8.573  |  alpha_x = 0.806
# s = 0.176 m  |  beta_x = 8.517  |  alpha_x = 0.799
# s = 0.736 m  |  beta_x = 7.681  |  alpha_x = 0.694
# s = 2.066 m  |  beta_x = 6.170  |  alpha_x = 0.442
# s = 2.101 m  |  beta_x = 6.139  |  alpha_x = 0.435
# s = 2.157 m  |  beta_x = 6.090  |  alpha_x = 0.425
# s = 2.158 m  |  beta_x = 6.090  |  alpha_x = 0.424
# s = 2.215 m  |  beta_x = 6.042  |  alpha_x = 0.413
# s = 2.250 m  |  beta_x = 6.014  |  alpha_x = 0.407
# s = 4.139 m  |  beta_x = 5.159  |  alpha_x = 0.045
# s = 4.174 m  |  beta_x = 5.156  |  alpha_x = 0.039
# s = 4.231 m  |  beta_x = 5.152  |  alpha_x = 0.028
# s = 4.302 m  |  beta_x = 5.149  |  alpha_x = 0.014
# s = 4.372 m  |  beta_x = 5.148  |  alpha_x = 0.000
# s = 4.415 m  |  beta_x = 5.148  |  alpha_x = -0.008
# s = 4.471 m  |  beta_x = 5.150  |  alpha_x = -0.019
# s = 4.506 m  |  beta_x = 5.151  |  alpha_x = -0.026
# s = 5.066 m  |  beta_x = 5.241  |  alpha_x = -0.133
# s = 6.396 m  |  beta_x = 5.934  |  alpha_x = -0.388
# s = 6.431 m  |  beta_x = 5.961  |  alpha_x = -0.395
# s = 6.487 m  |  beta_x = 6.006  |  alpha_x = -0.406
# s = 6.488 m  |  beta_x = 6.007  |  alpha_x = -0.406
# s = 6.545 m  |  beta_x = 6.053  |  alpha_x = -0.417
# s = 6.580 m  |  beta_x = 6.083  |  alpha_x = -0.424
# s = 8.469 m  |  beta_x = 8.365  |  alpha_x = -0.784
# s = 8.504 m  |  beta_x = 8.420  |  alpha_x = -0.790
# s = 8.561 m  |  beta_x = 8.510  |  alpha_x = -0.801
# s = 8.603 m  |  beta_x = 8.578  |  alpha_x = -0.810
# s = 8.756 m  |  beta_x = 8.830  |  alpha_x = -0.839
# s = 8.759 m  |  beta_x = 8.835  |  alpha_x = -0.840
# s = 8.892 m  |  beta_x = 10.003  |  alpha_x = -8.214
# s = 8.979 m  |  beta_x = 11.488  |  alpha_x = -8.811
# s = 9.232 m  |  beta_x = 11.486  |  alpha_x = 8.819
# s = 9.298 m  |  beta_x = 10.338  |  alpha_x = 8.361
# s = 9.319 m  |  beta_x = 9.999  |  alpha_x = 8.221
# s = 9.452 m  |  beta_x = 8.830  |  alpha_x = 0.849
# s = 9.510 m  |  beta_x = 8.732  |  alpha_x = 0.838
# s = 9.595 m  |  beta_x = 8.591  |  alpha_x = 0.821
# s = 9.652 m  |  beta_x = 8.499  |  alpha_x = 0.810
# s = 9.687 m  |  beta_x = 8.443  |  alpha_x = 0.803
# s = 10.246 m  |  beta_x = 7.603  |  alpha_x = 0.696
# s = 11.576 m  |  beta_x = 6.094  |  alpha_x = 0.439
# s = 11.611 m  |  beta_x = 6.064  |  alpha_x = 0.432
# s = 11.667 m  |  beta_x = 6.015  |  alpha_x = 0.421
# s = 11.668 m  |  beta_x = 6.015  |  alpha_x = 0.421
# s = 11.725 m  |  beta_x = 5.968  |  alpha_x = 0.410
# s = 11.760 m  |  beta_x = 5.939  |  alpha_x = 0.403
# s = 13.649 m  |  beta_x = 5.109  |  alpha_x = 0.036
# s = 13.684 m  |  beta_x = 5.107  |  alpha_x = 0.029
# s = 13.741 m  |  beta_x = 5.104  |  alpha_x = 0.018
# s = 13.812 m  |  beta_x = 5.102  |  alpha_x = 0.004
# s = 13.882 m  |  beta_x = 5.103  |  alpha_x = -0.009
# s = 13.925 m  |  beta_x = 5.104  |  alpha_x = -0.018
# s = 13.981 m  |  beta_x = 5.106  |  alpha_x = -0.029
# s = 14.016 m  |  beta_x = 5.109  |  alpha_x = -0.036
# s = 14.576 m  |  beta_x = 5.210  |  alpha_x = -0.145
# s = 15.906 m  |  beta_x = 5.938  |  alpha_x = -0.403
# s = 15.941 m  |  beta_x = 5.966  |  alpha_x = -0.410
# s = 15.997 m  |  beta_x = 6.013  |  alpha_x = -0.421
# s = 15.998 m  |  beta_x = 6.014  |  alpha_x = -0.421
# s = 16.055 m  |  beta_x = 6.062  |  alpha_x = -0.432
# s = 16.090 m  |  beta_x = 6.093  |  alpha_x = -0.439
# s = 17.979 m  |  beta_x = 8.443  |  alpha_x = -0.805
# s = 18.014 m  |  beta_x = 8.500  |  alpha_x = -0.812
# s = 18.071 m  |  beta_x = 8.592  |  alpha_x = -0.823
# s = 18.113 m  |  beta_x = 8.662  |  alpha_x = -0.831
# s = 18.266 m  |  beta_x = 8.920  |  alpha_x = -0.861
# s = 18.269 m  |  beta_x = 8.926  |  alpha_x = -0.861
# s = 18.402 m  |  beta_x = 10.109  |  alpha_x = -8.314
# s = 18.489 m  |  beta_x = 11.613  |  alpha_x = -8.919
# s = 18.742 m  |  beta_x = 11.616  |  alpha_x = 8.907
# s = 18.829 m  |  beta_x = 10.115  |  alpha_x = 8.303
# s = 18.962 m  |  beta_x = 8.935  |  alpha_x = 0.847
# s = 19.200 m  |  beta_x = 8.543  |  alpha_x = 0.802
# s = 19.285 m  |  beta_x = 8.408  |  alpha_x = 0.785
# s = 19.342 m  |  beta_x = 8.320  |  alpha_x = 0.774
# s = 19.377 m  |  beta_x = 8.266  |  alpha_x = 0.768
# s = 19.936 m  |  beta_x = 7.466  |  alpha_x = 0.661
# s = 21.266 m  |  beta_x = 6.045  |  alpha_x = 0.407
# s = 21.301 m  |  beta_x = 6.017  |  alpha_x = 0.400
# s = 21.357 m  |  beta_x = 5.972  |  alpha_x = 0.389
# s = 21.358 m  |  beta_x = 5.972  |  alpha_x = 0.389
# s = 21.415 m  |  beta_x = 5.928  |  alpha_x = 0.378
# s = 21.450 m  |  beta_x = 5.902  |  alpha_x = 0.372
# s = 23.339 m  |  beta_x = 5.182  |  alpha_x = 0.009
# s = 23.374 m  |  beta_x = 5.182  |  alpha_x = 0.003
# s = 23.431 m  |  beta_x = 5.182  |  alpha_x = -0.008
# s = 23.502 m  |  beta_x = 5.185  |  alpha_x = -0.022
# s = 23.572 m  |  beta_x = 5.189  |  alpha_x = -0.036
# s = 23.615 m  |  beta_x = 5.192  |  alpha_x = -0.044
# s = 23.671 m  |  beta_x = 5.198  |  alpha_x = -0.055
# s = 23.706 m  |  beta_x = 5.202  |  alpha_x = -0.062
# s = 24.266 m  |  beta_x = 5.331  |  alpha_x = -0.169
# s = 25.596 m  |  beta_x = 6.120  |  alpha_x = -0.424
# s = 25.631 m  |  beta_x = 6.149  |  alpha_x = -0.431
# s = 25.687 m  |  beta_x = 6.199  |  alpha_x = -0.442
# s = 25.688 m  |  beta_x = 6.199  |  alpha_x = -0.442
# s = 25.745 m  |  beta_x = 6.250  |  alpha_x = -0.453
# s = 25.780 m  |  beta_x = 6.282  |  alpha_x = -0.459
# s = 27.669 m  |  beta_x = 8.701  |  alpha_x = -0.821
# s = 27.704 m  |  beta_x = 8.759  |  alpha_x = -0.828
# s = 27.761 m  |  beta_x = 8.853  |  alpha_x = -0.838
# s = 27.803 m  |  beta_x = 8.925  |  alpha_x = -0.847
# s = 27.956 m  |  beta_x = 9.188  |  alpha_x = -0.876
# s = 27.959 m  |  beta_x = 9.193  |  alpha_x = -0.877
# s = 28.092 m  |  beta_x = 10.409  |  alpha_x = -8.549
# s = 28.179 m  |  beta_x = 11.955  |  alpha_x = -9.170
# s = 28.432 m  |  beta_x = 11.953  |  alpha_x = 9.178
# s = 28.499 m  |  beta_x = 10.758  |  alpha_x = 8.701
# s = 28.519 m  |  beta_x = 10.406  |  alpha_x = 8.556
# s = 28.652 m  |  beta_x = 9.188  |  alpha_x = 0.886
# s = 28.800 m  |  beta_x = 8.930  |  alpha_x = 0.857
# s = 28.885 m  |  beta_x = 8.786  |  alpha_x = 0.840
# s = 28.942 m  |  beta_x = 8.692  |  alpha_x = 0.829
# s = 28.977 m  |  beta_x = 8.634  |  alpha_x = 0.823
# s = 29.536 m  |  beta_x = 7.773  |  alpha_x = 0.715
# s = 30.866 m  |  beta_x = 6.214  |  alpha_x = 0.458
# s = 30.901 m  |  beta_x = 6.183  |  alpha_x = 0.451
# s = 30.957 m  |  beta_x = 6.132  |  alpha_x = 0.440
# s = 30.958 m  |  beta_x = 6.132  |  alpha_x = 0.440
# s = 31.015 m  |  beta_x = 6.083  |  alpha_x = 0.429
# s = 31.050 m  |  beta_x = 6.053  |  alpha_x = 0.422
# s = 32.939 m  |  beta_x = 5.150  |  alpha_x = 0.056
# s = 32.974 m  |  beta_x = 5.147  |  alpha_x = 0.049
# s = 33.031 m  |  beta_x = 5.142  |  alpha_x = 0.038
# s = 33.102 m  |  beta_x = 5.137  |  alpha_x = 0.024
# s = 33.172 m  |  beta_x = 5.135  |  alpha_x = 0.010
# s = 33.215 m  |  beta_x = 5.135  |  alpha_x = 0.002
# s = 33.271 m  |  beta_x = 5.135  |  alpha_x = -0.009
# s = 33.306 m  |  beta_x = 5.136  |  alpha_x = -0.016
# s = 33.866 m  |  beta_x = 5.215  |  alpha_x = -0.125
# s = 35.196 m  |  beta_x = 5.889  |  alpha_x = -0.382
# s = 35.231 m  |  beta_x = 5.916  |  alpha_x = -0.389
# s = 35.287 m  |  beta_x = 5.960  |  alpha_x = -0.400
# s = 35.288 m  |  beta_x = 5.961  |  alpha_x = -0.400
# s = 35.345 m  |  beta_x = 6.007  |  alpha_x = -0.411
# s = 35.380 m  |  beta_x = 6.036  |  alpha_x = -0.418
# s = 37.269 m  |  beta_x = 8.307  |  alpha_x = -0.784
# s = 37.304 m  |  beta_x = 8.363  |  alpha_x = -0.791
# s = 37.361 m  |  beta_x = 8.453  |  alpha_x = -0.802
# s = 37.403 m  |  beta_x = 8.521  |  alpha_x = -0.810
# s = 37.556 m  |  beta_x = 8.773  |  alpha_x = -0.840
# s = 37.559 m  |  beta_x = 8.778  |  alpha_x = -0.840
# s = 37.692 m  |  beta_x = 9.940  |  alpha_x = -8.168
# s = 37.779 m  |  beta_x = 11.417  |  alpha_x = -8.763
# s = 38.032 m  |  beta_x = 11.418  |  alpha_x = 8.760
# s = 38.099 m  |  beta_x = 10.278  |  alpha_x = 8.305
# s = 38.119 m  |  beta_x = 9.941  |  alpha_x = 8.166
# s = 38.252 m  |  beta_x = 8.780  |  alpha_x = 0.837
# s = 38.400 m  |  beta_x = 8.537  |  alpha_x = 0.809
# s = 38.485 m  |  beta_x = 8.401  |  alpha_x = 0.792
# s = 38.542 m  |  beta_x = 8.312  |  alpha_x = 0.781
# s = 38.577 m  |  beta_x = 8.257  |  alpha_x = 0.774
# s = 39.136 m  |  beta_x = 7.451  |  alpha_x = 0.666
# s = 40.466 m  |  beta_x = 6.021  |  alpha_x = 0.409
# s = 40.501 m  |  beta_x = 5.993  |  alpha_x = 0.402
# s = 40.557 m  |  beta_x = 5.948  |  alpha_x = 0.391
# s = 40.558 m  |  beta_x = 5.947  |  alpha_x = 0.391
# s = 40.615 m  |  beta_x = 5.904  |  alpha_x = 0.380
# s = 40.650 m  |  beta_x = 5.877  |  alpha_x = 0.374
# s = 42.539 m  |  beta_x = 5.157  |  alpha_x = 0.008
# s = 42.574 m  |  beta_x = 5.156  |  alpha_x = 0.001
# s = 42.631 m  |  beta_x = 5.157  |  alpha_x = -0.010
# s = 42.702 m  |  beta_x = 5.159  |  alpha_x = -0.024
# s = 42.772 m  |  beta_x = 5.164  |  alpha_x = -0.037
# s = 42.815 m  |  beta_x = 5.167  |  alpha_x = -0.046
# s = 42.871 m  |  beta_x = 5.173  |  alpha_x = -0.057
# s = 42.906 m  |  beta_x = 5.177  |  alpha_x = -0.063
# s = 43.466 m  |  beta_x = 5.309  |  alpha_x = -0.172
# s = 44.796 m  |  beta_x = 6.108  |  alpha_x = -0.429
# s = 44.831 m  |  beta_x = 6.138  |  alpha_x = -0.436
# s = 44.887 m  |  beta_x = 6.188  |  alpha_x = -0.447
# s = 44.888 m  |  beta_x = 6.189  |  alpha_x = -0.447
# s = 44.945 m  |  beta_x = 6.240  |  alpha_x = -0.458
# s = 44.980 m  |  beta_x = 6.272  |  alpha_x = -0.465
# s = 46.869 m  |  beta_x = 8.719  |  alpha_x = -0.830
# s = 46.904 m  |  beta_x = 8.778  |  alpha_x = -0.837
# s = 46.961 m  |  beta_x = 8.873  |  alpha_x = -0.848
# s = 47.003 m  |  beta_x = 8.945  |  alpha_x = -0.856
# s = 47.156 m  |  beta_x = 9.211  |  alpha_x = -0.886
# s = 47.159 m  |  beta_x = 9.217  |  alpha_x = -0.886
# s = 47.292 m  |  beta_x = 10.483  |  alpha_x = -8.949
# s = 47.379 m  |  beta_x = 12.104  |  alpha_x = -9.624
# s = 47.632 m  |  beta_x = 12.061  |  alpha_x = 9.770
# s = 47.699 m  |  beta_x = 10.791  |  alpha_x = 9.236
# s = 47.719 m  |  beta_x = 10.417  |  alpha_x = 9.072
# s = 47.852 m  |  beta_x = 9.113  |  alpha_x = 1.055
# s = 48.000 m  |  beta_x = 8.806  |  alpha_x = 1.021
# s = 48.085 m  |  beta_x = 8.634  |  alpha_x = 1.001
# s = 48.142 m  |  beta_x = 8.522  |  alpha_x = 0.988
# s = 48.177 m  |  beta_x = 8.453  |  alpha_x = 0.980
# s = 48.736 m  |  beta_x = 7.428  |  alpha_x = 0.851
# s = 50.066 m  |  beta_x = 5.576  |  alpha_x = 0.542
# s = 50.101 m  |  beta_x = 5.538  |  alpha_x = 0.534
# s = 50.157 m  |  beta_x = 5.478  |  alpha_x = 0.521
# s = 50.158 m  |  beta_x = 5.478  |  alpha_x = 0.521
# s = 50.215 m  |  beta_x = 5.419  |  alpha_x = 0.508
# s = 50.250 m  |  beta_x = 5.384  |  alpha_x = 0.500
# s = 52.139 m  |  beta_x = 4.323  |  alpha_x = 0.062
# s = 52.174 m  |  beta_x = 4.319  |  alpha_x = 0.054
# s = 52.231 m  |  beta_x = 4.314  |  alpha_x = 0.040
# s = 52.302 m  |  beta_x = 4.309  |  alpha_x = 0.024
# s = 52.372 m  |  beta_x = 4.307  |  alpha_x = 0.007
# s = 52.415 m  |  beta_x = 4.307  |  alpha_x = -0.002
# s = 52.471 m  |  beta_x = 4.308  |  alpha_x = -0.016
# s = 52.506 m  |  beta_x = 4.309  |  alpha_x = -0.024
# s = 53.066 m  |  beta_x = 4.408  |  alpha_x = -0.154
# s = 54.396 m  |  beta_x = 5.227  |  alpha_x = -0.462
# s = 54.431 m  |  beta_x = 5.259  |  alpha_x = -0.470
# s = 54.487 m  |  beta_x = 5.313  |  alpha_x = -0.483
# s = 54.488 m  |  beta_x = 5.314  |  alpha_x = -0.483
# s = 54.545 m  |  beta_x = 5.369  |  alpha_x = -0.496
# s = 54.580 m  |  beta_x = 5.404  |  alpha_x = -0.505
# s = 56.469 m  |  beta_x = 8.138  |  alpha_x = -0.942
# s = 56.504 m  |  beta_x = 8.205  |  alpha_x = -0.951
# s = 56.561 m  |  beta_x = 8.313  |  alpha_x = -0.964
# s = 56.603 m  |  beta_x = 8.395  |  alpha_x = -0.973
# s = 56.756 m  |  beta_x = 8.697  |  alpha_x = -1.009
# s = 56.759 m  |  beta_x = 8.704  |  alpha_x = -1.010
# s = 56.892 m  |  beta_x = 9.966  |  alpha_x = -8.794
# s = 56.979 m  |  beta_x = 11.560  |  alpha_x = -9.480
# s = 57.232 m  |  beta_x = 11.569  |  alpha_x = 9.449
# s = 57.299 m  |  beta_x = 10.341  |  alpha_x = 8.928
# s = 57.319 m  |  beta_x = 9.980  |  alpha_x = 8.769
# s = 57.452 m  |  beta_x = 8.726  |  alpha_x = 0.975
# s = 57.600 m  |  beta_x = 8.443  |  alpha_x = 0.942
# s = 57.685 m  |  beta_x = 8.284  |  alpha_x = 0.923
# s = 57.742 m  |  beta_x = 8.181  |  alpha_x = 0.910
# s = 57.777 m  |  beta_x = 8.117  |  alpha_x = 0.902
# s = 58.336 m  |  beta_x = 7.177  |  alpha_x = 0.777
# s = 59.666 m  |  beta_x = 5.506  |  alpha_x = 0.480
# s = 59.701 m  |  beta_x = 5.473  |  alpha_x = 0.472
# s = 59.757 m  |  beta_x = 5.420  |  alpha_x = 0.459
# s = 59.758 m  |  beta_x = 5.419  |  alpha_x = 0.459
# s = 59.815 m  |  beta_x = 5.368  |  alpha_x = 0.447
# s = 59.850 m  |  beta_x = 5.337  |  alpha_x = 0.439
# s = 61.739 m  |  beta_x = 4.477  |  alpha_x = 0.017
# s = 61.774 m  |  beta_x = 4.476  |  alpha_x = 0.009
# s = 61.831 m  |  beta_x = 4.475  |  alpha_x = -0.004
# s = 61.873 m  |  beta_x = 4.476  |  alpha_x = -0.013
# s = 61.916 m  |  beta_x = 4.478  |  alpha_x = -0.023
# s = 61.958 m  |  beta_x = 4.480  |  alpha_x = -0.032
# s = 62.015 m  |  beta_x = 4.484  |  alpha_x = -0.045
# s = 62.071 m  |  beta_x = 4.490  |  alpha_x = -0.058
# s = 62.106 m  |  beta_x = 4.494  |  alpha_x = -0.065
# s = 62.666 m  |  beta_x = 4.638  |  alpha_x = -0.191
# s = 63.996 m  |  beta_x = 5.539  |  alpha_x = -0.488
# s = 64.031 m  |  beta_x = 5.574  |  alpha_x = -0.495
# s = 64.087 m  |  beta_x = 5.631  |  alpha_x = -0.508
# s = 64.088 m  |  beta_x = 5.631  |  alpha_x = -0.508
# s = 64.145 m  |  beta_x = 5.689  |  alpha_x = -0.521
# s = 64.180 m  |  beta_x = 5.726  |  alpha_x = -0.529
# s = 66.069 m  |  beta_x = 8.522  |  alpha_x = -0.951
# s = 66.104 m  |  beta_x = 8.589  |  alpha_x = -0.959
# s = 66.161 m  |  beta_x = 8.698  |  alpha_x = -0.971
# s = 66.203 m  |  beta_x = 8.781  |  alpha_x = -0.981
# s = 66.356 m  |  beta_x = 9.085  |  alpha_x = -1.015
# s = 66.359 m  |  beta_x = 9.092  |  alpha_x = -1.016
# s = 66.492 m  |  beta_x = 10.379  |  alpha_x = -8.982
# s = 66.579 m  |  beta_x = 12.007  |  alpha_x = -9.668
# s = 66.832 m  |  beta_x = 11.902  |  alpha_x = 10.025
# s = 66.899 m  |  beta_x = 10.601  |  alpha_x = 9.455
# s = 66.919 m  |  beta_x = 10.218  |  alpha_x = 9.281
# s = 67.052 m  |  beta_x = 8.839  |  alpha_x = 1.423
# s = 67.115 m  |  beta_x = 8.662  |  alpha_x = 1.402
# s = 67.158 m  |  beta_x = 8.543  |  alpha_x = 1.387
# s = 67.200 m  |  beta_x = 8.426  |  alpha_x = 1.373
# s = 67.285 m  |  beta_x = 8.195  |  alpha_x = 1.344
# s = 67.342 m  |  beta_x = 8.044  |  alpha_x = 1.324
# s = 67.377 m  |  beta_x = 7.952  |  alpha_x = 1.312
# s = 67.936 m  |  beta_x = 6.589  |  alpha_x = 1.121
# s = 69.266 m  |  beta_x = 4.213  |  alpha_x = 0.666
# s = 69.301 m  |  beta_x = 4.167  |  alpha_x = 0.654
# s = 69.357 m  |  beta_x = 4.094  |  alpha_x = 0.635
# s = 69.358 m  |  beta_x = 4.093  |  alpha_x = 0.635
# s = 69.415 m  |  beta_x = 4.022  |  alpha_x = 0.615
# s = 69.450 m  |  beta_x = 3.980  |  alpha_x = 0.603
# s = 71.339 m  |  beta_x = 2.923  |  alpha_x = -0.044
# s = 71.374 m  |  beta_x = 2.926  |  alpha_x = -0.056
# s = 71.431 m  |  beta_x = 2.934  |  alpha_x = -0.075
# s = 71.473 m  |  beta_x = 2.941  |  alpha_x = -0.090
# s = 71.516 m  |  beta_x = 2.949  |  alpha_x = -0.104
# s = 71.558 m  |  beta_x = 2.959  |  alpha_x = -0.119
# s = 71.615 m  |  beta_x = 2.973  |  alpha_x = -0.138
# s = 71.671 m  |  beta_x = 2.990  |  alpha_x = -0.158
# s = 71.706 m  |  beta_x = 3.001  |  alpha_x = -0.170
# s = 72.266 m  |  beta_x = 3.299  |  alpha_x = -0.362
# s = 73.596 m  |  beta_x = 4.866  |  alpha_x = -0.817
# s = 73.631 m  |  beta_x = 4.924  |  alpha_x = -0.829
# s = 73.687 m  |  beta_x = 5.018  |  alpha_x = -0.848
# s = 73.688 m  |  beta_x = 5.020  |  alpha_x = -0.848
# s = 73.745 m  |  beta_x = 5.117  |  alpha_x = -0.868
# s = 73.780 m  |  beta_x = 5.178  |  alpha_x = -0.880
# s = 75.669 m  |  beta_x = 9.724  |  alpha_x = -1.526
# s = 75.704 m  |  beta_x = 9.831  |  alpha_x = -1.538
# s = 75.761 m  |  beta_x = 10.006  |  alpha_x = -1.557
# s = 75.846 m  |  beta_x = 10.273  |  alpha_x = -1.586
# s = 75.948 m  |  beta_x = 10.600  |  alpha_x = -1.621
# s = 76.001 m  |  beta_x = 10.775  |  alpha_x = -1.640
# s = 76.044 m  |  beta_x = 10.915  |  alpha_x = -1.654
# s = 76.126 m  |  beta_x = 11.188  |  alpha_x = -1.682
# s = 76.246 m  |  beta_x = 11.597  |  alpha_x = -1.723
# s = 76.385 m  |  beta_x = 12.086  |  alpha_x = -1.771
# s = 76.505 m  |  beta_x = 12.516  |  alpha_x = -1.812
# s = 76.551 m  |  beta_x = 12.683  |  alpha_x = -1.828
# s = 76.577 m  |  beta_x = 12.778  |  alpha_x = -1.837
# s = 76.707 m  |  beta_x = 13.260  |  alpha_x = -1.881
# s = 76.940 m  |  beta_x = 14.154  |  alpha_x = -1.961
# s = 77.262 m  |  beta_x = 17.495  |  alpha_x = -8.860
# s = 77.345 m  |  beta_x = 18.999  |  alpha_x = -9.238
# s = 77.402 m  |  beta_x = 20.077  |  alpha_x = -9.499
# s = 77.470 m  |  beta_x = 21.374  |  alpha_x = -9.804
# s = 77.792 m  |  beta_x = 23.476  |  alpha_x = 3.704
# s = 78.034 m  |  beta_x = 21.721  |  alpha_x = 3.552
# s = 78.336 m  |  beta_x = 19.630  |  alpha_x = 3.362
# s = 78.624 m  |  beta_x = 17.745  |  alpha_x = 3.182
# s = 78.833 m  |  beta_x = 16.440  |  alpha_x = 3.050
# s = 78.969 m  |  beta_x = 15.624  |  alpha_x = 2.965
# s = 79.050 m  |  beta_x = 15.150  |  alpha_x = 2.915
# s = 79.170 m  |  beta_x = 14.459  |  alpha_x = 2.840
# s = 79.309 m  |  beta_x = 13.678  |  alpha_x = 2.752
# s = 79.429 m  |  beta_x = 13.026  |  alpha_x = 2.677
# s = 79.519 m  |  beta_x = 12.552  |  alpha_x = 2.621
# s = 79.735 m  |  beta_x = 11.447  |  alpha_x = 2.485
# s = 79.752 m  |  beta_x = 11.366  |  alpha_x = 2.475
# s = 79.852 m  |  beta_x = 11.177  |  alpha_x = -0.564
# s = 79.952 m  |  beta_x = 11.596  |  alpha_x = -3.664
# s = 80.052 m  |  beta_x = 12.669  |  alpha_x = -7.161
# s = 80.152 m  |  beta_x = 14.285  |  alpha_x = -8.415
# s = 80.252 m  |  beta_x = 16.018  |  alpha_x = -8.918
# s = 80.352 m  |  beta_x = 17.638  |  alpha_x = -6.309
# s = 80.452 m  |  beta_x = 18.464  |  alpha_x = -1.874
# s = 80.552 m  |  beta_x = 18.375  |  alpha_x = 2.748
# s = 80.652 m  |  beta_x = 17.484  |  alpha_x = 5.001
# s = 80.752 m  |  beta_x = 16.499  |  alpha_x = 4.852
# s = 80.852 m  |  beta_x = 15.543  |  alpha_x = 4.703
# s = 80.952 m  |  beta_x = 14.618  |  alpha_x = 4.554
# s = 81.052 m  |  beta_x = 13.722  |  alpha_x = 4.406
# s = 81.152 m  |  beta_x = 0.174  |  alpha_x = -0.004
# s = 81.252 m  |  beta_x = 0.151  |  alpha_x = -1.996
# s = 81.352 m  |  beta_x = 0.767  |  alpha_x = -6.779
# s = 81.452 m  |  beta_x = 2.349  |  alpha_x = -14.536
# s = 81.552 m  |  beta_x = 5.372  |  alpha_x = -25.416
# s = 81.652 m  |  beta_x = 10.346  |  alpha_x = -39.558
# s = 81.752 m  |  beta_x = 17.788  |  alpha_x = -57.019
# s = 81.852 m  |  beta_x = 28.122  |  alpha_x = -77.560
# s = 81.952 m  |  beta_x = 41.406  |  alpha_x = -100.148
# s = 82.052 m  |  beta_x = 56.767  |  alpha_x = -122.196
# s = 82.152 m  |  beta_x = 71.905  |  alpha_x = -139.366
# s = 82.252 m  |  beta_x = 83.743  |  alpha_x = -147.531
# s = 82.352 m  |  beta_x = 90.445  |  alpha_x = -145.963
# s = 82.452 m  |  beta_x = 92.454  |  alpha_x = -137.577
# s = 82.552 m  |  beta_x = 91.403  |  alpha_x = -126.111
# s = 82.652 m  |  beta_x = 88.792  |  alpha_x = -114.134
# s = 82.752 m  |  beta_x = 85.574  |  alpha_x = -102.904
# s = 82.852 m  |  beta_x = 82.252  |  alpha_x = -92.867
# s = 82.952 m  |  beta_x = 79.065  |  alpha_x = -84.084
# s = 83.052 m  |  beta_x = 77.601  |  alpha_x = -77.463
# s = 83.152 m  |  beta_x = 85.533  |  alpha_x = -77.548
# s = 83.252 m  |  beta_x = 93.458  |  alpha_x = -77.612
# s = 83.352 m  |  beta_x = 101.377  |  alpha_x = -77.663
# s = 83.452 m  |  beta_x = 109.292  |  alpha_x = -77.703
# s = 83.552 m  |  beta_x = 117.204  |  alpha_x = -77.736
# s = 83.652 m  |  beta_x = 125.113  |  alpha_x = -77.763
# s = 83.752 m  |  beta_x = 133.020  |  alpha_x = -77.785
# s = 83.852 m  |  beta_x = 140.925  |  alpha_x = -77.803
# s = 83.952 m  |  beta_x = 396.782  |  alpha_x = -150.248
# s = 84.052 m  |  beta_x = 2627.743  |  alpha_x = -49.927
# s = 84.152 m  |  beta_x = 541.083  |  alpha_x = 183.919
# s = 84.252 m  |  beta_x = 85.732  |  alpha_x = 55.529
# s = 84.352 m  |  beta_x = 80.079  |  alpha_x = 55.524
# s = 84.452 m  |  beta_x = 74.425  |  alpha_x = 55.517
# s = 84.552 m  |  beta_x = 68.771  |  alpha_x = 55.509
# s = 84.652 m  |  beta_x = 63.116  |  alpha_x = 55.499
# s = 84.752 m  |  beta_x = 57.459  |  alpha_x = 55.485
# s = 84.852 m  |  beta_x = 51.801  |  alpha_x = 55.467
# s = 84.952 m  |  beta_x = 46.141  |  alpha_x = 55.441
# s = 85.052 m  |  beta_x = 40.477  |  alpha_x = 55.404
# s = 85.152 m  |  beta_x = 36.972  |  alpha_x = 57.620
# s = 85.252 m  |  beta_x = 35.536  |  alpha_x = 62.806
# s = 85.352 m  |  beta_x = 33.523  |  alpha_x = 68.646
# s = 85.452 m  |  beta_x = 30.664  |  alpha_x = 75.004
# s = 85.552 m  |  beta_x = 26.523  |  alpha_x = 81.160
# s = 85.652 m  |  beta_x = 20.379  |  alpha_x = 84.338
# s = 85.752 m  |  beta_x = 11.460  |  alpha_x = 75.112
# s = 85.852 m  |  beta_x = 2.092  |  alpha_x = 35.670
# s = 85.952 m  |  beta_x = 1.004  |  alpha_x = -24.173
# s = 86.052 m  |  beta_x = 11.000  |  alpha_x = -73.601
# s = 86.152 m  |  beta_x = 29.953  |  alpha_x = -111.957
# s = 86.252 m  |  beta_x = 58.606  |  alpha_x = -146.879
# s = 86.352 m  |  beta_x = 100.479  |  alpha_x = -183.179
# s = 86.452 m  |  beta_x = 161.728  |  alpha_x = -223.649
# s = 86.552 m  |  beta_x = 252.128  |  alpha_x = -269.959
# s = 86.652 m  |  beta_x = 387.033  |  alpha_x = -322.620
# s = 86.752 m  |  beta_x = 589.215  |  alpha_x = -379.086
# s = 86.852 m  |  beta_x = 876.541  |  alpha_x = -424.018
# s = 86.952 m  |  beta_x = 1164.613  |  alpha_x = -400.947
# s = 87.052 m  |  beta_x = 1241.729  |  alpha_x = -325.907
# s = 87.152 m  |  beta_x = 1307.491  |  alpha_x = -334.388
# s = 87.252 m  |  beta_x = 1374.930  |  alpha_x = -342.865
# s = 87.352 m  |  beta_x = 1444.044  |  alpha_x = -351.337
# s = 87.452 m  |  beta_x = 1514.831  |  alpha_x = -359.804
# s = 87.552 m  |  beta_x = 1587.290  |  alpha_x = -368.266
# s = 87.652 m  |  beta_x = 1661.418  |  alpha_x = -376.722
# s = 87.752 m  |  beta_x = 1477.692  |  alpha_x = -630.158
# s = 87.852 m  |  beta_x = 531.884  |  alpha_x = -375.315
# s = 87.952 m  |  beta_x = 193.152  |  alpha_x = -182.788
# s = 88.052 m  |  beta_x = 127.013  |  alpha_x = -128.979
# s = 88.152 m  |  beta_x = 140.052  |  alpha_x = -129.024
# s = 88.252 m  |  beta_x = 153.089  |  alpha_x = -129.060
# s = 88.352 m  |  beta_x = 405.278  |  alpha_x = -235.358
# s = 88.452 m  |  beta_x = 3449.457  |  alpha_x = -863.713
# s = 88.552 m  |  beta_x = 5380.697  |  alpha_x = 351.926
# s = 88.652 m  |  beta_x = 3688.832  |  alpha_x = 910.882
# s = 88.752 m  |  beta_x = 3553.669  |  alpha_x = 899.740
# s = 88.852 m  |  beta_x = 3419.018  |  alpha_x = 888.152
# s = 88.952 m  |  beta_x = 3284.948  |  alpha_x = 876.100
# s = 89.052 m  |  beta_x = 3151.536  |  alpha_x = 863.567
# s = 89.152 m  |  beta_x = 1947.616  |  alpha_x = 647.519
# s = 89.252 m  |  beta_x = 1098.169  |  alpha_x = 457.250
# s = 89.352 m  |  beta_x = 680.637  |  alpha_x = 347.315
# s = 89.452 m  |  beta_x = 445.553  |  alpha_x = 275.268
# s = 89.552 m  |  beta_x = 300.858  |  alpha_x = 223.873
# s = 89.652 m  |  beta_x = 206.644  |  alpha_x = 185.320
# s = 89.752 m  |  beta_x = 142.866  |  alpha_x = 155.404
# s = 89.852 m  |  beta_x = 98.407  |  alpha_x = 131.541
# s = 89.952 m  |  beta_x = 66.667  |  alpha_x = 111.939
# s = 90.052 m  |  beta_x = 43.541  |  alpha_x = 95.163
# s = 90.152 m  |  beta_x = 26.384  |  alpha_x = 79.720
# s = 90.252 m  |  beta_x = 13.500  |  alpha_x = 63.221
# s = 90.352 m  |  beta_x = 4.139  |  alpha_x = 39.973
# s = 90.452 m  |  beta_x = 0.002  |  alpha_x = -0.215
# s = 90.552 m  |  beta_x = 3.782  |  alpha_x = -38.007
# s = 90.652 m  |  beta_x = 9.492  |  alpha_x = -48.834
# s = 90.752 m  |  beta_x = 13.948  |  alpha_x = -48.793
# s = 90.852 m  |  beta_x = 17.321  |  alpha_x = -46.248
# s = 90.952 m  |  beta_x = 19.943  |  alpha_x = -43.271
# s = 91.052 m  |  beta_x = 23.561  |  alpha_x = -42.315
# s = 91.152 m  |  beta_x = 27.962  |  alpha_x = -42.433
# s = 91.252 m  |  beta_x = 32.356  |  alpha_x = -42.511
# s = 91.352 m  |  beta_x = 36.746  |  alpha_x = -42.564
# s = 91.452 m  |  beta_x = 41.131  |  alpha_x = -42.602
# s = 91.552 m  |  beta_x = 45.515  |  alpha_x = -42.631
# s = 91.652 m  |  beta_x = 49.896  |  alpha_x = -42.654
# s = 91.752 m  |  beta_x = 54.276  |  alpha_x = -42.671
# s = 91.852 m  |  beta_x = 58.655  |  alpha_x = -42.685
# s = 91.952 m  |  beta_x = 543.175  |  alpha_x = -177.534
# s = 92.052 m  |  beta_x = 1268.595  |  alpha_x = 137.138
# s = 92.152 m  |  beta_x = 132.118  |  alpha_x = 72.318
# s = 92.252 m  |  beta_x = 56.639  |  alpha_x = 42.788
# s = 92.352 m  |  beta_x = 52.260  |  alpha_x = 42.782
# s = 92.452 m  |  beta_x = 47.880  |  alpha_x = 42.774
# s = 92.552 m  |  beta_x = 43.498  |  alpha_x = 42.763
# s = 92.652 m  |  beta_x = 39.114  |  alpha_x = 42.746
# s = 92.752 m  |  beta_x = 34.728  |  alpha_x = 42.722
# s = 92.852 m  |  beta_x = 30.337  |  alpha_x = 42.685
# s = 92.952 m  |  beta_x = 25.939  |  alpha_x = 42.626
# s = 93.052 m  |  beta_x = 21.532  |  alpha_x = 42.522
# s = 93.152 m  |  beta_x = 18.911  |  alpha_x = 45.173
# s = 93.252 m  |  beta_x = 15.978  |  alpha_x = 48.244
# s = 93.352 m  |  beta_x = 12.130  |  alpha_x = 50.288
# s = 93.452 m  |  beta_x = 6.954  |  alpha_x = 46.947
# s = 93.552 m  |  beta_x = 1.186  |  alpha_x = 23.085
# s = 93.652 m  |  beta_x = 1.077  |  alpha_x = -21.488
# s = 93.752 m  |  beta_x = 8.056  |  alpha_x = -51.358
# s = 93.852 m  |  beta_x = 18.864  |  alpha_x = -69.783
# s = 93.952 m  |  beta_x = 33.375  |  alpha_x = -85.137
# s = 94.052 m  |  beta_x = 52.828  |  alpha_x = -100.829
# s = 94.152 m  |  beta_x = 79.310  |  alpha_x = -118.601
# s = 94.252 m  |  beta_x = 116.080  |  alpha_x = -139.872
# s = 94.352 m  |  beta_x = 168.354  |  alpha_x = -166.288
# s = 94.452 m  |  beta_x = 244.896  |  alpha_x = -200.190
# s = 94.552 m  |  beta_x = 361.496  |  alpha_x = -245.414
# s = 94.652 m  |  beta_x = 549.614  |  alpha_x = -309.192
# s = 94.752 m  |  beta_x = 881.934  |  alpha_x = -407.665
# s = 94.852 m  |  beta_x = 1559.359  |  alpha_x = -582.588
# s = 94.952 m  |  beta_x = 3013.848  |  alpha_x = -884.735
# s = 95.052 m  |  beta_x = 3454.533  |  alpha_x = -933.986
# s = 95.152 m  |  beta_x = 3588.203  |  alpha_x = -944.568
# s = 95.252 m  |  beta_x = 3722.142  |  alpha_x = -954.677
# s = 95.352 m  |  beta_x = 3856.304  |  alpha_x = -964.335
# s = 95.452 m  |  beta_x = 4605.811  |  alpha_x = -1031.612
# s = 95.552 m  |  beta_x = 6597.490  |  alpha_x = 603.337
# s = 95.652 m  |  beta_x = 1077.968  |  alpha_x = 444.208
# s = 95.752 m  |  beta_x = 194.960  |  alpha_x = 147.710
# s = 95.852 m  |  beta_x = 146.817  |  alpha_x = 129.238
# s = 95.952 m  |  beta_x = 133.793  |  alpha_x = 129.229
# s = 96.052 m  |  beta_x = 127.777  |  alpha_x = 134.199
# s = 96.152 m  |  beta_x = 312.801  |  alpha_x = 260.096
# s = 96.252 m  |  beta_x = 1018.086  |  alpha_x = 580.733
# s = 96.352 m  |  beta_x = 2073.899  |  alpha_x = 573.203
# s = 96.452 m  |  beta_x = 2004.975  |  alpha_x = 459.568
# s = 96.552 m  |  beta_x = 1914.491  |  alpha_x = 449.124
# s = 96.652 m  |  beta_x = 1826.069  |  alpha_x = 438.674
# s = 96.752 m  |  beta_x = 1739.711  |  alpha_x = 428.218
# s = 96.852 m  |  beta_x = 1655.420  |  alpha_x = 417.755
# s = 96.952 m  |  beta_x = 1573.199  |  alpha_x = 407.286
# s = 97.052 m  |  beta_x = 1440.178  |  alpha_x = 402.511
# s = 97.152 m  |  beta_x = 888.612  |  alpha_x = 365.906
# s = 97.252 m  |  beta_x = 553.076  |  alpha_x = 309.923
# s = 97.352 m  |  beta_x = 359.865  |  alpha_x = 264.066
# s = 97.452 m  |  beta_x = 238.175  |  alpha_x = 225.076
# s = 97.552 m  |  beta_x = 156.691  |  alpha_x = 190.412
# s = 97.652 m  |  beta_x = 100.381  |  alpha_x = 158.851
# s = 97.752 m  |  beta_x = 60.963  |  alpha_x = 129.454
# s = 97.852 m  |  beta_x = 33.423  |  alpha_x = 100.932
# s = 97.952 m  |  beta_x = 14.726  |  alpha_x = 71.191
# s = 98.052 m  |  beta_x = 3.489  |  alpha_x = 37.028
# s = 98.152 m  |  beta_x = 0.043  |  alpha_x = -4.204
# s = 98.252 m  |  beta_x = 4.907  |  alpha_x = -46.079
# s = 98.352 m  |  beta_x = 14.167  |  alpha_x = -71.615
# s = 98.452 m  |  beta_x = 22.312  |  alpha_x = -78.339
# s = 98.552 m  |  beta_x = 27.980  |  alpha_x = -75.967
# s = 98.652 m  |  beta_x = 31.788  |  alpha_x = -70.797
# s = 98.752 m  |  beta_x = 34.388  |  alpha_x = -65.199
# s = 98.852 m  |  beta_x = 36.196  |  alpha_x = -59.925
# s = 98.952 m  |  beta_x = 37.580  |  alpha_x = -55.279
# s = 99.052 m  |  beta_x = 43.260  |  alpha_x = -55.356
# s = 99.152 m  |  beta_x = 48.933  |  alpha_x = -55.407
# s = 99.252 m  |  beta_x = 54.601  |  alpha_x = -55.442
# s = 99.352 m  |  beta_x = 60.264  |  alpha_x = -55.467
# s = 99.452 m  |  beta_x = 65.925  |  alpha_x = -55.485
# s = 99.552 m  |  beta_x = 71.584  |  alpha_x = -55.499
# s = 99.652 m  |  beta_x = 77.241  |  alpha_x = -55.510
# s = 99.752 m  |  beta_x = 82.897  |  alpha_x = -55.518
# s = 99.852 m  |  beta_x = 154.271  |  alpha_x = -80.843
# s = 99.952 m  |  beta_x = 1766.127  |  alpha_x = -282.604
# s = 100.052 m  |  beta_x = 1533.606  |  alpha_x = 302.902
# s = 100.152 m  |  beta_x = 144.406  |  alpha_x = 77.564
# s = 100.252 m  |  beta_x = 136.489  |  alpha_x = 77.526
# s = 100.352 m  |  beta_x = 128.570  |  alpha_x = 77.481
# s = 100.452 m  |  beta_x = 120.646  |  alpha_x = 77.427
# s = 100.552 m  |  beta_x = 112.718  |  alpha_x = 77.363
# s = 100.652 m  |  beta_x = 104.783  |  alpha_x = 77.285
# s = 100.752 m  |  beta_x = 96.842  |  alpha_x = 77.188
# s = 100.852 m  |  beta_x = 88.892  |  alpha_x = 77.067
# s = 100.952 m  |  beta_x = 80.930  |  alpha_x = 76.912
# s = 101.052 m  |  beta_x = 76.774  |  alpha_x = 79.344
# s = 101.152 m  |  beta_x = 79.441  |  alpha_x = 87.038
# s = 101.252 m  |  beta_x = 82.054  |  alpha_x = 95.597
# s = 101.352 m  |  beta_x = 84.301  |  alpha_x = 104.796
# s = 101.452 m  |  beta_x = 85.613  |  alpha_x = 114.000
# s = 101.552 m  |  beta_x = 85.068  |  alpha_x = 121.876
# s = 101.652 m  |  beta_x = 81.474  |  alpha_x = 126.243
# s = 101.752 m  |  beta_x = 73.923  |  alpha_x = 124.633
# s = 101.852 m  |  beta_x = 62.698  |  alpha_x = 115.846
# s = 101.952 m  |  beta_x = 49.532  |  alpha_x = 101.167
# s = 102.052 m  |  beta_x = 36.617  |  alpha_x = 83.547
# s = 102.152 m  |  beta_x = 25.457  |  alpha_x = 65.749
# s = 102.252 m  |  beta_x = 16.627  |  alpha_x = 49.440
# s = 102.352 m  |  beta_x = 10.094  |  alpha_x = 35.343
# s = 102.452 m  |  beta_x = 5.564  |  alpha_x = 23.669
# s = 102.552 m  |  beta_x = 2.664  |  alpha_x = 14.416
# s = 102.652 m  |  beta_x = 1.015  |  alpha_x = 7.508
# s = 102.752 m  |  beta_x = 0.259  |  alpha_x = 2.848
# s = 102.852 m  |  beta_x = 0.076  |  alpha_x = 0.334
# s = 102.952 m  |  beta_x = 8.975  |  alpha_x = -2.721
# s = 103.052 m  |  beta_x = 9.528  |  alpha_x = -2.814
# s = 103.152 m  |  beta_x = 10.100  |  alpha_x = -2.908
# s = 103.252 m  |  beta_x = 10.691  |  alpha_x = -3.001
# s = 103.352 m  |  beta_x = 11.301  |  alpha_x = -3.095
# s = 103.452 m  |  beta_x = 11.929  |  alpha_x = -3.189
# s = 103.552 m  |  beta_x = 12.576  |  alpha_x = -3.282
# s = 103.652 m  |  beta_x = 13.242  |  alpha_x = -3.376
# s = 103.752 m  |  beta_x = 13.927  |  alpha_x = -3.470
# s = 103.852 m  |  beta_x = 14.630  |  alpha_x = -3.563
# s = 103.952 m  |  beta_x = 15.352  |  alpha_x = -3.657
# s = 104.052 m  |  beta_x = 16.093  |  alpha_x = -3.750
# s = 104.152 m  |  beta_x = 16.923  |  alpha_x = -5.385
# s = 104.252 m  |  beta_x = 18.366  |  alpha_x = -9.141
# s = 104.352 m  |  beta_x = 20.628  |  alpha_x = -13.619
# s = 104.452 m  |  beta_x = 23.858  |  alpha_x = -18.031
# s = 104.552 m  |  beta_x = 27.601  |  alpha_x = -19.398
# s = 104.652 m  |  beta_x = 31.599  |  alpha_x = -19.626
# s = 104.752 m  |  beta_x = 34.903  |  alpha_x = -13.175
# s = 104.852 m  |  beta_x = 36.792  |  alpha_x = -5.581
# s = 104.952 m  |  beta_x = 37.103  |  alpha_x = 2.498
# s = 104.957 m  |  beta_x = 37.072  |  alpha_x = 2.952
# s = 105.064 m  |  beta_x = 36.444  |  alpha_x = 2.924
# s = 105.157 m  |  beta_x = 35.905  |  alpha_x = 2.900
# s = 105.242 m  |  beta_x = 35.414  |  alpha_x = 2.877
# s = 106.394 m  |  beta_x = 29.129  |  alpha_x = 2.575
# s = 106.452 m  |  beta_x = 28.834  |  alpha_x = 2.560
# s = 106.502 m  |  beta_x = 28.578  |  alpha_x = 2.547
# s = 106.572 m  |  beta_x = 28.223  |  alpha_x = 2.529
# s = 108.707 m  |  beta_x = 18.618  |  alpha_x = 1.969
# s = 108.749 m  |  beta_x = 18.453  |  alpha_x = 1.958
# s = 108.981 m  |  beta_x = 17.559  |  alpha_x = 1.898
# s = 109.303 m  |  beta_x = 19.560  |  alpha_x = -8.477
# s = 109.510 m  |  beta_x = 23.232  |  alpha_x = -9.249
# s = 109.834 m  |  beta_x = 25.677  |  alpha_x = 2.067
# s = 109.990 m  |  beta_x = 25.035  |  alpha_x = 2.035
# s = 110.125 m  |  beta_x = 24.489  |  alpha_x = 2.007
# s = 110.430 m  |  beta_x = 23.286  |  alpha_x = 1.945
# s = 110.570 m  |  beta_x = 22.746  |  alpha_x = 1.916
# s = 110.654 m  |  beta_x = 22.424  |  alpha_x = 1.899
# s = 110.696 m  |  beta_x = 22.263  |  alpha_x = 1.890
# s = 110.739 m  |  beta_x = 22.103  |  alpha_x = 1.881
# s = 111.206 m  |  beta_x = 20.390  |  alpha_x = 1.785
# s = 111.246 m  |  beta_x = 20.248  |  alpha_x = 1.777
# s = 111.326 m  |  beta_x = 19.965  |  alpha_x = 1.761
# s = 112.032 m  |  beta_x = 17.580  |  alpha_x = 1.616
# s = 112.152 m  |  beta_x = 17.196  |  alpha_x = 1.591
# s = 112.292 m  |  beta_x = 16.754  |  alpha_x = 1.562
# s = 112.412 m  |  beta_x = 16.382  |  alpha_x = 1.538
# s = 112.663 m  |  beta_x = 15.624  |  alpha_x = 1.486
# s = 112.748 m  |  beta_x = 15.373  |  alpha_x = 1.469
# s = 112.804 m  |  beta_x = 15.208  |  alpha_x = 1.457
# s = 112.839 m  |  beta_x = 15.106  |  alpha_x = 1.450
# s = 113.399 m  |  beta_x = 13.547  |  alpha_x = 1.335
# s = 114.729 m  |  beta_x = 10.358  |  alpha_x = 1.063
# s = 114.764 m  |  beta_x = 10.283  |  alpha_x = 1.056
# s = 114.820 m  |  beta_x = 10.165  |  alpha_x = 1.044
# s = 114.847 m  |  beta_x = 10.109  |  alpha_x = 1.039
# s = 114.904 m  |  beta_x = 9.992  |  alpha_x = 1.027
# s = 114.939 m  |  beta_x = 9.920  |  alpha_x = 1.020
# s = 116.828 m  |  beta_x = 6.798  |  alpha_x = 0.632
# s = 116.863 m  |  beta_x = 6.754  |  alpha_x = 0.625
# s = 116.920 m  |  beta_x = 6.684  |  alpha_x = 0.613
# s = 116.962 m  |  beta_x = 6.633  |  alpha_x = 0.605
# s = 117.005 m  |  beta_x = 6.582  |  alpha_x = 0.596
# s = 117.062 m  |  beta_x = 6.514  |  alpha_x = 0.584
# s = 117.112 m  |  beta_x = 6.456  |  alpha_x = 0.574
# s = 117.182 m  |  beta_x = 6.376  |  alpha_x = 0.559
# s = 117.225 m  |  beta_x = 6.329  |  alpha_x = 0.551
# s = 117.261 m  |  beta_x = 6.289  |  alpha_x = 0.543
# s = 117.318 m  |  beta_x = 6.228  |  alpha_x = 0.531
# s = 117.353 m  |  beta_x = 6.191  |  alpha_x = 0.524
# s = 117.913 m  |  beta_x = 5.669  |  alpha_x = 0.409
# s = 119.242 m  |  beta_x = 4.945  |  alpha_x = 0.136
# s = 119.277 m  |  beta_x = 4.935  |  alpha_x = 0.128
# s = 119.334 m  |  beta_x = 4.922  |  alpha_x = 0.117
# s = 119.361 m  |  beta_x = 4.915  |  alpha_x = 0.111
# s = 119.417 m  |  beta_x = 4.903  |  alpha_x = 0.100
# s = 119.452 m  |  beta_x = 4.897  |  alpha_x = 0.092
# s = 121.342 m  |  beta_x = 5.282  |  alpha_x = -0.296
# s = 121.377 m  |  beta_x = 5.303  |  alpha_x = -0.303
# s = 121.433 m  |  beta_x = 5.338  |  alpha_x = -0.315
# s = 121.476 m  |  beta_x = 5.365  |  alpha_x = -0.324
# s = 121.518 m  |  beta_x = 5.393  |  alpha_x = -0.333
# s = 121.561 m  |  beta_x = 5.421  |  alpha_x = -0.341
# s = 121.713 m  |  beta_x = 5.530  |  alpha_x = -0.373
# s = 121.716 m  |  beta_x = 5.532  |  alpha_x = -0.373
# s = 121.920 m  |  beta_x = 6.749  |  alpha_x = -5.941
# s = 121.955 m  |  beta_x = 7.172  |  alpha_x = -6.129
# s = 122.011 m  |  beta_x = 7.876  |  alpha_x = -6.431
# s = 122.215 m  |  beta_x = 9.029  |  alpha_x = 1.132
# s = 122.263 m  |  beta_x = 8.921  |  alpha_x = 1.120
# s = 122.348 m  |  beta_x = 8.733  |  alpha_x = 1.098
# s = 122.404 m  |  beta_x = 8.610  |  alpha_x = 1.084
# s = 122.439 m  |  beta_x = 8.534  |  alpha_x = 1.075
# s = 122.999 m  |  beta_x = 7.409  |  alpha_x = 0.934
# s = 124.329 m  |  beta_x = 5.372  |  alpha_x = 0.598
# s = 124.364 m  |  beta_x = 5.330  |  alpha_x = 0.590
# s = 124.420 m  |  beta_x = 5.264  |  alpha_x = 0.575
# s = 124.447 m  |  beta_x = 5.234  |  alpha_x = 0.568
# s = 124.504 m  |  beta_x = 5.170  |  alpha_x = 0.554
# s = 124.539 m  |  beta_x = 5.132  |  alpha_x = 0.545
# s = 126.428 m  |  beta_x = 3.973  |  alpha_x = 0.068
# s = 126.463 m  |  beta_x = 3.968  |  alpha_x = 0.059
# s = 126.520 m  |  beta_x = 3.962  |  alpha_x = 0.045
# s = 126.577 m  |  beta_x = 3.958  |  alpha_x = 0.030
# s = 126.627 m  |  beta_x = 3.956  |  alpha_x = 0.018
# s = 126.697 m  |  beta_x = 3.954  |  alpha_x = -0.000
# s = 126.740 m  |  beta_x = 3.955  |  alpha_x = -0.011
# s = 126.782 m  |  beta_x = 3.956  |  alpha_x = -0.022
# s = 126.825 m  |  beta_x = 3.959  |  alpha_x = -0.032
# s = 126.861 m  |  beta_x = 3.961  |  alpha_x = -0.042
# s = 126.918 m  |  beta_x = 3.967  |  alpha_x = -0.056
# s = 126.953 m  |  beta_x = 3.971  |  alpha_x = -0.065
# s = 127.513 m  |  beta_x = 4.123  |  alpha_x = -0.206
# s = 128.842 m  |  beta_x = 5.118  |  alpha_x = -0.542
# s = 128.877 m  |  beta_x = 5.156  |  alpha_x = -0.551
# s = 128.934 m  |  beta_x = 5.219  |  alpha_x = -0.565
# s = 128.961 m  |  beta_x = 5.250  |  alpha_x = -0.572
# s = 129.017 m  |  beta_x = 5.315  |  alpha_x = -0.586
# s = 129.052 m  |  beta_x = 5.356  |  alpha_x = -0.595
# s = 130.942 m  |  beta_x = 8.507  |  alpha_x = -1.072
# s = 130.977 m  |  beta_x = 8.582  |  alpha_x = -1.081
# s = 131.033 m  |  beta_x = 8.705  |  alpha_x = -1.095
# s = 131.076 m  |  beta_x = 8.798  |  alpha_x = -1.106
# s = 131.228 m  |  beta_x = 9.142  |  alpha_x = -1.144
# s = 131.231 m  |  beta_x = 9.149  |  alpha_x = -1.145
# s = 131.435 m  |  beta_x = 11.403  |  alpha_x = -10.558
# s = 131.526 m  |  beta_x = 13.409  |  alpha_x = -11.457
# s = 131.730 m  |  beta_x = 15.577  |  alpha_x = 1.486
# s = 131.863 m  |  beta_x = 15.187  |  alpha_x = 1.458
# s = 131.948 m  |  beta_x = 14.941  |  alpha_x = 1.441
# s = 132.004 m  |  beta_x = 14.779  |  alpha_x = 1.429
# s = 132.039 m  |  beta_x = 14.679  |  alpha_x = 1.422
# s = 132.599 m  |  beta_x = 13.151  |  alpha_x = 1.307
# s = 133.929 m  |  beta_x = 10.039  |  alpha_x = 1.034
# s = 133.964 m  |  beta_x = 9.966  |  alpha_x = 1.027
# s = 134.020 m  |  beta_x = 9.851  |  alpha_x = 1.015
# s = 134.047 m  |  beta_x = 9.797  |  alpha_x = 1.009
# s = 134.104 m  |  beta_x = 9.683  |  alpha_x = 0.998
# s = 134.139 m  |  beta_x = 9.614  |  alpha_x = 0.991
# s = 136.028 m  |  beta_x = 6.605  |  alpha_x = 0.602
# s = 136.063 m  |  beta_x = 6.563  |  alpha_x = 0.595
# s = 136.120 m  |  beta_x = 6.496  |  alpha_x = 0.583
# s = 136.177 m  |  beta_x = 6.430  |  alpha_x = 0.571
# s = 136.227 m  |  beta_x = 6.373  |  alpha_x = 0.561
# s = 136.297 m  |  beta_x = 6.296  |  alpha_x = 0.546
# s = 136.340 m  |  beta_x = 6.250  |  alpha_x = 0.537
# s = 136.381 m  |  beta_x = 6.205  |  alpha_x = 0.529
# s = 136.461 m  |  beta_x = 6.122  |  alpha_x = 0.512
# s = 136.518 m  |  beta_x = 6.065  |  alpha_x = 0.501
# s = 136.553 m  |  beta_x = 6.030  |  alpha_x = 0.494
# s = 137.113 m  |  beta_x = 5.542  |  alpha_x = 0.378
# s = 138.442 m  |  beta_x = 4.900  |  alpha_x = 0.104
# s = 138.477 m  |  beta_x = 4.893  |  alpha_x = 0.097
# s = 138.534 m  |  beta_x = 4.883  |  alpha_x = 0.085
# s = 138.561 m  |  beta_x = 4.879  |  alpha_x = 0.080
# s = 138.617 m  |  beta_x = 4.870  |  alpha_x = 0.068
# s = 138.652 m  |  beta_x = 4.866  |  alpha_x = 0.061
# s = 140.542 m  |  beta_x = 5.371  |  alpha_x = -0.328
# s = 140.577 m  |  beta_x = 5.394  |  alpha_x = -0.336
# s = 140.633 m  |  beta_x = 5.433  |  alpha_x = -0.347
# s = 140.676 m  |  beta_x = 5.463  |  alpha_x = -0.356
# s = 140.828 m  |  beta_x = 5.576  |  alpha_x = -0.388
# s = 140.831 m  |  beta_x = 5.579  |  alpha_x = -0.388
# s = 141.035 m  |  beta_x = 6.667  |  alpha_x = -5.222
# s = 141.126 m  |  beta_x = 7.654  |  alpha_x = -5.608
# s = 141.330 m  |  beta_x = 8.777  |  alpha_x = 0.381
# s = 141.463 m  |  beta_x = 8.679  |  alpha_x = 0.364
# s = 141.548 m  |  beta_x = 8.618  |  alpha_x = 0.353
# s = 141.604 m  |  beta_x = 8.578  |  alpha_x = 0.345
# s = 141.639 m  |  beta_x = 8.554  |  alpha_x = 0.341
# s = 142.199 m  |  beta_x = 8.213  |  alpha_x = 0.268
# s = 143.529 m  |  beta_x = 7.731  |  alpha_x = 0.095
# s = 143.564 m  |  beta_x = 7.724  |  alpha_x = 0.090
# s = 143.620 m  |  beta_x = 7.715  |  alpha_x = 0.083
# s = 143.647 m  |  beta_x = 7.710  |  alpha_x = 0.079
# s = 143.704 m  |  beta_x = 7.702  |  alpha_x = 0.072
# s = 143.739 m  |  beta_x = 7.697  |  alpha_x = 0.067
# s = 145.628 m  |  beta_x = 7.907  |  alpha_x = -0.179
# s = 145.663 m  |  beta_x = 7.919  |  alpha_x = -0.183
# s = 145.720 m  |  beta_x = 7.940  |  alpha_x = -0.190
# s = 145.777 m  |  beta_x = 7.963  |  alpha_x = -0.198
# s = 145.827 m  |  beta_x = 7.983  |  alpha_x = -0.205
# s = 145.897 m  |  beta_x = 8.012  |  alpha_x = -0.214
# s = 145.940 m  |  beta_x = 8.031  |  alpha_x = -0.219
# s = 146.061 m  |  beta_x = 8.086  |  alpha_x = -0.235
# s = 146.118 m  |  beta_x = 8.113  |  alpha_x = -0.242
# s = 146.153 m  |  beta_x = 8.130  |  alpha_x = -0.247
# s = 146.713 m  |  beta_x = 8.447  |  alpha_x = -0.320
# s = 148.042 m  |  beta_x = 9.528  |  alpha_x = -0.493
# s = 148.077 m  |  beta_x = 9.563  |  alpha_x = -0.498
# s = 148.134 m  |  beta_x = 9.620  |  alpha_x = -0.505
# s = 148.161 m  |  beta_x = 9.647  |  alpha_x = -0.508
# s = 148.217 m  |  beta_x = 9.705  |  alpha_x = -0.516
# s = 148.252 m  |  beta_x = 9.741  |  alpha_x = -0.520
# s = 150.142 m  |  beta_x = 12.172  |  alpha_x = -0.766
# s = 150.177 m  |  beta_x = 12.225  |  alpha_x = -0.771
# s = 150.233 m  |  beta_x = 12.313  |  alpha_x = -0.778
# s = 150.276 m  |  beta_x = 12.379  |  alpha_x = -0.783
# s = 150.428 m  |  beta_x = 12.621  |  alpha_x = -0.803
# s = 150.431 m  |  beta_x = 12.626  |  alpha_x = -0.804
# s = 150.635 m  |  beta_x = 15.105  |  alpha_x = -11.988
# s = 150.726 m  |  beta_x = 17.369  |  alpha_x = -12.861
# s = 150.930 m  |  beta_x = 19.846  |  alpha_x = 1.361
# s = 151.012 m  |  beta_x = 19.623  |  alpha_x = 1.349
# s = 151.063 m  |  beta_x = 19.488  |  alpha_x = 1.342
# s = 151.148 m  |  beta_x = 19.261  |  alpha_x = 1.330
# s = 151.204 m  |  beta_x = 19.111  |  alpha_x = 1.321
# s = 151.239 m  |  beta_x = 19.018  |  alpha_x = 1.316
# s = 151.478 m  |  beta_x = 18.399  |  alpha_x = 1.282
# s = 153.129 m  |  beta_x = 14.556  |  alpha_x = 1.046
# s = 153.164 m  |  beta_x = 14.483  |  alpha_x = 1.041
# s = 153.220 m  |  beta_x = 14.366  |  alpha_x = 1.032
# s = 153.247 m  |  beta_x = 14.310  |  alpha_x = 1.029
# s = 153.304 m  |  beta_x = 14.194  |  alpha_x = 1.020
# s = 153.339 m  |  beta_x = 14.123  |  alpha_x = 1.015
# s = 155.228 m  |  beta_x = 10.798  |  alpha_x = 0.744
# s = 155.263 m  |  beta_x = 10.746  |  alpha_x = 0.739
# s = 155.320 m  |  beta_x = 10.663  |  alpha_x = 0.731
# s = 155.377 m  |  beta_x = 10.580  |  alpha_x = 0.723
# s = 155.427 m  |  beta_x = 10.508  |  alpha_x = 0.716
# s = 155.497 m  |  beta_x = 10.408  |  alpha_x = 0.705
# s = 155.540 m  |  beta_x = 10.349  |  alpha_x = 0.699
# s = 155.661 m  |  beta_x = 10.180  |  alpha_x = 0.682
# s = 155.718 m  |  beta_x = 10.104  |  alpha_x = 0.674
# s = 155.753 m  |  beta_x = 10.057  |  alpha_x = 0.669
# s = 156.313 m  |  beta_x = 9.353  |  alpha_x = 0.588
# s = 157.642 m  |  beta_x = 8.043  |  alpha_x = 0.397
# s = 157.677 m  |  beta_x = 8.016  |  alpha_x = 0.392
# s = 157.734 m  |  beta_x = 7.972  |  alpha_x = 0.384
# s = 157.761 m  |  beta_x = 7.951  |  alpha_x = 0.380
# s = 157.817 m  |  beta_x = 7.909  |  alpha_x = 0.372
# s = 157.852 m  |  beta_x = 7.883  |  alpha_x = 0.367
# s = 159.742 m  |  beta_x = 7.010  |  alpha_x = 0.095
# s = 159.777 m  |  beta_x = 7.003  |  alpha_x = 0.090
# s = 159.833 m  |  beta_x = 6.993  |  alpha_x = 0.082
# s = 159.852 m  |  beta_x = 6.990  |  alpha_x = 0.079
# s = 159.894 m  |  beta_x = 6.984  |  alpha_x = 0.073
# s = 160.047 m  |  beta_x = 6.965  |  alpha_x = 0.051
# s = 160.050 m  |  beta_x = 6.965  |  alpha_x = 0.051
# s = 160.254 m  |  beta_x = 8.135  |  alpha_x = -6.099
# s = 160.345 m  |  beta_x = 9.286  |  alpha_x = -6.527
# s = 160.549 m  |  beta_x = 10.433  |  alpha_x = 1.206
# s = 160.612 m  |  beta_x = 10.280  |  alpha_x = 1.192
# s = 160.690 m  |  beta_x = 10.096  |  alpha_x = 1.173
# s = 160.796 m  |  beta_x = 9.850  |  alpha_x = 1.148
# s = 160.835 m  |  beta_x = 9.761  |  alpha_x = 1.139
# s = 161.395 m  |  beta_x = 8.559  |  alpha_x = 1.007
# s = 162.725 m  |  beta_x = 6.296  |  alpha_x = 0.695
# s = 162.764 m  |  beta_x = 6.242  |  alpha_x = 0.685
# s = 162.896 m  |  beta_x = 6.065  |  alpha_x = 0.654
# s = 162.935 m  |  beta_x = 6.015  |  alpha_x = 0.645
# s = 164.824 m  |  beta_x = 4.417  |  alpha_x = 0.201
# s = 164.863 m  |  beta_x = 4.401  |  alpha_x = 0.191
# s = 164.898 m  |  beta_x = 4.388  |  alpha_x = 0.183
# s = 164.941 m  |  beta_x = 4.373  |  alpha_x = 0.173
# s = 164.999 m  |  beta_x = 4.354  |  alpha_x = 0.159
# s = 165.049 m  |  beta_x = 4.338  |  alpha_x = 0.148
# s = 165.119 m  |  beta_x = 4.319  |  alpha_x = 0.131
# s = 165.161 m  |  beta_x = 4.308  |  alpha_x = 0.121
# s = 165.204 m  |  beta_x = 4.298  |  alpha_x = 0.111
# s = 165.310 m  |  beta_x = 4.277  |  alpha_x = 0.086
# s = 165.349 m  |  beta_x = 4.271  |  alpha_x = 0.077
# s = 165.909 m  |  beta_x = 4.259  |  alpha_x = -0.055
# s = 167.238 m  |  beta_x = 4.821  |  alpha_x = -0.368
# s = 167.277 m  |  beta_x = 4.850  |  alpha_x = -0.377
# s = 167.409 m  |  beta_x = 4.953  |  alpha_x = -0.408
# s = 167.448 m  |  beta_x = 4.985  |  alpha_x = -0.417
# s = 169.338 m  |  beta_x = 7.402  |  alpha_x = -0.862
# s = 169.377 m  |  beta_x = 7.470  |  alpha_x = -0.871
# s = 169.412 m  |  beta_x = 7.531  |  alpha_x = -0.879
# s = 169.526 m  |  beta_x = 7.735  |  alpha_x = -0.906
# s = 169.568 m  |  beta_x = 7.812  |  alpha_x = -0.916
# s = 169.721 m  |  beta_x = 8.097  |  alpha_x = -0.952
# s = 169.724 m  |  beta_x = 8.103  |  alpha_x = -0.953
# s = 169.928 m  |  beta_x = 9.927  |  alpha_x = -8.469
# s = 169.955 m  |  beta_x = 10.399  |  alpha_x = -8.670
# s = 170.019 m  |  beta_x = 11.531  |  alpha_x = -9.136
# s = 170.223 m  |  beta_x = 13.391  |  alpha_x = 0.510
# s = 170.282 m  |  beta_x = 13.330  |  alpha_x = 0.504
# s = 170.360 m  |  beta_x = 13.252  |  alpha_x = 0.497
# s = 170.466 m  |  beta_x = 13.148  |  alpha_x = 0.487
# s = 170.505 m  |  beta_x = 13.110  |  alpha_x = 0.483
# s = 171.065 m  |  beta_x = 12.599  |  alpha_x = 0.431
# s = 172.395 m  |  beta_x = 11.619  |  alpha_x = 0.306
# s = 172.434 m  |  beta_x = 11.595  |  alpha_x = 0.302
# s = 172.566 m  |  beta_x = 11.517  |  alpha_x = 0.290
# s = 172.605 m  |  beta_x = 11.495  |  alpha_x = 0.286
# s = 174.494 m  |  beta_x = 10.748  |  alpha_x = 0.109
# s = 174.533 m  |  beta_x = 10.740  |  alpha_x = 0.105
# s = 174.568 m  |  beta_x = 10.733  |  alpha_x = 0.102
# s = 174.611 m  |  beta_x = 10.724  |  alpha_x = 0.098
# s = 174.669 m  |  beta_x = 10.713  |  alpha_x = 0.092
# s = 174.719 m  |  beta_x = 10.704  |  alpha_x = 0.088
# s = 174.789 m  |  beta_x = 10.692  |  alpha_x = 0.081
# s = 174.831 m  |  beta_x = 10.686  |  alpha_x = 0.077
# s = 174.874 m  |  beta_x = 10.679  |  alpha_x = 0.073
# s = 174.980 m  |  beta_x = 10.665  |  alpha_x = 0.063
# s = 175.019 m  |  beta_x = 10.660  |  alpha_x = 0.059
# s = 176.908 m  |  beta_x = 10.771  |  alpha_x = -0.118
# s = 176.947 m  |  beta_x = 10.780  |  alpha_x = -0.122
# s = 177.079 m  |  beta_x = 10.814  |  alpha_x = -0.134
# s = 177.118 m  |  beta_x = 10.825  |  alpha_x = -0.138
# s = 178.772 m  |  beta_x = 11.537  |  alpha_x = -0.293
# s = 179.008 m  |  beta_x = 11.681  |  alpha_x = -0.315
# s = 179.047 m  |  beta_x = 11.705  |  alpha_x = -0.319
# s = 179.082 m  |  beta_x = 11.728  |  alpha_x = -0.322

# %%
def get_energy_at_s(s_target, tws_list):
    s_array = np.array([tw.s for tw in tws_list])
    E_array = np.array([tw.E for tw in tws_list])
    return np.interp(s_target, s_array, E_array)

# %%
def plot_opt_func(lat, tws, top_plot=["Dx"], legend=True, fig_name=None, grid=True, font_size=12,
                  excld_legend=None, figsize=None, plt_figure=None):
    from ocelot.cpbd.optics import lattice_transfer_map

    if plt_figure is None:
        if fig_name is None:
            fig = plt.figure(figsize=figsize)
        else:
            fig = plt.figure(fig_name, figsize=figsize)
    else:
        fig = plt_figure

    plt.rc('axes', grid=grid)
    plt.rc('grid', color='0.75', linestyle='-', linewidth=0.5)
    left, width = 0.1, 0.85

    rect1 = [left, 0.65, width, 0.3]
    rect2 = [left, 0.19, width, 0.46]
    rect3 = [left, 0.07, width, 0.12]

    ax_top = fig.add_axes(rect1)
    ax_b = fig.add_axes(rect2, sharex=ax_top)
    ax_el = fig.add_axes(rect3, sharex=ax_top)

    for ax in ax_b, ax_el, ax_top:
        if ax != ax_el:
            for label in ax.get_xticklabels():
                label.set_visible(False)

    ax_b.grid(grid)
    ax_top.grid(grid)
    ax_el.set_yticks([])
    ax_el.grid(grid)

    fig.subplots_adjust(hspace=0)
    beta_x = [p.beta_x for p in tws]
    beta_y = [p.beta_y for p in tws]
    S = [p.s for p in tws]

    plt.xlim(S[0], S[-1])

    # Plot standard Twiss parameters
    plot_disp(ax_top, tws, [p for p in top_plot if p != "R56"], font_size)

    # ---- Add R56 Plotting ----
    if "R56" in top_plot:
        R56_vals = []
        s_vals = []

        for i in range(2, len(lat.sequence)):
            partial_lat = MagneticLattice(lat.sequence[:i])
            s_here = sum(e.l for e in partial_lat.sequence)

            try:
                E_here = get_energy_at_s(s_here, tws)
                R = lattice_transfer_map(partial_lat, energy=E_here)
                r56 = R[4, 5]
            except Exception as e:
                print(f"[WARN] Failed R56 at s = {s_here:.2f} m: {e}")
                r56 = 0

            # Debug print
            if i % 50 == 0 or s_here > 100:  # customize condition as you like
                print(f"s = {s_here:.2f} m, E = {E_here:.3f} GeV, R56 = {r56*1000:.3f} mm")

            R56_vals.append(r56)
            s_vals.append(s_here)

        
        ax_top.plot(s_vals, np.array(R56_vals), label="R56 [m]", color="red", linewidth=2)

    if "R56" in top_plot or legend:
        ax_top.legend(fontsize=font_size - 2)

    # Plot betas and elements
    plot_betas(ax_b, S, beta_x, beta_y, font_size)
    plot_elems(fig, ax_el, lat, s_point=S[0], legend=legend, y_scale=0.8, font_size=font_size,
               excld_legend=excld_legend)

# %%
plot_opt_func(lat, tws, top_plot=["Dx", "R56"], legend=True )
# Out:
# s = 8.98 m, E = 0.659 GeV, R56 = -0.004 mm
# s = 18.11 m, E = 0.817 GeV, R56 = -0.004 mm
# s = 27.67 m, E = 0.976 GeV, R56 = -0.004 mm
# s = 35.34 m, E = 1.095 GeV, R56 = -0.004 mm
# s = 44.80 m, E = 1.222 GeV, R56 = -0.004 mm
# s = 53.07 m, E = 1.318 GeV, R56 = -0.004 mm
# s = 61.96 m, E = 1.369 GeV, R56 = -0.004 mm
# s = 71.34 m, E = 1.449 GeV, R56 = -0.004 mm
# s = 77.40 m, E = 1.528 GeV, R56 = -0.004 mm
# s = 83.54 m, E = 1.528 GeV, R56 = 51.392 mm
# s = 91.14 m, E = 1.528 GeV, R56 = -0.089 mm
# s = 95.98 m, E = 1.528 GeV, R56 = -48.092 mm
# s = 100.14 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.24 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.28 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.28 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.33 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.51 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.51 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.63 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 100.87 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 101.02 m, E = 1.528 GeV, R56 = -51.560 mm
# s = 102.92 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 102.92 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 102.92 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 102.92 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 102.92 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.07 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.12 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.16 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.16 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.30 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.30 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.42 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.56 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.56 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.68 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.87 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 103.87 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 104.11 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 104.11 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 104.43 m, E = 1.528 GeV, R56 = -0.167 mm
# s = 104.51 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 104.56 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 104.64 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 104.64 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 104.96 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 104.96 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 105.06 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 105.06 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 105.16 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 105.24 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 105.24 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.39 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.45 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.45 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.50 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.50 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 106.57 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 108.71 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 108.75 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 108.75 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 108.98 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 108.98 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 109.30 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 109.51 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 109.83 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 109.99 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 109.99 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.13 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.13 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.43 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.43 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.57 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.57 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.65 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.70 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 110.74 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 111.21 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 111.25 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 111.33 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 111.33 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 111.33 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.03 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.15 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.29 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.41 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.41 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.41 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.66 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.75 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.80 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.80 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.84 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 112.84 m, E = 1.528 GeV, R56 = -0.168 mm
# s = 113.40 m, E = 1.540 GeV, R56 = -0.168 mm
# s = 113.40 m, E = 1.540 GeV, R56 = -0.168 mm
# s = 113.40 m, E = 1.540 GeV, R56 = -0.168 mm
# s = 114.73 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.73 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.76 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.82 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.85 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.90 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.94 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 114.94 m, E = 1.568 GeV, R56 = -0.169 mm
# s = 116.83 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 116.83 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 116.86 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 116.92 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 116.96 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 116.96 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.00 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.06 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.06 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.11 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.11 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.18 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.18 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.22 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.26 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.32 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.35 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.35 m, E = 1.607 GeV, R56 = -0.171 mm
# s = 117.91 m, E = 1.619 GeV, R56 = -0.171 mm
# s = 117.91 m, E = 1.619 GeV, R56 = -0.171 mm
# s = 117.91 m, E = 1.619 GeV, R56 = -0.171 mm
# s = 119.24 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.24 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.28 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.33 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.36 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.42 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.45 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 119.45 m, E = 1.647 GeV, R56 = -0.172 mm
# s = 121.34 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.34 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.38 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.43 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.48 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.48 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.52 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.56 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.56 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.71 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.72 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.72 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.92 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.96 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 121.96 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.01 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.22 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.22 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.26 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.35 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.40 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.44 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 122.44 m, E = 1.687 GeV, R56 = -0.174 mm
# s = 123.00 m, E = 1.698 GeV, R56 = -0.174 mm
# s = 123.00 m, E = 1.698 GeV, R56 = -0.174 mm
# s = 123.00 m, E = 1.698 GeV, R56 = -0.174 mm
# s = 124.33 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.33 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.36 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.42 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.45 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.50 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.54 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 124.54 m, E = 1.726 GeV, R56 = -0.175 mm
# s = 126.43 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.43 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.46 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.52 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.58 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.58 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.63 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.63 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.70 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.70 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.74 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.78 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.78 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.82 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.86 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.92 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.95 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 126.95 m, E = 1.766 GeV, R56 = -0.177 mm
# s = 127.51 m, E = 1.778 GeV, R56 = -0.177 mm
# s = 127.51 m, E = 1.778 GeV, R56 = -0.177 mm
# s = 127.51 m, E = 1.778 GeV, R56 = -0.177 mm
# s = 128.84 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 128.84 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 128.88 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 128.93 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 128.96 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 129.02 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 129.05 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 129.05 m, E = 1.806 GeV, R56 = -0.178 mm
# s = 130.94 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 130.94 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 130.98 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.03 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.08 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.08 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.23 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.23 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.23 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.44 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.53 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.73 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.73 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.73 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.86 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 131.95 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 132.00 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 132.04 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 132.04 m, E = 1.845 GeV, R56 = -0.179 mm
# s = 132.60 m, E = 1.857 GeV, R56 = -0.180 mm
# s = 132.60 m, E = 1.857 GeV, R56 = -0.180 mm
# s = 132.60 m, E = 1.857 GeV, R56 = -0.180 mm
# s = 133.93 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 133.93 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 133.96 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 134.02 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 134.05 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 134.10 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 134.14 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 134.14 m, E = 1.885 GeV, R56 = -0.180 mm
# s = 136.03 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.03 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.06 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.12 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.18 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.18 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.23 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.23 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.30 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.30 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.34 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.38 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.38 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.46 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.52 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.55 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 136.55 m, E = 1.925 GeV, R56 = -0.182 mm
# s = 137.11 m, E = 1.937 GeV, R56 = -0.182 mm
# s = 137.11 m, E = 1.937 GeV, R56 = -0.182 mm
# s = 137.11 m, E = 1.937 GeV, R56 = -0.182 mm
# s = 138.44 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.44 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.48 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.53 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.56 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.62 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.65 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 138.65 m, E = 1.964 GeV, R56 = -0.183 mm
# s = 140.54 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.54 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.58 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.63 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.68 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.68 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.83 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.83 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 140.83 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.04 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.13 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.33 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.33 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.33 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.33 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.46 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.55 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.60 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.64 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 141.64 m, E = 2.004 GeV, R56 = -0.184 mm
# s = 142.20 m, E = 2.016 GeV, R56 = -0.184 mm
# s = 142.20 m, E = 2.016 GeV, R56 = -0.184 mm
# s = 142.20 m, E = 2.016 GeV, R56 = -0.184 mm
# s = 143.53 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.53 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.56 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.62 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.65 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.70 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.74 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 143.74 m, E = 2.044 GeV, R56 = -0.185 mm
# s = 145.63 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.63 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.66 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.72 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.78 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.78 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.83 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.83 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.90 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.90 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 145.94 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 146.06 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 146.12 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 146.15 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 146.15 m, E = 2.084 GeV, R56 = -0.186 mm
# s = 146.71 m, E = 2.095 GeV, R56 = -0.187 mm
# s = 146.71 m, E = 2.095 GeV, R56 = -0.187 mm
# s = 146.71 m, E = 2.095 GeV, R56 = -0.187 mm
# s = 148.04 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.04 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.08 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.13 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.16 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.22 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.25 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 148.25 m, E = 2.123 GeV, R56 = -0.187 mm
# s = 150.14 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.14 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.18 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.23 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.28 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.28 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.43 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.43 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.64 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.73 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.93 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.93 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 150.93 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.01 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.06 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.15 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.20 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.24 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.24 m, E = 2.163 GeV, R56 = -0.188 mm
# s = 151.48 m, E = 2.167 GeV, R56 = -0.188 mm
# s = 151.48 m, E = 2.167 GeV, R56 = -0.188 mm
# s = 151.48 m, E = 2.167 GeV, R56 = -0.188 mm
# s = 153.13 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.13 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.16 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.22 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.25 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.30 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.34 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 153.34 m, E = 2.197 GeV, R56 = -0.189 mm
# s = 155.23 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.23 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.26 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.32 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.38 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.38 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.43 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.43 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.50 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.50 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.54 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.66 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.72 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.75 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 155.75 m, E = 2.231 GeV, R56 = -0.190 mm
# s = 156.31 m, E = 2.241 GeV, R56 = -0.190 mm
# s = 156.31 m, E = 2.241 GeV, R56 = -0.190 mm
# s = 156.31 m, E = 2.241 GeV, R56 = -0.190 mm
# s = 157.64 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.64 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.68 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.73 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.76 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.82 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.85 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 157.85 m, E = 2.265 GeV, R56 = -0.191 mm
# s = 159.74 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.74 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.78 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.83 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.85 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.89 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 159.89 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.05 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.05 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.25 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.34 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.55 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.55 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.55 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.61 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.69 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.80 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.84 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 160.84 m, E = 2.299 GeV, R56 = -0.192 mm
# s = 161.40 m, E = 2.311 GeV, R56 = -0.192 mm
# s = 161.40 m, E = 2.311 GeV, R56 = -0.192 mm
# s = 161.40 m, E = 2.311 GeV, R56 = -0.192 mm
# s = 162.72 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 162.72 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 162.76 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 162.90 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 162.93 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 162.93 m, E = 2.339 GeV, R56 = -0.193 mm
# s = 164.82 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 164.82 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 164.86 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 164.90 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 164.94 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.00 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.00 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.05 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.05 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.12 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.12 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.16 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.20 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.31 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.35 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.35 m, E = 2.378 GeV, R56 = -0.194 mm
# s = 165.91 m, E = 2.390 GeV, R56 = -0.194 mm
# s = 165.91 m, E = 2.390 GeV, R56 = -0.194 mm
# s = 165.91 m, E = 2.390 GeV, R56 = -0.194 mm
# s = 167.24 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 167.24 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 167.28 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 167.41 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 167.45 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 167.45 m, E = 2.418 GeV, R56 = -0.195 mm
# s = 169.34 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.34 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.38 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.41 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.53 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.57 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.57 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.72 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.72 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.93 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.96 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 169.96 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.02 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.22 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.28 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.36 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.47 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.51 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 170.51 m, E = 2.458 GeV, R56 = -0.195 mm
# s = 171.07 m, E = 2.468 GeV, R56 = -0.196 mm
# s = 171.07 m, E = 2.468 GeV, R56 = -0.196 mm
# s = 171.07 m, E = 2.468 GeV, R56 = -0.196 mm
# s = 172.39 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 172.39 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 172.43 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 172.57 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 172.60 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 172.60 m, E = 2.494 GeV, R56 = -0.196 mm
# s = 174.49 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.49 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.53 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.57 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.61 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.67 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.67 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.72 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.72 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.79 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.79 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.83 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.87 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 174.98 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 175.02 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 175.02 m, E = 2.529 GeV, R56 = -0.197 mm
# s = 176.91 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 176.91 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 176.95 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 177.08 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 177.12 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 177.12 m, E = 2.565 GeV, R56 = -0.198 mm
# s = 178.77 m, E = 2.597 GeV, R56 = -0.198 mm
# s = 178.77 m, E = 2.597 GeV, R56 = -0.198 mm
# s = 178.77 m, E = 2.597 GeV, R56 = -0.198 mm
# s = 179.01 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.01 m, E = 2.601 GeV, R56 = -0.198 mm
# s = 179.05 m, E = 2.601 GeV, R56 = -0.198 mm

# %%
# Your element IDs
start_id = "PJARCM1"
end_id   = "PSECTC"

# Find their indices in the lattice
start_index = next(i for i, el in enumerate(lattice_list) if el.id == start_id)
end_index   = next(i for i, el in enumerate(lattice_list) if el.id == end_id)

# Create the sub-lattice
partial_lat = MagneticLattice(lattice_list[start_index:end_index + 1])

# Get s-positions of those indices
s_start = sum(el.l for el in lattice_list[:start_index])
s_end   = sum(el.l for el in lattice_list[:end_index + 1])
s_mid   = 0.5 * (s_start + s_end)

# Interpolate energy at midpoint
E_here = get_energy_at_s(s_mid, tws)

# Calculate R56
R = lattice_transfer_map(partial_lat, energy=E_here)
r56 = R[4, 5]

# Print result
print(f"R56 from '{start_id}' to '{end_id}' (s = {s_start:.2f} to {s_end:.2f} m, E ≈ {E_here:.3f} GeV): R56 = {r56*1000:.3f} mm")
# Out:
# R56 from 'PJARCM1' to 'PSECTC' (s = 76.00 to 112.80 m, E ≈ 1.528 GeV): R56 = -0.277 mm

# %%
def compute_r56_with_energy_evolution(lat_list, tws, id_start, id_end):
    # Find element indices
    i_start = next(i for i, el in enumerate(lat_list) if el.id == id_start)
    i_end   = next(i for i, el in enumerate(lat_list) if el.id == id_end)

    # Build the sub-lattice
    partial_lat = MagneticLattice(lat_list[i_start:i_end + 1])

    # Use starting energy from Twiss at i_start
    s_start = sum(e.l for e in lat_list[:i_start])
    E_start = get_energy_at_s(s_start, tws)

    # Compute transfer maps at every step (tracks energy changes!)
    Bs, Rs, Ts, Ss = partial_lat.transfer_maps(energy=E_start, output_at_each_step=True)

    # Get the last transfer matrix — full map from PJARCM1 to PSECTC
    R_final = Rs[-1]
    r56 = R_final[4, 5]

    s_end = s_start + sum(e.l for e in lat_list[i_start:i_end + 1])
    print(f"R56 from '{id_start}' to '{id_end}' (s = {s_start:.2f} → {s_end:.2f} m): R56 = {r56*1000:.3f} mm")

# %%
compute_r56_with_energy_evolution(lattice_list, tws, "PJARCM1", "PSECTC")
# Out:
# R56 from 'PJARCM1' to 'PSECTC' (s = 76.00 → 112.80 m): R56 = -0.277 mm
