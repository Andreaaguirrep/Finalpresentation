# %%
from ocelot import *
from ocelot.cpbd.elements import *
from ocelot.gui.accelerator import *
from ocelot.cpbd.track import track_debug
import matplotlib.pyplot as plt


from linaccopy import *

# Define a very simple lattice: one big drift
# Define elements
drift_length = 50.0  # meters
drift = Drift(l=drift_length, eid="D1")

cavity_voltage = 5e6  # 5 MV (can adjust)
cavity = Cavity(l=10, eid="CAV1")  # simple 0.5 m cavity
cavity.voltage = cavity_voltage  # Voltage in Volts
cavity.freq = 1.3e9  # 1.3 GHz typical frequency
cavity.phase = 0.0   # 0° synchronous phase (can play with later)

# Create the toy lattice: Cavity + Drift
toy_lat = MagneticLattice([cavity, drift])


lat = MagneticLattice(linac)

#lat = toy_lat



##### PA1RFGUN #####
AX =-21.12   
BX =24.36 
AY =-21.16     
BY =24.42      
EMITX =1.2023504614117648e-06
EMITY =1.2023504614117648e-06 
DP =.01
##### PA1RFGUN #####

energy = 0.0091 # GeV  #why?
tw0 = Twiss()
tw0.alpha_x = AX
tw0.beta_x = BX

tw0.alpha_y = AY
tw0.beta_y = BY
tw0.E = energy
tw0.emit_xn = EMITX 
tw0.emit_yn = EMITY
tw0.emit_x = EMITX   / energy * 0.511e-3
tw0.emit_y = EMITY / energy * 0.511e-3

tws = twiss(lat,tw0)

plot_opt_func(lat, tws,legend=False, grid=False, top_plot=['Dx','Dy'])


for elem in lat.sequence:
    if not isinstance(elem, Drift):
        print(elem)
# Out:
# Marker(eid="PA1RFGUN")
# Quadrupole(l=0.07360, k1=-4.662753e+01, eid="QDA1G1")
# Quadrupole(l=0.07360, k1=4.709763e+01, eid="QFA1G2")
# Bend(eid="BXA1G")
# Bend(tilt=1.570796e+00, eid="BYA1G")
# Quadrupole(l=0.07360, k1=-8.030131e+00, eid="QDA101")
# Quadrupole(l=0.07360, k1=2.957378e+00, eid="QFA102")
# Marker(eid="PACA11")
# Cavity(l=0.61850, v=6.662282e-03, freq=2.856000e+09, phi=4.000000e+01, eid="ACA111")
# Bend(eid="SXA11")
# Bend(tilt=1.570796e+00, eid="SYA11")
# Cavity(l=1.27095, v=1.369683e-02, freq=2.856000e+09, phi=4.000000e+01, eid="ACA112")
# Marker(eid="PACA11")
# Quadrupole(l=0.07360, k1=-1.142003e-01, eid="QDA111")
# Quadrupole(l=0.11460, k1=5.928660e+00, eid="QFA112")
# Quadrupole(l=0.07360, k1=-7.876449e-03, eid="QDA113")
# Bend(l=0.14725, angle=1.605878e-01, e2=1.605878e-01, eid="BMA1C1")
# Bend(l=0.14725, angle=-1.605878e-01, e1=-1.605878e-01, eid="BMA1C2")
# Bend(l=0.14725, angle=-1.605878e-01, e2=-1.605878e-01, eid="BMA1C3")
# Bend(l=0.14725, angle=1.605878e-01, e1=1.605878e-01, eid="BMA1C4")
# Bend(l=0.17300, eid="BMATJ5")
# Marker(eid="PSECTA")
# Quadrupole(l=0.12235, k1=-9.100855e+00, eid="PDA1M")
# Quadrupole(l=0.12235, k1=1.137240e+01, eid="PFA1M")
# Bend(eid="PXA1M")
# Bend(tilt=1.570796e+00, eid="PYA1M")
# Cavity(l=0.03499, eid="AKA21")
# Marker(eid="PACA21")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA21")
# Bend(eid="SXA21")
# Bend(tilt=1.570796e+00, eid="SYA21")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA212")
# Marker(eid="PACA21")
# Cavity(l=0.03499, eid="AKA21")
# Marker(eid="PPDA21")
# Quadrupole(l=0.12235, k1=-1.323075e+01, eid="PDA21")
# Quadrupole(l=0.12235, k1=1.689616e+01, eid="PFA21")
# Cavity(l=0.03499, eid="AKA22")
# Marker(eid="PACA22")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA22")
# Bend(eid="SXA22")
# Bend(tilt=1.570796e+00, eid="SYA22")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA222")
# Marker(eid="PACA22")
# Cavity(l=0.03499, eid="AKA22")
# Cavity(l=0.03499, eid="AKA23")
# Marker(eid="PACA23")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA23")
# Bend(eid="SXA23")
# Bend(tilt=1.570796e+00, eid="SYA23")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA232")
# Marker(eid="PACA23")
# Cavity(l=0.03499, eid="AKA23")
# Quadrupole(l=0.07500, k1=-1.071808e+01, eid="QDA23")
# Quadrupole(l=0.12100, k1=1.182822e+01, eid="QFA23")
# Quadrupole(l=0.07500, k1=-1.071808e+01, eid="QDA23")
# Cavity(l=0.03499, eid="AKA24")
# Marker(eid="PACA24")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA24")
# Bend(eid="SXA24")
# Bend(tilt=1.570796e+00, eid="SYA24")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA242")
# Marker(eid="PACA24")
# Cavity(l=0.03499, eid="AKA24")
# Marker(eid="PQDA24")
# Quadrupole(l=0.12100, k1=-8.575773e+00, eid="QDA24")
# Quadrupole(l=0.22200, k1=9.049769e+00, eid="QFA24")
# Quadrupole(l=0.12100, k1=-8.575773e+00, eid="QDA24")
# Cavity(l=0.03499, eid="AKA31")
# Marker(eid="PACA31")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA31")
# Bend(eid="SXA31")
# Bend(tilt=1.570796e+00, eid="SYA31")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA312")
# Marker(eid="PACA31")
# Cavity(l=0.03499, eid="AKA31")
# Cavity(l=0.03499, eid="AKA32")
# Marker(eid="PACA32")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA32")
# Bend(eid="SXA32")
# Bend(tilt=1.570796e+00, eid="SYA32")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA322")
# Marker(eid="PACA32")
# Cavity(l=0.03499, eid="AKA32")
# Marker(eid="PQDA32")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA32")
# Quadrupole(l=0.22200, k1=9.294356e+00, eid="QFA32")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA32")
# Cavity(l=0.03499, eid="AKA33")
# Marker(eid="PACA33")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA33")
# Bend(eid="SXA33")
# Bend(tilt=1.570796e+00, eid="SYA33")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA332")
# Marker(eid="PACA33")
# Cavity(l=0.03499, eid="AKA33")
# Cavity(l=0.03499, eid="AKA34")
# Marker(eid="PACA34")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA34")
# Bend(eid="SXA34")
# Bend(tilt=1.570796e+00, eid="SYA34")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA342")
# Marker(eid="PACA34")
# Cavity(l=0.03499, eid="AKA34")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA34")
# Quadrupole(l=0.22200, k1=9.294356e+00, eid="QFA34")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA34")
# Cavity(l=0.03499, eid="AKA41")
# Marker(eid="PACA41")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA41")
# Bend(eid="SXA41")
# Bend(tilt=1.570796e+00, eid="SYA41")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA412")
# Marker(eid="PACA41")
# Cavity(l=0.03499, eid="AKA41")
# Cavity(l=0.03499, eid="AKA42")
# Marker(eid="PACA42")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA42")
# Bend(eid="SXA42")
# Bend(tilt=1.570796e+00, eid="SYA42")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA422")
# Marker(eid="PACA42")
# Cavity(l=0.03499, eid="AKA42")
# Quadrupole(l=0.12100, k1=-4.601097e+00, eid="QDA42")
# Quadrupole(l=0.22200, k1=5.050408e+00, eid="QFA42")
# Quadrupole(l=0.12100, k1=-4.601097e+00, eid="QDA42")
# Cavity(l=0.03499, eid="AKA43")
# Marker(eid="PACA43")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA43")
# Bend(eid="SXA43")
# Bend(tilt=1.570796e+00, eid="SYA43")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA432")
# Marker(eid="PACA43")
# Cavity(l=0.03499, eid="AKA43")
# Cavity(l=0.03499, eid="AKA44")
# Marker(eid="PACA44")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA44")
# Bend(eid="SXA44")
# Bend(tilt=1.570796e+00, eid="SYA44")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA442")
# Marker(eid="PACA44")
# Cavity(l=0.03499, eid="AKA44")
# Quadrupole(l=0.12100, k1=-6.419987e+00, eid="QDA44")
# Quadrupole(l=0.22200, k1=6.868209e+00, eid="QFA44")
# Quadrupole(l=0.12100, k1=-6.419987e+00, eid="QDA44")
# Bend(l=0.14155, eid="PXA44")
# Bend(l=0.14155, tilt=1.570796e+00, eid="PYA44")
# Marker(eid="PSECTB")
# Cavity(l=0.03499, eid="AKB11")
# Marker(eid="PACB11")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB11")
# Bend(eid="SXB11")
# Bend(tilt=1.570796e+00, eid="SYB11")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB112")
# Marker(eid="PACB11")
# Cavity(l=0.03499, eid="AKB11")
# Cavity(l=0.03499, eid="AKB12")
# Marker(eid="PACB12")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB12")
# Marker(eid="PACB12")
# Cavity(l=0.03499, eid="AKB12")
# Cavity(l=0.03499, eid="AKB13")
# Marker(eid="PACB13")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB13")
# Bend(eid="SXB13")
# Bend(tilt=1.570796e+00, eid="SYB13")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB132")
# Marker(eid="PACB13")
# Cavity(l=0.03499, eid="AKB13")
# Cavity(l=0.03499, eid="AKB14")
# Marker(eid="PACB14")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB14")
# Marker(eid="PACB14")
# Cavity(l=0.03499, eid="AKB14")
# Marker(eid="PQDB14")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB14")
# Quadrupole(l=0.25220, k1=5.900647e+00, eid="QFB14")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB14")
# Cavity(l=0.03499, eid="AKB21")
# Marker(eid="PACB21")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB21")
# Bend(eid="SXB21")
# Bend(tilt=1.570796e+00, eid="SYB21")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB212")
# Marker(eid="PACB21")
# Cavity(l=0.03499, eid="AKB21")
# Cavity(l=0.03499, eid="AKB22")
# Marker(eid="PACB22")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB22")
# Marker(eid="PACB22")
# Cavity(l=0.03499, eid="AKB22")
# Cavity(l=0.03499, eid="AKB23")
# Marker(eid="PACB23")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB23")
# Bend(eid="SXB23")
# Bend(tilt=1.570796e+00, eid="SYB23")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB232")
# Marker(eid="PACB23")
# Cavity(l=0.03499, eid="AKB23")
# Cavity(l=0.03499, eid="AKB24")
# Marker(eid="PACB24")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB24")
# Marker(eid="PACB24")
# Cavity(l=0.03499, eid="AKB24")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB24")
# Quadrupole(l=0.25220, k1=5.900647e+00, eid="QFB24")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB24")
# Cavity(l=0.03499, eid="AKB31")
# Marker(eid="PACB31")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB31")
# Bend(eid="SXB31")
# Bend(tilt=1.570796e+00, eid="SYB31")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB312")
# Marker(eid="PACB31")
# Cavity(l=0.03499, eid="AKB31")
# Cavity(l=0.03499, eid="AKB32")
# Marker(eid="PACB32")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB32")
# Marker(eid="PACB32")
# Cavity(l=0.03499, eid="AKB32")
# Cavity(l=0.03499, eid="AKB33")
# Marker(eid="PACB33")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB33")
# Bend(eid="SXB33")
# Bend(tilt=1.570796e+00, eid="SYB33")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB332")
# Marker(eid="PACB33")
# Cavity(l=0.03499, eid="AKB33")
# Cavity(l=0.03499, eid="AKB34")
# Marker(eid="PACB34")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB34")
# Marker(eid="PACB34")
# Cavity(l=0.03499, eid="AKB34")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB34")
# Quadrupole(l=0.25220, k1=5.900647e+00, eid="QFB34")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB34")
# Cavity(l=0.03499, eid="AKB41")
# Marker(eid="PACB41")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB41")
# Bend(eid="SXB41")
# Bend(tilt=1.570796e+00, eid="SYB41")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB412")
# Marker(eid="PACB41")
# Cavity(l=0.03499, eid="AKB41")
# Cavity(l=0.03499, eid="AKB42")
# Marker(eid="PACB42")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB42")
# Marker(eid="PACB42")
# Cavity(l=0.03499, eid="AKB42")
# Cavity(l=0.03499, eid="AKB43")
# Marker(eid="PACB43")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB43")
# Bend(eid="SXB43")
# Bend(tilt=1.570796e+00, eid="SYB43")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB432")
# Marker(eid="PACB43")
# Cavity(l=0.03499, eid="AKB43")
# Cavity(l=0.03499, eid="AKB44")
# Marker(eid="PACB44")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB44")
# Marker(eid="PACB44")
# Cavity(l=0.03499, eid="AKB44")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB44")
# Quadrupole(l=0.25220, k1=5.900647e+00, eid="QFB44")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB44")
# Cavity(l=0.03499, eid="AKB51")
# Marker(eid="PACB51")
# Cavity(l=0.55984, v=7.446514e-03, freq=2.856000e+09, eid="ACB51")
# Bend(eid="SXB51")
# Bend(tilt=1.570796e+00, eid="SYB51")
# Cavity(l=1.32961, v=2.113438e-02, freq=2.856000e+09, eid="ACB512")
# Marker(eid="PACB51")
# Cavity(l=0.03499, eid="AKB51")
# Cavity(l=0.03499, eid="AKB52")
# Marker(eid="PACB52")
# Cavity(l=1.88945, v=3.003307e-02, freq=2.856000e+09, eid="ACB52")
# Marker(eid="PACB52")
# Cavity(l=0.03499, eid="AKB52")
# Cavity(l=0.03499, eid="AKB53")
# Marker(eid="PACB53")
# Cavity(l=0.55984, v=7.446514e-03, freq=2.856000e+09, eid="ACB53")
# Bend(eid="SXB53")
# Bend(tilt=1.570796e+00, eid="SYB53")
# Cavity(l=1.32961, v=2.113438e-02, freq=2.856000e+09, eid="ACB532")
# Marker(eid="PACB53")
# Cavity(l=0.03499, eid="AKB53")
# Cavity(l=0.03499, eid="AKB54")
# Marker(eid="PACB54")
# Cavity(l=1.88945, v=3.003307e-02, freq=2.856000e+09, eid="ACB54")
# Marker(eid="PACB54")
# Cavity(l=0.03499, eid="AKB54")
# Quadrupole(l=0.13330, k1=-5.953089e+00, eid="QDB54")
# Quadrupole(l=0.25220, k1=6.161439e+00, eid="QFB54")
# Quadrupole(l=0.13330, k1=-5.953089e+00, eid="QDB54")
# Cavity(l=0.03499, eid="AKB61")
# Marker(eid="PACB61")
# Cavity(l=0.55984, v=7.446514e-03, freq=2.856000e+09, eid="ACB61")
# Bend(eid="SXB61")
# Bend(tilt=1.570796e+00, eid="SYB61")
# Cavity(l=1.32961, v=2.113438e-02, freq=2.856000e+09, eid="ACB612")
# Marker(eid="PACB61")
# Cavity(l=0.03499, eid="AKB61")
# Cavity(l=0.03499, eid="AKB62")
# Marker(eid="PACB62")
# Cavity(l=1.88945, v=3.003307e-02, freq=2.856000e+09, eid="ACB62")
# Marker(eid="PACB62")
# Cavity(l=0.03499, eid="AKB62")
# Cavity(l=0.03499, eid="AKB63")
# Marker(eid="PACB63")
# Cavity(l=0.55984, v=7.446514e-03, freq=2.856000e+09, eid="ACB63")
# Bend(eid="SXB63")
# Bend(tilt=1.570796e+00, eid="SYB63")
# Cavity(l=1.32961, v=2.113438e-02, freq=2.856000e+09, eid="ACB632")
# Marker(eid="PACB63")
# Cavity(l=0.03499, eid="AKB63")
# Cavity(l=0.03499, eid="AKB64")
# Marker(eid="PACB64")
# Cavity(l=1.88945, v=3.003307e-02, freq=2.856000e+09, eid="ACB64")
# Marker(eid="PACB64")
# Cavity(l=0.03499, eid="AKB64")
# Quadrupole(l=0.13330, k1=-6.044669e+00, eid="QDB64")
# Quadrupole(l=0.25220, k1=6.279358e+00, eid="QFB64")
# Quadrupole(l=0.13330, k1=-6.044669e+00, eid="QDB64")
# Cavity(l=0.03499, eid="AKB71")
# Marker(eid="PACB71")
# Cavity(l=0.55984, freq=2.856000e+09, eid="ACB71")
# Bend(eid="SXB71")
# Bend(tilt=1.570796e+00, eid="SYB71")
# Cavity(l=1.32961, freq=2.856000e+09, eid="ACB712")
# Marker(eid="PACB71")
# Cavity(l=0.03499, eid="AKB71")
# Cavity(l=0.03499, eid="AKB72")
# Marker(eid="PACB72")
# Cavity(l=1.88945, freq=2.856000e+09, eid="ACB72")
# Marker(eid="PACB72")
# Cavity(l=0.03499, eid="AKB72")
# Cavity(l=0.03499, eid="AKB73")
# Marker(eid="PACB73")
# Cavity(l=0.55984, freq=2.856000e+09, eid="ACB73")
# Bend(eid="SXB73")
# Bend(tilt=1.570796e+00, eid="SYB73")
# Cavity(l=1.32961, freq=2.856000e+09, eid="ACB732")
# Marker(eid="PACB73")
# Cavity(l=0.03499, eid="AKB73")
# Cavity(l=0.03499, eid="AKB74")
# Marker(eid="PACB74")
# Cavity(l=1.88945, freq=2.856000e+09, eid="ACB74")
# Marker(eid="PACB74")
# Cavity(l=0.03499, eid="AKB74")
# Quadrupole(l=0.13330, k1=-5.937041e+00, eid="QDB74")
# Quadrupole(l=0.25220, k1=6.318395e+00, eid="QFB74")
# Quadrupole(l=0.13330, k1=-5.937041e+00, eid="QDB74")
# Cavity(l=0.03499, eid="AKB81")
# Marker(eid="PACB81")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB81")
# Bend(eid="SXB81")
# Bend(tilt=1.570796e+00, eid="SYB81")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB812")
# Marker(eid="PACB81")
# Cavity(l=0.03499, eid="AKB81")
# Cavity(l=0.03499, eid="AKB82")
# Marker(eid="PACB82")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB82")
# Marker(eid="PACB82")
# Cavity(l=0.03499, eid="AKB82")
# Cavity(l=0.03499, eid="AKB83")
# Marker(eid="PACB83")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB83")
# Bend(eid="SXB83")
# Bend(tilt=1.570796e+00, eid="SYB83")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB832")
# Marker(eid="PACB83")
# Cavity(l=0.03499, eid="AKB83")
# Cavity(l=0.03499, eid="AKB84")
# Marker(eid="PACB84")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB84")
# Marker(eid="PACB84")
# Cavity(l=0.03499, eid="AKB84")
# Marker(eid="PSECTJ")
# Marker(eid="PJARCM1")
# Marker(eid="JPXR001")
# Bend(l=0.12000, eid="PXR001")
# Marker(eid="JPYR001")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PYR001")
# Marker(eid="JQDR001")
# Quadrupole(l=0.32210, k1=-1.257494e+00, eid="PDR001")
# Marker(eid="JQFR002")
# Quadrupole(l=0.32210, k1=1.863293e+00, eid="PFR001")
# Bend(l=0.28800, tilt=1.570796e+00, eid="FYR002")
# Marker(eid="JPXR002")
# Bend(l=0.12000, eid="PXR002")
# Marker(eid="JPYR002")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PYR002")
# Quadrupole(l=0.32210, k1=-2.686861e+00, eid="PDR002")
# Marker(eid="JQDR003")
# Quadrupole(l=0.32210, k1=2.507463e+00, eid="PFR002")
# Marker(eid="PJARC")
# Bend(eid="BSR01")
# Marker(eid="JBMR01S")
# Bend(l=1.90757, angle=5.235988e-01, eid="BMR01")
# Marker(eid="JBMR01E")
# Bend(eid="BSR01")
# Bend(eid="BSR01")
# Marker(eid="JSFR013")
# Sextupole(l=0.11679, eid="SFR013")
# Marker(eid="JQFR014")
# Quadrupole(l=0.32314, k1=3.569323e+00, eid="QFR014")
# Marker(eid="JBMR02S")
# Bend(l=1.90920, angle=5.235988e-01, eid="BMR02")
# Marker(eid="JBMR02E")
# Bend(eid="BSR02")
# Marker(eid="JSFR021")
# Sextupole(l=0.11679, eid="SFR021")
# Marker(eid="JQDR022")
# Quadrupole(l=0.32314, k1=-3.136311e+00, eid="QDR022")
# Marker(eid="JQFR023")
# Quadrupole(l=0.32314, k1=3.143170e+00, eid="QFR023")
# Bend(tilt=1.570796e+00, eid="BYR023")
# Marker(eid="JBMR03S")
# Bend(l=1.90920, angle=5.235988e-01, eid="BMR03")
# Marker(eid="JBMR03E")
# Bend(eid="BSR03")
# Marker(eid="JSDR031")
# Sextupole(l=0.11679, eid="SDR031")
# Marker(eid="JQFR032")
# Quadrupole(l=0.32659, k1=4.337403e+00, eid="QFR032")
# Marker(eid="PMIDJARC")
# Marker(eid="JSDR033")
# Sextupole(l=0.11679, eid="SDR033")
# Marker(eid="JBMR04S")
# Bend(l=1.90920, angle=5.235988e-01, eid="BMR04")
# Marker(eid="JBMR04E")
# Bend(eid="BSR04")
# Bend(tilt=1.570796e+00, eid="BYR041")
# Marker(eid="JQFR041")
# Quadrupole(l=0.32314, k1=3.143170e+00, eid="QFR041")
# Marker(eid="JQDR042")
# Quadrupole(l=0.32314, k1=-3.136311e+00, eid="QDR042")
# Marker(eid="JSFR043")
# Sextupole(l=0.11679, eid="SFR043")
# Marker(eid="JBMR05S")
# Bend(l=1.90920, angle=5.235988e-01, eid="BMR05")
# Marker(eid="JBMR05E")
# Bend(eid="BSR05")
# Marker(eid="JQFR051")
# Quadrupole(l=0.32314, k1=3.569323e+00, eid="QFR051")
# Marker(eid="JSFR052")
# Sextupole(l=0.11679, eid="SFR052")
# Bend(eid="BSR06")
# Marker(eid="JBMR06S")
# Bend(l=1.90757, angle=5.235988e-01, eid="BMR06")
# Marker(eid="JBMR06E")
# Bend(eid="BSR06")
# Marker(eid="PJARCM2")
# Marker(eid="JPXR061")
# Bend(l=0.12000, eid="PXR061")
# Marker(eid="JPYR061")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PYR061")
# Marker(eid="JQDR061")
# Quadrupole(l=0.32210, k1=-1.961852e+00, eid="PDR061")
# Marker(eid="JQFR062")
# Quadrupole(l=0.32210, k1=2.185025e+00, eid="PFR061")
# Marker(eid="JQDR063")
# Quadrupole(l=0.32210, k1=-1.730731e+00, eid="PDR063")
# Quadrupole(l=0.32314, k1=1.439867e+00, eid="PFR063")
# Marker(eid="JPXR063")
# Marker(eid="JPYR063")
# Bend(l=0.12000, eid="PXR063")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PYR063")
# Marker(eid="PSECTC")
# Cavity(l=0.03499, eid="AKC11")
# Marker(eid="PACC11")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACC11")
# Bend(eid="SXC11")
# Bend(tilt=1.570796e+00, eid="SYC11")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACC112")
# Marker(eid="PACC11")
# Cavity(l=0.03499, eid="AKC11")
# Cavity(l=0.03499, eid="AKC12")
# Marker(eid="PACC12")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACC12")
# Marker(eid="PACC12")
# Cavity(l=0.03499, eid="AKC12")
# Cavity(l=0.03499, eid="AKC13")
# Marker(eid="PACC13")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACC13")
# Bend(eid="SXC13")
# Bend(tilt=1.570796e+00, eid="SYC13")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACC132")
# Marker(eid="PACC13")
# Cavity(l=0.03499, eid="AKC13")
# Cavity(l=0.03499, eid="AKC14")
# Marker(eid="PACC14")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACC14")
# Marker(eid="PACC14")
# Cavity(l=0.03499, eid="AKC14")
# Marker(eid="PQDC14")
# Quadrupole(l=0.20390, k1=-4.250983e+00, eid="QDC14")
# Quadrupole(l=0.20390, k1=4.447379e+00, eid="QFC14")
# Marker(eid="PQFC14")
# Cavity(l=0.03499, eid="AKC21")
# Marker(eid="PACC21")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACC21")
# Bend(eid="SXC21")
# Bend(tilt=1.570796e+00, eid="SYC21")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACC212")
# Marker(eid="PACC21")
# Cavity(l=0.03499, eid="AKC21")
# Cavity(l=0.03499, eid="AKC22")
# Marker(eid="PACC22")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACC22")
# Marker(eid="PACC22")
# Cavity(l=0.03499, eid="AKC22")
# Cavity(l=0.03499, eid="AKC23")
# Marker(eid="PACC23")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACC23")
# Bend(eid="SXC23")
# Bend(tilt=1.570796e+00, eid="SYC23")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACC232")
# Marker(eid="PACC23")
# Cavity(l=0.03499, eid="AKC23")
# Cavity(l=0.03499, eid="AKC24")
# Marker(eid="PACC24")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACC24")
# Marker(eid="PACC24")
# Cavity(l=0.03499, eid="AKC24")
# Marker(eid="PQDC24")
# Quadrupole(l=0.20390, k1=-4.262673e+00, eid="QDC24")
# Quadrupole(l=0.20390, k1=4.453336e+00, eid="QFC24")
# Cavity(l=0.03499, eid="AKC31")
# Marker(eid="PACC31")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACC31")
# Bend(eid="SXC31")
# Bend(tilt=1.570796e+00, eid="SYC31")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACC312")
# Marker(eid="PACC31")
# Cavity(l=0.03499, eid="AKC31")
# Cavity(l=0.03499, eid="AKC32")
# Marker(eid="PACC32")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACC32")
# Marker(eid="PACC32")
# Cavity(l=0.03499, eid="AKC32")
# Cavity(l=0.03499, eid="AKC33")
# Marker(eid="PACC33")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACC33")
# Bend(eid="SXC33")
# Bend(tilt=1.570796e+00, eid="SYC33")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACC332")
# Marker(eid="PACC33")
# Cavity(l=0.03499, eid="AKC33")
# Cavity(l=0.03499, eid="AKC34")
# Marker(eid="PACC34")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACC34")
# Marker(eid="PACC34")
# Cavity(l=0.03499, eid="AKC34")
# Marker(eid="PQDC34")
# Quadrupole(l=0.20390, k1=-3.705628e+00, eid="QDC34")
# Quadrupole(l=0.20390, k1=3.658361e+00, eid="QFC34")
# Marker(eid="PQFC34")
# Cavity(l=0.03499, eid="AKC41")
# Marker(eid="PACC41")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACC41")
# Bend(eid="SXC41")
# Bend(tilt=1.570796e+00, eid="SYC41")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACC412")
# Marker(eid="PACC41")
# Cavity(l=0.03499, eid="AKC41")
# Cavity(l=0.03499, eid="AKC42")
# Marker(eid="PACC42")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACC42")
# Marker(eid="PACC42")
# Cavity(l=0.03499, eid="AKC42")
# Cavity(l=0.03499, eid="AKC43")
# Marker(eid="PACC43")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACC43")
# Bend(eid="SXC43")
# Bend(tilt=1.570796e+00, eid="SYC43")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACC432")
# Marker(eid="PACC43")
# Cavity(l=0.03499, eid="AKC43")
# Cavity(l=0.03499, eid="AKC44")
# Marker(eid="PACC44")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACC44")
# Marker(eid="PACC44")
# Cavity(l=0.03499, eid="AKC44")
# Quadrupole(l=0.20390, k1=-3.812705e+00, eid="QDC44")
# Quadrupole(l=0.20390, k1=3.809771e+00, eid="QFC44")
# Cavity(l=0.03499, eid="AKC51")
# Marker(eid="PACC51")
# Cavity(l=0.23850, v=4.293000e-03, freq=2.856000e+09, eid="ACC51")
# Bend(eid="BXC51")
# Bend(tilt=1.570796e+00, eid="BYC51")
# Cavity(l=1.65095, v=2.971709e-02, freq=2.856000e+09, eid="ACC512")
# Marker(eid="PACC51")
# Cavity(l=0.03499, eid="AKC51")
# Cavity(l=0.03499, eid="AKC52")
# Marker(eid="PACC52")
# Cavity(l=1.88945, v=3.401009e-02, freq=2.856000e+09, eid="ACC52")
# Marker(eid="PACC52")
# Cavity(l=0.03499, eid="AKC52")
# Cavity(l=0.03499, eid="AKC53")
# Marker(eid="PACC53")
# Cavity(l=0.55984, v=1.007706e-02, freq=2.856000e+09, eid="ACC53")
# Bend(eid="SXC53")
# Bend(tilt=1.570796e+00, eid="SYC53")
# Cavity(l=1.32961, v=2.393302e-02, freq=2.856000e+09, eid="ACC532")
# Marker(eid="PACC53")
# Cavity(l=0.03499, eid="AKC53")
# Cavity(l=0.03499, eid="AKC54")
# Marker(eid="PACC54")
# Cavity(l=1.88945, v=3.401009e-02, freq=2.856000e+09, eid="ACC54")
# Marker(eid="PACC54")
# Cavity(l=0.03499, eid="AKC54")
# Quadrupole(l=0.20390, k1=-3.887419e+00, eid="QDC54")
# Quadrupole(l=0.20390, k1=3.887414e+00, eid="QFC54")
# Cavity(l=0.03900, eid="AKC61")
# Marker(eid="PACC61")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACC61")
# Bend(eid="SXC61")
# Bend(tilt=1.570796e+00, eid="SYC61")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACC612")
# Marker(eid="PACC61")
# Cavity(l=0.03900, eid="AKC61")
# Cavity(l=0.03900, eid="AKC62")
# Marker(eid="PACC62")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACC62")
# Marker(eid="PACC62")
# Cavity(l=0.03900, eid="AKC62")
# Cavity(l=0.03900, eid="AKC63")
# Marker(eid="PACC63")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACC63")
# Bend(eid="SXC63")
# Bend(tilt=1.570796e+00, eid="SYC63")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACC632")
# Marker(eid="PACC63")
# Cavity(l=0.03900, eid="AKC63")
# Cavity(l=0.03900, eid="AKC64")
# Marker(eid="PACC64")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACC64")
# Marker(eid="PACC64")
# Cavity(l=0.03900, eid="AKC64")
# Quadrupole(l=0.20390, k1=-3.887419e+00, eid="QDC64")
# Quadrupole(l=0.20390, k1=3.887414e+00, eid="QFC64")
# Cavity(l=0.03900, eid="AKC71")
# Marker(eid="PACC71")
# Cavity(l=0.55984, v=1.063690e-02, freq=2.856000e+09, eid="ACC71")
# Bend(eid="SXC71")
# Bend(tilt=1.570796e+00, eid="SYC71")
# Cavity(l=1.32961, v=2.526264e-02, freq=2.856000e+09, eid="ACC712")
# Marker(eid="PACC71")
# Cavity(l=0.03900, eid="AKC71")
# Cavity(l=0.03900, eid="AKC72")
# Marker(eid="PACC72")
# Cavity(l=1.88945, v=3.589953e-02, freq=2.856000e+09, eid="ACC72")
# Marker(eid="PACC72")
# Cavity(l=0.03900, eid="AKC72")
# Cavity(l=0.03900, eid="AKC73")
# Marker(eid="PACC73")
# Cavity(l=1.88945, v=3.589953e-02, freq=2.856000e+09, eid="ACC73")
# Marker(eid="PACC73")
# Cavity(l=0.03900, eid="AKC73")
# Cavity(l=0.03900, eid="AKC74")
# Marker(eid="PACC74")
# Cavity(l=1.65345, v=3.141553e-02, freq=2.856000e+09, eid="ACC74")
# Bend(eid="BXC74")
# Bend(tilt=1.570796e+00, eid="BYC74")
# Cavity(l=0.23600, v=4.484000e-03, freq=2.856000e+09, eid="ACC742")
# Marker(eid="PACC74")
# Cavity(l=0.03900, eid="AKC74")
# Quadrupole(l=0.20390, k1=-4.752158e+00, eid="QDC74")
# Quadrupole(l=0.20390, k1=4.631665e+00, eid="QFC74")
# Bend(l=0.14155, eid="PXC74")
# Bend(l=0.14155, tilt=1.570796e+00, eid="PYC74")
# Cavity(l=0.03900, eid="AKC81")
# Marker(eid="PACC81")
# Cavity(l=0.55984, v=1.007706e-02, freq=2.856000e+09, eid="ACC81")
# Bend(eid="SXC81")
# Bend(tilt=1.570796e+00, eid="SYC81")
# Cavity(l=1.32961, v=2.393302e-02, freq=2.856000e+09, eid="ACC812")
# Marker(eid="PACC81")
# Cavity(l=0.03900, eid="AKC81")
# Cavity(l=0.03900, eid="AKC82")
# Marker(eid="PACC82")
# Cavity(l=1.88945, v=3.401009e-02, freq=2.856000e+09, eid="ACC82")
# Marker(eid="PACC82")
# Cavity(l=0.03900, eid="AKC82")
# Cavity(l=0.03900, eid="AKC83")
# Marker(eid="PACC83")
# Cavity(l=0.55984, v=1.007706e-02, freq=2.856000e+09, eid="ACC83")
# Cavity(l=1.32961, v=2.393302e-02, freq=2.856000e+09, eid="ACC832")
# Marker(eid="PACC83")
# Cavity(l=0.03900, eid="AKC83")
# Cavity(l=0.03900, eid="AKC84")
# Marker(eid="PACC84")
# Cavity(l=1.88945, v=3.401009e-02, freq=2.856000e+09, eid="ACC84")
# Marker(eid="PACC84")
# Cavity(l=0.03900, eid="AKC84")
# Quadrupole(l=0.20390, k1=-3.680885e+00, eid="QDC84")
# Quadrupole(l=0.20390, k1=3.757568e+00, eid="QFC84")
# Marker(eid="PSECT1")
# Cavity(l=0.03900, eid="AK111")
# Marker(eid="PAC111")
# Cavity(l=0.55984, v=9.517226e-03, freq=2.856000e+09, eid="AC111")
# Bend(eid="SX111")
# Bend(tilt=1.570796e+00, eid="SY111")
# Cavity(l=1.32961, v=2.260341e-02, freq=2.856000e+09, eid="AC1112")
# Marker(eid="PAC111")
# Cavity(l=0.03900, eid="AK111")
# Cavity(l=0.03900, eid="AK112")
# Marker(eid="PAC112")
# Cavity(l=1.88945, v=3.212064e-02, freq=2.856000e+09, eid="AC112")
# Marker(eid="PAC112")
# Cavity(l=0.03900, eid="AK112")
# Cavity(l=0.03900, eid="AK113")
# Marker(eid="PAC113")
# Cavity(l=0.55984, v=9.517226e-03, freq=2.856000e+09, eid="AC113")
# Bend(eid="SX113")
# Bend(tilt=1.570796e+00, eid="SY113")
# Cavity(l=1.32961, v=2.260341e-02, freq=2.856000e+09, eid="AC1132")
# Marker(eid="PAC113")
# Cavity(l=0.03900, eid="AK113")
# Cavity(l=0.03900, eid="AK114")
# Marker(eid="PAC114")
# Cavity(l=1.88945, v=3.212064e-02, freq=2.856000e+09, eid="AC114")
# Marker(eid="PAC114")
# Cavity(l=0.03900, eid="AK114")
# Marker(eid="PQD114")
# Quadrupole(l=0.20390, k1=-1.359693e-01, eid="QD114")
# Quadrupole(l=0.20390, k1=1.499692e-03, eid="QF114")
# Marker(eid="PQF114")
# Cavity(l=0.03900, eid="AK121")
# Marker(eid="PAC121")
# Cavity(l=0.55984, v=1.066667e-02, freq=2.856000e+09, eid="AC121")
# Bend(eid="SX121")
# Bend(tilt=1.570796e+00, eid="SY121")
# Cavity(l=1.32961, v=2.533334e-02, freq=2.856000e+09, eid="AC1212")
# Marker(eid="PAC121")
# Cavity(l=0.03900, eid="AK121")
# Cavity(l=0.03900, eid="AK122")
# Marker(eid="PAC122")
# Cavity(l=1.88945, v=3.600000e-02, freq=2.856000e+09, eid="AC122")
# Marker(eid="PAC122")
# Cavity(l=0.03900, eid="AK122")
# Bend(tilt=1.570796e+00, eid="PY122")
# Cavity(l=0.03900, eid="AK123")
# Marker(eid="PAC123")
# Cavity(l=0.55984, v=1.066667e-02, freq=2.856000e+09, eid="AC123")
# Bend(eid="SX123")
# Bend(tilt=1.570796e+00, eid="SY123")
# Cavity(l=1.32961, v=2.533334e-02, freq=2.856000e+09, eid="AC1232")
# Marker(eid="PAC123")
# Cavity(l=0.03900, eid="AK123")
# Cavity(l=0.03900, eid="AK124")
# Marker(eid="PAC124")
# Cavity(l=1.88945, v=3.600000e-02, freq=2.856000e+09, eid="AC124")
# Marker(eid="PAC124")
# Cavity(l=0.03900, eid="AK124")
# Quadrupole(l=0.20390, k1=-2.690951e+00, eid="QD124")
# Quadrupole(l=0.20390, k1=3.328534e+00, eid="QF124")
# Marker(eid="F0")
# Marker(eid="PAC131")
# Quadrupole(l=0.25550, eid="AC1311")
# Bend(eid="BX131")
# Bend(tilt=1.570796e+00, eid="BY131")
# Quadrupole(l=1.63400, eid="AC1312")
# Marker(eid="PAC131")
# Marker(eid="PAC132")
# Quadrupole(l=1.88945, eid="AC132")
# Marker(eid="PAC132")
# Bend(l=0.18000, eid="PX132")
# Marker(eid="PAC133")
# Quadrupole(l=0.61603, eid="AC1331")
# Quadrupole(l=1.27342, eid="AC1332")
# Marker(eid="PAC133")
# Marker(eid="PAC134")
# Quadrupole(l=1.88945, eid="AC134")
# Marker(eid="PAC134")
# Quadrupole(l=0.21100, k1=-1.456107e+00, eid="PD135")
# Marker(eid="SP135")
# Quadrupole(l=0.21100, k1=1.642516e+00, eid="PF135")
# Bend(l=0.18000, eid="PX1352")
# Bend(l=0.18000, eid="PX135")
# Quadrupole(l=0.15000, eid="BX135")
# Quadrupole(l=0.15000, eid="BY135")
# Bend(l=0.18000, tilt=1.570796e+00, eid="PY135")
# Marker(eid="SP15T")
# Marker(eid="SC15T")
# Marker(eid="PTARGET")
# Solenoid(eid="SSOLB")
# Marker(eid="PAC151")
# Quadrupole(l=1.99442, eid="AC151")
# Marker(eid="PAC151")
# Marker(eid="SP1515")
# Bend(eid="SX1515")
# Marker(eid="PAC152")
# Quadrupole(l=1.99442, eid="AC152")
# Marker(eid="PAC152")
# Marker(eid="PAC161")
# Quadrupole(l=1.99442, eid="AC161")
# Marker(eid="PAC161")
# Marker(eid="SP1615")
# Bend(tilt=1.570796e+00, eid="SY1615")
# Marker(eid="PAC162")
# Quadrupole(l=1.99442, eid="AC162")
# Marker(eid="PAC162")
# Marker(eid="PAC163")
# Quadrupole(l=1.99442, eid="AC163")
# Marker(eid="PAC163")
# Marker(eid="PAC164")
# Quadrupole(l=1.99442, eid="AC164")
# Marker(eid="PAC164")
# Solenoid(eid="SSOLE")
# Marker(eid="P16SOLEND")
# Marker(eid="SC164")
# Quadrupole(l=0.18080, k1=2.341637e-01, eid="QF1641")
# Quadrupole(l=0.18080, k1=-5.167718e-01, eid="QD1642")
# Quadrupole(l=0.18080, k1=4.931047e-01, eid="QF1643")
# Quadrupole(l=0.18080, k1=-2.161014e-01, eid="QD1644")
# Bend(l=0.25330, angle=-3.499325e-03, e2=-3.499325e-03, eid="BM16C1")
# Bend(l=0.25330, angle=3.499325e-03, e1=3.499325e-03, eid="BM16C2")
# Bend(l=0.25330, angle=3.499325e-03, e2=3.499325e-03, eid="BM16C3")
# Bend(l=0.25330, angle=-3.499325e-03, e1=-3.499325e-03, eid="BM16C4")
# Quadrupole(l=0.18080, k1=-2.689304e-01, eid="QD1651")
# Quadrupole(l=0.18080, k1=5.323276e-01, eid="QF1652")
# Quadrupole(l=0.18080, k1=-5.079849e-01, eid="QD1653")
# Quadrupole(l=0.18080, k1=2.560100e-01, eid="QF1654")
# Marker(eid="SC165")
# Quadrupole(l=0.18080, k1=-1.455784e-01, eid="QD1655")
# Bend(eid="PX165")
# Quadrupole(l=0.18080, k1=2.668252e-01, eid="QF1656")
# Bend(tilt=1.570796e+00, eid="PY165")
# Marker(eid="SP165")
# Quadrupole(l=0.18080, k1=-4.055596e-01, eid="QD1657")
# Marker(eid="PAC171")
# Quadrupole(l=0.17855, eid="AC1711")
# Quadrupole(l=0.33440, k1=2.814680e-01, eid="QF1711")
# Quadrupole(l=0.31510, eid="AC1712")
# Quadrupole(l=0.33440, k1=-3.551304e-01, eid="QD1712")
# Quadrupole(l=0.31560, eid="AC1713")
# Quadrupole(l=0.33440, k1=3.653127e-01, eid="QF1713")
# Quadrupole(l=0.18197, eid="AC1714")
# Marker(eid="PAC171")
# Quadrupole(l=0.17371, k1=-6.597253e-01, eid="QD1714")
# Marker(eid="PAC172")
# Quadrupole(l=0.18405, eid="AC1721")
# Quadrupole(l=0.33440, k1=3.418939e-01, eid="QF1721")
# Quadrupole(l=0.31060, eid="AC1722")
# Quadrupole(l=0.33440, k1=-3.513446e-01, eid="QD1722")
# Quadrupole(l=0.31560, eid="AC1723")
# Quadrupole(l=0.33440, k1=3.459666e-01, eid="QF1723")
# Quadrupole(l=0.18097, eid="AC1724")
# Marker(eid="PAC172")
# Marker(eid="SP172")
# Quadrupole(l=0.17371, k1=-7.199065e-01, eid="QD1724")
# Bend(l=0.12000, eid="PX172")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PY172")
# Quadrupole(l=0.17371, k1=7.107459e-01, eid="QF1725")
# Marker(eid="PAC173")
# Quadrupole(l=0.17905, eid="AC1731")
# Quadrupole(l=0.33440, k1=-4.128527e-01, eid="QD1731")
# Quadrupole(l=0.31460, eid="AC1732")
# Quadrupole(l=0.33440, k1=4.450327e-01, eid="QF1732")
# Quadrupole(l=0.31660, eid="AC1733")
# Quadrupole(l=0.33440, k1=-4.631918e-01, eid="QD1733")
# Quadrupole(l=0.18097, eid="AC1734")
# Marker(eid="PAC173")
# Quadrupole(l=0.17371, k1=8.564307e-01, eid="QF1734")
# Marker(eid="PAC174")
# Quadrupole(l=0.18705, eid="AC1741")
# Quadrupole(l=0.33440, k1=-5.079079e-01, eid="QD1741")
# Quadrupole(l=0.29860, eid="AC1742")
# Quadrupole(l=0.33440, k1=4.933967e-01, eid="QF1742")
# Quadrupole(l=0.39060, eid="AC1743")
# Quadrupole(l=0.33440, k1=-5.080504e-01, eid="QD1743")
# Quadrupole(l=0.11497, eid="AC1744")
# Marker(eid="PAC174")
# Marker(eid="SC174")
# Marker(eid="SP1744")
# Quadrupole(l=0.17371, k1=8.655690e-01, eid="QF1744")
# Bend(l=0.18000, eid="PX174")
# Quadrupole(l=0.17371, k1=-7.230026e-01, eid="QD1745")
# Bend(l=0.18000, tilt=1.570796e+00, eid="PY174")
# Quadrupole(l=0.17371, k1=9.007778e-01, eid="QF1746")
# Marker(eid="PAC181")
# Quadrupole(l=0.05650, eid="AC1811")
# Quadrupole(l=0.33440, k1=-4.772322e-01, eid="QD1811")
# Quadrupole(l=0.41540, eid="AC1812")
# Quadrupole(l=0.33440, k1=4.640601e-01, eid="QF1812")
# Quadrupole(l=0.30460, eid="AC1813")
# Quadrupole(l=0.33440, k1=-5.722233e-01, eid="QD1813")
# Quadrupole(l=0.10975, eid="AC1814")
# Marker(eid="PAC181")
# Quadrupole(l=0.17371, k1=1.000282e+00, eid="QF1814")
# Marker(eid="PAC182")
# Quadrupole(l=0.12595, eid="AC1821")
# Quadrupole(l=0.33440, k1=-5.292437e-01, eid="QD1821")
# Quadrupole(l=0.34440, eid="AC1822")
# Quadrupole(l=0.33440, k1=5.279733e-01, eid="QF1822")
# Quadrupole(l=0.29360, eid="AC1823")
# Quadrupole(l=0.33440, k1=-6.113681e-01, eid="QD1823")
# Quadrupole(l=0.12230, eid="AC1824")
# Marker(eid="PAC182")
# Marker(eid="SP182")
# Quadrupole(l=0.17371, k1=9.062770e-01, eid="QF1824")
# Bend(l=0.12000, eid="PX182")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PY182")
# Quadrupole(l=0.17880, k1=-5.496294e-01, eid="PD1825")
# Marker(eid="PAC183")
# Quadrupole(l=0.08230, eid="AC1831")
# Quadrupole(l=0.33440, k1=6.252186e-01, eid="QF1831")
# Quadrupole(l=0.39260, eid="AC1832")
# Quadrupole(l=0.33440, k1=-6.216828e-01, eid="QD1832")
# Quadrupole(l=0.29560, eid="AC1833")
# Quadrupole(l=0.33440, k1=6.127412e-01, eid="QF1833")
# Quadrupole(l=0.11575, eid="AC1834")
# Marker(eid="PAC183")
# Quadrupole(l=0.17371, k1=-1.168708e+00, eid="QD1834")
# Marker(eid="PAC184")
# Quadrupole(l=0.11495, eid="AC1841")
# Quadrupole(l=0.33440, k1=6.340684e-01, eid="QF1841")
# Quadrupole(l=0.35340, eid="AC1842")
# Quadrupole(l=0.33440, k1=-6.836121e-01, eid="QD1842")
# Quadrupole(l=0.29660, eid="AC1843")
# Quadrupole(l=0.33440, k1=7.266014e-01, eid="QF1843")
# Quadrupole(l=0.12130, eid="AC1844")
# Marker(eid="PAC184")
# Quadrupole(l=0.17371, k1=-1.301319e+00, eid="QD1844")
# Quadrupole(l=0.17371, k1=1.284064e+00, eid="QF1845")
# Bend(l=0.18000, tilt=1.570796e+00, eid="PY184")
# Quadrupole(l=0.17371, k1=-1.447888e+00, eid="QD1846")
# Marker(eid="SP1847")
# Quadrupole(l=0.17371, k1=1.239241e+00, eid="QF1847")
# Bend(l=0.18000, eid="PX184")
# Quadrupole(l=0.17371, k1=-1.372586e+00, eid="QD1848")
# Quadrupole(l=0.17880, k1=7.262856e-01, eid="PF1849")
# Marker(eid="SC184")
# Marker(eid="PSECT2")
# Marker(eid="PAC211")
# Quadrupole(l=0.18359, eid="AC2111")
# Quadrupole(l=0.32784, k1=-6.233892e-01, eid="QD2111")
# Quadrupole(l=0.29216, eid="AC2112")
# Quadrupole(l=0.32784, k1=6.485207e-01, eid="QF2112")
# Quadrupole(l=0.27216, eid="AC2113")
# Quadrupole(l=0.32784, k1=-6.043409e-01, eid="QD2113")
# Quadrupole(l=0.15802, eid="AC2114")
# Marker(eid="PAC211")
# Quadrupole(l=0.17371, k1=1.155156e+00, eid="QF2114")
# Marker(eid="PAC212")
# Quadrupole(l=0.18159, eid="AC2121")
# Quadrupole(l=0.32784, k1=-6.185370e-01, eid="QD2121")
# Quadrupole(l=0.28116, eid="AC2122")
# Quadrupole(l=0.32784, k1=6.786480e-01, eid="QF2122")
# Quadrupole(l=0.27816, eid="AC2123")
# Quadrupole(l=0.32784, k1=-6.507246e-01, eid="QD2123")
# Quadrupole(l=0.16502, eid="AC2124")
# Marker(eid="PAC212")
# Quadrupole(l=0.17880, k1=7.749983e-01, eid="PF2124")
# Bend(l=0.12000, eid="PX212")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PY212")
# Marker(eid="SP212")
# Quadrupole(l=0.17371, k1=-1.181709e+00, eid="QD2125")
# Marker(eid="PAC213")
# Quadrupole(l=0.22659, eid="AC2131")
# Quadrupole(l=0.32784, k1=7.111474e-01, eid="QF2131")
# Quadrupole(l=0.23216, eid="AC2132")
# Quadrupole(l=0.32784, k1=-7.318839e-01, eid="QD2132")
# Quadrupole(l=0.30116, eid="AC2133")
# Quadrupole(l=0.32784, k1=6.417661e-01, eid="QF2133")
# Quadrupole(l=0.14602, eid="AC2134")
# Marker(eid="PAC213")
# Quadrupole(l=0.17371, k1=-1.247026e+00, eid="QD2134")
# Marker(eid="PAC214")
# Quadrupole(l=0.17859, eid="AC2141")
# Quadrupole(l=0.32784, k1=7.311534e-01, eid="QF2141")
# Quadrupole(l=0.28816, eid="AC2142")
# Quadrupole(l=0.32784, k1=-7.451637e-01, eid="QD2142")
# Quadrupole(l=0.28616, eid="AC2143")
# Quadrupole(l=0.32784, k1=6.689380e-01, eid="QF2143")
# Quadrupole(l=0.15302, eid="AC2144")
# Marker(eid="PAC214")
# Marker(eid="SC214")
# Marker(eid="SP214")
# Quadrupole(l=0.17371, k1=-1.170827e+00, eid="QD2144")
# Bend(l=0.18000, eid="PX214")
# Quadrupole(l=0.17371, k1=1.197134e+00, eid="QF2145")
# Bend(l=0.18000, tilt=1.570796e+00, eid="PY214")
# Quadrupole(l=0.17371, k1=-1.286432e+00, eid="QD2146")
# Marker(eid="PAC221")
# Quadrupole(l=0.30926, eid="AC2211")
# Quadrupole(l=0.32784, k1=6.505742e-01, eid="QF2211")
# Quadrupole(l=0.52096, eid="AC2212")
# Quadrupole(l=0.32784, k1=-6.729194e-01, eid="QD2212")
# Quadrupole(l=0.40355, eid="AC2213")
# Marker(eid="PAC221")
# Quadrupole(l=0.17371, k1=1.317659e+00, eid="QF2213")
# Marker(eid="PAC222")
# Quadrupole(l=0.39600, eid="AC2221")
# Quadrupole(l=0.32784, k1=-7.175585e-01, eid="QD2221")
# Quadrupole(l=0.47716, eid="AC2222")
# Quadrupole(l=0.32784, k1=7.153572e-01, eid="QF2222")
# Quadrupole(l=0.36061, eid="AC2223")
# Marker(eid="PAC222")
# Marker(eid="SP222")
# Quadrupole(l=0.17371, k1=-1.355209e+00, eid="QD2223")
# Marker(eid="PAC223")
# Quadrupole(l=0.33581, eid="AC2231")
# Quadrupole(l=0.32784, k1=7.324561e-01, eid="QF2231")
# Quadrupole(l=0.50796, eid="AC2232")
# Quadrupole(l=0.32784, k1=-6.231897e-01, eid="QD2232")
# Quadrupole(l=0.39000, eid="AC2233")
# Marker(eid="PAC223")
# Quadrupole(l=0.17371, k1=1.131588e+00, eid="QF2233")
# Marker(eid="PAC224")
# Quadrupole(l=0.40255, eid="AC2241")
# Quadrupole(l=0.32784, k1=-6.340527e-01, eid="QD2241")
# Quadrupole(l=0.48416, eid="AC2242")
# Quadrupole(l=0.32784, k1=6.120353e-01, eid="QF2242")
# Quadrupole(l=0.34706, eid="AC2243")
# Marker(eid="PAC224")
# Marker(eid="WS224")
# Bend(l=0.12000, eid="PX224")
# Marker(eid="SP224")
# Quadrupole(l=0.17371, k1=-9.238112e-01, eid="QD2243")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PY224")
# Marker(eid="PAC231")
# Quadrupole(l=0.35024, eid="AC2311")
# Quadrupole(l=0.32784, k1=5.173862e-01, eid="QF2311")
# Quadrupole(l=0.49376, eid="AC2312")
# Quadrupole(l=0.32784, k1=-5.520880e-01, eid="QD2312")
# Quadrupole(l=0.38977, eid="AC2313")
# Marker(eid="PAC231")
# Quadrupole(l=0.17880, k1=9.944060e-01, eid="PF2313")
# Marker(eid="PAC232")
# Quadrupole(l=0.38278, eid="AC2321")
# Quadrupole(l=0.32784, k1=-5.786425e-01, eid="QD2321")
# Quadrupole(l=0.50216, eid="AC2322")
# Quadrupole(l=0.32784, k1=5.246744e-01, eid="QF2322")
# Quadrupole(l=0.34883, eid="AC2323")
# Marker(eid="PAC232")
# Marker(eid="SP232")
# Quadrupole(l=0.17371, k1=-1.111786e+00, eid="QD2323")
# Marker(eid="PAC233")
# Quadrupole(l=0.31859, eid="AC2331")
# Quadrupole(l=0.32784, k1=5.694511e-01, eid="QF2331")
# Quadrupole(l=0.53996, eid="AC2332")
# Quadrupole(l=0.32784, k1=-6.154474e-01, eid="QD2332")
# Quadrupole(l=0.37522, eid="AC2333")
# Marker(eid="PAC233")
# Quadrupole(l=0.17371, k1=1.406689e+00, eid="QF2333")
# Marker(eid="PAC234")
# Quadrupole(l=0.38433, eid="AC2341")
# Quadrupole(l=0.32784, k1=-5.103899e-01, eid="QD2341")
# Quadrupole(l=0.51416, eid="AC2342")
# Quadrupole(l=0.32784, k1=3.154989e-01, eid="QF2342")
# Quadrupole(l=0.33527, eid="AC2343")
# Marker(eid="PAC234")
# Marker(eid="SP234")
# Quadrupole(l=0.13330, k1=-2.024581e+00, eid="QD2343")
# Bend(eid="PX234")
# Quadrupole(l=0.12610, k1=2.199908e+00, eid="QF2345")
# Marker(eid="SC234")
# Marker(eid="F00")
# Marker(eid="PAC241")
# Cavity(l=0.64250, v=1.349250e-02, freq=2.856000e+09, eid="AC2411")
# Bend(eid="SX241")
# Bend(tilt=1.570796e+00, eid="PY241")
# Cavity(l=1.24695, v=2.618593e-02, freq=2.856000e+09, eid="AC2412")
# Marker(eid="PAC241")
# Marker(eid="SP241")
# Quadrupole(l=0.11150, k1=-2.579572e+00, eid="QD241")
# Quadrupole(l=0.10575, k1=2.717031e+00, eid="QF241")
# Marker(eid="SC241")
# Marker(eid="PAC242")
# Cavity(l=0.63750, v=1.338750e-02, freq=2.856000e+09, eid="AC2421")
# Bend(eid="SX242")
# Bend(tilt=1.570796e+00, eid="SY242")
# Cavity(l=1.25195, v=2.629093e-02, freq=2.856000e+09, eid="AC2422")
# Marker(eid="PAC242")
# Marker(eid="SP242")
# Quadrupole(l=0.11150, k1=-2.666802e+00, eid="QD242")
# Quadrupole(l=0.10575, k1=2.808910e+00, eid="QF242")
# Marker(eid="WS242")
# Marker(eid="PAC243")
# Cavity(l=0.63750, v=1.338750e-02, freq=2.856000e+09, eid="AC2431")
# Bend(eid="SX243")
# Bend(tilt=1.570796e+00, eid="SY243")
# Cavity(l=1.25195, v=2.629093e-02, freq=2.856000e+09, eid="AC2432")
# Marker(eid="PAC243")
# Marker(eid="SP243")
# Quadrupole(l=0.11150, k1=-2.759051e+00, eid="QD243")
# Quadrupole(l=0.10575, k1=2.898690e+00, eid="QF243")
# Marker(eid="SC243")
# Marker(eid="PAC244")
# Cavity(l=0.94472, v=1.983920e-02, freq=2.856000e+09, eid="AC244")
# Marker(eid="PAC244")
# Bend(l=0.18000, eid="PX244")
# Bend(l=0.18000, tilt=1.570796e+00, eid="PY244")
# Marker(eid="SP244")
# Quadrupole(l=0.11150, k1=-3.197029e+00, eid="QD244")
# Quadrupole(l=0.10575, k1=3.141442e+00, eid="QF244")
# Marker(eid="SC244")
# Marker(eid="PAC261")
# Cavity(l=0.63750, freq=2.856000e+09, eid="AC2611")
# Bend(eid="PX261")
# Bend(tilt=1.570796e+00, eid="SY261")
# Cavity(l=1.25195, freq=2.856000e+09, eid="AC2612")
# Marker(eid="PAC261")
# Marker(eid="SP261")
# Quadrupole(l=0.11150, k1=-2.529969e+00, eid="QD261")
# Quadrupole(l=0.10575, k1=2.687392e+00, eid="QF261")
# Marker(eid="WS261")
# Marker(eid="PAC262")
# Cavity(l=0.63750, freq=2.856000e+09, eid="AC2621")
# Bend(eid="SX262")
# Bend(tilt=1.570796e+00, eid="SY262")
# Cavity(l=1.25195, freq=2.856000e+09, eid="AC2622")
# Marker(eid="PAC262")
# Marker(eid="SP262")
# Quadrupole(l=0.11150, k1=-2.832298e+00, eid="QD262")
# Quadrupole(l=0.10575, k1=2.935875e+00, eid="QF262")
# Marker(eid="SC262")
# Marker(eid="PAC263")
# Cavity(l=0.63750, freq=2.856000e+09, eid="AC2631")
# Bend(eid="SX263")
# Bend(tilt=1.570796e+00, eid="SY263")
# Cavity(l=1.25195, freq=2.856000e+09, eid="AC2632")
# Marker(eid="PAC263")
# Marker(eid="SP263")
# Quadrupole(l=0.11150, k1=-2.883126e+00, eid="QD263")
# Quadrupole(l=0.10575, k1=2.856580e+00, eid="QF263")
# Marker(eid="SC263")
# Marker(eid="PAC264")
# Cavity(l=0.63750, freq=2.856000e+09, eid="AC2641")
# Bend(eid="SX264")
# Bend(tilt=1.570796e+00, eid="PY264")
# Cavity(l=1.25195, freq=2.856000e+09, eid="AC2642")
# Marker(eid="PAC264")
# Marker(eid="SP264")
# Quadrupole(l=0.11150, k1=-2.199185e+00, eid="QD264")
# Quadrupole(l=0.10575, k1=2.281813e+00, eid="QF264")
# Marker(eid="SC264")
# Marker(eid="PAC271")
# Cavity(l=0.65603, v=4.668197e-03, freq=2.856000e+09, eid="AC2711")
# Bend(eid="SX271")
# Bend(tilt=1.570796e+00, eid="SY271")
# Cavity(l=1.23342, v=8.776798e-03, freq=2.856000e+09, eid="AC2712")
# Marker(eid="PAC271")
# Marker(eid="PAC272")
# Cavity(l=1.88945, v=1.344499e-02, freq=2.856000e+09, eid="AC272")
# Marker(eid="PAC272")
# Marker(eid="SP272")
# Quadrupole(l=0.13330, k1=-1.821276e+00, eid="QD272")
# Bend(eid="PX272")
# Quadrupole(l=0.12610, k1=1.945125e+00, eid="QF272")
# Marker(eid="WS272")
# Marker(eid="PAC273")
# Cavity(l=0.65603, v=4.668197e-03, freq=2.856000e+09, eid="AC2731")
# Bend(eid="SX273")
# Bend(tilt=1.570796e+00, eid="SY273")
# Cavity(l=1.23342, v=8.776798e-03, freq=2.856000e+09, eid="AC2732")
# Marker(eid="PAC273")
# Marker(eid="PAC274")
# Cavity(l=1.88945, v=1.344499e-02, freq=2.856000e+09, eid="AC274")
# Marker(eid="PAC274")
# Marker(eid="SP274")
# Quadrupole(l=0.13330, k1=-1.901662e+00, eid="QD274")
# Quadrupole(l=0.12610, k1=1.912809e+00, eid="QF274")
# Marker(eid="SC274")
# Marker(eid="PAC281")
# Cavity(l=0.65442, v=4.656769e-03, freq=2.856000e+09, eid="AC2811")
# Bend(eid="SX281")
# Bend(tilt=1.570796e+00, eid="SY281")
# Cavity(l=1.23503, v=8.788226e-03, freq=2.856000e+09, eid="AC2812")
# Marker(eid="PAC281")
# Marker(eid="PAC282")
# Cavity(l=1.88945, v=1.344499e-02, freq=2.856000e+09, eid="AC282")
# Marker(eid="PAC282")
# Marker(eid="SP282")
# Quadrupole(l=0.13330, k1=-1.836157e+00, eid="QD282")
# Bend(tilt=1.570796e+00, eid="PY282")
# Quadrupole(l=0.12610, k1=1.885923e+00, eid="QF282")
# Marker(eid="SC282")
# Marker(eid="PAC283")
# Cavity(l=0.65442, v=4.656769e-03, freq=2.856000e+09, eid="AC2831")
# Bend(eid="SX283")
# Bend(tilt=1.570796e+00, eid="SY283")
# Cavity(l=1.23503, v=8.788226e-03, freq=2.856000e+09, eid="AC2832")
# Marker(eid="PAC283")
# Marker(eid="PAC284")
# Cavity(l=1.88945, v=1.344499e-02, freq=2.856000e+09, eid="AC284")
# Marker(eid="PAC284")
# Marker(eid="SP284")
# Quadrupole(l=0.13330, k1=-1.892729e+00, eid="QD284")
# Quadrupole(l=0.13330, k1=1.917670e+00, eid="QF284")
# Marker(eid="SC284")
# Marker(eid="PEND2")
# Marker(eid="PSY2")
# Marker(eid="JBC1E1S")
# Bend(l=1.07607, angle=-7.694330e-02, e2=-7.694330e-02, eid="BC1E")
# Marker(eid="JBC1E1E")
# Marker(eid="JBC2E1S")
# Bend(l=1.33216, angle=7.694330e-02, e1=3.847165e-02, e2=3.847165e-02, eid="BC2E")
# Marker(eid="JBC2E1E")
# Monitor(eid="SPDC2")
# Marker(eid="JBC2E2S")
# Marker(eid="JBC2E2E")
# Marker(eid="JBC1E2S")
# Marker(eid="JBC1E2E")
# Marker(eid="PSECT3")
# Monitor(eid="SPDC4")
# Quadrupole(l=0.21100, k1=9.045476e-01, eid="PFDC4")
# Bend(l=0.08000, eid="PXDC4")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PYDC4")
# Quadrupole(l=0.21100, k1=-1.052927e+00, eid="PDDC4")
# Cavity(l=0.03900, eid="AK321")
# Marker(eid="PAC321")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC321")
# Bend(eid="SX321")
# Bend(tilt=1.570796e+00, eid="SY321")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC3212")
# Marker(eid="PAC321")
# Cavity(l=0.03900, eid="AK321")
# Cavity(l=0.03900, eid="AK322")
# Marker(eid="PAC322")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC322")
# Marker(eid="PAC322")
# Cavity(l=0.03900, eid="AK322")
# Cavity(l=0.03900, eid="AK323")
# Marker(eid="PAC323")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC323")
# Bend(eid="SX323")
# Bend(tilt=1.570796e+00, eid="SY323")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC3232")
# Marker(eid="PAC323")
# Cavity(l=0.03900, eid="AK323")
# Cavity(l=0.03900, eid="AK324")
# Marker(eid="PAC324")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC324")
# Marker(eid="PAC324")
# Cavity(l=0.03900, eid="AK324")
# Monitor(eid="SP324")
# Quadrupole(l=0.21100, k1=1.062294e+00, eid="PF324")
# Bend(l=0.08000, eid="PX324")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY324")
# Quadrupole(l=0.21100, k1=-9.503135e-01, eid="PD324")
# Cavity(l=0.03900, eid="AK331")
# Marker(eid="PAC331")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC331")
# Bend(eid="SX331")
# Bend(tilt=1.570796e+00, eid="SY331")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC3312")
# Marker(eid="PAC331")
# Cavity(l=0.03900, eid="AK331")
# Cavity(l=0.03900, eid="AK332")
# Marker(eid="PAC332")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC332")
# Marker(eid="PAC332")
# Cavity(l=0.03900, eid="AK332")
# Cavity(l=0.03900, eid="AK333")
# Marker(eid="PAC333")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC333")
# Bend(eid="SX333")
# Bend(tilt=1.570796e+00, eid="SY333")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC3332")
# Marker(eid="PAC333")
# Cavity(l=0.03900, eid="AK333")
# Cavity(l=0.03900, eid="AK334")
# Marker(eid="PAC334")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC334")
# Marker(eid="PAC334")
# Cavity(l=0.03900, eid="AK334")
# Cavity(l=0.03900, eid="AK341")
# Marker(eid="PAC341")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC341")
# Bend(eid="SX341")
# Bend(tilt=1.570796e+00, eid="SY341")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC3412")
# Marker(eid="PAC341")
# Cavity(l=0.03900, eid="AK341")
# Cavity(l=0.03900, eid="AK342")
# Marker(eid="PAC342")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC342")
# Marker(eid="PAC342")
# Cavity(l=0.03900, eid="AK342")
# Cavity(l=0.03900, eid="AK343")
# Marker(eid="PAC343")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC343")
# Bend(eid="SX343")
# Bend(tilt=1.570796e+00, eid="SY343")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC3432")
# Marker(eid="PAC343")
# Cavity(l=0.03900, eid="AK343")
# Cavity(l=0.03900, eid="AK344")
# Marker(eid="PAC344")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC344")
# Marker(eid="PAC344")
# Cavity(l=0.03900, eid="AK344")
# Monitor(eid="SP344")
# Quadrupole(l=0.21100, k1=1.451186e+00, eid="PF344")
# Bend(l=0.08000, eid="PX344")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY344")
# Quadrupole(l=0.21100, k1=-1.487679e+00, eid="PD344")
# Cavity(l=0.03900, eid="AK351")
# Marker(eid="PAC351")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC351")
# Bend(eid="SX351")
# Bend(tilt=1.570796e+00, eid="SY351")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC3512")
# Marker(eid="PAC351")
# Cavity(l=0.03900, eid="AK351")
# ...
# Marker(eid="PAC362")
# Cavity(l=0.03900, eid="AK362")
# Cavity(l=0.03900, eid="AK363")
# Marker(eid="PAC363")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC363")
# Marker(eid="PAC363")
# Cavity(l=0.03900, eid="AK363")
# Cavity(l=0.03900, eid="AK364")
# Marker(eid="PAC364")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC364")
# Marker(eid="PAC364")
# Cavity(l=0.03900, eid="AK364")
# Monitor(eid="SP364")
# Quadrupole(l=0.21100, k1=1.764558e+00, eid="PF364")
# Bend(l=0.08000, eid="PX364")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY364")
# Quadrupole(l=0.21100, k1=-1.765315e+00, eid="PD364")
# Cavity(l=0.03900, eid="AK371")
# Marker(eid="PAC371")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC371")
# Bend(eid="SX371")
# Bend(tilt=1.570796e+00, eid="SY371")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC3712")
# Marker(eid="PAC371")
# Cavity(l=0.03900, eid="AK371")
# Cavity(l=0.03900, eid="AK372")
# Marker(eid="PAC372")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC372")
# Marker(eid="PAC372")
# Cavity(l=0.03900, eid="AK372")
# Cavity(l=0.03900, eid="AK373")
# Marker(eid="PAC373")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC373")
# Bend(eid="SX373")
# Bend(tilt=1.570796e+00, eid="SY373")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC3732")
# Marker(eid="PAC373")
# Cavity(l=0.03900, eid="AK373")
# Cavity(l=0.03900, eid="AK374")
# Marker(eid="PAC374")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC374")
# Marker(eid="PAC374")
# Cavity(l=0.03900, eid="AK374")
# Cavity(l=0.03900, eid="AK381")
# Marker(eid="PAC381")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC381")
# Marker(eid="PAC381")
# Cavity(l=0.03900, eid="AK381")
# Cavity(l=0.03900, eid="AK382")
# Marker(eid="PAC382")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC382")
# Marker(eid="PAC382")
# Cavity(l=0.03900, eid="AK382")
# Cavity(l=0.03900, eid="AK383")
# Marker(eid="PAC383")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC383")
# Marker(eid="PAC383")
# Cavity(l=0.03900, eid="AK383")
# Cavity(l=0.03900, eid="AK384")
# Marker(eid="PAC384")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC384")
# Marker(eid="PAC384")
# Cavity(l=0.03900, eid="AK384")
# Monitor(eid="SP384")
# Quadrupole(l=0.21100, k1=1.708533e+00, eid="PF384")
# Bend(l=0.08000, eid="PX384")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY384")
# Quadrupole(l=0.21100, k1=-1.698429e+00, eid="PD384")
# Marker(eid="PSECT4")
# Cavity(l=0.03900, eid="AK411")
# Marker(eid="PAC411")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC411")
# Marker(eid="PAC411")
# Cavity(l=0.03900, eid="AK411")
# Cavity(l=0.03900, eid="AK412")
# Marker(eid="PAC412")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC412")
# Marker(eid="PAC412")
# Cavity(l=0.03900, eid="AK412")
# Cavity(l=0.03900, eid="AK413")
# Marker(eid="PAC413")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC413")
# Bend(eid="SX413")
# Bend(tilt=1.570796e+00, eid="SY413")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC4132")
# Marker(eid="PAC413")
# Cavity(l=0.03900, eid="AK413")
# Cavity(l=0.03900, eid="AK414")
# Marker(eid="PAC414")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC414")
# Marker(eid="PAC414")
# Cavity(l=0.03900, eid="AK414")
# Cavity(l=0.03900, eid="AK421")
# Marker(eid="PAC421")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC421")
# Marker(eid="PAC421")
# Cavity(l=0.03900, eid="AK421")
# Cavity(l=0.03900, eid="AK422")
# Marker(eid="PAC422")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC422")
# Marker(eid="PAC422")
# Cavity(l=0.03900, eid="AK422")
# Cavity(l=0.03900, eid="AK423")
# Marker(eid="PAC423")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC423")
# Marker(eid="PAC423")
# Cavity(l=0.03900, eid="AK423")
# Cavity(l=0.03900, eid="AK424")
# Marker(eid="PAC424")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC424")
# Marker(eid="PAC424")
# Cavity(l=0.03900, eid="AK424")
# Monitor(eid="SP424")
# Quadrupole(l=0.21100, k1=1.704765e+00, eid="PF424")
# Bend(l=0.08000, eid="PX424")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY424")
# Quadrupole(l=0.21100, k1=-1.714778e+00, eid="PD424")
# Cavity(l=0.03900, eid="AK431")
# Marker(eid="PAC431")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC431")
# Bend(eid="SX431")
# Bend(tilt=1.570796e+00, eid="SY431")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC4312")
# Marker(eid="PAC431")
# Cavity(l=0.03900, eid="AK431")
# Cavity(l=0.03900, eid="AK432")
# Marker(eid="PAC432")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC432")
# Marker(eid="PAC432")
# Cavity(l=0.03900, eid="AK432")
# Cavity(l=0.03900, eid="AK433")
# Marker(eid="PAC433")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC433")
# Bend(eid="SX433")
# Bend(tilt=1.570796e+00, eid="SY433")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC4332")
# Marker(eid="PAC433")
# Cavity(l=0.03900, eid="AK433")
# Cavity(l=0.03900, eid="AK434")
# Marker(eid="PAC434")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC434")
# Marker(eid="PAC434")
# Cavity(l=0.03900, eid="AK434")
# Cavity(l=0.03900, eid="AK441")
# Marker(eid="PAC441")
# Cavity(l=1.88945, freq=2.856000e+09, eid="AC441")
# Marker(eid="PAC441")
# Cavity(l=0.03900, eid="AK441")
# Cavity(l=0.03900, eid="AK442")
# Marker(eid="PAC442")
# Cavity(l=1.88945, freq=2.856000e+09, eid="AC442")
# Marker(eid="PAC442")
# Cavity(l=0.03900, eid="AK442")
# Cavity(l=0.03900, eid="AK443")
# Marker(eid="PAC443")
# Cavity(l=1.88945, freq=2.856000e+09, eid="AC443")
# Marker(eid="PAC443")
# Cavity(l=0.03900, eid="AK443")
# Cavity(l=0.03900, eid="AK444")
# Marker(eid="PAC444")
# Cavity(l=1.88945, freq=2.856000e+09, eid="AC444")
# Marker(eid="PAC444")
# Cavity(l=0.03900, eid="AK444")
# Monitor(eid="SP444")
# Quadrupole(l=0.21100, k1=1.764810e+00, eid="PF444")
# Bend(l=0.08000, eid="PX444")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY444")
# Quadrupole(l=0.21100, k1=-1.764929e+00, eid="PD444")
# Cavity(l=0.03900, eid="AK451")
# Marker(eid="PAC451")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC451")
# Bend(eid="SX451")
# Bend(tilt=1.570796e+00, eid="SY451")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC4512")
# Marker(eid="PAC451")
# Cavity(l=0.03900, eid="AK451")
# Cavity(l=0.03900, eid="AK452")
# Marker(eid="PAC452")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC452")
# Marker(eid="PAC452")
# Cavity(l=0.03900, eid="AK452")
# Cavity(l=0.03900, eid="AK453")
# Marker(eid="PAC453")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC453")
# Bend(eid="SX453")
# Bend(tilt=1.570796e+00, eid="SY453")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC4532")
# Marker(eid="PAC453")
# Cavity(l=0.03900, eid="AK453")
# Cavity(l=0.03900, eid="AK454")
# Marker(eid="PAC454")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC454")
# Marker(eid="PAC454")
# Cavity(l=0.03900, eid="AK454")
# Cavity(l=0.03900, eid="AK461")
# Marker(eid="PAC461")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC461")
# Marker(eid="PAC461")
# Cavity(l=0.03900, eid="AK461")
# Cavity(l=0.03900, eid="AK462")
# Marker(eid="PAC462")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC462")
# Marker(eid="PAC462")
# Cavity(l=0.03900, eid="AK462")
# Cavity(l=0.03900, eid="AK463")
# Marker(eid="PAC463")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC463")
# Marker(eid="PAC463")
# Cavity(l=0.03900, eid="AK463")
# Cavity(l=0.03900, eid="AK464")
# Marker(eid="PAC464")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC464")
# Marker(eid="PAC464")
# Cavity(l=0.03900, eid="AK464")
# Monitor(eid="SP464")
# Quadrupole(l=0.21100, k1=1.764681e+00, eid="PF464")
# Bend(l=0.08000, eid="PX464")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY464")
# Quadrupole(l=0.21100, k1=-1.764682e+00, eid="PD464")
# Cavity(l=0.03900, eid="AK471")
# Marker(eid="PAC471")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC471")
# Bend(eid="SX471")
# Bend(tilt=1.570796e+00, eid="SY471")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC4712")
# Marker(eid="PAC471")
# Cavity(l=0.03900, eid="AK471")
# Cavity(l=0.03900, eid="AK472")
# Marker(eid="PAC472")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC472")
# Marker(eid="PAC472")
# Cavity(l=0.03900, eid="AK472")
# Cavity(l=0.03900, eid="AK473")
# Marker(eid="PAC473")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC473")
# Bend(eid="SX473")
# Bend(tilt=1.570796e+00, eid="SY473")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC4732")
# Marker(eid="PAC473")
# Cavity(l=0.03900, eid="AK473")
# Cavity(l=0.03900, eid="AK474")
# Marker(eid="PAC474")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC474")
# Marker(eid="PAC474")
# Cavity(l=0.03900, eid="AK474")
# Cavity(l=0.03900, eid="AK481")
# Marker(eid="PAC481")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC481")
# Marker(eid="PAC481")
# Cavity(l=0.03900, eid="AK481")
# Cavity(l=0.03900, eid="AK482")
# Marker(eid="PAC482")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC482")
# Marker(eid="PAC482")
# Cavity(l=0.03900, eid="AK482")
# Cavity(l=0.03900, eid="AK483")
# Marker(eid="PAC483")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC483")
# Marker(eid="PAC483")
# Cavity(l=0.03900, eid="AK483")
# Cavity(l=0.03900, eid="AK484")
# Marker(eid="PAC484")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC484")
# Marker(eid="PAC484")
# Cavity(l=0.03900, eid="AK484")
# Monitor(eid="SP484")
# Quadrupole(l=0.21100, k1=1.708723e+00, eid="PF484")
# Bend(l=0.08000, eid="PX484")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY484")
# Quadrupole(l=0.21100, k1=-1.698631e+00, eid="PD484")
# Marker(eid="PSECT5")
# Cavity(l=0.03900, eid="AK511")
# Marker(eid="PAC511")
# Cavity(l=1.88945, v=6.596227e-03, freq=2.856000e+09, eid="AC511")
# Marker(eid="PAC511")
# Cavity(l=0.03900, eid="AK511")
# Cavity(l=0.03900, eid="AK512")
# Marker(eid="PAC512")
# Cavity(l=1.88945, v=6.596227e-03, freq=2.856000e+09, eid="AC512")
# Marker(eid="PAC512")
# Cavity(l=0.03900, eid="AK512")
# Cavity(l=0.03900, eid="AK513")
# Marker(eid="PAC513")
# Cavity(l=0.55984, v=1.954438e-03, freq=2.856000e+09, eid="AC513")
# Bend(eid="SX513")
# Bend(tilt=1.570796e+00, eid="SY513")
# Cavity(l=1.32961, v=4.641790e-03, freq=2.856000e+09, eid="AC5132")
# Marker(eid="PAC513")
# Cavity(l=0.03900, eid="AK513")
# Cavity(l=0.03900, eid="AK514")
# Marker(eid="PAC514")
# Cavity(l=1.88945, v=6.596227e-03, freq=2.856000e+09, eid="AC514")
# Marker(eid="PAC514")
# Cavity(l=0.03900, eid="AK514")
# Cavity(l=0.03900, eid="AK521")
# Marker(eid="PAC521")
# Cavity(l=1.88945, v=6.596227e-03, freq=2.856000e+09, eid="AC521")
# Marker(eid="PAC521")
# Cavity(l=0.03900, eid="AK521")
# Cavity(l=0.03900, eid="AK522")
# Marker(eid="PAC522")
# Cavity(l=1.88945, v=6.596227e-03, freq=2.856000e+09, eid="AC522")
# Marker(eid="PAC522")
# Cavity(l=0.03900, eid="AK522")
# Cavity(l=0.03900, eid="AK523")
# Marker(eid="PAC523")
# Cavity(l=1.88945, v=6.596227e-03, freq=2.856000e+09, eid="AC523")
# Marker(eid="PAC523")
# Cavity(l=0.03900, eid="AK523")
# Cavity(l=0.03900, eid="AK524")
# Marker(eid="PAC524")
# Cavity(l=1.88945, v=6.596227e-03, freq=2.856000e+09, eid="AC524")
# Marker(eid="PAC524")
# Cavity(l=0.03900, eid="AK524")
# Monitor(eid="SP524")
# Quadrupole(l=0.21100, k1=1.705004e+00, eid="PF524")
# Bend(l=0.08000, eid="PX524")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY524")
# Quadrupole(l=0.21100, k1=-1.714995e+00, eid="PD524")
# Cavity(l=0.03900, eid="AK531")
# Marker(eid="PAC531")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC531")
# Bend(eid="SX531")
# Bend(tilt=1.570796e+00, eid="SY531")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC5312")
# Marker(eid="PAC531")
# Cavity(l=0.03900, eid="AK531")
# Cavity(l=0.03900, eid="AK532")
# Marker(eid="PAC532")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC532")
# Marker(eid="PAC532")
# Cavity(l=0.03900, eid="AK532")
# Cavity(l=0.03900, eid="AK533")
# Marker(eid="PAC533")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC533")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC5332")
# Marker(eid="PAC533")
# Cavity(l=0.03900, eid="AK533")
# Cavity(l=0.03900, eid="AK534")
# Marker(eid="PAC534")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC534")
# Marker(eid="PAC534")
# Cavity(l=0.03900, eid="AK534")
# Cavity(l=0.03900, eid="AK541")
# Marker(eid="PAC541")
# Cavity(l=1.88945, freq=2.856000e+09, eid="AC541")
# Marker(eid="PAC541")
# Cavity(l=0.03900, eid="AK541")
# Cavity(l=0.03900, eid="AK542")
# Marker(eid="PAC542")
# Cavity(l=1.88945, freq=2.856000e+09, eid="AC542")
# Marker(eid="PAC542")
# Cavity(l=0.03900, eid="AK542")
# Cavity(l=0.03900, eid="AK543")
# Marker(eid="PAC543")
# Cavity(l=1.88945, freq=2.856000e+09, eid="AC543")
# Marker(eid="PAC543")
# Cavity(l=0.03900, eid="AK543")
# Cavity(l=0.03900, eid="AK544")
# Marker(eid="PAC544")
# Cavity(l=1.88945, freq=2.856000e+09, eid="AC544")
# Marker(eid="PAC544")
# Cavity(l=0.03900, eid="AK544")
# Monitor(eid="SP544")
# Quadrupole(l=0.21100, k1=1.764848e+00, eid="PF544")
# Bend(l=0.08000, eid="PX544")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY544")
# Quadrupole(l=0.21100, k1=-1.764971e+00, eid="PD544")
# Cavity(l=0.03499, eid="AK551")
# Marker(eid="PAC551")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC551")
# Bend(eid="SX551")
# Bend(tilt=1.570796e+00, eid="SY551")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC5512")
# Marker(eid="PAC551")
# Cavity(l=0.03499, eid="AK551")
# Cavity(l=0.03499, eid="AK552")
# Marker(eid="PAC552")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC552")
# Marker(eid="PAC552")
# Cavity(l=0.03499, eid="AK552")
# Cavity(l=0.03499, eid="AK553")
# Marker(eid="PAC553")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC553")
# Bend(eid="SX553")
# Bend(tilt=1.570796e+00, eid="SY553")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC5532")
# Marker(eid="PAC553")
# Cavity(l=0.03499, eid="AK553")
# Cavity(l=0.03499, eid="AK554")
# Marker(eid="PAC554")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC554")
# Marker(eid="PAC554")
# Cavity(l=0.03499, eid="AK554")
# Cavity(l=0.03900, eid="AK561")
# Marker(eid="PAC561")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC561")
# Marker(eid="PAC561")
# Cavity(l=0.03900, eid="AK561")
# Cavity(l=0.03900, eid="AK562")
# Marker(eid="PAC562")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC562")
# Marker(eid="PAC562")
# Cavity(l=0.03900, eid="AK562")
# Cavity(l=0.03900, eid="AK563")
# Marker(eid="PAC563")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC563")
# Marker(eid="PAC563")
# Cavity(l=0.03900, eid="AK563")
# Cavity(l=0.03900, eid="AK564")
# Marker(eid="PAC564")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC564")
# Marker(eid="PAC564")
# Cavity(l=0.03900, eid="AK564")
# Monitor(eid="SP564")
# Quadrupole(l=0.21100, k1=1.947072e+00, eid="PF564")
# Bend(l=0.08000, eid="PX564")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY564")
# Quadrupole(l=0.21100, k1=-1.851078e+00, eid="PD564")
# Cavity(l=0.03900, eid="AK571")
# Marker(eid="PAC571")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC571")
# Bend(eid="SX571")
# Bend(tilt=1.570796e+00, eid="SY571")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC5712")
# Marker(eid="PAC571")
# Cavity(l=0.03900, eid="AK571")
# Cavity(l=0.03900, eid="AK572")
# Marker(eid="PAC572")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC572")
# Marker(eid="PAC572")
# Cavity(l=0.03900, eid="AK572")
# Cavity(l=0.03900, eid="AK573")
# Marker(eid="PAC573")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="AC573")
# Bend(eid="SX573")
# Bend(tilt=1.570796e+00, eid="SY573")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="AC5732")
# Marker(eid="PAC573")
# Cavity(l=0.03900, eid="AK573")
# Cavity(l=0.03900, eid="AK574")
# Marker(eid="PAC574")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="AC574")
# Marker(eid="PAC574")
# Cavity(l=0.03900, eid="AK574")
# Marker(eid="PM574")
# Monitor(eid="SP580")
# Marker(eid="PBT")
# Bend(l=0.99226, eid="BP581")
# Bend(l=0.28800, tilt=1.570796e+00, eid="FY584")
# Monitor(eid="SP584")
# Quadrupole(l=0.21100, k1=1.770773e+00, eid="PF584")
# Bend(l=0.08000, eid="PX584")
# Bend(l=0.08000, tilt=1.570796e+00, eid="PY584")
# Quadrupole(l=0.21100, k1=-1.611993e+00, eid="PD584")
# Marker(eid="PSECT6")
# Marker(eid="ID_33329108_")

# %%
def gauss_from_twiss_vec(emit, beta, alpha, size=1):
    phi = 2 * np.pi * np.random.rand(size)
    u = np.random.rand(size)
    a = np.sqrt(-2 * np.log(1 - u) * emit)
    x = a * np.sqrt(beta) * np.cos(phi)
    xp = -a / np.sqrt(beta) * (np.sin(phi) + alpha * np.cos(phi))
    return x, xp

nparticles = 100000
p_array = ParticleArray(n=nparticles)

# sigma_tau = 6.7e-3  # (bunch length in)
# sigma_p = 5.e-4     # relative momentum spread (Δp/p)  

sigma_tau = 4e-3  # (bunch length in )
sigma_p = 0.001     # relative momentum spread (Δp/p)  


p_array.E = energy  # GeV

# Longitudinal
p_array.rparticles[4] = np.random.randn(nparticles) * sigma_tau
p_array.rparticles[5] = np.random.randn(nparticles) * sigma_p

# Transverse: vectorized sampling from Twiss parameters
x, xp = gauss_from_twiss_vec(tw0.emit_x, tw0.beta_x, tw0.alpha_x, size=nparticles)
y, yp = gauss_from_twiss_vec(tw0.emit_y, tw0.beta_y, tw0.alpha_y, size=nparticles)

p_array.rparticles[0] = x
p_array.rparticles[1] = xp
p_array.rparticles[2] = y
p_array.rparticles[3] = yp

# Charge distribution
charge = 4.0e-9  # nC
p_array.q_array = np.ones(nparticles) * (charge / nparticles)

# %%
from ocelot.cpbd.physics_proc import PhysProc
import numpy as np

class CustomLongitudinalWake(PhysProc):
    def __init__(self, beam_radius=0.01, bunch_length=4e-3, scale=1.0):
        super().__init__()
        self.Z0 = 377  # Ohm
        self.a = beam_radius
        self.L = bunch_length
        self.N = None
        self.scale = scale  # scaling factor for wake strength

    def apply(self, p_array, step_size):
        z = p_array.rparticles[4]
        q = p_array.q_array

        if self.N is None:
            self.N = len(z)
        
        z_mean = np.mean(z)
        x = (z - z_mean) / self.L  # normalized coordinate

        # Define the first two orthogonal modes:
        f0 = np.exp(-0.5 * x**2)           # symmetric
        f1 = x * np.exp(-0.5 * x**2)        # antisymmetric

        # Combine modes (you can adjust relative weights if you want)
        f_combined = f0 + 0.5 * f1   # 0.5 weight on f1 to see structure

        # Prefactor from theory
        prefactor = -(self.N * np.abs(q[0]) * self.Z0) / (np.sqrt(2*np.pi) * self.a**2 * self.L)

        voltage = prefactor * f_combined
        voltage *= self.scale  # Apply scaling

        # Apply energy kick
        delta_E = voltage * step_size
        E = p_array.E  # total energy [GeV]
        delta_dp_p = delta_E / (E * 1e9)  # convert eV to GeV

        p_array.rparticles[5] += delta_dp_p

# %%
import time
from copy import deepcopy
import numpy as np
import matplotlib.pyplot as plt
from ocelot.cpbd.physics_proc import PhysProc

# Define the HookProcess to monitor sigma_tau
class HookProcess(PhysProc):
    def __init__(self, sigma_tau_list):
        super().__init__()
        self.sigma_tau_list = sigma_tau_list

    def apply(self, p_array, step_size):
        sigma_tau = np.std(p_array.rparticles[4])
        self.sigma_tau_list.append(sigma_tau)
        print(f"s = {self.z0:.3f} m, σ_τ = {sigma_tau:.3e} s")


# Seed microbunching: small sinusoidal modulation
k_b = 2 * np.pi / (2e-3)  # 2 mm wavelength
mod_amp = 1e-4  # small amplitude ripple
p_array.rparticles[4] += mod_amp * np.sin(k_b * p_array.rparticles[4])


# === TRACK WITHOUT WAKEFIELD ===
p_array_no_wake = deepcopy(p_array)

navi_no_wake = Navigator(lat)
navi_no_wake.unit_step = 0.5

sigma_tau_list_no_wake = []
hook_no_wake = HookProcess(sigma_tau_list_no_wake)
navi_no_wake.add_physics_proc(hook_no_wake, lat.sequence[0], lat.sequence[-1])

tws_no_wake, p_array_no_wake = track(lat, p_array_no_wake, navi_no_wake)

# === TRACK WITH CUSTOM WAKEFIELD ===
p_array_wake = deepcopy(p_array)

navi_wake = Navigator(lat)
navi_wake.unit_step = 0.5

sigma_tau_list_wake = []
hook_wake = HookProcess(sigma_tau_list_wake)
navi_wake.add_physics_proc(hook_wake, lat.sequence[0], lat.sequence[-1])

# Add custom wake
wake_proc = CustomLongitudinalWake(beam_radius=0.01, bunch_length=sigma_tau)
navi_wake.add_physics_proc(wake_proc, lat.sequence[0], lat.sequence[-1])

tws_wake, p_array_wake = track(lat, p_array_wake, navi_wake)

# === PLOT THE COMPARISON ===
s_axis_no_wake = np.linspace(0, lat.totalLen, len(sigma_tau_list_no_wake))
s_axis_wake = np.linspace(0, lat.totalLen, len(sigma_tau_list_wake))

plt.plot(s_axis_no_wake, sigma_tau_list_no_wake, label='No Wake')
plt.plot(s_axis_wake, sigma_tau_list_wake, '--', label='With Custom Wake')
plt.xlabel("s [m]")
plt.ylabel("σ_τ [s]")
plt.title("Evolution of Bunch Length σ_τ With and Without Wakefield")
plt.grid(True)
plt.legend()
plt.show()

# === PHASE SPACE PLOTS ===
def plot_phase_space(z, dp_p, title):
    plt.figure(figsize=(8,6))
    hb = plt.hexbin(z*1e3, dp_p, gridsize=100, cmap='plasma', bins='log')
    plt.colorbar(hb, label='log(Particle density)')
    plt.xlabel('z [mm]')
    plt.ylabel('Δp/p')
    plt.title(title)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# No wake
plot_phase_space(p_array_no_wake.rparticles[4], p_array_no_wake.rparticles[5], 'No Wake')

# With wake
plot_phase_space(p_array_wake.rparticles[4], p_array_wake.rparticles[5], 'With Custom Wake')
# Out:
# s = 0.500 m, σ_τ = 3.991e-03 s
# z = 0.5 / 640.073448422781. Applied: HookProcesss = 1.000 m, σ_τ = 3.991e-03 s
# z = 1.0 / 640.073448422781. Applied: HookProcesss = 1.500 m, σ_τ = 3.991e-03 s
# z = 1.5 / 640.073448422781. Applied: HookProcesss = 2.000 m, σ_τ = 3.985e-03 s
# z = 2.0 / 640.073448422781. Applied: HookProcesss = 2.500 m, σ_τ = 3.941e-03 s
# z = 2.5 / 640.073448422781. Applied: HookProcesss = 3.000 m, σ_τ = 3.896e-03 s
# z = 3.0 / 640.073448422781. Applied: HookProcesss = 3.500 m, σ_τ = 3.860e-03 s
# z = 3.5 / 640.073448422781. Applied: HookProcesss = 4.000 m, σ_τ = 3.832e-03 s
# z = 4.0 / 640.073448422781. Applied: HookProcesss = 4.500 m, σ_τ = 3.806e-03 s
# z = 4.5 / 640.073448422781. Applied: HookProcesss = 5.000 m, σ_τ = 3.857e-03 s
# z = 5.0 / 640.073448422781. Applied: HookProcesss = 5.500 m, σ_τ = 2.351e-03 s
# z = 5.5 / 640.073448422781. Applied: HookProcesss = 6.000 m, σ_τ = 1.032e-03 s
# z = 6.0 / 640.073448422781. Applied: HookProcesss = 6.500 m, σ_τ = 1.059e-03 s
# z = 6.5 / 640.073448422781. Applied: HookProcesss = 7.000 m, σ_τ = 1.042e-03 s
# z = 7.0 / 640.073448422781. Applied: HookProcesss = 7.500 m, σ_τ = 1.025e-03 s
# z = 7.5 / 640.073448422781. Applied: HookProcesss = 8.000 m, σ_τ = 1.008e-03 s
# z = 8.0 / 640.073448422781. Applied: HookProcesss = 8.500 m, σ_τ = 9.921e-04 s
# z = 8.5 / 640.073448422781. Applied: HookProcesss = 9.000 m, σ_τ = 9.764e-04 s
# z = 9.0 / 640.073448422781. Applied: HookProcesss = 9.500 m, σ_τ = 9.612e-04 s
# z = 9.5 / 640.073448422781. Applied: HookProcesss = 10.000 m, σ_τ = 9.497e-04 s
# z = 10.0 / 640.073448422781. Applied: HookProcesss = 10.500 m, σ_τ = 9.449e-04 s
# z = 10.5 / 640.073448422781. Applied: HookProcesss = 11.000 m, σ_τ = 9.425e-04 s
# z = 11.0 / 640.073448422781. Applied: HookProcesss = 11.500 m, σ_τ = 9.412e-04 s
# z = 11.5 / 640.073448422781. Applied: HookProcesss = 12.000 m, σ_τ = 9.402e-04 s
# z = 12.0 / 640.073448422781. Applied: HookProcesss = 12.500 m, σ_τ = 9.392e-04 s
# z = 12.5 / 640.073448422781. Applied: HookProcesss = 13.000 m, σ_τ = 9.385e-04 s
# z = 13.0 / 640.073448422781. Applied: HookProcesss = 13.500 m, σ_τ = 9.380e-04 s
# z = 13.5 / 640.073448422781. Applied: HookProcesss = 14.000 m, σ_τ = 9.377e-04 s
# z = 14.0 / 640.073448422781. Applied: HookProcesss = 14.500 m, σ_τ = 9.374e-04 s
# z = 14.5 / 640.073448422781. Applied: HookProcesss = 15.000 m, σ_τ = 9.372e-04 s
# z = 15.0 / 640.073448422781. Applied: HookProcesss = 15.500 m, σ_τ = 9.370e-04 s
# z = 15.5 / 640.073448422781. Applied: HookProcesss = 16.000 m, σ_τ = 9.368e-04 s
# z = 16.0 / 640.073448422781. Applied: HookProcesss = 16.500 m, σ_τ = 9.367e-04 s
# z = 16.5 / 640.073448422781. Applied: HookProcesss = 17.000 m, σ_τ = 9.366e-04 s
# z = 17.0 / 640.073448422781. Applied: HookProcesss = 17.500 m, σ_τ = 9.366e-04 s
# z = 17.5 / 640.073448422781. Applied: HookProcesss = 18.000 m, σ_τ = 9.365e-04 s
# z = 18.0 / 640.073448422781. Applied: HookProcesss = 18.500 m, σ_τ = 9.364e-04 s
# z = 18.5 / 640.073448422781. Applied: HookProcesss = 19.000 m, σ_τ = 9.364e-04 s
# z = 19.0 / 640.073448422781. Applied: HookProcesss = 19.500 m, σ_τ = 9.363e-04 s
# z = 19.5 / 640.073448422781. Applied: HookProcesss = 20.000 m, σ_τ = 9.363e-04 s
# z = 20.0 / 640.073448422781. Applied: HookProcesss = 20.500 m, σ_τ = 9.363e-04 s
# z = 20.5 / 640.073448422781. Applied: HookProcesss = 21.000 m, σ_τ = 9.362e-04 s
# z = 21.0 / 640.073448422781. Applied: HookProcesss = 21.500 m, σ_τ = 9.362e-04 s
# z = 21.5 / 640.073448422781. Applied: HookProcesss = 22.000 m, σ_τ = 9.362e-04 s
# z = 22.0 / 640.073448422781. Applied: HookProcesss = 22.500 m, σ_τ = 9.362e-04 s
# z = 22.5 / 640.073448422781. Applied: HookProcesss = 23.000 m, σ_τ = 9.362e-04 s
# z = 23.0 / 640.073448422781. Applied: HookProcesss = 23.500 m, σ_τ = 9.362e-04 s
# z = 23.5 / 640.073448422781. Applied: HookProcesss = 24.000 m, σ_τ = 9.361e-04 s
# z = 24.0 / 640.073448422781. Applied: HookProcesss = 24.500 m, σ_τ = 9.361e-04 s
# z = 24.5 / 640.073448422781. Applied: HookProcesss = 25.000 m, σ_τ = 9.361e-04 s
# z = 25.0 / 640.073448422781. Applied: HookProcesss = 25.500 m, σ_τ = 9.361e-04 s
# z = 25.5 / 640.073448422781. Applied: HookProcesss = 26.000 m, σ_τ = 9.361e-04 s
# z = 26.0 / 640.073448422781. Applied: HookProcesss = 26.500 m, σ_τ = 9.361e-04 s
# z = 26.5 / 640.073448422781. Applied: HookProcesss = 27.000 m, σ_τ = 9.361e-04 s
# z = 27.0 / 640.073448422781. Applied: HookProcesss = 27.500 m, σ_τ = 9.361e-04 s
# z = 27.5 / 640.073448422781. Applied: HookProcesss = 28.000 m, σ_τ = 9.361e-04 s
# z = 28.0 / 640.073448422781. Applied: HookProcesss = 28.500 m, σ_τ = 9.361e-04 s
# z = 28.5 / 640.073448422781. Applied: HookProcesss = 29.000 m, σ_τ = 9.361e-04 s
# z = 29.0 / 640.073448422781. Applied: HookProcesss = 29.500 m, σ_τ = 9.361e-04 s
# z = 29.5 / 640.073448422781. Applied: HookProcesss = 30.000 m, σ_τ = 9.361e-04 s
# z = 30.0 / 640.073448422781. Applied: HookProcesss = 30.500 m, σ_τ = 9.361e-04 s
# z = 30.5 / 640.073448422781. Applied: HookProcesss = 31.000 m, σ_τ = 9.361e-04 s
# z = 31.0 / 640.073448422781. Applied: HookProcesss = 31.500 m, σ_τ = 9.361e-04 s
# z = 31.5 / 640.073448422781. Applied: HookProcesss = 32.000 m, σ_τ = 9.361e-04 s
# z = 32.0 / 640.073448422781. Applied: HookProcesss = 32.500 m, σ_τ = 9.361e-04 s
# z = 32.5 / 640.073448422781. Applied: HookProcesss = 33.000 m, σ_τ = 9.361e-04 s
# z = 33.0 / 640.073448422781. Applied: HookProcesss = 33.500 m, σ_τ = 9.361e-04 s
# z = 33.5 / 640.073448422781. Applied: HookProcesss = 34.000 m, σ_τ = 9.361e-04 s
# z = 34.0 / 640.073448422781. Applied: HookProcesss = 34.500 m, σ_τ = 9.361e-04 s
# z = 34.5 / 640.073448422781. Applied: HookProcesss = 35.000 m, σ_τ = 9.361e-04 s
# z = 35.0 / 640.073448422781. Applied: HookProcesss = 35.500 m, σ_τ = 9.361e-04 s
# z = 35.5 / 640.073448422781. Applied: HookProcesss = 36.000 m, σ_τ = 9.361e-04 s
# z = 36.0 / 640.073448422781. Applied: HookProcesss = 36.500 m, σ_τ = 9.361e-04 s
# z = 36.5 / 640.073448422781. Applied: HookProcesss = 37.000 m, σ_τ = 9.361e-04 s
# z = 37.0 / 640.073448422781. Applied: HookProcesss = 37.500 m, σ_τ = 9.361e-04 s
# z = 37.5 / 640.073448422781. Applied: HookProcesss = 38.000 m, σ_τ = 9.361e-04 s
# z = 38.0 / 640.073448422781. Applied: HookProcesss = 38.500 m, σ_τ = 9.361e-04 s
# z = 38.5 / 640.073448422781. Applied: HookProcesss = 39.000 m, σ_τ = 9.362e-04 s
# z = 39.0 / 640.073448422781. Applied: HookProcesss = 39.500 m, σ_τ = 9.362e-04 s
# z = 39.5 / 640.073448422781. Applied: HookProcesss = 40.000 m, σ_τ = 9.362e-04 s
# z = 40.0 / 640.073448422781. Applied: HookProcesss = 40.500 m, σ_τ = 9.362e-04 s
# z = 40.5 / 640.073448422781. Applied: HookProcesss = 41.000 m, σ_τ = 9.362e-04 s
# z = 41.0 / 640.073448422781. Applied: HookProcesss = 41.500 m, σ_τ = 9.362e-04 s
# z = 41.5 / 640.073448422781. Applied: HookProcesss = 42.000 m, σ_τ = 9.362e-04 s
# z = 42.0 / 640.073448422781. Applied: HookProcesss = 42.500 m, σ_τ = 9.362e-04 s
# z = 42.5 / 640.073448422781. Applied: HookProcesss = 43.000 m, σ_τ = 9.362e-04 s
# z = 43.0 / 640.073448422781. Applied: HookProcesss = 43.500 m, σ_τ = 9.362e-04 s
# z = 43.5 / 640.073448422781. Applied: HookProcesss = 44.000 m, σ_τ = 9.362e-04 s
# z = 44.0 / 640.073448422781. Applied: HookProcesss = 44.500 m, σ_τ = 9.362e-04 s
# z = 44.5 / 640.073448422781. Applied: HookProcesss = 45.000 m, σ_τ = 9.362e-04 s
# z = 45.0 / 640.073448422781. Applied: HookProcesss = 45.500 m, σ_τ = 9.362e-04 s
# z = 45.5 / 640.073448422781. Applied: HookProcesss = 46.000 m, σ_τ = 9.362e-04 s
# z = 46.0 / 640.073448422781. Applied: HookProcesss = 46.500 m, σ_τ = 9.362e-04 s
# z = 46.5 / 640.073448422781. Applied: HookProcesss = 47.000 m, σ_τ = 9.362e-04 s
# z = 47.0 / 640.073448422781. Applied: HookProcesss = 47.500 m, σ_τ = 9.362e-04 s
# z = 47.5 / 640.073448422781. Applied: HookProcesss = 48.000 m, σ_τ = 9.362e-04 s
# z = 48.0 / 640.073448422781. Applied: HookProcesss = 48.500 m, σ_τ = 9.362e-04 s
# z = 48.5 / 640.073448422781. Applied: HookProcesss = 49.000 m, σ_τ = 9.362e-04 s
# z = 49.0 / 640.073448422781. Applied: HookProcesss = 49.500 m, σ_τ = 9.362e-04 s
# z = 49.5 / 640.073448422781. Applied: HookProcesss = 50.000 m, σ_τ = 9.362e-04 s
# z = 50.0 / 640.073448422781. Applied: HookProcesss = 50.500 m, σ_τ = 9.362e-04 s
# z = 50.5 / 640.073448422781. Applied: HookProcesss = 51.000 m, σ_τ = 9.362e-04 s
# z = 51.0 / 640.073448422781. Applied: HookProcesss = 51.500 m, σ_τ = 9.362e-04 s
# z = 51.5 / 640.073448422781. Applied: HookProcesss = 52.000 m, σ_τ = 9.362e-04 s
# z = 52.0 / 640.073448422781. Applied: HookProcesss = 52.500 m, σ_τ = 9.362e-04 s
# z = 52.5 / 640.073448422781. Applied: HookProcesss = 53.000 m, σ_τ = 9.362e-04 s
# z = 53.0 / 640.073448422781. Applied: HookProcesss = 53.500 m, σ_τ = 9.362e-04 s
# z = 53.5 / 640.073448422781. Applied: HookProcesss = 54.000 m, σ_τ = 9.362e-04 s
# z = 54.0 / 640.073448422781. Applied: HookProcesss = 54.500 m, σ_τ = 9.362e-04 s
# z = 54.5 / 640.073448422781. Applied: HookProcesss = 55.000 m, σ_τ = 9.362e-04 s
# z = 55.0 / 640.073448422781. Applied: HookProcesss = 55.500 m, σ_τ = 9.362e-04 s
# z = 55.5 / 640.073448422781. Applied: HookProcesss = 56.000 m, σ_τ = 9.362e-04 s
# z = 56.0 / 640.073448422781. Applied: HookProcesss = 56.500 m, σ_τ = 9.362e-04 s
# z = 56.5 / 640.073448422781. Applied: HookProcesss = 57.000 m, σ_τ = 9.362e-04 s
# z = 57.0 / 640.073448422781. Applied: HookProcesss = 57.500 m, σ_τ = 9.362e-04 s
# z = 57.5 / 640.073448422781. Applied: HookProcesss = 58.000 m, σ_τ = 9.362e-04 s
# z = 58.0 / 640.073448422781. Applied: HookProcesss = 58.500 m, σ_τ = 9.362e-04 s
# z = 58.5 / 640.073448422781. Applied: HookProcesss = 59.000 m, σ_τ = 9.362e-04 s
# z = 59.0 / 640.073448422781. Applied: HookProcesss = 59.500 m, σ_τ = 9.362e-04 s
# z = 59.5 / 640.073448422781. Applied: HookProcesss = 60.000 m, σ_τ = 9.362e-04 s
# z = 60.0 / 640.073448422781. Applied: HookProcesss = 60.500 m, σ_τ = 9.362e-04 s
# z = 60.5 / 640.073448422781. Applied: HookProcesss = 61.000 m, σ_τ = 9.362e-04 s
# z = 61.0 / 640.073448422781. Applied: HookProcesss = 61.500 m, σ_τ = 9.362e-04 s
# z = 61.5 / 640.073448422781. Applied: HookProcesss = 62.000 m, σ_τ = 9.362e-04 s
# z = 62.0 / 640.073448422781. Applied: HookProcesss = 62.500 m, σ_τ = 9.362e-04 s
# z = 62.5 / 640.073448422781. Applied: HookProcesss = 63.000 m, σ_τ = 9.362e-04 s
# z = 63.0 / 640.073448422781. Applied: HookProcesss = 63.500 m, σ_τ = 9.362e-04 s
# z = 63.5 / 640.073448422781. Applied: HookProcesss = 64.000 m, σ_τ = 9.362e-04 s
# z = 64.0 / 640.073448422781. Applied: HookProcesss = 64.500 m, σ_τ = 9.362e-04 s
# z = 64.5 / 640.073448422781. Applied: HookProcesss = 65.000 m, σ_τ = 9.362e-04 s
# z = 65.0 / 640.073448422781. Applied: HookProcesss = 65.500 m, σ_τ = 9.362e-04 s
# z = 65.5 / 640.073448422781. Applied: HookProcesss = 66.000 m, σ_τ = 9.362e-04 s
# z = 66.0 / 640.073448422781. Applied: HookProcesss = 66.500 m, σ_τ = 9.362e-04 s
# z = 66.5 / 640.073448422781. Applied: HookProcesss = 67.000 m, σ_τ = 9.362e-04 s
# z = 67.0 / 640.073448422781. Applied: HookProcesss = 67.500 m, σ_τ = 9.362e-04 s
# z = 67.5 / 640.073448422781. Applied: HookProcesss = 68.000 m, σ_τ = 9.362e-04 s
# z = 68.0 / 640.073448422781. Applied: HookProcesss = 68.500 m, σ_τ = 9.362e-04 s
# z = 68.5 / 640.073448422781. Applied: HookProcesss = 69.000 m, σ_τ = 9.362e-04 s
# z = 69.0 / 640.073448422781. Applied: HookProcesss = 69.500 m, σ_τ = 9.362e-04 s
# z = 69.5 / 640.073448422781. Applied: HookProcesss = 70.000 m, σ_τ = 9.362e-04 s
# z = 70.0 / 640.073448422781. Applied: HookProcesss = 70.500 m, σ_τ = 9.362e-04 s
# z = 70.5 / 640.073448422781. Applied: HookProcesss = 71.000 m, σ_τ = 9.362e-04 s
# z = 71.0 / 640.073448422781. Applied: HookProcesss = 71.500 m, σ_τ = 9.362e-04 s
# z = 71.5 / 640.073448422781. Applied: HookProcesss = 72.000 m, σ_τ = 9.362e-04 s
# z = 72.0 / 640.073448422781. Applied: HookProcesss = 72.500 m, σ_τ = 9.362e-04 s
# z = 72.5 / 640.073448422781. Applied: HookProcesss = 73.000 m, σ_τ = 9.362e-04 s
# z = 73.0 / 640.073448422781. Applied: HookProcesss = 73.500 m, σ_τ = 9.362e-04 s
# z = 73.5 / 640.073448422781. Applied: HookProcesss = 74.000 m, σ_τ = 9.362e-04 s
# z = 74.0 / 640.073448422781. Applied: HookProcesss = 74.500 m, σ_τ = 9.362e-04 s
# z = 74.5 / 640.073448422781. Applied: HookProcesss = 75.000 m, σ_τ = 9.362e-04 s
# z = 75.0 / 640.073448422781. Applied: HookProcesss = 75.500 m, σ_τ = 9.362e-04 s
# z = 75.5 / 640.073448422781. Applied: HookProcesss = 76.000 m, σ_τ = 9.362e-04 s
# z = 76.0 / 640.073448422781. Applied: HookProcesss = 76.500 m, σ_τ = 9.362e-04 s
# z = 76.5 / 640.073448422781. Applied: HookProcesss = 77.000 m, σ_τ = 9.362e-04 s
# z = 77.0 / 640.073448422781. Applied: HookProcesss = 77.500 m, σ_τ = 9.362e-04 s
# z = 77.5 / 640.073448422781. Applied: HookProcesss = 78.000 m, σ_τ = 9.362e-04 s
# z = 78.0 / 640.073448422781. Applied: HookProcesss = 78.500 m, σ_τ = 9.362e-04 s
# z = 78.5 / 640.073448422781. Applied: HookProcesss = 79.000 m, σ_τ = 9.362e-04 s
# z = 79.0 / 640.073448422781. Applied: HookProcesss = 79.500 m, σ_τ = 9.362e-04 s
# z = 79.5 / 640.073448422781. Applied: HookProcesss = 80.000 m, σ_τ = 9.362e-04 s
# z = 80.0 / 640.073448422781. Applied: HookProcesss = 80.500 m, σ_τ = 9.362e-04 s
# z = 80.5 / 640.073448422781. Applied: HookProcesss = 81.000 m, σ_τ = 9.362e-04 s
# z = 81.0 / 640.073448422781. Applied: HookProcesss = 81.500 m, σ_τ = 9.362e-04 s
# z = 81.5 / 640.073448422781. Applied: HookProcesss = 82.000 m, σ_τ = 9.362e-04 s
# z = 82.0 / 640.073448422781. Applied: HookProcesss = 82.500 m, σ_τ = 9.362e-04 s
# z = 82.5 / 640.073448422781. Applied: HookProcesss = 83.000 m, σ_τ = 9.362e-04 s
# z = 83.0 / 640.073448422781. Applied: HookProcesss = 83.500 m, σ_τ = 9.362e-04 s
# z = 83.5 / 640.073448422781. Applied: HookProcesss = 84.000 m, σ_τ = 9.362e-04 s
# z = 84.0 / 640.073448422781. Applied: HookProcesss = 84.500 m, σ_τ = 9.362e-04 s
# z = 84.5 / 640.073448422781. Applied: HookProcesss = 85.000 m, σ_τ = 9.362e-04 s
# z = 85.0 / 640.073448422781. Applied: HookProcesss = 85.500 m, σ_τ = 9.362e-04 s
# z = 85.5 / 640.073448422781. Applied: HookProcesss = 86.000 m, σ_τ = 9.362e-04 s
# z = 86.0 / 640.073448422781. Applied: HookProcesss = 86.500 m, σ_τ = 9.362e-04 s
# z = 86.5 / 640.073448422781. Applied: HookProcesss = 87.000 m, σ_τ = 9.362e-04 s
# z = 87.0 / 640.073448422781. Applied: HookProcesss = 87.500 m, σ_τ = 9.362e-04 s
# z = 87.5 / 640.073448422781. Applied: HookProcesss = 88.000 m, σ_τ = 9.362e-04 s
# z = 88.0 / 640.073448422781. Applied: HookProcesss = 88.500 m, σ_τ = 9.362e-04 s
# z = 88.5 / 640.073448422781. Applied: HookProcesss = 89.000 m, σ_τ = 9.362e-04 s
# z = 89.0 / 640.073448422781. Applied: HookProcesss = 89.500 m, σ_τ = 9.363e-04 s
# z = 89.5 / 640.073448422781. Applied: HookProcesss = 90.000 m, σ_τ = 9.363e-04 s
# z = 90.0 / 640.073448422781. Applied: HookProcesss = 90.500 m, σ_τ = 9.363e-04 s
# z = 90.5 / 640.073448422781. Applied: HookProcesss = 91.000 m, σ_τ = 9.363e-04 s
# z = 91.0 / 640.073448422781. Applied: HookProcesss = 91.500 m, σ_τ = 9.363e-04 s
# z = 91.5 / 640.073448422781. Applied: HookProcesss = 92.000 m, σ_τ = 9.363e-04 s
# z = 92.0 / 640.073448422781. Applied: HookProcesss = 92.500 m, σ_τ = 9.363e-04 s
# z = 92.5 / 640.073448422781. Applied: HookProcesss = 93.000 m, σ_τ = 9.363e-04 s
# z = 93.0 / 640.073448422781. Applied: HookProcesss = 93.500 m, σ_τ = 9.363e-04 s
# z = 93.5 / 640.073448422781. Applied: HookProcesss = 94.000 m, σ_τ = 9.363e-04 s
# z = 94.0 / 640.073448422781. Applied: HookProcesss = 94.500 m, σ_τ = 9.363e-04 s
# z = 94.5 / 640.073448422781. Applied: HookProcesss = 95.000 m, σ_τ = 9.363e-04 s
# z = 95.0 / 640.073448422781. Applied: HookProcesss = 95.500 m, σ_τ = 9.363e-04 s
# z = 95.5 / 640.073448422781. Applied: HookProcesss = 96.000 m, σ_τ = 9.363e-04 s
# z = 96.0 / 640.073448422781. Applied: HookProcesss = 96.500 m, σ_τ = 9.363e-04 s
# z = 96.5 / 640.073448422781. Applied: HookProcesss = 97.000 m, σ_τ = 9.363e-04 s
# z = 97.0 / 640.073448422781. Applied: HookProcesss = 97.500 m, σ_τ = 9.363e-04 s
# z = 97.5 / 640.073448422781. Applied: HookProcesss = 98.000 m, σ_τ = 9.363e-04 s
# z = 98.0 / 640.073448422781. Applied: HookProcesss = 98.500 m, σ_τ = 9.363e-04 s
# z = 98.5 / 640.073448422781. Applied: HookProcesss = 99.000 m, σ_τ = 9.363e-04 s
# z = 99.0 / 640.073448422781. Applied: HookProcesss = 99.500 m, σ_τ = 9.363e-04 s
# z = 99.5 / 640.073448422781. Applied: HookProcesss = 100.000 m, σ_τ = 9.363e-04 s
# z = 100.0 / 640.073448422781. Applied: HookProcesss = 100.500 m, σ_τ = 9.363e-04 s
# z = 100.5 / 640.073448422781. Applied: HookProcesss = 101.000 m, σ_τ = 9.363e-04 s
# z = 101.0 / 640.073448422781. Applied: HookProcesss = 101.500 m, σ_τ = 9.363e-04 s
# z = 101.5 / 640.073448422781. Applied: HookProcesss = 102.000 m, σ_τ = 9.363e-04 s
# z = 102.0 / 640.073448422781. Applied: HookProcesss = 102.500 m, σ_τ = 9.363e-04 s
# z = 102.5 / 640.073448422781. Applied: HookProcesss = 103.000 m, σ_τ = 9.363e-04 s
# z = 103.0 / 640.073448422781. Applied: HookProcesss = 103.500 m, σ_τ = 9.363e-04 s
# z = 103.5 / 640.073448422781. Applied: HookProcesss = 104.000 m, σ_τ = 9.363e-04 s
# z = 104.0 / 640.073448422781. Applied: HookProcesss = 104.500 m, σ_τ = 9.363e-04 s
# z = 104.5 / 640.073448422781. Applied: HookProcesss = 105.000 m, σ_τ = 9.363e-04 s
# z = 105.0 / 640.073448422781. Applied: HookProcesss = 105.500 m, σ_τ = 9.363e-04 s
# z = 105.5 / 640.073448422781. Applied: HookProcesss = 106.000 m, σ_τ = 9.363e-04 s
# z = 106.0 / 640.073448422781. Applied: HookProcesss = 106.500 m, σ_τ = 9.363e-04 s
# z = 106.5 / 640.073448422781. Applied: HookProcesss = 107.000 m, σ_τ = 9.363e-04 s
# z = 107.0 / 640.073448422781. Applied: HookProcesss = 107.500 m, σ_τ = 9.363e-04 s
# z = 107.5 / 640.073448422781. Applied: HookProcesss = 108.000 m, σ_τ = 9.363e-04 s
# z = 108.0 / 640.073448422781. Applied: HookProcesss = 108.500 m, σ_τ = 9.363e-04 s
# z = 108.5 / 640.073448422781. Applied: HookProcesss = 109.000 m, σ_τ = 9.363e-04 s
# z = 109.0 / 640.073448422781. Applied: HookProcesss = 109.500 m, σ_τ = 9.363e-04 s
# z = 109.5 / 640.073448422781. Applied: HookProcesss = 110.000 m, σ_τ = 9.363e-04 s
# z = 110.0 / 640.073448422781. Applied: HookProcesss = 110.500 m, σ_τ = 9.363e-04 s
# z = 110.5 / 640.073448422781. Applied: HookProcesss = 111.000 m, σ_τ = 9.363e-04 s
# z = 111.0 / 640.073448422781. Applied: HookProcesss = 111.500 m, σ_τ = 9.363e-04 s
# z = 111.5 / 640.073448422781. Applied: HookProcesss = 112.000 m, σ_τ = 9.363e-04 s
# z = 112.0 / 640.073448422781. Applied: HookProcesss = 112.500 m, σ_τ = 9.363e-04 s
# z = 112.5 / 640.073448422781. Applied: HookProcesss = 113.000 m, σ_τ = 9.363e-04 s
# z = 113.0 / 640.073448422781. Applied: HookProcesss = 113.500 m, σ_τ = 9.363e-04 s
# z = 113.5 / 640.073448422781. Applied: HookProcesss = 114.000 m, σ_τ = 9.363e-04 s
# z = 114.0 / 640.073448422781. Applied: HookProcesss = 114.500 m, σ_τ = 9.363e-04 s
# z = 114.5 / 640.073448422781. Applied: HookProcesss = 115.000 m, σ_τ = 9.363e-04 s
# z = 115.0 / 640.073448422781. Applied: HookProcesss = 115.500 m, σ_τ = 9.363e-04 s
# z = 115.5 / 640.073448422781. Applied: HookProcesss = 116.000 m, σ_τ = 9.363e-04 s
# z = 116.0 / 640.073448422781. Applied: HookProcesss = 116.500 m, σ_τ = 9.363e-04 s
# z = 116.5 / 640.073448422781. Applied: HookProcesss = 117.000 m, σ_τ = 9.363e-04 s
# z = 117.0 / 640.073448422781. Applied: HookProcesss = 117.500 m, σ_τ = 9.363e-04 s
# z = 117.5 / 640.073448422781. Applied: HookProcesss = 118.000 m, σ_τ = 9.363e-04 s
# z = 118.0 / 640.073448422781. Applied: HookProcesss = 118.500 m, σ_τ = 9.363e-04 s
# z = 118.5 / 640.073448422781. Applied: HookProcesss = 119.000 m, σ_τ = 9.363e-04 s
# z = 119.0 / 640.073448422781. Applied: HookProcesss = 119.500 m, σ_τ = 9.363e-04 s
# z = 119.5 / 640.073448422781. Applied: HookProcesss = 120.000 m, σ_τ = 9.363e-04 s
# z = 120.0 / 640.073448422781. Applied: HookProcesss = 120.500 m, σ_τ = 9.363e-04 s
# z = 120.5 / 640.073448422781. Applied: HookProcesss = 121.000 m, σ_τ = 9.363e-04 s
# z = 121.0 / 640.073448422781. Applied: HookProcesss = 121.500 m, σ_τ = 9.363e-04 s
# z = 121.5 / 640.073448422781. Applied: HookProcesss = 122.000 m, σ_τ = 9.363e-04 s
# z = 122.0 / 640.073448422781. Applied: HookProcesss = 122.500 m, σ_τ = 9.363e-04 s
# z = 122.5 / 640.073448422781. Applied: HookProcesss = 123.000 m, σ_τ = 9.363e-04 s
# z = 123.0 / 640.073448422781. Applied: HookProcesss = 123.500 m, σ_τ = 9.363e-04 s
# z = 123.5 / 640.073448422781. Applied: HookProcesss = 124.000 m, σ_τ = 9.363e-04 s
# z = 124.0 / 640.073448422781. Applied: HookProcesss = 124.500 m, σ_τ = 9.363e-04 s
# z = 124.5 / 640.073448422781. Applied: HookProcesss = 125.000 m, σ_τ = 9.363e-04 s
# z = 125.0 / 640.073448422781. Applied: HookProcesss = 125.500 m, σ_τ = 9.363e-04 s
# z = 125.5 / 640.073448422781. Applied: HookProcesss = 126.000 m, σ_τ = 9.363e-04 s
# z = 126.0 / 640.073448422781. Applied: HookProcesss = 126.500 m, σ_τ = 9.335e-04 s
# z = 126.5 / 640.073448422781. Applied: HookProcesss = 127.000 m, σ_τ = 8.975e-04 s
# z = 127.0 / 640.073448422781. Applied: HookProcesss = 127.500 m, σ_τ = 7.921e-04 s
# z = 127.5 / 640.073448422781. Applied: HookProcesss = 128.000 m, σ_τ = 6.463e-04 s
# z = 128.0 / 640.073448422781. Applied: HookProcesss = 128.500 m, σ_τ = 6.369e-04 s
# z = 128.5 / 640.073448422781. Applied: HookProcesss = 129.000 m, σ_τ = 6.369e-04 s
# z = 129.0 / 640.073448422781. Applied: HookProcesss = 129.500 m, σ_τ = 6.369e-04 s
# z = 129.5 / 640.073448422781. Applied: HookProcesss = 130.000 m, σ_τ = 6.369e-04 s
# z = 130.0 / 640.073448422781. Applied: HookProcesss = 130.500 m, σ_τ = 6.343e-04 s
# z = 130.5 / 640.073448422781. Applied: HookProcesss = 131.000 m, σ_τ = 6.476e-04 s
# z = 131.0 / 640.073448422781. Applied: HookProcesss = 131.500 m, σ_τ = 6.287e-04 s
# z = 131.5 / 640.073448422781. Applied: HookProcesss = 132.000 m, σ_τ = 6.395e-04 s
# z = 132.0 / 640.073448422781. Applied: HookProcesss = 132.500 m, σ_τ = 6.423e-04 s
# z = 132.5 / 640.073448422781. Applied: HookProcesss = 133.000 m, σ_τ = 6.423e-04 s
# z = 133.0 / 640.073448422781. Applied: HookProcesss = 133.500 m, σ_τ = 6.423e-04 s
# z = 133.5 / 640.073448422781. Applied: HookProcesss = 134.000 m, σ_τ = 6.423e-04 s
# z = 134.0 / 640.073448422781. Applied: HookProcesss = 134.500 m, σ_τ = 7.830e-04 s
# z = 134.5 / 640.073448422781. Applied: HookProcesss = 135.000 m, σ_τ = 9.828e-04 s
# z = 135.0 / 640.073448422781. Applied: HookProcesss = 135.500 m, σ_τ = 1.062e-03 s
# z = 135.5 / 640.073448422781. Applied: HookProcesss = 136.000 m, σ_τ = 9.437e-04 s
# z = 136.0 / 640.073448422781. Applied: HookProcesss = 136.500 m, σ_τ = 9.428e-04 s
# z = 136.5 / 640.073448422781. Applied: HookProcesss = 137.000 m, σ_τ = 9.428e-04 s
# z = 137.0 / 640.073448422781. Applied: HookProcesss = 137.500 m, σ_τ = 9.428e-04 s
# z = 137.5 / 640.073448422781. Applied: HookProcesss = 138.000 m, σ_τ = 9.428e-04 s
# z = 138.0 / 640.073448422781. Applied: HookProcesss = 138.500 m, σ_τ = 8.362e-04 s
# z = 138.5 / 640.073448422781. Applied: HookProcesss = 139.000 m, σ_τ = 8.757e-04 s
# z = 139.0 / 640.073448422781. Applied: HookProcesss = 139.500 m, σ_τ = 1.071e-03 s
# z = 139.5 / 640.073448422781. Applied: HookProcesss = 140.000 m, σ_τ = 1.396e-03 s
# z = 140.0 / 640.073448422781. Applied: HookProcesss = 140.500 m, σ_τ = 1.396e-03 s
# z = 140.5 / 640.073448422781. Applied: HookProcesss = 141.000 m, σ_τ = 1.396e-03 s
# z = 141.0 / 640.073448422781. Applied: HookProcesss = 141.500 m, σ_τ = 1.396e-03 s
# z = 141.5 / 640.073448422781. Applied: HookProcesss = 142.000 m, σ_τ = 1.396e-03 s
# z = 142.0 / 640.073448422781. Applied: HookProcesss = 142.500 m, σ_τ = 1.565e-03 s
# z = 142.5 / 640.073448422781. Applied: HookProcesss = 143.000 m, σ_τ = 1.677e-03 s
# z = 143.0 / 640.073448422781. Applied: HookProcesss = 143.500 m, σ_τ = 1.642e-03 s
# z = 143.5 / 640.073448422781. Applied: HookProcesss = 144.000 m, σ_τ = 1.432e-03 s
# z = 144.0 / 640.073448422781. Applied: HookProcesss = 144.500 m, σ_τ = 1.432e-03 s
# z = 144.5 / 640.073448422781. Applied: HookProcesss = 145.000 m, σ_τ = 1.432e-03 s
# z = 145.0 / 640.073448422781. Applied: HookProcesss = 145.500 m, σ_τ = 1.432e-03 s
# z = 145.5 / 640.073448422781. Applied: HookProcesss = 146.000 m, σ_τ = 1.432e-03 s
# z = 146.0 / 640.073448422781. Applied: HookProcesss = 146.500 m, σ_τ = 1.139e-03 s
# z = 146.5 / 640.073448422781. Applied: HookProcesss = 147.000 m, σ_τ = 9.915e-04 s
# z = 147.0 / 640.073448422781. Applied: HookProcesss = 147.500 m, σ_τ = 9.431e-04 s
# z = 147.5 / 640.073448422781. Applied: HookProcesss = 148.000 m, σ_τ = 9.377e-04 s
# z = 148.0 / 640.073448422781. Applied: HookProcesss = 148.500 m, σ_τ = 9.377e-04 s
# z = 148.5 / 640.073448422781. Applied: HookProcesss = 149.000 m, σ_τ = 9.377e-04 s
# z = 149.0 / 640.073448422781. Applied: HookProcesss = 149.500 m, σ_τ = 9.377e-04 s
# z = 149.5 / 640.073448422781. Applied: HookProcesss = 150.000 m, σ_τ = 9.377e-04 s
# z = 150.0 / 640.073448422781. Applied: HookProcesss = 150.500 m, σ_τ = 9.377e-04 s
# z = 150.5 / 640.073448422781. Applied: HookProcesss = 151.000 m, σ_τ = 9.377e-04 s
# z = 151.0 / 640.073448422781. Applied: HookProcesss = 151.500 m, σ_τ = 9.377e-04 s
# z = 151.5 / 640.073448422781. Applied: HookProcesss = 152.000 m, σ_τ = 9.377e-04 s
# z = 152.0 / 640.073448422781. Applied: HookProcesss = 152.500 m, σ_τ = 9.377e-04 s
# z = 152.5 / 640.073448422781. Applied: HookProcesss = 153.000 m, σ_τ = 9.377e-04 s
# z = 153.0 / 640.073448422781. Applied: HookProcesss = 153.500 m, σ_τ = 9.377e-04 s
# z = 153.5 / 640.073448422781. Applied: HookProcesss = 154.000 m, σ_τ = 9.377e-04 s
# z = 154.0 / 640.073448422781. Applied: HookProcesss = 154.500 m, σ_τ = 9.377e-04 s
# z = 154.5 / 640.073448422781. Applied: HookProcesss = 155.000 m, σ_τ = 9.377e-04 s
# z = 155.0 / 640.073448422781. Applied: HookProcesss = 155.500 m, σ_τ = 9.377e-04 s
# z = 155.5 / 640.073448422781. Applied: HookProcesss = 156.000 m, σ_τ = 9.377e-04 s
# z = 156.0 / 640.073448422781. Applied: HookProcesss = 156.500 m, σ_τ = 9.377e-04 s
# z = 156.5 / 640.073448422781. Applied: HookProcesss = 157.000 m, σ_τ = 9.377e-04 s
# z = 157.0 / 640.073448422781. Applied: HookProcesss = 157.500 m, σ_τ = 9.377e-04 s
# z = 157.5 / 640.073448422781. Applied: HookProcesss = 158.000 m, σ_τ = 9.377e-04 s
# z = 158.0 / 640.073448422781. Applied: HookProcesss = 158.500 m, σ_τ = 9.377e-04 s
# z = 158.5 / 640.073448422781. Applied: HookProcesss = 159.000 m, σ_τ = 9.377e-04 s
# z = 159.0 / 640.073448422781. Applied: HookProcesss = 159.500 m, σ_τ = 9.377e-04 s
# z = 159.5 / 640.073448422781. Applied: HookProcesss = 160.000 m, σ_τ = 9.377e-04 s
# z = 160.0 / 640.073448422781. Applied: HookProcesss = 160.500 m, σ_τ = 9.377e-04 s
# z = 160.5 / 640.073448422781. Applied: HookProcesss = 161.000 m, σ_τ = 9.377e-04 s
# z = 161.0 / 640.073448422781. Applied: HookProcesss = 161.500 m, σ_τ = 9.377e-04 s
# z = 161.5 / 640.073448422781. Applied: HookProcesss = 162.000 m, σ_τ = 9.377e-04 s
# z = 162.0 / 640.073448422781. Applied: HookProcesss = 162.500 m, σ_τ = 9.377e-04 s
# z = 162.5 / 640.073448422781. Applied: HookProcesss = 163.000 m, σ_τ = 9.377e-04 s
# z = 163.0 / 640.073448422781. Applied: HookProcesss = 163.500 m, σ_τ = 9.377e-04 s
# z = 163.5 / 640.073448422781. Applied: HookProcesss = 164.000 m, σ_τ = 9.377e-04 s
# z = 164.0 / 640.073448422781. Applied: HookProcesss = 164.500 m, σ_τ = 9.377e-04 s
# z = 164.5 / 640.073448422781. Applied: HookProcesss = 165.000 m, σ_τ = 9.377e-04 s
# z = 165.0 / 640.073448422781. Applied: HookProcesss = 165.500 m, σ_τ = 9.377e-04 s
# z = 165.5 / 640.073448422781. Applied: HookProcesss = 166.000 m, σ_τ = 9.377e-04 s
# z = 166.0 / 640.073448422781. Applied: HookProcesss = 166.500 m, σ_τ = 9.377e-04 s
# z = 166.5 / 640.073448422781. Applied: HookProcesss = 167.000 m, σ_τ = 9.377e-04 s
# z = 167.0 / 640.073448422781. Applied: HookProcesss = 167.500 m, σ_τ = 9.377e-04 s
# z = 167.5 / 640.073448422781. Applied: HookProcesss = 168.000 m, σ_τ = 9.377e-04 s
# z = 168.0 / 640.073448422781. Applied: HookProcesss = 168.500 m, σ_τ = 9.377e-04 s
# z = 168.5 / 640.073448422781. Applied: HookProcesss = 169.000 m, σ_τ = 9.377e-04 s
# z = 169.0 / 640.073448422781. Applied: HookProcesss = 169.500 m, σ_τ = 9.377e-04 s
# z = 169.5 / 640.073448422781. Applied: HookProcesss = 170.000 m, σ_τ = 9.377e-04 s
# z = 170.0 / 640.073448422781. Applied: HookProcesss = 170.500 m, σ_τ = 9.377e-04 s
# z = 170.5 / 640.073448422781. Applied: HookProcesss = 171.000 m, σ_τ = 9.377e-04 s
# z = 171.0 / 640.073448422781. Applied: HookProcesss = 171.500 m, σ_τ = 9.377e-04 s
# z = 171.5 / 640.073448422781. Applied: HookProcesss = 172.000 m, σ_τ = 9.377e-04 s
# z = 172.0 / 640.073448422781. Applied: HookProcesss = 172.500 m, σ_τ = 9.377e-04 s
# z = 172.5 / 640.073448422781. Applied: HookProcesss = 173.000 m, σ_τ = 9.377e-04 s
# z = 173.0 / 640.073448422781. Applied: HookProcesss = 173.500 m, σ_τ = 9.377e-04 s
# z = 173.5 / 640.073448422781. Applied: HookProcesss = 174.000 m, σ_τ = 9.377e-04 s
# z = 174.0 / 640.073448422781. Applied: HookProcesss = 174.500 m, σ_τ = 9.377e-04 s
# z = 174.5 / 640.073448422781. Applied: HookProcesss = 175.000 m, σ_τ = 9.377e-04 s
# z = 175.0 / 640.073448422781. Applied: HookProcesss = 175.500 m, σ_τ = 9.377e-04 s
# z = 175.5 / 640.073448422781. Applied: HookProcesss = 176.000 m, σ_τ = 9.377e-04 s
# z = 176.0 / 640.073448422781. Applied: HookProcesss = 176.500 m, σ_τ = 9.377e-04 s
# z = 176.5 / 640.073448422781. Applied: HookProcesss = 177.000 m, σ_τ = 9.377e-04 s
# z = 177.0 / 640.073448422781. Applied: HookProcesss = 177.500 m, σ_τ = 9.377e-04 s
# z = 177.5 / 640.073448422781. Applied: HookProcesss = 178.000 m, σ_τ = 9.377e-04 s
# z = 178.0 / 640.073448422781. Applied: HookProcesss = 178.500 m, σ_τ = 9.377e-04 s
# z = 178.5 / 640.073448422781. Applied: HookProcesss = 179.000 m, σ_τ = 9.377e-04 s
# z = 179.0 / 640.073448422781. Applied: HookProcesss = 179.500 m, σ_τ = 9.377e-04 s
# z = 179.5 / 640.073448422781. Applied: HookProcesss = 180.000 m, σ_τ = 9.377e-04 s
# z = 180.0 / 640.073448422781. Applied: HookProcesss = 180.500 m, σ_τ = 9.377e-04 s
# z = 180.5 / 640.073448422781. Applied: HookProcesss = 181.000 m, σ_τ = 9.377e-04 s
# z = 181.0 / 640.073448422781. Applied: HookProcesss = 181.500 m, σ_τ = 9.377e-04 s
# z = 181.5 / 640.073448422781. Applied: HookProcesss = 182.000 m, σ_τ = 9.377e-04 s
# z = 182.0 / 640.073448422781. Applied: HookProcesss = 182.500 m, σ_τ = 9.377e-04 s
# z = 182.5 / 640.073448422781. Applied: HookProcesss = 183.000 m, σ_τ = 9.377e-04 s
# z = 183.0 / 640.073448422781. Applied: HookProcesss = 183.500 m, σ_τ = 9.377e-04 s
# z = 183.5 / 640.073448422781. Applied: HookProcesss = 184.000 m, σ_τ = 9.377e-04 s
# z = 184.0 / 640.073448422781. Applied: HookProcesss = 184.500 m, σ_τ = 9.377e-04 s
# z = 184.5 / 640.073448422781. Applied: HookProcesss = 185.000 m, σ_τ = 9.377e-04 s
# z = 185.0 / 640.073448422781. Applied: HookProcesss = 185.500 m, σ_τ = 9.377e-04 s
# z = 185.5 / 640.073448422781. Applied: HookProcesss = 186.000 m, σ_τ = 9.377e-04 s
# z = 186.0 / 640.073448422781. Applied: HookProcesss = 186.500 m, σ_τ = 9.377e-04 s
# z = 186.5 / 640.073448422781. Applied: HookProcesss = 187.000 m, σ_τ = 9.377e-04 s
# z = 187.0 / 640.073448422781. Applied: HookProcesss = 187.500 m, σ_τ = 9.377e-04 s
# z = 187.5 / 640.073448422781. Applied: HookProcesss = 188.000 m, σ_τ = 9.377e-04 s
# z = 188.0 / 640.073448422781. Applied: HookProcesss = 188.500 m, σ_τ = 9.377e-04 s
# z = 188.5 / 640.073448422781. Applied: HookProcesss = 189.000 m, σ_τ = 9.377e-04 s
# z = 189.0 / 640.073448422781. Applied: HookProcesss = 189.500 m, σ_τ = 9.377e-04 s
# z = 189.5 / 640.073448422781. Applied: HookProcesss = 190.000 m, σ_τ = 9.377e-04 s
# z = 190.0 / 640.073448422781. Applied: HookProcesss = 190.500 m, σ_τ = 9.377e-04 s
# z = 190.5 / 640.073448422781. Applied: HookProcesss = 191.000 m, σ_τ = 9.377e-04 s
# z = 191.0 / 640.073448422781. Applied: HookProcesss = 191.500 m, σ_τ = 9.377e-04 s
# z = 191.5 / 640.073448422781. Applied: HookProcesss = 192.000 m, σ_τ = 9.377e-04 s
# z = 192.0 / 640.073448422781. Applied: HookProcesss = 192.500 m, σ_τ = 9.377e-04 s
# z = 192.5 / 640.073448422781. Applied: HookProcesss = 193.000 m, σ_τ = 9.377e-04 s
# z = 193.0 / 640.073448422781. Applied: HookProcesss = 193.500 m, σ_τ = 9.377e-04 s
# z = 193.5 / 640.073448422781. Applied: HookProcesss = 194.000 m, σ_τ = 9.377e-04 s
# z = 194.0 / 640.073448422781. Applied: HookProcesss = 194.500 m, σ_τ = 9.377e-04 s
# z = 194.5 / 640.073448422781. Applied: HookProcesss = 195.000 m, σ_τ = 9.377e-04 s
# z = 195.0 / 640.073448422781. Applied: HookProcesss = 195.500 m, σ_τ = 9.377e-04 s
# z = 195.5 / 640.073448422781. Applied: HookProcesss = 196.000 m, σ_τ = 9.377e-04 s
# z = 196.0 / 640.073448422781. Applied: HookProcesss = 196.500 m, σ_τ = 9.377e-04 s
# z = 196.5 / 640.073448422781. Applied: HookProcesss = 197.000 m, σ_τ = 9.377e-04 s
# z = 197.0 / 640.073448422781. Applied: HookProcesss = 197.500 m, σ_τ = 9.377e-04 s
# z = 197.5 / 640.073448422781. Applied: HookProcesss = 198.000 m, σ_τ = 9.377e-04 s
# z = 198.0 / 640.073448422781. Applied: HookProcesss = 198.500 m, σ_τ = 9.377e-04 s
# z = 198.5 / 640.073448422781. Applied: HookProcesss = 199.000 m, σ_τ = 9.377e-04 s
# z = 199.0 / 640.073448422781. Applied: HookProcesss = 199.500 m, σ_τ = 9.377e-04 s
# z = 199.5 / 640.073448422781. Applied: HookProcesss = 200.000 m, σ_τ = 9.377e-04 s
# z = 200.0 / 640.073448422781. Applied: HookProcesss = 200.500 m, σ_τ = 9.377e-04 s
# z = 200.5 / 640.073448422781. Applied: HookProcesss = 201.000 m, σ_τ = 9.377e-04 s
# z = 201.0 / 640.073448422781. Applied: HookProcesss = 201.500 m, σ_τ = 9.377e-04 s
# z = 201.5 / 640.073448422781. Applied: HookProcesss = 202.000 m, σ_τ = 9.377e-04 s
# z = 202.0 / 640.073448422781. Applied: HookProcesss = 202.500 m, σ_τ = 9.377e-04 s
# z = 202.5 / 640.073448422781. Applied: HookProcesss = 203.000 m, σ_τ = 9.377e-04 s
# z = 203.0 / 640.073448422781. Applied: HookProcesss = 203.500 m, σ_τ = 9.377e-04 s
# z = 203.5 / 640.073448422781. Applied: HookProcesss = 204.000 m, σ_τ = 9.377e-04 s
# z = 204.0 / 640.073448422781. Applied: HookProcesss = 204.500 m, σ_τ = 9.377e-04 s
# z = 204.5 / 640.073448422781. Applied: HookProcesss = 205.000 m, σ_τ = 9.377e-04 s
# z = 205.0 / 640.073448422781. Applied: HookProcesss = 205.500 m, σ_τ = 9.377e-04 s
# z = 205.5 / 640.073448422781. Applied: HookProcesss = 206.000 m, σ_τ = 9.377e-04 s
# z = 206.0 / 640.073448422781. Applied: HookProcesss = 206.500 m, σ_τ = 9.377e-04 s
# z = 206.5 / 640.073448422781. Applied: HookProcesss = 207.000 m, σ_τ = 9.377e-04 s
# z = 207.0 / 640.073448422781. Applied: HookProcesss = 207.500 m, σ_τ = 9.377e-04 s
# z = 207.5 / 640.073448422781. Applied: HookProcesss = 208.000 m, σ_τ = 9.377e-04 s
# z = 208.0 / 640.073448422781. Applied: HookProcesss = 208.500 m, σ_τ = 9.377e-04 s
# z = 208.5 / 640.073448422781. Applied: HookProcesss = 209.000 m, σ_τ = 9.377e-04 s
# z = 209.0 / 640.073448422781. Applied: HookProcesss = 209.500 m, σ_τ = 9.377e-04 s
# z = 209.5 / 640.073448422781. Applied: HookProcesss = 210.000 m, σ_τ = 9.377e-04 s
# z = 210.0 / 640.073448422781. Applied: HookProcesss = 210.500 m, σ_τ = 9.377e-04 s
# z = 210.5 / 640.073448422781. Applied: HookProcesss = 211.000 m, σ_τ = 9.377e-04 s
# z = 211.0 / 640.073448422781. Applied: HookProcesss = 211.500 m, σ_τ = 9.377e-04 s
# z = 211.5 / 640.073448422781. Applied: HookProcesss = 212.000 m, σ_τ = 9.377e-04 s
# z = 212.0 / 640.073448422781. Applied: HookProcesss = 212.500 m, σ_τ = 9.377e-04 s
# z = 212.5 / 640.073448422781. Applied: HookProcesss = 213.000 m, σ_τ = 9.377e-04 s
# z = 213.0 / 640.073448422781. Applied: HookProcesss = 213.500 m, σ_τ = 9.377e-04 s
# z = 213.5 / 640.073448422781. Applied: HookProcesss = 214.000 m, σ_τ = 9.377e-04 s
# z = 214.0 / 640.073448422781. Applied: HookProcesss = 214.500 m, σ_τ = 9.377e-04 s
# z = 214.5 / 640.073448422781. Applied: HookProcesss = 215.000 m, σ_τ = 9.377e-04 s
# z = 215.0 / 640.073448422781. Applied: HookProcesss = 215.500 m, σ_τ = 9.377e-04 s
# z = 215.5 / 640.073448422781. Applied: HookProcesss = 216.000 m, σ_τ = 9.377e-04 s
# z = 216.0 / 640.073448422781. Applied: HookProcesss = 216.500 m, σ_τ = 9.377e-04 s
# z = 216.5 / 640.073448422781. Applied: HookProcesss = 217.000 m, σ_τ = 9.377e-04 s
# z = 217.0 / 640.073448422781. Applied: HookProcesss = 217.500 m, σ_τ = 9.377e-04 s
# z = 217.5 / 640.073448422781. Applied: HookProcesss = 218.000 m, σ_τ = 9.377e-04 s
# z = 218.0 / 640.073448422781. Applied: HookProcesss = 218.500 m, σ_τ = 9.377e-04 s
# z = 218.5 / 640.073448422781. Applied: HookProcesss = 219.000 m, σ_τ = 9.377e-04 s
# z = 219.0 / 640.073448422781. Applied: HookProcesss = 219.500 m, σ_τ = 9.377e-04 s
# z = 219.5 / 640.073448422781. Applied: HookProcesss = 220.000 m, σ_τ = 9.377e-04 s
# z = 220.0 / 640.073448422781. Applied: HookProcesss = 220.500 m, σ_τ = 9.377e-04 s
# z = 220.5 / 640.073448422781. Applied: HookProcesss = 221.000 m, σ_τ = 9.377e-04 s
# z = 221.0 / 640.073448422781. Applied: HookProcesss = 221.500 m, σ_τ = 9.377e-04 s
# z = 221.5 / 640.073448422781. Applied: HookProcesss = 222.000 m, σ_τ = 9.377e-04 s
# z = 222.0 / 640.073448422781. Applied: HookProcesss = 222.500 m, σ_τ = 9.377e-04 s
# z = 222.5 / 640.073448422781. Applied: HookProcesss = 223.000 m, σ_τ = 9.377e-04 s
# z = 223.0 / 640.073448422781. Applied: HookProcesss = 223.500 m, σ_τ = 9.377e-04 s
# z = 223.5 / 640.073448422781. Applied: HookProcesss = 224.000 m, σ_τ = 9.377e-04 s
# z = 224.0 / 640.073448422781. Applied: HookProcesss = 224.500 m, σ_τ = 9.377e-04 s
# z = 224.5 / 640.073448422781. Applied: HookProcesss = 225.000 m, σ_τ = 9.377e-04 s
# z = 225.0 / 640.073448422781. Applied: HookProcesss = 225.500 m, σ_τ = 9.377e-04 s
# z = 225.5 / 640.073448422781. Applied: HookProcesss = 226.000 m, σ_τ = 9.377e-04 s
# z = 226.0 / 640.073448422781. Applied: HookProcesss = 226.500 m, σ_τ = 9.377e-04 s
# z = 226.5 / 640.073448422781. Applied: HookProcesss = 227.000 m, σ_τ = 9.377e-04 s
# z = 227.0 / 640.073448422781. Applied: HookProcesss = 227.500 m, σ_τ = 9.377e-04 s
# z = 227.5 / 640.073448422781. Applied: HookProcesss = 228.000 m, σ_τ = 9.377e-04 s
# z = 228.0 / 640.073448422781. Applied: HookProcesss = 228.500 m, σ_τ = 9.377e-04 s
# z = 228.5 / 640.073448422781. Applied: HookProcesss = 229.000 m, σ_τ = 9.377e-04 s
# z = 229.0 / 640.073448422781. Applied: HookProcesss = 229.500 m, σ_τ = 9.377e-04 s
# z = 229.5 / 640.073448422781. Applied: HookProcesss = 230.000 m, σ_τ = 9.377e-04 s
# z = 230.0 / 640.073448422781. Applied: HookProcesss = 230.500 m, σ_τ = 9.377e-04 s
# z = 230.5 / 640.073448422781. Applied: HookProcesss = 231.000 m, σ_τ = 9.377e-04 s
# z = 231.0 / 640.073448422781. Applied: HookProcesss = 231.500 m, σ_τ = 9.377e-04 s
# z = 231.5 / 640.073448422781. Applied: HookProcesss = 232.000 m, σ_τ = 9.377e-04 s
# z = 232.0 / 640.073448422781. Applied: HookProcesss = 232.500 m, σ_τ = 9.377e-04 s
# z = 232.5 / 640.073448422781. Applied: HookProcesss = 233.000 m, σ_τ = 9.377e-04 s
# z = 233.0 / 640.073448422781. Applied: HookProcesss = 233.500 m, σ_τ = 9.377e-04 s
# z = 233.5 / 640.073448422781. Applied: HookProcesss = 234.000 m, σ_τ = 9.377e-04 s
# z = 234.0 / 640.073448422781. Applied: HookProcesss = 234.500 m, σ_τ = 9.377e-04 s
# z = 234.5 / 640.073448422781. Applied: HookProcesss = 235.000 m, σ_τ = 9.377e-04 s
# z = 235.0 / 640.073448422781. Applied: HookProcesss = 235.500 m, σ_τ = 9.377e-04 s
# z = 235.5 / 640.073448422781. Applied: HookProcesss = 236.000 m, σ_τ = 9.377e-04 s
# z = 236.0 / 640.073448422781. Applied: HookProcesss = 236.500 m, σ_τ = 9.377e-04 s
# z = 236.5 / 640.073448422781. Applied: HookProcesss = 237.000 m, σ_τ = 9.377e-04 s
# z = 237.0 / 640.073448422781. Applied: HookProcesss = 237.500 m, σ_τ = 9.377e-04 s
# z = 237.5 / 640.073448422781. Applied: HookProcesss = 238.000 m, σ_τ = 9.377e-04 s
# z = 238.0 / 640.073448422781. Applied: HookProcesss = 238.500 m, σ_τ = 9.377e-04 s
# z = 238.5 / 640.073448422781. Applied: HookProcesss = 239.000 m, σ_τ = 9.377e-04 s
# z = 239.0 / 640.073448422781. Applied: HookProcesss = 239.500 m, σ_τ = 9.377e-04 s
# z = 239.5 / 640.073448422781. Applied: HookProcesss = 240.000 m, σ_τ = 9.377e-04 s
# z = 240.0 / 640.073448422781. Applied: HookProcesss = 240.500 m, σ_τ = 9.377e-04 s
# z = 240.5 / 640.073448422781. Applied: HookProcesss = 241.000 m, σ_τ = 9.377e-04 s
# z = 241.0 / 640.073448422781. Applied: HookProcesss = 241.500 m, σ_τ = 9.377e-04 s
# z = 241.5 / 640.073448422781. Applied: HookProcesss = 242.000 m, σ_τ = 9.377e-04 s
# z = 242.0 / 640.073448422781. Applied: HookProcesss = 242.500 m, σ_τ = 9.377e-04 s
# z = 242.5 / 640.073448422781. Applied: HookProcesss = 243.000 m, σ_τ = 9.377e-04 s
# z = 243.0 / 640.073448422781. Applied: HookProcesss = 243.500 m, σ_τ = 9.377e-04 s
# z = 243.5 / 640.073448422781. Applied: HookProcesss = 244.000 m, σ_τ = 9.377e-04 s
# z = 244.0 / 640.073448422781. Applied: HookProcesss = 244.500 m, σ_τ = 9.377e-04 s
# z = 244.5 / 640.073448422781. Applied: HookProcesss = 245.000 m, σ_τ = 9.377e-04 s
# z = 245.0 / 640.073448422781. Applied: HookProcesss = 245.500 m, σ_τ = 9.377e-04 s
# z = 245.5 / 640.073448422781. Applied: HookProcesss = 246.000 m, σ_τ = 9.377e-04 s
# z = 246.0 / 640.073448422781. Applied: HookProcesss = 246.500 m, σ_τ = 9.377e-04 s
# z = 246.5 / 640.073448422781. Applied: HookProcesss = 247.000 m, σ_τ = 9.377e-04 s
# z = 247.0 / 640.073448422781. Applied: HookProcesss = 247.500 m, σ_τ = 9.377e-04 s
# z = 247.5 / 640.073448422781. Applied: HookProcesss = 248.000 m, σ_τ = 9.377e-04 s
# z = 248.0 / 640.073448422781. Applied: HookProcesss = 248.500 m, σ_τ = 9.377e-04 s
# z = 248.5 / 640.073448422781. Applied: HookProcesss = 249.000 m, σ_τ = 9.377e-04 s
# z = 249.0 / 640.073448422781. Applied: HookProcesss = 249.500 m, σ_τ = 9.377e-04 s
# z = 249.5 / 640.073448422781. Applied: HookProcesss = 250.000 m, σ_τ = 9.377e-04 s
# z = 250.0 / 640.073448422781. Applied: HookProcesss = 250.500 m, σ_τ = 9.377e-04 s
# z = 250.5 / 640.073448422781. Applied: HookProcesss = 251.000 m, σ_τ = 9.377e-04 s
# z = 251.0 / 640.073448422781. Applied: HookProcesss = 251.500 m, σ_τ = 9.377e-04 s
# z = 251.5 / 640.073448422781. Applied: HookProcesss = 252.000 m, σ_τ = 9.377e-04 s
# z = 252.0 / 640.073448422781. Applied: HookProcesss = 252.500 m, σ_τ = 9.377e-04 s
# z = 252.5 / 640.073448422781. Applied: HookProcesss = 253.000 m, σ_τ = 9.377e-04 s
# z = 253.0 / 640.073448422781. Applied: HookProcesss = 253.500 m, σ_τ = 9.377e-04 s
# z = 253.5 / 640.073448422781. Applied: HookProcesss = 254.000 m, σ_τ = 9.377e-04 s
# z = 254.0 / 640.073448422781. Applied: HookProcesss = 254.500 m, σ_τ = 9.377e-04 s
# z = 254.5 / 640.073448422781. Applied: HookProcesss = 255.000 m, σ_τ = 9.377e-04 s
# z = 255.0 / 640.073448422781. Applied: HookProcesss = 255.500 m, σ_τ = 9.377e-04 s
# z = 255.5 / 640.073448422781. Applied: HookProcesss = 256.000 m, σ_τ = 9.377e-04 s
# z = 256.0 / 640.073448422781. Applied: HookProcesss = 256.500 m, σ_τ = 9.377e-04 s
# z = 256.5 / 640.073448422781. Applied: HookProcesss = 257.000 m, σ_τ = 9.377e-04 s
# z = 257.0 / 640.073448422781. Applied: HookProcesss = 257.500 m, σ_τ = 9.377e-04 s
# z = 257.5 / 640.073448422781. Applied: HookProcesss = 258.000 m, σ_τ = 9.377e-04 s
# z = 258.0 / 640.073448422781. Applied: HookProcesss = 258.500 m, σ_τ = 9.377e-04 s
# z = 258.5 / 640.073448422781. Applied: HookProcesss = 259.000 m, σ_τ = 9.377e-04 s
# z = 259.0 / 640.073448422781. Applied: HookProcesss = 259.500 m, σ_τ = 9.377e-04 s
# z = 259.5 / 640.073448422781. Applied: HookProcesss = 260.000 m, σ_τ = 9.377e-04 s
# z = 260.0 / 640.073448422781. Applied: HookProcesss = 260.500 m, σ_τ = 9.377e-04 s
# z = 260.5 / 640.073448422781. Applied: HookProcesss = 261.000 m, σ_τ = 9.377e-04 s
# z = 261.0 / 640.073448422781. Applied: HookProcesss = 261.500 m, σ_τ = 9.377e-04 s
# z = 261.5 / 640.073448422781. Applied: HookProcesss = 262.000 m, σ_τ = 9.377e-04 s
# z = 262.0 / 640.073448422781. Applied: HookProcesss = 262.500 m, σ_τ = 9.377e-04 s
# z = 262.5 / 640.073448422781. Applied: HookProcesss = 263.000 m, σ_τ = 9.377e-04 s
# z = 263.0 / 640.073448422781. Applied: HookProcesss = 263.500 m, σ_τ = 9.377e-04 s
# z = 263.5 / 640.073448422781. Applied: HookProcesss = 264.000 m, σ_τ = 9.377e-04 s
# z = 264.0 / 640.073448422781. Applied: HookProcesss = 264.500 m, σ_τ = 9.377e-04 s
# z = 264.5 / 640.073448422781. Applied: HookProcesss = 265.000 m, σ_τ = 9.377e-04 s
# z = 265.0 / 640.073448422781. Applied: HookProcesss = 265.500 m, σ_τ = 9.377e-04 s
# z = 265.5 / 640.073448422781. Applied: HookProcesss = 266.000 m, σ_τ = 9.377e-04 s
# z = 266.0 / 640.073448422781. Applied: HookProcesss = 266.500 m, σ_τ = 9.377e-04 s
# z = 266.5 / 640.073448422781. Applied: HookProcesss = 267.000 m, σ_τ = 9.377e-04 s
# z = 267.0 / 640.073448422781. Applied: HookProcesss = 267.500 m, σ_τ = 9.377e-04 s
# z = 267.5 / 640.073448422781. Applied: HookProcesss = 268.000 m, σ_τ = 9.377e-04 s
# z = 268.0 / 640.073448422781. Applied: HookProcesss = 268.500 m, σ_τ = 9.377e-04 s
# z = 268.5 / 640.073448422781. Applied: HookProcesss = 269.000 m, σ_τ = 9.377e-04 s
# z = 269.0 / 640.073448422781. Applied: HookProcesss = 269.500 m, σ_τ = 9.377e-04 s
# z = 269.5 / 640.073448422781. Applied: HookProcesss = 270.000 m, σ_τ = 9.377e-04 s
# z = 270.0 / 640.073448422781. Applied: HookProcesss = 270.500 m, σ_τ = 9.377e-04 s
# z = 270.5 / 640.073448422781. Applied: HookProcesss = 271.000 m, σ_τ = 9.377e-04 s
# z = 271.0 / 640.073448422781. Applied: HookProcesss = 271.500 m, σ_τ = 9.377e-04 s
# z = 271.5 / 640.073448422781. Applied: HookProcesss = 272.000 m, σ_τ = 9.377e-04 s
# z = 272.0 / 640.073448422781. Applied: HookProcesss = 272.500 m, σ_τ = 9.377e-04 s
# z = 272.5 / 640.073448422781. Applied: HookProcesss = 273.000 m, σ_τ = 9.377e-04 s
# z = 273.0 / 640.073448422781. Applied: HookProcesss = 273.500 m, σ_τ = 9.377e-04 s
# z = 273.5 / 640.073448422781. Applied: HookProcesss = 274.000 m, σ_τ = 9.377e-04 s
# z = 274.0 / 640.073448422781. Applied: HookProcesss = 274.500 m, σ_τ = 9.377e-04 s
# z = 274.5 / 640.073448422781. Applied: HookProcesss = 275.000 m, σ_τ = 9.377e-04 s
# z = 275.0 / 640.073448422781. Applied: HookProcesss = 275.500 m, σ_τ = 9.377e-04 s
# z = 275.5 / 640.073448422781. Applied: HookProcesss = 276.000 m, σ_τ = 9.377e-04 s
# z = 276.0 / 640.073448422781. Applied: HookProcesss = 276.500 m, σ_τ = 9.377e-04 s
# z = 276.5 / 640.073448422781. Applied: HookProcesss = 277.000 m, σ_τ = 9.377e-04 s
# z = 277.0 / 640.073448422781. Applied: HookProcesss = 277.500 m, σ_τ = 9.377e-04 s
# z = 277.5 / 640.073448422781. Applied: HookProcesss = 278.000 m, σ_τ = 9.377e-04 s
# z = 278.0 / 640.073448422781. Applied: HookProcesss = 278.500 m, σ_τ = 9.377e-04 s
# z = 278.5 / 640.073448422781. Applied: HookProcesss = 279.000 m, σ_τ = 9.377e-04 s
# z = 279.0 / 640.073448422781. Applied: HookProcesss = 279.500 m, σ_τ = 9.377e-04 s
# z = 279.5 / 640.073448422781. Applied: HookProcesss = 280.000 m, σ_τ = 9.377e-04 s
# z = 280.0 / 640.073448422781. Applied: HookProcesss = 280.500 m, σ_τ = 9.377e-04 s
# z = 280.5 / 640.073448422781. Applied: HookProcesss = 281.000 m, σ_τ = 9.377e-04 s
# z = 281.0 / 640.073448422781. Applied: HookProcesss = 281.500 m, σ_τ = 9.377e-04 s
# z = 281.5 / 640.073448422781. Applied: HookProcesss = 282.000 m, σ_τ = 9.377e-04 s
# z = 282.0 / 640.073448422781. Applied: HookProcesss = 282.500 m, σ_τ = 9.377e-04 s
# z = 282.5 / 640.073448422781. Applied: HookProcesss = 283.000 m, σ_τ = 9.377e-04 s
# z = 283.0 / 640.073448422781. Applied: HookProcesss = 283.500 m, σ_τ = 9.377e-04 s
# z = 283.5 / 640.073448422781. Applied: HookProcesss = 284.000 m, σ_τ = 9.377e-04 s
# z = 284.0 / 640.073448422781. Applied: HookProcesss = 284.500 m, σ_τ = 9.377e-04 s
# z = 284.5 / 640.073448422781. Applied: HookProcesss = 285.000 m, σ_τ = 9.377e-04 s
# z = 285.0 / 640.073448422781. Applied: HookProcesss = 285.500 m, σ_τ = 9.377e-04 s
# z = 285.5 / 640.073448422781. Applied: HookProcesss = 286.000 m, σ_τ = 9.377e-04 s
# z = 286.0 / 640.073448422781. Applied: HookProcesss = 286.500 m, σ_τ = 9.377e-04 s
# z = 286.5 / 640.073448422781. Applied: HookProcesss = 287.000 m, σ_τ = 9.377e-04 s
# z = 287.0 / 640.073448422781. Applied: HookProcesss = 287.500 m, σ_τ = 9.377e-04 s
# z = 287.5 / 640.073448422781. Applied: HookProcesss = 288.000 m, σ_τ = 9.377e-04 s
# z = 288.0 / 640.073448422781. Applied: HookProcesss = 288.500 m, σ_τ = 9.377e-04 s
# z = 288.5 / 640.073448422781. Applied: HookProcesss = 289.000 m, σ_τ = 9.377e-04 s
# z = 289.0 / 640.073448422781. Applied: HookProcesss = 289.500 m, σ_τ = 9.377e-04 s
# z = 289.5 / 640.073448422781. Applied: HookProcesss = 290.000 m, σ_τ = 9.377e-04 s
# z = 290.0 / 640.073448422781. Applied: HookProcesss = 290.500 m, σ_τ = 9.377e-04 s
# z = 290.5 / 640.073448422781. Applied: HookProcesss = 291.000 m, σ_τ = 9.377e-04 s
# z = 291.0 / 640.073448422781. Applied: HookProcesss = 291.500 m, σ_τ = 9.377e-04 s
# z = 291.5 / 640.073448422781. Applied: HookProcesss = 292.000 m, σ_τ = 9.378e-04 s
# ...
# z = 566.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 567.000 m, σ_τ = 1.019e-03 s
# z = 567.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 567.500 m, σ_τ = 1.019e-03 s
# z = 567.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 568.000 m, σ_τ = 1.019e-03 s
# z = 568.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 568.500 m, σ_τ = 1.019e-03 s
# z = 568.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 569.000 m, σ_τ = 1.019e-03 s
# z = 569.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 569.500 m, σ_τ = 1.019e-03 s
# z = 569.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 570.000 m, σ_τ = 1.019e-03 s
# z = 570.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 570.500 m, σ_τ = 1.019e-03 s
# z = 570.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 571.000 m, σ_τ = 1.019e-03 s
# z = 571.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 571.500 m, σ_τ = 1.019e-03 s
# z = 571.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 572.000 m, σ_τ = 1.019e-03 s
# z = 572.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 572.500 m, σ_τ = 1.019e-03 s
# z = 572.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 573.000 m, σ_τ = 1.019e-03 s
# z = 573.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 573.500 m, σ_τ = 1.019e-03 s
# z = 573.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 574.000 m, σ_τ = 1.019e-03 s
# z = 574.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 574.500 m, σ_τ = 1.019e-03 s
# z = 574.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 575.000 m, σ_τ = 1.019e-03 s
# z = 575.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 575.500 m, σ_τ = 1.019e-03 s
# z = 575.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 576.000 m, σ_τ = 1.019e-03 s
# z = 576.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 576.500 m, σ_τ = 1.019e-03 s
# z = 576.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 577.000 m, σ_τ = 1.019e-03 s
# z = 577.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 577.500 m, σ_τ = 1.019e-03 s
# z = 577.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 578.000 m, σ_τ = 1.019e-03 s
# z = 578.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 578.500 m, σ_τ = 1.019e-03 s
# z = 578.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 579.000 m, σ_τ = 1.019e-03 s
# z = 579.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 579.500 m, σ_τ = 1.019e-03 s
# z = 579.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 580.000 m, σ_τ = 1.019e-03 s
# z = 580.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 580.500 m, σ_τ = 1.019e-03 s
# z = 580.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 581.000 m, σ_τ = 1.019e-03 s
# z = 581.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 581.500 m, σ_τ = 1.019e-03 s
# z = 581.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 582.000 m, σ_τ = 1.019e-03 s
# z = 582.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 582.500 m, σ_τ = 1.019e-03 s
# z = 582.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 583.000 m, σ_τ = 1.019e-03 s
# z = 583.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 583.500 m, σ_τ = 1.019e-03 s
# z = 583.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 584.000 m, σ_τ = 1.019e-03 s
# z = 584.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 584.500 m, σ_τ = 1.019e-03 s
# z = 584.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 585.000 m, σ_τ = 1.019e-03 s
# z = 585.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 585.500 m, σ_τ = 1.019e-03 s
# z = 585.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 586.000 m, σ_τ = 1.019e-03 s
# z = 586.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 586.500 m, σ_τ = 1.019e-03 s
# z = 586.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 587.000 m, σ_τ = 1.019e-03 s
# z = 587.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 587.500 m, σ_τ = 1.019e-03 s
# z = 587.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 588.000 m, σ_τ = 1.019e-03 s
# z = 588.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 588.500 m, σ_τ = 1.019e-03 s
# z = 588.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 589.000 m, σ_τ = 1.019e-03 s
# z = 589.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 589.500 m, σ_τ = 1.019e-03 s
# z = 589.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 590.000 m, σ_τ = 1.019e-03 s
# z = 590.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 590.500 m, σ_τ = 1.019e-03 s
# z = 590.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 591.000 m, σ_τ = 1.019e-03 s
# z = 591.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 591.500 m, σ_τ = 1.019e-03 s
# z = 591.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 592.000 m, σ_τ = 1.019e-03 s
# z = 592.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 592.500 m, σ_τ = 1.019e-03 s
# z = 592.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 593.000 m, σ_τ = 1.019e-03 s
# z = 593.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 593.500 m, σ_τ = 1.019e-03 s
# z = 593.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 594.000 m, σ_τ = 1.019e-03 s
# z = 594.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 594.500 m, σ_τ = 1.019e-03 s
# z = 594.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 595.000 m, σ_τ = 1.019e-03 s
# z = 595.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 595.500 m, σ_τ = 1.019e-03 s
# z = 595.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 596.000 m, σ_τ = 1.019e-03 s
# z = 596.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 596.500 m, σ_τ = 1.019e-03 s
# z = 596.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 597.000 m, σ_τ = 1.019e-03 s
# z = 597.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 597.500 m, σ_τ = 1.019e-03 s
# z = 597.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 598.000 m, σ_τ = 1.019e-03 s
# z = 598.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 598.500 m, σ_τ = 1.019e-03 s
# z = 598.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 599.000 m, σ_τ = 1.019e-03 s
# z = 599.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 599.500 m, σ_τ = 1.019e-03 s
# z = 599.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 600.000 m, σ_τ = 1.019e-03 s
# z = 600.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 600.500 m, σ_τ = 1.019e-03 s
# z = 600.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 601.000 m, σ_τ = 1.019e-03 s
# z = 601.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 601.500 m, σ_τ = 1.019e-03 s
# z = 601.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 602.000 m, σ_τ = 1.019e-03 s
# z = 602.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 602.500 m, σ_τ = 1.019e-03 s
# z = 602.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 603.000 m, σ_τ = 1.019e-03 s
# z = 603.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 603.500 m, σ_τ = 1.019e-03 s
# z = 603.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 604.000 m, σ_τ = 1.019e-03 s
# z = 604.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 604.500 m, σ_τ = 1.019e-03 s
# z = 604.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 605.000 m, σ_τ = 1.019e-03 s
# z = 605.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 605.500 m, σ_τ = 1.019e-03 s
# z = 605.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 606.000 m, σ_τ = 1.019e-03 s
# z = 606.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 606.500 m, σ_τ = 1.019e-03 s
# z = 606.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 607.000 m, σ_τ = 1.019e-03 s
# z = 607.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 607.500 m, σ_τ = 1.019e-03 s
# z = 607.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 608.000 m, σ_τ = 1.019e-03 s
# z = 608.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 608.500 m, σ_τ = 1.019e-03 s
# z = 608.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 609.000 m, σ_τ = 1.019e-03 s
# z = 609.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 609.500 m, σ_τ = 1.019e-03 s
# z = 609.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 610.000 m, σ_τ = 1.019e-03 s
# z = 610.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 610.500 m, σ_τ = 1.019e-03 s
# z = 610.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 611.000 m, σ_τ = 1.019e-03 s
# z = 611.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 611.500 m, σ_τ = 1.019e-03 s
# z = 611.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 612.000 m, σ_τ = 1.019e-03 s
# z = 612.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 612.500 m, σ_τ = 1.019e-03 s
# z = 612.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 613.000 m, σ_τ = 1.019e-03 s
# z = 613.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 613.500 m, σ_τ = 1.019e-03 s
# z = 613.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 614.000 m, σ_τ = 1.019e-03 s
# z = 614.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 614.500 m, σ_τ = 1.019e-03 s
# z = 614.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 615.000 m, σ_τ = 1.019e-03 s
# z = 615.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 615.500 m, σ_τ = 1.019e-03 s
# z = 615.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 616.000 m, σ_τ = 1.019e-03 s
# z = 616.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 616.500 m, σ_τ = 1.019e-03 s
# z = 616.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 617.000 m, σ_τ = 1.019e-03 s
# z = 617.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 617.500 m, σ_τ = 1.019e-03 s
# z = 617.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 618.000 m, σ_τ = 1.019e-03 s
# z = 618.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 618.500 m, σ_τ = 1.019e-03 s
# z = 618.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 619.000 m, σ_τ = 1.019e-03 s
# z = 619.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 619.500 m, σ_τ = 1.019e-03 s
# z = 619.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 620.000 m, σ_τ = 1.019e-03 s
# z = 620.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 620.500 m, σ_τ = 1.019e-03 s
# z = 620.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 621.000 m, σ_τ = 1.019e-03 s
# z = 621.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 621.500 m, σ_τ = 1.019e-03 s
# z = 621.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 622.000 m, σ_τ = 1.019e-03 s
# z = 622.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 622.500 m, σ_τ = 1.019e-03 s
# z = 622.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 623.000 m, σ_τ = 1.019e-03 s
# z = 623.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 623.500 m, σ_τ = 1.019e-03 s
# z = 623.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 624.000 m, σ_τ = 1.019e-03 s
# z = 624.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 624.500 m, σ_τ = 1.019e-03 s
# z = 624.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 625.000 m, σ_τ = 1.019e-03 s
# z = 625.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 625.500 m, σ_τ = 1.019e-03 s
# z = 625.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 626.000 m, σ_τ = 1.019e-03 s
# z = 626.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 626.500 m, σ_τ = 1.019e-03 s
# z = 626.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 627.000 m, σ_τ = 1.019e-03 s
# z = 627.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 627.500 m, σ_τ = 1.019e-03 s
# z = 627.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 628.000 m, σ_τ = 1.019e-03 s
# z = 628.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 628.500 m, σ_τ = 1.019e-03 s
# z = 628.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 629.000 m, σ_τ = 1.019e-03 s
# z = 629.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 629.500 m, σ_τ = 1.019e-03 s
# z = 629.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 630.000 m, σ_τ = 1.019e-03 s
# z = 630.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 630.500 m, σ_τ = 1.019e-03 s
# z = 630.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 631.000 m, σ_τ = 1.019e-03 s
# z = 631.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 631.500 m, σ_τ = 1.019e-03 s
# z = 631.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 632.000 m, σ_τ = 1.019e-03 s
# z = 632.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 632.500 m, σ_τ = 1.019e-03 s
# z = 632.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 633.000 m, σ_τ = 1.019e-03 s
# z = 633.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 633.500 m, σ_τ = 1.019e-03 s
# z = 633.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 634.000 m, σ_τ = 1.019e-03 s
# z = 634.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 634.500 m, σ_τ = 1.019e-03 s
# z = 634.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 635.000 m, σ_τ = 1.019e-03 s
# z = 635.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 635.500 m, σ_τ = 1.019e-03 s
# z = 635.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 636.000 m, σ_τ = 1.019e-03 s
# z = 636.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 636.500 m, σ_τ = 1.019e-03 s
# z = 636.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 637.000 m, σ_τ = 1.019e-03 s
# z = 637.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 637.500 m, σ_τ = 1.019e-03 s
# z = 637.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 638.000 m, σ_τ = 1.019e-03 s
# z = 638.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 638.500 m, σ_τ = 1.019e-03 s
# z = 638.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 639.000 m, σ_τ = 1.019e-03 s
# z = 639.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 639.500 m, σ_τ = 1.019e-03 s
# z = 639.5 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 640.000 m, σ_τ = 1.019e-03 s
# z = 640.0 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWakes = 640.073 m, σ_τ = 1.019e-03 s
# z = 640.073448422781 / 640.073448422781. Applied: HookProcess, CustomLongitudinalWake

# %%
import matplotlib.pyplot as plt

# Energy distributions (Δp/p)
dp_p_no_wake = p_array_no_wake.rparticles[5]
dp_p_wake = p_array_wake.rparticles[5]

plt.figure(figsize=(8,6))
plt.hist(dp_p_no_wake, bins=200, histtype='step', label='No Wake', density=True)
plt.hist(dp_p_wake, bins=200, histtype='step', label='With Custom Wake', density=True, linestyle='--')
plt.xlabel('Δp/p')
plt.ylabel('Normalized counts')
plt.title('Energy distribution comparison')
plt.xlim(-0.1,0.1)
plt.grid(True)
plt.legend()
plt.show()

# %%
show_e_beam(p_array_no_wake)

# %%
show_e_beam(p_array_wake)

# %%
import numpy as np

# particle data 
np.save("particles_rparticles_wake.npy", p_array_wake.rparticles)

# charge array
np.save("particles_q_array_wake.npy", p_array_wake.q_array)
