# %%
from ocelot import *
from ocelot.cpbd.elements import *
from ocelot.gui.accelerator import *
from ocelot.cpbd.track import track_debug
import matplotlib.pyplot as plt


from linaccopy import *

# Define a very simple lattice: one big drift
# Define elements
drift_length = 50.0  # meters
drift = Drift(l=drift_length, eid="D1")

cavity_voltage = 5e6  # 5 MV (can adjust)
cavity = Cavity(l=10, eid="CAV1")  # simple 0.5 m cavity
cavity.voltage = cavity_voltage  # Voltage in Volts
cavity.freq = 1.3e9  # 1.3 GHz typical frequency
cavity.phase = 0.0   # 0° synchronous phase (can play with later)

# Create the toy lattice: Cavity + Drift
toy_lat = MagneticLattice([cavity, drift])


lat = MagneticLattice(guntoB)

#lat = toy_lat



##### PA1RFGUN #####
AX =-21.12   
BX =24.36 
AY =-21.16     
BY =24.42      
EMITX =1.2023504614117648e-06
EMITY =1.2023504614117648e-06 
DP =.01
##### PA1RFGUN #####

energy = 0.0091 # GeV  #why?
tw0 = Twiss()
tw0.alpha_x = AX
tw0.beta_x = BX

tw0.alpha_y = AY
tw0.beta_y = BY
tw0.E = energy
tw0.emit_xn = EMITX 
tw0.emit_yn = EMITY
tw0.emit_x = EMITX   / energy * 0.511e-3
tw0.emit_y = EMITY / energy * 0.511e-3

tws = twiss(lat,tw0)

plot_opt_func(lat, tws,legend=False, grid=False, top_plot=['Dx','Dy'])


for elem in lat.sequence:
    if not isinstance(elem, Drift):
        print(elem)
# Out:
# Marker(eid="PA1RFGUN")
# Quadrupole(l=0.07360, k1=-4.662753e+01, eid="QDA1G1")
# Quadrupole(l=0.07360, k1=4.709763e+01, eid="QFA1G2")
# Bend(eid="BXA1G")
# Bend(tilt=1.570796e+00, eid="BYA1G")
# Quadrupole(l=0.07360, k1=-8.030131e+00, eid="QDA101")
# Quadrupole(l=0.07360, k1=2.957378e+00, eid="QFA102")
# Marker(eid="PACA11")
# Cavity(l=0.61850, v=6.662282e-03, freq=2.856000e+09, phi=4.000000e+01, eid="ACA111")
# Bend(eid="SXA11")
# Bend(tilt=1.570796e+00, eid="SYA11")
# Cavity(l=1.27095, v=1.369683e-02, freq=2.856000e+09, phi=4.000000e+01, eid="ACA112")
# Marker(eid="PACA11")
# Quadrupole(l=0.07360, k1=-1.142003e-01, eid="QDA111")
# Quadrupole(l=0.11460, k1=5.928660e+00, eid="QFA112")
# Quadrupole(l=0.07360, k1=-7.876449e-03, eid="QDA113")
# Bend(l=0.14725, angle=1.605878e-01, e2=1.605878e-01, eid="BMA1C1")
# Bend(l=0.14725, angle=-1.605878e-01, e1=-1.605878e-01, eid="BMA1C2")
# Bend(l=0.14725, angle=-1.605878e-01, e2=-1.605878e-01, eid="BMA1C3")
# Bend(l=0.14725, angle=1.605878e-01, e1=1.605878e-01, eid="BMA1C4")
# Bend(l=0.17300, eid="BMATJ5")
# Marker(eid="PSECTA")
# Quadrupole(l=0.12235, k1=-9.100855e+00, eid="PDA1M")
# Quadrupole(l=0.12235, k1=1.137240e+01, eid="PFA1M")
# Bend(eid="PXA1M")
# Bend(tilt=1.570796e+00, eid="PYA1M")
# Cavity(l=0.03499, eid="AKA21")
# Marker(eid="PACA21")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA21")
# Bend(eid="SXA21")
# Bend(tilt=1.570796e+00, eid="SYA21")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA212")
# Marker(eid="PACA21")
# Cavity(l=0.03499, eid="AKA21")
# Marker(eid="PPDA21")
# Quadrupole(l=0.12235, k1=-1.323075e+01, eid="PDA21")
# Quadrupole(l=0.12235, k1=1.689616e+01, eid="PFA21")
# Cavity(l=0.03499, eid="AKA22")
# Marker(eid="PACA22")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA22")
# Bend(eid="SXA22")
# Bend(tilt=1.570796e+00, eid="SYA22")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA222")
# Marker(eid="PACA22")
# Cavity(l=0.03499, eid="AKA22")
# Cavity(l=0.03499, eid="AKA23")
# Marker(eid="PACA23")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA23")
# Bend(eid="SXA23")
# Bend(tilt=1.570796e+00, eid="SYA23")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA232")
# Marker(eid="PACA23")
# Cavity(l=0.03499, eid="AKA23")
# Quadrupole(l=0.07500, k1=-1.071808e+01, eid="QDA23")
# Quadrupole(l=0.12100, k1=1.182822e+01, eid="QFA23")
# Quadrupole(l=0.07500, k1=-1.071808e+01, eid="QDA23")
# Cavity(l=0.03499, eid="AKA24")
# Marker(eid="PACA24")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA24")
# Bend(eid="SXA24")
# Bend(tilt=1.570796e+00, eid="SYA24")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA242")
# Marker(eid="PACA24")
# Cavity(l=0.03499, eid="AKA24")
# Marker(eid="PQDA24")
# Quadrupole(l=0.12100, k1=-8.575773e+00, eid="QDA24")
# Quadrupole(l=0.22200, k1=9.049769e+00, eid="QFA24")
# Quadrupole(l=0.12100, k1=-8.575773e+00, eid="QDA24")
# Cavity(l=0.03499, eid="AKA31")
# Marker(eid="PACA31")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA31")
# Bend(eid="SXA31")
# Bend(tilt=1.570796e+00, eid="SYA31")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA312")
# Marker(eid="PACA31")
# Cavity(l=0.03499, eid="AKA31")
# Cavity(l=0.03499, eid="AKA32")
# Marker(eid="PACA32")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA32")
# Bend(eid="SXA32")
# Bend(tilt=1.570796e+00, eid="SYA32")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA322")
# Marker(eid="PACA32")
# Cavity(l=0.03499, eid="AKA32")
# Marker(eid="PQDA32")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA32")
# Quadrupole(l=0.22200, k1=9.294356e+00, eid="QFA32")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA32")
# Cavity(l=0.03499, eid="AKA33")
# Marker(eid="PACA33")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA33")
# Bend(eid="SXA33")
# Bend(tilt=1.570796e+00, eid="SYA33")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA332")
# Marker(eid="PACA33")
# Cavity(l=0.03499, eid="AKA33")
# Cavity(l=0.03499, eid="AKA34")
# Marker(eid="PACA34")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA34")
# Bend(eid="SXA34")
# Bend(tilt=1.570796e+00, eid="SYA34")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA342")
# Marker(eid="PACA34")
# Cavity(l=0.03499, eid="AKA34")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA34")
# Quadrupole(l=0.22200, k1=9.294356e+00, eid="QFA34")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA34")
# Cavity(l=0.03499, eid="AKA41")
# Marker(eid="PACA41")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA41")
# Bend(eid="SXA41")
# Bend(tilt=1.570796e+00, eid="SYA41")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA412")
# Marker(eid="PACA41")
# Cavity(l=0.03499, eid="AKA41")
# Cavity(l=0.03499, eid="AKA42")
# Marker(eid="PACA42")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA42")
# Bend(eid="SXA42")
# Bend(tilt=1.570796e+00, eid="SYA42")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA422")
# Marker(eid="PACA42")
# Cavity(l=0.03499, eid="AKA42")
# Quadrupole(l=0.12100, k1=-4.601097e+00, eid="QDA42")
# Quadrupole(l=0.22200, k1=5.050408e+00, eid="QFA42")
# Quadrupole(l=0.12100, k1=-4.601097e+00, eid="QDA42")
# Cavity(l=0.03499, eid="AKA43")
# Marker(eid="PACA43")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA43")
# Bend(eid="SXA43")
# Bend(tilt=1.570796e+00, eid="SYA43")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA432")
# Marker(eid="PACA43")
# Cavity(l=0.03499, eid="AKA43")
# Cavity(l=0.03499, eid="AKA44")
# Marker(eid="PACA44")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA44")
# Bend(eid="SXA44")
# Bend(tilt=1.570796e+00, eid="SYA44")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA442")
# Marker(eid="PACA44")
# Cavity(l=0.03499, eid="AKA44")
# Quadrupole(l=0.12100, k1=-6.419987e+00, eid="QDA44")
# Quadrupole(l=0.22200, k1=6.868209e+00, eid="QFA44")
# Quadrupole(l=0.12100, k1=-6.419987e+00, eid="QDA44")
# Bend(l=0.14155, eid="PXA44")
# Bend(l=0.14155, tilt=1.570796e+00, eid="PYA44")
# Marker(eid="PSECTB")
# Marker(eid="ID_44970975_")

# %%
def gauss_from_twiss_vec(emit, beta, alpha, size=1):
    phi = 2 * np.pi * np.random.rand(size)
    u = np.random.rand(size)
    a = np.sqrt(-2 * np.log(1 - u) * emit)
    x = a * np.sqrt(beta) * np.cos(phi)
    xp = -a / np.sqrt(beta) * (np.sin(phi) + alpha * np.cos(phi))
    return x, xp

nparticles = 100000
p_array = ParticleArray(n=nparticles)

# sigma_tau = 6.7e-3  # (bunch length in)
# sigma_p = 5.e-4     # relative momentum spread (Δp/p)  

sigma_tau = 4e-3  # (bunch length in )
sigma_p = 0.001     # relative momentum spread (Δp/p)  


p_array.E = energy  # GeV

# Longitudinal
p_array.rparticles[4] = np.random.randn(nparticles) * sigma_tau
p_array.rparticles[5] = np.random.randn(nparticles) * sigma_p

# Transverse: vectorized sampling from Twiss parameters
x, xp = gauss_from_twiss_vec(tw0.emit_x, tw0.beta_x, tw0.alpha_x, size=nparticles)
y, yp = gauss_from_twiss_vec(tw0.emit_y, tw0.beta_y, tw0.alpha_y, size=nparticles)

p_array.rparticles[0] = x
p_array.rparticles[1] = xp
p_array.rparticles[2] = y
p_array.rparticles[3] = yp

# Charge distribution
charge = 4.0e-9  # nC
p_array.q_array = np.ones(nparticles) * (charge / nparticles)

# %%
from ocelot.cpbd.physics_proc import PhysProc

class CustomLongitudinalWake(PhysProc):
    def __init__(self, beam_radius=0.01, bunch_length=4e-3):
        super().__init__()
        self.Z0 = 377  # Ohm
        self.a = beam_radius
        self.L = bunch_length
        self.N = None

    def apply(self, p_array, step_size):
        z = p_array.rparticles[4]
        q = p_array.q_array
        
        if self.N is None:
            self.N = len(z)
        
        z_mean = np.mean(z)
        s = z - z_mean  # centered z
        
        # Resistive Wall Wake approximation: ~ 1/sqrt(-z)
        wake = np.zeros_like(s)
        mask = s < 0  # only trailing particles feel the wake
        wake[mask] = 1.0 / np.sqrt(-s[mask] + 1e-12)  # add epsilon to avoid division by zero
        
        # Normalize and scale
        W0 = 1e6  # Scaling factor [V/C/m^1/2], can adjust
        voltage = - (self.N * np.abs(q[0]) * self.Z0 * W0 / (self.a**2)) * wake
        voltage /= 20  # Divide by 10 to reduce wake strength

        
        # Apply kick
        delta_E = voltage * step_size
        E = p_array.E  # GeV
        delta_dp_p = delta_E / (E * 1e9)
        
        p_array.rparticles[5] += delta_dp_p

# %%
import time
from copy import deepcopy
import numpy as np
import matplotlib.pyplot as plt
from ocelot.cpbd.physics_proc import PhysProc

# Define the HookProcess to monitor sigma_tau
class HookProcess(PhysProc):
    def __init__(self, sigma_tau_list):
        super().__init__()
        self.sigma_tau_list = sigma_tau_list

    def apply(self, p_array, step_size):
        sigma_tau = np.std(p_array.rparticles[4])
        self.sigma_tau_list.append(sigma_tau)
        print(f"s = {self.z0:.3f} m, σ_τ = {sigma_tau:.3e} s")

# === TRACK WITHOUT WAKEFIELD ===
p_array_no_wake = deepcopy(p_array)

navi_no_wake = Navigator(lat)
navi_no_wake.unit_step = 0.5

sigma_tau_list_no_wake = []
hook_no_wake = HookProcess(sigma_tau_list_no_wake)
navi_no_wake.add_physics_proc(hook_no_wake, lat.sequence[0], lat.sequence[-1])

tws_no_wake, p_array_no_wake = track(lat, p_array_no_wake, navi_no_wake)

# === TRACK WITH CUSTOM WAKEFIELD ===
p_array_wake = deepcopy(p_array)

navi_wake = Navigator(lat)
navi_wake.unit_step = 0.5

sigma_tau_list_wake = []
hook_wake = HookProcess(sigma_tau_list_wake)
navi_wake.add_physics_proc(hook_wake, lat.sequence[0], lat.sequence[-1])

# Add custom wake
wake_proc = CustomLongitudinalWake(beam_radius=0.01, bunch_length=sigma_tau)
navi_wake.add_physics_proc(wake_proc, lat.sequence[0], lat.sequence[-1])

tws_wake, p_array_wake = track(lat, p_array_wake, navi_wake)

# === PLOT THE COMPARISON ===
s_axis_no_wake = np.linspace(0, lat.totalLen, len(sigma_tau_list_no_wake))
s_axis_wake = np.linspace(0, lat.totalLen, len(sigma_tau_list_wake))

plt.plot(s_axis_no_wake, sigma_tau_list_no_wake, label='No Wake')
plt.plot(s_axis_wake, sigma_tau_list_wake, '--', label='With Custom Wake')
plt.xlabel("s [m]")
plt.ylabel("σ_τ [s]")
plt.title("Evolution of Bunch Length σ_τ With and Without Wakefield")
plt.grid(True)
plt.legend()
plt.show()

# === PHASE SPACE PLOTS ===
def plot_phase_space(z, dp_p, title):
    plt.figure(figsize=(8,6))
    hb = plt.hexbin(z*1e3, dp_p, gridsize=100, cmap='plasma', bins='log')
    plt.colorbar(hb, label='log(Particle density)')
    plt.xlabel('z [mm]')
    plt.ylabel('Δp/p')
    plt.title(title)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# No wake
plot_phase_space(p_array_no_wake.rparticles[4], p_array_no_wake.rparticles[5], 'No Wake')

# With wake
plot_phase_space(p_array_wake.rparticles[4], p_array_wake.rparticles[5], 'With Custom Wake')
# Out:
# s = 0.500 m, σ_τ = 4.002e-03 s
# z = 0.5 / 45.013947600000016. Applied: HookProcesss = 1.000 m, σ_τ = 4.002e-03 s
# z = 1.0 / 45.013947600000016. Applied: HookProcesss = 1.500 m, σ_τ = 4.002e-03 s
# z = 1.5 / 45.013947600000016. Applied: HookProcesss = 2.000 m, σ_τ = 3.996e-03 s
# z = 2.0 / 45.013947600000016. Applied: HookProcesss = 2.500 m, σ_τ = 3.952e-03 s
# z = 2.5 / 45.013947600000016. Applied: HookProcesss = 3.000 m, σ_τ = 3.907e-03 s
# z = 3.0 / 45.013947600000016. Applied: HookProcesss = 3.500 m, σ_τ = 3.871e-03 s
# z = 3.5 / 45.013947600000016. Applied: HookProcesss = 4.000 m, σ_τ = 3.842e-03 s
# z = 4.0 / 45.013947600000016. Applied: HookProcesss = 4.500 m, σ_τ = 3.816e-03 s
# z = 4.5 / 45.013947600000016. Applied: HookProcesss = 5.000 m, σ_τ = 3.867e-03 s
# z = 5.0 / 45.013947600000016. Applied: HookProcesss = 5.500 m, σ_τ = 2.357e-03 s
# z = 5.5 / 45.013947600000016. Applied: HookProcesss = 6.000 m, σ_τ = 1.033e-03 s
# z = 6.0 / 45.013947600000016. Applied: HookProcesss = 6.500 m, σ_τ = 1.060e-03 s
# z = 6.5 / 45.013947600000016. Applied: HookProcesss = 7.000 m, σ_τ = 1.043e-03 s
# z = 7.0 / 45.013947600000016. Applied: HookProcesss = 7.500 m, σ_τ = 1.026e-03 s
# z = 7.5 / 45.013947600000016. Applied: HookProcesss = 8.000 m, σ_τ = 1.009e-03 s
# z = 8.0 / 45.013947600000016. Applied: HookProcesss = 8.500 m, σ_τ = 9.930e-04 s
# z = 8.5 / 45.013947600000016. Applied: HookProcesss = 9.000 m, σ_τ = 9.772e-04 s
# z = 9.0 / 45.013947600000016. Applied: HookProcesss = 9.500 m, σ_τ = 9.619e-04 s
# z = 9.5 / 45.013947600000016. Applied: HookProcesss = 10.000 m, σ_τ = 9.504e-04 s
# z = 10.0 / 45.013947600000016. Applied: HookProcesss = 10.500 m, σ_τ = 9.456e-04 s
# z = 10.5 / 45.013947600000016. Applied: HookProcesss = 11.000 m, σ_τ = 9.432e-04 s
# z = 11.0 / 45.013947600000016. Applied: HookProcesss = 11.500 m, σ_τ = 9.419e-04 s
# z = 11.5 / 45.013947600000016. Applied: HookProcesss = 12.000 m, σ_τ = 9.409e-04 s
# z = 12.0 / 45.013947600000016. Applied: HookProcesss = 12.500 m, σ_τ = 9.399e-04 s
# z = 12.5 / 45.013947600000016. Applied: HookProcesss = 13.000 m, σ_τ = 9.392e-04 s
# z = 13.0 / 45.013947600000016. Applied: HookProcesss = 13.500 m, σ_τ = 9.387e-04 s
# z = 13.5 / 45.013947600000016. Applied: HookProcesss = 14.000 m, σ_τ = 9.383e-04 s
# z = 14.0 / 45.013947600000016. Applied: HookProcesss = 14.500 m, σ_τ = 9.381e-04 s
# z = 14.5 / 45.013947600000016. Applied: HookProcesss = 15.000 m, σ_τ = 9.379e-04 s
# z = 15.0 / 45.013947600000016. Applied: HookProcesss = 15.500 m, σ_τ = 9.377e-04 s
# z = 15.5 / 45.013947600000016. Applied: HookProcesss = 16.000 m, σ_τ = 9.375e-04 s
# z = 16.0 / 45.013947600000016. Applied: HookProcesss = 16.500 m, σ_τ = 9.374e-04 s
# z = 16.5 / 45.013947600000016. Applied: HookProcesss = 17.000 m, σ_τ = 9.373e-04 s
# z = 17.0 / 45.013947600000016. Applied: HookProcesss = 17.500 m, σ_τ = 9.372e-04 s
# z = 17.5 / 45.013947600000016. Applied: HookProcesss = 18.000 m, σ_τ = 9.371e-04 s
# z = 18.0 / 45.013947600000016. Applied: HookProcesss = 18.500 m, σ_τ = 9.371e-04 s
# z = 18.5 / 45.013947600000016. Applied: HookProcesss = 19.000 m, σ_τ = 9.370e-04 s
# z = 19.0 / 45.013947600000016. Applied: HookProcesss = 19.500 m, σ_τ = 9.370e-04 s
# z = 19.5 / 45.013947600000016. Applied: HookProcesss = 20.000 m, σ_τ = 9.369e-04 s
# z = 20.0 / 45.013947600000016. Applied: HookProcesss = 20.500 m, σ_τ = 9.369e-04 s
# z = 20.5 / 45.013947600000016. Applied: HookProcesss = 21.000 m, σ_τ = 9.369e-04 s
# z = 21.0 / 45.013947600000016. Applied: HookProcesss = 21.500 m, σ_τ = 9.369e-04 s
# z = 21.5 / 45.013947600000016. Applied: HookProcesss = 22.000 m, σ_τ = 9.368e-04 s
# z = 22.0 / 45.013947600000016. Applied: HookProcesss = 22.500 m, σ_τ = 9.368e-04 s
# z = 22.5 / 45.013947600000016. Applied: HookProcesss = 23.000 m, σ_τ = 9.368e-04 s
# z = 23.0 / 45.013947600000016. Applied: HookProcesss = 23.500 m, σ_τ = 9.368e-04 s
# z = 23.5 / 45.013947600000016. Applied: HookProcesss = 24.000 m, σ_τ = 9.368e-04 s
# z = 24.0 / 45.013947600000016. Applied: HookProcesss = 24.500 m, σ_τ = 9.368e-04 s
# z = 24.5 / 45.013947600000016. Applied: HookProcesss = 25.000 m, σ_τ = 9.368e-04 s
# z = 25.0 / 45.013947600000016. Applied: HookProcesss = 25.500 m, σ_τ = 9.368e-04 s
# z = 25.5 / 45.013947600000016. Applied: HookProcesss = 26.000 m, σ_τ = 9.368e-04 s
# z = 26.0 / 45.013947600000016. Applied: HookProcesss = 26.500 m, σ_τ = 9.368e-04 s
# z = 26.5 / 45.013947600000016. Applied: HookProcesss = 27.000 m, σ_τ = 9.368e-04 s
# z = 27.0 / 45.013947600000016. Applied: HookProcesss = 27.500 m, σ_τ = 9.368e-04 s
# z = 27.5 / 45.013947600000016. Applied: HookProcesss = 28.000 m, σ_τ = 9.368e-04 s
# z = 28.0 / 45.013947600000016. Applied: HookProcesss = 28.500 m, σ_τ = 9.368e-04 s
# z = 28.5 / 45.013947600000016. Applied: HookProcesss = 29.000 m, σ_τ = 9.368e-04 s
# z = 29.0 / 45.013947600000016. Applied: HookProcesss = 29.500 m, σ_τ = 9.368e-04 s
# z = 29.5 / 45.013947600000016. Applied: HookProcesss = 30.000 m, σ_τ = 9.368e-04 s
# z = 30.0 / 45.013947600000016. Applied: HookProcesss = 30.500 m, σ_τ = 9.368e-04 s
# z = 30.5 / 45.013947600000016. Applied: HookProcesss = 31.000 m, σ_τ = 9.368e-04 s
# z = 31.0 / 45.013947600000016. Applied: HookProcesss = 31.500 m, σ_τ = 9.368e-04 s
# z = 31.5 / 45.013947600000016. Applied: HookProcesss = 32.000 m, σ_τ = 9.368e-04 s
# z = 32.0 / 45.013947600000016. Applied: HookProcesss = 32.500 m, σ_τ = 9.368e-04 s
# z = 32.5 / 45.013947600000016. Applied: HookProcesss = 33.000 m, σ_τ = 9.368e-04 s
# z = 33.0 / 45.013947600000016. Applied: HookProcesss = 33.500 m, σ_τ = 9.368e-04 s
# z = 33.5 / 45.013947600000016. Applied: HookProcesss = 34.000 m, σ_τ = 9.368e-04 s
# z = 34.0 / 45.013947600000016. Applied: HookProcesss = 34.500 m, σ_τ = 9.368e-04 s
# z = 34.5 / 45.013947600000016. Applied: HookProcesss = 35.000 m, σ_τ = 9.368e-04 s
# z = 35.0 / 45.013947600000016. Applied: HookProcesss = 35.500 m, σ_τ = 9.368e-04 s
# z = 35.5 / 45.013947600000016. Applied: HookProcesss = 36.000 m, σ_τ = 9.368e-04 s
# z = 36.0 / 45.013947600000016. Applied: HookProcesss = 36.500 m, σ_τ = 9.368e-04 s
# z = 36.5 / 45.013947600000016. Applied: HookProcesss = 37.000 m, σ_τ = 9.368e-04 s
# z = 37.0 / 45.013947600000016. Applied: HookProcesss = 37.500 m, σ_τ = 9.368e-04 s
# z = 37.5 / 45.013947600000016. Applied: HookProcesss = 38.000 m, σ_τ = 9.368e-04 s
# z = 38.0 / 45.013947600000016. Applied: HookProcesss = 38.500 m, σ_τ = 9.368e-04 s
# z = 38.5 / 45.013947600000016. Applied: HookProcesss = 39.000 m, σ_τ = 9.368e-04 s
# z = 39.0 / 45.013947600000016. Applied: HookProcesss = 39.500 m, σ_τ = 9.368e-04 s
# z = 39.5 / 45.013947600000016. Applied: HookProcesss = 40.000 m, σ_τ = 9.368e-04 s
# z = 40.0 / 45.013947600000016. Applied: HookProcesss = 40.500 m, σ_τ = 9.368e-04 s
# z = 40.5 / 45.013947600000016. Applied: HookProcesss = 41.000 m, σ_τ = 9.368e-04 s
# z = 41.0 / 45.013947600000016. Applied: HookProcesss = 41.500 m, σ_τ = 9.368e-04 s
# z = 41.5 / 45.013947600000016. Applied: HookProcesss = 42.000 m, σ_τ = 9.368e-04 s
# z = 42.0 / 45.013947600000016. Applied: HookProcesss = 42.500 m, σ_τ = 9.368e-04 s
# z = 42.5 / 45.013947600000016. Applied: HookProcesss = 43.000 m, σ_τ = 9.368e-04 s
# z = 43.0 / 45.013947600000016. Applied: HookProcesss = 43.500 m, σ_τ = 9.368e-04 s
# z = 43.5 / 45.013947600000016. Applied: HookProcesss = 44.000 m, σ_τ = 9.368e-04 s
# z = 44.0 / 45.013947600000016. Applied: HookProcesss = 44.500 m, σ_τ = 9.368e-04 s
# z = 44.5 / 45.013947600000016. Applied: HookProcesss = 45.000 m, σ_τ = 9.368e-04 s
# z = 45.0 / 45.013947600000016. Applied: HookProcesss = 45.014 m, σ_τ = 9.368e-04 s
# z = 45.013947599999995 / 45.013947600000016. Applied: HookProcesss = 0.500 m, σ_τ = 4.002e-03 s
# z = 0.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 1.000 m, σ_τ = 4.002e-03 s
# z = 1.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 1.500 m, σ_τ = 4.001e-03 s
# z = 1.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 2.000 m, σ_τ = 3.994e-03 s
# z = 2.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 2.500 m, σ_τ = 3.949e-03 s
# z = 2.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 3.000 m, σ_τ = 3.904e-03 s
# z = 3.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 3.500 m, σ_τ = 3.867e-03 s
# z = 3.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 4.000 m, σ_τ = 3.838e-03 s
# z = 4.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 4.500 m, σ_τ = 3.812e-03 s
# z = 4.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 5.000 m, σ_τ = 3.863e-03 s
# z = 5.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 5.500 m, σ_τ = 2.342e-03 s
# z = 5.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 6.000 m, σ_τ = 1.009e-03 s
# z = 6.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 6.500 m, σ_τ = 1.032e-03 s
# z = 6.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 7.000 m, σ_τ = 1.014e-03 s
# z = 7.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 7.500 m, σ_τ = 9.966e-04 s
# z = 7.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 8.000 m, σ_τ = 9.797e-04 s
# z = 8.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 8.500 m, σ_τ = 9.632e-04 s
# z = 8.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 9.000 m, σ_τ = 9.471e-04 s
# z = 9.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 9.500 m, σ_τ = 9.315e-04 s
# z = 9.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 10.000 m, σ_τ = 9.197e-04 s
# z = 10.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 10.500 m, σ_τ = 9.147e-04 s
# z = 10.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 11.000 m, σ_τ = 9.122e-04 s
# z = 11.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 11.500 m, σ_τ = 9.108e-04 s
# z = 11.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 12.000 m, σ_τ = 9.098e-04 s
# z = 12.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 12.500 m, σ_τ = 9.087e-04 s
# z = 12.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 13.000 m, σ_τ = 9.080e-04 s
# z = 13.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 13.500 m, σ_τ = 9.074e-04 s
# z = 13.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 14.000 m, σ_τ = 9.071e-04 s
# z = 14.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 14.500 m, σ_τ = 9.068e-04 s
# z = 14.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 15.000 m, σ_τ = 9.066e-04 s
# z = 15.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 15.500 m, σ_τ = 9.064e-04 s
# z = 15.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 16.000 m, σ_τ = 9.062e-04 s
# z = 16.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 16.500 m, σ_τ = 9.060e-04 s
# z = 16.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 17.000 m, σ_τ = 9.059e-04 s
# z = 17.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 17.500 m, σ_τ = 9.059e-04 s
# z = 17.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 18.000 m, σ_τ = 9.058e-04 s
# z = 18.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 18.500 m, σ_τ = 9.057e-04 s
# z = 18.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 19.000 m, σ_τ = 9.056e-04 s
# z = 19.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 19.500 m, σ_τ = 9.056e-04 s
# z = 19.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 20.000 m, σ_τ = 9.056e-04 s
# z = 20.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 20.500 m, σ_τ = 9.055e-04 s
# z = 20.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 21.000 m, σ_τ = 9.055e-04 s
# z = 21.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 21.500 m, σ_τ = 9.055e-04 s
# z = 21.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 22.000 m, σ_τ = 9.054e-04 s
# z = 22.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 22.500 m, σ_τ = 9.054e-04 s
# z = 22.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 23.000 m, σ_τ = 9.054e-04 s
# z = 23.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 23.500 m, σ_τ = 9.054e-04 s
# z = 23.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 24.000 m, σ_τ = 9.054e-04 s
# z = 24.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 24.500 m, σ_τ = 9.054e-04 s
# z = 24.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 25.000 m, σ_τ = 9.054e-04 s
# z = 25.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 25.500 m, σ_τ = 9.053e-04 s
# z = 25.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 26.000 m, σ_τ = 9.053e-04 s
# z = 26.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 26.500 m, σ_τ = 9.053e-04 s
# z = 26.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 27.000 m, σ_τ = 9.053e-04 s
# z = 27.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 27.500 m, σ_τ = 9.053e-04 s
# z = 27.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 28.000 m, σ_τ = 9.053e-04 s
# z = 28.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 28.500 m, σ_τ = 9.053e-04 s
# z = 28.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 29.000 m, σ_τ = 9.053e-04 s
# z = 29.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 29.500 m, σ_τ = 9.053e-04 s
# z = 29.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 30.000 m, σ_τ = 9.053e-04 s
# z = 30.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 30.500 m, σ_τ = 9.053e-04 s
# z = 30.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 31.000 m, σ_τ = 9.053e-04 s
# z = 31.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 31.500 m, σ_τ = 9.053e-04 s
# z = 31.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 32.000 m, σ_τ = 9.053e-04 s
# z = 32.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 32.500 m, σ_τ = 9.053e-04 s
# z = 32.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 33.000 m, σ_τ = 9.053e-04 s
# z = 33.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 33.500 m, σ_τ = 9.053e-04 s
# z = 33.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 34.000 m, σ_τ = 9.053e-04 s
# z = 34.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 34.500 m, σ_τ = 9.053e-04 s
# z = 34.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 35.000 m, σ_τ = 9.053e-04 s
# z = 35.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 35.500 m, σ_τ = 9.053e-04 s
# z = 35.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 36.000 m, σ_τ = 9.053e-04 s
# z = 36.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 36.500 m, σ_τ = 9.053e-04 s
# z = 36.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 37.000 m, σ_τ = 9.053e-04 s
# z = 37.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 37.500 m, σ_τ = 9.053e-04 s
# z = 37.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 38.000 m, σ_τ = 9.053e-04 s
# z = 38.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 38.500 m, σ_τ = 9.053e-04 s
# z = 38.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 39.000 m, σ_τ = 9.053e-04 s
# z = 39.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 39.500 m, σ_τ = 9.053e-04 s
# z = 39.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 40.000 m, σ_τ = 9.053e-04 s
# z = 40.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 40.500 m, σ_τ = 9.053e-04 s
# z = 40.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 41.000 m, σ_τ = 9.053e-04 s
# z = 41.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 41.500 m, σ_τ = 9.053e-04 s
# z = 41.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 42.000 m, σ_τ = 9.053e-04 s
# z = 42.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 42.500 m, σ_τ = 9.053e-04 s
# z = 42.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 43.000 m, σ_τ = 9.053e-04 s
# z = 43.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 43.500 m, σ_τ = 9.053e-04 s
# z = 43.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 44.000 m, σ_τ = 9.053e-04 s
# z = 44.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 44.500 m, σ_τ = 9.053e-04 s
# z = 44.5 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 45.000 m, σ_τ = 9.053e-04 s
# z = 45.0 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWakes = 45.014 m, σ_τ = 9.053e-04 s
# z = 45.013947599999995 / 45.013947600000016. Applied: HookProcess, CustomLongitudinalWake

# %%
import matplotlib.pyplot as plt

# Energy distributions (Δp/p)
dp_p_no_wake = p_array_no_wake.rparticles[5]
dp_p_wake = p_array_wake.rparticles[5]

plt.figure(figsize=(8,6))
plt.hist(dp_p_no_wake, bins=200, histtype='step', label='No Wake', density=True)
plt.hist(dp_p_wake, bins=200, histtype='step', label='With Custom Wake', density=True, linestyle='--')
plt.xlabel('Δp/p')
plt.ylabel('Normalized counts')
plt.title('Energy distribution comparison')
plt.xlim(-0.1,0.1)
plt.grid(True)
plt.legend()
plt.show()

# %%
show_e_beam(p_array_no_wake)

# %%
show_e_beam(p_array_wake)

# %%
import numpy as np

# particle data 
np.save("particles_rparticles_wake.npy", p_array_wake.rparticles)

# charge array
np.save("particles_q_array_wake.npy", p_array_wake.q_array)
