# %%
from ocelot import *
from ocelot.cpbd.elements import *
from ocelot.gui.accelerator import *
from ocelot.cpbd.track import track_debug
import matplotlib.pyplot as plt


from linaccopy import *


lat = MagneticLattice(guntoB)



##### PA1RFGUN #####
AX =-21.12   
BX =24.36 
AY =-21.16     
BY =24.42      
EMITX =1.2023504614117648e-06
EMITY =1.2023504614117648e-06 
DP =.01
##### PA1RFGUN #####

energy = 0.0091 # GeV  #why?
tw0 = Twiss()
tw0.alpha_x = AX
tw0.beta_x = BX

tw0.alpha_y = AY
tw0.beta_y = BY
tw0.E = energy
tw0.emit_xn = EMITX 
tw0.emit_yn = EMITY
tw0.emit_x = EMITX   / energy * 0.511e-3
tw0.emit_y = EMITY / energy * 0.511e-3

tws = twiss(lat,tw0)

plot_opt_func(lat, tws,legend=False, grid=False, top_plot=['Dx','Dy'])


for elem in lat.sequence:
    if not isinstance(elem, Drift):
        print(elem)
# Out:
# initializing ocelot...
# Marker(eid="PA1RFGUN")
# Quadrupole(l=0.07360, k1=-4.662753e+01, eid="QDA1G1")
# Quadrupole(l=0.07360, k1=4.709763e+01, eid="QFA1G2")
# Bend(eid="BXA1G")
# Bend(tilt=1.570796e+00, eid="BYA1G")
# Quadrupole(l=0.07360, k1=-8.030131e+00, eid="QDA101")
# Quadrupole(l=0.07360, k1=2.957378e+00, eid="QFA102")
# Marker(eid="PACA11")
# Cavity(l=0.61850, v=6.662282e-03, freq=2.856000e+09, phi=4.000000e+01, eid="ACA111")
# Bend(eid="SXA11")
# Bend(tilt=1.570796e+00, eid="SYA11")
# Cavity(l=1.27095, v=1.369683e-02, freq=2.856000e+09, phi=4.000000e+01, eid="ACA112")
# Marker(eid="PACA11")
# Quadrupole(l=0.07360, k1=-1.142003e-01, eid="QDA111")
# Quadrupole(l=0.11460, k1=5.928660e+00, eid="QFA112")
# Quadrupole(l=0.07360, k1=-7.876449e-03, eid="QDA113")
# Bend(l=0.14725, angle=1.605878e-01, e2=1.605878e-01, eid="BMA1C1")
# Bend(l=0.14725, angle=-1.605878e-01, e1=-1.605878e-01, eid="BMA1C2")
# Bend(l=0.14725, angle=-1.605878e-01, e2=-1.605878e-01, eid="BMA1C3")
# Bend(l=0.14725, angle=1.605878e-01, e1=1.605878e-01, eid="BMA1C4")
# Bend(l=0.17300, eid="BMATJ5")
# Marker(eid="PSECTA")
# Quadrupole(l=0.12235, k1=-9.100855e+00, eid="PDA1M")
# Quadrupole(l=0.12235, k1=1.137240e+01, eid="PFA1M")
# Bend(eid="PXA1M")
# Bend(tilt=1.570796e+00, eid="PYA1M")
# Cavity(l=0.03499, eid="AKA21")
# Marker(eid="PACA21")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA21")
# Bend(eid="SXA21")
# Bend(tilt=1.570796e+00, eid="SYA21")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA212")
# Marker(eid="PACA21")
# Cavity(l=0.03499, eid="AKA21")
# Marker(eid="PPDA21")
# Quadrupole(l=0.12235, k1=-1.323075e+01, eid="PDA21")
# Quadrupole(l=0.12235, k1=1.689616e+01, eid="PFA21")
# Cavity(l=0.03499, eid="AKA22")
# Marker(eid="PACA22")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA22")
# Bend(eid="SXA22")
# Bend(tilt=1.570796e+00, eid="SYA22")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA222")
# Marker(eid="PACA22")
# Cavity(l=0.03499, eid="AKA22")
# Cavity(l=0.03499, eid="AKA23")
# Marker(eid="PACA23")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA23")
# Bend(eid="SXA23")
# Bend(tilt=1.570796e+00, eid="SYA23")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA232")
# Marker(eid="PACA23")
# Cavity(l=0.03499, eid="AKA23")
# Quadrupole(l=0.07500, k1=-1.071808e+01, eid="QDA23")
# Quadrupole(l=0.12100, k1=1.182822e+01, eid="QFA23")
# Quadrupole(l=0.07500, k1=-1.071808e+01, eid="QDA23")
# Cavity(l=0.03499, eid="AKA24")
# Marker(eid="PACA24")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA24")
# Bend(eid="SXA24")
# Bend(tilt=1.570796e+00, eid="SYA24")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA242")
# Marker(eid="PACA24")
# Cavity(l=0.03499, eid="AKA24")
# Marker(eid="PQDA24")
# Quadrupole(l=0.12100, k1=-8.575773e+00, eid="QDA24")
# Quadrupole(l=0.22200, k1=9.049769e+00, eid="QFA24")
# Quadrupole(l=0.12100, k1=-8.575773e+00, eid="QDA24")
# Cavity(l=0.03499, eid="AKA31")
# Marker(eid="PACA31")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA31")
# Bend(eid="SXA31")
# Bend(tilt=1.570796e+00, eid="SYA31")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA312")
# Marker(eid="PACA31")
# Cavity(l=0.03499, eid="AKA31")
# Cavity(l=0.03499, eid="AKA32")
# Marker(eid="PACA32")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA32")
# Bend(eid="SXA32")
# Bend(tilt=1.570796e+00, eid="SYA32")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA322")
# Marker(eid="PACA32")
# Cavity(l=0.03499, eid="AKA32")
# Marker(eid="PQDA32")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA32")
# Quadrupole(l=0.22200, k1=9.294356e+00, eid="QFA32")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA32")
# Cavity(l=0.03499, eid="AKA33")
# Marker(eid="PACA33")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA33")
# Bend(eid="SXA33")
# Bend(tilt=1.570796e+00, eid="SYA33")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA332")
# Marker(eid="PACA33")
# Cavity(l=0.03499, eid="AKA33")
# Cavity(l=0.03499, eid="AKA34")
# Marker(eid="PACA34")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA34")
# Bend(eid="SXA34")
# Bend(tilt=1.570796e+00, eid="SYA34")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA342")
# Marker(eid="PACA34")
# Cavity(l=0.03499, eid="AKA34")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA34")
# Quadrupole(l=0.22200, k1=9.294356e+00, eid="QFA34")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA34")
# Cavity(l=0.03499, eid="AKA41")
# Marker(eid="PACA41")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA41")
# Bend(eid="SXA41")
# Bend(tilt=1.570796e+00, eid="SYA41")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA412")
# Marker(eid="PACA41")
# Cavity(l=0.03499, eid="AKA41")
# Cavity(l=0.03499, eid="AKA42")
# Marker(eid="PACA42")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA42")
# Bend(eid="SXA42")
# Bend(tilt=1.570796e+00, eid="SYA42")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA422")
# Marker(eid="PACA42")
# Cavity(l=0.03499, eid="AKA42")
# Quadrupole(l=0.12100, k1=-4.601097e+00, eid="QDA42")
# Quadrupole(l=0.22200, k1=5.050408e+00, eid="QFA42")
# Quadrupole(l=0.12100, k1=-4.601097e+00, eid="QDA42")
# Cavity(l=0.03499, eid="AKA43")
# Marker(eid="PACA43")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA43")
# Bend(eid="SXA43")
# Bend(tilt=1.570796e+00, eid="SYA43")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA432")
# Marker(eid="PACA43")
# Cavity(l=0.03499, eid="AKA43")
# Cavity(l=0.03499, eid="AKA44")
# Marker(eid="PACA44")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA44")
# Bend(eid="SXA44")
# Bend(tilt=1.570796e+00, eid="SYA44")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA442")
# Marker(eid="PACA44")
# Cavity(l=0.03499, eid="AKA44")
# Quadrupole(l=0.12100, k1=-6.419987e+00, eid="QDA44")
# Quadrupole(l=0.22200, k1=6.868209e+00, eid="QFA44")
# Quadrupole(l=0.12100, k1=-6.419987e+00, eid="QDA44")
# Bend(l=0.14155, eid="PXA44")
# Bend(l=0.14155, tilt=1.570796e+00, eid="PYA44")
# Marker(eid="PSECTB")
# Marker(eid="ID_68011954_")

# %%
def gauss_from_twiss_vec(emit, beta, alpha, size=1):
    phi = 2 * np.pi * np.random.rand(size)
    u = np.random.rand(size)
    a = np.sqrt(-2 * np.log(1 - u) * emit)
    x = a * np.sqrt(beta) * np.cos(phi)
    xp = -a / np.sqrt(beta) * (np.sin(phi) + alpha * np.cos(phi))
    return x, xp

nparticles = 100000
p_array = ParticleArray(n=nparticles)

# sigma_tau = 6.7e-3  # (bunch length in)
# sigma_p = 5.e-4     # relative momentum spread (Δp/p)  

sigma_tau = 4e-3  # (bunch length in )
sigma_p = 0.001     # relative momentum spread (Δp/p)  


p_array.E = energy  # GeV

# Longitudinal
p_array.rparticles[4] = np.random.randn(nparticles) * sigma_tau
p_array.rparticles[5] = np.random.randn(nparticles) * sigma_p

# Transverse: vectorized sampling from Twiss parameters
x, xp = gauss_from_twiss_vec(tw0.emit_x, tw0.beta_x, tw0.alpha_x, size=nparticles)
y, yp = gauss_from_twiss_vec(tw0.emit_y, tw0.beta_y, tw0.alpha_y, size=nparticles)

p_array.rparticles[0] = x
p_array.rparticles[1] = xp
p_array.rparticles[2] = y
p_array.rparticles[3] = yp

# Charge distribution
charge = 4.0e-9  # nC
p_array.q_array = np.ones(nparticles) * (charge / nparticles)

# %%
import time
from copy import deepcopy
import numpy as np
import matplotlib.pyplot as plt
from ocelot.cpbd.physics_proc import PhysProc

# Create the Navigator
navi = Navigator(lat)
navi.unit_step = 0.1  # high-resolution steps

# CSR example (optional)
# csr = CSR(n_bin=500, m_bin=5, sigma_min=.2e-6)
# navi.add_physics_proc(csr, csrm1_start, csrm1_end)

# Define the hook as a physics process
class HookProcess(PhysProc):
    def __init__(self, sigma_tau_list):
        super().__init__()
        self.sigma_tau_list = sigma_tau_list

    def apply(self, p_array, step_size):
        sigma_tau = np.std(p_array.rparticles[4])
        self.sigma_tau_list.append(sigma_tau)
        print(f"s = {self.z0:.3f} m, σ_τ = {sigma_tau:.3e} s")

# Attach the custom hook process
sigma_tau_list = []
hook_proc = HookProcess(sigma_tau_list)
navi.add_physics_proc(hook_proc, lat.sequence[0], lat.sequence[-1])

# Track
p_array_t = deepcopy(p_array)
start = time.time()
tws_track, p_array_t = track(lat, p_array_t, navi)
print("\n time exec:", time.time() - start, "sec")

# Plot
print("sigma_tau_list length:", len(sigma_tau_list))
print("lat.totalLen:", lat.totalLen)

s_axis = np.linspace(0, lat.totalLen, len(sigma_tau_list))
plt.plot(s_axis, sigma_tau_list)
plt.xlabel("s [m]")
plt.ylabel("σ_τ [s]")
plt.title("Evolution of Bunch Length σ_τ Along the Lattice")
plt.grid(True)
plt.show()
# Out:
# s = 0.100 m, σ_τ = 4.003e-03 s
# z = 0.1 / 45.013947600000016. Applied: HookProcesss = 0.200 m, σ_τ = 4.003e-03 s
# z = 0.2 / 45.013947600000016. Applied: HookProcesss = 0.300 m, σ_τ = 4.003e-03 s
# z = 0.30000000000000004 / 45.013947600000016. Applied: HookProcesss = 0.400 m, σ_τ = 4.003e-03 s
# z = 0.4 / 45.013947600000016. Applied: HookProcesss = 0.500 m, σ_τ = 4.003e-03 s
# z = 0.5 / 45.013947600000016. Applied: HookProcesss = 0.600 m, σ_τ = 4.003e-03 s
# z = 0.6 / 45.013947600000016. Applied: HookProcesss = 0.700 m, σ_τ = 4.003e-03 s
# z = 0.7 / 45.013947600000016. Applied: HookProcesss = 0.800 m, σ_τ = 4.003e-03 s
# z = 0.7999999999999999 / 45.013947600000016. Applied: HookProcesss = 0.900 m, σ_τ = 4.003e-03 s
# z = 0.8999999999999999 / 45.013947600000016. Applied: HookProcesss = 1.000 m, σ_τ = 4.003e-03 s
# z = 0.9999999999999999 / 45.013947600000016. Applied: HookProcesss = 1.100 m, σ_τ = 4.003e-03 s
# z = 1.0999999999999999 / 45.013947600000016. Applied: HookProcesss = 1.200 m, σ_τ = 4.003e-03 s
# z = 1.2 / 45.013947600000016. Applied: HookProcesss = 1.300 m, σ_τ = 4.003e-03 s
# z = 1.3 / 45.013947600000016. Applied: HookProcesss = 1.400 m, σ_τ = 4.003e-03 s
# z = 1.4000000000000001 / 45.013947600000016. Applied: HookProcesss = 1.500 m, σ_τ = 4.003e-03 s
# z = 1.5000000000000002 / 45.013947600000016. Applied: HookProcesss = 1.600 m, σ_τ = 4.003e-03 s
# z = 1.6000000000000003 / 45.013947600000016. Applied: HookProcesss = 1.700 m, σ_τ = 4.003e-03 s
# z = 1.7000000000000004 / 45.013947600000016. Applied: HookProcesss = 1.800 m, σ_τ = 4.003e-03 s
# z = 1.8000000000000005 / 45.013947600000016. Applied: HookProcesss = 1.900 m, σ_τ = 4.002e-03 s
# z = 1.9000000000000006 / 45.013947600000016. Applied: HookProcesss = 2.000 m, σ_τ = 3.997e-03 s
# z = 2.0000000000000004 / 45.013947600000016. Applied: HookProcesss = 2.100 m, σ_τ = 3.990e-03 s
# z = 2.1000000000000005 / 45.013947600000016. Applied: HookProcesss = 2.200 m, σ_τ = 3.981e-03 s
# z = 2.2000000000000006 / 45.013947600000016. Applied: HookProcesss = 2.300 m, σ_τ = 3.972e-03 s
# z = 2.3000000000000007 / 45.013947600000016. Applied: HookProcesss = 2.400 m, σ_τ = 3.962e-03 s
# z = 2.400000000000001 / 45.013947600000016. Applied: HookProcesss = 2.500 m, σ_τ = 3.952e-03 s
# z = 2.500000000000001 / 45.013947600000016. Applied: HookProcesss = 2.600 m, σ_τ = 3.943e-03 s
# z = 2.600000000000001 / 45.013947600000016. Applied: HookProcesss = 2.700 m, σ_τ = 3.933e-03 s
# z = 2.700000000000001 / 45.013947600000016. Applied: HookProcesss = 2.800 m, σ_τ = 3.924e-03 s
# z = 2.800000000000001 / 45.013947600000016. Applied: HookProcesss = 2.900 m, σ_τ = 3.916e-03 s
# z = 2.9000000000000012 / 45.013947600000016. Applied: HookProcesss = 3.000 m, σ_τ = 3.907e-03 s
# z = 3.0000000000000013 / 45.013947600000016. Applied: HookProcesss = 3.100 m, σ_τ = 3.899e-03 s
# z = 3.1000000000000014 / 45.013947600000016. Applied: HookProcesss = 3.200 m, σ_τ = 3.891e-03 s
# z = 3.2000000000000015 / 45.013947600000016. Applied: HookProcesss = 3.300 m, σ_τ = 3.884e-03 s
# z = 3.3000000000000016 / 45.013947600000016. Applied: HookProcesss = 3.400 m, σ_τ = 3.877e-03 s
# z = 3.4000000000000017 / 45.013947600000016. Applied: HookProcesss = 3.500 m, σ_τ = 3.870e-03 s
# z = 3.5000000000000018 / 45.013947600000016. Applied: HookProcesss = 3.600 m, σ_τ = 3.864e-03 s
# z = 3.600000000000002 / 45.013947600000016. Applied: HookProcesss = 3.700 m, σ_τ = 3.858e-03 s
# z = 3.700000000000002 / 45.013947600000016. Applied: HookProcesss = 3.800 m, σ_τ = 3.853e-03 s
# z = 3.800000000000002 / 45.013947600000016. Applied: HookProcesss = 3.900 m, σ_τ = 3.847e-03 s
# z = 3.900000000000002 / 45.013947600000016. Applied: HookProcesss = 4.000 m, σ_τ = 3.842e-03 s
# z = 4.000000000000002 / 45.013947600000016. Applied: HookProcesss = 4.100 m, σ_τ = 3.837e-03 s
# z = 4.100000000000001 / 45.013947600000016. Applied: HookProcesss = 4.200 m, σ_τ = 3.832e-03 s
# z = 4.200000000000001 / 45.013947600000016. Applied: HookProcesss = 4.300 m, σ_τ = 3.827e-03 s
# z = 4.300000000000001 / 45.013947600000016. Applied: HookProcesss = 4.400 m, σ_τ = 3.822e-03 s
# z = 4.4 / 45.013947600000016. Applied: HookProcesss = 4.500 m, σ_τ = 3.816e-03 s
# z = 4.5 / 45.013947600000016. Applied: HookProcesss = 4.600 m, σ_τ = 3.811e-03 s
# z = 4.6 / 45.013947600000016. Applied: HookProcesss = 4.700 m, σ_τ = 3.811e-03 s
# z = 4.699999999999999 / 45.013947600000016. Applied: HookProcesss = 4.800 m, σ_τ = 3.878e-03 s
# z = 4.799999999999999 / 45.013947600000016. Applied: HookProcesss = 4.900 m, σ_τ = 3.873e-03 s
# z = 4.899999999999999 / 45.013947600000016. Applied: HookProcesss = 5.000 m, σ_τ = 3.867e-03 s
# z = 4.999999999999998 / 45.013947600000016. Applied: HookProcesss = 5.100 m, σ_τ = 3.862e-03 s
# z = 5.099999999999998 / 45.013947600000016. Applied: HookProcesss = 5.200 m, σ_τ = 3.299e-03 s
# z = 5.1999999999999975 / 45.013947600000016. Applied: HookProcesss = 5.300 m, σ_τ = 2.374e-03 s
# z = 5.299999999999997 / 45.013947600000016. Applied: HookProcesss = 5.400 m, σ_τ = 2.369e-03 s
# z = 5.399999999999997 / 45.013947600000016. Applied: HookProcesss = 5.500 m, σ_τ = 2.364e-03 s
# z = 5.4999999999999964 / 45.013947600000016. Applied: HookProcesss = 5.600 m, σ_τ = 1.776e-03 s
# z = 5.599999999999996 / 45.013947600000016. Applied: HookProcesss = 5.700 m, σ_τ = 1.052e-03 s
# z = 5.699999999999996 / 45.013947600000016. Applied: HookProcesss = 5.800 m, σ_τ = 1.049e-03 s
# z = 5.799999999999995 / 45.013947600000016. Applied: HookProcesss = 5.900 m, σ_τ = 1.045e-03 s
# z = 5.899999999999995 / 45.013947600000016. Applied: HookProcesss = 6.000 m, σ_τ = 1.042e-03 s
# z = 5.999999999999995 / 45.013947600000016. Applied: HookProcesss = 6.100 m, σ_τ = 1.075e-03 s
# z = 6.099999999999994 / 45.013947600000016. Applied: HookProcesss = 6.200 m, σ_τ = 1.081e-03 s
# z = 6.199999999999994 / 45.013947600000016. Applied: HookProcesss = 6.300 m, σ_τ = 1.078e-03 s
# z = 6.299999999999994 / 45.013947600000016. Applied: HookProcesss = 6.400 m, σ_τ = 1.074e-03 s
# z = 6.399999999999993 / 45.013947600000016. Applied: HookProcesss = 6.500 m, σ_τ = 1.070e-03 s
# z = 6.499999999999993 / 45.013947600000016. Applied: HookProcesss = 6.600 m, σ_τ = 1.067e-03 s
# z = 6.5999999999999925 / 45.013947600000016. Applied: HookProcesss = 6.700 m, σ_τ = 1.063e-03 s
# z = 6.699999999999992 / 45.013947600000016. Applied: HookProcesss = 6.800 m, σ_τ = 1.060e-03 s
# z = 6.799999999999992 / 45.013947600000016. Applied: HookProcesss = 6.900 m, σ_τ = 1.056e-03 s
# z = 6.8999999999999915 / 45.013947600000016. Applied: HookProcesss = 7.000 m, σ_τ = 1.053e-03 s
# z = 6.999999999999991 / 45.013947600000016. Applied: HookProcesss = 7.100 m, σ_τ = 1.049e-03 s
# z = 7.099999999999991 / 45.013947600000016. Applied: HookProcesss = 7.200 m, σ_τ = 1.046e-03 s
# z = 7.19999999999999 / 45.013947600000016. Applied: HookProcesss = 7.300 m, σ_τ = 1.042e-03 s
# z = 7.29999999999999 / 45.013947600000016. Applied: HookProcesss = 7.400 m, σ_τ = 1.039e-03 s
# z = 7.39999999999999 / 45.013947600000016. Applied: HookProcesss = 7.500 m, σ_τ = 1.036e-03 s
# z = 7.499999999999989 / 45.013947600000016. Applied: HookProcesss = 7.600 m, σ_τ = 1.032e-03 s
# z = 7.599999999999989 / 45.013947600000016. Applied: HookProcesss = 7.700 m, σ_τ = 1.029e-03 s
# z = 7.699999999999989 / 45.013947600000016. Applied: HookProcesss = 7.800 m, σ_τ = 1.025e-03 s
# z = 7.799999999999988 / 45.013947600000016. Applied: HookProcesss = 7.900 m, σ_τ = 1.022e-03 s
# z = 7.899999999999988 / 45.013947600000016. Applied: HookProcesss = 8.000 m, σ_τ = 1.019e-03 s
# z = 7.999999999999988 / 45.013947600000016. Applied: HookProcesss = 8.100 m, σ_τ = 1.015e-03 s
# z = 8.099999999999987 / 45.013947600000016. Applied: HookProcesss = 8.200 m, σ_τ = 1.012e-03 s
# z = 8.199999999999987 / 45.013947600000016. Applied: HookProcesss = 8.300 m, σ_τ = 1.009e-03 s
# z = 8.299999999999986 / 45.013947600000016. Applied: HookProcesss = 8.400 m, σ_τ = 1.006e-03 s
# z = 8.399999999999986 / 45.013947600000016. Applied: HookProcesss = 8.500 m, σ_τ = 1.002e-03 s
# z = 8.499999999999986 / 45.013947600000016. Applied: HookProcesss = 8.600 m, σ_τ = 9.992e-04 s
# z = 8.599999999999985 / 45.013947600000016. Applied: HookProcesss = 8.700 m, σ_τ = 9.959e-04 s
# z = 8.699999999999985 / 45.013947600000016. Applied: HookProcesss = 8.800 m, σ_τ = 9.927e-04 s
# z = 8.799999999999985 / 45.013947600000016. Applied: HookProcesss = 8.900 m, σ_τ = 9.896e-04 s
# z = 8.899999999999984 / 45.013947600000016. Applied: HookProcesss = 9.000 m, σ_τ = 9.864e-04 s
# z = 8.999999999999984 / 45.013947600000016. Applied: HookProcesss = 9.100 m, σ_τ = 9.832e-04 s
# z = 9.099999999999984 / 45.013947600000016. Applied: HookProcesss = 9.200 m, σ_τ = 9.801e-04 s
# z = 9.199999999999983 / 45.013947600000016. Applied: HookProcesss = 9.300 m, σ_τ = 9.770e-04 s
# z = 9.299999999999983 / 45.013947600000016. Applied: HookProcesss = 9.400 m, σ_τ = 9.739e-04 s
# z = 9.399999999999983 / 45.013947600000016. Applied: HookProcesss = 9.500 m, σ_τ = 9.709e-04 s
# z = 9.499999999999982 / 45.013947600000016. Applied: HookProcesss = 9.600 m, σ_τ = 9.678e-04 s
# z = 9.599999999999982 / 45.013947600000016. Applied: HookProcesss = 9.700 m, σ_τ = 9.649e-04 s
# z = 9.699999999999982 / 45.013947600000016. Applied: HookProcesss = 9.800 m, σ_τ = 9.626e-04 s
# z = 9.799999999999981 / 45.013947600000016. Applied: HookProcesss = 9.900 m, σ_τ = 9.607e-04 s
# z = 9.89999999999998 / 45.013947600000016. Applied: HookProcesss = 10.000 m, σ_τ = 9.591e-04 s
# z = 9.99999999999998 / 45.013947600000016. Applied: HookProcesss = 10.100 m, σ_τ = 9.578e-04 s
# z = 10.09999999999998 / 45.013947600000016. Applied: HookProcesss = 10.200 m, σ_τ = 9.566e-04 s
# z = 10.19999999999998 / 45.013947600000016. Applied: HookProcesss = 10.300 m, σ_τ = 9.557e-04 s
# z = 10.29999999999998 / 45.013947600000016. Applied: HookProcesss = 10.400 m, σ_τ = 9.549e-04 s
# z = 10.399999999999979 / 45.013947600000016. Applied: HookProcesss = 10.500 m, σ_τ = 9.541e-04 s
# z = 10.499999999999979 / 45.013947600000016. Applied: HookProcesss = 10.600 m, σ_τ = 9.535e-04 s
# z = 10.599999999999978 / 45.013947600000016. Applied: HookProcesss = 10.700 m, σ_τ = 9.530e-04 s
# z = 10.699999999999978 / 45.013947600000016. Applied: HookProcesss = 10.800 m, σ_τ = 9.525e-04 s
# z = 10.799999999999978 / 45.013947600000016. Applied: HookProcesss = 10.900 m, σ_τ = 9.521e-04 s
# z = 10.899999999999977 / 45.013947600000016. Applied: HookProcesss = 11.000 m, σ_τ = 9.517e-04 s
# z = 10.999999999999977 / 45.013947600000016. Applied: HookProcesss = 11.100 m, σ_τ = 9.514e-04 s
# z = 11.099999999999977 / 45.013947600000016. Applied: HookProcesss = 11.200 m, σ_τ = 9.511e-04 s
# z = 11.199999999999976 / 45.013947600000016. Applied: HookProcesss = 11.300 m, σ_τ = 9.508e-04 s
# z = 11.299999999999976 / 45.013947600000016. Applied: HookProcesss = 11.400 m, σ_τ = 9.505e-04 s
# z = 11.399999999999975 / 45.013947600000016. Applied: HookProcesss = 11.500 m, σ_τ = 9.503e-04 s
# z = 11.499999999999975 / 45.013947600000016. Applied: HookProcesss = 11.600 m, σ_τ = 9.501e-04 s
# z = 11.599999999999975 / 45.013947600000016. Applied: HookProcesss = 11.700 m, σ_τ = 9.499e-04 s
# z = 11.699999999999974 / 45.013947600000016. Applied: HookProcesss = 11.800 m, σ_τ = 9.497e-04 s
# z = 11.799999999999974 / 45.013947600000016. Applied: HookProcesss = 11.900 m, σ_τ = 9.495e-04 s
# z = 11.899999999999974 / 45.013947600000016. Applied: HookProcesss = 12.000 m, σ_τ = 9.493e-04 s
# z = 11.999999999999973 / 45.013947600000016. Applied: HookProcesss = 12.100 m, σ_τ = 9.491e-04 s
# z = 12.099999999999973 / 45.013947600000016. Applied: HookProcesss = 12.200 m, σ_τ = 9.489e-04 s
# z = 12.199999999999973 / 45.013947600000016. Applied: HookProcesss = 12.300 m, σ_τ = 9.487e-04 s
# z = 12.299999999999972 / 45.013947600000016. Applied: HookProcesss = 12.400 m, σ_τ = 9.485e-04 s
# z = 12.399999999999972 / 45.013947600000016. Applied: HookProcesss = 12.500 m, σ_τ = 9.483e-04 s
# z = 12.499999999999972 / 45.013947600000016. Applied: HookProcesss = 12.600 m, σ_τ = 9.481e-04 s
# z = 12.599999999999971 / 45.013947600000016. Applied: HookProcesss = 12.700 m, σ_τ = 9.480e-04 s
# z = 12.69999999999997 / 45.013947600000016. Applied: HookProcesss = 12.800 m, σ_τ = 9.478e-04 s
# z = 12.79999999999997 / 45.013947600000016. Applied: HookProcesss = 12.900 m, σ_τ = 9.477e-04 s
# z = 12.89999999999997 / 45.013947600000016. Applied: HookProcesss = 13.000 m, σ_τ = 9.475e-04 s
# z = 12.99999999999997 / 45.013947600000016. Applied: HookProcesss = 13.100 m, σ_τ = 9.474e-04 s
# z = 13.09999999999997 / 45.013947600000016. Applied: HookProcesss = 13.200 m, σ_τ = 9.473e-04 s
# z = 13.199999999999969 / 45.013947600000016. Applied: HookProcesss = 13.300 m, σ_τ = 9.472e-04 s
# z = 13.299999999999969 / 45.013947600000016. Applied: HookProcesss = 13.400 m, σ_τ = 9.471e-04 s
# z = 13.399999999999968 / 45.013947600000016. Applied: HookProcesss = 13.500 m, σ_τ = 9.470e-04 s
# z = 13.499999999999968 / 45.013947600000016. Applied: HookProcesss = 13.600 m, σ_τ = 9.470e-04 s
# z = 13.599999999999968 / 45.013947600000016. Applied: HookProcesss = 13.700 m, σ_τ = 9.469e-04 s
# z = 13.699999999999967 / 45.013947600000016. Applied: HookProcesss = 13.800 m, σ_τ = 9.468e-04 s
# z = 13.799999999999967 / 45.013947600000016. Applied: HookProcesss = 13.900 m, σ_τ = 9.468e-04 s
# z = 13.899999999999967 / 45.013947600000016. Applied: HookProcesss = 14.000 m, σ_τ = 9.467e-04 s
# z = 13.999999999999966 / 45.013947600000016. Applied: HookProcesss = 14.100 m, σ_τ = 9.466e-04 s
# z = 14.099999999999966 / 45.013947600000016. Applied: HookProcesss = 14.200 m, σ_τ = 9.466e-04 s
# z = 14.199999999999966 / 45.013947600000016. Applied: HookProcesss = 14.300 m, σ_τ = 9.465e-04 s
# z = 14.299999999999965 / 45.013947600000016. Applied: HookProcesss = 14.400 m, σ_τ = 9.465e-04 s
# z = 14.399999999999965 / 45.013947600000016. Applied: HookProcesss = 14.500 m, σ_τ = 9.465e-04 s
# z = 14.499999999999964 / 45.013947600000016. Applied: HookProcesss = 14.600 m, σ_τ = 9.464e-04 s
# z = 14.599999999999964 / 45.013947600000016. Applied: HookProcesss = 14.700 m, σ_τ = 9.464e-04 s
# z = 14.699999999999964 / 45.013947600000016. Applied: HookProcesss = 14.800 m, σ_τ = 9.463e-04 s
# z = 14.799999999999963 / 45.013947600000016. Applied: HookProcesss = 14.900 m, σ_τ = 9.463e-04 s
# z = 14.899999999999963 / 45.013947600000016. Applied: HookProcesss = 15.000 m, σ_τ = 9.462e-04 s
# z = 14.999999999999963 / 45.013947600000016. Applied: HookProcesss = 15.100 m, σ_τ = 9.462e-04 s
# z = 15.099999999999962 / 45.013947600000016. Applied: HookProcesss = 15.200 m, σ_τ = 9.461e-04 s
# z = 15.199999999999962 / 45.013947600000016. Applied: HookProcesss = 15.300 m, σ_τ = 9.461e-04 s
# z = 15.299999999999962 / 45.013947600000016. Applied: HookProcesss = 15.400 m, σ_τ = 9.461e-04 s
# z = 15.399999999999961 / 45.013947600000016. Applied: HookProcesss = 15.500 m, σ_τ = 9.460e-04 s
# z = 15.499999999999961 / 45.013947600000016. Applied: HookProcesss = 15.600 m, σ_τ = 9.460e-04 s
# z = 15.59999999999996 / 45.013947600000016. Applied: HookProcesss = 15.700 m, σ_τ = 9.459e-04 s
# z = 15.69999999999996 / 45.013947600000016. Applied: HookProcesss = 15.800 m, σ_τ = 9.459e-04 s
# z = 15.79999999999996 / 45.013947600000016. Applied: HookProcesss = 15.900 m, σ_τ = 9.459e-04 s
# z = 15.89999999999996 / 45.013947600000016. Applied: HookProcesss = 16.000 m, σ_τ = 9.458e-04 s
# z = 15.99999999999996 / 45.013947600000016. Applied: HookProcesss = 16.100 m, σ_τ = 9.458e-04 s
# z = 16.09999999999996 / 45.013947600000016. Applied: HookProcesss = 16.200 m, σ_τ = 9.458e-04 s
# z = 16.19999999999996 / 45.013947600000016. Applied: HookProcesss = 16.300 m, σ_τ = 9.458e-04 s
# z = 16.29999999999996 / 45.013947600000016. Applied: HookProcesss = 16.400 m, σ_τ = 9.457e-04 s
# z = 16.399999999999963 / 45.013947600000016. Applied: HookProcesss = 16.500 m, σ_τ = 9.457e-04 s
# z = 16.499999999999964 / 45.013947600000016. Applied: HookProcesss = 16.600 m, σ_τ = 9.457e-04 s
# z = 16.599999999999966 / 45.013947600000016. Applied: HookProcesss = 16.700 m, σ_τ = 9.457e-04 s
# z = 16.699999999999967 / 45.013947600000016. Applied: HookProcesss = 16.800 m, σ_τ = 9.456e-04 s
# z = 16.79999999999997 / 45.013947600000016. Applied: HookProcesss = 16.900 m, σ_τ = 9.456e-04 s
# z = 16.89999999999997 / 45.013947600000016. Applied: HookProcesss = 17.000 m, σ_τ = 9.456e-04 s
# z = 16.99999999999997 / 45.013947600000016. Applied: HookProcesss = 17.100 m, σ_τ = 9.456e-04 s
# z = 17.099999999999973 / 45.013947600000016. Applied: HookProcesss = 17.200 m, σ_τ = 9.456e-04 s
# z = 17.199999999999974 / 45.013947600000016. Applied: HookProcesss = 17.300 m, σ_τ = 9.456e-04 s
# z = 17.299999999999976 / 45.013947600000016. Applied: HookProcesss = 17.400 m, σ_τ = 9.456e-04 s
# z = 17.399999999999977 / 45.013947600000016. Applied: HookProcesss = 17.500 m, σ_τ = 9.455e-04 s
# z = 17.49999999999998 / 45.013947600000016. Applied: HookProcesss = 17.600 m, σ_τ = 9.455e-04 s
# z = 17.59999999999998 / 45.013947600000016. Applied: HookProcesss = 17.700 m, σ_τ = 9.455e-04 s
# z = 17.69999999999998 / 45.013947600000016. Applied: HookProcesss = 17.800 m, σ_τ = 9.455e-04 s
# z = 17.799999999999983 / 45.013947600000016. Applied: HookProcesss = 17.900 m, σ_τ = 9.455e-04 s
# z = 17.899999999999984 / 45.013947600000016. Applied: HookProcesss = 18.000 m, σ_τ = 9.455e-04 s
# z = 17.999999999999986 / 45.013947600000016. Applied: HookProcesss = 18.100 m, σ_τ = 9.454e-04 s
# z = 18.099999999999987 / 45.013947600000016. Applied: HookProcesss = 18.200 m, σ_τ = 9.454e-04 s
# z = 18.19999999999999 / 45.013947600000016. Applied: HookProcesss = 18.300 m, σ_τ = 9.454e-04 s
# z = 18.29999999999999 / 45.013947600000016. Applied: HookProcesss = 18.400 m, σ_τ = 9.454e-04 s
# z = 18.39999999999999 / 45.013947600000016. Applied: HookProcesss = 18.500 m, σ_τ = 9.454e-04 s
# z = 18.499999999999993 / 45.013947600000016. Applied: HookProcesss = 18.600 m, σ_τ = 9.454e-04 s
# z = 18.599999999999994 / 45.013947600000016. Applied: HookProcesss = 18.700 m, σ_τ = 9.454e-04 s
# z = 18.699999999999996 / 45.013947600000016. Applied: HookProcesss = 18.800 m, σ_τ = 9.454e-04 s
# z = 18.799999999999997 / 45.013947600000016. Applied: HookProcesss = 18.900 m, σ_τ = 9.454e-04 s
# z = 18.9 / 45.013947600000016. Applied: HookProcesss = 19.000 m, σ_τ = 9.453e-04 s
# z = 19.0 / 45.013947600000016. Applied: HookProcesss = 19.100 m, σ_τ = 9.453e-04 s
# z = 19.1 / 45.013947600000016. Applied: HookProcesss = 19.200 m, σ_τ = 9.453e-04 s
# z = 19.200000000000003 / 45.013947600000016. Applied: HookProcesss = 19.300 m, σ_τ = 9.453e-04 s
# z = 19.300000000000004 / 45.013947600000016. Applied: HookProcesss = 19.400 m, σ_τ = 9.453e-04 s
# z = 19.400000000000006 / 45.013947600000016. Applied: HookProcesss = 19.500 m, σ_τ = 9.453e-04 s
# z = 19.500000000000007 / 45.013947600000016. Applied: HookProcesss = 19.600 m, σ_τ = 9.453e-04 s
# z = 19.60000000000001 / 45.013947600000016. Applied: HookProcesss = 19.700 m, σ_τ = 9.453e-04 s
# z = 19.70000000000001 / 45.013947600000016. Applied: HookProcesss = 19.800 m, σ_τ = 9.453e-04 s
# z = 19.80000000000001 / 45.013947600000016. Applied: HookProcesss = 19.900 m, σ_τ = 9.453e-04 s
# z = 19.900000000000013 / 45.013947600000016. Applied: HookProcesss = 20.000 m, σ_τ = 9.453e-04 s
# z = 20.000000000000014 / 45.013947600000016. Applied: HookProcesss = 20.100 m, σ_τ = 9.453e-04 s
# z = 20.100000000000016 / 45.013947600000016. Applied: HookProcesss = 20.200 m, σ_τ = 9.453e-04 s
# z = 20.200000000000017 / 45.013947600000016. Applied: HookProcesss = 20.300 m, σ_τ = 9.452e-04 s
# z = 20.30000000000002 / 45.013947600000016. Applied: HookProcesss = 20.400 m, σ_τ = 9.452e-04 s
# z = 20.40000000000002 / 45.013947600000016. Applied: HookProcesss = 20.500 m, σ_τ = 9.452e-04 s
# z = 20.50000000000002 / 45.013947600000016. Applied: HookProcesss = 20.600 m, σ_τ = 9.452e-04 s
# z = 20.600000000000023 / 45.013947600000016. Applied: HookProcesss = 20.700 m, σ_τ = 9.452e-04 s
# z = 20.700000000000024 / 45.013947600000016. Applied: HookProcesss = 20.800 m, σ_τ = 9.452e-04 s
# z = 20.800000000000026 / 45.013947600000016. Applied: HookProcesss = 20.900 m, σ_τ = 9.452e-04 s
# z = 20.900000000000027 / 45.013947600000016. Applied: HookProcesss = 21.000 m, σ_τ = 9.452e-04 s
# z = 21.00000000000003 / 45.013947600000016. Applied: HookProcesss = 21.100 m, σ_τ = 9.452e-04 s
# z = 21.10000000000003 / 45.013947600000016. Applied: HookProcesss = 21.200 m, σ_τ = 9.452e-04 s
# z = 21.20000000000003 / 45.013947600000016. Applied: HookProcesss = 21.300 m, σ_τ = 9.452e-04 s
# z = 21.300000000000033 / 45.013947600000016. Applied: HookProcesss = 21.400 m, σ_τ = 9.452e-04 s
# z = 21.400000000000034 / 45.013947600000016. Applied: HookProcesss = 21.500 m, σ_τ = 9.452e-04 s
# z = 21.500000000000036 / 45.013947600000016. Applied: HookProcesss = 21.600 m, σ_τ = 9.452e-04 s
# z = 21.600000000000037 / 45.013947600000016. Applied: HookProcesss = 21.700 m, σ_τ = 9.452e-04 s
# z = 21.70000000000004 / 45.013947600000016. Applied: HookProcesss = 21.800 m, σ_τ = 9.452e-04 s
# z = 21.80000000000004 / 45.013947600000016. Applied: HookProcesss = 21.900 m, σ_τ = 9.452e-04 s
# z = 21.90000000000004 / 45.013947600000016. Applied: HookProcesss = 22.000 m, σ_τ = 9.452e-04 s
# z = 22.000000000000043 / 45.013947600000016. Applied: HookProcesss = 22.100 m, σ_τ = 9.451e-04 s
# z = 22.100000000000044 / 45.013947600000016. Applied: HookProcesss = 22.200 m, σ_τ = 9.451e-04 s
# z = 22.200000000000045 / 45.013947600000016. Applied: HookProcesss = 22.300 m, σ_τ = 9.451e-04 s
# z = 22.300000000000047 / 45.013947600000016. Applied: HookProcesss = 22.400 m, σ_τ = 9.451e-04 s
# z = 22.40000000000005 / 45.013947600000016. Applied: HookProcesss = 22.500 m, σ_τ = 9.451e-04 s
# z = 22.50000000000005 / 45.013947600000016. Applied: HookProcesss = 22.600 m, σ_τ = 9.451e-04 s
# z = 22.60000000000005 / 45.013947600000016. Applied: HookProcesss = 22.700 m, σ_τ = 9.451e-04 s
# z = 22.700000000000053 / 45.013947600000016. Applied: HookProcesss = 22.800 m, σ_τ = 9.451e-04 s
# z = 22.800000000000054 / 45.013947600000016. Applied: HookProcesss = 22.900 m, σ_τ = 9.451e-04 s
# z = 22.900000000000055 / 45.013947600000016. Applied: HookProcesss = 23.000 m, σ_τ = 9.451e-04 s
# z = 23.000000000000057 / 45.013947600000016. Applied: HookProcesss = 23.100 m, σ_τ = 9.451e-04 s
# z = 23.10000000000006 / 45.013947600000016. Applied: HookProcesss = 23.200 m, σ_τ = 9.451e-04 s
# z = 23.20000000000006 / 45.013947600000016. Applied: HookProcesss = 23.300 m, σ_τ = 9.451e-04 s
# z = 23.30000000000006 / 45.013947600000016. Applied: HookProcesss = 23.400 m, σ_τ = 9.451e-04 s
# z = 23.400000000000063 / 45.013947600000016. Applied: HookProcesss = 23.500 m, σ_τ = 9.451e-04 s
# z = 23.500000000000064 / 45.013947600000016. Applied: HookProcesss = 23.600 m, σ_τ = 9.451e-04 s
# z = 23.600000000000065 / 45.013947600000016. Applied: HookProcesss = 23.700 m, σ_τ = 9.451e-04 s
# z = 23.700000000000067 / 45.013947600000016. Applied: HookProcesss = 23.800 m, σ_τ = 9.451e-04 s
# z = 23.800000000000068 / 45.013947600000016. Applied: HookProcesss = 23.900 m, σ_τ = 9.451e-04 s
# z = 23.90000000000007 / 45.013947600000016. Applied: HookProcesss = 24.000 m, σ_τ = 9.451e-04 s
# z = 24.00000000000007 / 45.013947600000016. Applied: HookProcesss = 24.100 m, σ_τ = 9.451e-04 s
# z = 24.100000000000072 / 45.013947600000016. Applied: HookProcesss = 24.200 m, σ_τ = 9.451e-04 s
# z = 24.200000000000074 / 45.013947600000016. Applied: HookProcesss = 24.300 m, σ_τ = 9.451e-04 s
# z = 24.300000000000075 / 45.013947600000016. Applied: HookProcesss = 24.400 m, σ_τ = 9.451e-04 s
# z = 24.400000000000077 / 45.013947600000016. Applied: HookProcesss = 24.500 m, σ_τ = 9.451e-04 s
# z = 24.500000000000078 / 45.013947600000016. Applied: HookProcesss = 24.600 m, σ_τ = 9.451e-04 s
# z = 24.60000000000008 / 45.013947600000016. Applied: HookProcesss = 24.700 m, σ_τ = 9.451e-04 s
# z = 24.70000000000008 / 45.013947600000016. Applied: HookProcesss = 24.800 m, σ_τ = 9.451e-04 s
# z = 24.800000000000082 / 45.013947600000016. Applied: HookProcesss = 24.900 m, σ_τ = 9.451e-04 s
# z = 24.900000000000084 / 45.013947600000016. Applied: HookProcesss = 25.000 m, σ_τ = 9.451e-04 s
# z = 25.000000000000085 / 45.013947600000016. Applied: HookProcesss = 25.100 m, σ_τ = 9.451e-04 s
# z = 25.100000000000087 / 45.013947600000016. Applied: HookProcesss = 25.200 m, σ_τ = 9.451e-04 s
# z = 25.200000000000088 / 45.013947600000016. Applied: HookProcesss = 25.300 m, σ_τ = 9.451e-04 s
# z = 25.30000000000009 / 45.013947600000016. Applied: HookProcesss = 25.400 m, σ_τ = 9.451e-04 s
# z = 25.40000000000009 / 45.013947600000016. Applied: HookProcesss = 25.500 m, σ_τ = 9.451e-04 s
# z = 25.500000000000092 / 45.013947600000016. Applied: HookProcesss = 25.600 m, σ_τ = 9.451e-04 s
# z = 25.600000000000094 / 45.013947600000016. Applied: HookProcesss = 25.700 m, σ_τ = 9.451e-04 s
# z = 25.700000000000095 / 45.013947600000016. Applied: HookProcesss = 25.800 m, σ_τ = 9.451e-04 s
# z = 25.800000000000097 / 45.013947600000016. Applied: HookProcesss = 25.900 m, σ_τ = 9.451e-04 s
# z = 25.900000000000098 / 45.013947600000016. Applied: HookProcesss = 26.000 m, σ_τ = 9.451e-04 s
# z = 26.0000000000001 / 45.013947600000016. Applied: HookProcesss = 26.100 m, σ_τ = 9.451e-04 s
# z = 26.1000000000001 / 45.013947600000016. Applied: HookProcesss = 26.200 m, σ_τ = 9.451e-04 s
# z = 26.200000000000102 / 45.013947600000016. Applied: HookProcesss = 26.300 m, σ_τ = 9.451e-04 s
# z = 26.300000000000104 / 45.013947600000016. Applied: HookProcesss = 26.400 m, σ_τ = 9.451e-04 s
# z = 26.400000000000105 / 45.013947600000016. Applied: HookProcesss = 26.500 m, σ_τ = 9.451e-04 s
# z = 26.500000000000107 / 45.013947600000016. Applied: HookProcesss = 26.600 m, σ_τ = 9.451e-04 s
# z = 26.600000000000108 / 45.013947600000016. Applied: HookProcesss = 26.700 m, σ_τ = 9.451e-04 s
# z = 26.70000000000011 / 45.013947600000016. Applied: HookProcesss = 26.800 m, σ_τ = 9.451e-04 s
# z = 26.80000000000011 / 45.013947600000016. Applied: HookProcesss = 26.900 m, σ_τ = 9.451e-04 s
# z = 26.900000000000112 / 45.013947600000016. Applied: HookProcesss = 27.000 m, σ_τ = 9.451e-04 s
# z = 27.000000000000114 / 45.013947600000016. Applied: HookProcesss = 27.100 m, σ_τ = 9.451e-04 s
# z = 27.100000000000115 / 45.013947600000016. Applied: HookProcesss = 27.200 m, σ_τ = 9.451e-04 s
# z = 27.200000000000117 / 45.013947600000016. Applied: HookProcesss = 27.300 m, σ_τ = 9.451e-04 s
# z = 27.300000000000118 / 45.013947600000016. Applied: HookProcesss = 27.400 m, σ_τ = 9.451e-04 s
# z = 27.40000000000012 / 45.013947600000016. Applied: HookProcesss = 27.500 m, σ_τ = 9.451e-04 s
# z = 27.50000000000012 / 45.013947600000016. Applied: HookProcesss = 27.600 m, σ_τ = 9.451e-04 s
# z = 27.600000000000122 / 45.013947600000016. Applied: HookProcesss = 27.700 m, σ_τ = 9.451e-04 s
# z = 27.700000000000124 / 45.013947600000016. Applied: HookProcesss = 27.800 m, σ_τ = 9.451e-04 s
# z = 27.800000000000125 / 45.013947600000016. Applied: HookProcesss = 27.900 m, σ_τ = 9.451e-04 s
# z = 27.900000000000126 / 45.013947600000016. Applied: HookProcesss = 28.000 m, σ_τ = 9.451e-04 s
# z = 28.000000000000128 / 45.013947600000016. Applied: HookProcesss = 28.100 m, σ_τ = 9.451e-04 s
# z = 28.10000000000013 / 45.013947600000016. Applied: HookProcesss = 28.200 m, σ_τ = 9.451e-04 s
# z = 28.20000000000013 / 45.013947600000016. Applied: HookProcesss = 28.300 m, σ_τ = 9.451e-04 s
# z = 28.300000000000132 / 45.013947600000016. Applied: HookProcesss = 28.400 m, σ_τ = 9.451e-04 s
# z = 28.400000000000134 / 45.013947600000016. Applied: HookProcesss = 28.500 m, σ_τ = 9.451e-04 s
# z = 28.500000000000135 / 45.013947600000016. Applied: HookProcesss = 28.600 m, σ_τ = 9.451e-04 s
# z = 28.600000000000136 / 45.013947600000016. Applied: HookProcesss = 28.700 m, σ_τ = 9.451e-04 s
# z = 28.700000000000138 / 45.013947600000016. Applied: HookProcesss = 28.800 m, σ_τ = 9.451e-04 s
# z = 28.80000000000014 / 45.013947600000016. Applied: HookProcesss = 28.900 m, σ_τ = 9.451e-04 s
# z = 28.90000000000014 / 45.013947600000016. Applied: HookProcesss = 29.000 m, σ_τ = 9.451e-04 s
# z = 29.000000000000142 / 45.013947600000016. Applied: HookProcesss = 29.100 m, σ_τ = 9.451e-04 s
# z = 29.100000000000144 / 45.013947600000016. Applied: HookProcesss = 29.200 m, σ_τ = 9.451e-04 s
# z = 29.200000000000145 / 45.013947600000016. Applied: HookProcesss = 29.300 m, σ_τ = 9.451e-04 s
# z = 29.300000000000146 / 45.013947600000016. Applied: HookProcesss = 29.400 m, σ_τ = 9.451e-04 s
# z = 29.400000000000148 / 45.013947600000016. Applied: HookProcesss = 29.500 m, σ_τ = 9.451e-04 s
# z = 29.50000000000015 / 45.013947600000016. Applied: HookProcesss = 29.600 m, σ_τ = 9.451e-04 s
# z = 29.60000000000015 / 45.013947600000016. Applied: HookProcesss = 29.700 m, σ_τ = 9.451e-04 s
# z = 29.700000000000152 / 45.013947600000016. Applied: HookProcesss = 29.800 m, σ_τ = 9.451e-04 s
# z = 29.800000000000153 / 45.013947600000016. Applied: HookProcesss = 29.900 m, σ_τ = 9.451e-04 s
# z = 29.900000000000155 / 45.013947600000016. Applied: HookProcesss = 30.000 m, σ_τ = 9.451e-04 s
# z = 30.000000000000156 / 45.013947600000016. Applied: HookProcesss = 30.100 m, σ_τ = 9.451e-04 s
# z = 30.100000000000158 / 45.013947600000016. Applied: HookProcesss = 30.200 m, σ_τ = 9.451e-04 s
# z = 30.20000000000016 / 45.013947600000016. Applied: HookProcesss = 30.300 m, σ_τ = 9.451e-04 s
# z = 30.30000000000016 / 45.013947600000016. Applied: HookProcesss = 30.400 m, σ_τ = 9.451e-04 s
# z = 30.400000000000162 / 45.013947600000016. Applied: HookProcesss = 30.500 m, σ_τ = 9.451e-04 s
# z = 30.500000000000163 / 45.013947600000016. Applied: HookProcesss = 30.600 m, σ_τ = 9.451e-04 s
# z = 30.600000000000165 / 45.013947600000016. Applied: HookProcesss = 30.700 m, σ_τ = 9.451e-04 s
# z = 30.700000000000166 / 45.013947600000016. Applied: HookProcesss = 30.800 m, σ_τ = 9.451e-04 s
# z = 30.800000000000168 / 45.013947600000016. Applied: HookProcesss = 30.900 m, σ_τ = 9.451e-04 s
# z = 30.90000000000017 / 45.013947600000016. Applied: HookProcesss = 31.000 m, σ_τ = 9.451e-04 s
# z = 31.00000000000017 / 45.013947600000016. Applied: HookProcesss = 31.100 m, σ_τ = 9.451e-04 s
# z = 31.100000000000172 / 45.013947600000016. Applied: HookProcesss = 31.200 m, σ_τ = 9.451e-04 s
# z = 31.200000000000173 / 45.013947600000016. Applied: HookProcesss = 31.300 m, σ_τ = 9.451e-04 s
# z = 31.300000000000175 / 45.013947600000016. Applied: HookProcesss = 31.400 m, σ_τ = 9.451e-04 s
# z = 31.400000000000176 / 45.013947600000016. Applied: HookProcesss = 31.500 m, σ_τ = 9.451e-04 s
# z = 31.500000000000178 / 45.013947600000016. Applied: HookProcesss = 31.600 m, σ_τ = 9.451e-04 s
# z = 31.60000000000018 / 45.013947600000016. Applied: HookProcesss = 31.700 m, σ_τ = 9.451e-04 s
# z = 31.70000000000018 / 45.013947600000016. Applied: HookProcesss = 31.800 m, σ_τ = 9.451e-04 s
# z = 31.800000000000182 / 45.013947600000016. Applied: HookProcesss = 31.900 m, σ_τ = 9.451e-04 s
# z = 31.900000000000183 / 45.013947600000016. Applied: HookProcesss = 32.000 m, σ_τ = 9.451e-04 s
# z = 32.000000000000185 / 45.013947600000016. Applied: HookProcesss = 32.100 m, σ_τ = 9.451e-04 s
# z = 32.100000000000186 / 45.013947600000016. Applied: HookProcesss = 32.200 m, σ_τ = 9.451e-04 s
# z = 32.20000000000019 / 45.013947600000016. Applied: HookProcesss = 32.300 m, σ_τ = 9.451e-04 s
# z = 32.30000000000019 / 45.013947600000016. Applied: HookProcesss = 32.400 m, σ_τ = 9.451e-04 s
# z = 32.40000000000019 / 45.013947600000016. Applied: HookProcesss = 32.500 m, σ_τ = 9.451e-04 s
# z = 32.50000000000019 / 45.013947600000016. Applied: HookProcesss = 32.600 m, σ_τ = 9.451e-04 s
# z = 32.60000000000019 / 45.013947600000016. Applied: HookProcesss = 32.700 m, σ_τ = 9.451e-04 s
# z = 32.700000000000195 / 45.013947600000016. Applied: HookProcesss = 32.800 m, σ_τ = 9.451e-04 s
# z = 32.800000000000196 / 45.013947600000016. Applied: HookProcesss = 32.900 m, σ_τ = 9.451e-04 s
# z = 32.9000000000002 / 45.013947600000016. Applied: HookProcesss = 33.000 m, σ_τ = 9.451e-04 s
# z = 33.0000000000002 / 45.013947600000016. Applied: HookProcesss = 33.100 m, σ_τ = 9.451e-04 s
# z = 33.1000000000002 / 45.013947600000016. Applied: HookProcesss = 33.200 m, σ_τ = 9.451e-04 s
# z = 33.2000000000002 / 45.013947600000016. Applied: HookProcesss = 33.300 m, σ_τ = 9.451e-04 s
# z = 33.3000000000002 / 45.013947600000016. Applied: HookProcesss = 33.400 m, σ_τ = 9.451e-04 s
# z = 33.400000000000205 / 45.013947600000016. Applied: HookProcesss = 33.500 m, σ_τ = 9.451e-04 s
# z = 33.500000000000206 / 45.013947600000016. Applied: HookProcesss = 33.600 m, σ_τ = 9.451e-04 s
# z = 33.60000000000021 / 45.013947600000016. Applied: HookProcesss = 33.700 m, σ_τ = 9.451e-04 s
# z = 33.70000000000021 / 45.013947600000016. Applied: HookProcesss = 33.800 m, σ_τ = 9.451e-04 s
# z = 33.80000000000021 / 45.013947600000016. Applied: HookProcesss = 33.900 m, σ_τ = 9.451e-04 s
# z = 33.90000000000021 / 45.013947600000016. Applied: HookProcesss = 34.000 m, σ_τ = 9.451e-04 s
# z = 34.00000000000021 / 45.013947600000016. Applied: HookProcesss = 34.100 m, σ_τ = 9.451e-04 s
# z = 34.100000000000215 / 45.013947600000016. Applied: HookProcesss = 34.200 m, σ_τ = 9.451e-04 s
# z = 34.200000000000216 / 45.013947600000016. Applied: HookProcesss = 34.300 m, σ_τ = 9.451e-04 s
# z = 34.30000000000022 / 45.013947600000016. Applied: HookProcesss = 34.400 m, σ_τ = 9.451e-04 s
# z = 34.40000000000022 / 45.013947600000016. Applied: HookProcesss = 34.500 m, σ_τ = 9.451e-04 s
# z = 34.50000000000022 / 45.013947600000016. Applied: HookProcesss = 34.600 m, σ_τ = 9.451e-04 s
# z = 34.60000000000022 / 45.013947600000016. Applied: HookProcesss = 34.700 m, σ_τ = 9.451e-04 s
# z = 34.70000000000022 / 45.013947600000016. Applied: HookProcesss = 34.800 m, σ_τ = 9.451e-04 s
# z = 34.800000000000225 / 45.013947600000016. Applied: HookProcesss = 34.900 m, σ_τ = 9.451e-04 s
# z = 34.900000000000226 / 45.013947600000016. Applied: HookProcesss = 35.000 m, σ_τ = 9.451e-04 s
# z = 35.00000000000023 / 45.013947600000016. Applied: HookProcesss = 35.100 m, σ_τ = 9.451e-04 s
# z = 35.10000000000023 / 45.013947600000016. Applied: HookProcesss = 35.200 m, σ_τ = 9.451e-04 s
# z = 35.20000000000023 / 45.013947600000016. Applied: HookProcesss = 35.300 m, σ_τ = 9.451e-04 s
# z = 35.30000000000023 / 45.013947600000016. Applied: HookProcesss = 35.400 m, σ_τ = 9.451e-04 s
# z = 35.40000000000023 / 45.013947600000016. Applied: HookProcesss = 35.500 m, σ_τ = 9.451e-04 s
# z = 35.500000000000234 / 45.013947600000016. Applied: HookProcesss = 35.600 m, σ_τ = 9.451e-04 s
# z = 35.600000000000236 / 45.013947600000016. Applied: HookProcesss = 35.700 m, σ_τ = 9.451e-04 s
# z = 35.70000000000024 / 45.013947600000016. Applied: HookProcesss = 35.800 m, σ_τ = 9.451e-04 s
# z = 35.80000000000024 / 45.013947600000016. Applied: HookProcesss = 35.900 m, σ_τ = 9.451e-04 s
# z = 35.90000000000024 / 45.013947600000016. Applied: HookProcesss = 36.000 m, σ_τ = 9.451e-04 s
# z = 36.00000000000024 / 45.013947600000016. Applied: HookProcesss = 36.100 m, σ_τ = 9.451e-04 s
# z = 36.10000000000024 / 45.013947600000016. Applied: HookProcesss = 36.200 m, σ_τ = 9.451e-04 s
# z = 36.200000000000244 / 45.013947600000016. Applied: HookProcesss = 36.300 m, σ_τ = 9.451e-04 s
# z = 36.300000000000246 / 45.013947600000016. Applied: HookProcesss = 36.400 m, σ_τ = 9.451e-04 s
# z = 36.40000000000025 / 45.013947600000016. Applied: HookProcesss = 36.500 m, σ_τ = 9.451e-04 s
# z = 36.50000000000025 / 45.013947600000016. Applied: HookProcesss = 36.600 m, σ_τ = 9.451e-04 s
# z = 36.60000000000025 / 45.013947600000016. Applied: HookProcesss = 36.700 m, σ_τ = 9.451e-04 s
# z = 36.70000000000025 / 45.013947600000016. Applied: HookProcesss = 36.800 m, σ_τ = 9.451e-04 s
# z = 36.80000000000025 / 45.013947600000016. Applied: HookProcesss = 36.900 m, σ_τ = 9.451e-04 s
# z = 36.900000000000254 / 45.013947600000016. Applied: HookProcesss = 37.000 m, σ_τ = 9.451e-04 s
# z = 37.000000000000256 / 45.013947600000016. Applied: HookProcesss = 37.100 m, σ_τ = 9.451e-04 s
# z = 37.10000000000026 / 45.013947600000016. Applied: HookProcesss = 37.200 m, σ_τ = 9.451e-04 s
# z = 37.20000000000026 / 45.013947600000016. Applied: HookProcesss = 37.300 m, σ_τ = 9.451e-04 s
# z = 37.30000000000026 / 45.013947600000016. Applied: HookProcesss = 37.400 m, σ_τ = 9.451e-04 s
# z = 37.40000000000026 / 45.013947600000016. Applied: HookProcesss = 37.500 m, σ_τ = 9.451e-04 s
# z = 37.50000000000026 / 45.013947600000016. Applied: HookProcesss = 37.600 m, σ_τ = 9.451e-04 s
# z = 37.600000000000264 / 45.013947600000016. Applied: HookProcesss = 37.700 m, σ_τ = 9.451e-04 s
# z = 37.700000000000266 / 45.013947600000016. Applied: HookProcesss = 37.800 m, σ_τ = 9.451e-04 s
# z = 37.80000000000027 / 45.013947600000016. Applied: HookProcesss = 37.900 m, σ_τ = 9.451e-04 s
# z = 37.90000000000027 / 45.013947600000016. Applied: HookProcesss = 38.000 m, σ_τ = 9.451e-04 s
# z = 38.00000000000027 / 45.013947600000016. Applied: HookProcesss = 38.100 m, σ_τ = 9.451e-04 s
# z = 38.10000000000027 / 45.013947600000016. Applied: HookProcesss = 38.200 m, σ_τ = 9.451e-04 s
# z = 38.20000000000027 / 45.013947600000016. Applied: HookProcesss = 38.300 m, σ_τ = 9.451e-04 s
# z = 38.300000000000274 / 45.013947600000016. Applied: HookProcesss = 38.400 m, σ_τ = 9.451e-04 s
# z = 38.400000000000276 / 45.013947600000016. Applied: HookProcesss = 38.500 m, σ_τ = 9.451e-04 s
# z = 38.50000000000028 / 45.013947600000016. Applied: HookProcesss = 38.600 m, σ_τ = 9.451e-04 s
# z = 38.60000000000028 / 45.013947600000016. Applied: HookProcesss = 38.700 m, σ_τ = 9.451e-04 s
# z = 38.70000000000028 / 45.013947600000016. Applied: HookProcesss = 38.800 m, σ_τ = 9.451e-04 s
# z = 38.80000000000028 / 45.013947600000016. Applied: HookProcesss = 38.900 m, σ_τ = 9.451e-04 s
# z = 38.90000000000028 / 45.013947600000016. Applied: HookProcesss = 39.000 m, σ_τ = 9.451e-04 s
# z = 39.000000000000284 / 45.013947600000016. Applied: HookProcesss = 39.100 m, σ_τ = 9.451e-04 s
# z = 39.100000000000286 / 45.013947600000016. Applied: HookProcesss = 39.200 m, σ_τ = 9.451e-04 s
# z = 39.20000000000029 / 45.013947600000016. Applied: HookProcesss = 39.300 m, σ_τ = 9.451e-04 s
# z = 39.30000000000029 / 45.013947600000016. Applied: HookProcesss = 39.400 m, σ_τ = 9.451e-04 s
# z = 39.40000000000029 / 45.013947600000016. Applied: HookProcesss = 39.500 m, σ_τ = 9.451e-04 s
# z = 39.50000000000029 / 45.013947600000016. Applied: HookProcesss = 39.600 m, σ_τ = 9.451e-04 s
# z = 39.60000000000029 / 45.013947600000016. Applied: HookProcesss = 39.700 m, σ_τ = 9.451e-04 s
# z = 39.700000000000294 / 45.013947600000016. Applied: HookProcesss = 39.800 m, σ_τ = 9.451e-04 s
# z = 39.800000000000296 / 45.013947600000016. Applied: HookProcesss = 39.900 m, σ_τ = 9.451e-04 s
# z = 39.9000000000003 / 45.013947600000016. Applied: HookProcesss = 40.000 m, σ_τ = 9.451e-04 s
# z = 40.0000000000003 / 45.013947600000016. Applied: HookProcesss = 40.100 m, σ_τ = 9.451e-04 s
# z = 40.1000000000003 / 45.013947600000016. Applied: HookProcesss = 40.200 m, σ_τ = 9.451e-04 s
# z = 40.2000000000003 / 45.013947600000016. Applied: HookProcesss = 40.300 m, σ_τ = 9.451e-04 s
# z = 40.3000000000003 / 45.013947600000016. Applied: HookProcesss = 40.400 m, σ_τ = 9.451e-04 s
# z = 40.400000000000304 / 45.013947600000016. Applied: HookProcesss = 40.500 m, σ_τ = 9.451e-04 s
# z = 40.500000000000306 / 45.013947600000016. Applied: HookProcesss = 40.600 m, σ_τ = 9.451e-04 s
# z = 40.60000000000031 / 45.013947600000016. Applied: HookProcesss = 40.700 m, σ_τ = 9.451e-04 s
# z = 40.70000000000031 / 45.013947600000016. Applied: HookProcesss = 40.800 m, σ_τ = 9.451e-04 s
# z = 40.80000000000031 / 45.013947600000016. Applied: HookProcesss = 40.900 m, σ_τ = 9.451e-04 s
# z = 40.90000000000031 / 45.013947600000016. Applied: HookProcesss = 41.000 m, σ_τ = 9.451e-04 s
# z = 41.00000000000031 / 45.013947600000016. Applied: HookProcesss = 41.100 m, σ_τ = 9.451e-04 s
# z = 41.100000000000314 / 45.013947600000016. Applied: HookProcesss = 41.200 m, σ_τ = 9.451e-04 s
# z = 41.200000000000315 / 45.013947600000016. Applied: HookProcesss = 41.300 m, σ_τ = 9.451e-04 s
# z = 41.30000000000032 / 45.013947600000016. Applied: HookProcesss = 41.400 m, σ_τ = 9.451e-04 s
# z = 41.40000000000032 / 45.013947600000016. Applied: HookProcesss = 41.500 m, σ_τ = 9.451e-04 s
# z = 41.50000000000032 / 45.013947600000016. Applied: HookProcesss = 41.600 m, σ_τ = 9.451e-04 s
# z = 41.60000000000032 / 45.013947600000016. Applied: HookProcesss = 41.700 m, σ_τ = 9.451e-04 s
# z = 41.70000000000032 / 45.013947600000016. Applied: HookProcesss = 41.800 m, σ_τ = 9.451e-04 s
# z = 41.800000000000324 / 45.013947600000016. Applied: HookProcesss = 41.900 m, σ_τ = 9.451e-04 s
# z = 41.900000000000325 / 45.013947600000016. Applied: HookProcesss = 42.000 m, σ_τ = 9.451e-04 s
# z = 42.00000000000033 / 45.013947600000016. Applied: HookProcesss = 42.100 m, σ_τ = 9.451e-04 s
# z = 42.10000000000033 / 45.013947600000016. Applied: HookProcesss = 42.200 m, σ_τ = 9.451e-04 s
# z = 42.20000000000033 / 45.013947600000016. Applied: HookProcesss = 42.300 m, σ_τ = 9.451e-04 s
# z = 42.30000000000033 / 45.013947600000016. Applied: HookProcesss = 42.400 m, σ_τ = 9.451e-04 s
# z = 42.40000000000033 / 45.013947600000016. Applied: HookProcesss = 42.500 m, σ_τ = 9.451e-04 s
# z = 42.500000000000334 / 45.013947600000016. Applied: HookProcesss = 42.600 m, σ_τ = 9.451e-04 s
# z = 42.600000000000335 / 45.013947600000016. Applied: HookProcesss = 42.700 m, σ_τ = 9.451e-04 s
# z = 42.70000000000034 / 45.013947600000016. Applied: HookProcesss = 42.800 m, σ_τ = 9.451e-04 s
# z = 42.80000000000034 / 45.013947600000016. Applied: HookProcesss = 42.900 m, σ_τ = 9.451e-04 s
# z = 42.90000000000034 / 45.013947600000016. Applied: HookProcesss = 43.000 m, σ_τ = 9.451e-04 s
# z = 43.00000000000034 / 45.013947600000016. Applied: HookProcesss = 43.100 m, σ_τ = 9.451e-04 s
# z = 43.10000000000034 / 45.013947600000016. Applied: HookProcesss = 43.200 m, σ_τ = 9.451e-04 s
# z = 43.200000000000344 / 45.013947600000016. Applied: HookProcesss = 43.300 m, σ_τ = 9.451e-04 s
# z = 43.300000000000345 / 45.013947600000016. Applied: HookProcesss = 43.400 m, σ_τ = 9.451e-04 s
# z = 43.40000000000035 / 45.013947600000016. Applied: HookProcesss = 43.500 m, σ_τ = 9.451e-04 s
# z = 43.50000000000035 / 45.013947600000016. Applied: HookProcesss = 43.600 m, σ_τ = 9.451e-04 s
# z = 43.60000000000035 / 45.013947600000016. Applied: HookProcesss = 43.700 m, σ_τ = 9.451e-04 s
# z = 43.70000000000035 / 45.013947600000016. Applied: HookProcesss = 43.800 m, σ_τ = 9.451e-04 s
# z = 43.80000000000035 / 45.013947600000016. Applied: HookProcesss = 43.900 m, σ_τ = 9.451e-04 s
# z = 43.900000000000354 / 45.013947600000016. Applied: HookProcesss = 44.000 m, σ_τ = 9.451e-04 s
# z = 44.000000000000355 / 45.013947600000016. Applied: HookProcesss = 44.100 m, σ_τ = 9.451e-04 s
# z = 44.10000000000036 / 45.013947600000016. Applied: HookProcesss = 44.200 m, σ_τ = 9.451e-04 s
# z = 44.20000000000036 / 45.013947600000016. Applied: HookProcesss = 44.300 m, σ_τ = 9.451e-04 s
# z = 44.30000000000036 / 45.013947600000016. Applied: HookProcesss = 44.400 m, σ_τ = 9.451e-04 s
# z = 44.40000000000036 / 45.013947600000016. Applied: HookProcesss = 44.500 m, σ_τ = 9.451e-04 s
# z = 44.50000000000036 / 45.013947600000016. Applied: HookProcesss = 44.600 m, σ_τ = 9.451e-04 s
# z = 44.600000000000364 / 45.013947600000016. Applied: HookProcesss = 44.700 m, σ_τ = 9.451e-04 s
# z = 44.700000000000365 / 45.013947600000016. Applied: HookProcesss = 44.800 m, σ_τ = 9.451e-04 s
# z = 44.80000000000037 / 45.013947600000016. Applied: HookProcesss = 44.900 m, σ_τ = 9.451e-04 s
# z = 44.90000000000037 / 45.013947600000016. Applied: HookProcesss = 45.000 m, σ_τ = 9.451e-04 s
# z = 45.00000000000037 / 45.013947600000016. Applied: HookProcesss = 45.014 m, σ_τ = 9.451e-04 s
# z = 45.013947599999995 / 45.013947600000016. Applied: HookProcess
#  time exec: 8.127758741378784 sec
# sigma_tau_list length: 451
# lat.totalLen: 45.013947600000016

# %%
sigma_tau = np.std(p_array.rparticles[4])
print("σ_τ before tracking:", sigma_tau, "s")

sigma_tau = np.std(p_array_t.rparticles[4])
print("σ_τ after tracking:", sigma_tau, "s")
# Out:
# σ_τ before tracking: 0.004003174268226804 s
# σ_τ after tracking: 0.000945114288168313 s

# %%
import matplotlib.pyplot as plt

# Longitudinal phase space: z vs. Δp/p
z = p_array.rparticles[4]   # in meters
dp_p = p_array.rparticles[5]  # unitless

plt.figure(figsize=(8,6))
plt.hexbin(z * 1e3, dp_p, gridsize=150, cmap='viridis')  # convert z to mm for better readability
plt.colorbar(label='Particle density')
plt.xlabel("z [mm]")
plt.ylabel("Δp/p")
plt.title("Longitudinal Phase Space")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Longitudinal phase space: z vs. Δp/p
z = p_array_t.rparticles[4]   # in meters
dp_p = p_array_t.rparticles[5]  # unitless

plt.figure(figsize=(10, 6))

hb = plt.hexbin(z * 1e3, dp_p, gridsize=100, cmap='plasma', bins='log')  # log scale improves contrast
plt.colorbar(hb, label='log(Particle density)')

plt.xlabel("z [mm]", fontsize=14)
plt.ylabel("Δp/p", fontsize=14)
plt.title("Longitudinal Phase Space", fontsize=16)

plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
show_e_beam(p_array_t)

# %%
import numpy as np

# particle data 
np.save("particles_rparticles.npy", p_array_t.rparticles)

# charge array
np.save("particles_q_array.npy", p_array_t.q_array)
