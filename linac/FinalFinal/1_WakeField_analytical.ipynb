# %%
from ocelot import *
from ocelot.cpbd.elements import *
from ocelot.gui.accelerator import *
from ocelot.cpbd.track import track_debug
import matplotlib.pyplot as plt


from linaccopy import *

# # Define a very simple lattice: one big drift
# # Define elements
# drift_length = 50.0  # meters
# drift = Drift(l=drift_length, eid="D1")

# cavity_voltage = 5e6  # 5 MV (can adjust)
# cavity = Cavity(l=10, eid="CAV1")  # simple 0.5 m cavity
# cavity.voltage = cavity_voltage  # Voltage in Volts
# cavity.freq = 1.3e9  # 1.3 GHz typical frequency
# cavity.phase = 0.0   # 0° synchronous phase (can play with later)

# # Create the toy lattice: Cavity + Drift
# toy_lat = MagneticLattice([cavity, drift])

lat = MagneticLattice(guntoC)

# #lat = toy_lat

# === Define Cavity ===
cavity_voltage = 5e6  # 5 MV (can adjust)
cavity = Cavity(l=10, eid="CAV1")
cavity.voltage = cavity_voltage
cavity.freq = 1.3e9  # 1.3 GHz
cavity.phase = -20.0  # <<< Off-crest phase to introduce chirp!

# === Define Chicane (4 Dipoles) ===
# Parameters
bend_length = 1.0    # meters
bend_angle = 0.05    # radians (about 2.8 degrees)

# Bends
b1 = SBend(l=bend_length, angle=+bend_angle, eid="B1")
b2 = SBend(l=bend_length, angle=-bend_angle, eid="B2")
b3 = SBend(l=bend_length, angle=-bend_angle, eid="B3")
b4 = SBend(l=bend_length, angle=+bend_angle, eid="B4")

# Drifts between bends
dr1 = Drift(l=1.0, eid="D1")   # between B1 and B2
dr2 = Drift(l=2.0, eid="D2")   # middle drift between B2 and B3
dr3 = Drift(l=1.0, eid="D3")   # between B3 and B4

# === Define Drift after Chicane ===
drift_length = 50.0  # meters
drift_after = Drift(l=drift_length, eid="D4")

# === Build Full Toy Lattice ===
toy_lat = MagneticLattice([
    cavity,
    b1, dr1, b2, dr2, b3, dr3, b4,   # chicane section
    drift_after                      # long drift after compression
])

# Final lattice you will track on:
#lat = toy_lat



##### PA1RFGUN #####
AX =-21.12   
BX =24.36 
AY =-21.16     
BY =24.42      
EMITX =1.2023504614117648e-06
EMITY =1.2023504614117648e-06 
DP =.01
energy = 0.0091
##### PA1RFGUN #####

##### PSECTB #####
# AX =.8330530584703799  
# BX =8.804855185360497    
# AY =.8104567519439174
# BY =8.82335409438248       
# EMITX =10.2023504614117648e-06 
# EMITY =10.2023504614117648e-06 
##### PSECTB #####



 # GeV  #why?
tw0 = Twiss()
tw0.alpha_x = AX
tw0.beta_x = BX

tw0.alpha_y = AY
tw0.beta_y = BY
tw0.E = energy
tw0.emit_xn = EMITX 
tw0.emit_yn = EMITY
tw0.emit_x = EMITX   / energy * 0.511e-3
tw0.emit_y = EMITY / energy * 0.511e-3

tws = twiss(lat,tw0)

plot_opt_func(lat, tws,legend=False, grid=False, top_plot=['Dx','Dy'])


for elem in lat.sequence:
    if not isinstance(elem, Drift):
        print(elem)
# Out:
# initializing ocelot...
# Marker(eid="PA1RFGUN")
# Quadrupole(l=0.07360, k1=-4.662753e+01, eid="QDA1G1")
# Quadrupole(l=0.07360, k1=4.709763e+01, eid="QFA1G2")
# Bend(eid="BXA1G")
# Bend(tilt=1.570796e+00, eid="BYA1G")
# Quadrupole(l=0.07360, k1=-8.030131e+00, eid="QDA101")
# Quadrupole(l=0.07360, k1=2.957378e+00, eid="QFA102")
# Marker(eid="PACA11")
# Cavity(l=0.61850, v=6.662282e-03, freq=2.856000e+09, phi=4.000000e+01, eid="ACA111")
# Bend(eid="SXA11")
# Bend(tilt=1.570796e+00, eid="SYA11")
# Cavity(l=1.27095, v=1.369683e-02, freq=2.856000e+09, phi=4.000000e+01, eid="ACA112")
# Marker(eid="PACA11")
# Quadrupole(l=0.07360, k1=-1.142003e-01, eid="QDA111")
# Quadrupole(l=0.11460, k1=5.928660e+00, eid="QFA112")
# Quadrupole(l=0.07360, k1=-7.876449e-03, eid="QDA113")
# Bend(l=0.14725, angle=1.605878e-01, e2=1.605878e-01, eid="BMA1C1")
# Bend(l=0.14725, angle=-1.605878e-01, e1=-1.605878e-01, eid="BMA1C2")
# Bend(l=0.14725, angle=-1.605878e-01, e2=-1.605878e-01, eid="BMA1C3")
# Bend(l=0.14725, angle=1.605878e-01, e1=1.605878e-01, eid="BMA1C4")
# Bend(l=0.17300, eid="BMATJ5")
# Marker(eid="PSECTA")
# Quadrupole(l=0.12235, k1=-9.100855e+00, eid="PDA1M")
# Quadrupole(l=0.12235, k1=1.137240e+01, eid="PFA1M")
# Bend(eid="PXA1M")
# Bend(tilt=1.570796e+00, eid="PYA1M")
# Cavity(l=0.03499, eid="AKA21")
# Marker(eid="PACA21")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA21")
# Bend(eid="SXA21")
# Bend(tilt=1.570796e+00, eid="SYA21")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA212")
# Marker(eid="PACA21")
# Cavity(l=0.03499, eid="AKA21")
# Marker(eid="PPDA21")
# Quadrupole(l=0.12235, k1=-1.323075e+01, eid="PDA21")
# Quadrupole(l=0.12235, k1=1.689616e+01, eid="PFA21")
# Cavity(l=0.03499, eid="AKA22")
# Marker(eid="PACA22")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA22")
# Bend(eid="SXA22")
# Bend(tilt=1.570796e+00, eid="SYA22")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA222")
# Marker(eid="PACA22")
# Cavity(l=0.03499, eid="AKA22")
# Cavity(l=0.03499, eid="AKA23")
# Marker(eid="PACA23")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA23")
# Bend(eid="SXA23")
# Bend(tilt=1.570796e+00, eid="SYA23")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA232")
# Marker(eid="PACA23")
# Cavity(l=0.03499, eid="AKA23")
# Quadrupole(l=0.07500, k1=-1.071808e+01, eid="QDA23")
# Quadrupole(l=0.12100, k1=1.182822e+01, eid="QFA23")
# Quadrupole(l=0.07500, k1=-1.071808e+01, eid="QDA23")
# Cavity(l=0.03499, eid="AKA24")
# Marker(eid="PACA24")
# Cavity(l=0.55984, v=9.618213e-03, freq=2.856000e+09, eid="ACA24")
# Bend(eid="SXA24")
# Bend(tilt=1.570796e+00, eid="SYA24")
# Cavity(l=1.32961, v=2.284326e-02, freq=2.856000e+09, eid="ACA242")
# Marker(eid="PACA24")
# Cavity(l=0.03499, eid="AKA24")
# Marker(eid="PQDA24")
# Quadrupole(l=0.12100, k1=-8.575773e+00, eid="QDA24")
# Quadrupole(l=0.22200, k1=9.049769e+00, eid="QFA24")
# Quadrupole(l=0.12100, k1=-8.575773e+00, eid="QDA24")
# Cavity(l=0.03499, eid="AKA31")
# Marker(eid="PACA31")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA31")
# Bend(eid="SXA31")
# Bend(tilt=1.570796e+00, eid="SYA31")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA312")
# Marker(eid="PACA31")
# Cavity(l=0.03499, eid="AKA31")
# Cavity(l=0.03499, eid="AKA32")
# Marker(eid="PACA32")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA32")
# Bend(eid="SXA32")
# Bend(tilt=1.570796e+00, eid="SYA32")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA322")
# Marker(eid="PACA32")
# Cavity(l=0.03499, eid="AKA32")
# Marker(eid="PQDA32")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA32")
# Quadrupole(l=0.22200, k1=9.294356e+00, eid="QFA32")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA32")
# Cavity(l=0.03499, eid="AKA33")
# Marker(eid="PACA33")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA33")
# Bend(eid="SXA33")
# Bend(tilt=1.570796e+00, eid="SYA33")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA332")
# Marker(eid="PACA33")
# Cavity(l=0.03499, eid="AKA33")
# Cavity(l=0.03499, eid="AKA34")
# Marker(eid="PACA34")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA34")
# Bend(eid="SXA34")
# Bend(tilt=1.570796e+00, eid="SYA34")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA342")
# Marker(eid="PACA34")
# Cavity(l=0.03499, eid="AKA34")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA34")
# Quadrupole(l=0.22200, k1=9.294356e+00, eid="QFA34")
# Quadrupole(l=0.12100, k1=-8.822557e+00, eid="QDA34")
# Cavity(l=0.03499, eid="AKA41")
# Marker(eid="PACA41")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA41")
# Bend(eid="SXA41")
# Bend(tilt=1.570796e+00, eid="SYA41")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA412")
# Marker(eid="PACA41")
# Cavity(l=0.03499, eid="AKA41")
# Cavity(l=0.03499, eid="AKA42")
# Marker(eid="PACA42")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA42")
# Bend(eid="SXA42")
# Bend(tilt=1.570796e+00, eid="SYA42")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA422")
# Marker(eid="PACA42")
# Cavity(l=0.03499, eid="AKA42")
# Quadrupole(l=0.12100, k1=-4.601097e+00, eid="QDA42")
# Quadrupole(l=0.22200, k1=5.050408e+00, eid="QFA42")
# Quadrupole(l=0.12100, k1=-4.601097e+00, eid="QDA42")
# Cavity(l=0.03499, eid="AKA43")
# Marker(eid="PACA43")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA43")
# Bend(eid="SXA43")
# Bend(tilt=1.570796e+00, eid="SYA43")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA432")
# Marker(eid="PACA43")
# Cavity(l=0.03499, eid="AKA43")
# Cavity(l=0.03499, eid="AKA44")
# Marker(eid="PACA44")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACA44")
# Bend(eid="SXA44")
# Bend(tilt=1.570796e+00, eid="SYA44")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACA442")
# Marker(eid="PACA44")
# Cavity(l=0.03499, eid="AKA44")
# Quadrupole(l=0.12100, k1=-6.419987e+00, eid="QDA44")
# Quadrupole(l=0.22200, k1=6.868209e+00, eid="QFA44")
# Quadrupole(l=0.12100, k1=-6.419987e+00, eid="QDA44")
# Bend(l=0.14155, eid="PXA44")
# Bend(l=0.14155, tilt=1.570796e+00, eid="PYA44")
# Marker(eid="PSECTB")
# Cavity(l=0.03499, eid="AKB11")
# Marker(eid="PACB11")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB11")
# Bend(eid="SXB11")
# Bend(tilt=1.570796e+00, eid="SYB11")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB112")
# Marker(eid="PACB11")
# Cavity(l=0.03499, eid="AKB11")
# Cavity(l=0.03499, eid="AKB12")
# Marker(eid="PACB12")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB12")
# Marker(eid="PACB12")
# Cavity(l=0.03499, eid="AKB12")
# Cavity(l=0.03499, eid="AKB13")
# Marker(eid="PACB13")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB13")
# Bend(eid="SXB13")
# Bend(tilt=1.570796e+00, eid="SYB13")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB132")
# Marker(eid="PACB13")
# Cavity(l=0.03499, eid="AKB13")
# Cavity(l=0.03499, eid="AKB14")
# Marker(eid="PACB14")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB14")
# Marker(eid="PACB14")
# Cavity(l=0.03499, eid="AKB14")
# Marker(eid="PQDB14")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB14")
# Quadrupole(l=0.25220, k1=5.900647e+00, eid="QFB14")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB14")
# Cavity(l=0.03499, eid="AKB21")
# Marker(eid="PACB21")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB21")
# Bend(eid="SXB21")
# Bend(tilt=1.570796e+00, eid="SYB21")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB212")
# Marker(eid="PACB21")
# Cavity(l=0.03499, eid="AKB21")
# Cavity(l=0.03499, eid="AKB22")
# Marker(eid="PACB22")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB22")
# Marker(eid="PACB22")
# Cavity(l=0.03499, eid="AKB22")
# Cavity(l=0.03499, eid="AKB23")
# Marker(eid="PACB23")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB23")
# Bend(eid="SXB23")
# Bend(tilt=1.570796e+00, eid="SYB23")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB232")
# Marker(eid="PACB23")
# Cavity(l=0.03499, eid="AKB23")
# Cavity(l=0.03499, eid="AKB24")
# Marker(eid="PACB24")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB24")
# Marker(eid="PACB24")
# Cavity(l=0.03499, eid="AKB24")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB24")
# Quadrupole(l=0.25220, k1=5.900647e+00, eid="QFB24")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB24")
# Cavity(l=0.03499, eid="AKB31")
# Marker(eid="PACB31")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB31")
# Bend(eid="SXB31")
# Bend(tilt=1.570796e+00, eid="SYB31")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB312")
# Marker(eid="PACB31")
# Cavity(l=0.03499, eid="AKB31")
# Cavity(l=0.03499, eid="AKB32")
# Marker(eid="PACB32")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB32")
# Marker(eid="PACB32")
# Cavity(l=0.03499, eid="AKB32")
# Cavity(l=0.03499, eid="AKB33")
# Marker(eid="PACB33")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB33")
# Bend(eid="SXB33")
# Bend(tilt=1.570796e+00, eid="SYB33")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB332")
# Marker(eid="PACB33")
# Cavity(l=0.03499, eid="AKB33")
# Cavity(l=0.03499, eid="AKB34")
# Marker(eid="PACB34")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB34")
# Marker(eid="PACB34")
# Cavity(l=0.03499, eid="AKB34")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB34")
# Quadrupole(l=0.25220, k1=5.900647e+00, eid="QFB34")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB34")
# Cavity(l=0.03499, eid="AKB41")
# Marker(eid="PACB41")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB41")
# Bend(eid="SXB41")
# Bend(tilt=1.570796e+00, eid="SYB41")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB412")
# Marker(eid="PACB41")
# Cavity(l=0.03499, eid="AKB41")
# Cavity(l=0.03499, eid="AKB42")
# Marker(eid="PACB42")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB42")
# Marker(eid="PACB42")
# Cavity(l=0.03499, eid="AKB42")
# Cavity(l=0.03499, eid="AKB43")
# Marker(eid="PACB43")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB43")
# Bend(eid="SXB43")
# Bend(tilt=1.570796e+00, eid="SYB43")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB432")
# Marker(eid="PACB43")
# Cavity(l=0.03499, eid="AKB43")
# Cavity(l=0.03499, eid="AKB44")
# Marker(eid="PACB44")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB44")
# Marker(eid="PACB44")
# Cavity(l=0.03499, eid="AKB44")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB44")
# Quadrupole(l=0.25220, k1=5.900647e+00, eid="QFB44")
# Quadrupole(l=0.13330, k1=-5.696197e+00, eid="QDB44")
# Cavity(l=0.03499, eid="AKB51")
# Marker(eid="PACB51")
# Cavity(l=0.55984, v=7.446514e-03, freq=2.856000e+09, eid="ACB51")
# Bend(eid="SXB51")
# Bend(tilt=1.570796e+00, eid="SYB51")
# Cavity(l=1.32961, v=2.113438e-02, freq=2.856000e+09, eid="ACB512")
# Marker(eid="PACB51")
# Cavity(l=0.03499, eid="AKB51")
# Cavity(l=0.03499, eid="AKB52")
# Marker(eid="PACB52")
# Cavity(l=1.88945, v=3.003307e-02, freq=2.856000e+09, eid="ACB52")
# Marker(eid="PACB52")
# Cavity(l=0.03499, eid="AKB52")
# Cavity(l=0.03499, eid="AKB53")
# Marker(eid="PACB53")
# Cavity(l=0.55984, v=7.446514e-03, freq=2.856000e+09, eid="ACB53")
# Bend(eid="SXB53")
# Bend(tilt=1.570796e+00, eid="SYB53")
# Cavity(l=1.32961, v=2.113438e-02, freq=2.856000e+09, eid="ACB532")
# Marker(eid="PACB53")
# Cavity(l=0.03499, eid="AKB53")
# Cavity(l=0.03499, eid="AKB54")
# Marker(eid="PACB54")
# Cavity(l=1.88945, v=3.003307e-02, freq=2.856000e+09, eid="ACB54")
# Marker(eid="PACB54")
# Cavity(l=0.03499, eid="AKB54")
# Quadrupole(l=0.13330, k1=-5.953089e+00, eid="QDB54")
# Quadrupole(l=0.25220, k1=6.161439e+00, eid="QFB54")
# Quadrupole(l=0.13330, k1=-5.953089e+00, eid="QDB54")
# Cavity(l=0.03499, eid="AKB61")
# Marker(eid="PACB61")
# Cavity(l=0.55984, v=7.446514e-03, freq=2.856000e+09, eid="ACB61")
# Bend(eid="SXB61")
# Bend(tilt=1.570796e+00, eid="SYB61")
# Cavity(l=1.32961, v=2.113438e-02, freq=2.856000e+09, eid="ACB612")
# Marker(eid="PACB61")
# Cavity(l=0.03499, eid="AKB61")
# Cavity(l=0.03499, eid="AKB62")
# Marker(eid="PACB62")
# Cavity(l=1.88945, v=3.003307e-02, freq=2.856000e+09, eid="ACB62")
# Marker(eid="PACB62")
# Cavity(l=0.03499, eid="AKB62")
# Cavity(l=0.03499, eid="AKB63")
# Marker(eid="PACB63")
# Cavity(l=0.55984, v=7.446514e-03, freq=2.856000e+09, eid="ACB63")
# Bend(eid="SXB63")
# Bend(tilt=1.570796e+00, eid="SYB63")
# Cavity(l=1.32961, v=2.113438e-02, freq=2.856000e+09, eid="ACB632")
# Marker(eid="PACB63")
# Cavity(l=0.03499, eid="AKB63")
# Cavity(l=0.03499, eid="AKB64")
# Marker(eid="PACB64")
# Cavity(l=1.88945, v=3.003307e-02, freq=2.856000e+09, eid="ACB64")
# Marker(eid="PACB64")
# Cavity(l=0.03499, eid="AKB64")
# Quadrupole(l=0.13330, k1=-6.044669e+00, eid="QDB64")
# Quadrupole(l=0.25220, k1=6.279358e+00, eid="QFB64")
# Quadrupole(l=0.13330, k1=-6.044669e+00, eid="QDB64")
# Cavity(l=0.03499, eid="AKB71")
# Marker(eid="PACB71")
# Cavity(l=0.55984, freq=2.856000e+09, eid="ACB71")
# Bend(eid="SXB71")
# Bend(tilt=1.570796e+00, eid="SYB71")
# Cavity(l=1.32961, freq=2.856000e+09, eid="ACB712")
# Marker(eid="PACB71")
# Cavity(l=0.03499, eid="AKB71")
# Cavity(l=0.03499, eid="AKB72")
# Marker(eid="PACB72")
# Cavity(l=1.88945, freq=2.856000e+09, eid="ACB72")
# Marker(eid="PACB72")
# Cavity(l=0.03499, eid="AKB72")
# Cavity(l=0.03499, eid="AKB73")
# Marker(eid="PACB73")
# Cavity(l=0.55984, freq=2.856000e+09, eid="ACB73")
# Bend(eid="SXB73")
# Bend(tilt=1.570796e+00, eid="SYB73")
# Cavity(l=1.32961, freq=2.856000e+09, eid="ACB732")
# Marker(eid="PACB73")
# Cavity(l=0.03499, eid="AKB73")
# Cavity(l=0.03499, eid="AKB74")
# Marker(eid="PACB74")
# Cavity(l=1.88945, freq=2.856000e+09, eid="ACB74")
# Marker(eid="PACB74")
# Cavity(l=0.03499, eid="AKB74")
# Quadrupole(l=0.13330, k1=-5.937041e+00, eid="QDB74")
# Quadrupole(l=0.25220, k1=6.318395e+00, eid="QFB74")
# Quadrupole(l=0.13330, k1=-5.937041e+00, eid="QDB74")
# Cavity(l=0.03499, eid="AKB81")
# Marker(eid="PACB81")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB81")
# Bend(eid="SXB81")
# Bend(tilt=1.570796e+00, eid="SYB81")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB812")
# Marker(eid="PACB81")
# Cavity(l=0.03499, eid="AKB81")
# Cavity(l=0.03499, eid="AKB82")
# Marker(eid="PACB82")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB82")
# Marker(eid="PACB82")
# Cavity(l=0.03499, eid="AKB82")
# Cavity(l=0.03499, eid="AKB83")
# Marker(eid="PACB83")
# Cavity(l=0.55984, v=1.175657e-02, freq=2.856000e+09, eid="ACB83")
# Bend(eid="SXB83")
# Bend(tilt=1.570796e+00, eid="SYB83")
# Cavity(l=1.32961, v=2.792186e-02, freq=2.856000e+09, eid="ACB832")
# Marker(eid="PACB83")
# Cavity(l=0.03499, eid="AKB83")
# Cavity(l=0.03499, eid="AKB84")
# Marker(eid="PACB84")
# Cavity(l=1.88945, v=3.967843e-02, freq=2.856000e+09, eid="ACB84")
# Marker(eid="PACB84")
# Cavity(l=0.03499, eid="AKB84")
# Marker(eid="PSECTJ")
# Marker(eid="PJARCM1")
# Marker(eid="JPXR001")
# Bend(l=0.12000, eid="PXR001")
# Marker(eid="JPYR001")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PYR001")
# Marker(eid="JQDR001")
# Quadrupole(l=0.32210, k1=-1.257494e+00, eid="PDR001")
# Marker(eid="JQFR002")
# Quadrupole(l=0.32210, k1=1.863293e+00, eid="PFR001")
# Bend(l=0.28800, tilt=1.570796e+00, eid="FYR002")
# Marker(eid="JPXR002")
# Bend(l=0.12000, eid="PXR002")
# Marker(eid="JPYR002")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PYR002")
# Quadrupole(l=0.32210, k1=-2.686861e+00, eid="PDR002")
# Marker(eid="JQDR003")
# Quadrupole(l=0.32210, k1=2.507463e+00, eid="PFR002")
# Marker(eid="PJARC")
# Bend(eid="BSR01")
# Marker(eid="JBMR01S")
# Bend(l=1.90757, angle=5.235988e-01, eid="BMR01")
# Marker(eid="JBMR01E")
# Bend(eid="BSR01")
# Bend(eid="BSR01")
# Marker(eid="JSFR013")
# Sextupole(l=0.11679, eid="SFR013")
# Marker(eid="JQFR014")
# Quadrupole(l=0.32314, k1=3.569323e+00, eid="QFR014")
# Marker(eid="JBMR02S")
# Bend(l=1.90920, angle=5.235988e-01, eid="BMR02")
# Marker(eid="JBMR02E")
# Bend(eid="BSR02")
# Marker(eid="JSFR021")
# Sextupole(l=0.11679, eid="SFR021")
# Marker(eid="JQDR022")
# Quadrupole(l=0.32314, k1=-3.136311e+00, eid="QDR022")
# Marker(eid="JQFR023")
# Quadrupole(l=0.32314, k1=3.143170e+00, eid="QFR023")
# Bend(tilt=1.570796e+00, eid="BYR023")
# Marker(eid="JBMR03S")
# Bend(l=1.90920, angle=5.235988e-01, eid="BMR03")
# Marker(eid="JBMR03E")
# Bend(eid="BSR03")
# Marker(eid="JSDR031")
# Sextupole(l=0.11679, eid="SDR031")
# Marker(eid="JQFR032")
# Quadrupole(l=0.32659, k1=4.337403e+00, eid="QFR032")
# Marker(eid="PMIDJARC")
# Marker(eid="JSDR033")
# Sextupole(l=0.11679, eid="SDR033")
# Marker(eid="JBMR04S")
# Bend(l=1.90920, angle=5.235988e-01, eid="BMR04")
# Marker(eid="JBMR04E")
# Bend(eid="BSR04")
# Bend(tilt=1.570796e+00, eid="BYR041")
# Marker(eid="JQFR041")
# Quadrupole(l=0.32314, k1=3.143170e+00, eid="QFR041")
# Marker(eid="JQDR042")
# Quadrupole(l=0.32314, k1=-3.136311e+00, eid="QDR042")
# Marker(eid="JSFR043")
# Sextupole(l=0.11679, eid="SFR043")
# Marker(eid="JBMR05S")
# Bend(l=1.90920, angle=5.235988e-01, eid="BMR05")
# Marker(eid="JBMR05E")
# Bend(eid="BSR05")
# Marker(eid="JQFR051")
# Quadrupole(l=0.32314, k1=3.569323e+00, eid="QFR051")
# Marker(eid="JSFR052")
# Sextupole(l=0.11679, eid="SFR052")
# Bend(eid="BSR06")
# Marker(eid="JBMR06S")
# Bend(l=1.90757, angle=5.235988e-01, eid="BMR06")
# Marker(eid="JBMR06E")
# Bend(eid="BSR06")
# Marker(eid="PJARCM2")
# Marker(eid="JPXR061")
# Bend(l=0.12000, eid="PXR061")
# Marker(eid="JPYR061")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PYR061")
# Marker(eid="JQDR061")
# Quadrupole(l=0.32210, k1=-1.961852e+00, eid="PDR061")
# Marker(eid="JQFR062")
# Quadrupole(l=0.32210, k1=2.185025e+00, eid="PFR061")
# Marker(eid="JQDR063")
# Quadrupole(l=0.32210, k1=-1.730731e+00, eid="PDR063")
# Quadrupole(l=0.32314, k1=1.439867e+00, eid="PFR063")
# Marker(eid="JPXR063")
# Marker(eid="JPYR063")
# Bend(l=0.12000, eid="PXR063")
# Bend(l=0.12000, tilt=1.570796e+00, eid="PYR063")
# Marker(eid="PSECTC")
# Marker(eid="ID_90608403_")

# %%
def gauss_from_twiss_vec(emit, beta, alpha, size=1):
    phi = 2 * np.pi * np.random.rand(size)
    u = np.random.rand(size)
    a = np.sqrt(-2 * np.log(1 - u) * emit)
    x = a * np.sqrt(beta) * np.cos(phi)
    xp = -a / np.sqrt(beta) * (np.sin(phi) + alpha * np.cos(phi))
    return x, xp

nparticles = 100000
p_array = ParticleArray(n=nparticles)

# sigma_tau = 6.7e-3  # (bunch length in)
# sigma_p = 5.e-4     # relative momentum spread (Δp/p)  

sigma_tau = 4e-3  # (bunch length in )
sigma_p = 0.001     # relative momentum spread (Δp/p)  


p_array.E = energy  # GeV

# Longitudinal
p_array.rparticles[4] = np.random.randn(nparticles) * sigma_tau
p_array.rparticles[5] = np.random.randn(nparticles) * sigma_p

# Transverse: vectorized sampling from Twiss parameters
x, xp = gauss_from_twiss_vec(tw0.emit_x, tw0.beta_x, tw0.alpha_x, size=nparticles)
y, yp = gauss_from_twiss_vec(tw0.emit_y, tw0.beta_y, tw0.alpha_y, size=nparticles)

p_array.rparticles[0] = x
p_array.rparticles[1] = xp
p_array.rparticles[2] = y
p_array.rparticles[3] = yp

# Charge distribution
charge = 4.0e-9  # nC
p_array.q_array = np.ones(nparticles) * (charge / nparticles)

# %%
from ocelot.cpbd.physics_proc import PhysProc

class CustomLongitudinalWake(PhysProc):
    def __init__(self, beam_radius=0.01, bunch_length=4e-3):
        super().__init__()
        self.Z0 = 377  # Ohm
        self.a = beam_radius
        self.L = bunch_length
        self.N = None

    def apply(self, p_array, step_size):
        z = p_array.rparticles[4]
        q = p_array.q_array
        
        if self.N is None:
            self.N = len(z)
        
        z_mean = np.mean(z)
        s = z - z_mean  # centered z
        
        # Resistive Wall Wake approximation: ~ 1/sqrt(-z)
        wake = np.zeros_like(s)
        mask = s < 0  # only trailing particles feel the wake
        wake[mask] = 1.0 / np.sqrt(-s[mask] + 1e-12)  # add epsilon to avoid division by zero
        
        # Normalize and scale
        W0 = 1e5  # Scaling factor [V/C/m^1/2], can adjust
        voltage = - (self.N * np.abs(q[0]) * self.Z0 * W0 / (self.a**2)) * wake


        
        # Apply kick
        delta_E = voltage * step_size
        E = p_array.E  # GeV
        delta_dp_p = delta_E / (E * 1e9)
        
        p_array.rparticles[5] += delta_dp_p

# %%
import time
from copy import deepcopy
import numpy as np
import matplotlib.pyplot as plt
from ocelot.cpbd.physics_proc import PhysProc

# Define the HookProcess to monitor sigma_tau
class HookProcess(PhysProc):
    def __init__(self, sigma_tau_list):
        super().__init__()
        self.sigma_tau_list = sigma_tau_list

    def apply(self, p_array, step_size):
        sigma_tau = np.std(p_array.rparticles[4])
        self.sigma_tau_list.append(sigma_tau)
        print(f"s = {self.z0:.3f} m, σ_τ = {sigma_tau:.3e} s")

# === TRACK WITHOUT WAKEFIELD ===
p_array_no_wake = deepcopy(p_array)

navi_no_wake = Navigator(lat)
navi_no_wake.unit_step = 0.5

sigma_tau_list_no_wake = []
hook_no_wake = HookProcess(sigma_tau_list_no_wake)
navi_no_wake.add_physics_proc(hook_no_wake, lat.sequence[0], lat.sequence[-1])

tws_no_wake, p_array_no_wake = track(lat, p_array_no_wake, navi_no_wake)

# === TRACK WITH CUSTOM WAKEFIELD ===
p_array_wake = deepcopy(p_array)

navi_wake = Navigator(lat)
navi_wake.unit_step = 0.5

sigma_tau_list_wake = []
hook_wake = HookProcess(sigma_tau_list_wake)
navi_wake.add_physics_proc(hook_wake, lat.sequence[0], lat.sequence[-1])

# Add custom wake
wake_proc = CustomLongitudinalWake(beam_radius=0.01, bunch_length=sigma_tau)
navi_wake.add_physics_proc(wake_proc, lat.sequence[0], lat.sequence[-1])

tws_wake, p_array_wake = track(lat, p_array_wake, navi_wake)

# === PLOT THE COMPARISON ===
s_axis_no_wake = np.linspace(0, lat.totalLen, len(sigma_tau_list_no_wake))
s_axis_wake = np.linspace(0, lat.totalLen, len(sigma_tau_list_wake))

plt.plot(s_axis_no_wake, sigma_tau_list_no_wake, label='No Wake')
plt.plot(s_axis_wake, sigma_tau_list_wake, '--', label='With Custom Wake')
plt.xlabel("s [m]")
plt.ylabel("σ_τ [s]")
plt.title("Evolution of Bunch Length σ_τ With and Without Wakefield")
plt.grid(True)
plt.legend()
plt.show()

# === PHASE SPACE PLOTS ===
def plot_phase_space(z, dp_p, title):
    plt.figure(figsize=(8,6))
    hb = plt.hexbin(z*1e3, dp_p, gridsize=100, cmap='plasma', bins='log')
    plt.colorbar(hb, label='log(Particle density)')
    plt.xlabel('z [mm]')
    plt.ylabel('Δp/p')
    plt.title(title)
    plt.grid(True)
    plt.tight_layout()
    plt.show()


# No wake
plot_phase_space(p_array_no_wake.rparticles[4], p_array_no_wake.rparticles[5], 'No Wake')

# With wake

plot_phase_space(p_array_wake.rparticles[4], p_array_wake.rparticles[5], 'With Custom Wake')
# Out:
# s = 0.500 m, σ_τ = 3.989e-03 s
# z = 0.5 / 157.8181392000003. Applied: HookProcesss = 1.000 m, σ_τ = 3.989e-03 s
# z = 1.0 / 157.8181392000003. Applied: HookProcesss = 1.500 m, σ_τ = 3.989e-03 s
# z = 1.5 / 157.8181392000003. Applied: HookProcesss = 2.000 m, σ_τ = 3.983e-03 s
# z = 2.0 / 157.8181392000003. Applied: HookProcesss = 2.500 m, σ_τ = 3.939e-03 s
# z = 2.5 / 157.8181392000003. Applied: HookProcesss = 3.000 m, σ_τ = 3.894e-03 s
# z = 3.0 / 157.8181392000003. Applied: HookProcesss = 3.500 m, σ_τ = 3.858e-03 s
# z = 3.5 / 157.8181392000003. Applied: HookProcesss = 4.000 m, σ_τ = 3.830e-03 s
# z = 4.0 / 157.8181392000003. Applied: HookProcesss = 4.500 m, σ_τ = 3.804e-03 s
# z = 4.5 / 157.8181392000003. Applied: HookProcesss = 5.000 m, σ_τ = 3.854e-03 s
# z = 5.0 / 157.8181392000003. Applied: HookProcesss = 5.500 m, σ_τ = 2.351e-03 s
# z = 5.5 / 157.8181392000003. Applied: HookProcesss = 6.000 m, σ_τ = 1.034e-03 s
# z = 6.0 / 157.8181392000003. Applied: HookProcesss = 6.500 m, σ_τ = 1.061e-03 s
# z = 6.5 / 157.8181392000003. Applied: HookProcesss = 7.000 m, σ_τ = 1.044e-03 s
# z = 7.0 / 157.8181392000003. Applied: HookProcesss = 7.500 m, σ_τ = 1.027e-03 s
# z = 7.5 / 157.8181392000003. Applied: HookProcesss = 8.000 m, σ_τ = 1.010e-03 s
# z = 8.0 / 157.8181392000003. Applied: HookProcesss = 8.500 m, σ_τ = 9.937e-04 s
# z = 8.5 / 157.8181392000003. Applied: HookProcesss = 9.000 m, σ_τ = 9.780e-04 s
# z = 9.0 / 157.8181392000003. Applied: HookProcesss = 9.500 m, σ_τ = 9.627e-04 s
# z = 9.5 / 157.8181392000003. Applied: HookProcesss = 10.000 m, σ_τ = 9.513e-04 s
# z = 10.0 / 157.8181392000003. Applied: HookProcesss = 10.500 m, σ_τ = 9.464e-04 s
# z = 10.5 / 157.8181392000003. Applied: HookProcesss = 11.000 m, σ_τ = 9.441e-04 s
# z = 11.0 / 157.8181392000003. Applied: HookProcesss = 11.500 m, σ_τ = 9.427e-04 s
# z = 11.5 / 157.8181392000003. Applied: HookProcesss = 12.000 m, σ_τ = 9.418e-04 s
# z = 12.0 / 157.8181392000003. Applied: HookProcesss = 12.500 m, σ_τ = 9.408e-04 s
# z = 12.5 / 157.8181392000003. Applied: HookProcesss = 13.000 m, σ_τ = 9.400e-04 s
# z = 13.0 / 157.8181392000003. Applied: HookProcesss = 13.500 m, σ_τ = 9.395e-04 s
# z = 13.5 / 157.8181392000003. Applied: HookProcesss = 14.000 m, σ_τ = 9.392e-04 s
# z = 14.0 / 157.8181392000003. Applied: HookProcesss = 14.500 m, σ_τ = 9.390e-04 s
# z = 14.5 / 157.8181392000003. Applied: HookProcesss = 15.000 m, σ_τ = 9.388e-04 s
# z = 15.0 / 157.8181392000003. Applied: HookProcesss = 15.500 m, σ_τ = 9.386e-04 s
# z = 15.5 / 157.8181392000003. Applied: HookProcesss = 16.000 m, σ_τ = 9.384e-04 s
# z = 16.0 / 157.8181392000003. Applied: HookProcesss = 16.500 m, σ_τ = 9.383e-04 s
# z = 16.5 / 157.8181392000003. Applied: HookProcesss = 17.000 m, σ_τ = 9.382e-04 s
# z = 17.0 / 157.8181392000003. Applied: HookProcesss = 17.500 m, σ_τ = 9.381e-04 s
# z = 17.5 / 157.8181392000003. Applied: HookProcesss = 18.000 m, σ_τ = 9.380e-04 s
# z = 18.0 / 157.8181392000003. Applied: HookProcesss = 18.500 m, σ_τ = 9.380e-04 s
# z = 18.5 / 157.8181392000003. Applied: HookProcesss = 19.000 m, σ_τ = 9.379e-04 s
# z = 19.0 / 157.8181392000003. Applied: HookProcesss = 19.500 m, σ_τ = 9.379e-04 s
# z = 19.5 / 157.8181392000003. Applied: HookProcesss = 20.000 m, σ_τ = 9.378e-04 s
# z = 20.0 / 157.8181392000003. Applied: HookProcesss = 20.500 m, σ_τ = 9.378e-04 s
# z = 20.5 / 157.8181392000003. Applied: HookProcesss = 21.000 m, σ_τ = 9.378e-04 s
# z = 21.0 / 157.8181392000003. Applied: HookProcesss = 21.500 m, σ_τ = 9.378e-04 s
# z = 21.5 / 157.8181392000003. Applied: HookProcesss = 22.000 m, σ_τ = 9.377e-04 s
# z = 22.0 / 157.8181392000003. Applied: HookProcesss = 22.500 m, σ_τ = 9.377e-04 s
# z = 22.5 / 157.8181392000003. Applied: HookProcesss = 23.000 m, σ_τ = 9.377e-04 s
# z = 23.0 / 157.8181392000003. Applied: HookProcesss = 23.500 m, σ_τ = 9.377e-04 s
# z = 23.5 / 157.8181392000003. Applied: HookProcesss = 24.000 m, σ_τ = 9.377e-04 s
# z = 24.0 / 157.8181392000003. Applied: HookProcesss = 24.500 m, σ_τ = 9.377e-04 s
# z = 24.5 / 157.8181392000003. Applied: HookProcesss = 25.000 m, σ_τ = 9.377e-04 s
# z = 25.0 / 157.8181392000003. Applied: HookProcesss = 25.500 m, σ_τ = 9.377e-04 s
# z = 25.5 / 157.8181392000003. Applied: HookProcesss = 26.000 m, σ_τ = 9.377e-04 s
# z = 26.0 / 157.8181392000003. Applied: HookProcesss = 26.500 m, σ_τ = 9.377e-04 s
# z = 26.5 / 157.8181392000003. Applied: HookProcesss = 27.000 m, σ_τ = 9.377e-04 s
# z = 27.0 / 157.8181392000003. Applied: HookProcesss = 27.500 m, σ_τ = 9.377e-04 s
# z = 27.5 / 157.8181392000003. Applied: HookProcesss = 28.000 m, σ_τ = 9.377e-04 s
# z = 28.0 / 157.8181392000003. Applied: HookProcesss = 28.500 m, σ_τ = 9.377e-04 s
# z = 28.5 / 157.8181392000003. Applied: HookProcesss = 29.000 m, σ_τ = 9.377e-04 s
# z = 29.0 / 157.8181392000003. Applied: HookProcesss = 29.500 m, σ_τ = 9.377e-04 s
# z = 29.5 / 157.8181392000003. Applied: HookProcesss = 30.000 m, σ_τ = 9.377e-04 s
# z = 30.0 / 157.8181392000003. Applied: HookProcesss = 30.500 m, σ_τ = 9.377e-04 s
# z = 30.5 / 157.8181392000003. Applied: HookProcesss = 31.000 m, σ_τ = 9.377e-04 s
# z = 31.0 / 157.8181392000003. Applied: HookProcesss = 31.500 m, σ_τ = 9.377e-04 s
# z = 31.5 / 157.8181392000003. Applied: HookProcesss = 32.000 m, σ_τ = 9.377e-04 s
# z = 32.0 / 157.8181392000003. Applied: HookProcesss = 32.500 m, σ_τ = 9.377e-04 s
# z = 32.5 / 157.8181392000003. Applied: HookProcesss = 33.000 m, σ_τ = 9.377e-04 s
# z = 33.0 / 157.8181392000003. Applied: HookProcesss = 33.500 m, σ_τ = 9.377e-04 s
# z = 33.5 / 157.8181392000003. Applied: HookProcesss = 34.000 m, σ_τ = 9.377e-04 s
# z = 34.0 / 157.8181392000003. Applied: HookProcesss = 34.500 m, σ_τ = 9.377e-04 s
# z = 34.5 / 157.8181392000003. Applied: HookProcesss = 35.000 m, σ_τ = 9.377e-04 s
# z = 35.0 / 157.8181392000003. Applied: HookProcesss = 35.500 m, σ_τ = 9.377e-04 s
# z = 35.5 / 157.8181392000003. Applied: HookProcesss = 36.000 m, σ_τ = 9.377e-04 s
# z = 36.0 / 157.8181392000003. Applied: HookProcesss = 36.500 m, σ_τ = 9.377e-04 s
# z = 36.5 / 157.8181392000003. Applied: HookProcesss = 37.000 m, σ_τ = 9.377e-04 s
# z = 37.0 / 157.8181392000003. Applied: HookProcesss = 37.500 m, σ_τ = 9.377e-04 s
# z = 37.5 / 157.8181392000003. Applied: HookProcesss = 38.000 m, σ_τ = 9.377e-04 s
# z = 38.0 / 157.8181392000003. Applied: HookProcesss = 38.500 m, σ_τ = 9.377e-04 s
# z = 38.5 / 157.8181392000003. Applied: HookProcesss = 39.000 m, σ_τ = 9.377e-04 s
# z = 39.0 / 157.8181392000003. Applied: HookProcesss = 39.500 m, σ_τ = 9.377e-04 s
# z = 39.5 / 157.8181392000003. Applied: HookProcesss = 40.000 m, σ_τ = 9.377e-04 s
# z = 40.0 / 157.8181392000003. Applied: HookProcesss = 40.500 m, σ_τ = 9.377e-04 s
# z = 40.5 / 157.8181392000003. Applied: HookProcesss = 41.000 m, σ_τ = 9.377e-04 s
# z = 41.0 / 157.8181392000003. Applied: HookProcesss = 41.500 m, σ_τ = 9.377e-04 s
# z = 41.5 / 157.8181392000003. Applied: HookProcesss = 42.000 m, σ_τ = 9.377e-04 s
# z = 42.0 / 157.8181392000003. Applied: HookProcesss = 42.500 m, σ_τ = 9.377e-04 s
# z = 42.5 / 157.8181392000003. Applied: HookProcesss = 43.000 m, σ_τ = 9.377e-04 s
# z = 43.0 / 157.8181392000003. Applied: HookProcesss = 43.500 m, σ_τ = 9.377e-04 s
# z = 43.5 / 157.8181392000003. Applied: HookProcesss = 44.000 m, σ_τ = 9.377e-04 s
# z = 44.0 / 157.8181392000003. Applied: HookProcesss = 44.500 m, σ_τ = 9.377e-04 s
# z = 44.5 / 157.8181392000003. Applied: HookProcesss = 45.000 m, σ_τ = 9.377e-04 s
# z = 45.0 / 157.8181392000003. Applied: HookProcesss = 45.500 m, σ_τ = 9.377e-04 s
# z = 45.5 / 157.8181392000003. Applied: HookProcesss = 46.000 m, σ_τ = 9.377e-04 s
# z = 46.0 / 157.8181392000003. Applied: HookProcesss = 46.500 m, σ_τ = 9.377e-04 s
# z = 46.5 / 157.8181392000003. Applied: HookProcesss = 47.000 m, σ_τ = 9.377e-04 s
# z = 47.0 / 157.8181392000003. Applied: HookProcesss = 47.500 m, σ_τ = 9.377e-04 s
# z = 47.5 / 157.8181392000003. Applied: HookProcesss = 48.000 m, σ_τ = 9.377e-04 s
# z = 48.0 / 157.8181392000003. Applied: HookProcesss = 48.500 m, σ_τ = 9.377e-04 s
# z = 48.5 / 157.8181392000003. Applied: HookProcesss = 49.000 m, σ_τ = 9.377e-04 s
# z = 49.0 / 157.8181392000003. Applied: HookProcesss = 49.500 m, σ_τ = 9.377e-04 s
# z = 49.5 / 157.8181392000003. Applied: HookProcesss = 50.000 m, σ_τ = 9.377e-04 s
# z = 50.0 / 157.8181392000003. Applied: HookProcesss = 50.500 m, σ_τ = 9.377e-04 s
# z = 50.5 / 157.8181392000003. Applied: HookProcesss = 51.000 m, σ_τ = 9.377e-04 s
# z = 51.0 / 157.8181392000003. Applied: HookProcesss = 51.500 m, σ_τ = 9.377e-04 s
# z = 51.5 / 157.8181392000003. Applied: HookProcesss = 52.000 m, σ_τ = 9.377e-04 s
# z = 52.0 / 157.8181392000003. Applied: HookProcesss = 52.500 m, σ_τ = 9.377e-04 s
# z = 52.5 / 157.8181392000003. Applied: HookProcesss = 53.000 m, σ_τ = 9.377e-04 s
# z = 53.0 / 157.8181392000003. Applied: HookProcesss = 53.500 m, σ_τ = 9.377e-04 s
# z = 53.5 / 157.8181392000003. Applied: HookProcesss = 54.000 m, σ_τ = 9.377e-04 s
# z = 54.0 / 157.8181392000003. Applied: HookProcesss = 54.500 m, σ_τ = 9.378e-04 s
# z = 54.5 / 157.8181392000003. Applied: HookProcesss = 55.000 m, σ_τ = 9.378e-04 s
# z = 55.0 / 157.8181392000003. Applied: HookProcesss = 55.500 m, σ_τ = 9.378e-04 s
# z = 55.5 / 157.8181392000003. Applied: HookProcesss = 56.000 m, σ_τ = 9.378e-04 s
# z = 56.0 / 157.8181392000003. Applied: HookProcesss = 56.500 m, σ_τ = 9.378e-04 s
# z = 56.5 / 157.8181392000003. Applied: HookProcesss = 57.000 m, σ_τ = 9.378e-04 s
# z = 57.0 / 157.8181392000003. Applied: HookProcesss = 57.500 m, σ_τ = 9.378e-04 s
# z = 57.5 / 157.8181392000003. Applied: HookProcesss = 58.000 m, σ_τ = 9.378e-04 s
# z = 58.0 / 157.8181392000003. Applied: HookProcesss = 58.500 m, σ_τ = 9.378e-04 s
# z = 58.5 / 157.8181392000003. Applied: HookProcesss = 59.000 m, σ_τ = 9.378e-04 s
# z = 59.0 / 157.8181392000003. Applied: HookProcesss = 59.500 m, σ_τ = 9.378e-04 s
# z = 59.5 / 157.8181392000003. Applied: HookProcesss = 60.000 m, σ_τ = 9.378e-04 s
# z = 60.0 / 157.8181392000003. Applied: HookProcesss = 60.500 m, σ_τ = 9.378e-04 s
# z = 60.5 / 157.8181392000003. Applied: HookProcesss = 61.000 m, σ_τ = 9.378e-04 s
# z = 61.0 / 157.8181392000003. Applied: HookProcesss = 61.500 m, σ_τ = 9.378e-04 s
# z = 61.5 / 157.8181392000003. Applied: HookProcesss = 62.000 m, σ_τ = 9.378e-04 s
# z = 62.0 / 157.8181392000003. Applied: HookProcesss = 62.500 m, σ_τ = 9.378e-04 s
# z = 62.5 / 157.8181392000003. Applied: HookProcesss = 63.000 m, σ_τ = 9.378e-04 s
# z = 63.0 / 157.8181392000003. Applied: HookProcesss = 63.500 m, σ_τ = 9.378e-04 s
# z = 63.5 / 157.8181392000003. Applied: HookProcesss = 64.000 m, σ_τ = 9.378e-04 s
# z = 64.0 / 157.8181392000003. Applied: HookProcesss = 64.500 m, σ_τ = 9.378e-04 s
# z = 64.5 / 157.8181392000003. Applied: HookProcesss = 65.000 m, σ_τ = 9.378e-04 s
# z = 65.0 / 157.8181392000003. Applied: HookProcesss = 65.500 m, σ_τ = 9.378e-04 s
# z = 65.5 / 157.8181392000003. Applied: HookProcesss = 66.000 m, σ_τ = 9.378e-04 s
# z = 66.0 / 157.8181392000003. Applied: HookProcesss = 66.500 m, σ_τ = 9.378e-04 s
# z = 66.5 / 157.8181392000003. Applied: HookProcesss = 67.000 m, σ_τ = 9.378e-04 s
# z = 67.0 / 157.8181392000003. Applied: HookProcesss = 67.500 m, σ_τ = 9.378e-04 s
# z = 67.5 / 157.8181392000003. Applied: HookProcesss = 68.000 m, σ_τ = 9.378e-04 s
# z = 68.0 / 157.8181392000003. Applied: HookProcesss = 68.500 m, σ_τ = 9.378e-04 s
# z = 68.5 / 157.8181392000003. Applied: HookProcesss = 69.000 m, σ_τ = 9.378e-04 s
# z = 69.0 / 157.8181392000003. Applied: HookProcesss = 69.500 m, σ_τ = 9.378e-04 s
# z = 69.5 / 157.8181392000003. Applied: HookProcesss = 70.000 m, σ_τ = 9.378e-04 s
# z = 70.0 / 157.8181392000003. Applied: HookProcesss = 70.500 m, σ_τ = 9.378e-04 s
# z = 70.5 / 157.8181392000003. Applied: HookProcesss = 71.000 m, σ_τ = 9.378e-04 s
# z = 71.0 / 157.8181392000003. Applied: HookProcesss = 71.500 m, σ_τ = 9.378e-04 s
# z = 71.5 / 157.8181392000003. Applied: HookProcesss = 72.000 m, σ_τ = 9.378e-04 s
# z = 72.0 / 157.8181392000003. Applied: HookProcesss = 72.500 m, σ_τ = 9.378e-04 s
# z = 72.5 / 157.8181392000003. Applied: HookProcesss = 73.000 m, σ_τ = 9.378e-04 s
# z = 73.0 / 157.8181392000003. Applied: HookProcesss = 73.500 m, σ_τ = 9.378e-04 s
# z = 73.5 / 157.8181392000003. Applied: HookProcesss = 74.000 m, σ_τ = 9.378e-04 s
# z = 74.0 / 157.8181392000003. Applied: HookProcesss = 74.500 m, σ_τ = 9.378e-04 s
# z = 74.5 / 157.8181392000003. Applied: HookProcesss = 75.000 m, σ_τ = 9.378e-04 s
# z = 75.0 / 157.8181392000003. Applied: HookProcesss = 75.500 m, σ_τ = 9.378e-04 s
# z = 75.5 / 157.8181392000003. Applied: HookProcesss = 76.000 m, σ_τ = 9.378e-04 s
# z = 76.0 / 157.8181392000003. Applied: HookProcesss = 76.500 m, σ_τ = 9.378e-04 s
# z = 76.5 / 157.8181392000003. Applied: HookProcesss = 77.000 m, σ_τ = 9.378e-04 s
# z = 77.0 / 157.8181392000003. Applied: HookProcesss = 77.500 m, σ_τ = 9.378e-04 s
# z = 77.5 / 157.8181392000003. Applied: HookProcesss = 78.000 m, σ_τ = 9.378e-04 s
# z = 78.0 / 157.8181392000003. Applied: HookProcesss = 78.500 m, σ_τ = 9.378e-04 s
# z = 78.5 / 157.8181392000003. Applied: HookProcesss = 79.000 m, σ_τ = 9.378e-04 s
# z = 79.0 / 157.8181392000003. Applied: HookProcesss = 79.500 m, σ_τ = 9.378e-04 s
# z = 79.5 / 157.8181392000003. Applied: HookProcesss = 80.000 m, σ_τ = 9.378e-04 s
# z = 80.0 / 157.8181392000003. Applied: HookProcesss = 80.500 m, σ_τ = 9.378e-04 s
# z = 80.5 / 157.8181392000003. Applied: HookProcesss = 81.000 m, σ_τ = 9.378e-04 s
# z = 81.0 / 157.8181392000003. Applied: HookProcesss = 81.500 m, σ_τ = 9.378e-04 s
# z = 81.5 / 157.8181392000003. Applied: HookProcesss = 82.000 m, σ_τ = 9.378e-04 s
# z = 82.0 / 157.8181392000003. Applied: HookProcesss = 82.500 m, σ_τ = 9.378e-04 s
# z = 82.5 / 157.8181392000003. Applied: HookProcesss = 83.000 m, σ_τ = 9.378e-04 s
# z = 83.0 / 157.8181392000003. Applied: HookProcesss = 83.500 m, σ_τ = 9.378e-04 s
# z = 83.5 / 157.8181392000003. Applied: HookProcesss = 84.000 m, σ_τ = 9.378e-04 s
# z = 84.0 / 157.8181392000003. Applied: HookProcesss = 84.500 m, σ_τ = 9.378e-04 s
# z = 84.5 / 157.8181392000003. Applied: HookProcesss = 85.000 m, σ_τ = 9.378e-04 s
# z = 85.0 / 157.8181392000003. Applied: HookProcesss = 85.500 m, σ_τ = 9.378e-04 s
# z = 85.5 / 157.8181392000003. Applied: HookProcesss = 86.000 m, σ_τ = 9.378e-04 s
# z = 86.0 / 157.8181392000003. Applied: HookProcesss = 86.500 m, σ_τ = 9.378e-04 s
# z = 86.5 / 157.8181392000003. Applied: HookProcesss = 87.000 m, σ_τ = 9.378e-04 s
# z = 87.0 / 157.8181392000003. Applied: HookProcesss = 87.500 m, σ_τ = 9.378e-04 s
# z = 87.5 / 157.8181392000003. Applied: HookProcesss = 88.000 m, σ_τ = 9.378e-04 s
# z = 88.0 / 157.8181392000003. Applied: HookProcesss = 88.500 m, σ_τ = 9.378e-04 s
# z = 88.5 / 157.8181392000003. Applied: HookProcesss = 89.000 m, σ_τ = 9.378e-04 s
# z = 89.0 / 157.8181392000003. Applied: HookProcesss = 89.500 m, σ_τ = 9.378e-04 s
# z = 89.5 / 157.8181392000003. Applied: HookProcesss = 90.000 m, σ_τ = 9.378e-04 s
# z = 90.0 / 157.8181392000003. Applied: HookProcesss = 90.500 m, σ_τ = 9.378e-04 s
# z = 90.5 / 157.8181392000003. Applied: HookProcesss = 91.000 m, σ_τ = 9.378e-04 s
# z = 91.0 / 157.8181392000003. Applied: HookProcesss = 91.500 m, σ_τ = 9.378e-04 s
# z = 91.5 / 157.8181392000003. Applied: HookProcesss = 92.000 m, σ_τ = 9.378e-04 s
# z = 92.0 / 157.8181392000003. Applied: HookProcesss = 92.500 m, σ_τ = 9.378e-04 s
# z = 92.5 / 157.8181392000003. Applied: HookProcesss = 93.000 m, σ_τ = 9.378e-04 s
# z = 93.0 / 157.8181392000003. Applied: HookProcesss = 93.500 m, σ_τ = 9.378e-04 s
# z = 93.5 / 157.8181392000003. Applied: HookProcesss = 94.000 m, σ_τ = 9.378e-04 s
# z = 94.0 / 157.8181392000003. Applied: HookProcesss = 94.500 m, σ_τ = 9.378e-04 s
# z = 94.5 / 157.8181392000003. Applied: HookProcesss = 95.000 m, σ_τ = 9.378e-04 s
# z = 95.0 / 157.8181392000003. Applied: HookProcesss = 95.500 m, σ_τ = 9.378e-04 s
# z = 95.5 / 157.8181392000003. Applied: HookProcesss = 96.000 m, σ_τ = 9.378e-04 s
# z = 96.0 / 157.8181392000003. Applied: HookProcesss = 96.500 m, σ_τ = 9.378e-04 s
# z = 96.5 / 157.8181392000003. Applied: HookProcesss = 97.000 m, σ_τ = 9.378e-04 s
# z = 97.0 / 157.8181392000003. Applied: HookProcesss = 97.500 m, σ_τ = 9.378e-04 s
# z = 97.5 / 157.8181392000003. Applied: HookProcesss = 98.000 m, σ_τ = 9.378e-04 s
# z = 98.0 / 157.8181392000003. Applied: HookProcesss = 98.500 m, σ_τ = 9.378e-04 s
# z = 98.5 / 157.8181392000003. Applied: HookProcesss = 99.000 m, σ_τ = 9.378e-04 s
# z = 99.0 / 157.8181392000003. Applied: HookProcesss = 99.500 m, σ_τ = 9.378e-04 s
# z = 99.5 / 157.8181392000003. Applied: HookProcesss = 100.000 m, σ_τ = 9.378e-04 s
# z = 100.0 / 157.8181392000003. Applied: HookProcesss = 100.500 m, σ_τ = 9.378e-04 s
# z = 100.5 / 157.8181392000003. Applied: HookProcesss = 101.000 m, σ_τ = 9.378e-04 s
# z = 101.0 / 157.8181392000003. Applied: HookProcesss = 101.500 m, σ_τ = 9.378e-04 s
# z = 101.5 / 157.8181392000003. Applied: HookProcesss = 102.000 m, σ_τ = 9.378e-04 s
# z = 102.0 / 157.8181392000003. Applied: HookProcesss = 102.500 m, σ_τ = 9.378e-04 s
# z = 102.5 / 157.8181392000003. Applied: HookProcesss = 103.000 m, σ_τ = 9.378e-04 s
# z = 103.0 / 157.8181392000003. Applied: HookProcesss = 103.500 m, σ_τ = 9.378e-04 s
# z = 103.5 / 157.8181392000003. Applied: HookProcesss = 104.000 m, σ_τ = 9.378e-04 s
# z = 104.0 / 157.8181392000003. Applied: HookProcesss = 104.500 m, σ_τ = 9.378e-04 s
# z = 104.5 / 157.8181392000003. Applied: HookProcesss = 105.000 m, σ_τ = 9.378e-04 s
# z = 105.0 / 157.8181392000003. Applied: HookProcesss = 105.500 m, σ_τ = 9.378e-04 s
# z = 105.5 / 157.8181392000003. Applied: HookProcesss = 106.000 m, σ_τ = 9.378e-04 s
# z = 106.0 / 157.8181392000003. Applied: HookProcesss = 106.500 m, σ_τ = 9.378e-04 s
# z = 106.5 / 157.8181392000003. Applied: HookProcesss = 107.000 m, σ_τ = 9.378e-04 s
# z = 107.0 / 157.8181392000003. Applied: HookProcesss = 107.500 m, σ_τ = 9.378e-04 s
# z = 107.5 / 157.8181392000003. Applied: HookProcesss = 108.000 m, σ_τ = 9.378e-04 s
# z = 108.0 / 157.8181392000003. Applied: HookProcesss = 108.500 m, σ_τ = 9.378e-04 s
# z = 108.5 / 157.8181392000003. Applied: HookProcesss = 109.000 m, σ_τ = 9.378e-04 s
# z = 109.0 / 157.8181392000003. Applied: HookProcesss = 109.500 m, σ_τ = 9.378e-04 s
# z = 109.5 / 157.8181392000003. Applied: HookProcesss = 110.000 m, σ_τ = 9.378e-04 s
# z = 110.0 / 157.8181392000003. Applied: HookProcesss = 110.500 m, σ_τ = 9.378e-04 s
# z = 110.5 / 157.8181392000003. Applied: HookProcesss = 111.000 m, σ_τ = 9.378e-04 s
# z = 111.0 / 157.8181392000003. Applied: HookProcesss = 111.500 m, σ_τ = 9.378e-04 s
# z = 111.5 / 157.8181392000003. Applied: HookProcesss = 112.000 m, σ_τ = 9.378e-04 s
# z = 112.0 / 157.8181392000003. Applied: HookProcesss = 112.500 m, σ_τ = 9.378e-04 s
# z = 112.5 / 157.8181392000003. Applied: HookProcesss = 113.000 m, σ_τ = 9.378e-04 s
# z = 113.0 / 157.8181392000003. Applied: HookProcesss = 113.500 m, σ_τ = 9.378e-04 s
# z = 113.5 / 157.8181392000003. Applied: HookProcesss = 114.000 m, σ_τ = 9.378e-04 s
# z = 114.0 / 157.8181392000003. Applied: HookProcesss = 114.500 m, σ_τ = 9.378e-04 s
# z = 114.5 / 157.8181392000003. Applied: HookProcesss = 115.000 m, σ_τ = 9.378e-04 s
# z = 115.0 / 157.8181392000003. Applied: HookProcesss = 115.500 m, σ_τ = 9.378e-04 s
# z = 115.5 / 157.8181392000003. Applied: HookProcesss = 116.000 m, σ_τ = 9.378e-04 s
# z = 116.0 / 157.8181392000003. Applied: HookProcesss = 116.500 m, σ_τ = 9.378e-04 s
# z = 116.5 / 157.8181392000003. Applied: HookProcesss = 117.000 m, σ_τ = 9.378e-04 s
# z = 117.0 / 157.8181392000003. Applied: HookProcesss = 117.500 m, σ_τ = 9.378e-04 s
# z = 117.5 / 157.8181392000003. Applied: HookProcesss = 118.000 m, σ_τ = 9.378e-04 s
# z = 118.0 / 157.8181392000003. Applied: HookProcesss = 118.500 m, σ_τ = 9.378e-04 s
# z = 118.5 / 157.8181392000003. Applied: HookProcesss = 119.000 m, σ_τ = 9.378e-04 s
# z = 119.0 / 157.8181392000003. Applied: HookProcesss = 119.500 m, σ_τ = 9.378e-04 s
# z = 119.5 / 157.8181392000003. Applied: HookProcesss = 120.000 m, σ_τ = 9.378e-04 s
# z = 120.0 / 157.8181392000003. Applied: HookProcesss = 120.500 m, σ_τ = 9.378e-04 s
# z = 120.5 / 157.8181392000003. Applied: HookProcesss = 121.000 m, σ_τ = 9.378e-04 s
# z = 121.0 / 157.8181392000003. Applied: HookProcesss = 121.500 m, σ_τ = 9.378e-04 s
# z = 121.5 / 157.8181392000003. Applied: HookProcesss = 122.000 m, σ_τ = 9.378e-04 s
# z = 122.0 / 157.8181392000003. Applied: HookProcesss = 122.500 m, σ_τ = 9.378e-04 s
# z = 122.5 / 157.8181392000003. Applied: HookProcesss = 123.000 m, σ_τ = 9.378e-04 s
# z = 123.0 / 157.8181392000003. Applied: HookProcesss = 123.500 m, σ_τ = 9.378e-04 s
# z = 123.5 / 157.8181392000003. Applied: HookProcesss = 124.000 m, σ_τ = 9.378e-04 s
# z = 124.0 / 157.8181392000003. Applied: HookProcesss = 124.500 m, σ_τ = 9.378e-04 s
# z = 124.5 / 157.8181392000003. Applied: HookProcesss = 125.000 m, σ_τ = 9.378e-04 s
# z = 125.0 / 157.8181392000003. Applied: HookProcesss = 125.500 m, σ_τ = 9.378e-04 s
# z = 125.5 / 157.8181392000003. Applied: HookProcesss = 126.000 m, σ_τ = 9.378e-04 s
# z = 126.0 / 157.8181392000003. Applied: HookProcesss = 126.500 m, σ_τ = 9.350e-04 s
# z = 126.5 / 157.8181392000003. Applied: HookProcesss = 127.000 m, σ_τ = 8.988e-04 s
# z = 127.0 / 157.8181392000003. Applied: HookProcesss = 127.500 m, σ_τ = 7.932e-04 s
# z = 127.5 / 157.8181392000003. Applied: HookProcesss = 128.000 m, σ_τ = 6.509e-04 s
# z = 128.0 / 157.8181392000003. Applied: HookProcesss = 128.500 m, σ_τ = 6.424e-04 s
# z = 128.5 / 157.8181392000003. Applied: HookProcesss = 129.000 m, σ_τ = 6.424e-04 s
# z = 129.0 / 157.8181392000003. Applied: HookProcesss = 129.500 m, σ_τ = 6.424e-04 s
# z = 129.5 / 157.8181392000003. Applied: HookProcesss = 130.000 m, σ_τ = 6.424e-04 s
# z = 130.0 / 157.8181392000003. Applied: HookProcesss = 130.500 m, σ_τ = 6.452e-04 s
# z = 130.5 / 157.8181392000003. Applied: HookProcesss = 131.000 m, σ_τ = 6.604e-04 s
# z = 131.0 / 157.8181392000003. Applied: HookProcesss = 131.500 m, σ_τ = 6.388e-04 s
# z = 131.5 / 157.8181392000003. Applied: HookProcesss = 132.000 m, σ_τ = 6.446e-04 s
# z = 132.0 / 157.8181392000003. Applied: HookProcesss = 132.500 m, σ_τ = 6.472e-04 s
# z = 132.5 / 157.8181392000003. Applied: HookProcesss = 133.000 m, σ_τ = 6.472e-04 s
# z = 133.0 / 157.8181392000003. Applied: HookProcesss = 133.500 m, σ_τ = 6.472e-04 s
# z = 133.5 / 157.8181392000003. Applied: HookProcesss = 134.000 m, σ_τ = 6.472e-04 s
# z = 134.0 / 157.8181392000003. Applied: HookProcesss = 134.500 m, σ_τ = 7.844e-04 s
# z = 134.5 / 157.8181392000003. Applied: HookProcesss = 135.000 m, σ_τ = 9.849e-04 s
# z = 135.0 / 157.8181392000003. Applied: HookProcesss = 135.500 m, σ_τ = 1.065e-03 s
# z = 135.5 / 157.8181392000003. Applied: HookProcesss = 136.000 m, σ_τ = 9.455e-04 s
# z = 136.0 / 157.8181392000003. Applied: HookProcesss = 136.500 m, σ_τ = 9.446e-04 s
# z = 136.5 / 157.8181392000003. Applied: HookProcesss = 137.000 m, σ_τ = 9.446e-04 s
# z = 137.0 / 157.8181392000003. Applied: HookProcesss = 137.500 m, σ_τ = 9.446e-04 s
# z = 137.5 / 157.8181392000003. Applied: HookProcesss = 138.000 m, σ_τ = 9.446e-04 s
# z = 138.0 / 157.8181392000003. Applied: HookProcesss = 138.500 m, σ_τ = 8.376e-04 s
# z = 138.5 / 157.8181392000003. Applied: HookProcesss = 139.000 m, σ_τ = 8.771e-04 s
# z = 139.0 / 157.8181392000003. Applied: HookProcesss = 139.500 m, σ_τ = 1.074e-03 s
# z = 139.5 / 157.8181392000003. Applied: HookProcesss = 140.000 m, σ_τ = 1.402e-03 s
# z = 140.0 / 157.8181392000003. Applied: HookProcesss = 140.500 m, σ_τ = 1.402e-03 s
# z = 140.5 / 157.8181392000003. Applied: HookProcesss = 141.000 m, σ_τ = 1.402e-03 s
# z = 141.0 / 157.8181392000003. Applied: HookProcesss = 141.500 m, σ_τ = 1.402e-03 s
# z = 141.5 / 157.8181392000003. Applied: HookProcesss = 142.000 m, σ_τ = 1.402e-03 s
# z = 142.0 / 157.8181392000003. Applied: HookProcesss = 142.500 m, σ_τ = 1.574e-03 s
# z = 142.5 / 157.8181392000003. Applied: HookProcesss = 143.000 m, σ_τ = 1.687e-03 s
# z = 143.0 / 157.8181392000003. Applied: HookProcesss = 143.500 m, σ_τ = 1.652e-03 s
# z = 143.5 / 157.8181392000003. Applied: HookProcesss = 144.000 m, σ_τ = 1.439e-03 s
# z = 144.0 / 157.8181392000003. Applied: HookProcesss = 144.500 m, σ_τ = 1.439e-03 s
# z = 144.5 / 157.8181392000003. Applied: HookProcesss = 145.000 m, σ_τ = 1.439e-03 s
# z = 145.0 / 157.8181392000003. Applied: HookProcesss = 145.500 m, σ_τ = 1.439e-03 s
# z = 145.5 / 157.8181392000003. Applied: HookProcesss = 146.000 m, σ_τ = 1.439e-03 s
# z = 146.0 / 157.8181392000003. Applied: HookProcesss = 146.500 m, σ_τ = 1.143e-03 s
# z = 146.5 / 157.8181392000003. Applied: HookProcesss = 147.000 m, σ_τ = 9.934e-04 s
# z = 147.0 / 157.8181392000003. Applied: HookProcesss = 147.500 m, σ_τ = 9.446e-04 s
# z = 147.5 / 157.8181392000003. Applied: HookProcesss = 148.000 m, σ_τ = 9.392e-04 s
# z = 148.0 / 157.8181392000003. Applied: HookProcesss = 148.500 m, σ_τ = 9.392e-04 s
# z = 148.5 / 157.8181392000003. Applied: HookProcesss = 149.000 m, σ_τ = 9.392e-04 s
# z = 149.0 / 157.8181392000003. Applied: HookProcesss = 149.500 m, σ_τ = 9.392e-04 s
# z = 149.5 / 157.8181392000003. Applied: HookProcesss = 150.000 m, σ_τ = 9.392e-04 s
# z = 150.0 / 157.8181392000003. Applied: HookProcesss = 150.500 m, σ_τ = 9.392e-04 s
# z = 150.5 / 157.8181392000003. Applied: HookProcesss = 151.000 m, σ_τ = 9.392e-04 s
# z = 151.0 / 157.8181392000003. Applied: HookProcesss = 151.500 m, σ_τ = 9.392e-04 s
# z = 151.5 / 157.8181392000003. Applied: HookProcesss = 152.000 m, σ_τ = 9.392e-04 s
# z = 152.0 / 157.8181392000003. Applied: HookProcesss = 152.500 m, σ_τ = 9.392e-04 s
# z = 152.5 / 157.8181392000003. Applied: HookProcesss = 153.000 m, σ_τ = 9.392e-04 s
# z = 153.0 / 157.8181392000003. Applied: HookProcesss = 153.500 m, σ_τ = 9.392e-04 s
# z = 153.5 / 157.8181392000003. Applied: HookProcesss = 154.000 m, σ_τ = 9.392e-04 s
# z = 154.0 / 157.8181392000003. Applied: HookProcesss = 154.500 m, σ_τ = 9.393e-04 s
# z = 154.5 / 157.8181392000003. Applied: HookProcesss = 155.000 m, σ_τ = 9.393e-04 s
# z = 155.0 / 157.8181392000003. Applied: HookProcesss = 155.500 m, σ_τ = 9.393e-04 s
# z = 155.5 / 157.8181392000003. Applied: HookProcesss = 156.000 m, σ_τ = 9.393e-04 s
# z = 156.0 / 157.8181392000003. Applied: HookProcesss = 156.500 m, σ_τ = 9.393e-04 s
# z = 156.5 / 157.8181392000003. Applied: HookProcesss = 157.000 m, σ_τ = 9.393e-04 s
# z = 157.0 / 157.8181392000003. Applied: HookProcesss = 157.500 m, σ_τ = 9.393e-04 s
# z = 157.5 / 157.8181392000003. Applied: HookProcesss = 157.818 m, σ_τ = 9.393e-04 s
# z = 157.81813919999988 / 157.8181392000003. Applied: HookProcesss = 0.500 m, σ_τ = 3.989e-03 s
# z = 0.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 1.000 m, σ_τ = 3.988e-03 s
# z = 1.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 1.500 m, σ_τ = 3.986e-03 s
# z = 1.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 2.000 m, σ_τ = 3.978e-03 s
# z = 2.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 2.500 m, σ_τ = 3.932e-03 s
# z = 2.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 3.000 m, σ_τ = 3.887e-03 s
# z = 3.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 3.500 m, σ_τ = 3.850e-03 s
# z = 3.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 4.000 m, σ_τ = 3.821e-03 s
# z = 4.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 4.500 m, σ_τ = 3.795e-03 s
# z = 4.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 5.000 m, σ_τ = 3.847e-03 s
# z = 5.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 5.500 m, σ_τ = 2.324e-03 s
# z = 5.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 6.000 m, σ_τ = 9.986e-04 s
# z = 6.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 6.500 m, σ_τ = 1.016e-03 s
# z = 6.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 7.000 m, σ_τ = 9.991e-04 s
# z = 7.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 7.500 m, σ_τ = 9.821e-04 s
# z = 7.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 8.000 m, σ_τ = 9.655e-04 s
# z = 8.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 8.500 m, σ_τ = 9.493e-04 s
# z = 8.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 9.000 m, σ_τ = 9.335e-04 s
# z = 9.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 9.500 m, σ_τ = 9.181e-04 s
# z = 9.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 10.000 m, σ_τ = 9.064e-04 s
# z = 10.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 10.500 m, σ_τ = 9.015e-04 s
# z = 10.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 11.000 m, σ_τ = 8.991e-04 s
# z = 11.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 11.500 m, σ_τ = 8.978e-04 s
# z = 11.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 12.000 m, σ_τ = 8.968e-04 s
# z = 12.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 12.500 m, σ_τ = 8.957e-04 s
# z = 12.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 13.000 m, σ_τ = 8.950e-04 s
# z = 13.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 13.500 m, σ_τ = 8.945e-04 s
# z = 13.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 14.000 m, σ_τ = 8.942e-04 s
# z = 14.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 14.500 m, σ_τ = 8.939e-04 s
# z = 14.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 15.000 m, σ_τ = 8.937e-04 s
# z = 15.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 15.500 m, σ_τ = 8.935e-04 s
# z = 15.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 16.000 m, σ_τ = 8.933e-04 s
# z = 16.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 16.500 m, σ_τ = 8.932e-04 s
# z = 16.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 17.000 m, σ_τ = 8.931e-04 s
# z = 17.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 17.500 m, σ_τ = 8.930e-04 s
# z = 17.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 18.000 m, σ_τ = 8.929e-04 s
# z = 18.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 18.500 m, σ_τ = 8.928e-04 s
# z = 18.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 19.000 m, σ_τ = 8.928e-04 s
# z = 19.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 19.500 m, σ_τ = 8.928e-04 s
# z = 19.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 20.000 m, σ_τ = 8.927e-04 s
# z = 20.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 20.500 m, σ_τ = 8.927e-04 s
# z = 20.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 21.000 m, σ_τ = 8.927e-04 s
# z = 21.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 21.500 m, σ_τ = 8.926e-04 s
# z = 21.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 22.000 m, σ_τ = 8.926e-04 s
# z = 22.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 22.500 m, σ_τ = 8.926e-04 s
# z = 22.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 23.000 m, σ_τ = 8.926e-04 s
# z = 23.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 23.500 m, σ_τ = 8.925e-04 s
# z = 23.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 24.000 m, σ_τ = 8.925e-04 s
# z = 24.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 24.500 m, σ_τ = 8.925e-04 s
# z = 24.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 25.000 m, σ_τ = 8.925e-04 s
# z = 25.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 25.500 m, σ_τ = 8.925e-04 s
# z = 25.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 26.000 m, σ_τ = 8.925e-04 s
# z = 26.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 26.500 m, σ_τ = 8.925e-04 s
# z = 26.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 27.000 m, σ_τ = 8.925e-04 s
# z = 27.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 27.500 m, σ_τ = 8.925e-04 s
# z = 27.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 28.000 m, σ_τ = 8.925e-04 s
# z = 28.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 28.500 m, σ_τ = 8.925e-04 s
# z = 28.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 29.000 m, σ_τ = 8.925e-04 s
# z = 29.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 29.500 m, σ_τ = 8.925e-04 s
# z = 29.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 30.000 m, σ_τ = 8.925e-04 s
# z = 30.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 30.500 m, σ_τ = 8.925e-04 s
# z = 30.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 31.000 m, σ_τ = 8.925e-04 s
# z = 31.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 31.500 m, σ_τ = 8.925e-04 s
# z = 31.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 32.000 m, σ_τ = 8.925e-04 s
# z = 32.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 32.500 m, σ_τ = 8.925e-04 s
# z = 32.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 33.000 m, σ_τ = 8.925e-04 s
# z = 33.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 33.500 m, σ_τ = 8.925e-04 s
# z = 33.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 34.000 m, σ_τ = 8.925e-04 s
# z = 34.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 34.500 m, σ_τ = 8.925e-04 s
# z = 34.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 35.000 m, σ_τ = 8.925e-04 s
# z = 35.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 35.500 m, σ_τ = 8.925e-04 s
# z = 35.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 36.000 m, σ_τ = 8.925e-04 s
# z = 36.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 36.500 m, σ_τ = 8.925e-04 s
# z = 36.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 37.000 m, σ_τ = 8.925e-04 s
# z = 37.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 37.500 m, σ_τ = 8.925e-04 s
# z = 37.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 38.000 m, σ_τ = 8.925e-04 s
# z = 38.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 38.500 m, σ_τ = 8.925e-04 s
# z = 38.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 39.000 m, σ_τ = 8.925e-04 s
# z = 39.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 39.500 m, σ_τ = 8.925e-04 s
# z = 39.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 40.000 m, σ_τ = 8.925e-04 s
# z = 40.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 40.500 m, σ_τ = 8.925e-04 s
# z = 40.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 41.000 m, σ_τ = 8.925e-04 s
# z = 41.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 41.500 m, σ_τ = 8.925e-04 s
# z = 41.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 42.000 m, σ_τ = 8.925e-04 s
# z = 42.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 42.500 m, σ_τ = 8.925e-04 s
# z = 42.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 43.000 m, σ_τ = 8.925e-04 s
# z = 43.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 43.500 m, σ_τ = 8.925e-04 s
# z = 43.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 44.000 m, σ_τ = 8.925e-04 s
# z = 44.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 44.500 m, σ_τ = 8.925e-04 s
# z = 44.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 45.000 m, σ_τ = 8.925e-04 s
# z = 45.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 45.500 m, σ_τ = 8.925e-04 s
# z = 45.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 46.000 m, σ_τ = 8.925e-04 s
# z = 46.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 46.500 m, σ_τ = 8.925e-04 s
# z = 46.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 47.000 m, σ_τ = 8.925e-04 s
# z = 47.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 47.500 m, σ_τ = 8.925e-04 s
# z = 47.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 48.000 m, σ_τ = 8.925e-04 s
# z = 48.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 48.500 m, σ_τ = 8.926e-04 s
# z = 48.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 49.000 m, σ_τ = 8.926e-04 s
# z = 49.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 49.500 m, σ_τ = 8.926e-04 s
# z = 49.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 50.000 m, σ_τ = 8.926e-04 s
# z = 50.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 50.500 m, σ_τ = 8.926e-04 s
# z = 50.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 51.000 m, σ_τ = 8.926e-04 s
# z = 51.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 51.500 m, σ_τ = 8.926e-04 s
# z = 51.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 52.000 m, σ_τ = 8.926e-04 s
# z = 52.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 52.500 m, σ_τ = 8.926e-04 s
# z = 52.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 53.000 m, σ_τ = 8.926e-04 s
# z = 53.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 53.500 m, σ_τ = 8.926e-04 s
# z = 53.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 54.000 m, σ_τ = 8.926e-04 s
# z = 54.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 54.500 m, σ_τ = 8.926e-04 s
# z = 54.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 55.000 m, σ_τ = 8.926e-04 s
# z = 55.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 55.500 m, σ_τ = 8.926e-04 s
# z = 55.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 56.000 m, σ_τ = 8.926e-04 s
# z = 56.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 56.500 m, σ_τ = 8.926e-04 s
# z = 56.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 57.000 m, σ_τ = 8.926e-04 s
# z = 57.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 57.500 m, σ_τ = 8.926e-04 s
# z = 57.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 58.000 m, σ_τ = 8.926e-04 s
# z = 58.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 58.500 m, σ_τ = 8.926e-04 s
# z = 58.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 59.000 m, σ_τ = 8.926e-04 s
# z = 59.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 59.500 m, σ_τ = 8.926e-04 s
# z = 59.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 60.000 m, σ_τ = 8.926e-04 s
# z = 60.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 60.500 m, σ_τ = 8.926e-04 s
# z = 60.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 61.000 m, σ_τ = 8.926e-04 s
# z = 61.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 61.500 m, σ_τ = 8.926e-04 s
# z = 61.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 62.000 m, σ_τ = 8.926e-04 s
# z = 62.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 62.500 m, σ_τ = 8.926e-04 s
# z = 62.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 63.000 m, σ_τ = 8.926e-04 s
# z = 63.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 63.500 m, σ_τ = 8.926e-04 s
# z = 63.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 64.000 m, σ_τ = 8.926e-04 s
# z = 64.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 64.500 m, σ_τ = 8.926e-04 s
# z = 64.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 65.000 m, σ_τ = 8.926e-04 s
# z = 65.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 65.500 m, σ_τ = 8.926e-04 s
# z = 65.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 66.000 m, σ_τ = 8.926e-04 s
# z = 66.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 66.500 m, σ_τ = 8.926e-04 s
# z = 66.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 67.000 m, σ_τ = 8.926e-04 s
# z = 67.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 67.500 m, σ_τ = 8.926e-04 s
# z = 67.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 68.000 m, σ_τ = 8.926e-04 s
# z = 68.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 68.500 m, σ_τ = 8.926e-04 s
# z = 68.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 69.000 m, σ_τ = 8.926e-04 s
# z = 69.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 69.500 m, σ_τ = 8.926e-04 s
# z = 69.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 70.000 m, σ_τ = 8.926e-04 s
# z = 70.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 70.500 m, σ_τ = 8.926e-04 s
# z = 70.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 71.000 m, σ_τ = 8.926e-04 s
# z = 71.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 71.500 m, σ_τ = 8.926e-04 s
# z = 71.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 72.000 m, σ_τ = 8.926e-04 s
# z = 72.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 72.500 m, σ_τ = 8.926e-04 s
# z = 72.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 73.000 m, σ_τ = 8.926e-04 s
# z = 73.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 73.500 m, σ_τ = 8.926e-04 s
# z = 73.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 74.000 m, σ_τ = 8.926e-04 s
# z = 74.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 74.500 m, σ_τ = 8.926e-04 s
# z = 74.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 75.000 m, σ_τ = 8.926e-04 s
# z = 75.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 75.500 m, σ_τ = 8.926e-04 s
# z = 75.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 76.000 m, σ_τ = 8.926e-04 s
# z = 76.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 76.500 m, σ_τ = 8.926e-04 s
# z = 76.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 77.000 m, σ_τ = 8.926e-04 s
# z = 77.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 77.500 m, σ_τ = 8.926e-04 s
# z = 77.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 78.000 m, σ_τ = 8.926e-04 s
# z = 78.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 78.500 m, σ_τ = 8.926e-04 s
# z = 78.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 79.000 m, σ_τ = 8.926e-04 s
# z = 79.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 79.500 m, σ_τ = 8.926e-04 s
# z = 79.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 80.000 m, σ_τ = 8.926e-04 s
# z = 80.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 80.500 m, σ_τ = 8.926e-04 s
# z = 80.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 81.000 m, σ_τ = 8.926e-04 s
# z = 81.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 81.500 m, σ_τ = 8.926e-04 s
# z = 81.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 82.000 m, σ_τ = 8.926e-04 s
# z = 82.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 82.500 m, σ_τ = 8.926e-04 s
# z = 82.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 83.000 m, σ_τ = 8.926e-04 s
# z = 83.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 83.500 m, σ_τ = 8.926e-04 s
# z = 83.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 84.000 m, σ_τ = 8.926e-04 s
# z = 84.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 84.500 m, σ_τ = 8.926e-04 s
# z = 84.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 85.000 m, σ_τ = 8.926e-04 s
# z = 85.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 85.500 m, σ_τ = 8.926e-04 s
# z = 85.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 86.000 m, σ_τ = 8.926e-04 s
# z = 86.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 86.500 m, σ_τ = 8.926e-04 s
# z = 86.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 87.000 m, σ_τ = 8.926e-04 s
# z = 87.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 87.500 m, σ_τ = 8.926e-04 s
# z = 87.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 88.000 m, σ_τ = 8.926e-04 s
# z = 88.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 88.500 m, σ_τ = 8.926e-04 s
# z = 88.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 89.000 m, σ_τ = 8.926e-04 s
# z = 89.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 89.500 m, σ_τ = 8.926e-04 s
# z = 89.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 90.000 m, σ_τ = 8.926e-04 s
# z = 90.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 90.500 m, σ_τ = 8.926e-04 s
# z = 90.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 91.000 m, σ_τ = 8.926e-04 s
# z = 91.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 91.500 m, σ_τ = 8.926e-04 s
# z = 91.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 92.000 m, σ_τ = 8.926e-04 s
# z = 92.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 92.500 m, σ_τ = 8.926e-04 s
# z = 92.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 93.000 m, σ_τ = 8.926e-04 s
# z = 93.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 93.500 m, σ_τ = 8.926e-04 s
# z = 93.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 94.000 m, σ_τ = 8.926e-04 s
# z = 94.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 94.500 m, σ_τ = 8.926e-04 s
# z = 94.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 95.000 m, σ_τ = 8.926e-04 s
# z = 95.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 95.500 m, σ_τ = 8.926e-04 s
# z = 95.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 96.000 m, σ_τ = 8.926e-04 s
# z = 96.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 96.500 m, σ_τ = 8.926e-04 s
# z = 96.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 97.000 m, σ_τ = 8.926e-04 s
# z = 97.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 97.500 m, σ_τ = 8.926e-04 s
# z = 97.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 98.000 m, σ_τ = 8.926e-04 s
# z = 98.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 98.500 m, σ_τ = 8.926e-04 s
# z = 98.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 99.000 m, σ_τ = 8.926e-04 s
# z = 99.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 99.500 m, σ_τ = 8.926e-04 s
# z = 99.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 100.000 m, σ_τ = 8.926e-04 s
# z = 100.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 100.500 m, σ_τ = 8.926e-04 s
# z = 100.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 101.000 m, σ_τ = 8.926e-04 s
# z = 101.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 101.500 m, σ_τ = 8.926e-04 s
# z = 101.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 102.000 m, σ_τ = 8.926e-04 s
# z = 102.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 102.500 m, σ_τ = 8.926e-04 s
# z = 102.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 103.000 m, σ_τ = 8.926e-04 s
# z = 103.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 103.500 m, σ_τ = 8.926e-04 s
# z = 103.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 104.000 m, σ_τ = 8.926e-04 s
# z = 104.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 104.500 m, σ_τ = 8.926e-04 s
# z = 104.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 105.000 m, σ_τ = 8.926e-04 s
# z = 105.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 105.500 m, σ_τ = 8.926e-04 s
# z = 105.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 106.000 m, σ_τ = 8.926e-04 s
# z = 106.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 106.500 m, σ_τ = 8.926e-04 s
# z = 106.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 107.000 m, σ_τ = 8.926e-04 s
# z = 107.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 107.500 m, σ_τ = 8.926e-04 s
# z = 107.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 108.000 m, σ_τ = 8.926e-04 s
# z = 108.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 108.500 m, σ_τ = 8.926e-04 s
# z = 108.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 109.000 m, σ_τ = 8.926e-04 s
# z = 109.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 109.500 m, σ_τ = 8.926e-04 s
# z = 109.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 110.000 m, σ_τ = 8.926e-04 s
# z = 110.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 110.500 m, σ_τ = 8.926e-04 s
# z = 110.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 111.000 m, σ_τ = 8.926e-04 s
# z = 111.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 111.500 m, σ_τ = 8.926e-04 s
# z = 111.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 112.000 m, σ_τ = 8.926e-04 s
# z = 112.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 112.500 m, σ_τ = 8.926e-04 s
# z = 112.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 113.000 m, σ_τ = 8.926e-04 s
# z = 113.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 113.500 m, σ_τ = 8.926e-04 s
# z = 113.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 114.000 m, σ_τ = 8.926e-04 s
# z = 114.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 114.500 m, σ_τ = 8.926e-04 s
# z = 114.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 115.000 m, σ_τ = 8.926e-04 s
# z = 115.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 115.500 m, σ_τ = 8.926e-04 s
# z = 115.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 116.000 m, σ_τ = 8.926e-04 s
# z = 116.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 116.500 m, σ_τ = 8.926e-04 s
# z = 116.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 117.000 m, σ_τ = 8.926e-04 s
# z = 117.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 117.500 m, σ_τ = 8.926e-04 s
# z = 117.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 118.000 m, σ_τ = 8.926e-04 s
# z = 118.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 118.500 m, σ_τ = 8.926e-04 s
# z = 118.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 119.000 m, σ_τ = 8.926e-04 s
# z = 119.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 119.500 m, σ_τ = 8.926e-04 s
# z = 119.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 120.000 m, σ_τ = 8.926e-04 s
# z = 120.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 120.500 m, σ_τ = 8.926e-04 s
# z = 120.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 121.000 m, σ_τ = 8.926e-04 s
# z = 121.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 121.500 m, σ_τ = 8.926e-04 s
# z = 121.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 122.000 m, σ_τ = 8.926e-04 s
# z = 122.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 122.500 m, σ_τ = 8.926e-04 s
# z = 122.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 123.000 m, σ_τ = 8.926e-04 s
# z = 123.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 123.500 m, σ_τ = 8.926e-04 s
# z = 123.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 124.000 m, σ_τ = 8.926e-04 s
# z = 124.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 124.500 m, σ_τ = 8.926e-04 s
# z = 124.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 125.000 m, σ_τ = 8.926e-04 s
# z = 125.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 125.500 m, σ_τ = 8.926e-04 s
# z = 125.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 126.000 m, σ_τ = 8.926e-04 s
# z = 126.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 126.500 m, σ_τ = 8.797e-04 s
# z = 126.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 127.000 m, σ_τ = 8.425e-04 s
# z = 127.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 127.500 m, σ_τ = 7.785e-04 s
# z = 127.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 128.000 m, σ_τ = 8.241e-04 s
# z = 128.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 128.500 m, σ_τ = 8.480e-04 s
# z = 128.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 129.000 m, σ_τ = 8.480e-04 s
# z = 129.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 129.500 m, σ_τ = 8.480e-04 s
# z = 129.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 130.000 m, σ_τ = 8.480e-04 s
# z = 130.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 130.500 m, σ_τ = 9.957e-04 s
# z = 130.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 131.000 m, σ_τ = 1.060e-03 s
# z = 131.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 131.500 m, σ_τ = 9.856e-04 s
# z = 131.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 132.000 m, σ_τ = 8.695e-04 s
# z = 132.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 132.500 m, σ_τ = 8.644e-04 s
# z = 132.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 133.000 m, σ_τ = 8.644e-04 s
# z = 133.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 133.500 m, σ_τ = 8.644e-04 s
# z = 133.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 134.000 m, σ_τ = 8.644e-04 s
# z = 134.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 134.500 m, σ_τ = 8.507e-04 s
# z = 134.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 135.000 m, σ_τ = 1.012e-03 s
# z = 135.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 135.500 m, σ_τ = 1.117e-03 s
# z = 135.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 136.000 m, σ_τ = 1.064e-03 s
# z = 136.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 136.500 m, σ_τ = 1.064e-03 s
# z = 136.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 137.000 m, σ_τ = 1.064e-03 s
# z = 137.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 137.500 m, σ_τ = 1.064e-03 s
# z = 137.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 138.000 m, σ_τ = 1.064e-03 s
# z = 138.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 138.500 m, σ_τ = 9.809e-04 s
# z = 138.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 139.000 m, σ_τ = 9.511e-04 s
# z = 139.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 139.500 m, σ_τ = 1.048e-03 s
# z = 139.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 140.000 m, σ_τ = 1.363e-03 s
# z = 140.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 140.500 m, σ_τ = 1.363e-03 s
# z = 140.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 141.000 m, σ_τ = 1.363e-03 s
# z = 141.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 141.500 m, σ_τ = 1.363e-03 s
# z = 141.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 142.000 m, σ_τ = 1.363e-03 s
# z = 142.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 142.500 m, σ_τ = 1.561e-03 s
# z = 142.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 143.000 m, σ_τ = 1.696e-03 s
# z = 143.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 143.500 m, σ_τ = 1.653e-03 s
# z = 143.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 144.000 m, σ_τ = 1.398e-03 s
# z = 144.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 144.500 m, σ_τ = 1.398e-03 s
# z = 144.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 145.000 m, σ_τ = 1.398e-03 s
# z = 145.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 145.500 m, σ_τ = 1.398e-03 s
# z = 145.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 146.000 m, σ_τ = 1.398e-03 s
# z = 146.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 146.500 m, σ_τ = 1.070e-03 s
# z = 146.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 147.000 m, σ_τ = 9.305e-04 s
# z = 147.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 147.500 m, σ_τ = 8.925e-04 s
# z = 147.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 148.000 m, σ_τ = 8.912e-04 s
# z = 148.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 148.500 m, σ_τ = 8.912e-04 s
# z = 148.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 149.000 m, σ_τ = 8.912e-04 s
# z = 149.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 149.500 m, σ_τ = 8.912e-04 s
# z = 149.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 150.000 m, σ_τ = 8.912e-04 s
# z = 150.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 150.500 m, σ_τ = 8.912e-04 s
# z = 150.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 151.000 m, σ_τ = 8.912e-04 s
# z = 151.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 151.500 m, σ_τ = 8.912e-04 s
# z = 151.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 152.000 m, σ_τ = 8.912e-04 s
# z = 152.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 152.500 m, σ_τ = 8.912e-04 s
# z = 152.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 153.000 m, σ_τ = 8.912e-04 s
# z = 153.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 153.500 m, σ_τ = 8.912e-04 s
# z = 153.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 154.000 m, σ_τ = 8.912e-04 s
# z = 154.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 154.500 m, σ_τ = 8.912e-04 s
# z = 154.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 155.000 m, σ_τ = 8.912e-04 s
# z = 155.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 155.500 m, σ_τ = 8.912e-04 s
# z = 155.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 156.000 m, σ_τ = 8.912e-04 s
# z = 156.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 156.500 m, σ_τ = 8.912e-04 s
# z = 156.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 157.000 m, σ_τ = 8.912e-04 s
# z = 157.0 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 157.500 m, σ_τ = 8.912e-04 s
# z = 157.5 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWakes = 157.818 m, σ_τ = 8.912e-04 s
# z = 157.81813919999988 / 157.8181392000003. Applied: HookProcess, CustomLongitudinalWake

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract z positions (longitudinal coordinates) in meters
z_meters = p_array_wake.rparticles[4]  # assuming this is AFTER tracking

# Histogram to get longitudinal density profile
nbins = 2048
zmin, zmax = z_meters.min(), z_meters.max()
hist, bin_edges = np.histogram(z_meters, bins=nbins, range=(zmin, zmax))
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# Perform FFT
fft_result = np.fft.fft(hist - np.mean(hist))  # remove DC offset
fft_freq = np.fft.fftfreq(nbins, d=(bin_centers[1] - bin_centers[0]))  # in 1/m

# Compute bunching factor magnitude
bunching = np.abs(fft_result) / np.sum(hist)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(fft_freq[1:nbins//2], bunching[1:nbins//2])
plt.xlabel("Wavenumber $k$ [1/m]")
plt.ylabel("Bunching factor $b(k)$")
plt.title("Fourier-based Microbunching Analysis")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Energy distributions (Δp/p)
dp_p_no_wake = p_array_no_wake.rparticles[5]
dp_p_wake = p_array_wake.rparticles[5]

plt.figure(figsize=(8,6))
plt.hist(dp_p_no_wake, bins=200, histtype='step', label='No Wake', density=True)
plt.hist(dp_p_wake, bins=200, histtype='step', label='With Custom Wake', density=True, linestyle='--')
plt.xlabel('Δp/p')
plt.ylabel('Normalized counts')
plt.title('Energy distribution comparison')
plt.xlim(-0.1,0.1)
plt.grid(True)
plt.legend()
plt.show()

# %%
show_e_beam(p_array_no_wake)

# %%
show_e_beam(p_array_wake)

# %%
import numpy as np

# particle data 
np.save("particles_rparticles_wake.npy", p_array_wake.rparticles)

# charge array
np.save("particles_q_array_wake.npy", p_array_wake.q_array)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import gamma, hyp1f1

# Constants
Z0 = 377  # impedance of free space [Ohm]
c = 3e8   # speed of light [m/s]
Ne = 2e9  # number of electrons in bunch (e.g. 2 nC bunch charge)
sigma_z = 1e-3  # bunch length [m]
L = sigma_z     # length scale (as used in slide)

# Longitudinal grid
z = np.linspace(-5*sigma_z, 5*sigma_z, 1000)  # z in meters
x = z / sigma_z

# Function f_n(x) from slide (only few terms for demonstration)
def f_n(x, n):
    prefactor = ((-1)**n) * (2**(n/2)) / np.sqrt(np.math.factorial(n))
    # Approximate: keep only leading term of hypergeometric and gamma expressions
    # This is a simplification since full special function series is complex
    return prefactor * np.exp(-x**2 / 2) * np.polynomial.hermite.hermval(x, [0]*n + [1])

# Sum over few terms
Vz = np.zeros_like(x)
for n in range(5):  # Truncate at n=4 for simplicity
    Vz += f_n(x, n)

Vz_sum = np.zeros_like(x)
for n in range(5):  # Truncate at n=4
    Vz_sum += f_n(x, n)

Vz = Vz_sum / np.max(np.abs(Vz_sum)) * 1e5  # Normalize and scale to ~100 kV


# Normalize for plotting
Vz_norm = Vz / np.max(np.abs(Vz))

# Plot
plt.figure(figsize=(10,6))
plt.plot(z*1e3, Vz_norm, label='Analytical $V_z(z)$ (normalized)', color='tab:red')
plt.xlabel("z [mm]")
plt.ylabel("Normalized $V_z(z)$")
plt.title("Analytical Wakefield Voltage Distribution $V_z(z)$")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_64545/3494393891.py:18: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   prefactor = ((-1)**n) * (2**(n/2)) / np.sqrt(np.math.factorial(n))

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- Assume this is after tracking with wake ---
# z and Vz from the analytical calculation
# Use same z and Vz arrays from your earlier Vz computation
# e.g., z = np.linspace(-5*sigma_z, 5*sigma_z, 1000) in meters
# Vz = ... from analytical formula

z_center = np.mean(z_particles)
z_grid = np.linspace(-5*sigma_z, 5*sigma_z, 1000) + z_center
      # array from analytical formula (in meters)
Vz_analytical = Vz # voltage in volts

# Particle positions from tracked data
z_particles = p_array_wake.rparticles[4]  # in meters

# Interpolate Vz onto particle positions
Vz_interp = np.interp(z_particles, z_grid, Vz_analytical)

# Convert to Δp/p
energy_GeV = p_array_wake.E
delta_E_J = Vz_interp * 1.602e-19
delta_dp_p_analytical = delta_E_J / (energy_GeV * 1e9 * 1.602e-19)  # unitless

# Get simulated Δp/p
delta_dp_p_simulated = p_array_wake.rparticles[5]

# Histogram of particle z-positions (bunch shape)
hist, bins = np.histogram(p_array_wake.rparticles[4], bins=100, range=(z.min(), z.max()))
centers = 0.5 * (bins[1:] + bins[:-1])

plt.figure(figsize=(10,6))
plt.plot(centers * 1e3, hist / np.max(hist), label='Normalized Bunch Profile')
plt.plot(z * 1e3, Vz / np.max(np.abs(Vz)), label='Normalized $V_z(z)$', linestyle='--')
plt.xlabel("z [mm]")
plt.ylabel("Arbitrary Units")
plt.title("Wake Potential vs Beam Distribution")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()


from sklearn.metrics import mean_squared_error

# Apply correct units first
delta_dp_p_analytical = Vz_interp / (energy_GeV * 1e9)

# Remove any non-finite or extreme outliers
mask = np.isfinite(delta_dp_p_analytical) & np.isfinite(delta_dp_p_simulated)
mask &= np.abs(delta_dp_p_analytical) < 0.2
mask &= np.abs(delta_dp_p_simulated) < 0.2

# Ensure we have enough data to compare
if np.count_nonzero(mask) > 0:
    rms_error = np.sqrt(mean_squared_error(
        delta_dp_p_simulated[mask], delta_dp_p_analytical[mask]))
    print(f"✅ RMS error between analytical and simulated Δp/p: {rms_error:.2e}")
else:
    print("⚠️ No valid data points found within threshold for RMS comparison.")
# Out:
# ✅ RMS error between analytical and simulated Δp/p: 1.15e-02
